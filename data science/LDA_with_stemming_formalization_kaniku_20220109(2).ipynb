# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.53.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  *
FROM
  `future-data-track-1.sapporo_mart.topic_modelling`
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0                                     IKLAN NYA GANGGU AS*       1
# 1        Pihak lazada tolong di mengerti masa saya pesa...       1
# 2                            Iklan trossssssss, ganggu aja       1
# 3        Lazada Ruwet anjir. Mau menggunakan metode pem...       1
# 4        Dih jangan dwon ni aplikasi tempat para penipu...       1
# ...                                                    ...     ...
# 1695878                                    Sangat membantu       5
# 1695879                                    Sangat membantu       5
# 1695880                                    Sangat membantu       5
# 1695881                                    Sangat membantu       5
# 1695882                                    Sangat membantu       5
#
# [1695883 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"belum","cuiiihhh","bangt","selamat","begitu","bhineka","situ","loh","deh"
    ,"mah","yaa","tapi","the","karena","padabal","ttep","sopi","ealah","mas"
    ,"kampreeeeet","busetttt","tahi","ah","sich","tokped","lzd","gada","gatau"
    ,"udh","ttep","ehhh","bosss","wkekwk","bajing","laknat","asuuu","ku","woiii"
    ,"gueeee","njerr","waduhhhh","ma","dunk","dunk","untuk","dll","brupa"
    ,"sangatx","niih","bos","eh","smua","gni","bye","ajah","gilee","luu","ndro"
    ,"dg","kga","min","sm","haisshhh","piye","iki","skali","hehehe","ms","juga"
    ,"fff","mamam","inibsangat","andri","yopiyanto","broo","donk","tes","si"
    ,"ter","dech","wow","oh","toped","dahhhh","grab","ijo","oren","ovo","gopay"
    ,"kredivo","sok","david","gaes","dr","ovonya","bbrp","gmna","bbrpa","and"
    ,"uah","uhahhhhhh","topeeed","ngak","kamu","anj","nge","lah","linkaja"
    ,"gosend","sicepat","jne","yah","goto","gofood","goride","prakerja"
    ,"haduhhhh","pediya","kakak","hhe","bro","bismillah","fuulll","goof"
    ,"assalamualaikum","atsu","pea","you","agan","semenjak","gojek","lagiii"
    ,"lagi","bts","kkzara","cog","aaaaa","sich","cih","ciyy","padahal","ad"
    ,"adlh","ahaha","aj","ak","akika","akkoh","akuwh","alow","anjrit","ap2"
    ,"apasih","aps","aq","aqueh","q","asem","ato","awak","bakalan","bangedh"
    ,"bcanda","beud","bg","bgmn","bgt","bkl","bknnya","blum","boljug","boyeh"
    ,"bs","bt","btw","bwt","byk","can","thanks","d","dah","dapet","de","dek"
    ,"deyh","dgn","disono","dkk","dlu","dngn","dongs","dpt","dri","drmn","drtd"
    ,"dst","duh","egp","eke","ane","ente","elu","emangnya","emng","endak"
    ,"enggak","gaada","gag","gaje","gpp","gan","gbs","geje","ghiy","gimana"
    ,"githu","gj","gn","gt","gpny","gr","gtau","guoblok","ha","haha","hallow"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar","buka","lapak"
    ,"terima","kasih","alhamdulillah","pokok"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review'].values]]

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token
# Out:
#                                                     review  rating
# 0                                          iklan ganggu as       1
# 1                                  tolong erti pesan pesan       1
# 2                                 iklan trossssssss ganggu       1
# 3        ruwet metode bayar indomart mlh cod aplikasi v...       1
# 4        dih dwon aplikasi tipu order giveaway hp perca...       1
# ...                                                    ...     ...
# 1475049  belanja shoppe bantu temu barang dng cepat har...       5
# 1475050    sampe skrg pake alhamdulilah gapernah ngecewain       5
# 1475052     enk blanja shopeee tigkatkn gratis ongkir psan       5
# 1475053                                  belanja kirim cpt       5
# 1475055                               layan belanja shoope       5
#
# [767125 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['iklan', 'ganggu', 'as'],
#  ['tolong', 'erti', 'pesan', 'pesan'],
#  ['iklan', 'trossssssss', 'ganggu'],
#  ['ruwet', 'metode', 'bayar', 'indomart', 'mlh', 'cod', 'aplikasi', 'voucher'],
#  ['dih',
#   'dwon',
#   'aplikasi',
#   'tipu',
#   'order',
#   'giveaway',
#   'handphone',
#   'percaya',
#   'dateng',
#   'kawat',
#   'bayar',
#   'ribu',
#   'masak',
#   'kasi',
#   'kawat',
#   'untung',
#   'gin',
#   'tipu',
#   'bgettt',
#   'yaaa',
#   'gesss',
#   'aman',
#   'percaya',
#   'tukang',
#   'tipu',
#   'kaya',
#   'hapus',
#   'lgsung',
#   'aplikasi'],
#  ['cashbacknya', 'dapetnya', 'kirim', 'dikit', 'serius', 'bikin', 'promo'],
#  ['bnrn',
#   'sya',
#   'menang',
#   'untung',
#   'undi',
#   'handphone',
#   'ip',
#   'kirim',
#   'alamat',
#   'tinggal',
#   'sya',
#   'kp',
#   'rawahingkik',
#   'rt',
#   'rw',
#   'cileungsi',
#   'bogor',
#   'ichat'],
#  ['keluh', 'langgan', 'tanggung'],
#  ['pocer', 'tapi', 'ngk'],
#  ['ui', 'ribet'],
#  ['aplikasi', 'pesan', 'barang', 'bayar', 'barang', 'pesan', 'nyampe'],
#  ['keluan',
#   'setelah',
#   'bc',
#   'komntr',
#   'apa',
#   'banyak',
#   'penipuny',
#   'pelyananya'],
#  ['transaksi', 'tranfer', 'uang'],
#  ['cok', 'asyifa'],
#  ['ampuh', 'sehat', 'aman', 'damai'],
#  ['males', 'belanja', 'shope', 'lebih baik', 'toko', 'belah'],
#  ['maf',
#   'aplikasi',
#   'sayah',
#   'terimna',
#   'hadiah',
#   'puter',
#   'katnya',
#   'hadiah',
#   'uang',
#   'tapi',
#   'bacan',
#   'ambil',
#   'uang',
#   'sama',
#   'hadia',
#   'sayah',
#   'terimna',
#   'aplikasi',
#   'nga',
#   'bisin',
#   'kuota',
#   'bantu',
#   'jawap',
#   'kenah',
#   'ambil'],
#  ['beli', 'barang', 'sesuai', 'boykot'],
#  ['tolong', 'cepat'],
#  ['membaii', 'layanan'],
#  ['ban', 'ban', 'bekas'],
#  ['toko', 'beli', 'gantung', 'tas', 'nggkak', 'kirim', 'kirim'],
#  ['cod', 'transfer', 'proses', 'bikin', 'ribet'],
#  ['rupiah', 'ongkir', 'bayar'],
#  ['gratis',
#   'ongkir',
#   'promo',
#   'cashback',
#   'juga',
#   'hilang',
#   'pindah',
#   'aplikasi',
#   'nihh'],
#  ['kode',
#   'verifikasi',
#   'otp',
#   'sulit',
#   'verifikasi',
#   'whatsapp',
#   'nomer',
#   'via',
#   'telepon',
#   'nyampe',
#   'gin',
#   'bikin',
#   'sulit',
#   'daftar',
#   'shoppe',
#   'bayar',
#   'maaf',
#   'lanjur',
#   'harap',
#   'sistem',
#   'verifikasi',
#   'kode',
#   'otp',
#   'ribet',
#   'cuman',
#   'ganti',
#   'pasword',
#   'simple',
#   'maju',
#   'kayak',
#   'gin'],
#  ['belanja',
#   'barang',
#   'dateng',
#   'lapor',
#   'kirim',
#   'alhasil',
#   'bolak',
#   'ekspedisi',
#   'plus',
#   'debat',
#   'jual',
#   'uang',
#   'hilang',
#   'barang',
#   'nyampe',
#   'jujur',
#   'ekspedisi',
#   'expres'],
#  ['akun',
#   'nonaktif',
#   'order',
#   'bayar',
#   'shopeepay',
#   'nonaktif',
#   'jlskan',
#   'salah'],
#  ['proses',
#   'rim',
#   'padhal',
#   'update',
#   'tepaksa',
#   'batal',
#   'prises',
#   'kirim',
#   'tolong',
#   'dibantuh'],
#  ['paylater', 'beku', 'limit', 'terlambat', 'bayar', 'solusi'],
#  ['aplikasi',
#   'ndk',
#   'masak',
#   'beli',
#   'speaker',
#   'gantung',
#   'kunci',
#   'tolong',
#   'tok',
#   'bossku',
#   'aplikasi',
#   'rusak',
#   'serius'],
#  ['terkadang', 'dilazada', 'barang', 'sesuai'],
#  ['tukang',
#   'tipu',
#   'aplikasi',
#   'kawan',
#   'kawan',
#   'jngan',
#   'unduh',
#   'aplikasi',
#   'modus',
#   'tipu',
#   'iming',
#   'iming',
#   'hadiah',
#   'lebih baik',
#   'unduh',
#   'bonus'],
#  ['dtipu',
#   'muncul',
#   'pembritahuan',
#   'memdapat',
#   'hadiah',
#   'cmn',
#   'suruh',
#   'install',
#   'aplikasi',
#   'tempek'],
#  ['error', 'yaaaaaaa'],
#  ['iklan', 'akeh', 'cok'],
#  ['idexpress', 'hapus', 'paket', 'regelur', 'sampai'],
#  ['unduh', 'bantu'],
#  ['susah', 'memasukkn', 'otp', 'kirim'],
#  ['ngk', 'aplikasi'],
#  ['install', 'anjenk'],
#  ['emosi',
#   'internet',
#   'aplikasi',
#   'lancar',
#   'pas',
#   'shope',
#   'ketik',
#   'cari',
#   'pencet',
#   'enter',
#   'emosi',
#   'jam',
#   'seperti',
#   'besok',
#   'seperti',
#   'loading',
#   'pas',
#   'loading',
#   'produk',
#   'temu',
#   'tahu',
#   'barang',
#   'cari',
#   'iseng',
#   'sia',
#   'sia',
#   'tunggu'],
#  ['saldo', 'blokir', 'tolong', 'customer', 'care', 'aktifin', 'saldo'],
#  ['jangan',
#   'belanja',
#   'tipu',
#   'pesan',
#   'kirim',
#   'pakai',
#   'metode',
#   'bayar',
#   'cod',
#   'kurir',
#   'bilang',
#   'bayar',
#   'jual',
#   'prnah',
#   'beli',
#   'bareng',
#   'sesuai',
#   'pas',
#   'cod',
#   'dpn',
#   'kurir',
#   'kurir',
#   'sendiri',
#   'inisiatif',
#   'bilang',
#   'jual',
#   'basa',
#   'basi',
#   'rugi',
#   'tipu',
#   'berkah',
#   'makan',
#   'tu',
#   'duit',
#   'haram',
#   'ikhlas',
#   'dunia',
#   'akhirat'],
#  ['pesan',
#   'balik',
#   'gudang',
#   'lagi',
#   'kurir',
#   'wilayah',
#   'kirim',
#   'suruh',
#   'tunggu',
#   'lagi',
#   'sesuai',
#   'wilayah',
#   'kirim'],
#  ['iklanya', 'lindung', 'handphone', 'mu', 'viruz', 'pas', 'pencet', 'malak'],
#  ['tipu', 'tolong', 'pantau', 'jual', 'tipu', 'tolak'],
#  ['aplikasi',
#   'taiii',
#   'mesen',
#   'sampai',
#   'pas',
#   'sampai',
#   'barang',
#   'sampai',
#   'cancel',
#   'costumer'],
#  ['loading', 'berat', 'susahhhh'],
#  ['njirrr', 'selancar', 'alih', 'ksini', 'vanke'],
#  ['pesan',
#   'photocard',
#   'taehyung',
#   'eror',
#   'ulang',
#   'pas',
#   'checkout',
#   'notif',
#   'barang',
#   'saldo',
#   'potong',
#   'tolong',
#   'jngn',
#   'sperti'],
#  ['aplikasi', 'iklan', 'ngotak', 'mentang', 'duit', 'bikin', 'iklan'],
#  ['sebal',
#   'kesini',
#   'akun',
#   'apain',
#   'gagal',
#   'checkout',
#   'alas',
#   'curiga',
#   'janggal',
#   'ngeselin',
#   'pakai',
#   'shopeepay',
#   'gilir',
#   'pakai',
#   'bayar',
#   'gratis',
#   'ongkir',
#   'cashback',
#   'dipake',
#   'shopeepay',
#   'tolong',
#   'bikin',
#   'ribet'],
#  ['milih',
#   'jasa',
#   'ekspedisi',
#   'monopoli',
#   'express',
#   'cepat',
#   'sukur',
#   'paket',
#   'kirim',
#   'jakarta',
#   'estimasi',
#   'oktober',
#   'karawang',
#   'alih',
#   'toko'],
#  ['iklan', 'muncul', 'konttttttoooooooollllllllllll'],
#  ['kesel',
#   'update',
#   'diupdate',
#   'februari',
#   'besok',
#   'update',
#   'event',
#   'tanggal',
#   'februari',
#   'berat',
#   'handphone',
#   'handphone',
#   'kentang',
#   'ngebul',
#   'kuat',
#   'pakai',
#   'aplikasi',
#   'proses',
#   'belanja',
#   'gampang'],
#  ['pelit', 'ongkir', 'belanja', 'aplikasi', 'sedih', 'epribadi'],
#  ['iklan', 'muncul', 'ng'],
#  ['beli',
#   'sadar',
#   'barang',
#   'beli',
#   'beda',
#   'berat',
#   'tulis',
#   'berat',
#   'berat',
#   'sesunguhnya',
#   'berat',
#   'kg',
#   'tulis',
#   'kg',
#   'bayar',
#   'kg',
#   'kg',
#   'beli',
#   'ambil',
#   'bonus',
#   'beli',
#   'beli',
#   'cari',
#   'berat',
#   'barang',
#   'wajar',
#   'berat',
#   'sesuai',
#   'beda',
#   'kg',
#   'wajar',
#   'beda',
#   'kg',
#   'ajar'],
#  ['aplokasi', 'ribet', 'mau', 'jual', 'susah'],
#  ['member', 'platinum', 'shopepay', 'later', 'aktif', 'payahhh'],
#  ['spaylater',
#   'mesti',
#   'verifikasi',
#   'wajah',
#   'gagal',
#   'bayar',
#   'cicil',
#   'cicil',
#   'pakek',
#   'spaylater',
#   'malas',
#   'atm',
#   'sistem',
#   'bayar',
#   'sms',
#   'banking',
#   'kendala',
#   'malas',
#   'belanja',
#   'dishopee'],
#  ['seperti', 'ngk'],
#  ['ngapain', 'nongol', 'melulu', 'iklan', 'aplikasi', 'ganggu'],
#  ['unduh', 'update', 'hahaha', 'untung'],
#  ['hapus',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'hapus',
#   'bantu'],
#  ['sistem', 'beli', 'pulsa', 'uang', 'cepat', 'bangkrut', 'amin'],
#  ['dindownliad', 'hapus'],
#  ['isi',
#   'saldo',
#   'shoopepay',
#   'pas',
#   'klik',
#   'bank',
#   'virtual',
#   'account',
#   'blank',
#   'layar',
#   'handphone',
#   'putih',
#   'refresh',
#   'tetep',
#   'adehhhh',
#   'transaksi',
#   'njengggg'],
#  ['olshop',
#   'hancur',
#   'jasa',
#   'ekpedisi',
#   'kurir',
#   'amanh',
#   'smoga',
#   'benah',
#   'olshop',
#   'bagaimna',
#   'prioritas',
#   'customer'],
#  ['beli',
#   'handphone',
#   'barang',
#   'sesuai',
#   'retur',
#   'handphone',
#   'jual',
#   'uang',
#   'bantu',
#   'admin'],
#  ['toko', 'bnyak', 'tipu'],
#  ['aplikasi',
#   'tipu',
#   'program',
#   'promo',
#   'cashback',
#   'bodoh',
#   'rugi',
#   'nyesal',
#   'pokok'],
#  ['amanah',
#   'bayar',
#   'dibatalin',
#   'sistem',
#   'dana',
#   'dikembaliin',
#   'juga',
#   'belanja',
#   'tolong',
#   'cari',
#   'uang',
#   'susah',
#   'fikembalikan',
#   'cepat'],
#  ['sapi',
#   'lajanda',
#   'ribet',
#   'akun',
#   'cuman',
#   'handphone',
#   'ttp',
#   'batal',
#   'sistem',
#   'busul'],
#  ['shoope', 'pesan', 'dibatalin', 'tampa', 'konfirmasi'],
#  ['aplikasi', 'lambat', 'unduh'],
#  ['cari', 'tahu', 'tahu'],
#  ['kurir',
#   'expres',
#   'mahal',
#   'beda',
#   'kurir',
#   'ribu',
#   'pakai',
#   'expres',
#   'ribu',
#   'pakai',
#   'voucher',
#   'no',
#   'ongkir',
#   'tetep',
#   'biaya',
#   'ongkir'],
#  ['tanam',
#   'blank',
#   'eror',
#   'update',
#   'cache',
#   'uninstall',
#   'install',
#   'begtu'],
#  ['proses',
#   'bayar',
#   'btl',
#   'seller',
#   'tolong',
#   'bayar',
#   'cepat',
#   'cod',
#   'tindak',
#   'lh',
#   'mksh'],
#  ['toko',
#   'jual',
#   'barang',
#   'sesuai',
#   'klik',
#   'pesan',
#   'bantu',
#   'solusi',
#   'tertawa'],
#  ['daftar', 'susah'],
#  ['belanja', 'barang', 'batal', 'otomatis', 'terssss', 'kezeellllll'],
#  ['susah',
#   'cari',
#   'barang',
#   'isi',
#   'barang',
#   'pasang',
#   'harga',
#   'perut',
#   'efek',
#   'gampang',
#   'bikin',
#   'bahan',
#   'timbang',
#   'bikin',
#   'betah',
#   'buyer'],
#  ['shopeepay', 'later', 'jngan', 'bayar', 'sllu'],
#  ['ganggu', 'jual', 'murah', 'iklaaaan', 'terusss', 'kamorer'],
#  ['loginnya', 'login', 'pakai', 'no', 'telepon', 'error'],
#  ['bnyak',
#   'seller',
#   'tipu',
#   'hati',
#   'ditelfon',
#   'seller',
#   'remote',
#   'akun',
#   'shopeenya',
#   'tolong',
#   'aplikasiny',
#   'update',
#   'refund',
#   'jangan',
#   'bgitu',
#   'batal',
#   'refund',
#   'uang',
#   'tunggu',
#   'hari'],
#  ['aplikasi', 'ongkir', 'bayar'],
#  ['iklan', 'melulu'],
#  ['update', 'pas', 'update', 'error', 'komplain', 'fast', 'respon', 'solusi'],
#  ['engga',
#   'kapok',
#   'layan',
#   'super',
#   'dengar',
#   'komplain',
#   'langgan',
#   'langgan',
#   'kompalin',
#   'tetbaik',
#   'dengar',
#   'terkadang',
#   'fiturr',
#   'chat',
#   'mati',
#   'layan'],
#  ['maaf',
#   'kenape',
#   'verifikasi',
#   'sms',
#   'susah',
#   'bug',
#   'verifikasi',
#   'sms',
#   'auto',
#   'mengisi',
#   'salah',
#   'kode',
#   'kode',
#   'tulis',
#   'ulang',
#   'hapus',
#   'keyboard',
#   'ngetik',
#   'angka',
#   'bug',
#   'ganggu',
#   'asli',
#   'ampas',
#   'aplikasi',
#   'tolong',
#   'kasi',
#   'hadeh',
#   'ecommerce',
#   'indonesia',
#   'gin',
#   'ampas',
#   'hadeuh'],
#  ['barang',
#   'bilang',
#   'siap',
#   'pas',
#   'transfer',
#   'chat',
#   'balas',
#   'aplikasi',
#   'jual'],
#  ['maaf', 'toko', 'kirim', 'sesuai', 'pesan', 'ulang', 'ulang'],
#  ['iklan', 'melulu', 'aplikasi', 'droppppp'],
#  ['toko', 'tipu'],
#  ['belanja',
#   'dilazada',
#   'garansi',
#   'uang',
#   'hoaks',
#   'barang',
#   'sesuai',
#   'tahu',
#   'return',
#   'dh'],
#  ['eror', 'kode', 'io', 'buin'],
#  ['aplikasi', 'ganggu'],
#  ['livenya',
#   'rekam',
#   'diposting',
#   'minggu',
#   'baju',
#   'postingan',
#   'minggu',
#   'blackpink',
#   'ulang',
#   'please',
#   'fans',
#   'mengatasnamakan',
#   'live',
#   'blackpink'],
#  ['sring',
#   'kcewa',
#   'ditoped',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'tolak',
#   'seller',
#   'sellernya',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'bareng',
#   'nanggung',
#   'ongkir',
#   'pdhl',
#   'ksalahan',
#   'seller',
#   'bareng',
#   'bukan',
#   'ssuai',
#   'deskripsi',
#   'lagi',
#   'brgnya',
#   'palsu',
#   'kmbalikan',
#   'bareng',
#   'proses',
#   'rumit',
#   'waktu',
#   'garis',
#   'bsarnya',
#   'seller',
#   'mrugikan',
#   'scara',
#   'materi',
#   'energi',
#   'waktu',
#   'heran',
#   'tu',
#   'seller',
#   'sampai',
#   'hari',
#   'masih',
#   'bebas',
#   'jual',
#   'bareng',
#   'palsu',
#   'pdhl',
#   'bukti'],
#  ['aplikasi', 'aneh', 'search', 'produk', 'muncul'],
#  ['aplikasi',
#   'cek',
#   'pesan',
#   'gagal',
#   'antre',
#   'internet',
#   'offline',
#   'lancar',
#   'sesal',
#   'dowload',
#   'aplikasi'],
#  ['tanggung',
#   'koin',
#   'pakai',
#   'koin',
#   'kemarin',
#   'tanam',
#   'koin',
#   'siram',
#   'koin',
#   'koin',
#   'tolong',
#   'gin',
#   'pakai',
#   'jujur',
#   'pakai',
#   'pokok',
#   'koin',
#   'nama',
#   'glowindo'],
#  ['maaf', 'mesen', 'powerbank', 'pas', 'powerbank', 'rusak'],
#  ['error',
#   'main',
#   'game',
#   'segercep',
#   'kemarin',
#   'promo',
#   'cashbacknya',
#   'tarik',
#   'kemarin',
#   'harga',
#   'barang',
#   'murah',
#   'aplikasi',
#   'belah',
#   'pdhl',
#   'langgan',
#   'pakai',
#   'males',
#   'belanja',
#   'seru',
#   'promo',
#   'up',
#   'shopeepay',
#   'ribu',
#   'juta',
#   'hadiah',
#   'perak',
#   'gilir',
#   'orang',
#   'up',
#   'ribu',
#   'hadiah',
#   'voucher',
#   'emas',
#   'hadeuhh',
#   'fair'],
#  ['marketplace',
#   'kaku',
#   'atur',
#   'ubah',
#   'bikin',
#   'nyaman',
#   'jual',
#   'beli',
#   'kesini',
#   'ribet',
#   'sombong',
#   'maaf',
#   'berat',
#   'uninstall',
#   'makan',
#   'tu',
#   'atur',
#   'kamu'],
#  ['cod', 'cod', 'baku', 'hantam'],
#  ['bertanya', 'dowlod', 'nii'],
#  ['agen', 'call', 'center'],
#  ['tipu', 'aplikasi', 'yes', 'do', 'najis'],
#  ['sabar', 'matket', 'place', 'ribet', 'ribet', 'percaya'],
#  ['sen', 'paket', 'kont'],
#  ['maf',
#   'dowlod',
#   'aplikasi',
#   'garagara',
#   'misi',
#   'penhasil',
#   'saldo',
#   'andai',
#   'aduh',
#   'malas',
#   'dowlod'],
#  ['unduh', 'unduh', 'hidup', 'data', 'seluler', 'unduh', 'hapus'],
#  ['aplikasi',
#   'sengaja',
#   'hapus',
#   'unduh',
#   'lagi',
#   'gagal',
#   'terus',
#   'gmn',
#   'tolong',
#   'solusi',
#   'bayar',
#   'bayar',
#   'later'],
#  ['ongkir',
#   'gede',
#   'beli',
#   'barang',
#   'diskon',
#   'ongkir',
#   'nama',
#   'ongkir',
#   'barang',
#   'lebih baik',
#   'belah'],
#  ['bela',
#   'beli',
#   'wkwk',
#   'sayang',
#   'kaya',
#   'belah',
#   'prioritas',
#   'beli',
#   'tahu',
#   'beli',
#   'raja',
#   'layan',
#   'komplain',
#   'shope',
#   'banyak',
#   'alesan',
#   'gilir',
#   'ajak',
#   'debat',
#   'skak',
#   'ehh',
#   'cht',
#   'wkwkwkkw'],
#  ['jatuh',
#   'tempo',
#   'telpon',
#   'bayar',
#   'jam',
#   'bayar',
#   'bayar',
#   'apaaa',
#   'kesini',
#   'galogis',
#   'gaaakan',
#   'pakai',
#   'gituan',
#   'ribet'],
#  ['aju', 'paylater', 'tolak', 'loyal', 'aplikasi'],
#  ['voucher', 'gratis', 'ongkir', 'dipake', 'kntl'],
#  ['bayar',
#   'tagih',
#   'suruh',
#   'tunggu',
#   'proses',
#   'dana',
#   'salah',
#   'suruh',
#   'tunggu',
#   'dana'],
#  ['saldo',
#   'dana',
#   'beku',
#   'yabg',
#   'rp',
#   'ribu',
#   'tolong',
#   'akun',
#   'lapor',
#   'polisi',
#   'tolong',
#   'kirim',
#   'pesan',
#   'eamil',
#   'stolong',
#   'cepat',
#   'uang',
#   'tarik',
#   'pas',
#   'uang',
#   'beku',
#   'pas',
#   'beku',
#   'uang',
#   'pakai',
#   'butuh',
#   'gajelas'],
#  ['kesal', 'iklan'],
#  ['emangggg', 'tooopppp', 'margotop'],
#  ['order', 'batal', 'sistem'],
#  ['setia',
#   'aplikasi',
#   'aplikasi',
#   'banyak',
#   'mslah',
#   'lot',
#   'error',
#   'alih',
#   'kta',
#   'aplikasi',
#   'baca',
#   'ulas',
#   'tntg',
#   'males',
#   'untuk',
#   'install',
#   'hapus',
#   'sja'],
#  ['aplikasi',
#   'sampah',
#   'nyusahin',
#   'ribet',
#   'bget',
#   'promo',
#   'ikln',
#   'sesuai',
#   'pulsa',
#   'data',
#   'mahal',
#   'asliny'],
#  ['aplikasi', 'lot', 'berat', 'desain', 'ribet', 'beda', 'simpel', 'ringan'],
#  ['aplikasi', 'bgst', 'palir', 'tukang', 'ulah', 'babulu'],
#  ['goyang', 'knph', 'yh', 'klik', 'muncul'],
#  ['bikin', 'akun', 'username', 'salah', 'benar', 'username'],
#  ['kayak', 'siput'],
#  ['ongkir', 'mahal', 'barang', 'mahal', 'belah'],
#  ['saldo', 'juta', 'hangus'],
#  ['hoax', 'habisin', 'paket', 'data'],
#  ['bisa', 'diundh'],
#  ['iklan', 'muncul'],
#  ['kode', 'otp', 'order', 'order', 'verifikasi', 'no', 'telpon'],
#  ['sama', 'iklan'],
#  ['sekar',
#   'seringkali',
#   'belanja',
#   'reward',
#   'gold',
#   'aktif',
#   'shopeepaylater',
#   'mesti',
#   'suruh',
#   'topup',
#   'lagi',
#   'beribet',
#   'konfirmasi'],
#  ['males', 'iklan', 'melulu'],
#  ['maaf',
#   'kirim',
#   'nama',
#   'hj',
#   'leni',
#   'kebeneran',
#   'sen',
#   'aneh',
#   'yahhh',
#   'nmer',
#   'handphone',
#   'nmer',
#   'tapi',
#   'nama',
#   'alamat',
#   'persis',
#   'tapi',
#   'pribadi',
#   'kirim',
#   'misterius',
#   'sya',
#   'bayar',
#   'pdhl',
#   'sen',
#   'diambio',
#   'bayar',
#   'kasi',
#   'kulir',
#   'nyaaaa'],
#  ['sen',
#   'apa',
#   'paket',
#   'dateng',
#   'rumah',
#   'adek',
#   'tindaktegas',
#   'jual',
#   'nakal'],
#  ['masukkan',
#   'kode',
#   'verifikasi',
#   'angka',
#   'smsnya',
#   'masukkan',
#   'dftr',
#   'failed'],
#  ['pilih',
#   'halaman',
#   'search',
#   'produk',
#   'tekan',
#   'back',
#   'kemarin',
#   'tombol',
#   'pojok',
#   'kanan',
#   'versi',
#   'akmask',
#   'mobile',
#   'pakai',
#   'wifi',
#   'sulit',
#   'koneksi',
#   'pakai',
#   'koneksi',
#   'data',
#   'lancar',
#   'tolong',
#   'tim'],
#  ['voucher', 'gratis', 'ongkir', 'tapi', 'pke', 'hedehh'],
#  ['maaf',
#   'jatuh',
#   'aplikasi',
#   'beritahu',
#   'admin',
#   'undi',
#   'hadiah',
#   'malah',
#   'korban',
#   'tipu',
#   'bnyak',
#   'ber',
#   'nama',
#   'jebak'],
#  ['eta', 'da'],
#  ['biaya', 'admin', 'mahal', 'jual', 'raih', 'untung', 'star', 'seller'],
#  ['up', 'dana', 'saldo', 'pindah', 'dompet', 'saldo', 'dompet', 'beku'],
#  ['tolong',
#   'tingkat',
#   'kait',
#   'proses',
#   'aju',
#   'food',
#   'proses',
#   'makan',
#   'optimal',
#   'kait',
#   'makan',
#   'barang'],
#  ['kaya',
#   'harga',
#   'diskon',
#   'pas',
#   'harga',
#   'diskon',
#   'harga',
#   'diskon',
#   'cek',
#   'out',
#   'harga',
#   'diskon',
#   'keranjang',
#   'harga',
#   'diskon',
#   'harga',
#   'beda',
#   'keranjang',
#   'keranjang',
#   'harga',
#   'asli',
#   'coret',
#   'cek',
#   'out',
#   'hargane',
#   'utuh',
#   'diskon',
#   'malesin'],
#  ['mem', 'beli', 'akun', 'bayar', 'beda', 'gambar', 'toko'],
#  ['rate', 'sesuai', 'alam', 'beli', 'sembunyi', 'seller', 'tanggung'],
#  ['unduh', 'pulsa', 'ribu', 'promo', 'dikit', 'pulsa'],
#  ['susa', 'membebahari'],
#  ['fitur', 'pilih', 'jasa', 'kirim'],
#  ['barang', 'akun', 'blok'],
#  ['kendala',
#   'spaylater',
#   'hubung',
#   'agen',
#   'bantu',
#   'lunas',
#   'cicil',
#   'sisa',
#   'sukses'],
#  ['aplikasi', 'belanja', 'akurat', 'percaya'],
#  ['kirim', 'tera', 'maksimal', 'tanggal', 'kirim', 'tanggal'],
#  ['ulas',
#   'bintang',
#   'ikutin',
#   'karnakan',
#   'aplikasi',
#   'bangkrut',
#   'layan',
#   'langgan',
#   'ulas',
#   'ulas',
#   'mudah',
#   'retas',
#   'beli',
#   'topeng',
#   'mahal',
#   'ongkir',
#   'habis',
#   'topeng'],
#  ['daftar', 'belanja', 'bisaaa'],
#  ['konyol',
#   'beli',
#   'jam',
#   'salah',
#   'klik',
#   'barang',
#   'barang',
#   'duit',
#   'hangus',
#   'customer service',
#   'susah',
#   'hubung'],
#  ['ongkos', 'dilembalikan'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['belanja', 'stock', 'kosong'],
#  ['aplikasi', 'rena', 'voucher', 'alas', 'pesan'],
#  ['aplikasi', 'jellllekkkkk', 'akun', 'member', 'daftar', 'spaylater', 'akun'],
#  ['aplikasi', 'lambat'],
#  ['maaf',
#   'unduh',
#   'ulang',
#   'verifikasi',
#   'emain',
#   'no',
#   'tlf',
#   'pakek',
#   'hilang',
#   'aktif',
#   'cek',
#   'aplikasi',
#   'mytelkomsel',
#   'aktif',
#   'no',
#   'tlf',
#   'november',
#   'tolong',
#   'akal'],
#  ['balance', 'belanja', 'susah', 'dirarik'],
#  ['belanja',
#   'simpan',
#   'troli',
#   'bayar',
#   'jarak',
#   'update',
#   'updatenya',
#   'kelar',
#   'aplikasi',
#   'pakai',
#   'belanja',
#   'saldo',
#   'dana',
#   'bayar'],
#  ['nyaman',
#   'pakai',
#   'ehk',
#   'kesal',
#   'pesan',
#   'bareng',
#   'brngnya',
#   'slh',
#   'ktnya',
#   'tanggung',
#   'ehk',
#   'ngilang',
#   'tanggung'],
#  ['aplikasi', 'benar', 'njir'],
#  ['shopi', 'cod'],
#  ['sekian',
#   'pakai',
#   'ken',
#   'pakai',
#   'gegara',
#   'bosen',
#   'aplikasi',
#   'belah',
#   'pas',
#   'login',
#   'nomor',
#   'nonaktif',
#   'tolong',
#   'mudah',
#   'daftar',
#   'pakai',
#   'mail',
#   'konfirmasi',
#   'pilih',
#   'opsi',
#   'pakai',
#   'verifikasi',
#   'mail',
#   'google',
#   'account',
#   'seperti',
#   'gin',
#   'bingung',
#   'alhasil',
#   'bikin',
#   'account',
#   'males'],
#  ['lambat', 'lemod'],
#  ['order',
#   'barang',
#   'bom',
#   'sampai',
#   'samday',
#   'hilang',
#   'males',
#   'belanja',
#   'pagi',
#   'order',
#   'sore',
#   'sampai',
#   'pagi',
#   'order',
#   'bom',
#   'sampai'],
#  ['voucher', 'manipulasi', 'biji'],
#  ['super',
#   'lambat',
#   'jember',
#   'magelang',
#   'toko',
#   'cileduk',
#   'magelang',
#   'kapok',
#   'belanja'],
#  ['sayang',
#   'fitur',
#   'paylater',
#   'beli',
#   'barang',
#   'pulsa',
#   'tagih',
#   'listrik',
#   'pdam',
#   'tv',
#   'kabel'],
#  ['akun',
#   'block',
#   'ban',
#   'kah',
#   'akun',
#   'hilang',
#   'saldo',
#   'shoppe',
#   'hilang',
#   'beli',
#   'barang',
#   'impi',
#   'tua',
#   'smartphone'],
#  ['bintang',
#   'menu',
#   'bayar',
#   'later',
#   'kredit',
#   'aplikasi',
#   'shopeeku',
#   'smtra',
#   'orang',
#   'paylater',
#   'solusi',
#   'ditambahin',
#   'belanja',
#   'bayar',
#   'laternya',
#   'tolong',
#   'jangan',
#   'beda',
#   'langgan',
#   'juga',
#   'sring',
#   'mesan',
#   'smtr',
#   'teman',
#   'mesan',
#   'bayar',
#   'later'],
#  ['anjink', 'aplikasi', 'iklan', 'ganggu', 'tahu'],
#  ['ongkir', 'horor', 'iklan', 'bebas', 'ongkir', 'ongkir', 'keri'],
#  ['flassale', 'beli', 'reload', 'taikkkkkkkkkkkk'],
#  ['toko',
#   'filter',
#   'toko',
#   'toko',
#   'nakal',
#   'beli',
#   'mobil',
#   'remot',
#   'gantung'],
#  ['unduh', 'gagal', 'unduh', 'huh', 'belanja'],
#  ['dana',
#   'smp',
#   'skrng',
#   'transfer',
#   'rekening',
#   'telfon',
#   'customer',
#   'service',
#   'selalu',
#   'suruh',
#   'tunggu',
#   'sdah',
#   'hmpir',
#   'trnsferan',
#   'rekening',
#   'nunngu'],
#  ['belanja',
#   'pesan',
#   'sepatu',
#   'baju',
#   'aju',
#   'dana',
#   'barang',
#   'pesan',
#   'aju',
#   'dana',
#   'tingkat',
#   'kualitas',
#   'layan',
#   'hack'],
#  ['basi',
#   'keluarga',
#   'akun',
#   'promo',
#   'alas',
#   'alamat',
#   'keluarga',
#   'rumah',
#   'alamat',
#   'pakai',
#   'alamat',
#   'tetangga',
#   'pakai',
#   'bacot'],
#  ['kuis', 'aplikasi', 'ram', 'ruang', 'hadiah', 'capek'],
#  ['maaf', 'lebe', 'ongkir'],
#  ['ken',
#   'login',
#   'akun',
#   'susah',
#   'tunggu',
#   'sms',
#   'smsnya',
#   'bangke',
#   'capek',
#   'nungguin'],
#  ['tolong', 'bebas', 'milih', 'ekspedisi', 'jnt'],
#  ['kolom', 'cari', 'ngebug', 'melulu', 'anjg'],
#  ['tolong',
#   'kirim',
#   'layan',
#   'express',
#   'kur',
#   'barang',
#   'asing',
#   'konfirmasi',
#   'barang',
#   'elektronik',
#   'harga'],
#  ['shopeepay',
#   'emas',
#   'kirim',
#   'minimal',
#   'minggu',
#   'aneh',
#   'pakai',
#   'cod',
#   'why',
#   'perbaikin',
#   'tolong',
#   'reseller',
#   'tipu',
#   'tindak',
#   'bnyak',
#   'korban',
#   'beli'],
#  ['versi',
#   'ringan',
#   'update',
#   'versi',
#   'bin',
#   'lot',
#   'pakai',
#   'internet',
#   'cepat',
#   'mbps',
#   'bayangin',
#   'cepat',
#   'aplikasi',
#   'belanja',
#   'konten',
#   'nongol',
#   'alias',
#   'susah',
#   'update',
#   'versi',
#   'sekarang',
#   'auto',
#   'aplikasi',
#   'kaliyan',
#   'yuk',
#   'komentar',
#   'aplikasi'],
#  ['kurir', 'kirim', 'timika', 'papua', 'belanja', 'uninstal'],
#  ['barang', 'sampah'],
#  ['tolong',
#   'verifikasi',
#   'ganti',
#   'akun',
#   'mudah',
#   'akun',
#   'email',
#   'no',
#   'handphone',
#   'ganti',
#   'akun',
#   'double',
#   'akun',
#   'hadehh'],
#  ['seler',
#   'tolong',
#   'atur',
#   'ketat',
#   'order',
#   'barang',
#   'transfer',
#   'barang',
#   'jalan',
#   'cancel',
#   'uang',
#   'jangka',
#   'sampai',
#   'minggu'],
#  ['maap', 'sekarng', 'aplikasi', 'yoko', 'tida', 'mwnanggapi'],
#  ['devolepor',
#   'mesti',
#   'tipu',
#   'cashback',
#   'gratis',
#   'ongkir',
#   'iklan',
#   'tv',
#   'gratis',
#   'ongkir',
#   'minimum',
#   'belanja',
#   'belanja'],
#  ['easi',
#   'soping',
#   'pt',
#   'karisma',
#   'bahana',
#   'gemilang',
#   'tipu',
#   'suruh',
#   'mutar',
#   'lotery',
#   'lucki',
#   'miliader',
#   'rodah',
#   'henti',
#   'angka',
#   'miliard',
#   'hasil',
#   'rezeki',
#   'bukti',
#   'hoaks',
#   'tahu',
#   'almat',
#   'easi',
#   'soping',
#   'pulsa',
#   'informasi',
#   'hitung',
#   'buta',
#   'hukum',
#   'hak',
#   'tuhan',
#   'yesus',
#   'kutuk',
#   'cilakalah',
#   'binasa',
#   'kru',
#   'easy',
#   'soping',
#   'musiba',
#   'tabrak',
#   'maut',
#   'do',
#   'putra',
#   'flores',
#   'korban',
#   'tipu',
#   'amin',
#   'easi',
#   'soping',
#   'utang',
#   'timor'],
#  ['kode', 'otp', 'kirim', 'checkout'],
#  ['waaah',
#   'shoppi',
#   'benar',
#   'kirim',
#   'srkng',
#   'kesel',
#   'tunggu',
#   'jakarta',
#   'palembang',
#   'kemarin',
#   'kadang',
#   'sampai',
#   'sik',
#   'jasa',
#   'kirim',
#   'hadeh',
#   'langgan',
#   'pindah',
#   'aplikasi',
#   'tolong',
#   'seperti',
#   'jasa',
#   'kirim',
#   'yok',
#   'yok',
#   'seperti',
#   'jasa',
#   'kirim'],
#  ['bikin', 'emosi', 'tombal', 'batal', 'transaksi'],
#  ['pelit',
#   'gara',
#   'score',
#   'game',
#   'menu',
#   'bilang',
#   'main',
#   'normal',
#   'normal',
#   'ranking',
#   'voucher'],
#  ['kirim', 'lambattt', 'sen'],
#  ['platform', 'jaz'],
#  ['tunggu', 'jam', 'terintal', 'intal'],
#  ['tipu',
#   'hadiah',
#   'google',
#   'chrom',
#   'ujung',
#   'sruh',
#   'donlot',
#   'aplikasi',
#   'tapi',
#   'hadiah',
#   'bisa',
#   'ambil',
#   'dasar',
#   'tukang',
#   'tipu',
#   'pngen',
#   'bnyak',
#   'pngguna',
#   'tapi',
#   'pakai',
#   'mutu'],
#  ['aplikasi', 'nyaa', 'bagetttt', 'boooooggg'],
#  ['aplikasi', 'lihah', 'kopon', 'lodingnya'],
#  ['sesuai',
#   'iklan',
#   'iklan',
#   'promo',
#   'diskon',
#   'bebas',
#   'ongkir',
#   'promo',
#   'bayar',
#   'cod',
#   'bayar',
#   'bikin'],
#  ['kemarin',
#   'kasi',
#   'bintang',
#   'skarang',
#   'ganti',
#   'respon',
#   'pas',
#   'dana',
#   'barang',
#   'kirim',
#   'kasi',
#   'kabar',
#   'dana',
#   'jual',
#   'barang',
#   'uang',
#   'kontak',
#   'jual',
#   'hati',
#   'kirim'],
#  ['hancur',
#   'tokopoint',
#   'daerah',
#   'pakai',
#   'kupon',
#   'diskon',
#   'batal',
#   'transfer',
#   'alas',
#   'langgar',
#   'klu',
#   'jangan',
#   'kupon',
#   'diskon',
#   'pdahal',
#   'hancur',
#   'updatenya',
#   'maaf',
#   'uninstal',
#   'pindah',
#   'toko',
#   'belah',
#   'lebih baik'],
#  ['uninstal', 'dominan', 'toko', 'orange'],
#  ['unduh', 'kenapa', 'pas', 'taut', 'suruh', 'dwonload'],
#  ['layan',
#   'tunggu',
#   'pesan',
#   'tampa',
#   'update',
#   'kirim',
#   'batal',
#   'kirim',
#   'tampa',
#   'terang'],
#  ['bodo', 'aplikasi', 'gratis', 'ongkir', 'bayar', 'ongkir', 'mahal'],
#  ['tol', 'aplikasi'],
#  ['update',
#   'aplikasi',
#   'selalu',
#   'ngeblank',
#   'ngetik',
#   'cari',
#   'barang',
#   'susah',
#   'brng',
#   'keranjang',
#   'bisa',
#   'hapus',
#   'msih',
#   'banyak',
#   'setelah',
#   'update',
#   'perbaikin',
#   'bug'],
#  ['limit', 'spaylater', 'bayar', 'jatuh', 'tempo'],
#  ['mahal', 'beda', 'selisih', 'bangetttttt'],
#  ['maaf', 'transaksi', 'shopeepay', 'shopeepay', 'later', 'limit'],
#  ['minimal',
#   'belanja',
#   'ribu',
#   'free',
#   'ongkir',
#   'kaget',
#   'belanja',
#   'butuh',
#   'rumah',
#   'ongkir',
#   'langit',
#   'alih',
#   'pindah',
#   'belanja',
#   'toko',
#   'belah',
#   'free',
#   'ongkir'],
#  ['sembako', 'kupon', 'utuh'],
#  ['beli', 'paket', 'sertifikat', 'dashboard'],
#  ['kemarin',
#   'pesan',
#   'pesan',
#   'batal',
#   'dana',
#   'transfer',
#   'untuk',
#   'dana',
#   'tolong',
#   'rekening',
#   'akun',
#   'nama',
#   'masukkan',
#   'rekening',
#   'seller',
#   'aktif'],
#  ['dana',
#   'pesan',
#   'batal',
#   'dana',
#   'rekening',
#   'perhati',
#   'langgan',
#   'sulit',
#   'uang',
#   'hak',
#   'tolong',
#   'dana'],
#  ['deret', 'ssrx', 'det', 'er'],
#  ['mecahin',
#   'telur',
#   'update',
#   'koin',
#   'update',
#   'gratis',
#   'ongkir',
#   'update',
#   'update',
#   'padal',
#   'update',
#   'tetep',
#   'update',
#   'kuota',
#   'habis',
#   'update',
#   'aplikasi',
#   'ginian',
#   'tolong',
#   'perintah',
#   'update',
#   'rang'],
#  ['jgan',
#   'belanja',
#   'barang',
#   'pesan',
#   'barang',
#   'ngk',
#   'sesuai',
#   'sya',
#   'mesan',
#   'baju',
#   'celana',
#   'bokser',
#   'pendek'],
#  ['beri',
#   'kupon',
#   'diskon',
#   'pas',
#   'belanja',
#   'pesan',
#   'batal',
#   'otomatis',
#   'kupon',
#   'pakai',
#   'lagi',
#   'kupon',
#   'diskon',
#   'rugi'],
#  ['tracking',
#   'paket',
#   'jalan',
#   'web',
#   'kurir',
#   'cek',
#   'jalan',
#   'asa',
#   'belanja',
#   'gin'],
#  ['aplikasi',
#   'go',
#   'internasional',
#   'urus',
#   'tagih',
#   'spaylatter',
#   'spinjam',
#   'nada',
#   'bicara',
#   'pesan',
#   'ngalahin',
#   'rentenir',
#   'mkn',
#   'bangku',
#   'sekolah',
#   'bunga',
#   'gede',
#   'dibyr',
#   'cicil',
#   'masih',
#   'orang',
#   'peres',
#   'layak',
#   'hutang',
#   'ratus',
#   'juta',
#   'miris',
#   'gaji',
#   'krywn',
#   'hasil',
#   'paksa',
#   'pinjam',
#   'ksh',
#   'kenal',
#   'lagi',
#   'zaman',
#   'lagi',
#   'covid',
#   'tegang',
#   'aplikasi',
#   'sblh',
#   'move',
#   'on'],
#  ['aplikasi', 'mahal', 'ongkir', 'harga', 'normal'],
#  ['lot', 'loading', 'terusssss'],
#  ['beli',
#   'dishopee',
#   'jual',
#   'tanggung',
#   'barang',
#   'kirim',
#   'salah',
#   'dana',
#   'barang'],
#  ['iklan', 'paksa', 'resah', 'hadeh'],
#  ['bayar', 'pakai', 'dana', 'unistal'],
#  ['iklanya', 'menggangu'],
#  ['mh', 'transaksi', 'ny', 'eror', 'terusssssss'],
#  ['akun',
#   'non',
#   'aktif',
#   'beku',
#   'langgar',
#   'atur',
#   'aplikasi',
#   'banned',
#   'kominfo',
#   'beli',
#   'latih',
#   'aplikasi',
#   'lulus',
#   'sertifikat',
#   'skill',
#   'academy',
#   'lapor',
#   'instansi',
#   'taung',
#   'bekerjasama',
#   'aplikasi',
#   'sertifikat',
#   'latih',
#   'muncul',
#   'dashboard',
#   'akun',
#   'tipu',
#   'publik'],
#  ['penguna', 'ambil', 'rp', 'kocak'],
#  ['jelekkk',
#   'bangett',
#   'voucher',
#   'beli',
#   'kaos',
#   'toko',
#   'dibatalinn',
#   'uang',
#   'balik',
#   'kejebakk',
#   'saldo',
#   'ambil',
#   'gabisaa',
#   'pakai',
#   'dana',
#   'pakeovo',
#   'gabisaa',
#   'gabanyakk',
#   'namnaya',
#   'uang'],
#  ['daftar', 'kode', 'frivikasi', 'muncul', 'muncul'],
#  ['aplikasi',
#   'bohong',
#   'pakai',
#   'sopepay',
#   'susah',
#   'kode',
#   'otp',
#   'kirim',
#   'bonuss',
#   'akun',
#   'saldo',
#   'ribu',
#   'tipu'],
#  ['habisin', 'kuota', 'update', 'profil', 'sampai', 'kiamat'],
#  ['pesan',
#   'cancel',
#   'kirim',
#   'kirim',
#   'gmn',
#   'jual',
#   'verifikasi',
#   'sopenya',
#   'solusi',
#   'gmn'],
#  ['limit', 'shopeepaylater', 'rp', 'cicil', 'lunas'],
#  ['spaylater', 'diaktivasi', 'gagal'],
#  ['kirain',
#   'harga',
#   'murah',
#   'wkwkwkwk',
#   'diskon',
#   'pelit',
#   'maaf',
#   'auto',
#   'uninstal'],
#  ['cashback',
#   'bukareksa',
#   'promo',
#   'reksajul',
#   'reksajul',
#   'reksaaug',
#   'reksaaug',
#   'hitung',
#   'cashback',
#   'komplain',
#   'ulang',
#   'tunggu',
#   'seninggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'tahan',
#   'dana',
#   'jual'],
#  ['update', 'susah'],
#  ['barang', 'manaaaaa'],
#  ['rugi', 'beli', 'realpeack'],
#  ['aplikasi', 'nyampah'],
#  ['terimah', 'pesan', 'barangx', 'cepat', 'kirim'],
#  ['lindung',
#   'konsumen',
#   'tipu',
#   'seller',
#   'kayak',
#   'barang',
#   'butuh',
#   'minggu'],
#  ['akun',
#   'transaksi',
#   'kemarin',
#   'beli',
#   'promo',
#   'klaim',
#   'langgar',
#   'pdhal',
#   'transaksi',
#   'aju',
#   'kpan',
#   'langgar',
#   'internal',
#   'customer',
#   'bukti'],
#  ['kesini', 'aplikasi', 'kok', 'bayar', 'eror', 'gakda', 'solusi', 'aplikasi'],
#  ['update',
#   'versi',
#   'hubung',
#   'ulang',
#   'kolom',
#   'feed',
#   'tolong',
#   'nyaman',
#   'handphone',
#   'samsung',
#   'profesional'],
#  ['tarik', 'dana'],
#  ['aplikasi', 'layan'],
#  ['bnayak', 'update'],
#  ['sistem', 'error'],
#  ['bertanya',
#   'event',
#   'paket',
#   'data',
#   'pulsa',
#   'perak',
#   'tu',
#   'boongan',
#   'ubah',
#   'bintang',
#   'kecuali',
#   'please'],
#  ['sanggat', 'kecewaa'],
#  ['aju', 'hapus', 'akun', 'ribet'],
#  ['rugi', 'tolong', 'uang'],
#  ['krkurangan',
#   'transaksi',
#   'aplikasi',
#   'tampil',
#   'wahhh',
#   'sistem',
#   'transaksi',
#   'normal'],
#  ['barang', 'rusak', 'jual', 'gemanay'],
#  ['uda', 'bayar', 'bom', 'sampai'],
#  ['transfer', 'airpayinternal', 'beli', 'barang', 'batal', 'dana', 'tidak'],
#  ['jangan',
#   'unduh',
#   'bnyak',
#   'pnipuan',
#   'jual',
#   'buukn',
#   'brang',
#   'asli',
#   'rport',
#   'smaa',
#   'bnyak',
#   'unsur',
#   'penipuann'],
#  ['transaksi', 'batal', 'aplikasi', 'jelasssss'],
#  ['belanja',
#   'gilir',
#   'belanja',
#   'poin',
#   'ktanya',
#   'cod',
#   'isi',
#   'pdhl',
#   'pakai',
#   'ongkir',
#   'bebas',
#   'ongkir',
#   'moduss',
#   'kopeeet'],
#  ['saldo', 'hasil', 'refund', 'belanja'],
#  ['aplikasi', 'bohong', 'diskon', 'pas', 'tunggu', 'tunggu', 'unduh'],
#  ['ribet',
#   'jual',
#   'cair',
#   'dana',
#   'beli',
#   'sesuai',
#   'terang',
#   'terang',
#   'sampai',
#   'oktober',
#   'konfirmasi',
#   'beli',
#   'dana',
#   'otomatis',
#   'jual',
#   'oktober',
#   'dana',
#   'tahan',
#   'terang',
#   'bikin',
#   'jual',
#   'harap'],
#  ['kaya', 'massa', 'pesan', 'barang'],
#  ['komentar',
#   'hapus',
#   'nanti',
#   'ketik',
#   'pergi',
#   'hibur',
#   'nanti',
#   'ketik',
#   'komen',
#   'hapus',
#   'shoope',
#   'asw',
#   'salin',
#   'komen',
#   'hapus',
#   'tinggal',
#   'paste',
#   'dikomen',
#   'sembuyikan',
#   'komen',
#   'hapus',
#   'komen',
#   'ketik',
#   'salin',
#   'komen',
#   'hapus',
#   'shoope',
#   'update',
#   'macet',
#   'pantang',
#   'nyerah',
#   'ubah',
#   'santet',
#   'balesanya',
#   'santet'],
#  ['aplikasi', 'unduh'],
#  ['ongkir', 'mahal', 'tolong', 'murahin', 'kayak', 'pandemi', 'uang'],
#  ['komplain', 'ribet'],
#  ['freeong',
#   'belanja',
#   'ribu',
#   'freeong',
#   'belanja',
#   'freeong',
#   'pindah',
#   'market',
#   'place'],
#  ['belanja',
#   'beli',
#   'jual',
#   'biaya',
#   'adminnya',
#   'toko',
#   'dibanned',
#   'pajak',
#   'negara',
#   'ken',
#   'untung',
#   'buntung'],
#  ['ambisi', 'unt', 'unduh', 'iklan', 'muntah', 'tarik', 'belanja', 'turun'],
#  ['bayar', 'sayang', 'bayar'],
#  ['cuman', 'aplikasi', 'gilir', 'girim'],
#  ['aplikasi', 'rancang', 'tipu'],
#  ['aplikasi', 'maksa', 'ta', 'ekkkkkkkkkkkk', 'anjinkkkkkkkkk'],
#  ['iklan', 'asli', 'jlek', 'tipu', 'belanja', 'batal', 'otomatis'],
#  ['update', 'ui', 'user', 'friendly'],
#  ['sesuai', 'iklan'],
#  ['reses', 'iklan', 'bikin', 'risih', 'unduh'],
#  ['shoope',
#   'iklan',
#   'spam',
#   'melulu',
#   'renti',
#   'seperti',
#   'lagi',
#   'main',
#   'ml',
#   'iklan',
#   'shoope'],
#  ['kesini', 'lambat', 'njir', 'pakai', 'wifi', 'ram'],
#  ['iklan', 'ngabisin', 'kuota'],
#  ['sponsor', 'broser', 'unduh', 'aplikasi', 'melulu', 'susah', 'pusing'],
#  ['tiktok',
#   'iklan',
#   'toko',
#   'terus',
#   'diam',
#   'jan',
#   'ganggu',
#   'seru',
#   'nonton',
#   'tiktokk'],
#  ['update', 'koneksi', 'bikin', 'kesel'],
#  ['aju', 'tolak', 'spaylaternya', 'hadeh', 'bintang', 'atulah'],
#  ['ongkos',
#   'kirim',
#   'ribu',
#   'voucernya',
#   'sus',
#   'sope',
#   'bayar',
#   'cod',
#   'voucer',
#   'gratis',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'beli',
#   'kasi',
#   'voucher',
#   'sisa',
#   'rebut',
#   'icon',
#   'free',
#   'ogkir',
#   'hilang'],
#  ['aplikasi',
#   'nyampe',
#   'tangal',
#   'nyampenya',
#   'tangal',
#   'aplikasi',
#   'bohong',
#   'install',
#   'aplikasi',
#   'dasar',
#   'aplikasi',
#   'penbohong'],
#  ['beli',
#   'case',
#   'handphone',
#   'negeri',
#   'cari',
#   'produk',
#   'negeri',
#   'cari',
#   'case',
#   'negeri',
#   'negeri',
#   'gmn',
#   'solusi'],
#  ['bayar', 'suruh', 'tunggu', 'jam', 'jam', 'akun', 'blokirr', 'tanggung'],
#  ['susah', 'unduh'],
#  ['mengambil',
#   'gratis',
#   'ongkir',
#   'nominal',
#   'ongkir',
#   'ny',
#   'gede',
#   'sedih',
#   'kadang',
#   'barang',
#   'pes',
#   'mahal',
#   'ongkir'],
#  ['jual',
#   'ragu',
#   'waswas',
#   'sampai',
#   'opsi',
#   'pilih',
#   'asuransi',
#   'halaman',
#   'cek',
#   'out',
#   'produk',
#   'kalah',
#   'toko',
#   'online',
#   'belah',
#   'opsi',
#   'asuransi',
#   'pas',
#   'kantor',
#   'ribet',
#   'karyawan',
#   'admin',
#   'paham',
#   'menbahkan',
#   'asuransi',
#   'profesional',
#   'kacau'],
#  ['jual', 'buku', 'baja', 'liar', 'belanja', 'nyaman'],
#  ['kesini', 'pas', 'unduh', 'video', 'gugel'],
#  ['beli',
#   'produk',
#   'pas',
#   'gilir',
#   'beli',
#   'kamera',
#   'oppo',
#   'nyala',
#   'tolong',
#   'tindak',
#   'lanjutin',
#   'jual'],
#  ['dagang',
#   'nakal',
#   'daripahda',
#   'bikin',
#   'promo',
#   'tv',
#   'lebih baik',
#   'aplikasi'],
#  ['respon',
#   'tolong',
#   'toko',
#   'toko',
#   'amanah',
#   'jual',
#   'respon',
#   'makan',
#   'pergi',
#   'hilang',
#   'konsumen',
#   'keluh',
#   'diam'],
#  ['iklan',
#   'lebih baik',
#   'pas',
#   'nonton',
#   'youtube',
#   'nonton',
#   'halaman',
#   'utama',
#   'layar',
#   'tolong',
#   'iklan'],
#  ['beli',
#   'tas',
#   'gunung',
#   'minggu',
#   'sepatu',
#   'roda',
#   'tipu',
#   'amanah',
#   'pesan',
#   'tas',
#   'kamu',
#   'sepatu',
#   'roda',
#   'gin',
#   'hapus',
#   'aplikashi',
#   'amanah'],
#  ['plis',
#   'batal',
#   'pesan',
#   'ubah',
#   'pikir',
#   'kirimm',
#   'allah',
#   'tolong',
#   'rugi',
#   'bangett'],
#  ['update', 'melulu'],
#  ['from', 'zero', 'hero'],
#  ['ngk', 'gratis', 'ongir'],
#  ['customer',
#   'service',
#   'layan',
#   'nelpon',
#   'butuh',
#   'customer service',
#   'sopan',
#   'santun',
#   'mati',
#   'panggil',
#   'pulsa'],
#  ['aman',
#   'aman',
#   'gilir',
#   'kirim',
#   'barang',
#   'tim',
#   'ehh',
#   'hasil',
#   'nol',
#   'konfirmasi',
#   'bukti',
#   'adu',
#   'tim',
#   'jangan',
#   'harap'],
#  ['staff', 'tolong', 'profesional', 'beda', 'gratis', 'ongkir', 'sedih'],
#  ['ongkir', 'mahal'],
#  ['belanja',
#   'komplain',
#   'sanggup',
#   'sarat',
#   'berat',
#   'bangat',
#   'suruh',
#   'bikin',
#   'video',
#   'youtuber',
#   'nomor',
#   'seri',
#   'bukti',
#   'foto',
#   'lanjur',
#   'paket',
#   'wuish',
#   'nang',
#   'beli'],
#  ['shope', 'bayar', 'qd', 'blokir', 'salah'],
#  ['muncul', 'iklan', 'internet', 'otomatis', 'kesini', 'orang', 'maksa'],
#  ['maaf', 'sen', 'apa', 'dateng', 'tolong'],
#  ['jangan', 'kirim', 'promo', 'handphone', 'tarik', 'ganggu'],
#  ['erti', 'beli', 'latih', 'kartu', 'gagal', 'tipu', 'kayak', 'gin'],
#  ['jan', 'maksa', 'install'],
#  ['mntep', 'shopefood'],
#  ['cobakalau',
#   'promosi',
#   'tipu',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ongkir',
#   'gede',
#   'harga',
#   'barang'],
#  ['kesini', 'gara', 'google', 'crome', 'ribu'],
#  ['update', 'klik', 'toko'],
#  ['cerita', 'shopi', 'hoax'],
#  ['curang', 'event', 'event', 'sistem', 'talu', 'lot', 'sistem', 'jadul'],
#  ['kirim', 'pesan', 'kayak', 'buka', 'kirim', 'dikit', 'tinggal', 'buka'],
#  ['ualah', 'tahu', 'cod', 'biaya', 'nang', 'xixixixixididi'],
#  ['apdead', 'paylater'],
#  ['aplikasi',
#   'belanja',
#   'seller',
#   'blokir',
#   'toko',
#   'tanggung',
#   'rugi',
#   'beli'],
#  ['aplikasi', 'cuman', 'iklan', 'ganggu', 'anjeng'],
#  ['trooble', 'tuuuerruusss'],
#  ['berat',
#   'beli',
#   'setia',
#   'beli',
#   'barang',
#   'harga',
#   'juta',
#   'tipu',
#   'beli',
#   'ebook',
#   'tips',
#   'jitu',
#   'isi',
#   'screen',
#   'shot',
#   'kirim',
#   'biji',
#   'admin',
#   'tolak',
#   'adu',
#   'sungguh',
#   'menang',
#   'tipu',
#   'kayak',
#   'gin',
#   'lebih baik',
#   'unistall',
#   'jamin',
#   'aman',
#   'beli',
#   'tipu',
#   'bukalapa'],
#  ['tolong',
#   'aplikasi',
#   'muslim',
#   'profesional',
#   'solat',
#   'iklan',
#   'menganggu',
#   'muslim',
#   'profesional',
#   'tutup',
#   'aplikasi',
#   'kesel',
#   'maaf',
#   'ulas',
#   'salah',
#   'salah',
#   'seller',
#   'tanggung',
#   'tindak'],
#  ['benar',
#   'bikin',
#   'murka',
#   'pesan',
#   'sya',
#   'sesuai',
#   'chat',
#   'seller',
#   'tidak',
#   'etikad',
#   'baca',
#   'tolong',
#   'smpein',
#   'toko',
#   'ling',
#   'hong',
#   'jual',
#   'amanah'],
#  ['harga',
#   'dimainin',
#   'aplikasi',
#   'pilih',
#   'warna',
#   'size',
#   'harga',
#   'ubah',
#   'tertawa',
#   'capek',
#   'capek',
#   'milih',
#   'mlototin',
#   'order',
#   'harga',
#   'sesuai',
#   'tema',
#   'stop',
#   'gunain'],
#  ['aplikasi', 'aneh', 'barang', 'bayar', 'batal', 'aplikasi'],
#  ['susah', 'loadingnya'],
#  ['shope',
#   'plis',
#   'mengundng',
#   'teman',
#   'verif',
#   'ktp',
#   'teman',
#   'bom',
#   'bikin',
#   'ktf',
#   'macam',
#   'plis',
#   'rakyat',
#   'indonesia',
#   'even'],
#  ['daya', 'bayar', 'ngeblank'],
#  ['kada', 'baikk'],
#  ['akun',
#   'hack',
#   'atm',
#   'akun',
#   'pinjam',
#   'uang',
#   'jt',
#   'block',
#   'aplikasi',
#   'aman'],
#  ['masak',
#   'aju',
#   'spaylater',
#   'bayar',
#   'kartu',
#   'kredit',
#   'mengunakan',
#   'aplikasi',
#   'shoppee',
#   'lah',
#   'kartu',
#   'kredit',
#   'ngk',
#   'shopeepay',
#   'aneh',
#   'shoppe',
#   'limit',
#   'ngk'],
#  ['ribet', 'sen', 'gratis', 'ongkir'],
#  ['sesal', 'nang', 'akun', 'blok'],
#  ['sama',
#   'aplikasi',
#   'pilih',
#   'transaksi',
#   'batalakan',
#   'dn',
#   'belah',
#   'transaksi',
#   'sampai',
#   'tunggu',
#   'minggu',
#   'uang'],
#  ['sakit', 'killik', 'kirim', 'barang'],
#  ['hapus',
#   'aju',
#   'phaylater',
#   'tolak',
#   'muncul',
#   'tawar',
#   'phaylater',
#   'aju',
#   'tolak'],
#  ['maaf',
#   'pakai',
#   'aplikasi',
#   'ajh',
#   'gratis',
#   'ongkir',
#   'minggu',
#   'ganti',
#   'handphone',
#   'unduh',
#   'teman',
#   'kenapa',
#   'potong',
#   'ongkir'],
#  ['aplikasi', 'sempurna'],
#  ['sen',
#   'barang',
#   'dilazada',
#   'tahu',
#   'tahu',
#   'kurir',
#   'dateng',
#   'rumah',
#   'tas',
#   'slempang',
#   'bayar',
#   'sen',
#   'sen',
#   'dateng',
#   'gmn',
#   'hapus',
#   'akun'],
#  ['transaksi',
#   'batal',
#   'recommended',
#   'belanja',
#   'lebih baik',
#   'pakai',
#   'mudah',
#   'aman',
#   'ribet',
#   'iming',
#   'gratis',
#   'ongkir',
#   'tahu',
#   'fiktif',
#   'google',
#   'mereview',
#   'aplikasi',
#   'ngrugiin'],
#  ['kirim',
#   'lambattt',
#   'bngettt',
#   'proses',
#   'toko',
#   'belah',
#   'cepat',
#   'tolong',
#   'koreksi'],
#  ['aneh', 'transaksi', 'anggap', 'pesan', 'batal', 'alas', 'nila', 'fitnah'],
#  ['toko', 'ngentodddd'],
#  ['cepat',
#   'install',
#   'oo',
#   'penuh',
#   'lah',
#   'simpan',
#   'takbisa',
#   'ookesel',
#   'capek',
#   'huudan',
#   'baguss',
#   'oooooooooo'],
#  ['bangke', 'beli', 'paket', 'data', 'suruh', 'tunggu', 'tutup'],
#  ['klaim', 'barang', 'rp'],
#  ['susah', 'cek', 'out', 'lancar'],
#  ['aplikasi',
#   'cantemer',
#   'servis',
#   'sms',
#   'alibi',
#   'aju',
#   'pinjam',
#   'dana',
#   'aju',
#   'pinjam',
#   'dana',
#   'aplikasi',
#   'telepon',
#   'sms',
#   'ganggu'],
#  ['belanja', 'mudah'],
#  ['toko',
#   'vavio',
#   'acc',
#   'jual',
#   'chip',
#   'high',
#   'domino',
#   'tolong',
#   'band',
#   'sdah',
#   'bayar',
#   'suruh',
#   'batal',
#   'transaksi',
#   'aplikasi',
#   'skrng',
#   'tunggu',
#   'dana'],
#  ['bingung',
#   'jual',
#   'jujur',
#   'bilang',
#   'langgar',
#   'akun',
#   'batas',
#   'dana',
#   'beli',
#   'saldo',
#   'jual',
#   'beli',
#   'setia',
#   'hapus',
#   'bilang',
#   'curiga',
#   'toko',
#   'curiga',
#   'lancar',
#   'bayar',
#   'barang',
#   'beli',
#   'dishopee',
#   'bijak',
#   'seperti',
#   'sp',
#   'timbang'],
#  ['saring', 'jual', 'tipu', 'tayiiiilahhh'],
#  ['kanapa', 'barang', 'data', 'ng', 'sedangkab', 'mes', 'tipu'],
#  ['install',
#   'aplikasi',
#   'keamananya',
#   'kemarin',
#   'paket',
#   'tersesat',
#   'akun',
#   'mesan',
#   'log',
#   'out',
#   'akun',
#   'unistal',
#   'tahu',
#   'paket',
#   'ajar',
#   'real',
#   'alam',
#   'tolong',
#   'perhati'],
#  ['aplikasi', 'jlas', 'kirim', 'akun', 'cek', 'kosong'],
#  ['aplikasi', 'sungguh', 'sulit', 'paham', 'barang', 'batal', 'otomatis'],
#  ['tolong',
#   'dijelasin',
#   'aplikasi',
#   'klik',
#   'tapi',
#   'kluar',
#   'klik',
#   'kluar',
#   'lagi',
#   'klik',
#   'kluar',
#   'lagi',
#   'orang',
#   'belanja',
#   'tidak'],
#  ['sistem', 'jual', 'ekspedisi', 'ubah', 'rubah', 'ekspedisi'],
#  ['nggk', 'update', 'gim'],
#  ['balik', 'jasa', 'kirim'],
#  ['flash', 'sale', 'ngadat', 'anjeng'],
#  ['bayar', 'latter', 'bayar', 'sekarang', 'gabiisaa', 'butuh', 'baaanget'],
#  ['batas',
#   'kirim',
#   'seller',
#   'sistem',
#   'cod',
#   'kadang',
#   'kurir',
#   'rumah',
#   'rumah',
#   'kasihan',
#   'kurir',
#   'bolak',
#   'ngekost',
#   'titip',
#   'tetangga',
#   'tetangga'],
#  ['minggu', 'juga', 'pesan', 'detail', 'kirim', 'akurat'],
#  ['seller',
#   'nd',
#   'respon',
#   'proses',
#   'jual',
#   'kirim',
#   'kurir',
#   'nd',
#   'kayak',
#   'lari',
#   'dehh'],
#  ['ngeselin',
#   'aplikasi',
#   'beli',
#   'kirim',
#   'cepat',
#   'tapi',
#   'ngeselin',
#   'brli',
#   'barang',
#   'pengirimanya',
#   'minggu',
#   'kirim',
#   'tutup',
#   'batal',
#   'barang',
#   'begi',
#   'pindah',
#   'toko',
#   'online',
#   'belah',
#   'tolong',
#   'ekspedisi',
#   'instan',
#   'aktif',
#   'cepat',
#   'respon',
#   'auto',
#   'uninstal'],
#  ['benci', 'ygjadi', 'bintang', 'iklan', 'cowok', 'cowok', 'cantik'],
#  ['aplikasi',
#   'sesal',
#   'unduh',
#   'gratis',
#   'traktir',
#   'pas',
#   'pesan',
#   'dibatalin',
#   'langgar',
#   'langgar',
#   'pesan',
#   'kaya',
#   'aplikasi'],
#  ['rp',
#   'ambil',
#   'stok',
#   'habis',
#   'ambil',
#   'stok',
#   'habis',
#   'gilir',
#   'jarak',
#   'pilih',
#   'jasa',
#   'kirim',
#   'harga',
#   'beli',
#   'uninstall'],
#  ['voucher',
#   'jt',
#   'tapi',
#   'tu',
#   'saldo',
#   'toko',
#   'bohong',
#   'mnta',
#   'ampun',
#   'unduh'],
#  ['iklan', 'nongol', 'ganggu'],
#  ['ribet',
#   'ganti',
#   'nomer',
#   'telpon',
#   'susah',
#   'benar',
#   'kirim',
#   'sulit',
#   'kamera',
#   'handphone',
#   'telpon',
#   'customer service',
#   'ngebantunya'],
#  ['kesel', 'harga', 'ongkir', 'mahal', 'skrng', 'ongkir'],
#  ['gratis', 'ongkir', 'boongan'],
#  ['unduh', 'handphone', 'handphone'],
#  ['susah',
#   'flash',
#   'sale',
#   'barang',
#   'mewah',
#   'klik',
#   'terang',
#   'stok',
#   'habis',
#   'barang',
#   'murah',
#   'habis',
#   'stok',
#   'flash',
#   'sale',
#   'kaya',
#   'flash',
#   'sale',
#   'atur',
#   'antri',
#   'aplikasi',
#   'barang',
#   'flash',
#   'sale',
#   'atur',
#   'sistem',
#   'stel',
#   'beda',
#   'pkoknya',
#   'habis',
#   'kaya',
#   'atur',
#   'sistem',
#   'pokok',
#   'buyer',
#   'habis'],
#  ['kirim', 'cepat', 'terpercsya', 'tunggu', 'tidak', 'kirim'],
#  ['aplikasi', 'kirim', 'cepat', 'pokok'],
#  ['shope', 'aneh'],
#  ['bintang', 'pesan'],
#  ['aplikasi', 'tolong', 'bantu', 'masak', 'saldo', 'hilang', 'bintang'],
#  ['aplikasi', 'bujang', 'mahal', 'beda', 'tetangga', 'laz'],
#  ['sya', 'bayar', 'status', 'belanja', 'ubah', 'bayar'],
#  ['cocok', 'kulit', 'pakai', 'aloe', 'vera', 'pesan'],
#  ['sen',
#   'kirim',
#   'pesan',
#   'barang',
#   'cancel',
#   'jual',
#   'tolong',
#   'laa',
#   'bikin'],
#  ['ambil', 'aplikasi', 'pakai', 'jengkel', 'muncul'],
#  ['iklan', 'resah'],
#  ['cashback', 'rp', 'hilang', 'rugi', 'gin'],
#  ['cod', 'gratis', 'ongkir', 'bohong', 'nihhh'],
#  ['danta',
#   'paket',
#   'donwload',
#   'bekal',
#   'mentang',
#   'isi',
#   'paket',
#   'pakai',
#   'paket',
#   'mahal',
#   'sesuai',
#   'gadantaaaawwa'],
#  ['pindah', 'masak', 'kurir', 'anggap', 'budak'],
#  ['klaim',
#   'diskon',
#   'ribu',
#   'jam',
#   'voucher',
#   'hilang',
#   'refresh',
#   'ttp',
#   'ngadain',
#   'diskon',
#   'leg'],
#  ['agent',
#   'chat',
#   'live',
#   'shoppe',
#   'jk',
#   'bantu',
#   'chat',
#   'putus',
#   'paket',
#   'ydk',
#   'kirim',
#   'minta',
#   'dana',
#   'toko',
#   'tolak',
#   'aplikasi',
#   'lepas',
#   'tangan'],
#  ['driver',
#   'shope',
#   'food',
#   'pakai',
#   'fake',
#   'gps',
#   'tuyul',
#   'aplikasi',
#   'larang',
#   'tindak',
#   'jangan',
#   'mlh',
#   'kasihan',
#   'driver',
#   'jujur',
#   'driver',
#   'order',
#   'pakai',
#   'tuyul',
#   'suspend',
#   'pakai',
#   'aplikasi',
#   'aman',
#   'maju',
#   'jaya'],
#  ['beli', 'barang', 'paket', 'kosong', 'dana'],
#  ['iklan', 'otomatis', 'amit', 'lebih baik', 'shopie', 'olx'],
#  ['gratis',
#   'ongkir',
#   'belanja',
#   'ribu',
#   'ribu',
#   'sesuai',
#   'tema',
#   'lebih baik'],
#  ['seller', 'cetak', 'print', 'alamat', 'kirim', 'aplikasi'],
#  ['tipu',
#   'jgan',
#   'kayak',
#   'gin',
#   'percaya',
#   'sama',
#   'permai',
#   'pesan',
#   'batal',
#   'saldo',
#   'direfund',
#   'bisa',
#   'belanja',
#   'uang',
#   'bisa',
#   'tarik',
#   'capek',
#   'capek',
#   'alfamidi',
#   'bayar',
#   'uang',
#   'admin',
#   'batal',
#   'saldo',
#   'refund',
#   'pakai',
#   'tarik',
#   'malu',
#   'maluin'],
#  ['pesan',
#   'barang',
#   'oct',
#   'tngl',
#   'barang',
#   'kirim',
#   'barang',
#   'juga',
#   'belum',
#   'barang',
#   'kirim',
#   'kacau',
#   'toko',
#   'barang',
#   'belum',
#   'kirim',
#   'kurir',
#   'nelpon',
#   'tidak',
#   'barang',
#   'sampai',
#   'no',
#   'handphone',
#   'customer service',
#   'ninja',
#   'exxpres',
#   'beres',
#   'atw',
#   'pm',
#   'kurir'],
#  ['ongkir', 'mahal', 'barang', 'beli', 'ribu', 'ongkir'],
#  ['lot', 'parahh', 'sinyal', 'wifi', 'gambar', 'polos', 'notificationnya'],
#  ['check', 'out', 'hubungi', 'customer service'],
#  ['unduh',
#   'aplikasi',
#   'aplikasi',
#   'pesan',
#   'sampai',
#   'sampai',
#   'tangan',
#   'tungguin',
#   'tetep',
#   'datang',
#   'datang',
#   'belanja',
#   'mengecewaken',
#   'gabakal',
#   'belanja',
#   'rim',
#   'konsisten'],
#  ['log', 'nomor', 'blokir', 'pdhl', 'pakai', 'order', 'jual'],
#  ['aplikasi', 'php'],
#  ['aplikasi',
#   'akun',
#   'sya',
#   'blokir',
#   'sya',
#   'sarankn',
#   'dwonload',
#   'jangan',
#   'dwnload',
#   'nyeseel'],
#  ['bayar', 'link'],
#  ['belanja',
#   'pesan',
#   'bayar',
#   'tanggal',
#   'nov',
#   'tanda',
#   'kirim',
#   'catat',
#   'proses',
#   'kemas',
#   'gilir',
#   'chat',
#   'customer service',
#   'muter',
#   'karuan'],
#  ['iklan', 'melulu', 'kntol', 'aplikasi', 'anjng'],
#  ['seller', 'bodoh'],
#  ['kirim', 'kayak', 'toko'],
#  ['tolong',
#   'skrng',
#   'ongkir',
#   'pisah',
#   'pisah',
#   'ongkir',
#   'distuin',
#   'sdkit',
#   'tolong',
#   'satuin',
#   'ongkir'],
#  ['sayang',
#   'cicil',
#   'kartu',
#   'kredit',
#   'toko',
#   'belah',
#   'kredit',
#   'kartu',
#   'kredit'],
#  ['terkadang',
#   'masuk',
#   'fitur',
#   'siram',
#   'tanam',
#   'lngsng',
#   'freeze',
#   'baru',
#   'restart',
#   'ulang',
#   'handphone',
#   'khawarir',
#   'rebout',
#   'handphone',
#   'tolong',
#   'lagi',
#   'memori',
#   'masih',
#   'seger',
#   'ram',
#   'juga',
#   'masih',
#   'sisa',
#   'gb',
#   'lbh',
#   'gb',
#   'handphone',
#   'juga',
#   'bukan',
#   'kentang',
#   'aplikasi',
#   'berat',
#   'fitur',
#   'selalu',
#   'lin'],
#  ['aplikasi', 'gun', 'tipu'],
#  ['belanja',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'extra',
#   'susah',
#   'check',
#   'out',
#   'bolak'],
#  ['syah', 'bayar', 'expres'],
#  ['jelekkk',
#   'main',
#   'game',
#   'minecrft',
#   'nama',
#   'survival',
#   'na',
#   'muncul',
#   'ikkelan',
#   'pencet',
#   'skip',
#   'mati',
#   'iiih',
#   'jelekk'],
#  ['bug', 'bnerin'],
#  ['shope', 'gimmick', 'flashsale', 'iphone', 'kirim', 'batal', 'hahaha'],
#  ['beres',
#   'aplikasi',
#   'unduh',
#   'aplikasi',
#   'ken',
#   'coba',
#   'belanja',
#   'kayak',
#   'ny',
#   'checkout',
#   'payung',
#   'harga',
#   'ongkir',
#   'akal',
#   'tanggerang',
#   'jambi',
#   'ongkir',
#   'rp',
#   'benar',
#   'harga',
#   'payung'],
#  ['team',
#   'becus',
#   'cie',
#   'nanganin',
#   'custamer',
#   'transaksi',
#   'tanggal',
#   'nov',
#   'sampai',
#   'tanggal',
#   'nov',
#   'biarin',
#   'komplian',
#   'pakai',
#   'mesin',
#   'tolong',
#   'bantu',
#   'jual',
#   'pinter',
#   'barang',
#   'kirim',
#   'retur',
#   'kurir',
#   'tolong',
#   'bantu',
#   'dana',
#   'belanja'],
#  ['kenal',
#   'toko',
#   'sukses',
#   'beli',
#   'barang',
#   'sesuai',
#   'foto',
#   'beli',
#   'barang',
#   'rusak',
#   'kan',
#   'anjig'],
#  ['ribet', 'beli', 'shpee'],
#  ['recomended',
#   'aplikasi',
#   'belanja',
#   'pesan',
#   'akun',
#   'mes',
#   'lemari',
#   'harga',
#   'heboh',
#   'keluarga',
#   'batal',
#   'pesan',
#   'handphone',
#   'jam',
#   'pakai',
#   'ajar',
#   'kirim',
#   'kirim',
#   'alamat',
#   'bilang',
#   'pesan',
#   'kirim',
#   'men',
#   'percaya',
#   'cari',
#   'google'],
#  ['maaf',
#   'uninstal',
#   'tipu',
#   'tipu',
# ...
#   'diturunin',
#   'naekin',
#   'tolong',
#   'dinaekkn',
#   'merger',
#   'suramm'],
#  ['aplikasi',
#   'anjig',
#   'pdahal',
#   'install',
#   'promo',
#   'batal',
#   'sen',
#   'voucher',
#   'ongkir',
#   'hilang',
#   'tlol'],
#  ['aplikasi',
#   'produk',
#   'sesuai',
#   'pesan',
#   'sayang',
#   'ongkir',
#   'mahal',
#   'diskon',
#   'voucer',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'mengambil',
#   'ribu'],
#  ['promo',
#   'mancing',
#   'awam',
#   'pengaruh',
#   'promo',
#   'fitur',
#   'aplikasi',
#   'kaku',
#   'saldo',
#   'dipake',
#   'bayar',
#   'ambil',
#   'lebih baik'],
#  ['gratis',
#   'ongkir',
#   'dwnlod',
#   'pesan',
#   'barang',
#   'langgan',
#   'knk',
#   'cas',
#   'ribu',
#   'ongkir',
#   'kelimapuluh',
#   'kabupaten',
#   'batubara',
#   'harga',
#   'mahal',
#   'bnding',
#   'murah',
#   'ongkir',
#   'cmn',
#   'ribu',
#   'gratis',
#   'ongkir',
#   'pulau',
#   'jawa',
#   'kesumut',
#   'ribu',
#   'gilaaak',
#   'klen',
#   'seperti',
#   'gmn',
#   'banyak',
#   'plnggnnya',
#   'blnj',
#   'berat',
#   'diongkir',
#   'hrg',
#   'mahal',
#   'banding',
#   'aplikasi',
#   'ttngga'],
#  ['keluarin', 'iklan', 'boss', 'kesel', 'iklan', 'nyaman'],
#  ['up', 'kemarin', 'indomart', 'sukses', 'saldo'],
#  ['aplikasi',
#   'commerce',
#   'bikin',
#   'bingung',
#   'masukkan',
#   'nomor',
#   'rekening',
#   'susah'],
#  ['sinyal', 'butuh'],
#  ['maaf',
#   'bri',
#   'bintang',
#   'ea',
#   'nnti',
#   'klau',
#   'brng',
#   'smpai',
#   'baru',
#   'ksih',
#   'bintang',
#   'lagi'],
#  ['lambat', 'downloadnya'],
#  ['organisasi', 'birokrasi'],
#  ['gin',
#   'dowanload',
#   'lagu',
#   'chrome',
#   'ngapain',
#   'unduh',
#   'bilang',
#   'macam',
#   'macam',
#   'poromo',
#   'case',
#   'back',
#   'bikin',
#   'repot',
#   'perasaandah'],
#  ['iklan', 'ganggu', 'tolong', 'jangan', 'iklan', 'sembarang'],
#  ['beli',
#   'bayar',
#   'batal',
#   'promo',
#   'promo',
#   'sisa',
#   'promo',
#   'batal',
#   'transaksi',
#   'kupon',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'ribu',
#   'kupon',
#   'cashback',
#   'ribu',
#   'hilang',
#   'pagi',
#   'sisa',
#   'aju',
#   'care',
#   'balas',
#   'sesuai',
#   'prosedur',
#   'langgar',
#   'tolong'],
#  ['barang', 'siap', 'order', 'kirim', 'kirim', 'batal', 'konfirmasi'],
#  ['takut', 'jahat', 'ngrim', 'alamat'],
#  ['tmpat', 'tinggal', 'camat', 'grong', 'kabupaten', 'pidie', 'kota', 'sigli'],
#  ['tutup', 'akun', 'tanda', 'sistem', 'shoppe', 'kualitas'],
#  ['gratis',
#   'ongkir',
#   'pakai',
#   'sekal',
#   'cari',
#   'toko',
#   'label',
#   'gratis',
#   'ongkir',
#   'toko',
#   'barang',
#   'cari',
#   'pakai',
#   'toko',
#   'kacau',
#   'tolong'],
#  ['lot', 'bnget', 'bayar', 'susah', 'kesini', 'mkin', 'mles', 'lot'],
#  ['lma',
#   'lot',
#   'sebentar',
#   'logout',
#   'sendiri',
#   'pdhal',
#   'ram',
#   'msih',
#   'nyukup',
#   'ntah',
#   'berat',
#   'game',
#   'ny',
#   'tolong'],
#  ['unduh', 'komplen'],
#  ['aplikasi', 'eror', 'terus', 'pdhl', 'update', 'pke', 'pers', 'tetep'],
#  ['budug', 'rehan'],
#  ['gratis', 'ongkir'],
#  ['mola',
#   'minggu',
#   'malam',
#   'kirim',
#   'hadiah',
#   'menang',
#   'nga',
#   'nyampe',
#   'coi',
#   'hadiah',
#   'palsu'],
#  ['barang', 'sesuai'],
#  ['klu',
#   'setock',
#   'barang',
#   'jangan',
#   'pajang',
#   'pajang',
#   'gambar',
#   'pesan',
#   'baju',
#   'batas',
#   'proses',
#   'proses',
#   'potong',
#   'biayamah',
#   'cepat',
#   'kirim',
#   'susah',
#   'puayah'],
#  ['notifikasi', 'kirim', 'cepat', 'fakta', 'kaya', 'bulus', 'lot', 'estimasi'],
#  ['jual',
#   'amanah',
#   'aplikasi',
#   'proses',
#   'barang',
#   'salah',
#   'kirim',
#   'sulit',
#   'seler',
#   'amanah',
#   'tindak',
#   'sebenernya',
#   'rugi',
#   'aplikasi',
#   'customer',
#   'alih',
#   'aplikasi',
#   'lbh',
#   'amanah',
#   'lbh',
#   'mudah',
#   'proses',
#   'pengembalaian',
#   'barang'],
#  ['game', 'jual', 'ayig'],
#  ['toko', 'handal'],
#  ['tolong',
#   'bantu',
#   'foto',
#   'jual',
#   'ratus',
#   'muncul',
#   'tarik',
#   'pelang',
#   'barang',
#   'gudang',
#   'muncul',
#   'pantas',
#   'jual',
#   'terus'],
#  ['aplikasi',
#   'sihh',
#   'kmarin',
#   'apdet',
#   'isi',
#   'saldo',
#   'ribu',
#   'suruh',
#   'ngapdet',
#   'apdet',
#   'kok',
#   'uang',
#   'koin',
#   'koinya',
#   'hilang',
#   'rugi',
#   'dongg',
#   'erti'],
#  ['update',
#   'asa',
#   'gratis',
#   'ongkir',
#   'update',
#   'layar',
#   'putih',
#   'gambar',
#   'gapernah',
#   'gratis',
#   'ongkir',
#   'cod',
#   'why'],
#  ['tipu',
#   'promo',
#   'flash',
#   'sale',
#   'ken',
#   'hapus',
#   'aplikasi',
#   'standby',
#   'sblm',
#   'pkl',
#   'pesan',
#   'stock',
#   'habis',
#   'terang',
#   'jual',
#   'stock',
#   'kosong',
#   'jam',
#   'saran',
#   'klu',
#   'masih',
#   'banyak',
#   'tipu',
#   'promo',
#   'sesuai'],
#  ['update',
#   'bayar',
#   'chat',
#   'customer service',
#   'hang',
#   'restart',
#   'aplikasi'],
#  ['berat',
#   'aplikasi',
#   'respon',
#   'pencet',
#   'berat',
#   'beda',
#   'ringan',
#   'smooth'],
#  ['ongkir',
#   'mahal',
#   'brooo',
#   'hadeuh',
#   'hadeuh',
#   'ganti',
#   'opsi',
#   'kurir',
#   'harga',
#   'up',
#   'up',
#   'mahal',
#   'customer service',
#   'bot',
#   'mlu',
#   'jwbannya',
#   'ktnya',
#   'unicorn',
#   'customer service',
#   'bot'],
#  ['virus', 'iklan', 'handphone', 'eror'],
#  ['aplikasi',
#   'bela',
#   'seller',
#   'beli',
#   'please',
#   'be',
#   'careful',
#   'skripsi',
#   'sesat',
#   'seller',
#   'utama',
#   'dropship',
#   'seller',
#   'modal'],
#  ['chekout',
#   'pin',
#   'salah',
#   'pdhl',
#   'benar',
#   'sampai',
#   'blokir',
#   'tolong',
#   'gimanain'],
#  ['haraga', 'barang', 'beli'],
#  ['toko', 'tanggung', 'kirim', 'barang', 'sesuai', 'pesan', 'barang'],
#  ['kemarin',
#   'aktif',
#   'kredit',
#   'isi',
#   'data',
#   'data',
#   'hapus',
#   'nama',
#   'tika',
#   'aprilia',
#   'triyanto',
#   'kredit',
#   'handphone',
#   'counter',
#   'bantu',
#   'hapus',
#   'data'],
#  ['tipu', 'barang', 'sesuai', 'tokony', 'bawa', 'rezeky', 'usaha', 'tipu'],
#  ['beli', 'pulsa', 'refund', 'melulu', 'anjimmm', 'kaya'],
#  ['unduh', 'tunggu', 'hati', 'riang', 'gembira', 'tbtb', 'gagal'],
#  ['aplikasi', 'jelekk', 'login', 'pke', 'verifikasi', 'wajah', 'upgrade'],
#  ['aplikasi',
#   'hancur',
#   'ran',
#   'ribet',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'dasar'],
#  ['verrsi',
#   'android',
#   'hambat',
#   'tunanetra',
#   'menu',
#   'food',
#   'akses',
#   'searching',
#   'lokasi',
#   'resto',
#   'menu',
#   'keranjang',
#   'tulis',
#   'salah',
#   'tindak'],
#  ['lindung',
#   'garansi',
#   'bintang',
#   'bicara',
#   'tim',
#   'jual',
#   'jual',
#   'amanah',
#   'jual',
#   'jujur',
#   'tim',
#   'bantuin',
#   'keluh',
#   'mbelinya'],
#  ['jasa', 'kirim', 'sedia'],
#  ['scar', 'tri'],
#  ['engga',
#   'up',
#   'logika',
#   'up',
#   'akun',
#   'ngendap',
#   'bank',
#   'konvensional',
#   'tranfer',
#   'ganggu',
#   'jam',
#   'kelas',
#   'bank',
#   'aplikasi',
#   'urus',
#   'up',
#   'engga',
#   'tunggu'],
#  ['bintang', 'pakek', 'amplikasi', 'iklan', 'muncul', 'handphone'],
#  ['baru',
#   'pakai',
#   'order',
#   'ngecewain',
#   'batal',
#   'jasa',
#   'kirim',
#   'baru',
#   'tahu',
#   'js',
#   'pgriman',
#   'batal',
#   'kirim',
#   'jam',
#   'bareng',
#   'kirim',
#   'alamat',
#   'jm',
#   'sore',
#   'untuk',
#   'siapkn',
#   'uang',
#   'sstm',
#   'bayar',
#   'ttpi',
#   'jm',
#   'mlm',
#   'pmbritahuan',
#   'bareng',
#   'gagal',
#   'kirim',
#   'curiga',
#   'psnan',
#   'mysteri',
#   'box',
#   'nominal',
#   'paham',
#   'kan',
#   'kcurigaan',
#   'aneh',
#   'jsa',
#   'pgirimannya',
#   'sam',
#   'lx',
#   'tlglah',
#   'lbh',
#   'selektif',
#   'dlm',
#   'pilih',
#   'jasa',
#   'kirim',
#   'amatir',
#   'model',
#   'gtu'],
#  ['cod', 'toko', 'tipu', 'hadeeeee'],
#  ['unduh', 'lagu'],
#  ['aplikasi',
#   'browsing',
#   'tonton',
#   'drakor',
#   'ehh',
#   'suruh',
#   'unduh',
#   'aplikasi',
#   'aplikasi'],
#  ['iklan', 'anjim'],
#  ['aplikasi', 'tipu'],
#  ['semerawut',
#   'sen',
#   'bareng',
#   'tunggu',
#   'dibatalin',
#   'lagi',
#   'sellernya',
#   'kapok',
#   'blja',
#   'dsni',
#   'beli',
#   'sepele',
#   'uninstall',
#   'az',
#   'puzink'],
#  ['beli',
#   'platihan',
#   'status',
#   'transaksi',
#   'batal',
#   'status',
#   'platihan',
#   'aktif',
#   'voucher',
#   'pltihan',
#   'beli',
#   'hambat',
#   'beli',
#   'platihan',
#   'aktif',
#   'email',
#   'pusat',
#   'bantu',
#   'refand',
#   'ribet',
#   'hambat',
#   'karir'],
#  ['aplikasi',
#   'cekout',
#   'rupiah',
#   'pas',
#   'cek',
#   'out',
#   'batal',
#   'coba',
#   'ganti',
#   'nomer',
#   'batal',
#   'donlut',
#   'aplikasi',
#   'males',
#   'php',
#   'kaya',
#   'toko',
#   'pilih',
#   'barang',
#   'rupiah',
#   'batal'],
#  ['anteraja', 'dipake', 'laaah', 'bikin', 'layan'],
#  ['promo',
#   'pakai',
#   'coin',
#   'dahh',
#   'benar',
#   'promo',
#   'potong',
#   'ongkir',
#   'pakai',
#   'pakai',
#   'point',
#   'evektif'],
#  ['susah',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'online',
#   'tarik',
#   'murah',
#   'ongkir'],
#  ['pakai', 'trsnsaksi'],
#  ['kirim', 'kuno', 'instan'],
#  ['update', 'mennggapi'],
#  ['bintang',
#   'rena',
#   'install',
#   'ulang',
#   'sampai',
#   'akun',
#   'hapus',
#   'pindah',
#   'pakai',
#   'aplikasi',
#   'ribet'],
#  ['akun',
#   'shoppe',
#   'login',
#   'costumer',
#   'service',
#   'tolong',
#   'bantu',
#   'bayar',
#   'shoppepaylatter'],
#  ['aowkwowkwok', 'aplikasi', 'mandang', 'handphone'],
#  ['aneh', 'pesan', 'barang', 'nama', 'kirim'],
#  ['ganggu', 'link', 'unduh'],
#  ['tipu',
#   'toko',
#   'nakal',
#   'kirim',
#   'barang',
#   'cod',
#   'pesan',
#   'barang',
#   'filter',
#   'tipu'],
#  ['aplikasi', 'prank', 'konten'],
#  ['barang',
#   'dikirm',
#   'nggk',
#   'sesuai',
#   'mau',
#   'barang',
#   'proses',
#   'ribet',
#   'banding',
#   'toko',
#   'online',
#   'belah',
#   'nggk',
#   'kaya',
#   'gin'],
#  ['iklan', 'mental', 'play', 'toko'],
#  ['sampai',
#   'sertifikat',
#   'bom',
#   'muncul',
#   'dasbor',
#   'prakerjaaaaaaaa',
#   'tolong',
#   'cepat'],
#  ['sore',
#   'aplikasi',
#   'burik',
#   'loading',
#   'gagal',
#   'muat',
#   'pdahal',
#   'jaringal'],
#  ['bikin', 'promo', 'diskon', 'gilir', 'dipake', 'anggap', 'menyalaho'],
#  ['aplikasi', 'sen', 'paket', 'hancur', 'kirim', 'hancurrrrrrr'],
#  ['pilih', 'jasa', 'kirim', 'sinyal'],
#  ['aneh', 'dh', 'diupdate', 'ttp', 'ilangin', 'ganggu'],
#  ['bisa', 'downlod'],
#  ['woyy',
#   'bangke',
#   'cari',
#   'lot',
#   'bangkee',
#   'update',
#   'aplikasi',
#   'sinyal',
#   'tahi',
#   'laah'],
#  ['ngadain',
#   'cashback',
#   'cashback',
#   'jarang',
#   'aplikasi',
#   'tembah',
#   'lot',
#   'mitra',
#   'curang',
#   'males',
#   'beli',
#   'belanja',
#   'pakai',
#   'pindah',
#   'toko'],
#  ['tolong', 'tolong', 'up', 'snack', 'vidio', 'uang'],
#  ['kecewaaa',
#   'bangett',
#   'sntadar',
#   'ekpress',
#   'kirim',
#   'bangett',
#   'banding',
#   'kirim',
#   'reguler',
#   'lai',
#   'lebih baik',
#   'ituu',
#   'hedhhh'],
#  ['live', 'chat', 'susah'],
#  ['tolong', 'bantu', 'saldo', 'hubung', 'dana'],
#  ['ribet',
#   'dipake',
#   'lockout',
#   'verivikasi',
#   'belibet',
#   'muter',
#   'auto',
#   'un',
#   'install',
#   'ao',
#   'gin'],
#  ['aplikasi',
#   'pngiriman',
#   'bnyak',
#   'pnjual',
#   'jelassss',
#   'paket',
#   'dateng',
#   'lgsung',
#   'uinstal',
#   'bkal',
#   'dowlnd',
#   'lh'],
#  ['aplikasi',
#   'tipu',
#   'sen',
#   'box',
#   'dateng',
#   'cincin',
#   'harga',
#   'ribu',
#   'pantau',
#   'toko',
#   'toko',
#   'amanah',
#   'korban',
#   'aplikasi'],
#  ['baca',
#   'editor',
#   'notice',
#   'bintang',
#   'cuman',
#   'saran',
#   'letak',
#   'gambar',
#   'produk',
#   'sejajar',
#   'judul',
#   'produk',
#   'tulis',
#   'kecilin',
#   'mudah',
#   'gambar',
#   'contolah',
#   'akun',
#   'shope',
#   'belah',
#   'gambar',
#   'iklan',
#   'nyaingin',
#   'toko',
#   'belah',
#   'fitur',
#   'tampil',
#   'tarik',
#   'toko',
#   'belah',
#   'notice',
#   'baca'],
#  ['kurir',
#   'alamat',
#   'tera',
#   'cantum',
#   'nama',
#   'orang',
#   'belanja',
#   'setelah',
#   'komplain',
#   'tuntas',
#   'tutup',
#   'beli',
#   'rugi',
#   'barang',
#   'hilang'],
#  ['sayang',
#   'pesan',
#   'rupiah',
#   'beli',
#   'eror',
#   'bilang',
#   'pesan',
#   'sdngkan',
#   'dengn',
#   'bareng',
#   'kecewaa'],
#  ['gratis', 'ongkir', 'kya'],
#  ['tulis', 'kolom', 'cari', 'eror'],
#  ['tolong',
#   'benah',
#   'kurir',
#   'shoope',
#   'express',
#   'pesan',
#   'hold',
#   'jarak',
#   'kirim',
#   'lokasi',
#   'kirim'],
#  ['chat', 'eror', 'connect', 'jaring'],
#  ['mengisi', 'shopay', 'saldo', 'atm', 'duit'],
#  ['verivikasi', 'bikin', 'ribet'],
#  ['dear',
#   'mimin',
#   'kendala',
#   'checkout',
#   'checkout',
#   'pesan',
#   'checkout',
#   'gagal',
#   'risih',
#   'pesan',
#   'pesan',
#   'otomatis',
#   'checkout',
#   'pesan',
#   'harga',
#   'barang',
#   'beli',
#   'sesuai',
#   'voucher',
#   'voucher',
#   'tolong',
#   'mimin',
#   'mudah',
#   'checkout',
#   'tolong',
#   'checkout',
#   'gagal'],
#  ['belanja', 'kli', 'isi', 'pakrtnya', 'bodoh'],
#  ['iklan', 'spam', 'google', 'nonton', 'film', 'skip', 'heran'],
#  ['belanja',
#   'bayar',
#   'alfa',
#   'indomaret',
#   'barang',
#   'cod',
#   'malas',
#   'pakai',
#   'aplikasi',
#   'tolong',
#   'informasi'],
#  ['bintang', 'pilih', 'kurir', 'besok', 'tunggu', 'kurir', 'lamban'],
#  ['mantaaaa', 'belanja', 'tipu', 'belanja', 'pesan', 'sesuai'],
#  ['sampah', 'selalu', 'ganggu'],
#  ['aplikasi', 'serius'],
#  ['mahal', 'ongkir', 'beli', 'kirim', 'hadehhh', 'gaze'],
#  ['commerce',
#   'gajelas',
#   'pakai',
#   'voucher',
#   'promo',
#   'dipake',
#   'pas',
#   'dipake',
#   'transaksi',
#   'batal',
#   'otomatis',
#   'transaksi',
#   'akun',
#   'tahu',
#   'akun',
#   'bertanya',
#   'costumer',
#   'service',
#   'solusi'],
#  ['aplikasi',
#   'aman',
#   'hubung',
#   'akun',
#   'informasi',
#   'kartu',
#   'kredit',
#   'link',
#   'fintech',
#   'otp',
#   'login',
#   'perangkat',
#   'pin',
#   'transaksi',
#   'fintech',
#   'retas',
#   'alami',
#   'sendir',
#   'akun',
#   'retas',
#   'topup',
#   'money',
#   'koneksi',
#   'akun',
#   'bertanggungjawab',
#   'rubah',
#   'pin',
#   'password',
#   'rutin',
#   'hubung',
#   'bayar'],
#  ['donlod', 'chekout', 'aneh'],
#  ['pliss',
#   'data',
#   'cur',
#   'ganti',
#   'rugi',
#   'jt',
#   'lapor',
#   'shoppe',
#   'polisi',
#   'titik'],
#  ['benar',
#   'order',
#   'proses',
#   'kirim',
#   'toleransi',
#   'jual',
#   'kirim',
#   'recommended',
#   'order',
#   'kuciwa'],
#  ['bayar', 'cok'],
#  ['aduhh',
#   'maaf',
#   'isi',
#   'alamat',
#   'kecamatan',
#   'kota',
#   'salah',
#   'pdhal',
#   'ulang',
#   'ulang'],
#  ['menu',
#   'utama',
#   'mesti',
#   'pencet',
#   'salah',
#   'gimna',
#   'sen',
#   'haduh',
#   'makane',
#   'sebel',
#   'pakai',
#   'shoopee',
#   'gin',
#   'tolong',
#   'bantu',
#   'dibenerin',
#   'gimna'],
#  ['barang', 'bnyak', 'sesuai', 'kirim'],
#  ['gimn', 'belanja', 'sistem', 'cod'],
#  ['toko', 'tipu', 'tolong', 'banned', 'toko', 'tipu', 'periksa', 'lagiiiii'],
#  ['daftar', 'akun', 'sulit', 'mnding', 'toko', 'belah'],
#  ['tolong', 'aplikasi', 'beli', 'kouta', 'aplikasi', 'tapi', 'ny', 'aplikasi'],
#  ['pakai', 'pakai', 'voucher'],
#  ['bayar', 'link', 'enggk'],
#  ['daftar', 'ngabis', 'kuota'],
#  ['aplikasi', 'lot'],
#  ['pesan', 'sini', 'pesn', 'sini', 'barang', 'proses', 'bayar', 'hadeeeeee'],
#  ['suruh',
#   'kritik',
#   'keritik',
#   'ber',
#   'diam',
#   'ubah',
#   'kirim',
#   'lempar',
#   'xpres',
#   'lot',
#   'sap',
#   'expres',
#   'bangke',
#   'benar',
#   'kirim',
#   'area',
#   'jawa',
#   'makan',
#   'full'],
#  ['gambar', 'ampas'],
#  ['maaf',
#   'masak',
#   'muncul',
#   'detik',
#   'muncul',
#   'detik',
#   'muncul',
#   'tolong',
#   'menit',
#   'seperti',
#   'menit',
#   'tibul',
#   'timbul',
#   'jengkel',
#   'cek',
#   'maaf',
#   'hoak'],
#  ['tolong',
#   'iklan',
#   'menggangu',
#   'nyaman',
#   'jelajah',
#   'internet',
#   'hapus',
#   'aplikasi',
#   'ganggu'],
#  ['unduh', 'aplikasi', 'tipu'],
#  ['beri',
#   'rating',
#   'tanggung',
#   'dsb',
#   'kerjain',
#   'nyuruh',
#   'hubung',
#   'hubung',
#   'puter',
#   'puter',
#   'lagi',
#   'orang',
#   'beri',
#   'kritik',
#   'ketidakpuasan',
#   'cepat',
#   'tanganin',
#   'nyuruh',
#   'hubung',
#   'gambar',
#   'tampil',
#   'pending',
#   'bingung',
#   'internet',
#   'pasang',
#   'gb',
#   'handphone',
#   'redmi',
#   'note',
#   'apalalagi',
#   'salah'],
#  ['install', 'aplikasi', 'hadiah', 'jangan', 'bohong', 'aje'],
#  ['tawarin',
#   'rupiah',
#   'pas',
#   'cek',
#   'tetep',
#   'beli',
#   'mahal',
#   'aplikasi',
#   'shopy'],
#  ['terlambat',
#   'bayar',
#   'shopeepaylater',
#   'tlponin',
#   'puluh',
#   'kayak',
#   'hutang',
#   'puluh',
#   'juta',
#   'ngk',
#   'bayar',
#   'bom',
#   'gaji',
#   'gaji',
#   'undur',
#   'nelponin',
#   'ngk',
#   'paut',
#   'tunggak',
#   'bayar',
#   'kasi',
#   'teman',
#   'diganguin',
#   'melulu',
#   'kayak',
#   'teror',
#   'ganggu',
#   'tolong',
#   'baca',
#   'tolong',
#   'erti'],
#  ['tari',
#   'saldo',
#   'even',
#   'bayar',
#   'kumpulun',
#   'kawan',
#   'susah',
#   'tolong',
#   'ikan'],
#  ['cod', 'cash', 'or', 'duel'],
#  ['akun',
#   'alami',
#   'janggal',
#   'live',
#   'chat',
#   'sulit',
#   'tombol',
#   'live',
#   'chat',
#   'unduh'],
#  ['setia', 'sllu', 'sperti', 'vocher', 'valid', 'vocher', 'msih'],
#  ['maaf', 'bri', 'dl', 'baru'],
#  ['iklan',
#   'amplikasi',
#   'ganggu',
#   'donlod',
#   'musik',
#   'tadi',
#   'muncul',
#   'handphone',
#   'teruss',
#   'bikin',
#   'emosi'],
#  ['aplikasi',
#   'nggk',
#   'install',
#   'unduh',
#   'berualang',
#   'ulang',
#   'kuota',
#   'hangus',
#   'bgtu',
#   'gara',
#   'unduh',
#   'tapi',
#   'terinstal'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (5, 6):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha='asymmetric', eta='symmetric')
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the outputt
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(0, 0.055473145), (1, 0.03833102), (2, 0.0292822), (3, 0.52371424), (4, 0.35319933)]
# [(0, 0.11094737), (1, 0.07666249), (2, 0.058564592), (3, 0.047379576), (4, 0.706446)]
# [(0, 0.13954346), (1, 0.04236508), (2, 0.17588006), (3, 0.6060648), (4, 0.036146667)]
# [(0, 0.3331995), (1, 0.05749634), (2, 0.54393315), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.06656754), (1, 0.24596632), (2, 0.27919507), (3, 0.028455907), (4, 0.37981513)]
# [(0, 0.16659342), (1, 0.028748168), (2, 0.02196163), (3, 0.017767329), (4, 0.7649295)]
# [(0, 0.8308962), (1, 0.059331644), (2, 0.044304267), (3, 0.035605706), (4, 0.029862225)]
# [(0, 0.77761257), (1, 0.07666171), (2, 0.058564324), (3, 0.047379535), (4, 0.039781872)]
# [(0, 0.8723499), (1, 0.09642238), (2, 0.012549541), (3, 0.0101527665)]
# [(0, 0.3407017), (1, 0.025903381), (2, 0.019661644), (3, 0.015797071), (4, 0.59793615)]
# [(0, 0.44427958), (1, 0.4099947), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.060644865), (1, 0.03285502), (2, 0.025411109), (3, 0.8640396), (4, 0.017049376)]
# [(0, 0.03698199), (1, 0.026361797), (2, 0.01952145), (3, 0.46023464), (4, 0.45690018)]
# [(0, 0.053353284), (1, 0.032855026), (2, 0.025099004), (3, 0.8716421), (4, 0.017050596)]
# [(0, 0.05547512), (1, 0.038331974), (2, 0.2261203), (3, 0.6601691), (4, 0.019903421)]
# [(0, 0.6514076), (1, 0.045997143), (2, 0.035593204), (3, 0.24311706), (4, 0.023884993)]
# [(0, 0.12023867), (1, 0.052064195), (2, 0.14720553), (3, 0.08141196), (4, 0.59907967)]
# [(0, 0.11478124), (1, 0.076661736), (2, 0.7213631), (3, 0.047393385), (4, 0.039800517)]
# [(0, 0.017518515), (1, 0.86172515), (2, 0.06482014), (3, 0.04965487)]
# [(0, 0.4442792), (1, 0.07666171), (2, 0.39189768), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.44427755), (1, 0.07666174), (2, 0.05856434), (3, 0.38071448), (4, 0.03978188)]
# [(0, 0.14222664), (1, 0.076661706), (2, 0.058564324), (3, 0.6827654), (4, 0.039781872)]
# [(0, 0.44414064), (1, 0.40999413), (2, 0.058564335), (3, 0.047519013), (4, 0.039781876)]
# [(0, 0.08321115), (1, 0.55558467), (2, 0.04392334), (3, 0.035534672), (4, 0.2817462)]
# [(0, 0.3332388), (1, 0.05749959), (2, 0.54389054), (3, 0.03553471), (4, 0.029836416)]
# [(0, 0.123966455), (1, 0.07666201), (2, 0.37889585), (3, 0.047379553), (4, 0.3730961)]
# [(0, 0.033283792), (1, 0.22299506), (2, 0.017569305), (3, 0.014213865), (4, 0.711938)]
# [(0, 0.33310533), (1, 0.0574963), (2, 0.29392162), (3, 0.035639353), (4, 0.2798374)]
# [(0, 0.110946245), (1, 0.4100153), (2, 0.39187706), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.11094606), (1, 0.07666185), (2, 0.39190033), (3, 0.047379542), (4, 0.3731122)]
# [(0, 0.58326423), (1, 0.30744126), (2, 0.043923445), (3, 0.03553469), (4, 0.029836416)]
# [(0, 0.33325666), (1, 0.03285502), (2, 0.025098998), (3, 0.5917322), (4, 0.0170571)]
# [(0, 0.38179487), (1, 0.123076126), (2, 0.11761699), (3, 0.014224514), (4, 0.3632875)]
# [(0, 0.28934652), (1, 0.18582338), (2, 0.09795518), (3, 0.10664444), (4, 0.3202305)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.083209634), (1, 0.057496447), (2, 0.7939229), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.2781621), (1, 0.26874974), (2, 0.09796696), (3, 0.17853755), (4, 0.17658366)]
# [(0, 0.11094632), (1, 0.07666201), (2, 0.39188886), (3, 0.3807209), (4, 0.039781883)]
# [(0, 0.77758026), (1, 0.07666171), (2, 0.058596596), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.08320945), (1, 0.5574981), (2, 0.043923255), (3, 0.035534654), (4, 0.2798346)]
# [(0, 0.58324057), (1, 0.05749713), (2, 0.043923438), (3, 0.035534695), (4, 0.2798042)]
# [(0, 0.09854776), (1, 0.057496283), (2, 0.043923248), (3, 0.5355349), (4, 0.2644978)]
# [(0, 0.46656346), (1, 0.045997288), (2, 0.03513866), (3, 0.028427737), (4, 0.42387286)]
# [(0, 0.05547293), (1, 0.03908717), (2, 0.029863343), (3, 0.02368977), (4, 0.85188675)]
# [(0, 0.4761222), (1, 0.032855045), (2, 0.16794996), (3, 0.3060193), (4, 0.017053485)]
# [(0, 0.08016591), (1, 0.045997124), (2, 0.4351469), (3, 0.41481453), (4, 0.023875536)]
# [(0, 0.46656743), (1, 0.04599703), (2, 0.43511772), (3, 0.02844874), (4, 0.023869125)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.04433004), (3, 0.03554992), (4, 0.77941436)]
# [(0, 0.833178), (1, 0.05749628), (2, 0.043923248), (3, 0.03556606), (4, 0.029836407)]
# [(0, 0.44427922), (1, 0.07666177), (2, 0.3918976), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.47610798), (1, 0.2896016), (2, 0.025099011), (3, 0.020323316), (4, 0.18886809)]
# [(0, 0.046456777), (1, 0.45663893), (2, 0.021961652), (3, 0.017772762), (4, 0.45716983)]
# [(0, 0.1504614), (1, 0.13666981), (2, 0.01952146), (3, 0.25075138), (4, 0.44259602)]
# [(0, 0.083209485), (1, 0.05749634), (2, 0.044767354), (3, 0.78469044), (4, 0.029836409)]
# [(0, 0.11094592), (1, 0.40999702), (2, 0.39189565), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.7776125), (1, 0.07666172), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.110967845), (1, 0.076670505), (2, 0.058564737), (3, 0.71401507), (4, 0.03978189)]
# [(0, 0.58302534), (1, 0.057496324), (2, 0.04392326), (3, 0.0357166), (4, 0.2798385)]
# [(0, 0.5821746), (1, 0.30853078), (2, 0.04392355), (3, 0.035534717), (4, 0.029836422)]
# [(0, 0.13162692), (1, 0.40999496), (2, 0.05856433), (3, 0.04737954), (4, 0.35243425)]
# [(0, 0.4665678), (1, 0.2459968), (2, 0.0351386), (3, 0.02847657), (4, 0.22382024)]
# [(0, 0.45100933), (1, 0.074394435), (2, 0.3245134), (3, 0.07643309), (4, 0.073649734)]
# [(0, 0.2058497), (1, 0.033070136), (2, 0.02519331), (3, 0.34975618), (4, 0.38613066)]
# [(0, 0.64167696), (1, 0.045997024), (2, 0.0351386), (3, 0.028427724), (4, 0.24875975)]
# [(0, 0.48919034), (1, 0.02013501), (2, 0.46885964), (3, 0.011867799)]
# [(0, 0.3247033), (1, 0.20271856), (2, 0.44880274), (3, 0.012923139), (4, 0.010852239)]
# [(0, 0.2665672), (1, 0.24599703), (2, 0.0351386), (3, 0.028427726), (4, 0.42386946)]
# [(0, 0.110946186), (1, 0.07666189), (2, 0.05947027), (3, 0.04737955), (4, 0.7055421)]
# [(0, 0.7727597), (1, 0.08009331), (2, 0.059985537), (3, 0.047379617), (4, 0.039781895)]
# [(0, 0.22304855), (1, 0.7036083), (2, 0.02972191), (3, 0.023730317), (4, 0.01989094)]
# [(0, 0.1614423), (1, 0.020907976), (2, 0.015972283), (3, 0.7908278), (4, 0.010849603)]
# [(0, 0.33318177), (1, 0.55752385), (2, 0.043923296), (3, 0.035534665), (4, 0.029836409)]
# [(0, 0.066675015), (1, 0.046289273), (2, 0.3032085), (3, 0.5599538), (4, 0.02387347)]
# [(0, 0.34563115), (1, 0.226375), (2, 0.029390408), (3, 0.37871143), (4, 0.019892007)]
# [(0, 0.52016646), (1, 0.057496283), (2, 0.043923248), (3, 0.3485776), (4, 0.029836407)]
# [(0, 0.0832099), (1, 0.5574849), (2, 0.043923326), (3, 0.035534672), (4, 0.27984717)]
# [(0, 0.6665426), (1, 0.04707171), (2, 0.23405644), (3, 0.028452644), (4, 0.023876643)]
# [(0, 0.66654193), (1, 0.045997024), (2, 0.0351386), (3, 0.028453285), (4, 0.22386912)]
# [(0, 0.11094592), (1, 0.4099951), (2, 0.05856434), (3, 0.04737954), (4, 0.37311506)]
# [(0, 0.8332094), (1, 0.05749631), (2, 0.043923255), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.42567262), (1, 0.24599692), (2, 0.0351386), (3, 0.028427724), (4, 0.2647641)]
# [(0, 0.054490734), (1, 0.17570254), (2, 0.5965386), (3, 0.15619789), (4, 0.01707023)]
# [(0, 0.33636633), (1, 0.033051096), (2, 0.38905722), (3, 0.22447307), (4, 0.017052293)]
# [(0, 0.11126736), (1, 0.07666438), (2, 0.058564696), (3, 0.380311), (4, 0.37319255)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.06656948), (1, 0.24579868), (2, 0.035138905), (3, 0.42856374), (4, 0.22392917)]
# [(0, 0.066567525), (1, 0.045997027), (2, 0.0351386), (3, 0.028438171), (4, 0.82385874)]
# [(0, 0.4165546), (1, 0.15357465), (2, 0.39711407), (3, 0.017833274), (4, 0.0149234)]
# [(0, 0.5205785), (1, 0.05749628), (2, 0.043923248), (3, 0.3481527), (4, 0.029849267)]
# [(0, 0.29727897), (1, 0.03285524), (2, 0.1678982), (3, 0.19917433), (4, 0.30279323)]
# [(0, 0.33323535), (1, 0.05749708), (2, 0.29398337), (3, 0.035534695), (4, 0.27974954)]
# [(0, 0.11094592), (1, 0.07666174), (2, 0.058564346), (3, 0.047439817), (4, 0.70638824)]
# [(0, 0.5832012), (1, 0.05749643), (2, 0.2939313), (3, 0.035534665), (4, 0.02983641)]
# [(0, 0.21919978), (1, 0.17553383), (2, 0.16257335), (3, 0.017767351), (4, 0.4249257)]
# [(0, 0.045126375), (1, 0.15375075), (2, 0.021961635), (3, 0.21723893), (4, 0.5619224)]
# [(0, 0.60886306), (1, 0.21149197), (2, 0.021961637), (3, 0.14276516), (4, 0.014918205)]
# [(0, 0.14204836), (1, 0.07666171), (2, 0.05856433), (3, 0.68294376), (4, 0.039781876)]
# [(0, 0.53649694), (1, 0.10382611), (2, 0.1480299), (3, 0.011844904), (4, 0.19980216)]
# [(0, 0.3332092), (1, 0.057496283), (2, 0.043923248), (3, 0.03555941), (4, 0.52981186)]
# [(0, 0.4442965), (1, 0.076662265), (2, 0.058564454), (3, 0.38069487), (4, 0.03978188)]
# [(0, 0.06656757), (1, 0.04599706), (2, 0.43511337), (3, 0.028448757), (4, 0.42387325)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.33321023), (1, 0.05749631), (2, 0.043923255), (3, 0.5355245), (4, 0.029845705)]
# [(0, 0.83275366), (1, 0.057496283), (2, 0.04430978), (3, 0.035603844), (4, 0.029836407)]
# [(0, 0.503876), (1, 0.038330853), (2, 0.029282166), (3, 0.4086201), (4, 0.019890938)]
# [(0, 0.06667227), (1, 0.04599706), (2, 0.03513861), (3, 0.82832295), (4, 0.023869127)]
# [(0, 0.46653014), (1, 0.24599281), (2, 0.23514023), (3, 0.028427726), (4, 0.023909122)]
# [(0, 0.3888233), (1, 0.03833152), (2, 0.029282331), (3, 0.3570728), (4, 0.18649004)]
# [(0, 0.161711), (1, 0.12983045), (2, 0.017615989), (3, 0.57296455), (4, 0.11787798)]
# [(0, 0.6065999), (1, 0.032855038), (2, 0.025154399), (3, 0.16577137), (4, 0.16961923)]
# [(0, 0.3331041), (1, 0.057496287), (2, 0.04392325), (3, 0.035670105), (4, 0.5298063)]
# [(0, 0.44428053), (1, 0.07666175), (2, 0.39189628), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.05547436), (1, 0.038331505), (2, 0.18795058), (3, 0.6983526), (4, 0.019890938)]
# [(0, 0.24062653), (1, 0.26916078), (2, 0.014687928), (3, 0.011880543), (4, 0.46364427)]
# [(0, 0.08320942), (1, 0.057496294), (2, 0.04392325), (3, 0.035534654), (4, 0.77983636)]
# [(0, 0.90468043), (1, 0.03285511), (2, 0.025099019), (3, 0.0203142), (4, 0.017051226)]
# [(0, 0.59695995), (1, 0.014526695), (2, 0.010980836), (3, 0.21563813), (4, 0.16189437)]
# [(0, 0.6689884), (1, 0.22226056), (2, 0.012556597), (3, 0.010155613), (4, 0.086038806)]
# [(0, 0.4442794), (1, 0.07666171), (2, 0.39189744), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.24369764), (1, 0.5453523), (2, 0.10312163), (3, 0.09788037)]
# [(0, 0.11095827), (1, 0.07666666), (2, 0.7251761), (3, 0.047417045), (4, 0.03978188)]
# [(0, 0.33321524), (1, 0.3074818), (2, 0.043923296), (3, 0.035534665), (4, 0.279845)]
# [(0, 0.11094586), (1, 0.07666171), (2, 0.7252113), (3, 0.04737954), (4, 0.039801557)]
# [(0, 0.44447514), (1, 0.076665364), (2, 0.058564708), (3, 0.047379605), (4, 0.3729152)]
# [(0, 0.066567674), (1, 0.44600695), (2, 0.035138622), (3, 0.22841303), (4, 0.22387369)]
# [(0, 0.7764921), (1, 0.07666173), (2, 0.059684772), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.08608429), (1, 0.30749628), (2, 0.54100883), (3, 0.03554504), (4, 0.02986558)]
# [(0, 0.0832094), (1, 0.057496283), (2, 0.043923248), (3, 0.035534654), (4, 0.7798364)]
# [(0, 0.10208619), (1, 0.057496294), (2, 0.043923255), (3, 0.035534658), (4, 0.7609596)]
# [(0, 0.58322275), (1, 0.05749654), (2, 0.29390964), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.11095837), (1, 0.07666676), (2, 0.7252134), (3, 0.04737957), (4, 0.03978188)]
# [(0, 0.34635782), (1, 0.5427222), (2, 0.045548733), (3, 0.035534788), (4, 0.029836435)]
# [(0, 0.6416749), (1, 0.045997024), (2, 0.0351386), (3, 0.028427724), (4, 0.24876177)]
# [(0, 0.4442792), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.3731152)]
# [(0, 0.11094606), (1, 0.07666184), (2, 0.058564376), (3, 0.047379542), (4, 0.70644814)]
# [(0, 0.110978834), (1, 0.74329495), (2, 0.0585648), (3, 0.047379583), (4, 0.039781887)]
# [(0, 0.46652538), (1, 0.245997), (2, 0.0351386), (3, 0.028469842), (4, 0.2238692)]
# [(0, 0.5832094), (1, 0.057496298), (2, 0.29386392), (3, 0.035594), (4, 0.029836409)]
# [(0, 0.066567555), (1, 0.04732447), (2, 0.6338102), (3, 0.028427724), (4, 0.22387001)]
# [(0, 0.26408842), (1, 0.11670279), (2, 0.35849282), (3, 0.012941831), (4, 0.24777411)]
# [(0, 0.21961676), (1, 0.14666203), (2, 0.27374902), (4, 0.35107577)]
# [(0, 0.7756585), (1, 0.028748173), (2, 0.021961631), (3, 0.017767329), (4, 0.1558644)]
# [(0, 0.53212476), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.3309211)]
# [(0, 0.46647987), (1, 0.050752837), (2, 0.43046874), (3, 0.02842943), (4, 0.023869134)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.27196282), (1, 0.13666573), (2, 0.019521447), (3, 0.01579318), (4, 0.5560568)]
# [(0, 0.44427678), (1, 0.40999746), (2, 0.058564346), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.53564465), (1, 0.3186271), (2, 0.05856663), (3, 0.04737972), (4, 0.039781902)]
# [(0, 0.44428015), (1, 0.07666174), (2, 0.058564335), (3, 0.38071188), (4, 0.039781876)]
# [(0, 0.44428328), (1, 0.07666185), (2, 0.39189345), (3, 0.047379546), (4, 0.039781883)]
# [(0, 0.44426218), (1, 0.07666192), (2, 0.3919145), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.58321697), (1, 0.05749642), (2, 0.043923277), (3, 0.03553466), (4, 0.27982867)]
# [(0, 0.21668078), (1, 0.09455766), (2, 0.013562212), (3, 0.087872416), (4, 0.58732694)]
# [(0, 0.1066255), (1, 0.05749645), (2, 0.043923285), (3, 0.5121412), (4, 0.27981356)]
# [(0, 0.2665675), (1, 0.045997027), (2, 0.0351386), (3, 0.028427726), (4, 0.6238692)]
# [(0, 0.2970714), (1, 0.18939652), (2, 0.010334901), (3, 0.49617487)]
# [(0, 0.11094613), (1, 0.7433281), (2, 0.058564376), (3, 0.047379553), (4, 0.039781883)]
# [(0, 0.555506), (1, 0.20497914), (2, 0.029282304), (3, 0.19033276), (4, 0.019899806)]
# [(0, 0.38877273), (1, 0.20499532), (2, 0.029282168), (3, 0.023724085), (4, 0.3532257)]
# [(0, 0.7775619), (1, 0.07666171), (2, 0.058564324), (3, 0.04743017), (4, 0.039781872)]
# [(0, 0.11094587), (1, 0.4099954), (2, 0.39175782), (3, 0.047519054), (4, 0.039781876)]
# [(0, 0.11096486), (1, 0.07666248), (2, 0.39161098), (3, 0.3809797), (4, 0.03978199)]
# [(0, 0.38027406), (1, 0.32536015), (2, 0.19602565), (4, 0.08997903)]
# [(0, 0.047560554), (1, 0.03292971), (2, 0.36180457), (3, 0.39077684), (4, 0.16692828)]
# [(0, 0.11095809), (1, 0.40104768), (2, 0.058567464), (3, 0.38964486), (4, 0.03978189)]
# [(0, 0.066568), (1, 0.045997355), (2, 0.03513869), (3, 0.62850773), (4, 0.22378823)]
# [(0, 0.4442807), (1, 0.07666177), (2, 0.058564346), (3, 0.3807113), (4, 0.039781876)]
# [(0, 0.11094596), (1, 0.07666177), (2, 0.39189473), (3, 0.38071564), (4, 0.039781876)]
# [(0, 0.58964795), (1, 0.0307204), (2, 0.34692684), (3, 0.017786652), (4, 0.014918204)]
# [(0, 0.08321954), (1, 0.80748594), (2, 0.043923315), (3, 0.03553467), (4, 0.02983659)]
# [(0, 0.2711496), (1, 0.01643522), (2, 0.47191018), (3, 0.010203234), (4, 0.23030175)]
# [(0, 0.90439695), (1, 0.03313452), (2, 0.025099), (3, 0.020318303), (4, 0.017051226)]
# [(0, 0.11094589), (1, 0.40999606), (2, 0.058564335), (3, 0.38071182), (4, 0.039781876)]
# [(0, 0.44424972), (1, 0.409995), (2, 0.05856433), (3, 0.04737954), (4, 0.0398114)]
# [(0, 0.11094595), (1, 0.076661766), (2, 0.7252309), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.11324946), (1, 0.028748138), (2, 0.021961622), (3, 0.21863182), (4, 0.61740893)]
# [(0, 0.58315957), (1, 0.30749726), (2, 0.043923255), (3, 0.035583567), (4, 0.029836409)]
# [(0, 0.31078583), (1, 0.022998517), (2, 0.1849877), (3, 0.27813706), (4, 0.20309088)]
# [(0, 0.08320944), (1, 0.05749631), (2, 0.04392326), (3, 0.03555268), (4, 0.77981836)]
# [(0, 0.18454452), (1, 0.1268037), (2, 0.1493315), (4, 0.5318308)]
# [(0, 0.14210036), (1, 0.07666171), (2, 0.058564335), (3, 0.6828917), (4, 0.03978188)]
# [(0, 0.7757094), (1, 0.07666171), (2, 0.06036296), (3, 0.04748407), (4, 0.039781876)]
# [(0, 0.3363459), (1, 0.038330857), (2, 0.029282166), (3, 0.35702327), (4, 0.23901783)]
# [(0, 0.44429076), (1, 0.4099834), (2, 0.058564413), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.8147595), (1, 0.025553912), (2, 0.019521445), (3, 0.01579318), (4, 0.12437197)]
# [(0, 0.4227264), (1, 0.24599704), (2, 0.0351386), (3, 0.028471295), (4, 0.2676667)]
# [(0, 0.26657328), (1, 0.24603875), (2, 0.035138734), (3, 0.22845685), (4, 0.22379239)]
# [(0, 0.4441352), (1, 0.076661736), (2, 0.3918968), (3, 0.047524404), (4, 0.039781876)]
# [(0, 0.44426295), (1, 0.07666243), (2, 0.05856448), (3, 0.04737957), (4, 0.3731306)]
# [(0, 0.5038572), (1, 0.038330857), (2, 0.029282166), (3, 0.40863883), (4, 0.019890938)]
# [(0, 0.8331774), (1, 0.057496283), (2, 0.04392325), (3, 0.035566695), (4, 0.029836409)]
# [(0, 0.08607282), (1, 0.057496704), (2, 0.79104674), (3, 0.03554733), (4, 0.02983641)]
# [(0, 0.7775912), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039803185)]
# [(0, 0.7332824), (1, 0.02299853), (2, 0.21755698), (3, 0.014217844), (4, 0.011944268)]
# [(0, 0.06657404), (1, 0.045999903), (2, 0.5633376), (3, 0.30021936), (4, 0.023869134)]
# [(0, 0.1437601), (1, 0.13279365), (2, 0.050573505), (3, 0.2753855), (4, 0.39748725)]
# [(0, 0.11097449), (1, 0.07667323), (2, 0.058564816), (3, 0.047379598), (4, 0.70640785)]
# [(0, 0.19040798), (1, 0.1757187), (2, 0.025099024), (3, 0.44887042), (4, 0.15990387)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.38071296), (4, 0.37311515)]
# [(0, 0.26656753), (1, 0.2459969), (2, 0.0351386), (3, 0.028427724), (4, 0.42386928)]
# [(0, 0.33320975), (1, 0.057496313), (2, 0.29392192), (3, 0.28553566), (4, 0.029836409)]
# [(0, 0.33321664), (1, 0.057496496), (2, 0.0439233), (3, 0.28554583), (4, 0.27981776)]
# [(0, 0.7803331), (1, 0.028748147), (2, 0.022303272), (3, 0.01779031), (4, 0.1508252)]
# [(0, 0.11094593), (1, 0.07666176), (2, 0.39189947), (3, 0.04737954), (4, 0.37311327)]
# [(0, 0.0681297), (1, 0.04599902), (2, 0.035138756), (3, 0.5389912), (4, 0.31174132)]
# [(0, 0.0416047), (1, 0.2987475), (2, 0.14696123), (3, 0.017780876), (4, 0.49490565)]
# [(0, 0.3907977), (1, 0.032926846), (2, 0.025099179), (3, 0.24782835), (4, 0.3033479)]
# [(0, 0.2221056), (1, 0.039338212), (2, 0.30065182), (3, 0.1903484), (4, 0.24755597)]
# [(0, 0.16660497), (1, 0.27874804), (2, 0.022016201), (3, 0.14276697), (4, 0.38986385)]
# [(0, 0.2120605), (1, 0.20273556), (2, 0.015972104), (3, 0.012940723), (4, 0.5562911)]
# [(0, 0.8658168), (1, 0.04599703), (2, 0.035853144), (3, 0.028460715), (4, 0.023872342)]
# [(0, 0.03209943), (1, 0.111816786), (2, 0.016201843), (3, 0.49408704), (4, 0.34579492)]
# [(0, 0.77759874), (1, 0.07666171), (2, 0.058564335), (3, 0.047379542), (4, 0.039795656)]
# [(0, 0.66654235), (1, 0.045997027), (2, 0.0351386), (3, 0.028452903), (4, 0.22386909)]
# [(0, 0.05547295), (1, 0.20499797), (2, 0.02928217), (3, 0.023689771), (4, 0.6865571)]
# [(0, 0.5832097), (1, 0.307496), (2, 0.04392325), (3, 0.035534658), (4, 0.029836409)]
# [(0, 0.06656756), (1, 0.04599705), (2, 0.035138603), (3, 0.028427724), (4, 0.82386905)]
# [(0, 0.48959348), (1, 0.17993657), (2, 0.011712869), (3, 0.31079784)]
# [(0, 0.33320984), (1, 0.30749485), (2, 0.2939243), (3, 0.035534658), (4, 0.029836409)]
# [(0, 0.77758014), (1, 0.07666171), (2, 0.0585967), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.44427833), (1, 0.4099959), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.41654468), (1, 0.15374184), (2, 0.3970279), (3, 0.017767342), (4, 0.014918207)]
# [(0, 0.8332094), (1, 0.057496298), (2, 0.04392325), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.2665557), (1, 0.0459973), (2, 0.43517286), (3, 0.028427735), (4, 0.22384644)]
# [(0, 0.34063905), (1, 0.29781395), (2, 0.19330518), (3, 0.1549782), (4, 0.013263628)]
# [(0, 0.48648557), (1, 0.03144989), (2, 0.14696659), (3, 0.14277558), (4, 0.19232237)]
# [(0, 0.08320941), (1, 0.057496287), (2, 0.29392278), (3, 0.035534658), (4, 0.5298369)]
# [(0, 0.110946685), (1, 0.076662436), (2, 0.3919364), (3, 0.047379564), (4, 0.37307498)]
# [(0, 0.08320942), (1, 0.80749625), (2, 0.043923255), (3, 0.035534658), (4, 0.029836409)]
# [(0, 0.7775577), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039836716)]
# [(0, 0.41658962), (1, 0.15374562), (2, 0.021961626), (3, 0.017783104), (4, 0.38992006)]
# [(0, 0.20074248), (1, 0.12301215), (2, 0.46428505), (3, 0.014213872), (4, 0.19774649)]
# [(0, 0.44428864), (1, 0.076662086), (2, 0.058564406), (3, 0.380703), (4, 0.039781883)]
# [(0, 0.3977519), (1, 0.49295333), (2, 0.043923616), (3, 0.03553473), (4, 0.029836422)]
# [(0, 0.52025276), (1, 0.057496287), (2, 0.043923248), (3, 0.34849128), (4, 0.029836407)]
# [(0, 0.46656427), (1, 0.24599926), (2, 0.23513961), (3, 0.028427726), (4, 0.023869125)]
# [(0, 0.46652657), (1, 0.44599843), (2, 0.0351386), (3, 0.028467251), (4, 0.023869123)]
# [(0, 0.5831504), (1, 0.30749634), (2, 0.043923248), (3, 0.03558277), (4, 0.029847255)]
# [(0, 0.77754515), (1, 0.076661706), (2, 0.05856433), (3, 0.047446925), (4, 0.039781876)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05948319), (3, 0.04737954), (4, 0.7055297)]
# [(0, 0.110946395), (1, 0.07667575), (2, 0.0585644), (3, 0.047379557), (4, 0.7064339)]
# [(0, 0.04690285), (1, 0.028748177), (2, 0.021961633), (3, 0.48854405), (4, 0.4138433)]
# [(0, 0.047729477), (1, 0.1537138), (2, 0.021961642), (3, 0.2826647), (4, 0.49393046)]
# [(0, 0.08349982), (1, 0.058309242), (2, 0.044374544), (3, 0.3533763), (4, 0.4604401)]
# [(0, 0.5832252), (1, 0.057496626), (2, 0.043923322), (3, 0.28551847), (4, 0.02983641)]
# [(0, 0.44427657), (1, 0.076662235), (2, 0.05856445), (3, 0.047379564), (4, 0.37311718)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.043923248), (3, 0.28553462), (4, 0.5298365)]
# [(0, 0.34682837), (1, 0.038330853), (2, 0.029282166), (3, 0.23233432), (4, 0.3532243)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.46656758), (1, 0.045997027), (2, 0.4351386), (3, 0.028427724), (4, 0.023869125)]
# [(0, 0.4665893), (1, 0.045997407), (2, 0.03513869), (3, 0.22840841), (4, 0.22386615)]
# [(0, 0.8332094), (1, 0.05749629), (2, 0.04392325), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.4442799), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.37311447)]
# [(0, 0.4442794), (1, 0.07666171), (2, 0.39189744), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.55266917), (1, 0.17571306), (2, 0.23421764), (3, 0.020345392), (4, 0.01705475)]
# [(0, 0.58320475), (1, 0.05749637), (2, 0.043923266), (3, 0.2855392), (4, 0.029836407)]
# [(0, 0.5916285), (1, 0.34590068), (2, 0.025102051), (3, 0.020319415), (4, 0.017049383)]
# [(0, 0.25452515), (1, 0.087865286), (2, 0.15530662), (3, 0.29521063), (4, 0.20709227)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.110946365), (1, 0.41000846), (2, 0.05856441), (3, 0.38069892), (4, 0.039781883)]
# [(0, 0.5415938), (1, 0.1537444), (2, 0.27196386), (3, 0.017779794), (4, 0.014918205)]
# [(0, 0.05547295), (1, 0.038330864), (2, 0.02928217), (3, 0.85702306), (4, 0.01989094)]
# [(0, 0.110967666), (1, 0.07667038), (2, 0.058564708), (3, 0.71401536), (4, 0.03978188)]
# [(0, 0.5831897), (1, 0.05749668), (2, 0.29389316), (3, 0.035584074), (4, 0.02983641)]
# [(0, 0.7776125), (1, 0.07666174), (2, 0.05856434), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.24257365), (1, 0.100463696), (2, 0.26998064), (3, 0.1511362), (4, 0.23584582)]
# [(0, 0.41728613), (1, 0.2879995), (2, 0.25110433), (3, 0.023719108), (4, 0.019890945)]
# [(0, 0.68586326), (1, 0.025553916), (2, 0.019965846), (3, 0.25535196), (4, 0.013265031)]
# [(0, 0.3332349), (1, 0.032855015), (2, 0.025098996), (3, 0.020339482), (4, 0.5884716)]
# [(0, 0.6860865), (1, 0.01780356), (2, 0.108811855), (3, 0.17811511)]
# [(0, 0.36576062), (1, 0.122998774), (2, 0.017633175), (3, 0.014219406), (4, 0.47938806)]
# [(0, 0.049275383), (1, 0.03285535), (2, 0.6917424), (3, 0.20907745), (4, 0.017049376)]
# [(0, 0.16454539), (1, 0.24759966), (2, 0.2537318), (3, 0.015796773), (4, 0.31832644)]
# [(0, 0.44427934), (1, 0.076661706), (2, 0.058564324), (3, 0.38071272), (4, 0.039781872)]
# [(0, 0.3331078), (1, 0.057496402), (2, 0.04392328), (3, 0.03563992), (4, 0.52983266)]
# [(0, 0.8331775), (1, 0.05749628), (2, 0.043923248), (3, 0.035566542), (4, 0.029836407)]
# [(0, 0.3568793), (1, 0.23328207), (2, 0.20667517), (3, 0.18610972), (4, 0.017053757)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.11095894), (1, 0.076667), (2, 0.058564648), (3, 0.71402746), (4, 0.039781883)]
# [(0, 0.04754973), (1, 0.19015633), (2, 0.17856468), (3, 0.56667984), (4, 0.017049378)]
# [(0, 0.1109503), (1, 0.07666466), (2, 0.05856501), (3, 0.38092366), (4, 0.37289634)]
# [(0, 0.58320785), (1, 0.057496317), (2, 0.29392475), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.05547293), (1, 0.038330853), (2, 0.029282166), (3, 0.28493688), (4, 0.5919772)]
# [(0, 0.76265985), (1, 0.025555104), (2, 0.019625733), (3, 0.17889477), (4, 0.013264557)]
# [(0, 0.55216724), (1, 0.07666173), (2, 0.28394565), (3, 0.047443483), (4, 0.03978188)]
# [(0, 0.49664554), (1, 0.016626345), (2, 0.39255133), (3, 0.010154905), (4, 0.08402186)]
# [(0, 0.77757996), (1, 0.076693796), (2, 0.05856481), (3, 0.047379598), (4, 0.039781887)]
# [(0, 0.033288408), (1, 0.821904), (2, 0.017569719), (3, 0.014213933), (4, 0.11302392)]
# [(0, 0.11094611), (1, 0.4099847), (2, 0.39190146), (3, 0.047385804), (4, 0.039781876)]
# [(0, 0.26656777), (1, 0.6458599), (2, 0.035275523), (3, 0.028427726), (4, 0.023869127)]
# [(0, 0.11094659), (1, 0.4100142), (2, 0.39187777), (3, 0.04737956), (4, 0.039781883)]
# [(0, 0.43636346), (1, 0.13191615), (2, 0.19975427), (3, 0.010171498), (4, 0.22179465)]
# [(0, 0.0441982), (1, 0.12771264), (2, 0.5606948), (4, 0.26308578)]
# [(0, 0.44415513), (1, 0.0766619), (2, 0.39191055), (3, 0.04749052), (4, 0.03978188)]
# [(0, 0.11939222), (1, 0.07666269), (2, 0.058564518), (3, 0.3723069), (4, 0.37307367)]
# [(0, 0.7775422), (1, 0.07666171), (2, 0.05856433), (3, 0.04744986), (4, 0.039781876)]
# [(0, 0.56661564), (1, 0.025554033), (2, 0.01952147), (3, 0.015801173), (4, 0.3725077)]
# [(0, 0.11094587), (1, 0.4099956), (2, 0.39189708), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.12631725), (1, 0.07666709), (2, 0.7098052), (3, 0.047428608), (4, 0.039781883)]
# [(0, 0.8331775), (1, 0.057496287), (2, 0.043923248), (3, 0.035566542), (4, 0.029836407)]
# [(0, 0.44428003), (1, 0.076661736), (2, 0.39189684), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.3975342), (1, 0.028748192), (2, 0.27197084), (3, 0.1618263), (4, 0.13992047)]
# [(0, 0.08320953), (1, 0.5574949), (2, 0.043923266), (3, 0.2855359), (4, 0.029836407)]
# [(0, 0.4442794), (1, 0.07666171), (2, 0.05856433), (3, 0.38071266), (4, 0.039781876)]
# [(0, 0.32331726), (1, 0.24779415), (2, 0.019521467), (3, 0.39607236), (4, 0.013294773)]
# [(0, 0.03886398), (1, 0.13666475), (2, 0.019521443), (3, 0.6272876), (4, 0.17766221)]
# [(0, 0.14216548), (1, 0.07666171), (2, 0.05856433), (3, 0.6828266), (4, 0.039781876)]
# [(0, 0.45796505), (1, 0.07666688), (2, 0.05856492), (3, 0.36702117), (4, 0.039782003)]
# [(0, 0.055474367), (1, 0.465335), (2, 0.43559504), (3, 0.023704672), (4, 0.019890944)]
# [(0, 0.44427922), (1, 0.07666171), (2, 0.058564335), (3, 0.047379542), (4, 0.3731152)]
# [(0, 0.33319905), (1, 0.05749635), (2, 0.5439336), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.6665336), (1, 0.2460049), (2, 0.03513862), (3, 0.028453747), (4, 0.023869127)]
# [(0, 0.05547294), (1, 0.37166408), (2, 0.029282168), (3, 0.023689771), (4, 0.5198911)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.059487805), (3, 0.047379542), (4, 0.70552504)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.7798364)]
# [(0, 0.14215313), (1, 0.07666171), (2, 0.058564335), (3, 0.682839), (4, 0.03978188)]
# [(0, 0.015405378), (1, 0.086252466), (3, 0.20183839), (4, 0.6885041)]
# [(0, 0.6361681), (1, 0.04599703), (2, 0.0351386), (3, 0.25881237), (4, 0.02388389)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.37514025), (1, 0.028748699), (2, 0.021961687), (3, 0.017767338), (4, 0.556382)]
# [(0, 0.055472955), (1, 0.20499411), (2, 0.02928217), (3, 0.023689771), (4, 0.686561)]
# [(0, 0.3702888), (1, 0.24777052), (2, 0.019521449), (3, 0.01582145), (4, 0.34659782)]
# [(0, 0.11094629), (1, 0.07666201), (2, 0.39191413), (3, 0.38069567), (4, 0.03978188)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.8332094), (1, 0.057496283), (2, 0.043923248), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.5320051), (1, 0.057496287), (2, 0.043923248), (3, 0.035534654), (4, 0.33104077)]
# [(0, 0.33321065), (1, 0.05897236), (2, 0.29392445), (3, 0.035715587), (4, 0.27817696)]
# [(0, 0.11094593), (1, 0.07666175), (2, 0.05856434), (3, 0.38071522), (4, 0.37311277)]
# [(0, 0.3332061), (1, 0.057496306), (2, 0.04392325), (3, 0.03587402), (4, 0.52950037)]
# [(0, 0.08535544), (1, 0.24599664), (2, 0.0351386), (3, 0.4096399), (4, 0.2238694)]
# [(0, 0.33321092), (1, 0.05749633), (2, 0.5439217), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.08320942), (1, 0.057496294), (2, 0.04392325), (3, 0.7855347), (4, 0.029836407)]
# [(0, 0.33310428), (1, 0.30749625), (2, 0.043923248), (3, 0.03563977), (4, 0.27983645)]
# [(0, 0.53323394), (1, 0.42304102), (2, 0.017569328), (3, 0.014221214), (4, 0.011934565)]
# [(0, 0.2623114), (1, 0.025554381), (2, 0.019540582), (3, 0.015800858), (4, 0.6767928)]
# [(0, 0.04755011), (1, 0.20054694), (2, 0.025099095), (3, 0.37680137), (4, 0.3500025)]
# [(0, 0.28947255), (1, 0.0459973), (2, 0.6122333), (3, 0.028427735), (4, 0.023869129)]
# [(0, 0.036162574), (1, 0.02362913), (2, 0.21756932), (3, 0.2797432), (4, 0.4428958)]
# [(0, 0.4141956), (1, 0.05749629), (2, 0.04392325), (3, 0.035534654), (4, 0.4488502)]
# [(0, 0.8332027), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.029843092)]
# [(0, 0.33787477), (1, 0.038330983), (2, 0.029282195), (3, 0.27503663), (4, 0.31947538)]
# [(0, 0.13165578), (1, 0.4099951), (2, 0.058564335), (3, 0.047379542), (4, 0.35240525)]
# [(0, 0.46656832), (1, 0.045997113), (2, 0.2351288), (3, 0.22842152), (4, 0.023884194)]
# [(0, 0.46652693), (1, 0.045997106), (2, 0.03513862), (3, 0.42843607), (4, 0.023901304)]
# [(0, 0.33320302), (1, 0.032855038), (2, 0.025099004), (3, 0.02046316), (4, 0.58837974)]
# [(0, 0.066567525), (1, 0.045997027), (2, 0.0351386), (3, 0.61183506), (4, 0.2404618)]
# [(0, 0.58315796), (1, 0.30749705), (2, 0.043923255), (3, 0.03558538), (4, 0.029836409)]
# [(0, 0.047548227), (1, 0.032855015), (2, 0.025098998), (3, 0.44887695), (4, 0.4456208)]
# [(0, 0.24946533), (1, 0.105402276), (2, 0.17963018), (3, 0.45555678)]
# [(0, 0.44428053), (1, 0.07666186), (2, 0.39189616), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.032346442), (1, 0.101661846), (2, 0.4101545), (3, 0.22723138), (4, 0.22860582)]
# [(0, 0.51151556), (1, 0.04599992), (2, 0.39015335), (3, 0.028462028), (4, 0.023869133)]
# [(0, 0.888794), (1, 0.038330857), (2, 0.029282166), (3, 0.023702001), (4, 0.019890938)]
# [(0, 0.083209485), (1, 0.30748874), (2, 0.54393077), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.037882406), (1, 0.26350355), (2, 0.122417726), (3, 0.22854118), (4, 0.34765515)]
# [(0, 0.777539), (1, 0.076733656), (2, 0.05856578), (3, 0.047379646), (4, 0.0397819)]
# [(0, 0.11094593), (1, 0.40999863), (2, 0.05856434), (3, 0.04737954), (4, 0.37311158)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.08321205), (1, 0.8074935), (2, 0.043923367), (3, 0.035534676), (4, 0.029836413)]
# [(0, 0.7776068), (1, 0.07666441), (2, 0.058567148), (3, 0.047379613), (4, 0.03978205)]
# [(0, 0.25445932), (1, 0.022998773), (2, 0.14303663), (3, 0.21842328), (4, 0.36108196)]
# [(0, 0.110958435), (1, 0.07666703), (2, 0.72521305), (3, 0.04737958), (4, 0.039781883)]
# [(0, 0.42096278), (1, 0.13669837), (2, 0.019521493), (3, 0.18731959), (4, 0.23549779)]
# [(0, 0.43330914), (1, 0.22303776), (2, 0.1174867), (3, 0.11422346), (4, 0.111942984)]
# [(0, 0.38756266), (1, 0.022998588), (2, 0.15273169), (3, 0.01423541), (4, 0.42247167)]
# [(0, 0.77754253), (1, 0.07666183), (2, 0.058564354), (3, 0.047449376), (4, 0.039781876)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.8332023), (1, 0.057496287), (2, 0.04392325), (3, 0.035534658), (4, 0.029843515)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.05856433), (3, 0.7140462), (4, 0.039781872)]
# [(0, 0.6665658), (1, 0.045997243), (2, 0.2351145), (3, 0.028453285), (4, 0.023869127)]
# [(0, 0.35446894), (1, 0.4715403), (2, 0.14493011), (3, 0.015798133), (4, 0.013262501)]
# [(0, 0.11094594), (1, 0.40999746), (2, 0.05856434), (3, 0.04737954), (4, 0.37311268)]
# [(0, 0.21426643), (1, 0.37602776), (2, 0.016090408), (3, 0.012976285), (4, 0.3806391)]
# [(0, 0.77759856), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.039795842)]
# [(0, 0.05126002), (1, 0.032855023), (2, 0.31081286), (3, 0.5880227), (4, 0.017049376)]
# [(0, 0.7775573), (1, 0.076661706), (2, 0.058564324), (3, 0.047379535), (4, 0.039837092)]
# [(0, 0.44428322), (1, 0.07666184), (2, 0.3918935), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.3332094), (1, 0.30749628), (2, 0.04392325), (3, 0.2855347), (4, 0.029836409)]
# [(0, 0.26649666), (1, 0.045997947), (2, 0.23511855), (3, 0.22845554), (4, 0.22393131)]
# [(0, 0.17941546), (1, 0.017691208), (2, 0.01352251), (3, 0.010937563), (4, 0.77843326)]
# [(0, 0.066569746), (1, 0.6383454), (2, 0.035575528), (3, 0.028427746), (4, 0.23108162)]
# [(0, 0.7775472), (1, 0.07666177), (2, 0.058564346), (3, 0.047444817), (4, 0.039781876)]
# [(0, 0.32048792), (1, 0.029252805), (2, 0.022354674), (3, 0.017769828), (4, 0.6101348)]
# [(0, 0.42048544), (1, 0.029094923), (2, 0.35799155), (3, 0.017767383), (4, 0.1746607)]
# [(0, 0.083214775), (1, 0.8074907), (2, 0.043923434), (3, 0.035534684), (4, 0.029836413)]
# [(0, 0.060941532), (1, 0.03833088), (2, 0.02928217), (3, 0.19035755), (4, 0.6810879)]
# [(0, 0.15369086), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.6637035)]
# [(0, 0.44427907), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.37311533)]
# [(0, 0.030259715), (1, 0.3216247), (2, 0.015972199), (3, 0.4135426), (4, 0.21860076)]
# [(0, 0.41016114), (1, 0.02555395), (2, 0.31299755), (3, 0.015818479), (4, 0.23546892)]
# [(0, 0.33321014), (1, 0.30749685), (2, 0.293922), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.31077605), (1, 0.03833087), (2, 0.02928217), (3, 0.43505618), (4, 0.18655474)]
# [(0, 0.8331706), (1, 0.057496283), (2, 0.04392325), (3, 0.035566345), (4, 0.02984353)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.05856433), (3, 0.71404624), (4, 0.039781876)]
# [(0, 0.44427958), (1, 0.40999466), (2, 0.05856434), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.044620022), (1, 0.028748162), (2, 0.14695954), (3, 0.14276247), (4, 0.63690984)]
# [(0, 0.3729432), (1, 0.045997027), (2, 0.0351386), (3, 0.5219956), (4, 0.023925606)]
# [(0, 0.06657121), (1, 0.28146997), (2, 0.59966195), (3, 0.02842777), (4, 0.023869136)]
# [(0, 0.80707693), (1, 0.025554525), (2, 0.019535882), (3, 0.13457198), (4, 0.013260627)]
# [(0, 0.44427934), (1, 0.40999493), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.22215594), (1, 0.20493148), (2, 0.31413898), (3, 0.023689777), (4, 0.23508386)]
# [(0, 0.7765143), (1, 0.07666177), (2, 0.05954757), (3, 0.04749447), (4, 0.039781876)]
# [(0, 0.048956264), (1, 0.4605108), (2, 0.45317298), (3, 0.020305516), (4, 0.017054455)]
# [(0, 0.7775988), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039795686)]
# [(0, 0.30498287), (1, 0.24598089), (2, 0.39671844), (3, 0.028427726), (4, 0.02389003)]
# [(0, 0.06656756), (1, 0.046109498), (2, 0.035523128), (3, 0.5802662), (4, 0.27153358)]
# [(0, 0.083234325), (1, 0.05750054), (2, 0.5009773), (3, 0.035534758), (4, 0.32275307)]
# [(0, 0.032590017), (1, 0.11181624), (2, 0.015983889), (3, 0.012923391), (4, 0.8266865)]
# [(0, 0.19687684), (1, 0.06085631), (2, 0.39950916), (3, 0.17432591), (4, 0.16843179)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.17994863), (1, 0.16781479), (2, 0.30730975), (3, 0.01776973), (4, 0.32715708)]
# [(0, 0.7776119), (1, 0.076662235), (2, 0.058564454), (3, 0.047379564), (4, 0.03978188)]
# [(0, 0.030539697), (1, 0.2949359), (2, 0.17371339), (3, 0.012921697), (4, 0.48788932)]
# [(0, 0.33320597), (1, 0.3075074), (2, 0.04392328), (3, 0.285527), (4, 0.02983641)]
# [(0, 0.110946506), (1, 0.07666243), (2, 0.3919271), (3, 0.3806821), (4, 0.03978188)]
# [(0, 0.3143131), (1, 0.25434622), (2, 0.3789824), (3, 0.028471291), (4, 0.023886992)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.71403664), (4, 0.039791472)]
# [(0, 0.66654235), (1, 0.24599695), (2, 0.0351386), (3, 0.028452953), (4, 0.023869125)]
# [(0, 0.06656759), (1, 0.24600105), (2, 0.036097117), (3, 0.028427726), (4, 0.62290657)]
# [(0, 0.11094587), (1, 0.40996432), (2, 0.05856433), (3, 0.38071302), (4, 0.039812427)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.058564335), (3, 0.7140366), (4, 0.039791513)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.058564335), (3, 0.71404624), (4, 0.03978188)]
# [(0, 0.2732771), (1, 0.15423527), (2, 0.13885027), (3, 0.014213884), (4, 0.4194235)]
# [(0, 0.23287052), (1, 0.69421506), (2, 0.029333575), (3, 0.023689793), (4, 0.019891093)]
# [(0, 0.3332096), (1, 0.0574963), (2, 0.2939239), (3, 0.035534658), (4, 0.27983558)]
# [(0, 0.44428137), (1, 0.4099928), (2, 0.05856435), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.08449643), (1, 0.015356693), (2, 0.044643752), (3, 0.57576406), (4, 0.27973902)]
# [(0, 0.23723933), (1, 0.15375014), (2, 0.022403404), (3, 0.17421983), (4, 0.41238734)]
# [(0, 0.27717933), (1, 0.07828952), (2, 0.31653386), (3, 0.25534183), (4, 0.072655395)]
# [(0, 0.42588693), (1, 0.24599746), (2, 0.035407312), (3, 0.028427724), (4, 0.26428062)]
# [(0, 0.77753836), (1, 0.07673431), (2, 0.058565784), (3, 0.047379646), (4, 0.0397819)]
# [(0, 0.65635145), (1, 0.21533234), (2, 0.011712866), (4, 0.1071249)]
# [(0, 0.72211385), (1, 0.20499748), (2, 0.029282168), (3, 0.023689771), (4, 0.019916797)]
# [(0, 0.22852975), (1, 0.41084242), (2, 0.3170471), (3, 0.023689816), (4, 0.019890947)]
# [(0, 0.06688684), (1, 0.24599743), (2, 0.63479584), (3, 0.028450083), (4, 0.023869772)]
# [(0, 0.44428396), (1, 0.07666191), (2, 0.39189267), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.06656752), (1, 0.045997024), (2, 0.0351386), (3, 0.8284277), (4, 0.023869125)]
# [(0, 0.44429997), (1, 0.07666234), (2, 0.05856448), (3, 0.3806913), (4, 0.039781883)]
# [(0, 0.8332094), (1, 0.05749631), (2, 0.043923255), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.043923248), (3, 0.5355347), (4, 0.27983645)]
# [(0, 0.5832096), (1, 0.30749613), (2, 0.043923248), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.7221241), (1, 0.038330853), (2, 0.029282166), (3, 0.023705356), (4, 0.18655749)]
# [(0, 0.4442792), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.3731152)]
# [(0, 0.777589), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.03980538)]
# [(0, 0.0832094), (1, 0.057496283), (2, 0.043923248), (3, 0.7855347), (4, 0.029836407)]
# [(0, 0.44428006), (1, 0.076661736), (2, 0.39189675), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.09827866), (1, 0.057496317), (2, 0.043923255), (3, 0.7704654), (4, 0.029836407)]
# [(0, 0.06656755), (1, 0.24599417), (2, 0.2351393), (3, 0.028427724), (4, 0.42387122)]
# [(0, 0.19040522), (1, 0.03300401), (2, 0.18636201), (3, 0.57317066), (4, 0.017058088)]
# [(0, 0.16246533), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.6549291)]
# [(0, 0.33320946), (1, 0.057496317), (2, 0.043923255), (3, 0.28553653), (4, 0.27983442)]
# [(0, 0.7776122), (1, 0.07666194), (2, 0.05856439), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.33905762), (1, 0.057496306), (2, 0.04392325), (3, 0.5296864), (4, 0.029836403)]
# [(0, 0.2665614), (1, 0.24599817), (2, 0.035138607), (3, 0.42843276), (4, 0.023869125)]
# [(0, 0.44426835), (1, 0.07666228), (2, 0.39190793), (3, 0.047379572), (4, 0.039781883)]
# [(0, 0.44428325), (1, 0.4097179), (2, 0.05883746), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.7798365)]
# [(0, 0.06657191), (1, 0.046024982), (2, 0.622378), (3, 0.24115591), (4, 0.023869138)]
# [(0, 0.08060012), (1, 0.3468274), (2, 0.19600682), (3, 0.023853384), (4, 0.35271227)]
# [(0, 0.52019644), (1, 0.057496436), (2, 0.04392328), (3, 0.34854746), (4, 0.029836409)]
# [(0, 0.3331974), (1, 0.057496674), (2, 0.29391554), (3, 0.035534672), (4, 0.27985573)]
# [(0, 0.66659844), (1, 0.045997333), (2, 0.03513866), (3, 0.22839645), (4, 0.023869129)]
# [(0, 0.07603905), (1, 0.38571638), (2, 0.03513881), (3, 0.2676246), (4, 0.23548111)]
# [(0, 0.4441388), (1, 0.07666173), (2, 0.3918972), (3, 0.047520403), (4, 0.03978188)]
# [(0, 0.19241874), (1, 0.19740784), (2, 0.025099114), (3, 0.020314397), (4, 0.5647599)]
# [(0, 0.3332094), (1, 0.3074963), (2, 0.04392325), (3, 0.035534658), (4, 0.2798364)]
# [(0, 0.049738616), (1, 0.03285531), (2, 0.025099037), (3, 0.8752576), (4, 0.017049376)]
# [(0, 0.2876491), (1, 0.045997046), (2, 0.6140523), (3, 0.02843244), (4, 0.023869125)]
# [(0, 0.19040535), (1, 0.03285502), (2, 0.025099), (3, 0.020305518), (4, 0.73133516)]
# [(0, 0.4929956), (1, 0.15374908), (2, 0.1469591), (3, 0.19137084), (4, 0.014925434)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.39189756), (3, 0.04737954), (4, 0.3731153)]
# [(0, 0.38881567), (1, 0.038331117), (2, 0.19596682), (3, 0.1903181), (4, 0.18656828)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.71404624), (4, 0.039781876)]
# [(0, 0.44414124), (1, 0.409995), (2, 0.05856433), (3, 0.04751755), (4, 0.039781876)]
# [(0, 0.51939034), (1, 0.020908426), (2, 0.2299632), (3, 0.21888839), (4, 0.010849606)]
# [(0, 0.62606555), (1, 0.016809357), (2, 0.25918072), (3, 0.010155009), (4, 0.0877894)]
# [(0, 0.26656884), (1, 0.24600008), (2, 0.03513861), (3, 0.42841586), (4, 0.02387658)]
# [(0, 0.142414), (1, 0.07666172), (2, 0.058564335), (3, 0.6825781), (4, 0.03978188)]
# [(0, 0.23328471), (1, 0.022998532), (2, 0.21756384), (3, 0.17092565), (4, 0.3552273)]
# [(0, 0.5549029), (1, 0.20499778), (2, 0.029831069), (3, 0.023710556), (4, 0.18655765)]
# [(0, 0.11094594), (1, 0.4099988), (2, 0.39189386), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.48236084), (1, 0.028749714), (2, 0.02196177), (3, 0.017767351), (4, 0.44916034)]
# [(0, 0.066567525), (1, 0.24599612), (2, 0.0351386), (3, 0.22842781), (4, 0.42386994)]
# [(0, 0.083209395), (1, 0.057496283), (2, 0.043923248), (3, 0.035774343), (4, 0.77959675)]
# [(0, 0.7618267), (1, 0.032855038), (2, 0.025099004), (3, 0.020315988), (4, 0.15990324)]
# [(0, 0.33326977), (1, 0.12299831), (2, 0.0175693), (3, 0.014231737), (4, 0.5119309)]
# [(0, 0.34087083), (1, 0.25353074), (2, 0.014641169), (3, 0.38101003)]
# [(0, 0.44428173), (1, 0.40999246), (2, 0.05856435), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.8332094), (1, 0.057496306), (2, 0.043923255), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.52832925), (1, 0.04712708), (2, 0.37223133), (3, 0.028443256), (4, 0.023869125)]
# [(0, 0.7611044), (1, 0.033350687), (2, 0.025309702), (3, 0.020328123), (4, 0.1599071)]
# [(0, 0.44342017), (1, 0.40990034), (2, 0.05943623), (3, 0.047461376), (4, 0.039781887)]
# [(0, 0.77754456), (1, 0.07666171), (2, 0.058564335), (3, 0.047447532), (4, 0.03978188)]
# [(0, 0.11096984), (1, 0.74330384), (2, 0.058564812), (3, 0.047379617), (4, 0.03978189)]
# [(0, 0.41815102), (1, 0.028748868), (2, 0.31937668), (3, 0.017808737), (4, 0.21591471)]
# [(0, 0.44413772), (1, 0.40999404), (2, 0.058564335), (3, 0.04752201), (4, 0.039781876)]
# [(0, 0.21132754), (1, 0.01642758), (2, 0.012749914), (3, 0.21813709), (4, 0.5413579)]
# [(0, 0.8330191), (1, 0.057496283), (2, 0.044069305), (3, 0.03557376), (4, 0.029841568)]
# [(0, 0.5832097), (1, 0.05749629), (2, 0.29392296), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.44428635), (1, 0.07666198), (2, 0.058564395), (3, 0.04737955), (4, 0.37310773)]
# [(0, 0.4617596), (1, 0.09470479), (2, 0.013783233), (3, 0.34376076), (4, 0.08599159)]
# [(0, 0.46630922), (1, 0.045997027), (2, 0.03537371), (3, 0.028450718), (4, 0.4238693)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.71404624), (4, 0.039781876)]
# [(0, 0.4012271), (1, 0.020010253), (2, 0.014891942), (3, 0.30477166), (4, 0.2590991)]
# [(0, 0.6665682), (1, 0.04599704), (2, 0.2351379), (3, 0.028427724), (4, 0.023869125)]
# [(0, 0.08608009), (1, 0.3074871), (2, 0.5410374), (3, 0.035545044), (4, 0.02985039)]
# [(0, 0.34689146), (1, 0.20499836), (2, 0.029282166), (3, 0.23226978), (4, 0.18655822)]
# [(0, 0.77754545), (1, 0.07666172), (2, 0.058564335), (3, 0.047446642), (4, 0.039781876)]
# [(0, 0.08320957), (1, 0.3074965), (2, 0.29391852), (3, 0.035534658), (4, 0.27984077)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.1480915), (1, 0.025553921), (2, 0.26323062), (3, 0.13298199), (4, 0.430142)]
# [(0, 0.4442877), (1, 0.4099865), (2, 0.058564395), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.44427922), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.37311515)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.33320954), (1, 0.057496287), (2, 0.044600245), (3, 0.035534654), (4, 0.52915925)]
# [(0, 0.4079682), (1, 0.24599974), (2, 0.2937241), (3, 0.028433567), (4, 0.023874436)]
# [(0, 0.16240388), (1, 0.13659675), (2, 0.019605568), (3, 0.015838662), (4, 0.6655551)]
# [(0, 0.09014702), (1, 0.057496414), (2, 0.04392328), (3, 0.28553614), (4, 0.5228972)]
# [(0, 0.06657076), (1, 0.84599364), (2, 0.03513875), (3, 0.02842775), (4, 0.02386913)]
# [(0, 0.4761141), (1, 0.032855053), (2, 0.1679581), (3, 0.020305518), (4, 0.30276725)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.42563283), (1, 0.013528671), (2, 0.0994085), (3, 0.39567617), (4, 0.06575378)]
# [(0, 0.83317745), (1, 0.057496287), (2, 0.043923248), (3, 0.03556663), (4, 0.029836407)]
# [(0, 0.775151), (1, 0.028748142), (2, 0.021961624), (3, 0.017767327), (4, 0.15637195)]
# [(0, 0.033283763), (1, 0.023271518), (2, 0.017616736), (3, 0.014213862), (4, 0.9116141)]
# [(0, 0.2665675), (1, 0.045997024), (2, 0.0351386), (3, 0.4003411), (4, 0.2519558)]
# [(0, 0.57528114), (1, 0.14230974), (2, 0.01490793), (3, 0.01184948), (4, 0.25565168)]
# [(0, 0.77755904), (1, 0.07666171), (2, 0.058564335), (3, 0.047379542), (4, 0.03983541)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.8332094), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.72213495), (1, 0.20499724), (2, 0.029282168), (3, 0.023689771), (4, 0.019895859)]
# [(0, 0.085694395), (1, 0.20714293), (2, 0.3859414), (3, 0.12475096), (4, 0.19647032)]
# [(0, 0.110948704), (1, 0.41031042), (2, 0.058564764), (3, 0.047379628), (4, 0.37279645)]
# [(0, 0.24444284), (1, 0.038330942), (2, 0.5023576), (3, 0.19495483), (4, 0.019913822)]
# [(0, 0.777534), (1, 0.076661706), (2, 0.05856433), (3, 0.047443587), (4, 0.03979634)]
# [(0, 0.28397623), (1, 0.24877045), (2, 0.15353604), (3, 0.30044684), (4, 0.013270471)]
# [(0, 0.110946596), (1, 0.41004422), (2, 0.05856444), (3, 0.38066283), (4, 0.03978188)]
# [(0, 0.83238673), (1, 0.057496287), (2, 0.04472664), (3, 0.03555391), (4, 0.029836407)]
# [(0, 0.44427708), (1, 0.076661736), (2, 0.058564335), (3, 0.38068974), (4, 0.039807096)]
# [(0, 0.4327857), (1, 0.45783776), (2, 0.043923568), (3, 0.035605587), (4, 0.029847408)]
# [(0, 0.08384774), (1, 0.30749476), (2, 0.54328513), (3, 0.035534654), (4, 0.029837687)]
# [(0, 0.33319873), (1, 0.057496376), (2, 0.04392327), (3, 0.035534658), (4, 0.52984697)]
# [(0, 0.4442813), (1, 0.07666178), (2, 0.39189553), (3, 0.047379546), (4, 0.03978188)]
# [(0, 0.16246814), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.65492624)]
# [(0, 0.4442842), (1, 0.40998998), (2, 0.05856437), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.19441016), (1, 0.10246885), (2, 0.43136036), (3, 0.17848755), (4, 0.093273066)]
# [(0, 0.083209395), (1, 0.3074696), (2, 0.043923244), (3, 0.53552675), (4, 0.029870974)]
# [(0, 0.11094587), (1, 0.40999505), (2, 0.05856433), (3, 0.04737954), (4, 0.37311527)]
# [(0, 0.07186632), (1, 0.045997027), (2, 0.0351386), (3, 0.8231289), (4, 0.023869125)]
# [(0, 0.77753854), (1, 0.07673414), (2, 0.05856578), (3, 0.047379646), (4, 0.0397819)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# ...
# [(0, 0.7775457), (1, 0.07666171), (2, 0.058564335), (3, 0.04744643), (4, 0.03978188)]
# [(0, 0.11094589), (1, 0.07666173), (2, 0.05856433), (3, 0.7140462), (4, 0.039781872)]
# [(0, 0.39293373), (1, 0.013528783), (2, 0.22297935), (3, 0.23799032), (4, 0.13256788)]
# [(0, 0.21199735), (1, 0.211499), (3, 0.18691982), (4, 0.3807794)]
# [(0, 0.11094599), (1, 0.07666178), (2, 0.058564354), (3, 0.047379542), (4, 0.7064483)]
# [(0, 0.33321202), (1, 0.5574937), (2, 0.04392327), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.12367102), (1, 0.17577419), (2, 0.1679597), (3, 0.30595773), (4, 0.2266374)]
# [(0, 0.8332027), (1, 0.057496283), (2, 0.04392325), (3, 0.035534658), (4, 0.029843101)]
# [(0, 0.1109459), (1, 0.40999672), (2, 0.058564335), (3, 0.38071117), (4, 0.039781876)]
# [(0, 0.11095965), (1, 0.7433143), (2, 0.058564577), (3, 0.047379572), (4, 0.039781883)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.33320946), (1, 0.057496287), (2, 0.2939232), (3, 0.035534658), (4, 0.27983642)]
# [(0, 0.11097529), (1, 0.076673366), (2, 0.05856469), (3, 0.7140048), (4, 0.039781883)]
# [(0, 0.2916025), (1, 0.028748145), (2, 0.021961626), (3, 0.3694968), (4, 0.28819096)]
# [(0, 0.0832094), (1, 0.057496283), (2, 0.044860445), (3, 0.7845975), (4, 0.029836407)]
# [(0, 0.4442787), (1, 0.07666171), (2, 0.058564335), (3, 0.38071337), (4, 0.039781876)]
# [(0, 0.66654146), (1, 0.045997027), (2, 0.0351386), (3, 0.028453913), (4, 0.223869)]
# [(0, 0.06657033), (1, 0.2778861), (2, 0.60324675), (3, 0.028427739), (4, 0.023869127)]
# [(0, 0.7775484), (1, 0.07666171), (2, 0.058564335), (3, 0.047443703), (4, 0.03978188)]
# [(0, 0.07087155), (1, 0.045997046), (2, 0.03536535), (3, 0.028444583), (4, 0.81932145)]
# [(0, 0.33310577), (1, 0.057496306), (2, 0.043923255), (3, 0.035638962), (4, 0.52983576)]
# [(0, 0.036982816), (1, 0.2855965), (2, 0.13515481), (3, 0.015793193), (4, 0.52647275)]
# [(0, 0.08320953), (1, 0.5575098), (2, 0.04392327), (3, 0.035534658), (4, 0.2798228)]
# [(0, 0.6835109), (1, 0.20719458), (2, 0.043923452), (3, 0.03553469), (4, 0.029836414)]
# [(0, 0.44425145), (1, 0.07666181), (2, 0.39189443), (3, 0.047379542), (4, 0.03981273)]
# [(0, 0.20819809), (1, 0.07498493), (2, 0.36666656), (3, 0.042018957), (4, 0.30813152)]
# [(0, 0.3332954), (1, 0.31874636), (2, 0.16772339), (3, 0.16318546), (4, 0.017049378)]
# [(0, 0.022342987), (1, 0.48019022), (2, 0.31101245), (4, 0.17757066)]
# [(0, 0.4442792), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.3731152)]
# [(0, 0.5011833), (1, 0.08200783), (2, 0.14169686), (4, 0.26560557)]
# [(0, 0.7618321), (1, 0.032855023), (2, 0.025098998), (3, 0.16316226), (4, 0.017051611)]
# [(0, 0.19262221), (1, 0.02299855), (2, 0.12519082), (3, 0.64725006), (4, 0.01193837)]
# [(0, 0.7038231), (1, 0.038330853), (2, 0.029282166), (3, 0.20867293), (4, 0.019890938)]
# [(0, 0.30597845), (1, 0.06798289), (2, 0.14752015), (3, 0.06731628), (4, 0.4112022)]
# [(0, 0.5553978), (1, 0.37173924), (2, 0.029282248), (3, 0.023689779), (4, 0.01989094)]
# [(0, 0.44422162), (1, 0.076662354), (2, 0.39195457), (3, 0.047379572), (4, 0.039781883)]
# [(0, 0.33320978), (1, 0.057496298), (2, 0.043923255), (3, 0.5355343), (4, 0.029836409)]
# [(0, 0.27422088), (1, 0.019732626), (2, 0.23932151), (3, 0.26185313), (4, 0.20487188)]
# [(0, 0.777544), (1, 0.076661706), (2, 0.05856433), (3, 0.047448073), (4, 0.039781876)]
# [(0, 0.11094595), (1, 0.74332833), (2, 0.058564346), (3, 0.047379546), (4, 0.03978188)]
# [(0, 0.5329482), (1, 0.20500177), (2, 0.029684119), (3, 0.02370917), (4, 0.20865673)]
# [(0, 0.2664823), (1, 0.045997024), (2, 0.0351386), (3, 0.028528128), (4, 0.62385404)]
# [(0, 0.77754503), (1, 0.07666228), (2, 0.058564443), (3, 0.047446344), (4, 0.039781883)]
# [(0, 0.5553845), (1, 0.20499909), (2, 0.19594349), (3, 0.023770051), (4, 0.019902825)]
# [(0, 0.44435355), (1, 0.076662436), (2, 0.39182255), (3, 0.047379572), (4, 0.039781883)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.41053006), (1, 0.038634595), (2, 0.5072333), (3, 0.023711102), (4, 0.019890938)]
# [(0, 0.8331885), (1, 0.057496287), (2, 0.04393873), (3, 0.035534654), (4, 0.029841835)]
# [(0, 0.07078595), (1, 0.19806823), (3, 0.2733224), (4, 0.45014364)]
# [(0, 0.11094588), (1, 0.07666172), (2, 0.058564335), (3, 0.7140365), (4, 0.039791524)]
# [(0, 0.0832094), (1, 0.057496283), (2, 0.04392325), (3, 0.7855347), (4, 0.029836409)]
# [(0, 0.618976), (1, 0.17569937), (2, 0.025099), (3, 0.16316317), (4, 0.017062457)]
# [(0, 0.08320946), (1, 0.05805091), (2, 0.4760779), (3, 0.035534658), (4, 0.34712705)]
# [(0, 0.223426), (1, 0.23839897), (2, 0.029455481), (3, 0.48882863), (4, 0.01989094)]
# [(0, 0.11094656), (1, 0.74332756), (2, 0.05856444), (3, 0.047379546), (4, 0.039781876)]
# [(0, 0.2914801), (1, 0.028748395), (2, 0.14697804), (3, 0.017767338), (4, 0.5150262)]
# [(0, 0.32162532), (1, 0.40525246), (2, 0.13638827), (4, 0.1283728)]
# [(0, 0.7618292), (1, 0.17571199), (2, 0.025099), (3, 0.020305518), (4, 0.017054277)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.33316502), (1, 0.057496842), (2, 0.543967), (3, 0.035534766), (4, 0.029836414)]
# [(0, 0.08595174), (1, 0.5547538), (2, 0.04392325), (3, 0.035534654), (4, 0.2798366)]
# [(0, 0.44422746), (1, 0.07666243), (2, 0.3919486), (3, 0.047379572), (4, 0.039781883)]
# [(0, 0.5862479), (1, 0.08029209), (2, 0.24629855), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.69582254), (1, 0.15366353), (2, 0.018059615), (3, 0.12051741), (4, 0.01193689)]
# [(0, 0.44397607), (1, 0.41029775), (2, 0.05856468), (3, 0.047379598), (4, 0.039781887)]
# [(0, 0.11094651), (1, 0.07666215), (2, 0.05856443), (3, 0.38073885), (4, 0.3730881)]
# [(0, 0.8331471), (1, 0.057536498), (2, 0.04392334), (3, 0.03554375), (4, 0.029849324)]
# [(0, 0.3471136), (1, 0.20692204), (2, 0.122855045), (3, 0.020340782), (4, 0.3027685)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.083209395), (1, 0.05749628), (2, 0.043923248), (3, 0.7855347), (4, 0.029836407)]
# [(0, 0.58318186), (1, 0.05749691), (2, 0.043923363), (3, 0.035534676), (4, 0.27986318)]
# [(0, 0.06656752), (1, 0.045997024), (2, 0.0351386), (3, 0.028427724), (4, 0.8238691)]
# [(0, 0.46496245), (1, 0.09695036), (3, 0.28665218), (4, 0.14377765)]
# [(0, 0.5333608), (1, 0.038330864), (2, 0.19590771), (3, 0.023753583), (4, 0.20864709)]
# [(0, 0.25091147), (1, 0.118321344), (2, 0.015972126), (3, 0.35299838), (4, 0.26179674)]
# [(0, 0.41662073), (1, 0.15376101), (2, 0.021961655), (3, 0.16118158), (4, 0.24647497)]
# [(0, 0.44427943), (1, 0.07666171), (2, 0.3918974), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.7776122), (1, 0.076662), (2, 0.058564395), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.21817246), (1, 0.18842186), (2, 0.37705055), (3, 0.011844888), (4, 0.20451027)]
# [(0, 0.5493863), (1, 0.038331017), (2, 0.19595735), (3, 0.023689777), (4, 0.19263558)]
# [(0, 0.043885652), (1, 0.16607277), (2, 0.022241117), (3, 0.22728777), (4, 0.54051274)]
# [(0, 0.6957437), (1, 0.13669929), (2, 0.019521467), (3, 0.13477498), (4, 0.013260626)]
# [(0, 0.083209395), (1, 0.057496283), (2, 0.043923248), (3, 0.035534654), (4, 0.7798365)]
# [(0, 0.333204), (1, 0.057496347), (2, 0.043923266), (3, 0.03553466), (4, 0.5298418)]
# [(0, 0.05547307), (1, 0.20500465), (2, 0.029483706), (3, 0.023705909), (4, 0.68633264)]
# [(0, 0.33323342), (1, 0.032855023), (2, 0.16795512), (3, 0.020334411), (4, 0.44562203)]
# [(0, 0.05082458), (1, 0.032855023), (2, 0.025598824), (3, 0.8736697), (4, 0.017051863)]
# [(0, 0.21577759), (1, 0.33479014), (2, 0.12087888), (3, 0.32191512)]
# [(0, 0.7775431), (1, 0.07666171), (2, 0.058564335), (3, 0.04744894), (4, 0.03978188)]
# [(0, 0.9046824), (1, 0.032855038), (2, 0.025099002), (3, 0.020314202), (4, 0.017049374)]
# [(0, 0.7913044), (1, 0.16894741), (2, 0.015973287), (3, 0.012921698), (4, 0.010853242)]
# [(0, 0.8332094), (1, 0.05749631), (2, 0.043923255), (3, 0.035534658), (4, 0.029836409)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.58237535), (1, 0.30962372), (2, 0.014641185), (3, 0.08341428)]
# [(0, 0.44427934), (1, 0.40999493), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.46577483), (1, 0.44599304), (2, 0.03590113), (3, 0.028461907), (4, 0.023869125)]
# [(0, 0.77754486), (1, 0.07666173), (2, 0.05856434), (3, 0.047447182), (4, 0.03978188)]
# [(0, 0.08320951), (1, 0.057496358), (2, 0.54391813), (3, 0.035534658), (4, 0.27984133)]
# [(0, 0.11094589), (1, 0.07666173), (2, 0.391898), (3, 0.3807125), (4, 0.039781876)]
# [(0, 0.3332095), (1, 0.057496287), (2, 0.044607032), (3, 0.035534654), (4, 0.5291525)]
# [(0, 0.44427922), (1, 0.40999505), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.41630682), (1, 0.028748315), (2, 0.021961667), (3, 0.5180634), (4, 0.014919773)]
# [(0, 0.8332094), (1, 0.057496294), (2, 0.04392325), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.115827695), (1, 0.3443535), (4, 0.5245859)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.066567734), (1, 0.44600415), (2, 0.4351196), (3, 0.028427726), (4, 0.02388077)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.058564335), (3, 0.71404624), (4, 0.03978188)]
# [(0, 0.17242612), (1, 0.028748203), (2, 0.021961639), (3, 0.01776733), (4, 0.7590967)]
# [(0, 0.26428697), (1, 0.03833107), (2, 0.29723912), (3, 0.38024387), (4, 0.019899001)]
# [(0, 0.06656752), (1, 0.2459969), (2, 0.035463702), (3, 0.028442133), (4, 0.62352973)]
# [(0, 0.19317545), (1, 0.27873975), (2, 0.021961631), (3, 0.1871166), (4, 0.31900656)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.05856433), (3, 0.047399882), (4, 0.70642823)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.095293626), (1, 0.057496283), (2, 0.043923248), (3, 0.035534654), (4, 0.76775223)]
# [(0, 0.11094587), (1, 0.07666171), (2, 0.05856433), (3, 0.71404624), (4, 0.039781876)]
# [(0, 0.7775462), (1, 0.076661706), (2, 0.05856433), (3, 0.047445834), (4, 0.039781876)]
# [(0, 0.58320946), (1, 0.30749622), (2, 0.043923248), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.7776122), (1, 0.076661974), (2, 0.05856439), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.46656305), (1, 0.04599707), (2, 0.23514168), (3, 0.22842908), (4, 0.023869125)]
# [(0, 0.88879126), (1, 0.038330857), (2, 0.029282166), (3, 0.023702031), (4, 0.019893708)]
# [(0, 0.1109463), (1, 0.40998432), (2, 0.39190796), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05949952), (3, 0.04737954), (4, 0.7055134)]
# [(0, 0.63996977), (1, 0.045997024), (2, 0.0351386), (3, 0.02845388), (4, 0.2504407)]
# [(0, 0.44427928), (1, 0.07666171), (2, 0.05856433), (3, 0.38071284), (4, 0.039781876)]
# [(0, 0.1109899), (1, 0.07667956), (2, 0.05856483), (3, 0.047379583), (4, 0.70638615)]
# [(0, 0.16874212), (1, 0.50153553), (2, 0.16575706), (3, 0.017767336), (4, 0.14619799)]
# [(0, 0.44413415), (1, 0.07666171), (2, 0.05856433), (3, 0.04752459), (4, 0.37311518)]
# [(0, 0.29328886), (1, 0.65206397), (2, 0.02196165), (3, 0.017767332), (4, 0.014918204)]
# [(0, 0.06773342), (1, 0.045997053), (2, 0.63398254), (3, 0.028427726), (4, 0.22385928)]
# [(0, 0.44421086), (1, 0.07666172), (2, 0.058632683), (3, 0.38071287), (4, 0.039781876)]
# [(0, 0.6189502), (1, 0.3185959), (2, 0.025099028), (3, 0.020305524), (4, 0.017049376)]
# [(0, 0.1108642), (1, 0.76919), (2, 0.014838078), (3, 0.011844885), (4, 0.09326285)]
# [(0, 0.06216593), (1, 0.038676936), (2, 0.36227247), (3, 0.5169911), (4, 0.019893594)]
# [(0, 0.22439645), (1, 0.5201638), (2, 0.211859), (3, 0.023689797), (4, 0.019890944)]
# [(0, 0.08320943), (1, 0.057496306), (2, 0.29392004), (3, 0.53553784), (4, 0.029836407)]
# [(0, 0.07608087), (1, 0.24599683), (2, 0.0351386), (3, 0.028427724), (4, 0.614356)]
# [(0, 0.7775433), (1, 0.07666171), (2, 0.058564335), (3, 0.04744876), (4, 0.03978188)]
# [(0, 0.52033526), (1, 0.057496317), (2, 0.04392326), (3, 0.34840882), (4, 0.029836409)]
# [(0, 0.4442501), (1, 0.40999514), (2, 0.058564335), (3, 0.047379542), (4, 0.03981089)]
# [(0, 0.3264612), (1, 0.13930646), (2, 0.010354292), (3, 0.17570591), (4, 0.34817213)]
# [(0, 0.26655772), (1, 0.04599709), (2, 0.4351479), (3, 0.028427724), (4, 0.22386955)]
# [(0, 0.06973664), (1, 0.04726302), (2, 0.3903166), (3, 0.26884997), (4, 0.22383375)]
# [(0, 0.7776125), (1, 0.07666172), (2, 0.058564335), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.4460106), (1, 0.1757058), (2, 0.025167417), (3, 0.02030828), (4, 0.33280787)]
# [(0, 0.083209395), (1, 0.30749616), (2, 0.043923248), (3, 0.035534654), (4, 0.52983654)]
# [(0, 0.86654484), (1, 0.04599703), (2, 0.0351386), (3, 0.02844643), (4, 0.023873124)]
# [(0, 0.05653767), (1, 0.038330857), (2, 0.50699866), (3, 0.3782419), (4, 0.019890938)]
# [(0, 0.27891344), (1, 0.13588828), (2, 0.10686905), (3, 0.4674654), (4, 0.010863845)]
# [(0, 0.372991), (1, 0.045997187), (2, 0.035138637), (3, 0.52200407), (4, 0.023869133)]
# [(0, 0.057250377), (1, 0.15490119), (2, 0.3386401), (3, 0.42929474), (4, 0.019913582)]
# [(0, 0.16266972), (1, 0.05749643), (2, 0.04444617), (3, 0.31144404), (4, 0.42394367)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.4404147), (1, 0.24205314), (2, 0.2739514), (3, 0.023689773), (4, 0.019890938)]
# [(0, 0.11094615), (1, 0.409984), (2, 0.39190844), (3, 0.04737955), (4, 0.03978188)]
# [(0, 0.11095954), (1, 0.74331445), (2, 0.058564547), (3, 0.04737957), (4, 0.039781895)]
# [(0, 0.7776125), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.25333866), (1, 0.032855026), (2, 0.16795641), (3, 0.020314004), (4, 0.5255359)]
# [(0, 0.7776125), (1, 0.07666171), (2, 0.05856433), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.44427922), (1, 0.07666171), (2, 0.058564335), (3, 0.38071287), (4, 0.03978188)]
# [(0, 0.08320941), (1, 0.057496287), (2, 0.04392325), (3, 0.7855347), (4, 0.029836409)]
# [(0, 0.4442793), (1, 0.07666171), (2, 0.3918976), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.4442816), (1, 0.07666178), (2, 0.058564346), (3, 0.047379542), (4, 0.37311268)]
# [(0, 0.64167947), (1, 0.045997027), (2, 0.0351386), (3, 0.028427724), (4, 0.24875721)]
# [(0, 0.8332023), (1, 0.05749628), (2, 0.043923248), (3, 0.035534654), (4, 0.029843492)]
# [(0, 0.110946), (1, 0.076661795), (2, 0.058564354), (3, 0.714046), (4, 0.03978188)]
# [(0, 0.3331041), (1, 0.0574963), (2, 0.043923255), (3, 0.035640556), (4, 0.5298358)]
# [(0, 0.010418953), (1, 0.5148014), (2, 0.22423363), (3, 0.18322067), (4, 0.06732541)]
# [(0, 0.18146147), (1, 0.49194467), (2, 0.30646655), (3, 0.010946846)]
# [(0, 0.48521414), (1, 0.14932823), (2, 0.06458329), (3, 0.24999715), (4, 0.05087717)]
# [(0, 0.76150423), (1, 0.1760257), (2, 0.025099052), (3, 0.020315966), (4, 0.017055018)]
# [(0, 0.44427586), (1, 0.40999842), (2, 0.05856434), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.27392635), (1, 0.18408352), (2, 0.057879206), (3, 0.30868885), (4, 0.17542203)]
# [(0, 0.6848371), (1, 0.03833462), (2, 0.030065164), (3, 0.023738677), (4, 0.22302444)]
# [(0, 0.11094618), (1, 0.40998688), (2, 0.058564376), (3, 0.04737955), (4, 0.37312296)]
# [(0, 0.11094586), (1, 0.076661706), (2, 0.05856433), (3, 0.04737954), (4, 0.70644855)]
# [(0, 0.11094588), (1, 0.07666171), (2, 0.725231), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.08321965), (1, 0.5241138), (2, 0.04392341), (3, 0.035534672), (4, 0.31320852)]
# [(0, 0.6881415), (1, 0.025558969), (2, 0.13627945), (3, 0.015793348), (4, 0.13422668)]
# [(0, 0.14765778), (1, 0.17696285), (2, 0.19054627), (3, 0.1610291), (4, 0.32380402)]
# [(0, 0.3583357), (1, 0.022998536), (2, 0.13420881), (3, 0.22652182), (4, 0.25793514)]
# [(0, 0.2110189), (1, 0.17571701), (2, 0.41885898), (3, 0.020320794), (4, 0.17408434)]
# [(0, 0.043947585), (1, 0.028748559), (2, 0.13249882), (3, 0.6527823), (4, 0.14202276)]
# [(0, 0.33310524), (1, 0.057496283), (2, 0.04392325), (3, 0.035638813), (4, 0.5298365)]
# [(0, 0.58316135), (1, 0.057496287), (2, 0.29389012), (3, 0.03558263), (4, 0.029869666)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#         Document_No  ...                                               Text
# 0                 0  ...                                [iklan, ganggu, as]
# 1                 1  ...                       [tolong, erti, pesan, pesan]
# 2                 2  ...                       [iklan, trossssssss, ganggu]
# 3                 3  ...  [ruwet, metode, bayar, indomart, mlh, cod, apl...
# 4                 4  ...  [dih, dwon, aplikasi, tipu, order, giveaway, h...
# ...             ...  ...                                                ...
# 767120       767120  ...  [belanja, shoppe, bantu, temu, barang, dng, ce...
# 767121       767121  ...  [sampai, sekarang, pakai, alhamdulilah, gapern...
# 767122       767122  ...  [enk, belanja, shopeee, tigkatkn, gratis, ongk...
# 767123       767123  ...                            [belanja, kirim, cepat]
# 767124       767124  ...                           [layan, belanja, shoope]
#
# [767125 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    355592
# 1.0     87528
# 2.0    104407
# 3.0    105808
# 4.0    113790
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500000)

plt.show()
