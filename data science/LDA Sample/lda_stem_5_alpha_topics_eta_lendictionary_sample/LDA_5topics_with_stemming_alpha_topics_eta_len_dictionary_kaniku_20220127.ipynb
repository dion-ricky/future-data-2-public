# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install PySastrawi
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ## Passed

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %%
df_token
# Out:
#                                                 review  ...                                   review_processed
# 0    Pembelian pakai cc ribet, di tolak terus sama ...  ...              beli pakai cc ribet tolak sedia layan
# 1    Kenapa saya tidak bisa verifikasi email saya?!...  ...                             verifikasi email kesel
# 2    TOP UP GAK MASUK E MONEY DIBILANG MASUK, MANAJ...  ...                          up money bilang manajemen
# 3                               Iklan nya nyebelin anj  ...                                     iklan nyebelin
# 4                 Anj..gw mau nonton ngapa kesini mulu  ...                           nonton ngapa kesini mulu
# ..                                                 ...  ...                                                ...
# 995                      Semoga barang semakin lengkap  ...                                     barang lengkap
# 996  Belanja aman dan menyenangkan. Topup tanpa bia...  ...  belanja aman topup biaya admin harga murah jan...
# 997           sip tingkat kan trus aja promo nya ehehe  ...                                tingkat promo ehehe
# 998                                     bags barang ny  ...                                     bags barang ny
# 999                      Pesanan bagus cepat sampe nya  ...                                  pesan cepat sampe
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lemot', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lemot', 'buanget'],
#  ['habis',
#   'update',
#   'lemot',
#   'sihh',
#   'shoppenya',
#   'lemot',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lemot',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lemot'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lemot', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lemot', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lemot',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lemot',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lemot',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'malah',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'malah',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lemot', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lemot',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lemot'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lemot',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lemot',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
#   'kaya',
#   'keong',
# ...
#   'jasa',
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lemot', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lemot',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai']]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_alpha_topics_eta_lendictionary_5')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(0, 0.47851297), (3, 0.5172317)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.43914118), (3, 0.55345136)]
# [(2, 0.9804878)]
# [(0, 0.37326008), (3, 0.6193325)]
# [(2, 0.68219465), (3, 0.20301579), (4, 0.11257963)]
# [(0, 0.17701705), (1, 0.423327), (3, 0.34406653), (4, 0.05503537)]
# [(0, 0.3628806), (1, 0.18543267), (4, 0.44920224)]
# [(1, 0.65882933), (4, 0.3313346)]
# [(1, 0.2016877), (2, 0.14306417), (3, 0.35698318), (4, 0.29755318)]
# [(1, 0.52293265), (3, 0.25363618), (4, 0.21947074)]
# [(0, 0.23427057), (1, 0.27838507), (3, 0.48553437)]
# [(2, 0.78530145), (3, 0.21256329)]
# [(3, 0.535351), (4, 0.46133408)]
# [(0, 0.15693499), (3, 0.7477089), (4, 0.093696326)]
# [(0, 0.09161292), (1, 0.29376507), (2, 0.07452839), (3, 0.5398162)]
# [(0, 0.10049752), (1, 0.4472235), (2, 0.11408484), (3, 0.33719912)]
# [(3, 0.7936616), (4, 0.20137967)]
# [(0, 0.13355482), (2, 0.074260056), (3, 0.5250755), (4, 0.26644516)]
# [(0, 0.16296631), (1, 0.15323848), (3, 0.46578074), (4, 0.21735002)]
# [(0, 0.56471074), (1, 0.14734535), (2, 0.14326295), (3, 0.14326249)]
# [(2, 0.20568427), (3, 0.6121099), (4, 0.17890008)]
# [(1, 0.319226), (3, 0.49538276), (4, 0.18208542)]
# [(0, 0.16513006), (1, 0.06295509), (2, 0.35165918), (3, 0.30235595), (4, 0.11789967)]
# [(1, 0.32284886), (2, 0.4187533), (3, 0.12546584), (4, 0.13168976)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.12594533), (2, 0.29435453), (3, 0.5772156)]
# [(0, 0.3322314), (1, 0.16694213), (3, 0.3322314), (4, 0.16694213)]
# [(2, 0.47803754), (3, 0.3299688), (4, 0.19046108)]
# [(0, 0.23874113), (2, 0.2011724), (3, 0.55842674)]
# [(0, 0.21151172), (1, 0.2872537), (4, 0.49629626)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.1432624), (1, 0.6317943), (3, 0.2221064)]
# [(0, 0.12816665), (1, 0.29390246), (2, 0.4027172), (3, 0.13774434), (4, 0.037469316)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(1, 0.29831687), (2, 0.18134633), (3, 0.4576283), (4, 0.062122013)]
# [(3, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.16680497), (2, 0.17416081), (3, 0.56616056), (4, 0.092043824)]
# [(0, 0.3980198), (3, 0.5960396)]
# [(0, 0.20089026), (3, 0.79612464)]
# [(1, 0.9619048)]
# [(0, 0.35238254), (2, 0.23402213), (3, 0.4096349)]
# [(0, 0.0914027), (3, 0.809464), (4, 0.0973233)]
# [(0, 0.11505796), (1, 0.09169934), (2, 0.20392509), (3, 0.37758538), (4, 0.21173224)]
# [(0, 0.2009351), (1, 0.12553898), (2, 0.22209947), (3, 0.15246516), (4, 0.29896134)]
# [(0, 0.19927303), (2, 0.196046), (3, 0.43605906), (4, 0.166969)]
# [(1, 0.4611378), (3, 0.5346069)]
# [(2, 0.30505347), (3, 0.12278537), (4, 0.56995124)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(2, 0.41716504), (3, 0.5768944)]
# [(1, 0.98688525)]
# [(1, 0.48643777), (2, 0.19999999), (4, 0.30960184)]
# [(1, 0.49626184), (2, 0.49633077)]
# [(1, 0.2441368), (3, 0.22230667), (4, 0.5310721)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.059246693), (1, 0.13653158), (2, 0.1062782), (3, 0.596356), (4, 0.10158749)]
# [(0, 0.20234011), (1, 0.42948085), (2, 0.11160222), (3, 0.14497466), (4, 0.11160222)]
# [(0, 0.4179327), (1, 0.5674332)]
# [(0, 0.19999999), (1, 0.10049751), (3, 0.49850747), (4, 0.19999999)]
# [(0, 0.19999999), (3, 0.5960396), (4, 0.19999999)]
# [(3, 0.6087451), (4, 0.38853994)]
# [(3, 0.8195541), (4, 0.17548724)]
# [(0, 0.20005421), (1, 0.23050204), (2, 0.36746353), (4, 0.19999999)]
# [(0, 0.18557993), (1, 0.35415947), (2, 0.17825125), (3, 0.28142285)]
# [(0, 0.16694213), (2, 0.65022546), (3, 0.17952663)]
# [(0, 0.4125334), (1, 0.15920405), (3, 0.26221028), (4, 0.16534056)]
# [(1, 0.1575566), (3, 0.2851064), (4, 0.55450016)]
# [(0, 0.2243981), (2, 0.20725076), (3, 0.24309435), (4, 0.32360387)]
# [(1, 0.3980198), (3, 0.5960396)]
# [(0, 0.2493827), (2, 0.2493827), (3, 0.49629626)]
# [(1, 0.16984351), (2, 0.14741012), (3, 0.54824674), (4, 0.13412994)]
# [(2, 0.09301217), (3, 0.7089147), (4, 0.19641341)]
# [(3, 0.98688525)]
# [(1, 0.0914027), (3, 0.6351554), (4, 0.2716319)]
# [(0, 0.1709696), (1, 0.22712702), (2, 0.12523365), (3, 0.4070007), (4, 0.069669105)]
# [(0, 0.12911907), (1, 0.39928582), (3, 0.3033505), (4, 0.16733964)]
# [(0, 0.21437693), (1, 0.11931983), (2, 0.3328836), (3, 0.3323147)]
# [(1, 0.762896), (3, 0.23214532)]
# [(0, 0.123041466), (2, 0.29370612), (3, 0.5810425)]
# [(1, 0.21142775), (3, 0.25710765), (4, 0.5298048)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(0, 0.12570259), (3, 0.5873642), (4, 0.28568715)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(3, 0.9619048)]
# [(1, 0.19999999), (2, 0.5117082), (3, 0.2843314)]
# [(0, 0.49752066), (3, 0.49752066)]
# [(2, 0.2493827), (3, 0.2493827), (4, 0.49629626)]
# [(0, 0.6161718), (3, 0.37399212)]
# [(0, 0.17184739), (1, 0.054046717), (2, 0.1989269), (3, 0.29355356), (4, 0.28162542)]
# [(3, 0.48496997), (4, 0.51007134)]
# [(0, 0.26582858), (1, 0.19837604), (2, 0.19884379), (3, 0.2199137), (4, 0.11703786)]
# [(3, 0.9804878)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(3, 0.98688525)]
# [(0, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.71169686), (4, 0.28089568)]
# [(0, 0.1430605), (2, 0.15734878), (3, 0.6981672)]
# [(0, 0.04031936), (1, 0.1723152), (2, 0.13804588), (3, 0.5029171), (4, 0.1464025)]
# [(0, 0.107491955), (1, 0.2399373), (2, 0.3956216), (3, 0.25604418)]
# [(0, 0.6542537), (1, 0.17549834), (3, 0.16694213)]
# [(0, 0.28421253), (1, 0.14306049), (2, 0.28710252), (3, 0.20012724), (4, 0.08549723)]
# [(3, 0.9619048)]
# [(0, 0.09171469), (1, 0.49691433), (2, 0.101844735), (3, 0.30862123)]
# [(1, 0.98688525)]
# [(1, 0.31354374), (3, 0.50274587), (4, 0.18190044)]
# [(1, 0.33114758), (3, 0.6590164)]
# [(1, 0.5029804), (3, 0.4896122)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.117346376), (1, 0.4363926), (3, 0.17295787), (4, 0.2723982)]
# [(0, 0.17480412), (1, 0.17237367), (2, 0.15195382), (3, 0.08176623), (4, 0.41910222)]
# [(0, 0.9619048)]
# [(0, 0.2526812), (2, 0.4929978), (4, 0.24938273)]
# [(0, 0.36173946), (1, 0.3390149), (3, 0.29528522)]
# [(0, 0.33223143), (3, 0.47893196), (4, 0.18553087)]
# [(0, 0.13526933), (1, 0.53953815), (2, 0.20635104), (3, 0.11784648)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.24968943), (3, 0.53750706), (4, 0.210319)]
# [(0, 0.32604933), (1, 0.20843822), (3, 0.22209944), (4, 0.24230799)]
# [(0, 0.25853276), (3, 0.5977365), (4, 0.142071)]
# [(1, 0.9920792)]
# [(0, 0.08381742), (3, 0.6647303), (4, 0.2497925)]
# [(1, 0.16694213), (2, 0.3322314), (3, 0.49752066)]
# [(0, 0.08382431), (1, 0.11417139), (2, 0.16012217), (3, 0.44135648), (4, 0.20052561)]
# [(3, 0.33474338), (4, 0.6615299)]
# [(3, 0.9619048)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(3, 0.5960396), (4, 0.3980198)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.2867132), (1, 0.3600918), (2, 0.16694345), (4, 0.18459864)]
# [(0, 0.13701278), (1, 0.23771597), (2, 0.24322535), (3, 0.13815433), (4, 0.24389154)]
# [(0, 0.9804878)]
# [(0, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(0, 0.16497464), (1, 0.5009534), (2, 0.055955682), (3, 0.22216068), (4, 0.055955682)]
# [(0, 0.17653957), (1, 0.17653957), (2, 0.46696326), (3, 0.12098862), (4, 0.05896894)]
# [(1, 0.46888933), (2, 0.25125194), (3, 0.278199)]
# [(0, 0.2), (1, 0.36030212), (4, 0.4357375)]
# [(0, 0.21103357), (1, 0.28773186), (3, 0.49629632)]
# [(0, 0.6166427), (1, 0.37352118)]
# [(0, 0.2493827), (1, 0.49352238), (2, 0.2521566)]
# [(0, 0.25657472), (1, 0.2), (2, 0.20037727), (3, 0.34106782)]
# [(0, 0.19999999), (1, 0.19999999), (3, 0.24025862), (4, 0.35776114)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.16668904), (2, 0.17229044), (3, 0.65818363)]
# [(0, 0.22063753), (1, 0.12061863), (2, 0.07240682), (3, 0.41035587), (4, 0.17598112)]
# [(0, 0.6732147), (4, 0.32305863)]
# [(0, 0.17085658), (1, 0.23280926), (3, 0.26128098), (4, 0.3336347)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(1, 0.19493634), (2, 0.5302955), (3, 0.27371833)]
# [(1, 0.4149447), (2, 0.12546584), (3, 0.24968697), (4, 0.20866019)]
# [(0, 0.20690854), (2, 0.19838968), (3, 0.5155871), (4, 0.07875819)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(0, 0.12546584), (1, 0.37391302), (2, 0.12546584), (3, 0.37391302)]
# [(1, 0.42695034), (2, 0.5687943)]
# [(0, 0.7430758), (2, 0.2495168)]
# [(0, 0.28510636), (1, 0.2851777), (2, 0.1432624), (3, 0.14319108), (4, 0.1432624)]
# [(1, 0.26338667), (3, 0.44867006), (4, 0.28510636)]
# [(0, 0.5535912), (3, 0.2547673), (4, 0.18943161)]
# [(0, 0.18805277), (1, 0.23733498), (2, 0.34375477), (4, 0.23014571)]
# [(0, 0.49629626), (2, 0.2493827), (3, 0.2493827)]
# [(1, 0.33114755), (3, 0.3311475), (4, 0.33114755)]
# [(1, 0.42598167), (2, 0.14377292), (3, 0.23239672), (4, 0.19754611)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.2493827), (2, 0.2493827), (3, 0.2493827), (4, 0.2493827)]
# [(0, 0.18190047), (1, 0.2542115), (2, 0.1159111), (3, 0.35657427), (4, 0.09140272)]
# [(0, 0.15702485), (1, 0.20405696), (2, 0.120375395), (3, 0.42308468), (4, 0.09545817)]
# [(0, 0.08381742), (1, 0.2735165), (3, 0.64100635)]
# [(0, 0.19999997), (3, 0.79405946)]
# [(1, 0.08874778), (3, 0.5314855), (4, 0.3785206)]
# [(1, 0.4161052), (2, 0.123824656), (3, 0.395899), (4, 0.06361711)]
# [(3, 0.9804878)]
# [(0, 0.16743034), (1, 0.31143695), (2, 0.09356863), (3, 0.30171922), (4, 0.12584488)]
# [(0, 0.25180852), (3, 0.4137516), (4, 0.33278012)]
# [(1, 0.16694213), (2, 0.3322314), (3, 0.3322314), (4, 0.16694213)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(0, 0.2995025), (1, 0.12373939), (2, 0.34519663), (4, 0.23056644)]
# [(1, 0.4237208), (2, 0.2770784), (3, 0.29636395)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.16694213), (2, 0.33223143), (3, 0.3322314), (4, 0.16694213)]
# [(0, 0.17388107), (1, 0.38208425), (3, 0.3392135), (4, 0.103916235)]
# [(1, 0.59603965), (4, 0.3980198)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.21086234), (1, 0.67502105), (3, 0.1121265)]
# [(0, 0.06710963), (1, 0.30473715), (2, 0.1968858), (3, 0.20741642), (4, 0.223851)]
# [(0, 0.26726624), (3, 0.7253263)]
# [(0, 0.6166726), (1, 0.37349135)]
# [(0, 0.30772024), (1, 0.08852048), (3, 0.5389323), (4, 0.064203836)]
# [(0, 0.32839292), (3, 0.39076778), (4, 0.27835485)]
# [(3, 0.8241497), (4, 0.17089158)]
# [(0, 0.6628099), (1, 0.16694213), (4, 0.16694213)]
# [(0, 0.25181675), (1, 0.19471388), (2, 0.17633726), (4, 0.37650907)]
# [(2, 0.6627547), (3, 0.3274092)]
# [(0, 0.55166644), (1, 0.18883389), (3, 0.25701517)]
# [(1, 0.9804878)]
# [(0, 0.24968943), (1, 0.12546584), (3, 0.49813667), (4, 0.12546584)]
# [(0, 0.14877555), (1, 0.12610807), (2, 0.23141706), (3, 0.29630136), (4, 0.19739799)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(2, 0.49752066), (3, 0.49752066)]
# [(1, 0.083817415), (2, 0.20687291), (3, 0.33278012), (4, 0.3756997)]
# [(0, 0.36289597), (3, 0.5376716), (4, 0.09762246)]
# [(0, 0.13377628), (2, 0.6531381), (4, 0.21183947)]
# [(0, 0.2), (1, 0.22492746), (2, 0.31025606), (3, 0.26283628)]
# [(0, 0.49629626), (1, 0.2493827), (2, 0.2493827)]
# [(1, 0.33223143), (2, 0.49752066), (3, 0.16694213)]
# [(1, 0.48331925), (2, 0.094064005), (3, 0.42150876)]
# [(2, 0.65901643), (4, 0.33114755)]
# [(2, 0.6788379), (3, 0.31690678)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.2356538), (1, 0.13950145), (2, 0.34809494), (3, 0.27550754)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.5960396), (2, 0.19999999), (4, 0.19999999)]
# [(3, 0.99012345)]
# [(0, 0.18286912), (2, 0.23108882), (3, 0.37905177), (4, 0.20608528)]
# [(0, 0.2493827), (3, 0.74320984)]
# [(3, 0.3980198), (4, 0.5960396)]
# [(0, 0.09802397), (1, 0.08196165), (2, 0.6681104), (4, 0.15113774)]
# [(0, 0.09000477), (1, 0.09767146), (2, 0.5570808), (4, 0.25441313)]
# [(1, 0.14923957), (3, 0.84703374)]
# [(1, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(0, 0.229969), (1, 0.33223143), (2, 0.21193823), (3, 0.22420847)]
# [(1, 0.43320063), (4, 0.5608587)]
# [(2, 0.2821744), (3, 0.5504513), (4, 0.16571458)]
# [(0, 0.3739098), (2, 0.37391606), (3, 0.2496897)]
# [(0, 0.14326242), (1, 0.3210767), (2, 0.39098004), (4, 0.14326242)]
# [(0, 0.11160221), (3, 0.8850829)]
# [(0, 0.42695034), (3, 0.42695034), (4, 0.1432624)]
# [(1, 0.4444638), (3, 0.54570013)]
# [(1, 0.8783492), (3, 0.11833589)]
# [(0, 0.33560607), (2, 0.22313039), (3, 0.43795776)]
# [(0, 0.2), (3, 0.7940594)]
# [(1, 0.42693317), (2, 0.35767734), (3, 0.21255264)]
# [(0, 0.2467026), (1, 0.29522276), (2, 0.07763779), (3, 0.27186373), (4, 0.10857313)]
# [(4, 0.9804878)]
# [(1, 0.16896644), (2, 0.3003627), (3, 0.40803972), (4, 0.12207716)]
# [(2, 0.9804878)]
# [(1, 0.19999999), (2, 0.3980198), (4, 0.3980198)]
# [(1, 0.49751118), (2, 0.21689786), (3, 0.28228515)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(3, 0.99012345)]
# [(3, 0.98688525)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.17154112), (1, 0.112087175), (3, 0.42490047), (4, 0.29056624)]
# [(0, 0.16694215), (3, 0.64810836), (4, 0.1816437)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(0, 0.16090779), (1, 0.17663975), (2, 0.17260472), (3, 0.32675502), (4, 0.16309272)]
# [(0, 0.24744637), (1, 0.11260002), (3, 0.50886947), (4, 0.1299791)]
# [(0, 0.14404115), (1, 0.3270155), (3, 0.5275198)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(1, 0.39618984), (2, 0.4125222), (3, 0.1879822)]
# [(0, 0.42695034), (3, 0.5687943)]
# [(1, 0.47852066), (2, 0.31751898), (3, 0.2)]
# [(0, 0.49813667), (1, 0.24968943), (3, 0.24968943)]
# [(0, 0.39801866), (3, 0.5960408)]
# [(0, 0.1745749), (1, 0.17517096), (2, 0.27824184), (3, 0.3713478)]
# [(4, 0.98688525)]
# [(1, 0.17740445), (3, 0.8183402)]
# [(1, 0.122240454), (2, 0.23239863), (3, 0.5326537), (4, 0.11160221)]
# [(3, 0.98688525)]
# [(1, 0.98688525)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.3980198), (1, 0.5960396)]
# [(0, 0.21322572), (2, 0.7837892)]
# [(0, 0.13629608), (1, 0.26389885), (2, 0.08792519), (3, 0.46800935), (4, 0.043870505)]
# [(1, 0.19999997), (2, 0.69751245), (4, 0.1004975)]
# [(1, 0.07988072), (2, 0.54310143), (3, 0.37548533)]
# [(0, 0.11989218), (1, 0.41557762), (2, 0.27542236), (4, 0.1883961)]
# [(1, 0.187852), (2, 0.25431594), (3, 0.389237), (4, 0.16694213)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(1, 0.9619048)]
# [(0, 0.11160221), (2, 0.22209944), (3, 0.11160533), (4, 0.5535881)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(4, 0.98688525)]
# [(0, 0.3322314), (3, 0.6628099)]
# [(0, 0.16694213), (4, 0.8280992)]
# [(1, 0.40275973), (3, 0.14020768), (4, 0.4545481)]
# [(1, 0.9804878)]
# [(0, 0.5074214), (3, 0.25835103), (4, 0.23289868)]
# [(0, 0.12546584), (1, 0.30687118), (3, 0.16403838), (4, 0.40238234)]
# [(3, 0.99012345)]
# [(0, 0.19999999), (1, 0.2880806), (2, 0.19999999), (3, 0.30993918)]
# [(0, 0.09665847), (1, 0.26513147), (3, 0.5167536), (4, 0.1209024)]
# [(0, 0.19999999), (1, 0.21611865), (2, 0.57992095)]
# [(1, 0.16723077), (2, 0.2225015), (3, 0.49655962), (4, 0.113043636)]
# [(0, 0.16857776), (1, 0.107394196), (2, 0.3537469), (3, 0.26075685), (4, 0.10952435)]
# [(2, 0.2493827), (3, 0.74320984)]
# [(0, 0.39432374), (2, 0.29950413), (3, 0.20000017), (4, 0.10517692)]
# [(0, 0.24968943), (3, 0.6198249), (4, 0.12800117)]
# [(1, 0.12668371), (3, 0.31877542), (4, 0.5525508)]
# [(1, 0.11925573), (2, 0.4240567), (3, 0.10665744), (4, 0.3495314)]
# [(0, 0.27926978), (1, 0.16720693), (3, 0.5520998)]
# [(1, 0.37261298), (2, 0.1679213), (3, 0.31402466), (4, 0.14472933)]
# [(0, 0.18065858), (1, 0.19431125), (2, 0.3314173), (3, 0.08636003), (4, 0.20725289)]
# [(1, 0.21423489), (2, 0.28041822), (3, 0.14752366), (4, 0.3571115)]
# [(0, 0.65901643), (1, 0.33114755)]
# [(3, 0.98688525)]
# [(0, 0.20601106), (1, 0.294385), (3, 0.33100888), (4, 0.16694213)]
# [(0, 0.5960367), (2, 0.3980227)]
# [(0, 0.22209944), (2, 0.39849702), (4, 0.37719357)]
# [(3, 0.7900877), (4, 0.20565695)]
# [(1, 0.99012345)]
# [(1, 0.28510636), (3, 0.4273331), (4, 0.28472364)]
# [(1, 0.3513836), (2, 0.20037259), (4, 0.44625378)]
# [(0, 0.21141987), (1, 0.28802204), (4, 0.4956198)]
# [(1, 0.6887407), (3, 0.16516007), (4, 0.1432624)]
# [(0, 0.13058569), (1, 0.26760715), (2, 0.26983678), (3, 0.14984982), (4, 0.18212055)]
# [(0, 0.09708423), (1, 0.16272072), (2, 0.26897603), (3, 0.22957839), (4, 0.24164061)]
# [(0, 0.059237532), (1, 0.11790691), (2, 0.56852025), (4, 0.25374877)]
# [(0, 0.05604988), (1, 0.23190746), (2, 0.32330155), (3, 0.3327855), (4, 0.055955682)]
# [(1, 0.19999999), (2, 0.51158476), (3, 0.28445485)]
# [(0, 0.19999999), (3, 0.7940594)]
# [(0, 0.1432624), (1, 0.42695034), (3, 0.28519157), (4, 0.14317727)]
# [(0, 0.20891489), (1, 0.08619879), (2, 0.17399317), (3, 0.28137904), (4, 0.24951413)]
# [(0, 0.19999999), (1, 0.21316878), (2, 0.31783304), (3, 0.2680031)]
# [(2, 0.74320984), (4, 0.2493827)]
# [(0, 0.15062018), (1, 0.22445771), (2, 0.072222546), (3, 0.3615389), (4, 0.19116072)]
# [(0, 0.2496894), (3, 0.7465838)]
# [(0, 0.44037154), (1, 0.13087347), (4, 0.42676488)]
# [(0, 0.5535912), (1, 0.11160221), (2, 0.22209944), (4, 0.11160221)]
# [(0, 0.16680497), (1, 0.24979256), (2, 0.24979247), (4, 0.3327801)]
# [(1, 0.13393971), (2, 0.39046618), (3, 0.105153166), (4, 0.36953598)]
# [(2, 0.49629626), (3, 0.49629626)]
# [(0, 0.16694213), (1, 0.49752066), (2, 0.16694213), (4, 0.16694213)]
# [(1, 0.18365249), (2, 0.5885517), (4, 0.22598584)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(0, 0.28576082), (1, 0.1765432), (3, 0.34484953), (4, 0.19225988)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.29852512), (2, 0.3657484), (3, 0.33078817)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.2760882), (1, 0.2205873), (2, 0.270789), (3, 0.13780434), (4, 0.094731145)]
# [(0, 0.11160221), (3, 0.3325967), (4, 0.5535912)]
# [(0, 0.17881112), (1, 0.09142922), (2, 0.093171425), (3, 0.4612629), (4, 0.17532535)]
# [(0, 0.23278376), (2, 0.096396275), (3, 0.5699885), (4, 0.10006518)]
# [(1, 0.2577366), (2, 0.08721863), (3, 0.65421325)]
# [(0, 0.12546584), (2, 0.44703618), (3, 0.4250135)]
# [(2, 0.4301577), (3, 0.31527737), (4, 0.24962662)]
# [(4, 0.9804878)]
# [(0, 0.3327801), (1, 0.29579052), (2, 0.08381742), (3, 0.19905804), (4, 0.08855391)]
# [(1, 0.1367919), (3, 0.7352578), (4, 0.12546584)]
# [(0, 0.49629626), (3, 0.49629626)]
# [(0, 0.29704484), (1, 0.25564998), (2, 0.23751539), (3, 0.17339341), (4, 0.036396354)]
# [(0, 0.1818457), (1, 0.22733943), (2, 0.10926101), (3, 0.13640021), (4, 0.34515366)]
# [(1, 0.4989324), (2, 0.26724243), (3, 0.23240168)]
# [(0, 0.26974702), (1, 0.09613916), (2, 0.37729713), (3, 0.07527109), (4, 0.1815456)]
# [(0, 0.57800233), (2, 0.10894288), (3, 0.31172585)]
# [(0, 0.15992185), (1, 0.10031885), (2, 0.27074102), (3, 0.46818843)]
# [(1, 0.22886786), (3, 0.7661735)]
# [(0, 0.27235198), (1, 0.09152859), (2, 0.256653), (3, 0.26128164), (4, 0.11818475)]
# [(1, 0.41814446), (2, 0.4133622), (4, 0.16683356)]
# [(3, 0.98688525)]
# [(1, 0.330956), (2, 0.2853117), (3, 0.3301014), (4, 0.053132176)]
# [(1, 0.98688525)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.3980198), (4, 0.19999999)]
# [(0, 0.2493827), (3, 0.74320984)]
# [(1, 0.3980198), (3, 0.5960396)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.19999999), (4, 0.3980198)]
# [(0, 0.10643514), (1, 0.14449655), (2, 0.12546584), (3, 0.49813667), (4, 0.12546584)]
# [(3, 0.45550027), (4, 0.54151464)]
# [(0, 0.32217938), (1, 0.21901664), (3, 0.45549822)]
# [(0, 0.16966785), (1, 0.23033217), (2, 0.19999999), (3, 0.3980198)]
# [(0, 0.09208864), (1, 0.14082536), (2, 0.12559788), (3, 0.6403831)]
# [(1, 0.17132999), (2, 0.28923175), (3, 0.5369538)]
# [(0, 0.18838032), (1, 0.16327769), (2, 0.30301014), (3, 0.12627654), (4, 0.21905532)]
# [(0, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.99012345)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.4926831), (4, 0.4926827)]
# [(0, 0.112692565), (1, 0.1942319), (2, 0.06366388), (3, 0.62907887)]
# [(0, 0.12399196), (1, 0.25866154), (2, 0.12964864), (3, 0.44733614), (4, 0.040361732)]
# [(1, 0.373913), (2, 0.37391302), (3, 0.24968943)]
# [(1, 0.38871711), (2, 0.15910845), (3, 0.3074534), (4, 0.14330262)]
# [(0, 0.24938273), (2, 0.4307989), (3, 0.31488013)]
# [(0, 0.20906225), (1, 0.37113914), (2, 0.18848848), (3, 0.12579837), (4, 0.10551178)]
# [(0, 0.2493827), (2, 0.2493827), (3, 0.49629626)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.09140271), (1, 0.32152146), (3, 0.395164), (4, 0.19100685)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.35879835), (2, 0.33568433), (3, 0.3026804)]
# [(4, 0.9804878)]
# [(0, 0.39933556), (1, 0.26440293), (2, 0.13355482), (3, 0.13355482), (4, 0.0691519)]
# [(0, 0.49629626), (3, 0.2493827), (4, 0.2493827)]
# [(0, 0.27913922), (1, 0.31019908), (2, 0.10877077), (3, 0.24989025), (4, 0.052000668)]
# [(1, 0.37604067), (2, 0.114465296), (3, 0.17795578), (4, 0.33063325)]
# [(2, 0.6581026), (4, 0.33206132)]
# [(0, 0.270826), (3, 0.17604421), (4, 0.549824)]
# [(2, 0.36777288), (3, 0.42755875), (4, 0.2018315)]
# [(0, 0.1120236), (1, 0.24229085), (2, 0.53297836), (4, 0.11160221)]
# [(0, 0.08381742), (1, 0.37868306), (2, 0.2472956), (3, 0.28937402)]
# [(0, 0.15777226), (1, 0.36936873), (3, 0.33077976), (4, 0.14108421)]
# [(0, 0.16007984), (1, 0.06574538), (2, 0.14774515), (3, 0.49401954), (4, 0.13241006)]
# [(1, 0.49009266), (2, 0.19592007), (3, 0.10255447), (4, 0.21043779)]
# [(0, 0.08940237), (1, 0.34290048), (2, 0.12886713), (3, 0.39315745), (4, 0.045672547)]
# [(0, 0.24938273), (3, 0.74320984)]
# [(1, 0.4670412), (3, 0.5255513)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2664452), (1, 0.15197566), (2, 0.09880062), (3, 0.19659665), (4, 0.28618184)]
# [(1, 0.42323223), (2, 0.15402299), (3, 0.342204), (4, 0.0797745)]
# [(3, 0.9804878)]
# [(0, 0.062928356), (1, 0.11433084), (2, 0.62367606), (3, 0.13613646), (4, 0.06292835)]
# [(0, 0.23065133), (1, 0.40646896), (2, 0.0775286), (3, 0.2845848)]
# [(0, 0.2074063), (1, 0.22187215), (2, 0.051481463), (3, 0.37209353), (4, 0.14714654)]
# [(1, 0.18194677), (2, 0.18204099), (3, 0.450885), (4, 0.18422228)]
# [(1, 0.65430045), (4, 0.34197286)]
# [(0, 0.244901), (1, 0.1008966), (2, 0.25252214), (3, 0.22768901), (4, 0.17399125)]
# [(1, 0.3076045), (3, 0.6849881)]
# [(2, 0.22209944), (3, 0.5535912), (4, 0.22209944)]
# [(0, 0.67581415), (3, 0.19542731), (4, 0.12758555)]
# [(0, 0.16694213), (1, 0.16694213), (2, 0.49752066), (4, 0.16694213)]
# [(1, 0.24982053), (2, 0.33352792), (3, 0.34137297), (4, 0.074566826)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.22209944), (3, 0.59644413), (4, 0.17924647)]
# [(0, 0.16694215), (2, 0.33223143), (3, 0.2981001), (4, 0.20107341)]
# [(1, 0.3980198), (3, 0.5960396)]
# [(0, 0.4459209), (1, 0.24756882), (3, 0.10472288), (4, 0.20079236)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(0, 0.24176273), (1, 0.18398857), (3, 0.4868456), (4, 0.08663682)]
# [(1, 0.5095289), (3, 0.4862158)]
# [(0, 0.12606105), (1, 0.2916651), (3, 0.24842979), (4, 0.3327391)]
# [(0, 0.13677175), (1, 0.23838352), (2, 0.26974788), (3, 0.22963098), (4, 0.12546584)]
# [(0, 0.13953045), (1, 0.65836495), (2, 0.20085852)]
# [(0, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.16573288), (2, 0.41453835), (3, 0.2603651), (4, 0.15874061)]
# [(1, 0.22962426), (2, 0.26306415), (3, 0.25370193), (4, 0.2527047)]
# [(0, 0.09847233), (1, 0.39715928), (2, 0.23237765), (3, 0.22613204), (4, 0.045858745)]
# [(1, 0.2548765), (2, 0.32419077), (3, 0.25233766), (4, 0.16694213)]
# [(1, 0.49752066), (2, 0.3322314), (4, 0.16694213)]
# [(2, 0.7227089), (4, 0.26988372)]
# [(0, 0.22578299), (1, 0.24459726), (2, 0.13633367), (3, 0.3926996)]
# [(2, 0.49629626), (3, 0.49629626)]
# [(0, 0.05301837), (1, 0.10552689), (2, 0.53308326), (3, 0.2542544), (4, 0.0541171)]
# [(1, 0.2493827), (2, 0.74320984)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(2, 0.42005587), (3, 0.25699955), (4, 0.32152104)]
# [(0, 0.2493827), (1, 0.2493827), (2, 0.2493827), (3, 0.2493827)]
# [(0, 0.16694213), (2, 0.16694213), (4, 0.66280997)]
# [(2, 0.2994893), (3, 0.10051477), (4, 0.5980059)]
# [(1, 0.19612676), (2, 0.111779176), (3, 0.5345167), (4, 0.15647237)]
# [(0, 0.24968943), (1, 0.3743274), (2, 0.22520828), (3, 0.14953263)]
# [(0, 0.52153563), (3, 0.24620368), (4, 0.23072807)]
# [(1, 0.9804878)]
# [(0, 0.33114755), (1, 0.33114755), (4, 0.33114755)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.4962954), (3, 0.49629715)]
# [(0, 0.33034018), (1, 0.3311591), (2, 0.33194327)]
# [(0, 0.32519582), (1, 0.12614895), (2, 0.29964095), (3, 0.121660575), (4, 0.12735365)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.31987888), (1, 0.14189528), (2, 0.26030716), (3, 0.2772542)]
# [(0, 0.65901595), (3, 0.33114797)]
# [(0, 0.33289033), (1, 0.06710963), (2, 0.06710963), (3, 0.46578074), (4, 0.06710963)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.10928336), (1, 0.16779466), (2, 0.13100998), (3, 0.372283), (4, 0.21962896)]
# [(1, 0.37883952), (2, 0.38581887), (3, 0.23203583)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.12162736), (1, 0.16489744), (2, 0.28510642), (3, 0.14326242), (4, 0.28510636)]
# [(2, 0.98688525)]
# [(0, 0.05773486), (1, 0.24218725), (2, 0.31233355), (3, 0.2690949), (4, 0.1186494)]
# [(4, 0.9804878)]
# [(2, 0.98688525)]
# [(0, 0.10049751), (1, 0.4961416), (2, 0.100292884), (3, 0.20020461), (4, 0.10286339)]
# [(1, 0.4738553), (2, 0.1004975), (3, 0.42365715)]
# [(1, 0.42695037), (2, 0.13736245), (3, 0.29100636), (4, 0.14326242)]
# [(3, 0.9619048)]
# [(0, 0.19903967), (1, 0.27669686), (2, 0.27587742), (3, 0.24728103)]
# [(0, 0.21734764), (1, 0.11635402), (2, 0.11160221), (3, 0.5535912)]
# [(1, 0.5960396), (2, 0.20000002), (4, 0.19999999)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(2, 0.65901643), (4, 0.33114755)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.25867465), (3, 0.53760386), (4, 0.2004157)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(2, 0.98688525)]
# [(0, 0.38415113), (1, 0.21386673), (2, 0.20000172), (3, 0.20000026)]
# [(0, 0.12546584), (2, 0.24968943), (3, 0.49813703), (4, 0.12546548)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.21146782), (1, 0.122233845), (3, 0.22209944), (4, 0.44309393)]
# [(0, 0.1743751), (1, 0.3101608), (2, 0.09140271), (3, 0.18918292), (4, 0.23487853)]
# [(2, 0.41093385), (3, 0.3323284), (4, 0.25179943)]
# [(3, 0.74320984), (4, 0.24938273)]
# [(0, 0.16102995), (2, 0.14993484), (3, 0.5613544), (4, 0.12643859)]
# [(1, 0.13721023), (2, 0.41571626), (3, 0.35476583), (4, 0.09140271)]
# [(1, 0.3617089), (3, 0.6359922)]
# [(0, 0.18633315), (1, 0.19863872), (3, 0.5249761), (4, 0.089527175)]
# [(1, 0.5960396), (4, 0.3980198)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(1, 0.16694215), (2, 0.16694215), (3, 0.6628099)]
# [(1, 0.18634784), (2, 0.20257178), (3, 0.111357346), (4, 0.49916896)]
# [(1, 0.22995077), (2, 0.13157398), (3, 0.2723994), (4, 0.36517087)]
# [(1, 0.33114758), (3, 0.6590164)]
# [(0, 0.121004686), (1, 0.40289658), (2, 0.25685203), (3, 0.21877165)]
# [(0, 0.10355587), (1, 0.46432054), (3, 0.33063102), (4, 0.1004975)]
# [(0, 0.24968943), (2, 0.5923231), (3, 0.155503)]
# [(1, 0.24938273), (2, 0.45940247), (3, 0.28627652)]
# [(1, 0.3980198), (2, 0.3980198), (3, 0.19999999)]
# [(0, 0.1303616), (1, 0.07519965), (2, 0.20017971), (3, 0.52268), (4, 0.071579084)]
# [(1, 0.27503642), (3, 0.4294818), (4, 0.29054353)]
# [(0, 0.07165775), (1, 0.19253176), (2, 0.34524065), (3, 0.29534814), (4, 0.09522169)]
# [(3, 0.98688525)]
# [(0, 0.1620951), (1, 0.35801882), (3, 0.47855717)]
# [(1, 0.3980198), (2, 0.3980198), (3, 0.19999999)]
# [(0, 0.3980198), (4, 0.5960396)]
# [(0, 0.19999999), (1, 0.34345606), (2, 0.10049751), (3, 0.35505137)]
# [(0, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(1, 0.49752066), (2, 0.3322314), (3, 0.16694213)]
# [(1, 0.34133053), (2, 0.26230592), (3, 0.15165274), (4, 0.24360582)]
# [(3, 0.9619048)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(1, 0.21325344), (2, 0.57421994), (3, 0.20856623)]
# [(2, 0.49629626), (3, 0.24938282), (4, 0.24938259)]
# [(0, 0.10666394), (1, 0.075077675), (2, 0.28211698), (3, 0.34721646), (4, 0.18892492)]
# [(1, 0.26027253), (2, 0.42695037), (3, 0.30994025)]
# [(0, 0.16694213), (2, 0.21033105), (3, 0.619421)]
# [(0, 0.42238948), (2, 0.5716699)]
# [(0, 0.08381742), (1, 0.24979255), (2, 0.113283716), (3, 0.5522765)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.9804878)]
# [(2, 0.4390118), (3, 0.3868518), (4, 0.17260383)]
# [(1, 0.37420464), (4, 0.6208366)]
# [(0, 0.12546584), (1, 0.12546584), (2, 0.24968943), (4, 0.4981366)]
# [(0, 0.12560782), (1, 0.30398014), (2, 0.1863529), (3, 0.29679444), (4, 0.087264664)]
# [(1, 0.2493827), (2, 0.74320984)]
# [(0, 0.16855499), (1, 0.26449925), (2, 0.16688742), (3, 0.39922848)]
# [(0, 0.108638056), (1, 0.25231272), (2, 0.42162183), (3, 0.102910206), (4, 0.11451715)]
# [(0, 0.0631713), (1, 0.21461807), (2, 0.37668726), (3, 0.27532935), (4, 0.07019398)]
# [(1, 0.9804878)]
# [(0, 0.14326242), (1, 0.15213972), (2, 0.14326242), (3, 0.41807306), (4, 0.14326242)]
# [(0, 0.076481044), (2, 0.08757863), (3, 0.7487261), (4, 0.08678032)]
# [(1, 0.41956383), (2, 0.13017228), (3, 0.3445979), (4, 0.10467097)]
# [(1, 0.25200832), (3, 0.5932316), (4, 0.15192313)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(0, 0.11212963), (1, 0.3273286), (2, 0.2738982), (3, 0.16589679), (4, 0.12074675)]
# [(1, 0.49629626), (2, 0.49629626)]
# [(3, 0.68417114), (4, 0.30842137)]
# [(2, 0.9804878)]
# [(0, 0.49629626), (1, 0.2493827), (3, 0.2493827)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.9804878)]
# [(1, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(0, 0.3980198), (2, 0.5960396)]
# [(3, 0.9619048)]
# [(0, 0.25708833), (1, 0.31911552), (2, 0.42158616)]
# [(1, 0.23627189), (2, 0.181644), (3, 0.5802741)]
# [(1, 0.6286655), (2, 0.36392713)]
# [(3, 0.9804878)]
# [(0, 0.6449652), (1, 0.34519875)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(0, 0.30190036), (2, 0.23011883), (3, 0.464675)]
# [(1, 0.32544237), (2, 0.29648268), (3, 0.28552943), (4, 0.09164052)]
# [(2, 0.465235), (3, 0.5273576)]
# [(0, 0.16970733), (1, 0.23029265), (2, 0.20000002), (3, 0.3980198)]
# [(0, 0.23425859), (1, 0.056550905), (2, 0.23318101), (3, 0.28551072), (4, 0.19049881)]
# [(0, 0.24938273), (2, 0.32423043), (3, 0.4214485)]
# [(3, 0.98688525)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(3, 0.98688525)]
# [(0, 0.055955674), (1, 0.38836563), (2, 0.24432075), (3, 0.2387574), (4, 0.07260052)]
# [(0, 0.41815555), (1, 0.5672103)]
# [(0, 0.19999999), (2, 0.34871733), (3, 0.44929263)]
# [(2, 0.9619048)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.33660576), (3, 0.6535582)]
# [(3, 0.5913533), (4, 0.39881063)]
# [(2, 0.7432099), (3, 0.2493827)]
# [(0, 0.21152422), (1, 0.28724125), (2, 0.24938273), (3, 0.2493827)]
# [(0, 0.32052344), (1, 0.11587951), (3, 0.437103), (4, 0.12538902)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.49268118), (3, 0.4926847)]
# [(3, 0.98688525)]
# [(1, 0.4513479), (2, 0.13321419), (4, 0.41295347)]
# [(0, 0.10579906), (1, 0.46966636), (3, 0.35937992), (4, 0.064629726)]
# [(4, 0.9619048)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114755), (1, 0.33114755), (2, 0.33114755)]
# [(0, 0.087540835), (1, 0.27937928), (2, 0.30632806), (3, 0.209366), (4, 0.11738588)]
# [(3, 0.9804878)]
# [(3, 0.85248226), (4, 0.1432624)]
# [(1, 0.21003652), (3, 0.5860031), (4, 0.2)]
# [(0, 0.19999999), (2, 0.4559125), (3, 0.3401271)]
# [(2, 0.16251415), (3, 0.38560027), (4, 0.44940105)]
# [(0, 0.59603673), (2, 0.3980227)]
# [(1, 0.19999999), (2, 0.3980198), (3, 0.3980198)]
# [(3, 0.59141463), (4, 0.39874926)]
# [(0, 0.11147643), (1, 0.1295973), (2, 0.12751971), (3, 0.55513704), (4, 0.07626948)]
# [(0, 0.49267113), (2, 0.49269468)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.3980198), (2, 0.19999999), (3, 0.3980198)]
# [(3, 0.9804878)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.39933592), (1, 0.035203695), (2, 0.1616758), (3, 0.21527345), (4, 0.18851118)]
# [(0, 0.2), (1, 0.43375582), (3, 0.36491528)]
# [(2, 0.27422237), (3, 0.5973337), (4, 0.12595949)]
# [(0, 0.1432624), (2, 0.28510636), (3, 0.56879437)]
# [(2, 0.9804878)]
# [(2, 0.33194372), (3, 0.6606488)]
# [(0, 0.15547198), (1, 0.20787345), (2, 0.21208437), (3, 0.25776523), (4, 0.16680497)]
# [(3, 0.9804878)]
# [(0, 0.03733826), (1, 0.16232915), (2, 0.44772512), (3, 0.3148337), (4, 0.037773788)]
# [(0, 0.13107818), (1, 0.16455653), (2, 0.4134223), (3, 0.29011312)]
# [(1, 0.61771727), (4, 0.3799839)]
# [(0, 0.1818594), (1, 0.2544115), (2, 0.05613031), (3, 0.40375558), (4, 0.10384324)]
# [(0, 0.9804878)]
# [(2, 0.49610806), (3, 0.49648452)]
# [(3, 0.33259663), (4, 0.66408837)]
# [(0, 0.41810068), (1, 0.56726515)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.3472841), (3, 0.31501096), (4, 0.33114755)]
# [(0, 0.2493827), (3, 0.74320984)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(0, 0.2965178), (2, 0.10273317), (3, 0.59908926)]
# [(1, 0.19999999), (2, 0.23502025), (3, 0.36299953), (4, 0.19999999)]
# [(1, 0.12538177), (2, 0.29565197), (3, 0.46591288), (4, 0.111948386)]
# [(0, 0.33898452), (1, 0.6511794)]
# [(1, 0.33112612), (2, 0.13197467), (3, 0.3286595), (4, 0.20768572)]
# [(4, 0.9804878)]
# [(0, 0.29384166), (2, 0.2103884), (3, 0.31500015), (4, 0.18018329)]
# [(0, 0.16684587), (3, 0.82819545)]
# [(0, 0.23941307), (3, 0.5613708), (4, 0.19797002)]
# [(0, 0.51150995), (2, 0.47385588)]
# [(0, 0.15140544), (1, 0.0828598), (2, 0.10659118), (3, 0.54801273), (4, 0.111130856)]
# [(2, 0.21031852), (3, 0.6194336), (4, 0.16694215)]
# [(2, 0.17346106), (3, 0.8222836)]
# [(0, 0.21810108), (1, 0.089965716), (2, 0.15403341), (3, 0.53713346)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.9804878)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(1, 0.7765902), (4, 0.21746916)]
# [(0, 0.24938273), (2, 0.49629626), (3, 0.2493827)]
# [(1, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(0, 0.16694213), (2, 0.4975146), (4, 0.33223742)]
# [(0, 0.1922291), (2, 0.33279428), (3, 0.47331688)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.42032903), (2, 0.12551667), (3, 0.45194435)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.20764482), (3, 0.7903618)]
# [(0, 0.2941985), (1, 0.063402124), (3, 0.4962739), (4, 0.14575578)]
# [(1, 0.55780274), (3, 0.43847057)]
# [(3, 0.98688525)]
# [(0, 0.2493827), (1, 0.49629626), (2, 0.2493827)]
# [(0, 0.3322314), (2, 0.33223143), (3, 0.16694213), (4, 0.16694213)]
# [(1, 0.3322314), (2, 0.49752066), (3, 0.16694216)]
# [(0, 0.20893477), (1, 0.22846076), (2, 0.23676713), (3, 0.27468196), (4, 0.05115538)]
# [(2, 0.32421306), (3, 0.42146596), (4, 0.24938273)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.1432624), (1, 0.16787599), (2, 0.40233675), (4, 0.28510636)]
# [(0, 0.24938273), (1, 0.49629626), (2, 0.2493827)]
# [(2, 0.50673854), (3, 0.47862732)]
# [(2, 0.1432624), (3, 0.85248226)]
# [(1, 0.24966633), (2, 0.24970676), (3, 0.49814242)]
# [(1, 0.4975207), (3, 0.49752066)]
# [(0, 0.08563736), (1, 0.17967857), (2, 0.12183665), (3, 0.4805831), (4, 0.13226433)]
# [(1, 0.49628162), (2, 0.2493955), (3, 0.24938455)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(0, 0.49267113), (2, 0.49269468)]
# [(0, 0.22209944), (2, 0.19090182), (3, 0.46466917), (4, 0.12122465)]
# [(0, 0.15044409), (1, 0.10959864), (2, 0.39255077), (3, 0.23647286), (4, 0.11093363)]
# [(0, 0.16594762), (2, 0.40965775), (3, 0.42286208)]
# [(1, 0.1432624), (2, 0.1432624), (3, 0.42695045), (4, 0.2851063)]
# [(2, 0.26430625), (3, 0.45090613), (4, 0.28082722)]
# [(1, 0.2794143), (2, 0.3002861), (3, 0.41848966)]
# [(0, 0.3980198), (1, 0.19999999), (2, 0.20000002), (4, 0.19999999)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.1653894), (1, 0.10606591), (3, 0.62184), (4, 0.10579974)]
# [(0, 0.2493827), (1, 0.49629626), (4, 0.2493827)]
# [(3, 0.632166), (4, 0.36357865)]
# [(1, 0.46032906), (2, 0.41292575), (4, 0.12453522)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.46696475), (2, 0.36278728), (4, 0.16694213)]
# [(0, 0.31319728), (1, 0.16694215), (3, 0.33223143), (4, 0.18597625)]
# [(1, 0.98688525)]
# [(0, 0.19999492), (1, 0.051232737), (2, 0.13897529), (3, 0.40064627), (4, 0.20915076)]
# [(0, 0.3322314), (2, 0.16694213), (3, 0.49752066)]
# [(0, 0.09140271), (1, 0.23490648), (2, 0.15829466), (3, 0.42399344), (4, 0.09140271)]
# [(0, 0.2), (1, 0.2846187), (2, 0.21217807), (3, 0.1695771), (4, 0.13362609)]
# [(0, 0.19415422), (2, 0.24473351), (3, 0.44681194), (4, 0.11380153)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.2493827), (2, 0.49629626), (4, 0.2493827)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(0, 0.2493827), (2, 0.2493827), (3, 0.49629626)]
# [(1, 0.47448626), (3, 0.39753696), (4, 0.1254923)]
# [(0, 0.24858274), (4, 0.74400985)]
# [(2, 0.37146255), (3, 0.6187014)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.1432624), (1, 0.33639747), (3, 0.51750326)]
# [(0, 0.08381742), (1, 0.083817415), (2, 0.18173032), (3, 0.64980495)]
# [(2, 0.33114755), (4, 0.65901643)]
# [(0, 0.19689748), (1, 0.1955554), (2, 0.10545322), (3, 0.3674763), (4, 0.1346176)]
# [(4, 0.98688525)]
# [(2, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.2851064), (1, 0.22197638), (2, 0.14053522), (3, 0.3509636)]
# [(0, 0.054777805), (1, 0.36797902), (2, 0.053018373), (3, 0.29946324), (4, 0.22476159)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(2, 0.4687397), (4, 0.5253197)]
# [(0, 0.32678586), (1, 0.19092304), (3, 0.4011654), (4, 0.08035937)]
# [(0, 0.16694213), (2, 0.55818224), (3, 0.27156985)]
# [(1, 0.62842506), (2, 0.36416748)]
# [(3, 0.9804878)]
# [(0, 0.24938273), (3, 0.49629632), (4, 0.2493827)]
# [(1, 0.30322912), (2, 0.3322314), (3, 0.36123368)]
# [(3, 0.74320984), (4, 0.24938273)]
# [(1, 0.3220996), (2, 0.3325967), (3, 0.34309375)]
# [(0, 0.077394634), (1, 0.11319407), (3, 0.3933326), (4, 0.41531244)]
# [(0, 0.19999999), (1, 0.5960396), (2, 0.19999999)]
# [(0, 0.5987044), (1, 0.3026723), (3, 0.09681338)]
# [(2, 0.6628099), (4, 0.3322314)]
# [(0, 0.14501102), (1, 0.4206858), (2, 0.26098138), (3, 0.059685018), (4, 0.11363676)]
# [(1, 0.4919311), (4, 0.49343476)]
# [(1, 0.2137934), (2, 0.17133036), (3, 0.43903095), (4, 0.17460304)]
# [(2, 0.24938273), (3, 0.45308927), (4, 0.29258978)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.49629626), (1, 0.24938273), (4, 0.2493827)]
# [(0, 0.30850568), (1, 0.11551555), (2, 0.123175204), (3, 0.18559003), (4, 0.26721355)]
# [(0, 0.55283064), (3, 0.43733323)]
# [(3, 0.9804878)]
# [(1, 0.399005), (2, 0.36942708), (3, 0.13007541), (4, 0.10049751)]
# [(1, 0.19999999), (2, 0.19999999), (4, 0.59800994)]
# [(1, 0.4542002), (2, 0.3287309), (3, 0.21310845)]
# [(0, 0.49629626), (1, 0.2493827), (3, 0.2493827)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(3, 0.9804878)]
# [(0, 0.38553756), (1, 0.3572262), (2, 0.2543993)]
# [(1, 0.34186974), (2, 0.116257004), (3, 0.21559855), (4, 0.3253697)]
# [(0, 0.33114442), (3, 0.6590195)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.19999999), (1, 0.3980198), (2, 0.3980198)]
# [(2, 0.1630645), (3, 0.83268017)]
# [(3, 0.98688525)]
# [(0, 0.17627235), (1, 0.24210878), (2, 0.06565861), (3, 0.45672303), (4, 0.059237182)]
# [(0, 0.19775747), (1, 0.25558487), (2, 0.08357589), (3, 0.37463105), (4, 0.08845079)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(0, 0.320213), (1, 0.114821196), (2, 0.23366193), (3, 0.330474)]
# [(1, 0.14326242), (2, 0.2851064), (3, 0.5687943)]
# [(0, 0.2338449), (1, 0.18133835), (2, 0.16050762), (3, 0.3508981), (4, 0.07341104)]
# [(1, 0.33141607), (2, 0.6587479)]
# [(0, 0.17810084), (1, 0.17193705), (3, 0.56531525), (4, 0.083817005)]
# [(0, 0.33545583), (1, 0.19031034), (2, 0.47092807)]
# [(0, 0.2493827), (2, 0.24938273), (3, 0.49629632)]
# [(0, 0.050641254), (1, 0.114961445), (2, 0.2220869), (3, 0.5558737), (4, 0.056436688)]
# [(0, 0.2292689), (1, 0.15968266), (3, 0.6085639)]
# [(0, 0.18423128), (1, 0.12143327), (2, 0.17918685), (3, 0.2783549), (4, 0.23679368)]
# [(0, 0.16694215), (1, 0.16694215), (2, 0.21695128), (3, 0.28222227), (4, 0.16694215)]
# [(0, 0.65901345), (2, 0.33115047)]
# [(0, 0.16694213), (1, 0.3322314), (2, 0.16694213), (3, 0.16694213), (4, 0.16694213)]
# [(0, 0.124710195), (1, 0.18069014), (2, 0.11930143), (3, 0.5172923), (4, 0.058005977)]
# [(1, 0.09597845), (2, 0.42440057), (3, 0.47808844)]
# [(0, 0.23322958), (1, 0.18783441), (2, 0.13664728), (3, 0.20040041), (4, 0.2418883)]
# [(1, 0.9619048)]
# [(0, 0.43066004), (2, 0.35022235), (3, 0.21690768)]
# [(0, 0.19999999), (1, 0.19999999), (2, 0.37427375), (3, 0.22374606)]
# [(0, 0.24938273), (2, 0.41034552), (3, 0.33533347)]
# [(0, 0.16694213), (1, 0.3322314), (2, 0.16694213), (3, 0.16694216), (4, 0.16694213)]
# [(0, 0.19999999), (1, 0.19999999), (2, 0.10885307), (3, 0.4901519)]
# [(1, 0.16694213), (2, 0.49752066), (4, 0.3322314)]
# [(2, 0.643088), (4, 0.3526567)]
# [(1, 0.19999999), (2, 0.3980198), (3, 0.19999999), (4, 0.19999999)]
# [(0, 0.19999999), (2, 0.55782205), (3, 0.23821755)]
# [(0, 0.16089498), (3, 0.6909427), (4, 0.14617224)]
# [(0, 0.31214952), (1, 0.12523364), (3, 0.36144602), (4, 0.20054771)]
# [(0, 0.16781582), (2, 0.55467004), (3, 0.2742083)]
# [(0, 0.2), (3, 0.5265444), (4, 0.2694952)]
# [(0, 0.27901375), (1, 0.14935504), (2, 0.3206819), (3, 0.24953082)]
# [(1, 0.31214952), (2, 0.06873332), (3, 0.5555658), (4, 0.06292834)]
# [(0, 0.070114456), (1, 0.18725194), (2, 0.32460573), (3, 0.34887525), (4, 0.06915259)]
# [(1, 0.5114332), (2, 0.2993865), (3, 0.18587452)]
# [(0, 0.12546584), (1, 0.41616443), (3, 0.3316616), (4, 0.12546584)]
# [(2, 0.9619048)]
# [(0, 0.14948367), (1, 0.3146917), (2, 0.19659154), (3, 0.19438206), (4, 0.14485098)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.19999999), (3, 0.53786933), (4, 0.25817025)]
# [(3, 0.9804878)]
# [(1, 0.49629626), (2, 0.24938273), (3, 0.24938273)]
# [(3, 0.8708074), (4, 0.12546583)]
# [(0, 0.2873042), (2, 0.22136249), (3, 0.48849645)]
# [(1, 0.51293474), (2, 0.47243112)]
# [(0, 0.9619048)]
# [(2, 0.22180708), (3, 0.77225226)]
# [(1, 0.9804878)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(0, 0.3474957), (1, 0.3698809), (2, 0.10636753), (3, 0.10984506), (4, 0.06641075)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.20159589), (2, 0.5944437), (4, 0.19999999)]
# [(0, 0.49629545), (3, 0.49629715)]
# [(0, 0.37284836), (1, 0.6173156)]
# [(0, 0.5160651), (2, 0.47799426)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.657443), (4, 0.3351496)]
# [(3, 0.9804878)]
# [(0, 0.9804878)]
# [(3, 0.98688525)]
# [(0, 0.28510636), (3, 0.5577117), (4, 0.15434502)]
# [(1, 0.3605525), (2, 0.6344888)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(0, 0.33114755), (4, 0.6590164)]
# [(2, 0.24528229), (3, 0.7487771)]
# [(2, 0.65901643), (4, 0.33114755)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.10049751), (1, 0.21123755), (2, 0.3877674), (3, 0.18775664), (4, 0.112740874)]
# [(0, 0.40407714), (1, 0.1297257), (2, 0.33239797), (4, 0.13255693)]
# [(0, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.33553156), (2, 0.65463233)]
# [(1, 0.6223602), (3, 0.373913)]
# [(0, 0.24920224), (1, 0.2493827), (3, 0.24938273), (4, 0.24956316)]
# [(1, 0.42978808), (4, 0.56037587)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.14413336), (1, 0.17787471), (2, 0.24360088), (3, 0.3123871), (4, 0.12200399)]
# [(1, 0.41930783), (2, 0.5708561)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.41819084), (1, 0.56717503)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.44459268), (3, 0.54557127)]
# [(3, 0.9804878)]
# [(0, 0.19204639), (1, 0.16694213), (2, 0.16694213), (3, 0.4724164)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.59155893), (4, 0.40471438)]
# [(0, 0.49629626), (1, 0.2493827), (4, 0.2493827)]
# [(0, 0.41838866), (2, 0.39138135), (4, 0.1869242)]
# [(0, 0.3019375), (1, 0.22768411), (2, 0.23034753), (3, 0.13613658), (4, 0.103894345)]
# [(0, 0.9619048)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(2, 0.2493827), (3, 0.74320984)]
# [(0, 0.2493827), (1, 0.24938273), (2, 0.2493827), (3, 0.2493827)]
# [(0, 0.08394582), (1, 0.124589235), (3, 0.7002281), (4, 0.090470575)]
# [(0, 0.65901595), (3, 0.33114794)]
# [(0, 0.24938273), (1, 0.2493827), (3, 0.49629626)]
# [(3, 0.98688525)]
# [(1, 0.23153327), (2, 0.30286497), (3, 0.46276483)]
# [(1, 0.27239817), (2, 0.09899969), (3, 0.44579673), (4, 0.18190044)]
# [(0, 0.19999999), (2, 0.20000002), (3, 0.5960396)]
# [(1, 0.37884483), (3, 0.61619645)]
# [(0, 0.41823095), (1, 0.5671349)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(0, 0.115062326), (1, 0.1774833), (2, 0.23949574), (3, 0.46724692)]
# [(0, 0.094108276), (1, 0.3883816), (2, 0.18741958), (3, 0.21912192), (4, 0.11096856)]
# [(0, 0.65901595), (3, 0.33114797)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.24468467), (1, 0.46674877), (2, 0.1913757), (4, 0.09628587)]
# [(0, 0.11204971), (1, 0.36809173), (2, 0.26422012), (3, 0.25453344)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(3, 0.9804878)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.5914233), (4, 0.39874065)]
# [(1, 0.44467872), (3, 0.5454852)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(0, 0.45204026), (1, 0.29363844), (3, 0.24938306)]
# [(2, 0.99012345)]
# [(2, 0.3980198), (3, 0.37839073), (4, 0.21962903)]
# [(0, 0.19837257), (1, 0.36172873), (2, 0.27855104), (4, 0.16010542)]
# [(1, 0.628984), (2, 0.36117995)]
# [(0, 0.11526151), (1, 0.3447929), (3, 0.5385221)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(1, 0.43729442), (3, 0.54807144)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.41939256), (2, 0.57077134)]
# [(1, 0.3744233), (4, 0.61816925)]
# [(0, 0.19728991), (1, 0.069815345), (2, 0.46328953), (3, 0.26894072)]
# [(0, 0.3311475), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.3823331), (1, 0.2851064), (2, 0.16512276), (3, 0.16601934)]
# [(1, 0.41947654), (2, 0.57068735)]
# [(3, 0.9804878)]
# [(0, 0.1680535), (1, 0.18826745), (2, 0.29333457), (3, 0.3486916)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.11160221), (1, 0.5535912), (2, 0.11160221), (3, 0.22209944)]
# [(3, 0.9804878)]
# [(0, 0.42695037), (1, 0.21795043), (2, 0.17001407), (4, 0.1836667)]
# [(0, 0.3959199), (2, 0.14326316), (3, 0.27785435), (4, 0.18154415)]
# [(0, 0.3322314), (2, 0.16694213), (3, 0.49752066)]
# [(1, 0.48074797), (2, 0.26665995), (3, 0.24863164)]
# [(2, 0.49610806), (3, 0.4964845)]
# [(0, 0.3014507), (3, 0.43485487), (4, 0.26038867)]
# [(0, 0.2493827), (3, 0.74320984)]
# [(3, 0.9804878)]
# [(1, 0.64485765), (2, 0.34773496)]
# [(1, 0.64867836), (3, 0.345381)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.33114758), (2, 0.6590164)]
# [(0, 0.41215777), (2, 0.20436527), (3, 0.38017115)]
# [(1, 0.9804878)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.26747704), (1, 0.06996232), (2, 0.14752136), (3, 0.5143748)]
# [(0, 0.9619048)]
# [(0, 0.09171609), (1, 0.113125265), (2, 0.27795434), (3, 0.3589026), (4, 0.15830167)]
# [(0, 0.511626), (2, 0.47373992)]
# [(1, 0.2493827), (2, 0.24938273), (3, 0.2493827), (4, 0.2493827)]
# [(2, 0.2493827), (4, 0.74320984)]
# [(1, 0.27730736), (2, 0.30445066), (3, 0.29153392), (4, 0.12546584)]
# [(0, 0.44554496), (1, 0.16694213), (2, 0.19240674), (3, 0.19345322)]
# [(1, 0.55476785), (2, 0.43782473)]
# [(0, 0.10077422), (2, 0.45466703), (3, 0.44256875)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.32748866), (3, 0.29611376), (4, 0.37391302)]
# [(0, 0.24938273), (1, 0.35979044), (3, 0.38588855)]
# [(3, 0.99012345)]
# [(1, 0.98688525)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.33222896), (2, 0.16694364), (3, 0.49752158)]
# [(0, 0.2493827), (3, 0.4454107), (4, 0.30026826)]
# [(0, 0.23340473), (2, 0.11373229), (3, 0.6513304)]
# [(3, 0.2), (4, 0.7940594)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(0, 0.49629626), (2, 0.2493827), (3, 0.2493827)]
# [(0, 0.33114755), (1, 0.33114755), (2, 0.33114755)]
# [(0, 0.47688884), (1, 0.26016936), (3, 0.25318566)]
# [(3, 0.9619048)]
# [(1, 0.22523071), (2, 0.40195674), (3, 0.36885217)]
# [(0, 0.16791286), (2, 0.22773454), (3, 0.6015157)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.4269503), (4, 0.56879437)]
# [(3, 0.6628099), (4, 0.33223143)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(4, 0.9804878)]
# [(0, 0.3980198), (2, 0.3980198), (3, 0.19999999)]
# [(2, 0.74320984), (4, 0.2493827)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.4521374), (1, 0.5404552)]
# [(0, 0.20000002), (1, 0.27611765), (3, 0.29259938), (4, 0.22930276)]
# [(1, 0.4284709), (3, 0.48605195), (4, 0.08381742)]
# [(0, 0.22039142), (1, 0.27372715), (3, 0.5025756)]
# [(2, 0.9804878)]
# [(0, 0.14402615), (1, 0.49003804), (2, 0.36309898)]
# [(1, 0.56187195), (3, 0.42829195)]
# [(0, 0.3980198), (4, 0.5960396)]
# [(0, 0.49629626), (2, 0.2493827), (3, 0.2493827)]
# [(3, 0.98688525)]
# [(0, 0.42066488), (1, 0.1572582), (3, 0.41924003)]
# [(1, 0.22209944), (3, 0.77458566)]
# [(1, 0.37444213), (4, 0.6181504)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(0, 0.2493827), (1, 0.49629626), (3, 0.2493827)]
# [(0, 0.49629626), (1, 0.24938273), (3, 0.2493827)]
# [(2, 0.9804878)]
# [(0, 0.2493827), (3, 0.49629626), (4, 0.2493827)]
# [(2, 0.26581165), (3, 0.72824776)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(3, 0.9804878)]
# [(1, 0.5960396), (4, 0.3980198)]
# [(3, 0.9804878)]
# [(1, 0.6590139), (3, 0.33114997)]
# [(1, 0.4194375), (2, 0.57072645)]
# [(0, 0.24434711), (1, 0.13080814), (2, 0.24968943), (3, 0.12546584), (4, 0.24968943)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(0, 0.65901595), (3, 0.33114794)]
# [(1, 0.4475889), (2, 0.33224735), (3, 0.21685798)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(1, 0.39835742), (2, 0.26208612), (3, 0.165153), (4, 0.17396963)]
# [(1, 0.33114752), (2, 0.33089706), (3, 0.331398)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.29117548), (3, 0.7050978)]
# [(3, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(4, 0.98688525)]
# [(0, 0.9619048)]
# [(1, 0.44471624), (3, 0.5454477)]
# [(3, 0.9804878)]
# [(0, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.12606394), (1, 0.3340984), (2, 0.2004328), (3, 0.33816263)]
# [(2, 0.98688525)]
# [(0, 0.3355336), (2, 0.6546303)]
# [(0, 0.19999999), (2, 0.19999999), (3, 0.3980198), (4, 0.19999999)]
# [(0, 0.20202267), (1, 0.7920367)]
# [(0, 0.14407697), (1, 0.5680211), (2, 0.28506505)]
# [(3, 0.49629626), (4, 0.49629626)]
# [(1, 0.2493827), (2, 0.49629626), (3, 0.2493827)]
# [(0, 0.49629626), (1, 0.2493827), (4, 0.2493827)]
# [(0, 0.33226505), (2, 0.4901543), (3, 0.17427483)]
# [(3, 0.9804878)]
# [(0, 0.3307854), (1, 0.15597959), (2, 0.13421832), (3, 0.37791172)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.9804878)]
# [(2, 0.49268287), (4, 0.49268293)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1              1  ...                         [verifikasi, email, kesel]
# 2              2  ...                     [up, money, bilang, manajemen]
# 3              3  ...                                     [iklan, sebal]
# 4              4  ...                    [nonton, ngapa, kesini, melulu]
# ..           ...  ...                                                ...
# 995          995  ...                                  [barang, lengkap]
# 996          996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 997          997  ...                            [tingkat, promo, ehehe]
# 998          998  ...                                 [bags, barang, ny]
# 999          999  ...                             [pesan, cepat, sampai]
#
# [1000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    142
# 1.0    221
# 2.0    177
# 3.0    378
# 4.0     82
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_5topics_with_stemming_alpha_topics_eta_len_dictionary.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
