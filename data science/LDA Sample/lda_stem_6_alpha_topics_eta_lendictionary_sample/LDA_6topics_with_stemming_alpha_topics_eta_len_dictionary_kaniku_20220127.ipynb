# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install PySastrawi
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ## Passed

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %%
df_token
# Out:
#                                                 review  ...                                   review_processed
# 0    Pembelian pakai cc ribet, di tolak terus sama ...  ...              beli pakai cc ribet tolak sedia layan
# 1    Kenapa saya tidak bisa verifikasi email saya?!...  ...                             verifikasi email kesel
# 2    TOP UP GAK MASUK E MONEY DIBILANG MASUK, MANAJ...  ...                          up money bilang manajemen
# 3                               Iklan nya nyebelin anj  ...                                     iklan nyebelin
# 4                 Anj..gw mau nonton ngapa kesini mulu  ...                           nonton ngapa kesini mulu
# ..                                                 ...  ...                                                ...
# 995                      Semoga barang semakin lengkap  ...                                     barang lengkap
# 996  Belanja aman dan menyenangkan. Topup tanpa bia...  ...  belanja aman topup biaya admin harga murah jan...
# 997           sip tingkat kan trus aja promo nya ehehe  ...                                tingkat promo ehehe
# 998                                     bags barang ny  ...                                     bags barang ny
# 999                      Pesanan bagus cepat sampe nya  ...                                  pesan cepat sampe
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lemot', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lemot', 'buanget'],
#  ['habis',
#   'update',
#   'lemot',
#   'sihh',
#   'shoppenya',
#   'lemot',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lemot',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lemot'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lemot', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lemot', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lemot',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lemot',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lemot',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'malah',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'malah',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lemot', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lemot',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lemot'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lemot',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lemot',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
#   'kaya',
#   'keong',
# ...
#   'jasa',
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lemot', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lemot',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai']]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_alpha_topics_eta_lendictionary_6')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(0, 0.19914714), (2, 0.44429958), (4, 0.35230398)]
# [(2, 0.49029127), (3, 0.4902912)]
# [(2, 0.98768467)]
# [(4, 0.4902912), (5, 0.49029133)]
# [(2, 0.55130124), (5, 0.43884656)]
# [(0, 0.50915754), (2, 0.12505662), (3, 0.36247456)]
# [(0, 0.062527105), (1, 0.111295685), (2, 0.16666667), (3, 0.39380372), (4, 0.05592619), (5, 0.20978068)]
# [(1, 0.15689409), (2, 0.24561821), (3, 0.5937657)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(0, 0.16352904), (1, 0.2593164), (2, 0.20765036), (3, 0.081171945), (4, 0.28762102)]
# [(2, 0.19960475), (3, 0.39723322), (4, 0.39723322)]
# [(0, 0.34422302), (1, 0.42603934), (3, 0.22702517)]
# [(0, 0.37858945), (1, 0.16159287), (3, 0.38656017), (4, 0.07183499)]
# [(0, 0.45991284), (2, 0.5356721)]
# [(0, 0.09742044), (1, 0.30953977), (2, 0.5076335), (5, 0.08374794)]
# [(0, 0.0928089), (1, 0.04502269), (2, 0.12797979), (3, 0.56183666), (4, 0.14434305), (5, 0.028008915)]
# [(0, 0.25608587), (2, 0.24292009), (3, 0.49801192)]
# [(0, 0.47227478), (2, 0.16666669), (3, 0.35610804)]
# [(1, 0.14198826), (2, 0.5233391), (3, 0.33268064)]
# [(1, 0.1998672), (2, 0.5318725), (3, 0.26626825)]
# [(2, 0.14312014), (3, 0.31443077), (4, 0.17082845), (5, 0.36878777)]
# [(0, 0.26265365), (3, 0.7307457)]
# [(0, 0.49669966), (1, 0.16666667), (4, 0.33168316)]
# [(0, 0.2737622), (1, 0.31138608), (2, 0.22203767), (3, 0.13633569), (5, 0.055924695)]
# [(2, 0.8697271), (4, 0.12531018)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.20798676), (1, 0.12531018), (2, 0.24937966), (3, 0.41484207)]
# [(2, 0.46865004), (3, 0.19471627), (5, 0.33168316)]
# [(0, 0.5045235), (2, 0.25809377), (3, 0.15851556), (5, 0.07733578)]
# [(0, 0.61023045), (2, 0.19301857), (4, 0.1942634)]
# [(3, 0.26084325), (4, 0.72930455)]
# [(2, 0.6568285), (3, 0.33009952)]
# [(0, 0.34883222), (3, 0.36221594), (4, 0.28470254)]
# [(0, 0.22425768), (1, 0.2400627), (2, 0.14773704), (3, 0.11673981), (4, 0.21387213), (5, 0.05733061)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.16806348), (2, 0.45190945), (3, 0.1322959), (4, 0.24655886)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(5, 0.97572815)]
# [(0, 0.26250133), (2, 0.48169413), (4, 0.17039827), (5, 0.08374793)]
# [(0, 0.24511027), (2, 0.30959877), (3, 0.19960475), (4, 0.24173364)]
# [(0, 0.29984343), (1, 0.10039762), (2, 0.48283145), (3, 0.11493946)]
# [(3, 0.95283026)]
# [(3, 0.20490786), (4, 0.58955854), (5, 0.19960472)]
# [(0, 0.5433996), (2, 0.36256784), (4, 0.09132006)]
# [(0, 0.19937243), (1, 0.094976455), (2, 0.085361905), (3, 0.24994972), (4, 0.20367284), (5, 0.16666667)]
# [(0, 0.11147902), (2, 0.12665732), (3, 0.31705126), (5, 0.44260487)]
# [(0, 0.33168316), (1, 0.33168316), (5, 0.33168316)]
# [(0, 0.26829717), (2, 0.2418059), (3, 0.48564768)]
# [(0, 0.113614365), (1, 0.33222958), (4, 0.33009425), (5, 0.22185431)]
# [(0, 0.65686274), (4, 0.33006537)]
# [(1, 0.33006537), (2, 0.3300653), (5, 0.33006537)]
# [(1, 0.19960472), (2, 0.7924901)]
# [(3, 0.98366016)]
# [(1, 0.19969712), (3, 0.52872247), (4, 0.26565155)]
# [(0, 0.49012285), (3, 0.28695765), (4, 0.21553034)]
# [(2, 0.13359791), (3, 0.5743034), (4, 0.1643072), (5, 0.12531018)]
# [(3, 0.98366016)]
# [(2, 0.49029127), (4, 0.49029127)]
# [(0, 0.29691336), (2, 0.4595987), (3, 0.06587946), (4, 0.11781945), (5, 0.05920281)]
# [(0, 0.4430569), (2, 0.11147904), (3, 0.33177754), (5, 0.111479044)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(0, 0.19991079), (1, 0.283898), (2, 0.21510793), (3, 0.19969158), (4, 0.10039761)]
# [(2, 0.7924901), (4, 0.19960472)]
# [(1, 0.08965402), (2, 0.48566893), (4, 0.33154866), (5, 0.09132007)]
# [(1, 0.16666666), (2, 0.49669966), (3, 0.33168313)]
# [(0, 0.391959), (3, 0.19960472), (4, 0.20487891), (5, 0.19960475)]
# [(0, 0.20924908), (1, 0.117819466), (3, 0.059202816), (4, 0.35228607), (5, 0.26085642)]
# [(0, 0.19809067), (1, 0.30025914), (3, 0.33168316), (5, 0.16666667)]
# [(0, 0.09893696), (1, 0.17165202), (2, 0.1429803), (3, 0.22892028), (4, 0.27147663), (5, 0.08603383)]
# [(0, 0.16620074), (2, 0.14305949), (3, 0.11991825), (4, 0.5679887)]
# [(2, 0.49649367), (4, 0.33188918), (5, 0.16666667)]
# [(0, 0.39723322), (2, 0.5948617)]
# [(2, 0.74137926), (5, 0.24876848)]
# [(0, 0.306243), (1, 0.074708335), (2, 0.13484459), (3, 0.20191406), (4, 0.24496554), (5, 0.037324462)]
# [(1, 0.24958539), (2, 0.57091486), (3, 0.09360853), (4, 0.08423286)]
# [(0, 0.98366016)]
# [(0, 0.40184477), (2, 0.41370678), (3, 0.091320075), (4, 0.09132007)]
# [(0, 0.2635999), (2, 0.16733678), (3, 0.36232314), (4, 0.13958135), (5, 0.066536136)]
# [(2, 0.19362439), (3, 0.45724443), (4, 0.3464187)]
# [(1, 0.11147904), (2, 0.3205985), (3, 0.56461126)]
# [(0, 0.28487182), (3, 0.70852757)]
# [(0, 0.36811686), (2, 0.34741735), (4, 0.28115448)]
# [(0, 0.64988387), (1, 0.0980432), (4, 0.24958542)]
# [(1, 0.33006537), (2, 0.33006537), (5, 0.33006537)]
# [(0, 0.26750293), (1, 0.15038684), (3, 0.144175), (4, 0.18762077), (5, 0.24969175)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(0, 0.95283026)]
# [(2, 0.3971776), (3, 0.3972888), (5, 0.19960475)]
# [(1, 0.16666667), (2, 0.49669966), (3, 0.33168316)]
# [(0, 0.49507388), (2, 0.49507383)]
# [(0, 0.98366016)]
# [(0, 0.18375589), (1, 0.14643975), (2, 0.2088434), (3, 0.17848663), (4, 0.1953104), (5, 0.08716392)]
# [(0, 0.17002687), (2, 0.22875041), (3, 0.33168498), (4, 0.26623744)]
# [(0, 0.06998537), (1, 0.19597991), (2, 0.20962703), (3, 0.41681224), (4, 0.107318126)]
# [(2, 0.97572815)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(0, 0.98366016)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(3, 0.95283026)]
# [(0, 0.6109024), (1, 0.37924537)]
# [(0, 0.28520626), (1, 0.07183499), (2, 0.4985775), (4, 0.14295875)]
# [(0, 0.08281619), (1, 0.17991684), (2, 0.4561193), (3, 0.09790427), (4, 0.10303591), (5, 0.080207504)]
# [(0, 0.6611628), (4, 0.2381948), (5, 0.09792994)]
# [(1, 0.33168316), (2, 0.16666667), (3, 0.20884863), (4, 0.28950122)]
# [(0, 0.31550953), (3, 0.07183499), (4, 0.25490296), (5, 0.35633004)]
# [(2, 0.95283026)]
# [(0, 0.34646544), (2, 0.18173598), (3, 0.28521958), (4, 0.18477066)]
# [(4, 0.98366016)]
# [(0, 0.15560232), (3, 0.11745374), (4, 0.7242314)]
# [(0, 0.6568628), (4, 0.33006534)]
# [(0, 0.24281204), (4, 0.7473357)]
# [(0, 0.4902912), (4, 0.49029127)]
# [(0, 0.35850993), (1, 0.09132007), (2, 0.09132007), (3, 0.10208625), (4, 0.35585952)]
# [(1, 0.11357794), (2, 0.3246308), (3, 0.3499371), (4, 0.2107467)]
# [(4, 0.95283026)]
# [(0, 0.47352526), (1, 0.24876848), (3, 0.2703171)]
# [(1, 0.19960475), (4, 0.79249007)]
# [(0, 0.18644914), (1, 0.47691718), (4, 0.33168316)]
# [(0, 0.6709559), (4, 0.325068)]
# [(4, 0.4902912), (5, 0.49029127)]
# [(0, 0.2024004), (1, 0.36274794), (2, 0.15703738), (4, 0.15126337), (5, 0.12531017)]
# [(1, 0.31382373), (2, 0.3506354), (3, 0.33222958)]
# [(2, 0.4931765), (3, 0.09578246), (4, 0.4085535)]
# [(3, 0.59372497), (4, 0.20072903), (5, 0.19961716)]
# [(0, 0.083747916), (1, 0.33250412), (2, 0.4154014), (4, 0.083769426), (5, 0.083747916)]
# [(4, 0.81316733), (5, 0.18023199)]
# [(1, 0.33250415), (2, 0.49412265), (4, 0.17088567)]
# [(1, 0.12531017), (2, 0.14464922), (3, 0.24937963), (4, 0.4781795)]
# [(2, 0.95283026)]
# [(2, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(0, 0.39723322), (2, 0.39723322), (3, 0.19960475)]
# [(0, 0.98366016)]
# [(0, 0.16725247), (3, 0.66113037), (5, 0.16666667)]
# [(0, 0.10739539), (2, 0.29875183), (3, 0.3931534), (4, 0.19945402)]
# [(4, 0.97572815)]
# [(1, 0.33006537), (2, 0.33006537), (4, 0.3300653)]
# [(1, 0.16666666), (2, 0.22203763), (3, 0.6096346)]
# [(0, 0.24968866), (1, 0.06288916), (2, 0.29101637), (4, 0.33289394), (5, 0.062889166)]
# [(0, 0.12870768), (2, 0.31021047), (3, 0.17091487), (4, 0.26823226), (5, 0.121105544)]
# [(0, 0.39723322), (1, 0.19960475), (4, 0.39723322)]
# [(0, 0.24876848), (2, 0.24876848), (4, 0.49507388)]
# [(3, 0.37955815), (4, 0.60736996)]
# [(0, 0.24877466), (3, 0.4950677), (5, 0.24876848)]
# [(0, 0.39723322), (4, 0.19960475), (5, 0.39723322)]
# [(0, 0.3972339), (2, 0.19960406), (4, 0.39723322)]
# [(1, 0.98366016)]
# [(0, 0.46499625), (1, 0.22013679), (2, 0.15639827), (4, 0.15563585)]
# [(0, 0.2759435), (1, 0.05978574), (2, 0.2345359), (3, 0.2552868), (4, 0.08132186), (5, 0.09312624)]
# [(0, 0.14932266), (2, 0.34943664), (4, 0.24937963), (5, 0.24937963)]
# [(0, 0.4099568), (2, 0.42634562), (4, 0.1594483)]
# [(2, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(0, 0.5687445), (3, 0.17717466), (4, 0.09510707), (5, 0.15792449)]
# [(0, 0.24166471), (2, 0.13302508), (4, 0.6215881)]
# [(0, 0.43134534), (2, 0.3359741), (3, 0.079574734), (4, 0.11675501), (5, 0.035994392)]
# [(2, 0.33006537), (4, 0.33006534), (5, 0.33006534)]
# [(0, 0.24937966), (2, 0.37344912), (3, 0.24937966), (4, 0.12531018)]
# [(0, 0.13958007), (1, 0.14305949), (2, 0.14653891), (3, 0.28470254), (5, 0.28470254)]
# [(5, 0.98768467)]
# [(0, 0.26779926), (1, 0.14305949), (2, 0.15684444), (3, 0.14617784), (4, 0.28470254)]
# [(1, 0.28468806), (3, 0.42636007), (4, 0.28470254)]
# [(2, 0.12912957), (3, 0.42495427), (5, 0.44260487)]
# [(0, 0.33134738), (2, 0.07628399), (3, 0.31410483), (4, 0.2768413)]
# [(0, 0.24876848), (3, 0.24876848), (4, 0.49507388)]
# [(0, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(0, 0.3501523), (1, 0.10830826), (2, 0.03314746), (3, 0.38031846), (4, 0.12777106)]
# [(2, 0.97572815)]
# [(0, 0.24876848), (2, 0.24876848), (3, 0.49507388)]
# [(0, 0.39926502), (2, 0.28943712), (3, 0.12775357), (4, 0.09132007), (5, 0.091320075)]
# [(0, 0.1388169), (1, 0.14709336), (2, 0.24296723), (3, 0.24447407), (4, 0.16098037), (5, 0.065668054)]
# [(0, 0.17338245), (1, 0.30989042), (2, 0.15424344), (3, 0.18256463), (4, 0.09617116), (5, 0.08374793)]
# [(1, 0.39723322), (2, 0.39723322), (4, 0.19960476)]
# [(0, 0.4932472), (1, 0.21440244), (2, 0.069019414), (3, 0.09512284), (4, 0.12758546)]
# [(0, 0.23349887), (2, 0.23676462), (3, 0.31499705), (4, 0.21363199)]
# [(2, 0.97572815)]
# [(0, 0.10900091), (1, 0.03302969), (2, 0.34201223), (3, 0.34511092), (4, 0.13832854), (5, 0.032517705)]
# [(0, 0.45595974), (2, 0.24958539), (3, 0.16185872), (4, 0.13093773)]
# [(1, 0.16666667), (2, 0.49669966), (3, 0.16666667), (5, 0.16666667)]
# [(0, 0.3300653), (3, 0.33006537), (5, 0.33006537)]
# [(0, 0.4263345), (1, 0.14943516), (3, 0.12099957), (4, 0.102435544), (5, 0.19980118)]
# [(2, 0.35061604), (3, 0.50207514), (5, 0.14305949)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.49128273), (3, 0.16666667), (4, 0.1720836), (5, 0.16666667)]
# [(0, 0.44830653), (2, 0.18640772), (4, 0.3625733)]
# [(0, 0.5942234), (4, 0.39787146)]
# [(0, 0.4902919), (2, 0.49029064)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(2, 0.16491476), (3, 0.5974155), (4, 0.2346876)]
# [(0, 0.19986717), (2, 0.33266932), (3, 0.1998672), (4, 0.26626825)]
# [(1, 0.24876848), (2, 0.2484966), (4, 0.4953458)]
# [(3, 0.37967852), (4, 0.6072496)]
# [(0, 0.11279141), (2, 0.36351985), (3, 0.06926009), (4, 0.45318338)]
# [(0, 0.4664656), (2, 0.2281394), (4, 0.14655611), (5, 0.15635756)]
# [(0, 0.4554656), (3, 0.5379337)]
# [(0, 0.49669966), (5, 0.49669966)]
# [(1, 0.39561257), (3, 0.3528189), (5, 0.24970047)]
# [(0, 0.33006537), (2, 0.3300653), (5, 0.33006537)]
# [(2, 0.29331353), (4, 0.21798614), (5, 0.4849782)]
# [(3, 0.97572815)]
# [(2, 0.37344912), (3, 0.37344912), (5, 0.24937963)]
# [(0, 0.23046958), (2, 0.33706713), (3, 0.16730039), (4, 0.2260224), (5, 0.038756713)]
# [(3, 0.98366016)]
# [(0, 0.3273004), (2, 0.33168316), (4, 0.17104942), (5, 0.16666667)]
# [(2, 0.5812604), (4, 0.24958539), (5, 0.16666666)]
# [(0, 0.2331178), (1, 0.2721519), (2, 0.4016019), (5, 0.09132007)]
# [(0, 0.090747), (1, 0.24966879), (3, 0.31197503), (4, 0.3463638)]
# [(0, 0.38243923), (3, 0.41202712), (5, 0.19960475)]
# [(1, 0.24876848), (2, 0.24876848), (3, 0.49507388)]
# [(1, 0.16666666), (2, 0.66171616), (3, 0.16666666)]
# [(0, 0.23953561), (2, 0.22603542), (3, 0.47739682), (5, 0.05592469)]
# [(3, 0.33006537), (4, 0.6568627)]
# [(2, 0.7606395), (4, 0.23369479)]
# [(0, 0.49029127), (3, 0.4902912)]
# [(0, 0.12531017), (2, 0.16355945), (3, 0.12887037), (4, 0.5797786)]
# [(0, 0.97572815)]
# [(0, 0.19960475), (3, 0.39723322), (5, 0.39723322)]
# [(0, 0.24876848), (3, 0.24876848), (4, 0.49507383)]
# [(0, 0.59390426), (2, 0.12590232), (4, 0.27748096)]
# [(2, 0.24876845), (3, 0.49507388), (5, 0.24876845)]
# [(0, 0.19150545), (2, 0.28055498), (3, 0.52201074)]
# [(2, 0.3798067), (3, 0.1507), (4, 0.31405687), (5, 0.15390503)]
# [(1, 0.14326468), (2, 0.13907757), (3, 0.31355086), (4, 0.4024485)]
# [(0, 0.41718313), (2, 0.37344915), (3, 0.20564559)]
# [(0, 0.33006537), (1, 0.33006537), (3, 0.33006537)]
# [(0, 0.16666667), (1, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.33168316)]
# [(2, 0.1996047), (3, 0.7924901)]
# [(0, 0.24757302), (2, 0.559004), (3, 0.10801666), (5, 0.08374793)]
# [(1, 0.12531018), (2, 0.13012075), (3, 0.45439675), (4, 0.28769097)]
# [(2, 0.3166323), (3, 0.34230986), (4, 0.33680856)]
# [(0, 0.11147904), (1, 0.22185431), (2, 0.22185431), (4, 0.44260487)]
# [(0, 0.14305949), (2, 0.14305949), (3, 0.14305949), (4, 0.28470254), (5, 0.28470254)]
# [(0, 0.3283088), (2, 0.33006537), (4, 0.33182195)]
# [(2, 0.18726608), (3, 0.5407725), (4, 0.2686501)]
# [(0, 0.33024868), (2, 0.16635768), (4, 0.49844316)]
# [(0, 0.23080167), (2, 0.39718315), (3, 0.36608627)]
# [(2, 0.7104427), (4, 0.14224848), (5, 0.14305948)]
# [(0, 0.11289071), (1, 0.12526526), (2, 0.29792422), (3, 0.15465502), (4, 0.30879)]
# [(2, 0.49029127), (4, 0.4902912)]
# [(0, 0.06441328), (2, 0.6760715), (3, 0.14719325), (4, 0.11121451)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(3, 0.19960475), (4, 0.39723322), (5, 0.39723322)]
# [(2, 0.4976799), (3, 0.4957194)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(2, 0.49507388), (3, 0.49507388)]
# [(0, 0.45237973), (2, 0.2914626), (4, 0.24876848)]
# [(0, 0.49029127), (2, 0.4902912)]
# [(1, 0.091320075), (2, 0.45298374), (4, 0.45298374)]
# [(0, 0.16666667), (2, 0.33168316), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.3300653), (5, 0.65686274)]
# [(0, 0.05128587), (1, 0.22933504), (2, 0.09356705), (3, 0.36991566), (4, 0.25544307)]
# [(0, 0.5355862), (1, 0.11147904), (3, 0.2218543), (4, 0.128873)]
# [(0, 0.24123524), (1, 0.07183499), (2, 0.2140825), (3, 0.47142482)]
# [(3, 0.98366016)]
# [(0, 0.49128264), (3, 0.33168313), (4, 0.17208368)]
# [(0, 0.42634562), (2, 0.28470254), (3, 0.14305949), (4, 0.14305949)]
# [(0, 0.36137214), (2, 0.43309423), (5, 0.19960475)]
# [(0, 0.12531017), (2, 0.6215762), (3, 0.24939153)]
# [(0, 0.24493852), (2, 0.19991085), (3, 0.5492218)]
# [(0, 0.42017904), (1, 0.16585295), (2, 0.16932373), (3, 0.24331626)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(0, 0.18340237), (2, 0.8109319)]
# [(0, 0.32964557), (1, 0.2218543), (3, 0.33304983), (4, 0.11324278)]
# [(3, 0.98366016)]
# [(3, 0.98366016)]
# [(2, 0.49507388), (3, 0.49507388)]
# [(3, 0.575925), (4, 0.21854144), (5, 0.19960472)]
# [(1, 0.18755032), (2, 0.32884735), (3, 0.3614558), (5, 0.120158456)]
# [(0, 0.17337175), (1, 0.04197839), (2, 0.2663437), (3, 0.309341), (4, 0.08386121), (5, 0.12510392)]
# [(0, 0.2959389), (2, 0.49801192), (4, 0.10366344), (5, 0.10039761)]
# [(0, 0.4455874), (1, 0.29495203), (2, 0.09944442), (3, 0.15848473)]
# [(0, 0.25948274), (1, 0.14297736), (3, 0.5954062)]
# [(0, 0.16666667), (1, 0.2922646), (2, 0.2060773), (3, 0.16667461), (4, 0.16666667)]
# [(0, 0.33006534), (3, 0.33006534), (4, 0.33006537)]
# [(3, 0.95283026)]
# [(2, 0.77373075), (5, 0.2218543)]
# [(0, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(2, 0.98366016)]
# [(0, 0.6352781), (2, 0.19310473), (5, 0.16666667)]
# [(2, 0.33168316), (3, 0.49669966), (5, 0.16666667)]
# [(0, 0.14456981), (2, 0.23019405), (3, 0.3968), (4, 0.22595467)]
# [(0, 0.4902912), (4, 0.49029127)]
# [(0, 0.361874), (1, 0.25574768), (2, 0.22259374), (4, 0.08344075), (5, 0.07567984)]
# [(0, 0.15664022), (2, 0.38022223), (3, 0.45941547)]
# [(0, 0.49507388), (5, 0.49507388)]
# [(1, 0.39723322), (2, 0.5948617)]
# [(0, 0.21354814), (2, 0.2767605), (3, 0.37331125), (4, 0.079901285), (5, 0.055925086)]
# [(0, 0.19996251), (1, 0.39723322), (3, 0.199247), (5, 0.19960475)]
# [(0, 0.44052926), (1, 0.06706507), (3, 0.06717505), (4, 0.35750157), (5, 0.06706507)]
# [(0, 0.25441295), (1, 0.16453472), (2, 0.06583476), (3, 0.13626142), (4, 0.16849902), (5, 0.21045716)]
# [(0, 0.24876845), (1, 0.24876845), (2, 0.49507388)]
# [(0, 0.26280573), (2, 0.32805645), (4, 0.3067521), (5, 0.10039761)]
# [(0, 0.18216468), (1, 0.37344915), (2, 0.44066402)]
# [(0, 0.2877979), (1, 0.10039761), (2, 0.3936465), (3, 0.116766326), (4, 0.10039761)]
# [(0, 0.1463692), (1, 0.15004984), (2, 0.14106965), (3, 0.19508784), (4, 0.20388298), (5, 0.16354045)]
# [(0, 0.63755375), (1, 0.2140825), (4, 0.07510625), (5, 0.07183499)]
# [(1, 0.176148), (2, 0.42081338), (4, 0.1875336), (5, 0.2140825)]
# [(0, 0.1930849), (1, 0.08021417), (3, 0.39677432), (4, 0.24931952), (5, 0.080208056)]
# [(2, 0.393501), (3, 0.35633), (4, 0.17691152), (5, 0.071835)]
# [(3, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(2, 0.16666667), (3, 0.49669966), (4, 0.33168316)]
# [(1, 0.39723322), (2, 0.19976518), (3, 0.23223035), (4, 0.1668187)]
# [(0, 0.2154792), (2, 0.33222955), (3, 0.11167106), (4, 0.11766209), (5, 0.2218543)]
# [(1, 0.39509523), (2, 0.36756575), (3, 0.2330897)]
# [(0, 0.24876848), (3, 0.7413793)]
# [(0, 0.14305949), (2, 0.42634562), (3, 0.14305949), (4, 0.14305949), (5, 0.14305949)]
# [(0, 0.11882312), (1, 0.23721346), (2, 0.12915139), (3, 0.33376518), (4, 0.1800528)]
# [(0, 0.30689391), (3, 0.6832539)]
# [(0, 0.8512748), (2, 0.14305948)]
# [(0, 0.33491176), (1, 0.061040502), (2, 0.08015518), (3, 0.30619955), (4, 0.1738942), (5, 0.043798786)]
# [(0, 0.3422036), (1, 0.14485346), (2, 0.08805142), (3, 0.30907783), (4, 0.1151497)]
# [(0, 0.19499093), (1, 0.05920281), (2, 0.16550401), (3, 0.34119028), (4, 0.17990921), (5, 0.05920281)]
# [(0, 0.13273896), (1, 0.07841806), (2, 0.37769866), (3, 0.35466534), (5, 0.055925284)]
# [(1, 0.3972209), (3, 0.39724547), (5, 0.19960472)]
# [(0, 0.4902809), (1, 0.3041855), (4, 0.19960475)]
# [(2, 0.14305949), (3, 0.42634562), (4, 0.28470254), (5, 0.14305949)]
# [(0, 0.38072887), (2, 0.15392913), (3, 0.07936434), (4, 0.23130691), (5, 0.15390505)]
# [(0, 0.39860836), (1, 0.19979867), (3, 0.1066333), (4, 0.29297167)]
# [(1, 0.49507383), (3, 0.49507388)]
# [(1, 0.09733994), (2, 0.4739388), (4, 0.34052676), (5, 0.08694914)]
# [(0, 0.12531017), (1, 0.12531017), (2, 0.4975186), (4, 0.24937963)]
# [(0, 0.23809962), (1, 0.104491815), (2, 0.20945972), (4, 0.3465562), (5, 0.10039865)]
# [(1, 0.11147904), (2, 0.11147902), (3, 0.11147904), (4, 0.28571734), (5, 0.37874183)]
# [(0, 0.08374792), (2, 0.08374793), (3, 0.16666666), (4, 0.49834162), (5, 0.16666666)]
# [(0, 0.111779645), (2, 0.40531692), (3, 0.389775), (5, 0.09132006)]
# [(2, 0.7413793), (3, 0.24876848)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.33168316)]
# [(0, 0.2610402), (1, 0.17104624), (2, 0.091320075), (4, 0.47478515)]
# [(0, 0.33006537), (4, 0.65686274)]
# [(1, 0.17934327), (2, 0.17352714), (3, 0.11782124), (4, 0.528136)]
# [(1, 0.4902912), (5, 0.49029127)]
# [(3, 0.7399779), (4, 0.25016987)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.95283026)]
# [(0, 0.1763999), (1, 0.16646546), (2, 0.18783668), (3, 0.39675018), (5, 0.07183654)]
# [(0, 0.4383241), (2, 0.11575978), (3, 0.2218543), (4, 0.2218543)]
# [(0, 0.3132116), (1, 0.03436732), (2, 0.34280828), (3, 0.078946166), (4, 0.16289477), (5, 0.06777185)]
# [(0, 0.43789425), (1, 0.07733537), (3, 0.18698768), (4, 0.21968067), (5, 0.07733628)]
# [(0, 0.13853644), (1, 0.16666667), (2, 0.35599488), (3, 0.09131841), (4, 0.24706797)]
# [(0, 0.24588047), (3, 0.1288093), (4, 0.6215881)]
# [(2, 0.5111621), (5, 0.4789857)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(2, 0.16666666), (3, 0.45011255), (4, 0.29781446), (5, 0.08374792)]
# [(0, 0.37344915), (2, 0.4975186), (4, 0.12531017)]
# [(0, 0.24876845), (1, 0.49507388), (4, 0.24876845)]
# [(0, 0.35050327), (1, 0.11397769), (3, 0.13387717), (4, 0.36654198), (5, 0.03475579)]
# [(0, 0.20682964), (1, 0.060798544), (2, 0.26789775), (3, 0.13114071), (4, 0.2725348), (5, 0.060798552)]
# [(0, 0.19917165), (1, 0.07183499), (2, 0.14295875), (3, 0.15786959), (4, 0.07183499), (5, 0.35633007)]
# [(0, 0.34708825), (2, 0.13117424), (3, 0.21416815), (4, 0.30650896)]
# [(0, 0.079044335), (1, 0.30799827), (2, 0.06788385), (4, 0.33266652), (5, 0.21174304)]
# [(0, 0.3973072), (2, 0.33294725), (3, 0.122068845), (4, 0.06309964), (5, 0.08374793)]
# [(0, 0.16673428), (1, 0.33166268), (3, 0.33163607), (4, 0.16666667)]
# [(0, 0.3322165), (1, 0.2724054), (3, 0.11059332), (4, 0.19256057), (5, 0.09132007)]
# [(0, 0.22778955), (1, 0.24958539), (2, 0.43563947), (4, 0.0853272)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(0, 0.15640628), (1, 0.10019941), (2, 0.1069574), (3, 0.31866938), (4, 0.317269)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(2, 0.39723322), (3, 0.19960475), (4, 0.39723322)]
# [(0, 0.24876845), (2, 0.24876845), (3, 0.49507388)]
# [(0, 0.16666667), (2, 0.33168316), (4, 0.49669966)]
# [(0, 0.33006537), (3, 0.65686274)]
# [(2, 0.39723322), (4, 0.39723322), (5, 0.19960475)]
# [(2, 0.37344915), (3, 0.2759297), (4, 0.22282958), (5, 0.12531017)]
# [(0, 0.3702822), (1, 0.27677003), (2, 0.34996566)]
# [(1, 0.44458732), (2, 0.16666667), (3, 0.38379553)]
# [(2, 0.49507388), (3, 0.49507388)]
# [(0, 0.33209556), (1, 0.22185431), (2, 0.22185431), (4, 0.11161156), (5, 0.111480504)]
# [(0, 0.14684054), (2, 0.50668836), (4, 0.13227302), (5, 0.21171664)]
# [(0, 0.10479124), (1, 0.22179152), (2, 0.19831121), (3, 0.09770983), (4, 0.28681883), (5, 0.09057734)]
# [(2, 0.95283026)]
# [(3, 0.97572815)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(3, 0.32353598), (4, 0.66661173)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.97572815)]
# [(0, 0.09629611), (1, 0.13393156), (2, 0.44317505), (3, 0.1229882), (4, 0.20327641)]
# [(0, 0.30064777), (1, 0.12406573), (2, 0.06611885), (4, 0.47147363), (5, 0.037324466)]
# [(2, 0.12531017), (3, 0.3734491), (4, 0.4975186)]
# [(0, 0.18466258), (2, 0.29688013), (3, 0.37256268), (4, 0.14306174)]
# [(0, 0.49507388), (1, 0.49507388)]
# [(0, 0.12704265), (1, 0.052988514), (2, 0.3365445), (3, 0.23692346), (4, 0.24597618)]
# [(0, 0.74137926), (3, 0.24876845)]
# [(1, 0.33006534), (3, 0.6568628)]
# [(0, 0.30856577), (1, 0.12016664), (2, 0.091320075), (3, 0.116475575), (4, 0.3625678)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(2, 0.62603456), (4, 0.3682997)]
# [(0, 0.97572815)]
# [(0, 0.14638849), (1, 0.19986717), (2, 0.25334588), (3, 0.2662683), (5, 0.13346612)]
# [(2, 0.49507388), (3, 0.24876848), (4, 0.24876848)]
# [(1, 0.15880847), (2, 0.39369807), (3, 0.24976778), (4, 0.19677599)]
# [(0, 0.47566816), (2, 0.34000432), (4, 0.181615)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(0, 0.40581733), (4, 0.587582)]
# [(2, 0.4263456), (4, 0.28470254), (5, 0.28470257)]
# [(0, 0.3033359), (1, 0.11147902), (3, 0.4714973), (5, 0.111480236)]
# [(2, 0.29107603), (3, 0.5397697), (4, 0.16666666)]
# [(0, 0.1098718), (1, 0.20956545), (2, 0.16741812), (3, 0.2941461), (4, 0.2180045)]
# [(0, 0.39239952), (1, 0.045112018), (2, 0.08737232), (3, 0.1606222), (4, 0.23428643), (5, 0.0802075)]
# [(0, 0.17559868), (2, 0.34883317), (3, 0.3678153), (5, 0.105764754)]
# [(0, 0.31592497), (1, 0.14926228), (2, 0.05953993), (3, 0.29793122), (4, 0.09017737), (5, 0.08716425)]
# [(1, 0.49507388), (2, 0.49507383)]
# [(0, 0.70503926), (3, 0.2851085)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(0, 0.29234794), (1, 0.16044454), (2, 0.13346612), (3, 0.14680912), (5, 0.26626825)]
# [(0, 0.17294426), (1, 0.11325642), (2, 0.14069939), (3, 0.25330546), (4, 0.31902876)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.24110186), (1, 0.22627409), (2, 0.062889166), (3, 0.09094936), (4, 0.12909688), (5, 0.24968868)]
# [(0, 0.23047738), (3, 0.41629612), (4, 0.26637787), (5, 0.085317224)]
# [(0, 0.27347815), (1, 0.069167234), (2, 0.11185745), (3, 0.37228337), (4, 0.10732155), (5, 0.06589221)]
# [(0, 0.082696915), (1, 0.20521012), (2, 0.50852185), (3, 0.09132018), (4, 0.111346774)]
# [(2, 0.37344912), (3, 0.6215881)]
# [(0, 0.050784964), (2, 0.046385717), (3, 0.3348742), (4, 0.4314544), (5, 0.1360671)]
# [(0, 0.35519212), (3, 0.38865024), (4, 0.24876848)]
# [(0, 0.2218543), (1, 0.11147902), (2, 0.33222955), (3, 0.2218543), (5, 0.11147904)]
# [(0, 0.34365994), (1, 0.23505272), (3, 0.13366967), (4, 0.2864453)]
# [(0, 0.16666667), (2, 0.33168316), (3, 0.49669966)]
# [(0, 0.54111564), (2, 0.14609505), (3, 0.2387326), (4, 0.07263426)]
# [(0, 0.3300653), (3, 0.33006537), (5, 0.33006537)]
# [(0, 0.37476525), (3, 0.5104444), (4, 0.11147902)]
# [(0, 0.40943953), (1, 0.2539268), (2, 0.16666667), (4, 0.16666667)]
# [(2, 0.79249007), (3, 0.19960475)]
# [(0, 0.25398976), (2, 0.102774255), (3, 0.24263209), (4, 0.3986158)]
# [(2, 0.33006534), (3, 0.6568628)]
# [(0, 0.16631328), (1, 0.46018377), (2, 0.15876576), (3, 0.21320583)]
# [(0, 0.34903768), (2, 0.2853559), (3, 0.3613571)]
# [(0, 0.23690514), (1, 0.11147904), (2, 0.11227862), (5, 0.53712964)]
# [(0, 0.22703269), (2, 0.39579606), (3, 0.24937963), (4, 0.12531017)]
# [(0, 0.102843136), (2, 0.19771895), (3, 0.30197704), (4, 0.1471496), (5, 0.24968866)]
# [(4, 0.95283026)]
# [(3, 0.4902912), (4, 0.49029127)]
# [(0, 0.069765195), (1, 0.30161074), (2, 0.280863), (3, 0.09676891), (4, 0.25036952)]
# [(0, 0.1037754), (1, 0.091320075), (2, 0.20934612), (3, 0.19509795), (4, 0.3995563)]
# [(0, 0.28137928), (1, 0.043798782), (2, 0.22354586), (3, 0.3152479), (4, 0.048864245), (5, 0.08716392)]
# [(0, 0.3313561), (1, 0.49669966), (4, 0.1669937)]
# [(3, 0.66171616), (4, 0.33168316)]
# [(0, 0.6571915), (3, 0.33295634)]
# [(1, 0.13769682), (2, 0.2738285), (3, 0.30241084), (4, 0.20910625), (5, 0.07637141)]
# [(0, 0.6648517), (3, 0.32529604)]
# [(1, 0.21965583), (2, 0.25358227), (3, 0.10546075), (4, 0.42025182)]
# [(0, 0.49507388), (2, 0.24876848), (3, 0.24876848)]
# [(2, 0.4902912), (4, 0.49029127)]
# [(0, 0.073582396), (1, 0.09282716), (2, 0.6900402), (4, 0.071004055), (5, 0.071835)]
# [(2, 0.49507388), (3, 0.24876848), (5, 0.24876851)]
# [(1, 0.49669966), (3, 0.33168316), (4, 0.16666667)]
# [(0, 0.1798278), (1, 0.1998012), (2, 0.120367154), (3, 0.20677942), (4, 0.29223043)]
# [(2, 0.29367268), (3, 0.7019123)]
# [(0, 0.37344912), (1, 0.24937963), (3, 0.24937963), (5, 0.12531017)]
# [(0, 0.08796099), (1, 0.07733538), (2, 0.15758197), (3, 0.18639049), (4, 0.3758473), (5, 0.114883915)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(2, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(3, 0.33006537), (5, 0.65686274)]
# [(1, 0.49507388), (2, 0.2489459), (4, 0.24859104)]
# [(3, 0.33006582), (5, 0.65686226)]
# [(0, 0.17229533), (2, 0.26482448), (4, 0.22844307), (5, 0.33222955)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(0, 0.5841423), (1, 0.13346612), (2, 0.07860593), (3, 0.13603324), (4, 0.06708838)]
# [(1, 0.33006537), (4, 0.65686274)]
# [(0, 0.26626825), (1, 0.3869845), (2, 0.19986717), (4, 0.14555201)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(0, 0.31008285), (2, 0.4091029), (4, 0.23190556), (5, 0.047959052)]
# [(0, 0.24933138), (2, 0.41402063), (5, 0.3316975)]
# [(1, 0.3300653), (2, 0.6568628)]
# [(3, 0.95283026)]
# [(0, 0.23922302), (2, 0.14305949), (3, 0.19310924), (4, 0.28013232), (5, 0.14305949)]
# [(0, 0.6283663), (3, 0.35856175)]
# [(0, 0.27327317), (1, 0.05679805), (2, 0.41198152), (3, 0.2568398)]
# [(3, 0.97572815)]
# [(0, 0.65686274), (4, 0.33006537)]
# [(0, 0.2775617), (1, 0.10039761), (2, 0.19146197), (3, 0.19980118), (4, 0.22978348)]
# [(0, 0.10039761), (2, 0.22044308), (3, 0.18519159), (4, 0.4919796)]
# [(0, 0.56798863), (2, 0.14305949), (3, 0.28470254)]
# [(0, 0.95283026)]
# [(0, 0.42210203), (2, 0.11808456), (3, 0.13144974), (4, 0.21578085), (5, 0.11147902)]
# [(1, 0.11147902), (2, 0.5529801), (3, 0.1208609), (4, 0.21247242)]
# [(2, 0.39723322), (3, 0.39723322), (5, 0.19960476)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(2, 0.4902912), (4, 0.49029133)]
# [(2, 0.40233737), (3, 0.4703604), (5, 0.12235174)]
# [(0, 0.6568628), (1, 0.33006534)]
# [(2, 0.98366016)]
# [(0, 0.39723322), (1, 0.19960475), (3, 0.23258162), (4, 0.16662785)]
# [(0, 0.34816033), (1, 0.24937966), (3, 0.13912408), (4, 0.26085454)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(1, 0.11147904), (2, 0.2218543), (4, 0.5529801), (5, 0.11147902)]
# [(0, 0.37872958), (3, 0.36857533), (4, 0.24998261)]
# [(1, 0.24876848), (4, 0.74137926)]
# [(0, 0.24876845), (1, 0.49507388), (2, 0.24876845)]
# [(0, 0.25397632), (2, 0.492921), (3, 0.24938056)]
# [(0, 0.3602357), (1, 0.091320075), (2, 0.09897984), (3, 0.17640832), (4, 0.2721519)]
# [(0, 0.11171712), (1, 0.15390505), (2, 0.3478134), (4, 0.30846083), (5, 0.07733792)]
# [(0, 0.08942181), (1, 0.14166512), (2, 0.2628721), (3, 0.26342726), (4, 0.13715729), (5, 0.10545646)]
# [(0, 0.42896685), (2, 0.27891463), (3, 0.28618965)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.16666667), (1, 0.33168316), (2, 0.16666667), (3, 0.33168316)]
# [(1, 0.059380736), (2, 0.32932362), (3, 0.3463469), (4, 0.20720895), (5, 0.057186123)]
# [(0, 0.117561825), (2, 0.42710596), (3, 0.1005211), (4, 0.17217097), (5, 0.18173598)]
# [(0, 0.65686274), (4, 0.33006537)]
# [(0, 0.10046097), (1, 0.15257725), (2, 0.04645969), (3, 0.3814149), (4, 0.22175631), (5, 0.09733087)]
# [(0, 0.19980118), (1, 0.10039761), (2, 0.29920474), (3, 0.39860836)]
# [(0, 0.34787083), (1, 0.24937963), (2, 0.13277243), (3, 0.14342621), (4, 0.12531017)]
# [(1, 0.24876848), (4, 0.49507388), (5, 0.24876848)]
# [(3, 0.37869185), (4, 0.39723322), (5, 0.21814613)]
# [(0, 0.40079594), (1, 0.13834381), (2, 0.16929425), (3, 0.1745063), (4, 0.11639567)]
# [(3, 0.4888577), (4, 0.5012901)]
# [(0, 0.33384734), (1, 0.10727013), (2, 0.18907148), (3, 0.14350237), (4, 0.1546765), (5, 0.071632214)]
# [(0, 0.33006537), (1, 0.3300653), (2, 0.33006537)]
# [(0, 0.06706507), (1, 0.13346612), (2, 0.24057429), (3, 0.27439255), (4, 0.28383794)]
# [(0, 0.39723316), (5, 0.5948616)]
# [(0, 0.22320066), (1, 0.5712657), (4, 0.19960475)]
# [(0, 0.19987088), (1, 0.10039761), (2, 0.11141647), (3, 0.28811622), (4, 0.100397594), (5, 0.1998012)]
# [(1, 0.33006537), (5, 0.65686274)]
# [(0, 0.16670783), (3, 0.49665853), (4, 0.16666666), (5, 0.16666666)]
# [(0, 0.24856696), (1, 0.16194992), (2, 0.20301434), (3, 0.38426125)]
# [(0, 0.95283026)]
# [(1, 0.7413793), (4, 0.24876848)]
# [(0, 0.5948617), (3, 0.39723322)]
# [(0, 0.48852852), (1, 0.24876848), (4, 0.25531384)]
# [(0, 0.23376404), (2, 0.3416761), (3, 0.23183276), (4, 0.19139907)]
# [(1, 0.5679887), (2, 0.14305948), (3, 0.28470257)]
# [(1, 0.33168316), (2, 0.49669966), (4, 0.16666667)]
# [(0, 0.39723322), (1, 0.39723322), (4, 0.19960475)]
# [(0, 0.33250415), (3, 0.4154229), (4, 0.16666666), (5, 0.08374792)]
# [(0, 0.24876848), (3, 0.24876848), (4, 0.24876848), (5, 0.24876848)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(3, 0.5186722), (5, 0.4619103)]
# [(0, 0.15992291), (2, 0.64157444), (3, 0.11963582), (5, 0.077335365)]
# [(3, 0.703438), (4, 0.2899613)]
# [(0, 0.12531018), (2, 0.12531017), (3, 0.4975186), (4, 0.24937963)]
# [(0, 0.2227756), (1, 0.23787662), (2, 0.062124915), (3, 0.21002619), (4, 0.21923815), (5, 0.047958527)]
# [(1, 0.47269496), (2, 0.27114192), (3, 0.24877396)]
# [(0, 0.16771792), (1, 0.08992365), (2, 0.27186084), (4, 0.46883926)]
# [(0, 0.07180764), (1, 0.10627283), (2, 0.15712577), (3, 0.3837134), (4, 0.24856243), (5, 0.03251796)]
# [(0, 0.3205333), (1, 0.062889166), (2, 0.22414662), (3, 0.20406796), (4, 0.18774033)]
# [(2, 0.97572815)]
# [(0, 0.14305949), (2, 0.42634562), (4, 0.28470254), (5, 0.14305949)]
# [(1, 0.059976887), (2, 0.32693124), (3, 0.40325236), (4, 0.20897217)]
# [(0, 0.18640597), (2, 0.39860836), (3, 0.31260002), (4, 0.10039762)]
# [(0, 0.13070722), (1, 0.12973946), (2, 0.24937963), (3, 0.48769224)]
# [(1, 0.24876848), (2, 0.24876848), (4, 0.49507388)]
# [(0, 0.50007415), (3, 0.2716699), (4, 0.22494465)]
# [(3, 0.728053), (5, 0.26209483)]
# [(0, 0.28780445), (2, 0.24876848), (3, 0.4560379)]
# [(3, 0.97572815)]
# [(2, 0.24876845), (3, 0.49507388), (5, 0.24876845)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(3, 0.97572815)]
# [(0, 0.6568628), (4, 0.33006534)]
# [(0, 0.39723322), (4, 0.19960475), (5, 0.39723322)]
# [(1, 0.95283026)]
# [(0, 0.30765983), (2, 0.11147904), (3, 0.40078914), (4, 0.17786443)]
# [(1, 0.12173665), (2, 0.54436886), (3, 0.33118203)]
# [(0, 0.4408314), (3, 0.5493164)]
# [(2, 0.97572815)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(0, 0.19960475), (2, 0.5948617), (4, 0.19960476)]
# [(0, 0.18862557), (1, 0.2940932), (3, 0.3473142), (5, 0.16666667)]
# [(0, 0.31750625), (2, 0.092663616), (3, 0.12046805), (4, 0.34439978), (5, 0.12405808)]
# [(2, 0.49507388), (4, 0.24876848), (5, 0.24876848)]
# [(0, 0.19960475), (1, 0.19960472), (2, 0.19960475), (3, 0.39723322)]
# [(0, 0.25655693), (1, 0.09544159), (2, 0.23423614), (3, 0.166345), (4, 0.1962788), (5, 0.05114151)]
# [(0, 0.24876848), (2, 0.49507383), (5, 0.24876848)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.98366016)]
# [(0, 0.65686274), (1, 0.33006537)]
# [(0, 0.37804687), (2, 0.28140432), (3, 0.060410544), (4, 0.22203764), (5, 0.057546895)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(0, 0.11683852), (1, 0.26824436), (2, 0.50019366), (4, 0.11273539)]
# [(0, 0.95283026)]
# [(2, 0.7413793), (3, 0.24876848)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(1, 0.65686274), (5, 0.3300653)]
# [(0, 0.24876848), (1, 0.24876848), (4, 0.24876848), (5, 0.24876848)]
# [(1, 0.24876845), (4, 0.74137926)]
# [(0, 0.29436296), (1, 0.2218543), (3, 0.114071354), (4, 0.36750385)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(1, 0.4902912), (4, 0.49029127)]
# [(0, 0.6568627), (1, 0.33006537)]
# [(0, 0.29120123), (2, 0.24937966), (3, 0.45569703)]
# [(0, 0.54126847), (1, 0.13248421), (2, 0.056650076), (3, 0.13810655), (4, 0.13096602)]
# [(2, 0.95283026)]
# [(0, 0.33006537), (5, 0.65686274)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.452264), (5, 0.5346641)]
# [(0, 0.3307229), (2, 0.29175252), (3, 0.2091995), (4, 0.16666667)]
# [(2, 0.4902912), (4, 0.49029127)]
# [(0, 0.28470254), (2, 0.28470254), (3, 0.14305949), (4, 0.14305949), (5, 0.14305949)]
# [(0, 0.19960475), (3, 0.19960475), (4, 0.5948617)]
# [(2, 0.24459106), (3, 0.19960475), (4, 0.5498753)]
# [(0, 0.16209374), (1, 0.21098574), (2, 0.47372577), (3, 0.15071337)]
# [(1, 0.19960472), (2, 0.19963686), (4, 0.5948295)]
# [(0, 0.39723322), (1, 0.19960476), (3, 0.39723322)]
# [(1, 0.5710597), (3, 0.4158684)]
# [(0, 0.20490623), (1, 0.25905398), (2, 0.15318587), (3, 0.27124923), (5, 0.11123514)]
# [(3, 0.5707839), (4, 0.4097986)]
# [(4, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.33269215), (2, 0.2618319), (4, 0.20191868), (5, 0.19960475)]
# [(2, 0.97572815)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(0, 0.1175644), (1, 0.24004567), (2, 0.11437536), (3, 0.14289787), (4, 0.32094502), (5, 0.06417168)]
# [(0, 0.19382063), (1, 0.09170454), (2, 0.3034326), (3, 0.077708885), (4, 0.13346612), (5, 0.1998672)]
# [(0, 0.12531017), (1, 0.6180438), (2, 0.12885451), (5, 0.12531017)]
# [(1, 0.5679887), (2, 0.4263456)]
# [(0, 0.97572815)]
# [(0, 0.24876848), (2, 0.7413793)]
# [(0, 0.24958539), (1, 0.08374793), (2, 0.24958539), (3, 0.27669287), (4, 0.13955922)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.2237688), (1, 0.28162718), (2, 0.17470664), (3, 0.20829353), (4, 0.074279375), (5, 0.037324466)]
# [(0, 0.5237162), (1, 0.17802347), (3, 0.10743848), (4, 0.10624372), (5, 0.08374896)]
# [(0, 0.31970677), (2, 0.30745733), (3, 0.3705388)]
# [(0, 0.37812835), (1, 0.05950709), (2, 0.27030686), (3, 0.10769547), (4, 0.05618084), (5, 0.12818137)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(2, 0.49503914), (3, 0.24876848), (4, 0.24880321)]
# [(2, 0.9944812)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(3, 0.98366016)]
# [(0, 0.32530558), (4, 0.6616225)]
# [(1, 0.24876848), (2, 0.49507388), (4, 0.24876848)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(3, 0.5184855), (5, 0.46209702)]
# [(0, 0.21045229), (1, 0.17042688), (3, 0.37227648), (4, 0.24518599)]
# [(0, 0.33783045), (2, 0.25900748), (3, 0.19960475), (4, 0.19960475)]
# [(0, 0.30564913), (1, 0.15821038), (2, 0.13619536), (3, 0.14307664), (4, 0.14538947), (5, 0.11147904)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.303356), (1, 0.22234197), (2, 0.23389785), (3, 0.13645951), (4, 0.103391014)]
# [(0, 0.49029127), (5, 0.4902912)]
# [(0, 0.5789366), (1, 0.17643611), (2, 0.18425214), (4, 0.05920281)]
# [(0, 0.49669966), (1, 0.16666667), (2, 0.33168316)]
# [(0, 0.31195515), (1, 0.28447995), (2, 0.27124444), (5, 0.13107508)]
# [(0, 0.48767045), (4, 0.49291208)]
# [(0, 0.31963286), (1, 0.17225128), (2, 0.22761203), (4, 0.2797057)]
# [(0, 0.49669966), (1, 0.16666667), (4, 0.33168316)]
# [(2, 0.5679887), (3, 0.42634562)]
# [(0, 0.077340186), (1, 0.15391463), (2, 0.53672457), (3, 0.23048906)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(2, 0.97572815)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(3, 0.99011856)]
# [(0, 0.4885633), (1, 0.24876848), (4, 0.2552791)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(0, 0.16666666), (1, 0.66171616), (4, 0.16666666)]
# [(0, 0.17074978), (1, 0.4477378), (2, 0.1595552), (3, 0.22029881)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(0, 0.37022364), (2, 0.22823267), (3, 0.28775632), (4, 0.11157987)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(3, 0.97572815)]
# [(0, 0.18702741), (1, 0.030358057), (2, 0.63496023), (4, 0.14632624)]
# [(0, 0.32178319), (1, 0.0720145), (2, 0.21861044), (3, 0.29325143), (4, 0.09397092)]
# [(0, 0.2078463), (2, 0.24937963), (3, 0.41477516), (4, 0.1255175)]
# [(0, 0.33006534), (2, 0.6568628)]
# [(3, 0.7413793), (5, 0.24876848)]
# [(1, 0.66171616), (4, 0.33168313)]
# [(0, 0.16666667), (2, 0.49669966), (4, 0.33168316)]
# [(0, 0.25841287), (1, 0.17222907), (2, 0.11879614), (4, 0.3997141), (5, 0.05034931)]
# [(2, 0.49507388), (4, 0.24876848), (5, 0.24876851)]
# [(1, 0.33006537), (4, 0.65686274)]
# [(0, 0.14305949), (2, 0.51630104), (3, 0.14305949), (4, 0.19474712)]
# [(1, 0.49507388), (2, 0.24876848), (4, 0.24876848)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(0, 0.17089905), (1, 0.5401491), (2, 0.28470254)]
# [(0, 0.24937963), (2, 0.12532464), (4, 0.49750417), (5, 0.12531017)]
# [(0, 0.16666667), (2, 0.3316367), (3, 0.33172962), (4, 0.16666667)]
# [(0, 0.38776514), (2, 0.32026666), (3, 0.12590577), (4, 0.16534963)]
# [(0, 0.24876848), (2, 0.4955521), (4, 0.24829029)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(0, 0.97572815)]
# [(3, 0.57076365), (4, 0.40981892)]
# [(0, 0.123597555), (1, 0.11147904), (2, 0.5408616), (4, 0.22185431)]
# [(0, 0.14925857), (1, 0.119819224), (2, 0.27979586), (3, 0.2456555), (4, 0.20503715)]
# [(0, 0.7166335), (2, 0.08526144), (3, 0.19580795)]
# [(0, 0.28093868), (2, 0.28470254), (4, 0.14682336), (5, 0.28470254)]
# [(0, 0.19960475), (3, 0.39282006), (4, 0.20401789), (5, 0.19960475)]
# [(0, 0.34798852), (1, 0.1404707), (2, 0.4184124), (5, 0.09132007)]
# [(1, 0.39723322), (2, 0.19960475), (3, 0.19960475), (4, 0.19960475)]
# [(0, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(0, 0.13325962), (1, 0.2583809), (2, 0.21796528), (3, 0.13595492), (4, 0.2535351)]
# [(1, 0.24876848), (3, 0.49507388), (5, 0.24876848)]
# [(0, 0.6992902), (2, 0.15339945), (5, 0.14306106)]
# [(2, 0.3424703), (3, 0.6531147)]
# [(2, 0.97572815)]
# [(0, 0.16666667), (2, 0.33163676), (3, 0.33172956), (5, 0.16666667)]
# [(1, 0.16666667), (2, 0.33168316), (3, 0.16666667), (4, 0.33168316)]
# [(0, 0.65686274), (2, 0.3300653)]
# [(0, 0.29188254), (1, 0.10238526), (2, 0.17253962), (3, 0.05162649), (4, 0.23864111), (5, 0.14292498)]
# [(0, 0.18583089), (2, 0.47753543), (3, 0.16666667), (4, 0.16666667)]
# [(0, 0.32522798), (2, 0.27985895), (3, 0.091320075), (4, 0.3017847)]
# [(0, 0.06706507), (1, 0.13346612), (2, 0.19986717), (3, 0.5318725), (4, 0.06706507)]
# [(0, 0.15929948), (1, 0.1752104), (2, 0.21938391), (3, 0.29301608), (4, 0.1001994), (5, 0.052890785)]
# [(1, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(2, 0.24876848), (3, 0.32461125), (4, 0.41923115)]
# [(0, 0.65686274), (5, 0.33006537)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.24876848), (3, 0.24876848)]
# [(2, 0.38565773), (3, 0.60937953)]
# [(0, 0.49507388), (2, 0.24876845), (5, 0.24876845)]
# [(0, 0.65686274), (5, 0.33006537)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.23374473), (2, 0.3018637), (3, 0.3184992), (5, 0.14305949)]
# [(0, 0.16666666), (1, 0.08374792), (2, 0.33250415), (3, 0.24958542), (5, 0.16666666)]
# [(0, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(0, 0.16084217), (1, 0.10116706), (2, 0.3039896), (3, 0.20513853), (4, 0.22842903)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(0, 0.14305949), (1, 0.20862909), (2, 0.1799259), (3, 0.32195786), (4, 0.14501125)]
# [(0, 0.30968243), (1, 0.052990556), (2, 0.10708196), (3, 0.15792237), (4, 0.10946856), (5, 0.26285416)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(2, 0.49029127), (3, 0.4902912)]
# [(0, 0.5948617), (2, 0.39723322)]
# [(0, 0.115167834), (1, 0.30704442), (3, 0.2563124), (4, 0.31994396)]
# [(0, 0.35454586), (2, 0.47383696), (4, 0.16666666)]
# [(3, 0.73997784), (4, 0.25016996)]
# [(1, 0.97572815)]
# [(0, 0.24876845), (1, 0.49507388), (3, 0.24876845)]
# [(0, 0.20833053), (1, 0.16666667), (3, 0.2900193), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.24876845), (2, 0.74137926)]
# [(2, 0.11147902), (3, 0.33222955), (4, 0.33222955), (5, 0.22185431)]
# [(0, 0.41540405), (1, 0.12788513), (3, 0.3012744), (5, 0.15390505)]
# [(3, 0.39723316), (4, 0.39723322), (5, 0.19960475)]
# [(0, 0.30890566), (3, 0.17633744), (4, 0.5120444)]
# [(0, 0.49669966), (2, 0.33168313), (5, 0.16666666)]
# [(0, 0.33391064), (2, 0.085343555), (3, 0.2883961), (4, 0.1805003), (5, 0.11129567)]
# [(0, 0.97572815)]
# [(0, 0.15357545), (2, 0.46899137), (3, 0.24964157), (5, 0.12531017)]
# [(0, 0.24876848), (2, 0.49507388), (3, 0.24876848)]
# [(0, 0.33006537), (1, 0.33006537), (3, 0.33006537)]
# [(3, 0.24876848), (4, 0.7413793)]
# [(0, 0.27832645), (1, 0.2218543), (2, 0.12444831), (3, 0.11545998), (4, 0.25880718)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.1998012), (2, 0.59740776), (3, 0.19980896)]
# [(0, 0.10039762), (2, 0.39860836), (3, 0.19980122), (5, 0.29920477)]
# [(3, 0.21201469), (4, 0.58245176), (5, 0.19960475)]
# [(0, 0.24876845), (1, 0.24876845), (2, 0.49507388)]
# [(0, 0.24876848), (2, 0.24876848), (3, 0.24876851), (5, 0.24876848)]
# [(0, 0.4902912), (5, 0.49029127)]
# [(1, 0.14305949), (3, 0.42634562), (4, 0.4263456)]
# [(1, 0.091320075), (2, 0.49653962), (3, 0.1890182), (4, 0.22131379)]
# [(1, 0.33006537), (2, 0.33030087), (4, 0.32982987)]
# [(2, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(2, 0.19960475), (3, 0.39723322), (4, 0.39723322)]
# [(0, 0.5679887), (2, 0.4263456)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(0, 0.16271691), (1, 0.15016471), (2, 0.18803295), (3, 0.32206318), (4, 0.17643613)]
# [(0, 0.33103406), (1, 0.041978393), (2, 0.04197839), (3, 0.3095603), (4, 0.2334705), (5, 0.04197839)]
# [(0, 0.65686274), (2, 0.3300654)]
# [(0, 0.33137426), (1, 0.08374792), (2, 0.16668686), (4, 0.41653255)]
# [(0, 0.42634562), (2, 0.28470254), (3, 0.28470254)]
# [(0, 0.16833079), (1, 0.2306694), (2, 0.2689419), (3, 0.09551753), (4, 0.12951572), (5, 0.107024625)]
# [(2, 0.98366016)]
# [(0, 0.24073896), (1, 0.40746167), (2, 0.091706865), (3, 0.09259664), (4, 0.16666666)]
# [(0, 0.37518987), (2, 0.22787039), (4, 0.20425369), (5, 0.18938574)]
# [(1, 0.24876848), (2, 0.24876848), (4, 0.24876848), (5, 0.24876848)]
# [(0, 0.36913842), (3, 0.48651212), (4, 0.047958206), (5, 0.09544159)]
# [(0, 0.12531018), (1, 0.12531018), (2, 0.24937966), (3, 0.14072615), (4, 0.35803318)]
# [(0, 0.24390358), (1, 0.20267208), (2, 0.3746707), (4, 0.0994052), (5, 0.07908565)]
# [(0, 0.33168316), (1, 0.33167934), (3, 0.16667049), (5, 0.16666667)]
# [(1, 0.33006537), (3, 0.38425034), (4, 0.27588034)]
# [(0, 0.16666667), (1, 0.33168316), (2, 0.16666667), (3, 0.16666667), (5, 0.16666667)]
# [(0, 0.09826135), (1, 0.1902463), (2, 0.3153661), (3, 0.14705163), (4, 0.24854995)]
# [(0, 0.3884328), (1, 0.15390505), (3, 0.30222568), (4, 0.07733537), (5, 0.07733537)]
# [(0, 0.18375565), (1, 0.29074377), (2, 0.24812968), (3, 0.09864729), (4, 0.134412), (5, 0.04431164)]
# [(4, 0.95283026)]
# [(0, 0.17566226), (1, 0.44260487), (3, 0.15766397), (4, 0.22186138)]
# [(0, 0.19960475), (1, 0.19960475), (2, 0.19960475), (3, 0.39723322)]
# [(0, 0.42378372), (3, 0.32005867), (5, 0.24876848)]
# [(0, 0.33168316), (2, 0.16666667), (3, 0.33168316), (5, 0.16666667)]
# [(0, 0.2992048), (1, 0.17706569), (2, 0.22252755), (3, 0.29921395)]
# [(2, 0.16666667), (3, 0.33168316), (4, 0.49669966)]
# [(1, 0.3261565), (2, 0.2654988), (3, 0.40409544)]
# [(0, 0.39723322), (1, 0.19960475), (2, 0.19960475), (3, 0.19960476)]
# [(0, 0.59151435), (1, 0.19960475), (3, 0.20295207)]
# [(1, 0.29920477), (2, 0.3988077), (4, 0.2990054)]
# [(0, 0.12515566), (1, 0.23734924), (2, 0.26202804), (4, 0.30763736), (5, 0.067206964)]
# [(0, 0.46763435), (2, 0.36053586), (4, 0.16687925)]
# [(0, 0.39723322), (1, 0.19960475), (2, 0.39723322)]
# [(0, 0.5679887), (1, 0.14305948), (3, 0.28470254)]
# [(0, 0.06288916), (1, 0.21567126), (2, 0.3459621), (3, 0.3742321)]
# [(0, 0.23648992), (1, 0.30702654), (2, 0.230815), (3, 0.15404607), (4, 0.070958436)]
# [(2, 0.3551362), (3, 0.38827714), (4, 0.25163615)]
# [(0, 0.37344915), (1, 0.12531017), (2, 0.12531017), (3, 0.24937963), (4, 0.12531017)]
# [(0, 0.95283026)]
# [(0, 0.13130268), (1, 0.12515567), (2, 0.24358365), (3, 0.2696221), (4, 0.22971325)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(0, 0.77888936), (4, 0.21320549)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(2, 0.49507388), (3, 0.24876848), (4, 0.24876848)]
# [(0, 0.12531017), (2, 0.869727)]
# [(1, 0.14947478), (2, 0.18790954), (3, 0.46658215), (4, 0.19320063)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(4, 0.95283026)]
# [(0, 0.19960472), (2, 0.39721254), (3, 0.19962539), (4, 0.19960475)]
# [(3, 0.97572815)]
# [(1, 0.24876848), (2, 0.24876848), (3, 0.24876848), (4, 0.24876848)]
# [(0, 0.17200404), (1, 0.18742217), (2, 0.14120905), (3, 0.20785537), (4, 0.22861952), (5, 0.06288989)]
# [(1, 0.4902912), (5, 0.49029127)]
# [(0, 0.39722887), (1, 0.19960475), (2, 0.19960475), (5, 0.1996091)]
# [(1, 0.24876845), (2, 0.24894585), (4, 0.24859107), (5, 0.24876848)]
# [(3, 0.98366016)]
# [(0, 0.23618329), (3, 0.5582806), (5, 0.19960727)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(1, 0.7413793), (4, 0.24876851)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(3, 0.71406144), (5, 0.27286667)]
# [(1, 0.35345897), (2, 0.16898748), (3, 0.47330424)]
# [(0, 0.50355583), (3, 0.48984352)]
# [(1, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(0, 0.33006537), (3, 0.65686274)]
# [(0, 0.39684218), (1, 0.19960475), (2, 0.19960475), (4, 0.19999576)]
# [(0, 0.32530633), (4, 0.66162175)]
# [(1, 0.4902912), (5, 0.49029127)]
# [(1, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(0, 0.3257401), (2, 0.37207302), (4, 0.2992048)]
# [(1, 0.12531017), (2, 0.24942164), (3, 0.13093147), (4, 0.24371636), (5, 0.24937963)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(0, 0.6568556), (5, 0.33007252)]
# [(0, 0.37203667), (2, 0.12531017), (3, 0.37344915), (4, 0.12672263)]
# [(2, 0.24876848), (3, 0.24876848), (5, 0.49507388)]
# [(3, 0.3448938), (4, 0.6420343)]
# [(0, 0.33006537), (2, 0.33006537), (5, 0.33006537)]
# [(0, 0.21591087), (1, 0.14295876), (2, 0.2528536), (3, 0.173325), (4, 0.07198869), (5, 0.14296311)]
# [(0, 0.6283234), (3, 0.35860473)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.24876848), (3, 0.24876851)]
# [(0, 0.3300653), (3, 0.65686274)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(1, 0.97572815)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (3, 0.33168316), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.4902912), (2, 0.49029127)]
# [(0, 0.13670665), (1, 0.15387712), (3, 0.5816246), (4, 0.12531017)]
# [(1, 0.24876845), (3, 0.24876845), (4, 0.49507388)]
# [(0, 0.22604023), (1, 0.5606359), (4, 0.20837335)]
# [(0, 0.58927375), (2, 0.10624262), (3, 0.102639586), (4, 0.10045181), (5, 0.10039821)]
# [(0, 0.95283026)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(3, 0.24876845), (4, 0.49507388), (5, 0.24876845)]
# [(1, 0.49507388), (2, 0.24876845), (3, 0.24876845)]
# [(0, 0.1981926), (1, 0.10092172), (2, 0.18685037), (3, 0.21587661), (4, 0.22082287), (5, 0.077335864)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(1, 0.74137926), (2, 0.24876845)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(0, 0.38951814), (2, 0.15959708), (3, 0.33397308), (5, 0.11407887)]
# [(0, 0.09132007), (1, 0.09130494), (3, 0.18175109), (4, 0.54339963), (5, 0.09132007)]
# [(1, 0.19960472), (2, 0.39723322), (4, 0.39723322)]
# [(0, 0.16269065), (2, 0.33168316), (4, 0.5006757)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(1, 0.07183499), (2, 0.1429891), (3, 0.5547759), (4, 0.15785381), (5, 0.07183499)]
# [(0, 0.14558178), (1, 0.17711568), (2, 0.24434695), (3, 0.15742438), (4, 0.116255246), (5, 0.15927598)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(3, 0.6568627), (4, 0.33006537)]
# [(0, 0.23655072), (1, 0.18173598), (2, 0.30840212), (3, 0.27150282)]
# [(0, 0.19722117), (1, 0.11147902), (2, 0.2218543), (3, 0.24595581), (4, 0.22238591)]
# [(3, 0.95283026)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(0, 0.33006537), (1, 0.33006537), (3, 0.33006537)]
# [(0, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.33006537), (4, 0.65686274)]
# [(0, 0.65686274), (1, 0.33006537)]
# [(3, 0.33006537), (4, 0.65686274)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(3, 0.97572815)]
# [(3, 0.27223933), (4, 0.7179085)]
# [(0, 0.49458674), (1, 0.24876848), (4, 0.24925564)]
# [(0, 0.39723322), (2, 0.39723322), (3, 0.19960475)]
# [(0, 0.51910466), (3, 0.2662653), (4, 0.21090795)]
# [(2, 0.3586144), (3, 0.62831366)]
# [(0, 0.16561137), (1, 0.17992824), (2, 0.28531724), (3, 0.16342722), (4, 0.13387987), (5, 0.07183606)]
# [(3, 0.97572815)]
# [(1, 0.4902912), (4, 0.49029127)]
# [(2, 0.65686274), (5, 0.33006537)]
# [(2, 0.97572815)]
# [(1, 0.33006537), (2, 0.33006537), (5, 0.33006537)]
# [(3, 0.65682894), (5, 0.33009917)]
# [(0, 0.4393937), (2, 0.3044486), (5, 0.24876848)]
# [(0, 0.19258454), (1, 0.38710958), (2, 0.074349806), (3, 0.15060139), (4, 0.19469067)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(2, 0.97572815)]
# [(3, 0.14305949), (4, 0.42634562), (5, 0.42634562)]
# [(0, 0.62831), (3, 0.35861802)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(0, 0.29547137), (1, 0.33167145), (3, 0.36790663)]
# [(1, 0.4902912), (4, 0.49029127)]
# [(2, 0.43515232), (3, 0.11893158), (4, 0.44260487)]
# [(2, 0.97572815)]
# [(2, 0.14305949), (3, 0.42634562), (4, 0.42634562)]
# [(0, 0.28488564), (3, 0.16919123), (4, 0.26208317), (5, 0.2810071)]
# [(0, 0.49669963), (2, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.3796046), (1, 0.19960475), (3, 0.21684206), (4, 0.19999604)]
# [(0, 0.7143843), (2, 0.27576348)]
# [(1, 0.82673264), (4, 0.16666666)]
# [(1, 0.24876845), (2, 0.49507388), (5, 0.24876845)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(2, 0.29692978), (3, 0.693218)]
# [(0, 0.7797181), (4, 0.21237677)]
# [(3, 0.97572815)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(0, 0.648457), (2, 0.16666667), (4, 0.17992584)]
# [(0, 0.97572815)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(0, 0.23668246), (1, 0.26626825), (2, 0.16274694), (4, 0.20017022), (5, 0.13346809)]
# [(4, 0.95283026)]
# [(0, 0.3445524), (2, 0.27199313), (3, 0.10907813), (4, 0.27256805)]
# [(0, 0.4902625), (5, 0.49032003)]
# [(1, 0.46213162), (3, 0.24876848), (4, 0.2817107)]
# [(0, 0.49507388), (2, 0.49507383)]
# [(0, 0.6179747), (3, 0.12870444), (4, 0.24959871)]
# [(0, 0.29900727), (2, 0.16666667), (3, 0.33168316), (4, 0.19934261)]
# [(0, 0.44079033), (3, 0.5493575)]
# [(0, 0.27439967), (1, 0.1998012), (2, 0.14134106), (3, 0.20720623), (4, 0.17625783)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(0, 0.32677698), (3, 0.6682603)]
# [(1, 0.7067788), (3, 0.28336895)]
# [(1, 0.7284267), (2, 0.2617211)]
# [(4, 0.65686274), (5, 0.33006537)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(1, 0.33168316), (2, 0.33180186), (4, 0.3315645)]
# [(2, 0.24876848), (3, 0.49507388), (5, 0.24876848)]
# [(0, 0.3257641), (1, 0.44063637), (4, 0.23130241)]
# [(0, 0.17169663), (1, 0.39723322), (2, 0.42514133)]
# [(0, 0.98366016)]
# [(1, 0.49507388), (2, 0.24876845), (4, 0.24876845)]
# [(3, 0.65686274), (5, 0.33006537)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(2, 0.95283026)]
# [(0, 0.7854764), (3, 0.20661844)]
# [(1, 0.28470254), (3, 0.30157006), (4, 0.26783505), (5, 0.14305949)]
# [(1, 0.97572815)]
# [(0, 0.1467735), (3, 0.4226316), (4, 0.28470254), (5, 0.14305949)]
# [(1, 0.16666667), (2, 0.18587591), (3, 0.47749043), (4, 0.16666667)]
# [(1, 0.4902912), (4, 0.49029127)]
# [(0, 0.3300654), (1, 0.3300653), (2, 0.33006537)]
# [(1, 0.97572815)]
# [(1, 0.39723322), (2, 0.19960475), (4, 0.39723322)]
# [(0, 0.44705686), (3, 0.2967855), (4, 0.24876848)]
# [(1, 0.4902912), (3, 0.49029133)]
# [(0, 0.3052614), (3, 0.6848864)]
# [(1, 0.5323595), (3, 0.4597354)]
# [(1, 0.08374792), (2, 0.08374793), (3, 0.41470543), (4, 0.16737133), (5, 0.2495982)]
# [(0, 0.16666666), (1, 0.16666666), (3, 0.66171616)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(3, 0.5664367), (4, 0.28624818), (5, 0.14306583)]
# [(3, 0.71440035), (5, 0.27252772)]
# [(0, 0.22321005), (1, 0.5712564), (4, 0.19960475)]
# [(1, 0.24876845), (2, 0.44266337), (4, 0.301179)]
# [(1, 0.33006537), (4, 0.3300764), (5, 0.33005434)]
# [(0, 0.5679887), (3, 0.1494838), (4, 0.2782782)]
# [(1, 0.33222955), (2, 0.33222955), (3, 0.11147904), (4, 0.2218543)]
# [(1, 0.7413793), (4, 0.24876848)]
# [(3, 0.65686274), (4, 0.33006537)]
# [(1, 0.24876851), (2, 0.24876848), (3, 0.49507388)]
# [(1, 0.49505857), (3, 0.49508917)]
# [(0, 0.97572815)]
# [(1, 0.49507388), (4, 0.24876845), (5, 0.24876845)]
# [(0, 0.22748348), (1, 0.27819452), (3, 0.48839313)]
# [(1, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(3, 0.39723322), (5, 0.5948617)]
# [(1, 0.97572815)]
# [(0, 0.33006537), (2, 0.33030075), (4, 0.32982993)]
# [(0, 0.6283631), (3, 0.35856503)]
# [(0, 0.2301144), (1, 0.24937966), (4, 0.5167839)]
# [(2, 0.33006534), (3, 0.6568628)]
# [(1, 0.33006537), (3, 0.38420478), (4, 0.27592596)]
# [(1, 0.6398008), (4, 0.35359856)]
# [(3, 0.33006537), (4, 0.65686274)]
# [(0, 0.2572539), (1, 0.11623286), (2, 0.23367392), (3, 0.17389709), (4, 0.17389417), (5, 0.045048065)]
# [(0, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(1, 0.24937966), (2, 0.12532945), (3, 0.25810167), (4, 0.36470786)]
# [(1, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(5, 0.95283026)]
# [(2, 0.33006537), (3, 0.65686274)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.33006537), (2, 0.33006537), (5, 0.33006537)]
# [(0, 0.14561926), (1, 0.12531018), (2, 0.14659789), (3, 0.20776401), (5, 0.37346798)]
# [(0, 0.33006537), (3, 0.65686274)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(1, 0.39723322), (3, 0.19960475), (4, 0.39723322)]
# [(0, 0.42701617), (3, 0.56507874)]
# [(0, 0.5476899), (3, 0.44664437)]
# [(2, 0.98768467)]
# [(2, 0.24876845), (4, 0.24876845), (5, 0.49507388)]
# [(0, 0.49507388), (3, 0.24876848), (4, 0.24876848)]
# [(1, 0.16666667), (2, 0.16666667), (3, 0.49669966), (4, 0.16666667)]
# [(1, 0.97572815)]
# [(0, 0.22126485), (1, 0.2218543), (2, 0.2218543), (4, 0.22244132), (5, 0.11148144)]
# [(0, 0.4902912), (3, 0.49029127)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(0, 0.97572815)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1              1  ...                         [verifikasi, email, kesel]
# 2              2  ...                     [up, money, bilang, manajemen]
# 3              3  ...                                     [iklan, sebal]
# 4              4  ...                    [nonton, ngapa, kesini, melulu]
# ..           ...  ...                                                ...
# 995          995  ...                                  [barang, lengkap]
# 996          996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 997          997  ...                            [tingkat, promo, ehehe]
# 998          998  ...                                 [bags, barang, ny]
# 999          999  ...                             [pesan, cepat, sampai]
#
# [1000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    259
# 1.0    133
# 2.0    208
# 3.0    240
# 4.0    128
# 5.0     32
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_6topics_with_stemming_alpha_topics_eta_len_dictionary.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
