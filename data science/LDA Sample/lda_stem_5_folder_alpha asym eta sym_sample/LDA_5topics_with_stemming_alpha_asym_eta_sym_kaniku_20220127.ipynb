# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install PySastrawi
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ## Passed

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %%
df_token
# Out:
#                                                 review  ...                                   review_processed
# 0    Pembelian pakai cc ribet, di tolak terus sama ...  ...              beli pakai cc ribet tolak sedia layan
# 1    Kenapa saya tidak bisa verifikasi email saya?!...  ...                             verifikasi email kesel
# 2    TOP UP GAK MASUK E MONEY DIBILANG MASUK, MANAJ...  ...                          up money bilang manajemen
# 3                               Iklan nya nyebelin anj  ...                                     iklan nyebelin
# 4                 Anj..gw mau nonton ngapa kesini mulu  ...                           nonton ngapa kesini mulu
# ..                                                 ...  ...                                                ...
# 995                      Semoga barang semakin lengkap  ...                                     barang lengkap
# 996  Belanja aman dan menyenangkan. Topup tanpa bia...  ...  belanja aman topup biaya admin harga murah jan...
# 997           sip tingkat kan trus aja promo nya ehehe  ...                                tingkat promo ehehe
# 998                                     bags barang ny  ...                                     bags barang ny
# 999                      Pesanan bagus cepat sampe nya  ...                                  pesan cepat sampe
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lemot', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lemot', 'buanget'],
#  ['habis',
#   'update',
#   'lemot',
#   'sihh',
#   'shoppenya',
#   'lemot',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lemot',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lemot'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lemot', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lemot', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lemot',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lemot',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lemot',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'malah',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'malah',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lemot', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lemot',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lemot'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lemot',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lemot',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
#   'kaya',
#   'keong',
# ...
#   'jasa',
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lemot', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lemot',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai']]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_alpha_asym_eta_sym_5')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(0, 0.050445266), (1, 0.46509796), (2, 0.022038281), (3, 0.017767336), (4, 0.4446512)]
# [(0, 0.42455387), (1, 0.059745662), (2, 0.045689512), (3, 0.0357823), (4, 0.43422863)]
# [(0, 0.06809999), (1, 0.04712437), (2, 0.03513867), (3, 0.02842774), (4, 0.82120925)]
# [(0, 0.44432083), (1, 0.4099189), (2, 0.05856444), (3, 0.047379557), (4, 0.0398163)]
# [(0, 0.2928235), (1, 0.3872043), (2, 0.03514092), (3, 0.028427724), (4, 0.25640357)]
# [(0, 0.12729825), (1, 0.11083846), (2, 0.015973495), (3, 0.012921956), (4, 0.7329678)]
# [(0, 0.84873325), (1, 0.07029364), (4, 0.06502753)]
# [(0, 0.59253776), (1, 0.35888693), (2, 0.019521452), (3, 0.015793182), (4, 0.013260625)]
# [(0, 0.5191108), (1, 0.37136018), (2, 0.044150088), (3, 0.035534665), (4, 0.029844237)]
# [(0, 0.3673403), (1, 0.14864947), (2, 0.011712903), (3, 0.20944503), (4, 0.2628523)]
# [(0, 0.38880128), (1, 0.038330883), (2, 0.029282184), (3, 0.5236947), (4, 0.01989094)]
# [(0, 0.44347283), (1, 0.14368644), (2, 0.18505324), (3, 0.011844896), (4, 0.21594256)]
# [(0, 0.24868429), (1, 0.07665421), (2, 0.010371867), (3, 0.14659609), (4, 0.5176936)]
# [(0, 0.6871831), (1, 0.022998521), (2, 0.017569305), (3, 0.11360447), (4, 0.15864459)]
# [(0, 0.15100259), (1, 0.08157495), (2, 0.30051687), (3, 0.10829568), (4, 0.3586099)]
# [(0, 0.71108496), (1, 0.089311026), (4, 0.19142924)]
# [(0, 0.6431479), (1, 0.016625125), (2, 0.012691027), (3, 0.13493615), (4, 0.1925998)]
# [(0, 0.19999675), (1, 0.03285513), (2, 0.025099093), (3, 0.020305533), (4, 0.72174346)]
# [(0, 0.43922353), (1, 0.078601606), (2, 0.08420819), (3, 0.18147314), (4, 0.21649353)]
# [(0, 0.3332689), (1, 0.13937894), (2, 0.19850157), (4, 0.31996694)]
# [(0, 0.1907347), (1, 0.2788481), (2, 0.30418357), (3, 0.017767424), (4, 0.2084662)]
# [(0, 0.9149172), (1, 0.02999596), (2, 0.022322271), (3, 0.017825354), (4, 0.01493923)]
# [(0, 0.5356888), (1, 0.27871406), (2, 0.019741582), (3, 0.15257621), (4, 0.013279259)]
# [(0, 0.44002154), (1, 0.23058386), (3, 0.063497044), (4, 0.257057)]
# [(0, 0.8147714), (1, 0.025553992), (2, 0.01952151), (3, 0.015793191), (4, 0.124359965)]
# [(0, 0.08381399), (1, 0.0578279), (2, 0.79294324), (3, 0.03557524), (4, 0.029839616)]
# [(0, 0.7033408), (1, 0.13675399), (2, 0.13083406), (3, 0.0157932), (4, 0.013277863)]
# [(0, 0.19633809), (1, 0.028758936), (2, 0.44356585), (3, 0.017770676), (4, 0.31356645)]
# [(0, 0.659439), (1, 0.015404631), (2, 0.09938509), (3, 0.088477775), (4, 0.13729344)]
# [(0, 0.18321688), (1, 0.23653087), (2, 0.011419091), (3, 0.097505175), (4, 0.47132796)]
# [(0, 0.6665622), (1, 0.24600229), (2, 0.035138667), (3, 0.028427731), (4, 0.023869125)]
# [(0, 0.5836511), (1, 0.057496287), (2, 0.043923255), (3, 0.28509292), (4, 0.029836407)]
# [(0, 0.41660464), (1, 0.15374887), (2, 0.02196163), (3, 0.017767327), (4, 0.38991746)]
# [(0, 0.36589423), (1, 0.12791955), (2, 0.21241361), (4, 0.29074448)]
# [(0, 0.6663934), (1, 0.046005618), (2, 0.035144392), (3, 0.028428713), (4, 0.22402792)]
# [(0, 0.70729536), (1, 0.012777085), (3, 0.06344013), (4, 0.20672663)]
# [(0, 0.77761245), (1, 0.07666178), (2, 0.058564384), (3, 0.047379557), (4, 0.03978188)]
# [(0, 0.3332107), (1, 0.3077154), (2, 0.29370272), (3, 0.035534788), (4, 0.029836426)]
# [(0, 0.54877615), (1, 0.19797747), (4, 0.23536155)]
# [(0, 0.058485266), (1, 0.2050035), (2, 0.029282248), (3, 0.19036353), (4, 0.5168655)]
# [(0, 0.47615406), (1, 0.019344158), (2, 0.13626488), (3, 0.011857949), (4, 0.356379)]
# [(0, 0.6058623), (1, 0.060079336), (2, 0.04445795), (3, 0.2597101), (4, 0.029890273)]
# [(0, 0.38880858), (1, 0.5383175), (2, 0.029282304), (3, 0.023689793), (4, 0.019901818)]
# [(0, 0.44441485), (1, 0.10250745), (2, 0.014641161), (3, 0.011844901), (4, 0.42659166)]
# [(0, 0.6045173), (1, 0.06444168), (3, 0.1571169), (4, 0.16513862)]
# [(0, 0.465772), (1, 0.18619275), (2, 0.13968019), (3, 0.12318409), (4, 0.08517098)]
# [(0, 0.33351517), (1, 0.03285522), (2, 0.025099138), (3, 0.1629372), (4, 0.44559327)]
# [(0, 0.44706917), (1, 0.14665642), (2, 0.019523364), (3, 0.015795546), (4, 0.37095556)]
# [(0, 0.73328125), (1, 0.02299853), (2, 0.21756943), (3, 0.014213863), (4, 0.011936929)]
# [(0, 0.58320785), (1, 0.30749783), (2, 0.043923263), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.33322835), (1, 0.057497006), (2, 0.29404944), (3, 0.035534747), (4, 0.27969047)]
# [(0, 0.24681807), (1, 0.03833087), (2, 0.1959492), (3, 0.023689771), (4, 0.49521208)]
# [(0, 0.583192), (1, 0.30749774), (2, 0.043923263), (3, 0.035534658), (4, 0.029852364)]
# [(0, 0.3888019), (1, 0.3716677), (2, 0.19594972), (3, 0.023689775), (4, 0.019890938)]
# [(0, 0.22579046), (1, 0.51524067), (2, 0.02603566), (3, 0.020420568), (4, 0.21251264)]
# [(0, 0.7014145), (1, 0.021686945), (2, 0.016314792), (3, 0.01297512), (4, 0.2476086)]
# [(0, 0.833207), (1, 0.057496306), (2, 0.043923266), (3, 0.035534658), (4, 0.029838735)]
# [(0, 0.3133902), (1, 0.04714302), (2, 0.03609227), (3, 0.028562222), (4, 0.5748123)]
# [(0, 0.3924181), (1, 0.060784396), (2, 0.06497956), (3, 0.15927674), (4, 0.3225412)]
# [(0, 0.50532705), (1, 0.12299961), (2, 0.017569315), (3, 0.014213865), (4, 0.33989018)]
# [(0, 0.2945553), (1, 0.2932713), (2, 0.35974282), (3, 0.028505033), (4, 0.023925526)]
# [(0, 0.34876108), (1, 0.24365726), (2, 0.011200599), (4, 0.38745943)]
# [(0, 0.22227757), (1, 0.20499851), (2, 0.029282177), (3, 0.19021823), (4, 0.35322347)]
# [(0, 0.4542778), (1, 0.112663046), (2, 0.17072393), (3, 0.12501371), (4, 0.13732153)]
# [(0, 0.27690473), (1, 0.026603363), (2, 0.25065768), (3, 0.1817084), (4, 0.26412582)]
# [(0, 0.051145546), (1, 0.3558392), (2, 0.23280464), (3, 0.19769828), (4, 0.16251235)]
# [(0, 0.2973169), (1, 0.07040629), (2, 0.23203638), (3, 0.063450806), (4, 0.33678955)]
# [(0, 0.47610927), (1, 0.318574), (2, 0.025099028), (3, 0.1631683), (4, 0.017049376)]
# [(0, 0.39957687), (1, 0.20721811), (2, 0.14553432), (3, 0.049617484), (4, 0.19805323)]
# [(0, 0.79144895), (1, 0.02912319), (2, 0.021962296), (3, 0.01776749), (4, 0.1396981)]
# [(0, 0.90469104), (1, 0.032855045), (2, 0.025099019), (3, 0.020305522), (4, 0.017049374)]
# [(0, 0.55546373), (1, 0.038330965), (2, 0.029282248), (3, 0.19036259), (4, 0.18656047)]
# [(0, 0.26652026), (1, 0.2460167), (2, 0.035138786), (3, 0.028427755), (4, 0.4238965)]
# [(0, 0.28718758), (1, 0.18477558), (2, 0.10036578), (3, 0.035632145), (4, 0.39203894)]
# [(0, 0.40216002), (1, 0.10336174), (2, 0.18837833), (3, 0.09176982), (4, 0.21433012)]
# [(0, 0.08459732), (1, 0.057496294), (2, 0.043923255), (3, 0.035534658), (4, 0.7784485)]
# [(0, 0.44443357), (1, 0.18577611), (2, 0.014641183), (3, 0.011844984), (4, 0.34330413)]
# [(0, 0.42777905), (1, 0.19000556), (2, 0.010334906), (3, 0.18484403), (4, 0.18703645)]
# [(0, 0.6944186), (1, 0.17344198), (2, 0.11673658)]
# [(0, 0.5343149), (1, 0.22306201), (2, 0.017569933), (3, 0.11310135), (4, 0.11195183)]
# [(0, 0.31912348), (1, 0.032855455), (2, 0.16801657), (3, 0.020305518), (4, 0.45969898)]
# [(0, 0.17389598), (1, 0.37285557), (2, 0.017569397), (3, 0.01421388), (4, 0.42146516)]
# [(0, 0.54971987), (1, 0.26559448), (2, 0.012652184), (3, 0.010164031), (4, 0.1618694)]
# [(0, 0.3331815), (1, 0.057496402), (2, 0.29394522), (3, 0.03553467), (4, 0.27984226)]
# [(0, 0.81620884), (1, 0.0706236), (3, 0.09675167)]
# [(0, 0.06664077), (1, 0.25021988), (2, 0.6308354), (3, 0.028434385), (4, 0.02386955)]
# [(0, 0.46661395), (1, 0.24616082), (2, 0.23492822), (3, 0.028427834), (4, 0.023869142)]
# [(0, 0.11181878), (1, 0.39168572), (2, 0.058649108), (3, 0.39806333), (4, 0.039783027)]
# [(0, 0.19736145), (1, 0.35643762), (2, 0.23075666), (3, 0.19839299), (4, 0.017051267)]
# [(0, 0.19039366), (1, 0.3186334), (2, 0.16789718), (3, 0.020305568), (4, 0.3027702)]
# [(0, 0.71412987), (1, 0.043210804), (2, 0.029297382), (3, 0.19344053), (4, 0.019921388)]
# [(0, 0.06715874), (1, 0.27681056), (2, 0.035386316), (3, 0.59675634), (4, 0.023888042)]
# [(0, 0.47425005), (1, 0.17162871), (3, 0.13410136), (4, 0.21324621)]
# [(0, 0.39020744), (1, 0.0339877), (2, 0.02510144), (3, 0.16319115), (4, 0.38751227)]
# [(0, 0.3547786), (1, 0.24285445), (2, 0.16251266), (3, 0.056447092), (4, 0.18340725)]
# [(0, 0.44454202), (1, 0.07666175), (2, 0.058564365), (3, 0.38044998), (4, 0.039781876)]
# [(0, 0.7776124), (1, 0.07666182), (2, 0.05856442), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.46527576), (1, 0.045997653), (2, 0.035139065), (3, 0.02842929), (4, 0.4251582)]
# [(0, 0.08404532), (1, 0.35216495), (2, 0.4983552), (3, 0.035593357), (4, 0.029841134)]
# [(0, 0.5167462), (1, 0.08090976), (2, 0.3149438), (3, 0.04760053), (4, 0.039799716)]
# [(0, 0.6665128), (1, 0.2459952), (2, 0.03513863), (3, 0.02842773), (4, 0.02392568)]
# [(0, 0.33599955), (1, 0.15145168), (2, 0.107238024), (4, 0.39686683)]
# [(0, 0.4892721), (1, 0.04552417), (2, 0.04356328), (3, 0.16880915), (4, 0.25283128)]
# [(0, 0.220275), (1, 0.26375008), (2, 0.012044695), (3, 0.10945112), (4, 0.39447913)]
# [(0, 0.27826905), (1, 0.22576943), (2, 0.29502267), (3, 0.0109733865), (4, 0.18996544)]
# [(0, 0.73749477), (1, 0.15729721), (2, 0.011045706), (4, 0.08526765)]
# [(0, 0.111284554), (1, 0.07671931), (2, 0.058775645), (3, 0.04739747), (4, 0.705823)]
# [(0, 0.6556611), (1, 0.18589425), (2, 0.014641263), (3, 0.0118546225), (4, 0.13194875)]
# [(0, 0.33362603), (1, 0.057516333), (2, 0.0439255), (3, 0.035535093), (4, 0.5293971)]
# [(0, 0.09734855), (1, 0.18152411), (2, 0.011825365), (4, 0.6998077)]
# [(0, 0.58321804), (1, 0.05749657), (2, 0.04392344), (3, 0.035534695), (4, 0.2798273)]
# [(0, 0.5062684), (1, 0.045998335), (2, 0.035139307), (3, 0.02842776), (4, 0.38416615)]
# [(0, 0.4442776), (1, 0.40999663), (2, 0.058564346), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.24459328), (1, 0.34372094), (2, 0.011827817), (3, 0.102388255), (4, 0.2974697)]
# [(0, 0.46510625), (1, 0.067032605), (3, 0.17947626), (4, 0.27957416)]
# [(0, 0.113925725), (1, 0.73806095), (2, 0.060634594), (3, 0.047580916), (4, 0.039797824)]
# [(0, 0.24301754), (1, 0.31827226), (2, 0.029400706), (3, 0.023709835), (4, 0.38559964)]
# [(0, 0.28356668), (1, 0.30730382), (2, 0.24505305), (3, 0.15080713), (4, 0.013269279)]
# [(0, 0.19182195), (1, 0.3185601), (2, 0.16796476), (3, 0.16305004), (4, 0.15860313)]
# [(0, 0.3366011), (1, 0.24786654), (2, 0.10694608), (3, 0.10418751), (4, 0.20439877)]
# [(0, 0.8305734), (1, 0.060031563), (2, 0.04395148), (3, 0.03553936), (4, 0.029904213)]
# [(0, 0.48236388), (1, 0.02091169), (2, 0.19963545), (3, 0.012922139), (4, 0.28416684)]
# [(0, 0.47576502), (1, 0.15068863), (2, 0.20425242), (3, 0.013060484), (4, 0.15623344)]
# [(0, 0.32194656), (1, 0.31046814), (2, 0.011762976), (3, 0.086068556), (4, 0.26975378)]
# [(0, 0.72192335), (1, 0.2051729), (2, 0.029283233), (3, 0.023689771), (4, 0.019930772)]
# [(0, 0.38237783), (1, 0.07857989), (2, 0.08827961), (3, 0.18152404), (4, 0.26923868)]
# [(0, 0.7249256), (1, 0.21998183), (2, 0.022346327), (3, 0.017824253), (4, 0.014922046)]
# [(0, 0.44900694), (1, 0.016448427), (2, 0.08402757), (3, 0.010238266), (4, 0.44027883)]
# [(0, 0.46043828), (1, 0.11959274), (2, 0.25717), (3, 0.012932933), (4, 0.149866)]
# [(0, 0.08513212), (1, 0.05863802), (2, 0.47959915), (3, 0.035666082), (4, 0.34096465)]
# [(0, 0.26730105), (1, 0.24735105), (2, 0.43304974), (3, 0.028428722), (4, 0.023869453)]
# [(0, 0.35624316), (1, 0.029533338), (2, 0.022553863), (3, 0.017855583), (4, 0.57381403)]
# [(0, 0.34878302), (1, 0.047142807), (2, 0.03597649), (3, 0.028557498), (4, 0.5395402)]
# [(0, 0.5610431), (1, 0.22968702), (2, 0.17191406), (3, 0.02030641), (4, 0.017049449)]
# [(0, 0.407426), (1, 0.14965175), (3, 0.1407131), (4, 0.2953612)]
# [(0, 0.11100152), (1, 0.74324685), (2, 0.058564335), (3, 0.04737954), (4, 0.03980774)]
# [(0, 0.3332182), (1, 0.0574967), (2, 0.29387894), (3, 0.035534706), (4, 0.27987143)]
# [(0, 0.54183584), (1, 0.117540605), (2, 0.32971865)]
# [(0, 0.6419427), (1, 0.06836712), (3, 0.17470087), (4, 0.10514553)]
# [(0, 0.5866039), (1, 0.017739419), (2, 0.09580491), (3, 0.087880865), (4, 0.21197094)]
# [(0, 0.33417207), (1, 0.03296391), (2, 0.025102017), (3, 0.30213872), (4, 0.30562326)]
# [(0, 0.46656266), (1, 0.24601133), (2, 0.035138734), (3, 0.02842775), (4, 0.22385952)]
# [(0, 0.33321244), (1, 0.5574932), (2, 0.043923266), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.398083), (1, 0.038643084), (2, 0.32330102), (3, 0.023727082), (4, 0.21624583)]
# [(0, 0.55546635), (1, 0.038330954), (2, 0.19594999), (3, 0.023689782), (4, 0.18656294)]
# [(0, 0.06890838), (1, 0.5383265), (2, 0.029282203), (3, 0.023689777), (4, 0.33979312)]
# [(0, 0.5832342), (1, 0.057496708), (2, 0.29389802), (3, 0.03553471), (4, 0.029836416)]
# [(0, 0.37535334), (1, 0.02620696), (2, 0.19005407), (3, 0.015813695), (4, 0.392572)]
# [(0, 0.416761), (1, 0.18915352), (3, 0.05043598), (4, 0.33973908)]
# [(0, 0.3323294), (1, 0.13648516), (2, 0.2849351), (3, 0.015793212), (4, 0.2304571)]
# [(0, 0.41739997), (1, 0.1987144), (2, 0.021961827), (3, 0.017767372), (4, 0.3441564)]
# [(0, 0.6755932), (1, 0.046000596), (2, 0.035141032), (3, 0.21939607), (4, 0.023869159)]
# [(0, 0.40018234), (1, 0.11148193), (3, 0.107107684), (4, 0.37244326)]
# [(0, 0.1396016), (1, 0.25884476), (2, 0.01769802), (3, 0.014235144), (4, 0.5696205)]
# [(0, 0.3376987), (1, 0.3994871), (2, 0.09650161), (4, 0.16186607)]
# [(0, 0.33326122), (1, 0.057498615), (2, 0.29442862), (3, 0.035535015), (4, 0.27927655)]
# [(0, 0.6692076), (1, 0.025554297), (2, 0.019521745), (3, 0.015793204), (4, 0.26992318)]
# [(0, 0.27098843), (1, 0.025711417), (2, 0.01963424), (3, 0.3085002), (4, 0.37516567)]
# [(0, 0.29574946), (1, 0.41603723), (2, 0.23590979), (3, 0.028427731), (4, 0.023875793)]
# [(0, 0.4165337), (1, 0.028748294), (2, 0.1469742), (3, 0.26781744), (4, 0.13992634)]
# [(0, 0.38299507), (1, 0.15374324), (2, 0.021961657), (3, 0.14246556), (4, 0.2988345)]
# [(0, 0.43342048), (1, 0.12306694), (2, 0.41736406), (3, 0.0142139895), (4, 0.011934573)]
# [(0, 0.6776023), (1, 0.16550094), (2, 0.011712889), (4, 0.13570794)]
# [(0, 0.3813328), (1, 0.45486036), (2, 0.025488572), (3, 0.12126385), (4, 0.017054437)]
# [(0, 0.5832153), (1, 0.3074903), (2, 0.043923385), (3, 0.035534684), (4, 0.029836413)]
# [(0, 0.53603077), (1, 0.12168485), (2, 0.037675668), (3, 0.066905946), (4, 0.23770274)]
# [(0, 0.11094662), (1, 0.076662205), (2, 0.3919035), (3, 0.047379587), (4, 0.37310812)]
# [(0, 0.4665463), (1, 0.24595532), (2, 0.03513897), (3, 0.22849026), (4, 0.02386913)]
# [(0, 0.3493068), (1, 0.01916559), (2, 0.09798448), (3, 0.17857908), (4, 0.35496402)]
# [(0, 0.50192595), (1, 0.14718728), (2, 0.074816115), (3, 0.09841436), (4, 0.17765625)]
# [(0, 0.59026897), (1, 0.017697096), (2, 0.09046864), (3, 0.08787356), (4, 0.2136917)]
# [(0, 0.555483), (1, 0.038331203), (2, 0.19591393), (3, 0.023689816), (4, 0.18658207)]
# [(0, 0.58201015), (1, 0.07253635), (3, 0.1398409), (4, 0.1958135)]
# [(0, 0.32459852), (1, 0.064727835), (3, 0.06001283), (4, 0.5414092)]
# [(0, 0.44427395), (1, 0.07666182), (2, 0.05856441), (3, 0.047379564), (4, 0.37312028)]
# [(0, 0.396979), (1, 0.15557168), (3, 0.12689029), (4, 0.31613448)]
# [(0, 0.2753541), (1, 0.3075739), (2, 0.010470828), (4, 0.39821774)]
# [(0, 0.1724683), (1, 0.025675805), (2, 0.32637918), (3, 0.0158092), (4, 0.45966753)]
# [(0, 0.48492843), (1, 0.04624166), (2, 0.03530946), (3, 0.4096256), (4, 0.02389487)]
# [(0, 0.75471884), (1, 0.10365949), (2, 0.121487305), (3, 0.010946416)]
# [(0, 0.79228085), (1, 0.028748183), (2, 0.021961655), (3, 0.14207374), (4, 0.014935611)]
# [(0, 0.44455218), (1, 0.07666175), (2, 0.05856436), (3, 0.3804398), (4, 0.039781876)]
# [(0, 0.42048925), (1, 0.33449745), (2, 0.21231797), (3, 0.017776893), (4, 0.014918458)]
# [(0, 0.48439616), (1, 0.18030463), (2, 0.013532614), (3, 0.010933801), (4, 0.3108328)]
# [(0, 0.049617458), (1, 0.3482394), (2, 0.418116), (3, 0.020324126), (4, 0.16370301)]
# [(0, 0.77759343), (1, 0.07666172), (2, 0.05856434), (3, 0.04737954), (4, 0.039800916)]
# [(0, 0.44427672), (1, 0.40999746), (2, 0.058564376), (3, 0.04737955), (4, 0.039781876)]
# [(0, 0.74207765), (1, 0.1295723), (2, 0.014775529), (3, 0.011866033), (4, 0.101708464)]
# [(0, 0.70347464), (1, 0.16374615), (3, 0.0651546), (4, 0.05883904)]
# [(0, 0.29609486), (1, 0.32326877), (2, 0.34794858), (3, 0.017767545), (4, 0.014920231)]
# [(0, 0.33321244), (1, 0.55749327), (2, 0.043923266), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.16862395), (1, 0.2733105), (2, 0.07849135), (3, 0.18944936), (4, 0.29012477)]
# [(0, 0.3486839), (1, 0.14790726), (2, 0.01952151), (3, 0.015793191), (4, 0.4680942)]
# [(0, 0.17541716), (1, 0.028748423), (2, 0.02196182), (3, 0.14255366), (4, 0.6313189)]
# [(0, 0.19033362), (1, 0.032855276), (2, 0.025099186), (3, 0.020305553), (4, 0.7314064)]
# [(0, 0.60808), (1, 0.013238211), (2, 0.14780872), (4, 0.2229708)]
# [(0, 0.5832064), (1, 0.057496354), (2, 0.0439233), (3, 0.03553466), (4, 0.2798393)]
# [(0, 0.48089865), (1, 0.02570978), (2, 0.019521618), (3, 0.23799634), (4, 0.23587364)]
# [(0, 0.77754563), (1, 0.076661736), (2, 0.058564354), (3, 0.047379542), (4, 0.039848763)]
# [(0, 0.6325952), (1, 0.021199878), (2, 0.016181706), (3, 0.19769844), (4, 0.13232474)]
# [(0, 0.26810807), (1, 0.07067386), (2, 0.097807236), (3, 0.27453914), (4, 0.28887168)]
# [(0, 0.86372995), (1, 0.047515042), (2, 0.03627612), (3, 0.028595263), (4, 0.023883568)]
# [(0, 0.19041124), (1, 0.31855747), (2, 0.16793723), (3, 0.020305553), (4, 0.30278853)]
# [(0, 0.32665396), (1, 0.14405836), (2, 0.26216143), (4, 0.25875703)]
# [(0, 0.5076614), (1, 0.019165466), (2, 0.3480031), (3, 0.011844887), (4, 0.11332512)]
# [(0, 0.3135372), (1, 0.01362636), (2, 0.12803997), (3, 0.36138293), (4, 0.18341358)]
# [(0, 0.5457359), (1, 0.03341833), (2, 0.02568051), (3, 0.020370899), (4, 0.3747944)]
# [(0, 0.46631464), (1, 0.04599738), (2, 0.23522732), (3, 0.22859153), (4, 0.023869138)]
# [(0, 0.29478985), (1, 0.32153946), (2, 0.013685003), (3, 0.2738449), (4, 0.09614077)]
# [(0, 0.50060225), (1, 0.08766456), (2, 0.08833831), (4, 0.31768733)]
# [(0, 0.832039), (1, 0.058666654), (2, 0.043923296), (3, 0.035534665), (4, 0.029836409)]
# [(0, 0.35440838), (1, 0.30085236), (2, 0.019521685), (3, 0.015793223), (4, 0.30942428)]
# [(0, 0.863426), (1, 0.04817447), (2, 0.035941258), (3, 0.028549071), (4, 0.023909165)]
# [(0, 0.2138597), (1, 0.35964572), (2, 0.0148219615), (3, 0.20209129), (4, 0.20958135)]
# [(0, 0.44421938), (1, 0.076662175), (2, 0.058564648), (3, 0.38077188), (4, 0.039781876)]
# [(0, 0.72216153), (1, 0.038331058), (2, 0.19592506), (3, 0.023689799), (4, 0.019892566)]
# [(0, 0.66654545), (1, 0.04599725), (2, 0.03513877), (3, 0.22844937), (4, 0.023869127)]
# [(0, 0.3588082), (1, 0.10230671), (2, 0.11763947), (3, 0.010944646), (4, 0.410301)]
# [(0, 0.38884184), (1, 0.37156713), (2, 0.029282646), (3, 0.023689855), (4, 0.1866185)]
# [(0, 0.7247296), (1, 0.033488583), (2, 0.025546787), (3, 0.020489575), (4, 0.19574547)]
# [(0, 0.38670006), (1, 0.2753401), (2, 0.3225658)]
# [(0, 0.53148776), (1, 0.12373966), (2, 0.012617803), (3, 0.09894994), (4, 0.23320487)]
# [(0, 0.28864047), (1, 0.019242879), (2, 0.014718031), (3, 0.42578807), (4, 0.25161052)]
# [(0, 0.46799976), (1, 0.046017036), (2, 0.035152752), (3, 0.42696112), (4, 0.023869324)]
# [(0, 0.6189675), (1, 0.17571335), (2, 0.16796423), (3, 0.020305539), (4, 0.017049376)]
# [(0, 0.8888063), (1, 0.03833086), (2, 0.02928217), (3, 0.023689767), (4, 0.019890936)]
# [(0, 0.2302527), (1, 0.3720744), (2, 0.09455504), (4, 0.29363474)]
# [(0, 0.12642397), (1, 0.5285966), (2, 0.11997132), (3, 0.014215191), (4, 0.21079297)]
# [(0, 0.6767086), (1, 0.27471527), (2, 0.019522216), (3, 0.015793301), (4, 0.013260634)]
# [(0, 0.5332552), (1, 0.22300896), (2, 0.11758578), (3, 0.014213877), (4, 0.11193613)]
# [(0, 0.5416226), (1, 0.028748423), (2, 0.02196175), (3, 0.01776735), (4, 0.38989994)]
# [(0, 0.8331226), (1, 0.057501074), (2, 0.043925542), (3, 0.035534684), (4, 0.029916096)]
# [(0, 0.6536726), (1, 0.023000665), (2, 0.01757105), (3, 0.014214242), (4, 0.29154152)]
# [(0, 0.31474942), (1, 0.34435448), (2, 0.02217985), (3, 0.017803403), (4, 0.30091286)]
# [(0, 0.1572268), (1, 0.03833122), (2, 0.029282304), (3, 0.3569572), (4, 0.4182025)]
# [(0, 0.3120089), (1, 0.12829804), (2, 0.016101496), (3, 0.012999856), (4, 0.5305917)]
# [(0, 0.3497235), (1, 0.19213183), (2, 0.051658396), (3, 0.13555057), (4, 0.2709357)]
# [(0, 0.44258642), (1, 0.4480262), (2, 0.0439408), (3, 0.035556436), (4, 0.029890103)]
# [(0, 0.32779184), (1, 0.44861078), (4, 0.20768973)]
# [(0, 0.4442723), (1, 0.41000175), (2, 0.05856445), (3, 0.047379564), (4, 0.03978188)]
# [(0, 0.5555206), (1, 0.038331464), (2, 0.19607832), (3, 0.1901787), (4, 0.019890944)]
# [(0, 0.43579534), (1, 0.17571247), (2, 0.025124962), (3, 0.16288221), (4, 0.20048502)]
# [(0, 0.58320844), (1, 0.05749631), (2, 0.04392327), (3, 0.28553563), (4, 0.029836409)]
# [(0, 0.60318506), (1, 0.33391488), (2, 0.025433261), (3, 0.020412007), (4, 0.017054778)]
# [(0, 0.48542276), (1, 0.029321691), (2, 0.02237033), (3, 0.44795424), (4, 0.0149310315)]
# [(0, 0.44421986), (1, 0.4100537), (2, 0.058564886), (3, 0.04737964), (4, 0.039781887)]
# [(0, 0.3268497), (1, 0.31201312), (2, 0.011911222), (4, 0.3397226)]
# [(0, 0.6076959), (1, 0.032855336), (2, 0.025099289), (3, 0.16319893), (4, 0.17115061)]
# [(0, 0.083212115), (1, 0.057496354), (2, 0.5439231), (3, 0.035534665), (4, 0.2798338)]
# [(0, 0.36693978), (1, 0.37764826), (4, 0.24213524)]
# [(0, 0.333293), (1, 0.122857764), (2, 0.017569497), (3, 0.31432825), (4, 0.21195152)]
# [(0, 0.5596069), (1, 0.13389234), (2, 0.10687935), (3, 0.08073299), (4, 0.11888839)]
# [(0, 0.3842027), (1, 0.5065029), (2, 0.043923274), (3, 0.035534654), (4, 0.029836403)]
# [(0, 0.16459674), (1, 0.36094326), (2, 0.019848196), (3, 0.015844928), (4, 0.4387669)]
# [(0, 0.54157346), (1, 0.028748354), (2, 0.14696556), (3, 0.017767359), (4, 0.2649453)]
# [(0, 0.6656131), (1, 0.09486813), (2, 0.19592835), (3, 0.023689866), (4, 0.01990048)]
# [(0, 0.34405488), (1, 0.023094213), (2, 0.01763745), (3, 0.49895173), (4, 0.116261736)]
# [(0, 0.35808247), (1, 0.14259508), (2, 0.2168158), (3, 0.16041484), (4, 0.12209183)]
# [(0, 0.30069032), (1, 0.17366472), (2, 0.15538092), (4, 0.3631292)]
# [(0, 0.4810021), (1, 0.24613133), (2, 0.03513985), (3, 0.028428247), (4, 0.20929846)]
# [(0, 0.35363597), (1, 0.02874847), (2, 0.021961862), (3, 0.14268376), (4, 0.45296997)]
# [(0, 0.4331897), (1, 0.12301876), (2, 0.11761471), (3, 0.0142138945), (4, 0.311963)]
# [(0, 0.86329985), (1, 0.04789781), (2, 0.036324687), (3, 0.028595332), (4, 0.023882326)]
# [(0, 0.6388459), (1, 0.03935246), (2, 0.27812567), (3, 0.023777992), (4, 0.01989793)]
# [(0, 0.27570754), (1, 0.045997404), (2, 0.43531042), (3, 0.02842777), (4, 0.2145569)]
# [(0, 0.72247976), (1, 0.039211355), (2, 0.19472702), (3, 0.023690877), (4, 0.019891025)]
# [(0, 0.41667014), (1, 0.014572404), (2, 0.25244153), (3, 0.0957563), (4, 0.22055961)]
# [(0, 0.48666543), (1, 0.11289278), (2, 0.18619633), (4, 0.20950502)]
# [(0, 0.24669053), (1, 0.2028418), (2, 0.015972609), (3, 0.10348308), (4, 0.43101195)]
# [(0, 0.234768), (1, 0.1552684), (2, 0.011738052), (3, 0.25267473), (4, 0.34555078)]
# [(0, 0.43294486), (1, 0.08177106), (2, 0.08979769), (3, 0.080775686), (4, 0.31471074)]
# [(0, 0.1700316), (1, 0.16632263), (2, 0.022067185), (3, 0.49311507), (4, 0.1484635)]
# [(0, 0.3332057), (1, 0.30742604), (2, 0.04392371), (3, 0.28560814), (4, 0.029836414)]
# [(0, 0.44705725), (1, 0.07674218), (2, 0.05862191), (3, 0.377796), (4, 0.039782677)]
# [(0, 0.19417568), (1, 0.102508634), (2, 0.09793951), (3, 0.17861925), (4, 0.42675695)]
# [(0, 0.47994193), (1, 0.046223532), (2, 0.18148449), (3, 0.26847914), (4, 0.023870895)]
# [(0, 0.3332139), (1, 0.057496432), (2, 0.04392336), (3, 0.03553468), (4, 0.52983165)]
# [(0, 0.6661365), (1, 0.029183306), (2, 0.14695813), (3, 0.14278698), (4, 0.014935082)]
# [(0, 0.6200832), (1, 0.032862514), (2, 0.16654146), (3, 0.020306429), (4, 0.16020644)]
# [(0, 0.49739406), (1, 0.13051327), (2, 0.15207632), (3, 0.012937019), (4, 0.20707937)]
# [(0, 0.11094596), (1, 0.40999594), (2, 0.05856434), (3, 0.04737954), (4, 0.3731142)]
# [(0, 0.47002527), (1, 0.20315468), (2, 0.18681996), (3, 0.06677867), (4, 0.07322142)]
# [(0, 0.3887921), (1, 0.01654969), (2, 0.14763926), (3, 0.21788144), (4, 0.22913751)]
# [(0, 0.7222292), (1, 0.038334377), (2, 0.19580817), (3, 0.02370958), (4, 0.019918697)]
# [(0, 0.32558796), (1, 0.032858178), (2, 0.31817666), (3, 0.020305876), (4, 0.30307132)]
# [(0, 0.3984268), (1, 0.057651863), (2, 0.096571736), (3, 0.14005129), (4, 0.30729827)]
# [(0, 0.49998432), (1, 0.1454364), (2, 0.2079202), (3, 0.015829481), (4, 0.13082963)]
# [(0, 0.30099052), (1, 0.17861691), (2, 0.13706884), (3, 0.121992454), (4, 0.26133126)]
# [(0, 0.2681598), (1, 0.11608875), (2, 0.16087347), (3, 0.19687974), (4, 0.2579982)]
# [(0, 0.52823377), (1, 0.025856886), (2, 0.019737288), (3, 0.28597596), (4, 0.14019603)]
# [(0, 0.21199046), (1, 0.2027564), (2, 0.10683829), (3, 0.19481395), (4, 0.28360087)]
# [(0, 0.30844566), (1, 0.13666275), (2, 0.24181107), (3, 0.015793197), (4, 0.29728732)]
# [(0, 0.6354459), (1, 0.019274876), (2, 0.014719322), (3, 0.22628094), (4, 0.10427901)]
# [(0, 0.4186095), (1, 0.09331427), (2, 0.18779828), (3, 0.118233174), (4, 0.1820448)]
# [(0, 0.14074096), (1, 0.07756429), (2, 0.30731353), (3, 0.28279212), (4, 0.1915891)]
# [(0, 0.2762356), (1, 0.17484593), (2, 0.30342832), (4, 0.23660235)]
# [(0, 0.2702481), (1, 0.26518998), (2, 0.082326986), (3, 0.15986137), (4, 0.22237357)]
# [(0, 0.6105597), (1, 0.013797848), (2, 0.111649394), (4, 0.25562447)]
# [(0, 0.279903), (1, 0.279653), (2, 0.38809878), (3, 0.028472472), (4, 0.02387273)]
# [(0, 0.58320653), (1, 0.057496373), (2, 0.043923315), (3, 0.035534672), (4, 0.2798391)]
# [(0, 0.4761336), (1, 0.03285552), (2, 0.16796055), (3, 0.020305552), (4, 0.30274475)]
# [(0, 0.20865643), (1, 0.46172297), (2, 0.02509974), (3, 0.02044172), (4, 0.28407916)]
# [(0, 0.72464174), (1, 0.020351026), (2, 0.014918433), (3, 0.011928189), (4, 0.22816058)]
# [(0, 0.39746976), (1, 0.028748227), (2, 0.27200484), (3, 0.017767338), (4, 0.2840098)]
# [(0, 0.5579715), (1, 0.04042181), (2, 0.029310746), (3, 0.1839627), (4, 0.18833329)]
# [(0, 0.7521723), (1, 0.020923398), (2, 0.016019458), (3, 0.01292603), (4, 0.1979588)]
# [(0, 0.75758463), (1, 0.11176053), (2, 0.015972113), (3, 0.10383313), (4, 0.010849603)]
# [(0, 0.6665598), (1, 0.24599817), (2, 0.03513861), (3, 0.028427726), (4, 0.023875734)]
# [(0, 0.58766896), (1, 0.025555925), (2, 0.13101849), (3, 0.12605669), (4, 0.12969998)]
# [(0, 0.63863045), (2, 0.07156742), (3, 0.0458284), (4, 0.23476899)]
# [(0, 0.46998066), (1, 0.13936669), (2, 0.073464304), (3, 0.07107515), (4, 0.24611324)]
# [(0, 0.44084784), (1, 0.23762465), (2, 0.078509785), (3, 0.13430452), (4, 0.108713225)]
# [(0, 0.44773903), (1, 0.11685517), (2, 0.05593313), (3, 0.10933466), (4, 0.270138)]
# [(0, 0.5016314), (1, 0.03307569), (2, 0.2441303), (3, 0.20411111), (4, 0.0170515)]
# [(0, 0.34958896), (1, 0.033073023), (2, 0.2431496), (3, 0.20441309), (4, 0.16977534)]
# [(0, 0.7767396), (1, 0.023162853), (2, 0.17392856), (3, 0.014232899), (4, 0.01193612)]
# [(0, 0.16663095), (1, 0.37366852), (2, 0.22559857), (3, 0.08269673), (4, 0.15140525)]
# [(0, 0.28546536), (1, 0.19839919), (2, 0.11590421), (3, 0.30395058), (4, 0.096280634)]
# [(0, 0.2665707), (1, 0.045997314), (2, 0.03513883), (3, 0.02842776), (4, 0.62386537)]
# [(0, 0.48979005), (1, 0.19761774), (2, 0.11325632), (4, 0.19221593)]
# [(0, 0.25917393), (1, 0.24778625), (2, 0.13064195), (3, 0.015793188), (4, 0.34660465)]
# [(0, 0.4558527), (1, 0.016548026), (2, 0.09738325), (3, 0.3346352), (4, 0.09558084)]
# [(0, 0.533264), (1, 0.22301802), (2, 0.11756893), (3, 0.114214495), (4, 0.011934564)]
# [(0, 0.4015888), (1, 0.017691212), (2, 0.16735342), (3, 0.3186587), (4, 0.0947078)]
# [(0, 0.29179356), (1, 0.10227869), (2, 0.098052464), (3, 0.011844963), (4, 0.49603033)]
# [(0, 0.658636), (1, 0.045997083), (2, 0.03513864), (3, 0.028529843), (4, 0.23169851)]
# [(0, 0.66344744), (1, 0.1885673), (2, 0.017944299), (3, 0.014273273), (4, 0.11576773)]
# [(0, 0.4512725), (1, 0.18467964), (2, 0.14877975), (3, 0.10668363), (4, 0.10858448)]
# [(0, 0.33299848), (1, 0.30762556), (2, 0.043924425), (3, 0.03553505), (4, 0.2799165)]
# [(0, 0.5589705), (1, 0.012142149), (2, 0.13736732), (3, 0.065584645), (4, 0.22593538)]
# [(0, 0.77760744), (1, 0.07666453), (2, 0.058566242), (3, 0.047379874), (4, 0.039781913)]
# [(0, 0.19897716), (1, 0.23712091), (2, 0.022456944), (3, 0.017841578), (4, 0.5236034)]
# [(0, 0.11094589), (1, 0.07666173), (2, 0.39189732), (3, 0.04737954), (4, 0.37311554)]
# [(0, 0.51946175), (1, 0.07862213), (2, 0.31451577), (3, 0.04760099), (4, 0.03979937)]
# [(0, 0.5108983), (1, 0.08210173), (2, 0.14434803), (4, 0.25317585)]
# [(0, 0.50889355), (1, 0.20630307), (2, 0.016099362), (3, 0.012942969), (4, 0.25576097)]
# [(0, 0.30499738), (1, 0.39262512), (2, 0.03361702), (3, 0.061250422), (4, 0.20751005)]
# [(0, 0.22361366), (1, 0.29118636), (2, 0.22879499), (4, 0.24803266)]
# [(0, 0.3876895), (1, 0.12456011), (2, 0.14543948), (4, 0.33723077)]
# [(0, 0.3484614), (1, 0.13434613), (2, 0.017664384), (3, 0.27263603), (4, 0.22689211)]
# [(0, 0.0459981), (1, 0.029196756), (2, 0.41643107), (3, 0.017856129), (4, 0.49051788)]
# [(0, 0.82799476), (1, 0.060212016), (2, 0.046113703), (3, 0.03582101), (4, 0.029858544)]
# [(0, 0.6421558), (1, 0.017696293), (2, 0.0885771), (3, 0.010934243), (4, 0.24063656)]
# [(0, 0.21695447), (1, 0.11805554), (2, 0.12836148), (3, 0.3352021), (4, 0.20142637)]
# [(0, 0.41133258), (1, 0.23174463), (2, 0.31330338), (3, 0.02372557), (4, 0.019893823)]
# [(0, 0.23613262), (1, 0.21106654), (3, 0.07876672), (4, 0.46882775)]
# [(0, 0.5043683), (1, 0.12813559), (2, 0.118796445), (4, 0.24514048)]
# [(0, 0.47057253), (1, 0.013584679), (2, 0.08504032), (3, 0.075040445), (4, 0.35576203)]
# [(0, 0.29513907), (1, 0.32933176), (2, 0.17219254), (3, 0.05837776), (4, 0.14495888)]
# [(0, 0.219546), (1, 0.24943453), (2, 0.4463822), (4, 0.07671377)]
# [(0, 0.32808223), (1, 0.15994215), (2, 0.08127082), (3, 0.08197891), (4, 0.34872586)]
# [(0, 0.3410161), (1, 0.03285505), (2, 0.025099019), (3, 0.3058113), (4, 0.29521856)]
# [(0, 0.3957853), (1, 0.1710462), (2, 0.32903633), (3, 0.09560544)]
# [(0, 0.1808815), (1, 0.38483822), (2, 0.011031823), (3, 0.21706693), (4, 0.20618151)]
# [(0, 0.3342318), (1, 0.059576977), (2, 0.043923277), (3, 0.035534658), (4, 0.5267333)]
# [(0, 0.29925248), (1, 0.3598362), (4, 0.3270421)]
# [(0, 0.39060685), (1, 0.30775988), (2, 0.043924954), (3, 0.035534672), (4, 0.22217368)]
# [(0, 0.48254123), (1, 0.175889), (2, 0.1685023), (3, 0.1560181), (4, 0.017049402)]
# [(0, 0.46656704), (1, 0.24601085), (2, 0.03513873), (3, 0.028427746), (4, 0.22385558)]
# [(0, 0.489746), (1, 0.033027645), (2, 0.02519185), (3, 0.12492709), (4, 0.3271074)]
# [(0, 0.8332094), (1, 0.057496298), (2, 0.043923263), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.49307176), (1, 0.025840208), (2, 0.30606055), (3, 0.015892332), (4, 0.15913513)]
# [(0, 0.32187435), (1, 0.13268687), (2, 0.014791905), (3, 0.15429102), (4, 0.3763559)]
# [(0, 0.6856878), (1, 0.020907776), (2, 0.01597212), (3, 0.012921697), (4, 0.26451063)]
# [(0, 0.4401818), (1, 0.17174105), (2, 0.22091947), (3, 0.01779181), (4, 0.14936587)]
# [(0, 0.22207282), (1, 0.20502679), (2, 0.029282441), (3, 0.023689818), (4, 0.5199281)]
# [(0, 0.47459117), (1, 0.11116446), (2, 0.14157675), (3, 0.011855236), (4, 0.26081234)]
# [(0, 0.5042907), (1, 0.023097765), (2, 0.1272337), (3, 0.014215356), (4, 0.33116242)]
# [(0, 0.5620382), (1, 0.16547407), (2, 0.117787674), (3, 0.09826136), (4, 0.05643874)]
# [(0, 0.08553396), (1, 0.4038823), (2, 0.044573445), (3, 0.43615994), (4, 0.029850401)]
# [(0, 0.7762125), (1, 0.07769551), (2, 0.058918435), (3, 0.04737955), (4, 0.039793972)]
# [(0, 0.7044566), (1, 0.046090655), (2, 0.035480194), (3, 0.028456828), (4, 0.18551573)]
# [(0, 0.46656752), (1, 0.04599707), (2, 0.03513863), (3, 0.4284277), (4, 0.023869125)]
# [(0, 0.08458154), (1, 0.058006052), (2, 0.04428832), (3, 0.78327835), (4, 0.029845774)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564346), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.22488102), (1, 0.2321291), (2, 0.17492896), (3, 0.102196544), (4, 0.26586434)]
# [(0, 0.2584294), (1, 0.20382863), (2, 0.18112896), (3, 0.088464804), (4, 0.2681482)]
# [(0, 0.570057), (1, 0.20420465), (2, 0.10687246), (3, 0.012930468), (4, 0.10593546)]
# [(0, 0.648842), (1, 0.1642556), (2, 0.022005478), (3, 0.017767351), (4, 0.14712961)]
# [(0, 0.46653134), (1, 0.24599507), (2, 0.23514302), (3, 0.028427726), (4, 0.023902867)]
# [(0, 0.47640303), (1, 0.195331), (2, 0.120018594), (3, 0.15769003), (4, 0.05055733)]
# [(0, 0.46647307), (1, 0.045997318), (2, 0.035138827), (3, 0.4285217), (4, 0.023869127)]
# [(0, 0.58319336), (1, 0.057496823), (2, 0.2939349), (3, 0.03553473), (4, 0.029840235)]
# [(0, 0.42969832), (1, 0.12268351), (2, 0.10567259), (3, 0.010973999), (4, 0.33097157)]
# [(0, 0.7776122), (1, 0.07666189), (2, 0.05856447), (3, 0.047379564), (4, 0.03978188)]
# [(0, 0.91643834), (1, 0.02884498), (2, 0.021961682), (3, 0.017767338), (4, 0.0149876615)]
# [(0, 0.7776125), (1, 0.076661736), (2, 0.05856435), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.5836077), (1, 0.07693334), (2, 0.19811104), (4, 0.13246417)]
# [(0, 0.24477912), (1, 0.27074882), (2, 0.029735597), (3, 0.023761448), (4, 0.43097502)]
# [(0, 0.33578637), (1, 0.12581804), (2, 0.109859444), (3, 0.17398563), (4, 0.25455055)]
# [(0, 0.5243042), (1, 0.10245985), (2, 0.01464109), (3, 0.26172966), (4, 0.0968652)]
# [(0, 0.33320057), (1, 0.057500515), (2, 0.043923285), (3, 0.03553466), (4, 0.529841)]
# [(0, 0.55799156), (1, 0.24857971), (2, 0.019951459), (3, 0.015860751), (4, 0.15761656)]
# [(0, 0.4166091), (1, 0.028748447), (2, 0.27210933), (3, 0.017767368), (4, 0.26476577)]
# [(0, 0.21858396), (1, 0.38122034), (2, 0.22373867), (3, 0.01187179), (4, 0.16458522)]
# [(0, 0.40018678), (1, 0.014543911), (2, 0.011109986), (4, 0.56525517)]
# [(0, 0.42027813), (1, 0.098824844), (2, 0.19845136), (3, 0.2732647)]
# [(0, 0.6051206), (1, 0.045649394), (2, 0.04355514), (3, 0.078961134), (4, 0.22671369)]
# [(0, 0.5454664), (1, 0.09315715), (2, 0.10475054), (3, 0.24915794)]
# [(0, 0.21222496), (1, 0.12349241), (2, 0.09250363), (3, 0.102454126), (4, 0.4693249)]
# [(0, 0.41138294), (1, 0.23176835), (2, 0.3132293), (3, 0.023725597), (4, 0.019893827)]
# [(0, 0.35418472), (1, 0.04599703), (2, 0.035138603), (3, 0.028427735), (4, 0.5362519)]
# [(0, 0.33835748), (1, 0.057539187), (2, 0.044081487), (3, 0.035548005), (4, 0.52447385)]
# [(0, 0.39592743), (1, 0.014374734), (2, 0.2606365), (3, 0.07146732), (4, 0.25759402)]
# [(0, 0.39691073), (1, 0.18116157), (3, 0.10129292), (4, 0.31121665)]
# [(0, 0.44427824), (1, 0.07666176), (2, 0.05856437), (3, 0.047379542), (4, 0.37311605)]
# [(0, 0.52074605), (1, 0.29192713), (4, 0.17403798)]
# [(0, 0.32460362), (1, 0.27103558), (2, 0.010397471), (3, 0.15467036), (4, 0.23929298)]
# [(0, 0.36535734), (1, 0.2915035), (2, 0.04738618), (3, 0.1557217), (4, 0.14003125)]
# [(0, 0.26345286), (1, 0.22520997), (2, 0.23867822), (3, 0.010165201), (4, 0.26249376)]
# [(0, 0.74851507), (1, 0.02354856), (2, 0.017772624), (3, 0.014247306), (4, 0.19591644)]
# [(0, 0.44750994), (1, 0.2352763), (2, 0.16774292), (3, 0.047027923), (4, 0.10244291)]
# [(0, 0.3977625), (1, 0.03838637), (2, 0.029282572), (3, 0.023689825), (4, 0.51087874)]
# [(0, 0.30276784), (1, 0.20284757), (2, 0.10701871), (3, 0.1946692), (4, 0.1926967)]
# [(0, 0.2082083), (1, 0.30922684), (2, 0.19603777), (3, 0.061382584), (4, 0.22514455)]
# [(0, 0.33330423), (1, 0.17572717), (2, 0.02509948), (3, 0.020305598), (4, 0.4455635)]
# [(0, 0.27749676), (1, 0.21554989), (2, 0.085378855), (3, 0.15327512), (4, 0.26829943)]
# [(0, 0.58321077), (1, 0.057496384), (2, 0.2939218), (3, 0.035534665), (4, 0.029836409)]
# [(0, 0.56899625), (1, 0.11324005), (2, 0.103892915), (3, 0.10564863), (4, 0.10822217)]
# [(0, 0.47609118), (1, 0.032855406), (2, 0.16791625), (3, 0.16321638), (4, 0.15992077)]
# [(0, 0.5554696), (1, 0.038330887), (2, 0.029282192), (3, 0.023866037), (4, 0.35305133)]
# [(0, 0.61793435), (1, 0.1921886), (2, 0.012645644), (3, 0.08924645), (4, 0.08798496)]
# [(0, 0.33324108), (1, 0.057497323), (2, 0.043923944), (3, 0.28567225), (4, 0.2796654)]
# [(0, 0.23310165), (1, 0.082258806), (2, 0.40093547), (3, 0.075636655), (4, 0.20806746)]
# [(0, 0.4108711), (1, 0.1233804), (2, 0.11753194), (3, 0.11330477), (4, 0.23491177)]
# [(0, 0.2119355), (1, 0.09607957), (2, 0.34010652), (3, 0.15892297), (4, 0.19295543)]
# [(0, 0.33658406), (1, 0.110316515), (2, 0.13095023), (3, 0.010945553), (4, 0.41120365)]
# [(0, 0.49893063), (1, 0.20551798), (4, 0.2787315)]
# [(0, 0.1145533), (1, 0.73785424), (2, 0.06017031), (3, 0.0476212), (4, 0.039800912)]
# [(0, 0.8279559), (1, 0.060228873), (2, 0.046133418), (3, 0.035823204), (4, 0.029858653)]
# [(0, 0.5300339), (1, 0.13114369), (2, 0.010334929), (3, 0.24360028), (4, 0.08488725)]
# [(0, 0.4976928), (1, 0.09845175), (2, 0.1900352), (4, 0.204324)]
# [(0, 0.4236862), (1, 0.10658854), (2, 0.05789029), (3, 0.049947377), (4, 0.36188757)]
# [(0, 0.26242155), (1, 0.17583415), (2, 0.1682603), (3, 0.16327628), (4, 0.23020773)]
# [(0, 0.4810364), (1, 0.13725895), (2, 0.13015005), (3, 0.01579576), (4, 0.23575886)]
# [(0, 0.6666001), (1, 0.24595547), (2, 0.03513906), (3, 0.028427768), (4, 0.023877546)]
# [(0, 0.01590042), (1, 0.16229382), (2, 0.2944463), (3, 0.27593148), (4, 0.25142798)]
# [(0, 0.22217925), (1, 0.40499058), (2, 0.16261582), (3, 0.02368986), (4, 0.18652444)]
# [(0, 0.1680648), (1, 0.12890173), (2, 0.059772663), (3, 0.5995041), (4, 0.043756716)]
# [(0, 0.46654052), (1, 0.44602385), (2, 0.035138726), (3, 0.028427744), (4, 0.023869127)]
# [(0, 0.11094594), (1, 0.4099979), (2, 0.05856436), (3, 0.047379542), (4, 0.3731123)]
# [(0, 0.53202385), (1, 0.19073893), (2, 0.010335146), (3, 0.19825613), (4, 0.06864599)]
# [(0, 0.26915634), (1, 0.046012104), (2, 0.43244776), (3, 0.028428609), (4, 0.2239552)]
# [(0, 0.46510464), (1, 0.03285536), (2, 0.16801792), (3, 0.020305596), (4, 0.3137165)]
# [(0, 0.57864517), (1, 0.11181555), (2, 0.015972195), (3, 0.012921709), (4, 0.28064534)]
# [(0, 0.7696751), (1, 0.019356027), (2, 0.014777505), (3, 0.011867539), (4, 0.18432383)]
# [(0, 0.50286555), (1, 0.02100079), (2, 0.2606203), (3, 0.012932947), (4, 0.20258039)]
# [(0, 0.18448651), (1, 0.2670221), (2, 0.19202788), (3, 0.15189716), (4, 0.20456637)]
# [(0, 0.30439872), (1, 0.37041682), (2, 0.2727643), (3, 0.028541971), (4, 0.023878219)]
# [(0, 0.48338714), (1, 0.25772396), (2, 0.20657253), (3, 0.02844588), (4, 0.023870524)]
# [(0, 0.58321047), (1, 0.30749518), (2, 0.04392329), (3, 0.03553466), (4, 0.029836407)]
# [(0, 0.26658607), (1, 0.24600895), (2, 0.23508027), (3, 0.028427765), (4, 0.22389695)]
# [(0, 0.8612751), (1, 0.051212974), (2, 0.035159953), (3, 0.028430518), (4, 0.023921477)]
# [(0, 0.4861836), (1, 0.12233767), (2, 0.14619797), (3, 0.012936437), (4, 0.2323443)]
# [(0, 0.77761215), (1, 0.07666194), (2, 0.058564495), (3, 0.047379572), (4, 0.03978188)]
# [(0, 0.21178257), (1, 0.014374197), (2, 0.19851099), (4, 0.56644857)]
# [(0, 0.29238287), (1, 0.6195564), (2, 0.035673473), (3, 0.028511439), (4, 0.023875812)]
# [(0, 0.19601247), (1, 0.13144855), (2, 0.30414474), (3, 0.067386955), (4, 0.30100727)]
# [(0, 0.23753478), (1, 0.24579291), (2, 0.47303712), (3, 0.023740185), (4, 0.019895)]
# [(0, 0.5832228), (1, 0.057496764), (2, 0.2939093), (3, 0.03553472), (4, 0.029836418)]
# [(0, 0.4098487), (1, 0.15424392), (2, 0.13572432), (3, 0.065997325), (4, 0.23418573)]
# [(0, 0.34537798), (1, 0.03318059), (2, 0.025125388), (3, 0.020305527), (4, 0.5760105)]
# [(0, 0.28050953), (1, 0.04638839), (2, 0.4022556), (3, 0.028474446), (4, 0.24237204)]
# [(0, 0.1155225), (1, 0.0789141), (2, 0.25016525), (3, 0.04763095), (4, 0.5077672)]
# [(0, 0.16660888), (1, 0.52872753), (2, 0.021961788), (3, 0.017767357), (4, 0.2649345)]
# [(0, 0.07193864), (1, 0.046925), (2, 0.035810687), (3, 0.02853429), (4, 0.81679136)]
# [(0, 0.366934), (1, 0.06378369), (2, 0.086205624), (3, 0.06354269), (4, 0.41953403)]
# [(0, 0.77510566), (1, 0.07916858), (2, 0.05856435), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.0679521), (1, 0.3378038), (2, 0.035735235), (3, 0.028523844), (4, 0.529985)]
# [(0, 0.5219207), (1, 0.015426543), (2, 0.011803302), (3, 0.0952948), (4, 0.3555547)]
# [(0, 0.5846393), (1, 0.11183646), (2, 0.015972268), (3, 0.012921721), (4, 0.2746302)]
# [(0, 0.7952471), (1, 0.025927557), (2, 0.01979292), (3, 0.015836926), (4, 0.14319558)]
# [(0, 0.08491963), (1, 0.05851014), (2, 0.044660956), (3, 0.78206354), (4, 0.029845774)]
# [(0, 0.3123774), (1, 0.21546182), (2, 0.34727392), (3, 0.11403012), (4, 0.010856749)]
# [(0, 0.4924246), (1, 0.22583567), (2, 0.145273), (3, 0.012936034), (4, 0.12353065)]
# [(0, 0.61849654), (1, 0.17604166), (2, 0.025101898), (3, 0.02030601), (4, 0.16005391)]
# [(0, 0.2776398), (1, 0.046265908), (2, 0.42368278), (3, 0.22854236), (4, 0.023869134)]
# [(0, 0.51023066), (1, 0.046564054), (2, 0.035550147), (3, 0.38378066), (4, 0.023874484)]
# [(0, 0.11094601), (1, 0.07666179), (2, 0.05856439), (3, 0.38070917), (4, 0.37311864)]
# [(0, 0.7107226), (1, 0.034229167), (2, 0.025099011), (3, 0.02030552), (4, 0.20964368)]
# [(0, 0.5831552), (1, 0.05749645), (2, 0.29395527), (3, 0.03553468), (4, 0.02985838)]
# [(0, 0.11000635), (1, 0.05749633), (2, 0.043923285), (3, 0.28551674), (4, 0.5030573)]
# [(0, 0.3016226), (1, 0.17064752), (2, 0.02209919), (3, 0.35677648), (4, 0.14885423)]
# [(0, 0.39685062), (1, 0.24784358), (2, 0.019521724), (3, 0.23823264), (4, 0.09755148)]
# [(0, 0.44427812), (1, 0.076661736), (2, 0.05856435), (3, 0.047379542), (4, 0.37311623)]
# [(0, 0.12286744), (1, 0.38604668), (2, 0.19393297), (3, 0.1042841), (4, 0.19286886)]
# [(0, 0.47127414), (1, 0.18625109), (2, 0.012630096), (3, 0.18200204), (4, 0.14784263)]
# [(0, 0.22220546), (1, 0.041601192), (2, 0.02928231), (3, 0.35699096), (4, 0.34992006)]
# [(0, 0.28637075), (1, 0.045998197), (2, 0.23530746), (3, 0.02842777), (4, 0.4038958)]
# [(0, 0.73995817), (1, 0.21146342), (2, 0.019522337), (3, 0.015793184), (4, 0.013262874)]
# [(0, 0.48034605), (1, 0.18076669), (2, 0.012626775), (3, 0.010232071), (4, 0.31602842)]
# [(0, 0.20994529), (1, 0.012891665), (2, 0.11571503), (3, 0.11606089), (4, 0.5453871)]
# [(0, 0.54013777), (1, 0.10659468), (2, 0.11562526), (3, 0.055885676), (4, 0.18175665)]
# [(0, 0.39431244), (1, 0.029256482), (2, 0.022228258), (3, 0.28500795), (4, 0.2691949)]
# [(0, 0.44427744), (1, 0.40999678), (2, 0.05856438), (3, 0.047379553), (4, 0.03978188)]
# [(0, 0.48068684), (1, 0.3187067), (2, 0.025099674), (3, 0.020305634), (4, 0.15520115)]
# [(0, 0.46126202), (1, 0.1822228), (2, 0.17945777), (3, 0.11889689), (4, 0.05816056)]
# [(0, 0.48883393), (1, 0.26493904), (2, 0.14259669), (3, 0.010933756), (4, 0.09269659)]
# [(0, 0.5832037), (1, 0.057496395), (2, 0.04392333), (3, 0.03553467), (4, 0.27984193)]
# [(0, 0.46373716), (2, 0.20269078), (3, 0.07018028), (4, 0.2557256)]
# [(0, 0.6064326), (1, 0.015505714), (2, 0.14607859), (4, 0.22249006)]
# [(0, 0.14989386), (1, 0.2333251), (2, 0.1634847), (3, 0.26769292), (4, 0.18560342)]
# [(0, 0.6665001), (1, 0.2460347), (2, 0.035139058), (3, 0.028427798), (4, 0.023898339)]
# [(0, 0.6996873), (1, 0.040434554), (2, 0.029319791), (3, 0.023690118), (4, 0.20686819)]
# [(0, 0.5315737), (1, 0.13250439), (2, 0.14460818), (3, 0.06925374), (4, 0.12206002)]
# [(0, 0.73507243), (1, 0.19202085), (2, 0.029286241), (3, 0.023690276), (4, 0.019930158)]
# [(0, 0.397387), (1, 0.21284004), (2, 0.10816408), (3, 0.07181095), (4, 0.20979795)]
# [(0, 0.068120405), (1, 0.046375513), (2, 0.39078552), (3, 0.028472845), (4, 0.46624574)]
# [(0, 0.21340123), (1, 0.32698935), (2, 0.010980976), (4, 0.43974468)]
# [(0, 0.08054974), (1, 0.322764), (2, 0.21970956), (3, 0.19040294), (4, 0.18657374)]
# [(0, 0.44689557), (1, 0.17998824), (2, 0.34039727), (3, 0.01779826), (4, 0.014920694)]
# [(0, 0.512196), (1, 0.0209079), (2, 0.2886974), (3, 0.012921709), (4, 0.16527702)]
# [(0, 0.06709327), (1, 0.2699908), (2, 0.610559), (3, 0.02848407), (4, 0.023872845)]
# [(0, 0.4473069), (1, 0.17776044), (2, 0.02214974), (3, 0.20032896), (4, 0.152454)]
# [(0, 0.5225521), (1, 0.12924519), (2, 0.016110606), (3, 0.012944358), (4, 0.31914777)]
# [(0, 0.5191927), (1, 0.078615464), (2, 0.31479216), (3, 0.047600366), (4, 0.03979932)]
# [(0, 0.0665778), (1, 0.44704542), (2, 0.43407908), (3, 0.028428491), (4, 0.02386919)]
# [(0, 0.33503798), (1, 0.032855306), (2, 0.02509917), (3, 0.020305585), (4, 0.5867019)]
# [(0, 0.43035352), (1, 0.4963268), (2, 0.029671116), (3, 0.023752633), (4, 0.019895969)]
# [(0, 0.56282526), (1, 0.14014323), (2, 0.08179536), (3, 0.14434981), (4, 0.07088638)]
# [(0, 0.49308398), (1, 0.019406555), (2, 0.31451076), (3, 0.16305053)]
# [(0, 0.048621207), (1, 0.17571318), (2, 0.31081358), (3, 0.020305518), (4, 0.44454652)]
# [(0, 0.3634728), (1, 0.34928617), (2, 0.24981806), (3, 0.020332893), (4, 0.017090118)]
# [(0, 0.6644442), (1, 0.015339508), (2, 0.14535677), (4, 0.16537584)]
# [(0, 0.86656743), (1, 0.045997087), (2, 0.035138644), (3, 0.028427731), (4, 0.023869127)]
# [(0, 0.3785068), (1, 0.51065785), (2, 0.04531549), (3, 0.035672493), (4, 0.029847348)]
# [(0, 0.7684365), (1, 0.08583773), (2, 0.058564346), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.4261063), (1, 0.07687947), (2, 0.010980929), (3, 0.07105088), (4, 0.41498244)]
# [(0, 0.38260895), (1, 0.3185637), (2, 0.025099097), (3, 0.2566789), (4, 0.017049378)]
# [(0, 0.39752656), (1, 0.2091421), (2, 0.18446091), (3, 0.012926366), (4, 0.19594401)]
# [(0, 0.37054437), (1, 0.20737317), (2, 0.1363837), (3, 0.13010228), (4, 0.1555965)]
# [(0, 0.66709214), (1, 0.045997158), (2, 0.035138696), (3, 0.22790273), (4, 0.023869311)]
# [(0, 0.46605358), (1, 0.21235344), (2, 0.013055904), (3, 0.094381265), (4, 0.21415582)]
# [(0, 0.33382428), (1, 0.28159997), (2, 0.1709881), (3, 0.10179254), (4, 0.1117951)]
# [(0, 0.37514067), (1, 0.111580156), (2, 0.058975853), (3, 0.17607868), (4, 0.27822465)]
# [(0, 0.4442465), (1, 0.41002727), (2, 0.058564737), (3, 0.047379613), (4, 0.039781883)]
# [(0, 0.3841535), (1, 0.1468675), (2, 0.32328668), (3, 0.01580782), (4, 0.1298845)]
# [(0, 0.39049482), (1, 0.12954831), (2, 0.046870712), (3, 0.08430815), (4, 0.348778)]
# [(0, 0.5943903), (1, 0.3688452), (2, 0.014835686), (3, 0.011980812)]
# [(0, 0.57827526), (1, 0.27174118), (2, 0.012850868), (3, 0.010210333), (4, 0.12692235)]
# [(0, 0.22591896), (1, 0.31764475), (2, 0.029723192), (3, 0.23663454), (4, 0.19007857)]
# [(0, 0.43264583), (1, 0.20294732), (2, 0.19793342), (3, 0.012921706), (4, 0.15355168)]
# [(0, 0.44100198), (1, 0.046477765), (2, 0.24745724), (3, 0.028427744), (4, 0.23663525)]
# [(0, 0.5576071), (1, 0.16851366), (2, 0.02512486), (3, 0.020309804), (4, 0.22844459)]
# [(0, 0.32996732), (1, 0.0592035), (2, 0.043924376), (3, 0.28548378), (4, 0.28142104)]
# [(0, 0.24651568), (1, 0.5459985), (2, 0.029568635), (3, 0.023714261), (4, 0.15420297)]
# [(0, 0.33320665), (1, 0.05749636), (2, 0.043923307), (3, 0.2855352), (4, 0.2798385)]
# [(0, 0.7776125), (1, 0.076661736), (2, 0.05856435), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.58322346), (1, 0.30748174), (2, 0.043923683), (3, 0.03553471), (4, 0.029836416)]
# [(0, 0.38872147), (1, 0.20500763), (2, 0.36268976), (3, 0.023690201), (4, 0.01989094)]
# [(0, 0.4443135), (1, 0.07666285), (2, 0.058565184), (3, 0.38067654), (4, 0.039781887)]
# [(0, 0.44438), (1, 0.30858234), (2, 0.0112238405), (4, 0.22687483)]
# [(0, 0.5182105), (1, 0.102488555), (2, 0.097974926), (3, 0.011865546), (4, 0.26946053)]
# [(0, 0.5113548), (1, 0.045999754), (2, 0.035139088), (3, 0.028427724), (4, 0.37907863)]
# [(0, 0.08381963), (1, 0.057523206), (2, 0.04401824), (3, 0.035543036), (4, 0.7790959)]
# [(0, 0.27572304), (1, 0.27323523), (2, 0.39871114), (3, 0.028458944), (4, 0.023871649)]
# [(0, 0.20171966), (1, 0.03317153), (2, 0.025325654), (3, 0.23444246), (4, 0.5053407)]
# [(0, 0.44043323), (1, 0.028932976), (2, 0.20871004), (3, 0.17646483), (4, 0.14545895)]
# [(0, 0.19708255), (1, 0.1014895), (2, 0.26601607), (3, 0.010163653), (4, 0.42524824)]
# [(0, 0.19785549), (1, 0.19392002), (2, 0.23687279), (3, 0.20182264), (4, 0.16952907)]
# [(0, 0.22213358), (1, 0.3716583), (2, 0.19595848), (3, 0.023689775), (4, 0.18655984)]
# [(0, 0.43481424), (1, 0.18899927), (2, 0.09642518), (3, 0.12200736), (4, 0.15775396)]
# [(0, 0.06657589), (1, 0.44599876), (2, 0.03513861), (3, 0.22842045), (4, 0.22386625)]
# [(0, 0.35800073), (1, 0.057497654), (2, 0.0439239), (3, 0.035534665), (4, 0.505043)]
# [(0, 0.3331842), (1, 0.3075055), (2, 0.043923337), (3, 0.2855506), (4, 0.02983641)]
# [(0, 0.4716443), (1, 0.039174642), (2, 0.22212385), (3, 0.023833165), (4, 0.24322402)]
# [(0, 0.4896195), (1, 0.055777077), (2, 0.065774515), (3, 0.33384588), (4, 0.05498302)]
# [(0, 0.38625976), (1, 0.31478786), (2, 0.043988056), (3, 0.22510792), (4, 0.02985644)]
# [(0, 0.3573743), (1, 0.10847792), (2, 0.22749776), (3, 0.10670391), (4, 0.19994606)]
# [(0, 0.47477463), (1, 0.07694293), (2, 0.05857261), (3, 0.047405753), (4, 0.3423041)]
# ...
# [(0, 0.4245326), (1, 0.0597429), (2, 0.045638196), (3, 0.035777777), (4, 0.4343086)]
# [(0, 0.28577766), (1, 0.10835952), (2, 0.22655888), (3, 0.10680726), (4, 0.27249667)]
# [(0, 0.15191515), (1, 0.28735444), (2, 0.24499589), (3, 0.1158805), (4, 0.199854)]
# [(0, 0.48611492), (1, 0.046321705), (2, 0.41502506), (3, 0.028666552), (4, 0.02387176)]
# [(0, 0.06950803), (1, 0.27311203), (2, 0.39699078), (3, 0.02845863), (4, 0.23193052)]
# [(0, 0.7036602), (1, 0.025553979), (2, 0.019521497), (3, 0.01579319), (4, 0.23547114)]
# [(0, 0.27443725), (1, 0.24606946), (2, 0.03513924), (3, 0.028427845), (4, 0.41592625)]
# [(0, 0.30195373), (1, 0.35912055), (2, 0.035826832), (3, 0.028536042), (4, 0.2745629)]
# [(0, 0.33364528), (1, 0.05749651), (2, 0.043923415), (3, 0.035534687), (4, 0.52940017)]
# [(0, 0.47561854), (1, 0.077256516), (2, 0.07360554), (4, 0.36463094)]
# [(0, 0.36070663), (1, 0.057499632), (2, 0.043923892), (3, 0.035534658), (4, 0.5023352)]
# [(0, 0.06656983), (1, 0.24573962), (2, 0.03514325), (3, 0.42878205), (4, 0.22376525)]
# [(0, 0.5892195), (1, 0.048264205), (2, 0.035402358), (3, 0.30324122), (4, 0.023872662)]
# [(0, 0.37852), (1, 0.5106542), (2, 0.04530601), (3, 0.035672467), (4, 0.029847346)]
# [(0, 0.3454802), (1, 0.057912223), (2, 0.53119147), (3, 0.03557637), (4, 0.029839775)]
# [(0, 0.83312136), (1, 0.05750161), (2, 0.0439259), (3, 0.035534732), (4, 0.02991639)]
# [(0, 0.77741814), (1, 0.07667261), (2, 0.05856976), (3, 0.047379706), (4, 0.039959833)]
# [(0, 0.51257145), (1, 0.28811422), (2, 0.019665837), (3, 0.16638596), (4, 0.013262547)]
# [(0, 0.8280863), (1, 0.05968808), (2, 0.046005934), (3, 0.03623408), (4, 0.029985627)]
# [(0, 0.59254396), (1, 0.025553992), (2, 0.019521508), (3, 0.12689039), (4, 0.23549011)]
# [(0, 0.7220516), (1, 0.20508367), (2, 0.029283777), (3, 0.02368997), (4, 0.01989095)]
# [(0, 0.6187259), (1, 0.033055846), (2, 0.31086326), (3, 0.020305553), (4, 0.017049426)]
# [(0, 0.46036953), (1, 0.017964244), (2, 0.37246615), (3, 0.010944853), (4, 0.13825522)]
# [(0, 0.519262), (1, 0.0786182), (2, 0.31471983), (3, 0.047600627), (4, 0.03979934)]
# [(0, 0.83205765), (1, 0.058647472), (2, 0.043923765), (3, 0.035534736), (4, 0.029836414)]
# [(0, 0.5738411), (1, 0.025671003), (2, 0.37135646), (3, 0.01586969), (4, 0.013261778)]
# [(0, 0.66651565), (1, 0.24604838), (2, 0.035139073), (3, 0.0284278), (4, 0.023869133)]
# [(0, 0.5391587), (1, 0.14619401), (2, 0.08273191), (4, 0.22300814)]
# [(0, 0.3328044), (1, 0.5578994), (2, 0.043924864), (3, 0.035534915), (4, 0.029836431)]
# [(0, 0.22908531), (1, 0.038536247), (2, 0.5126992), (3, 0.023714544), (4, 0.19596472)]
# [(0, 0.8331211), (1, 0.057501666), (2, 0.04392595), (3, 0.03553474), (4, 0.02991653)]
# [(0, 0.6471147), (1, 0.029673366), (2, 0.021961836), (3, 0.017767329), (4, 0.28348276)]
# [(0, 0.3614639), (1, 0.1859309), (2, 0.097595416), (3, 0.09497354), (4, 0.26003626)]
# [(0, 0.17044565), (1, 0.02885989), (2, 0.3437042), (3, 0.31203908), (4, 0.14495116)]
# [(0, 0.43587697), (1, 0.1688931), (2, 0.20648916), (3, 0.1737826), (4, 0.014958149)]
# [(0, 0.090224534), (1, 0.31606603), (2, 0.043999042), (3, 0.03585173), (4, 0.51385874)]
# [(0, 0.8280529), (1, 0.060211893), (2, 0.046055704), (3, 0.035820987), (4, 0.029858543)]
# [(0, 0.5831617), (1, 0.057497412), (2, 0.04392402), (3, 0.035534777), (4, 0.27988207)]
# [(0, 0.54574156), (1, 0.11990235), (2, 0.16129659), (4, 0.1668703)]
# [(0, 0.56825495), (1, 0.19045268), (2, 0.067969814), (3, 0.06452725), (4, 0.10879533)]
# [(0, 0.33280438), (1, 0.5578995), (2, 0.04392486), (3, 0.03553491), (4, 0.02983643)]
# [(0, 0.8332094), (1, 0.057496306), (2, 0.043923266), (3, 0.035534658), (4, 0.029836407)]
# [(0, 0.09117185), (1, 0.55790794), (2, 0.19405128), (4, 0.14738628)]
# [(0, 0.517968), (1, 0.01941196), (2, 0.014817811), (3, 0.16572945), (4, 0.28207278)]
# [(0, 0.1273661), (1, 0.7250231), (2, 0.060183767), (3, 0.047625754), (4, 0.03980126)]
# [(0, 0.7776098), (1, 0.07666321), (2, 0.058565352), (3, 0.047379702), (4, 0.03978189)]
# [(0, 0.6662509), (1, 0.04600076), (2, 0.03532103), (3, 0.028428087), (4, 0.22399923)]
# [(0, 0.11101357), (1, 0.07941456), (2, 0.058564346), (3, 0.04737954), (4, 0.703628)]
# [(0, 0.4442649), (1, 0.07666201), (2, 0.058564577), (3, 0.04737958), (4, 0.37312892)]
# [(0, 0.560238), (1, 0.3515526), (2, 0.035808384), (3, 0.028520986), (4, 0.023880033)]
# [(0, 0.5824502), (1, 0.30812043), (2, 0.0439274), (3, 0.035534784), (4, 0.02996714)]
# [(0, 0.51016027), (1, 0.046563536), (2, 0.035544716), (3, 0.38385656), (4, 0.023874953)]
# [(0, 0.44427982), (1, 0.40999442), (2, 0.05856435), (3, 0.047379546), (4, 0.03978188)]
# [(0, 0.11094805), (1, 0.40987316), (2, 0.39201722), (3, 0.047379702), (4, 0.039781895)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.05856434), (3, 0.04737954), (4, 0.039781876)]
# [(0, 0.2869758), (1, 0.44600582), (2, 0.21472147), (3, 0.028427731), (4, 0.023869127)]
# [(0, 0.3325411), (1, 0.03919907), (2, 0.030134767), (3, 0.023772392), (4, 0.5743527)]
# [(0, 0.3888212), (1, 0.03833115), (2, 0.029282376), (3, 0.19039266), (4, 0.35317257)]
# [(0, 0.3891439), (1, 0.4587833), (2, 0.12592311), (3, 0.014213997), (4, 0.011935654)]
# [(0, 0.11027304), (1, 0.52902263), (2, 0.04392345), (3, 0.0355347), (4, 0.28124624)]
# [(0, 0.49023256), (1, 0.080801226), (2, 0.16573009), (3, 0.07901754), (4, 0.18421859)]
# [(0, 0.8280404), (1, 0.060212046), (2, 0.04606797), (3, 0.035821002), (4, 0.029858543)]
# [(0, 0.44404104), (1, 0.41023058), (2, 0.05856658), (3, 0.047379903), (4, 0.039781913)]
# [(0, 0.26534933), (1, 0.045999046), (2, 0.03514035), (3, 0.42954883), (4, 0.2239625)]
# [(0, 0.4399213), (1, 0.07893693), (2, 0.05856453), (3, 0.047379583), (4, 0.37519768)]
# [(0, 0.43526426), (1, 0.4547028), (2, 0.044096243), (3, 0.03603772), (4, 0.02989899)]
# [(0, 0.36729026), (1, 0.03873016), (2, 0.50534964), (3, 0.023733182), (4, 0.06489676)]
# [(0, 0.66667986), (1, 0.045997385), (2, 0.23502548), (3, 0.028428158), (4, 0.02386913)]
# [(0, 0.28988728), (1, 0.13954914), (2, 0.010366916), (3, 0.21290536), (4, 0.3472913)]
# [(0, 0.58320045), (1, 0.057496823), (2, 0.0439233), (3, 0.285543), (4, 0.029836407)]
# [(0, 0.66213566), (1, 0.05870877), (2, 0.21361187), (3, 0.035650693), (4, 0.029892981)]
# [(0, 0.40202302), (1, 0.13105275), (2, 0.3482563), (4, 0.10911632)]
# [(0, 0.3606971), (1, 0.057499606), (2, 0.043923877), (3, 0.035534654), (4, 0.5023448)]
# [(0, 0.44423842), (1, 0.07666202), (2, 0.058564585), (3, 0.38075307), (4, 0.03978188)]
# [(0, 0.613822), (1, 0.03285752), (2, 0.17351018), (3, 0.16272615), (4, 0.017084192)]
# [(0, 0.44404104), (1, 0.41023058), (2, 0.05856658), (3, 0.047379903), (4, 0.039781913)]
# [(0, 0.36111584), (1, 0.019166077), (2, 0.18057142), (3, 0.3458948), (4, 0.09325186)]
# [(0, 0.115997605), (1, 0.07666179), (2, 0.05856439), (3, 0.04737955), (4, 0.7013967)]
# [(0, 0.48161444), (1, 0.025555087), (2, 0.019522319), (3, 0.12658815), (4, 0.34671998)]
# [(0, 0.40041625), (1, 0.46303982), (2, 0.019582018), (3, 0.10370085), (4, 0.013261071)]
# [(0, 0.37394762), (1, 0.15801574), (2, 0.017845642), (3, 0.2058917), (4, 0.24429932)]
# [(0, 0.4259249), (1, 0.20522393), (2, 0.029283024), (3, 0.023689842), (4, 0.31587827)]
# [(0, 0.13625164), (1, 0.045997784), (2, 0.035138607), (3, 0.028427726), (4, 0.75418425)]
# [(0, 0.5169382), (1, 0.15945932), (2, 0.29451945), (3, 0.015820198), (4, 0.0132628)]
# [(0, 0.26653734), (1, 0.24602142), (2, 0.23517847), (3, 0.028427761), (4, 0.22383499)]
# [(0, 0.77743036), (1, 0.076672606), (2, 0.058569755), (3, 0.047379706), (4, 0.03994761)]
# [(0, 0.6366062), (1, 0.2759307), (2, 0.03513881), (3, 0.028427754), (4, 0.023896482)]
# [(0, 0.4672617), (1, 0.20255943), (2, 0.022360545), (3, 0.017888028), (4, 0.28993034)]
# [(0, 0.444266), (1, 0.41000816), (2, 0.058564443), (3, 0.047379557), (4, 0.03978188)]
# [(0, 0.33321333), (1, 0.30750966), (2, 0.043923426), (3, 0.035534684), (4, 0.27981892)]
# [(0, 0.4431827), (1, 0.27998918), (2, 0.021972502), (3, 0.23992452), (4, 0.014931111)]
# [(0, 0.7774331), (1, 0.07667113), (2, 0.05856875), (3, 0.047379542), (4, 0.039947484)]
# [(0, 0.08377496), (1, 0.34236392), (2, 0.50844693), (3, 0.035574563), (4, 0.029839635)]
# [(0, 0.43615693), (1, 0.19429737), (2, 0.07877121), (4, 0.28287178)]
# [(0, 0.113927364), (1, 0.73799175), (2, 0.060702022), (3, 0.047581002), (4, 0.039797824)]
# [(0, 0.5372233), (1, 0.1481381), (2, 0.0117807295), (4, 0.29337052)]
# [(0, 0.11526791), (1, 0.07666629), (2, 0.39253354), (3, 0.04737954), (4, 0.36815274)]
# [(0, 0.47620296), (1, 0.032866918), (2, 0.3110066), (3, 0.16287409), (4, 0.017049406)]
# [(0, 0.6692888), (1, 0.039244633), (2, 0.029964253), (3, 0.023793625), (4, 0.23770873)]
# [(0, 0.57627535), (1, 0.123032436), (2, 0.11762122), (3, 0.0142138805), (4, 0.1688571)]
# [(0, 0.17210573), (1, 0.45276278), (2, 0.022077741), (3, 0.33812785), (4, 0.014925941)]
# [(0, 0.27965322), (1, 0.04599865), (2, 0.035138912), (3, 0.028427724), (4, 0.6107815)]
# [(0, 0.5943004), (1, 0.11741674), (2, 0.014760944), (3, 0.011864491), (4, 0.26165742)]
# [(0, 0.4442843), (1, 0.07666207), (2, 0.39189216), (3, 0.047379587), (4, 0.03978188)]
# [(0, 0.9326992), (1, 0.023303965), (2, 0.017787943), (3, 0.014249623), (4, 0.011959242)]
# [(0, 0.5920622), (1, 0.038646165), (2, 0.3256702), (3, 0.023727452), (4, 0.019893972)]
# [(0, 0.4676197), (1, 0.19920133), (2, 0.02235798), (3, 0.2958829), (4, 0.014938082)]
# [(0, 0.33318162), (1, 0.057496395), (2, 0.04392333), (3, 0.5355622), (4, 0.029836409)]
# [(0, 0.444218), (1, 0.40999225), (2, 0.058564436), (3, 0.047379557), (4, 0.039845735)]
# [(0, 0.5122138), (1, 0.18070406), (2, 0.15512772), (3, 0.0142694665), (4, 0.13768493)]
# [(0, 0.66654867), (1, 0.045997173), (2, 0.03513872), (3, 0.22844632), (4, 0.023869127)]
# [(0, 0.30734712), (1, 0.1498552), (2, 0.07861968), (3, 0.07601191), (4, 0.3881661)]
# [(0, 0.36459306), (1, 0.40973645), (2, 0.025391832), (3, 0.020353489), (4, 0.17992516)]
# [(0, 0.51018775), (1, 0.04656408), (2, 0.035549738), (3, 0.38382393), (4, 0.023874486)]
# [(0, 0.22885996), (1, 0.22473226), (2, 0.3031238), (3, 0.22339116), (4, 0.019892808)]
# [(0, 0.33320928), (1, 0.05749648), (2, 0.29397053), (3, 0.03553468), (4, 0.27978906)]
# [(0, 0.37851945), (1, 0.5106553), (2, 0.04530552), (3, 0.03567246), (4, 0.029847344)]
# [(0, 0.44438544), (1, 0.07666505), (2, 0.058566805), (3, 0.38060078), (4, 0.039781902)]
# [(0, 0.21406795), (1, 0.03331634), (2, 0.025432825), (3, 0.020359542), (4, 0.70682335)]
# [(0, 0.45427498), (1, 0.376007), (2, 0.017790835), (3, 0.13998654), (4, 0.011940625)]
# [(0, 0.34550714), (1, 0.2789332), (2, 0.044172466), (3, 0.035576418), (4, 0.29581076)]
# [(0, 0.592656), (1, 0.025555398), (2, 0.13054188), (3, 0.015793266), (4, 0.2354534)]
# [(0, 0.49554732), (1, 0.02875041), (2, 0.14741847), (3, 0.13534021), (4, 0.19294362)]
# [(0, 0.4440411), (1, 0.41023055), (2, 0.058566574), (3, 0.0473799), (4, 0.03978191)]
# [(0, 0.2793463), (1, 0.046369098), (2, 0.0354099), (3, 0.61500204), (4, 0.023872707)]
# [(0, 0.7776125), (1, 0.07666173), (2, 0.058564346), (3, 0.047379542), (4, 0.039781876)]
# [(0, 0.055473894), (1, 0.03833144), (2, 0.1959229), (3, 0.5237623), (4, 0.1865095)]
# [(0, 0.6183316), (1, 0.045016944), (2, 0.029302003), (3, 0.023692867), (4, 0.28365657)]
# [(0, 0.7776098), (1, 0.0766632), (2, 0.058565352), (3, 0.047379702), (4, 0.03978189)]
# [(0, 0.6413564), (1, 0.2851802), (2, 0.029794432), (3, 0.023771452), (4, 0.01989744)]
# [(0, 0.6587995), (1, 0.033580173), (2, 0.27023196), (3, 0.020336451), (4, 0.017051872)]
# [(0, 0.58398426), (1, 0.017691577), (2, 0.090507396), (3, 0.010933772), (4, 0.296883)]
# [(0, 0.4761173), (1, 0.033469826), (2, 0.025099097), (3, 0.020305533), (4, 0.44500822)]
# [(0, 0.08359072), (1, 0.057714112), (2, 0.044082273), (3, 0.035560504), (4, 0.7790524)]
# [(0, 0.73328245), (1, 0.022999942), (2, 0.11774276), (3, 0.114027224), (4, 0.011947626)]
# [(0, 0.8288363), (1, 0.061869252), (2, 0.043923274), (3, 0.035534665), (4, 0.029836519)]
# [(0, 0.49624965), (1, 0.19395249), (2, 0.27242017), (3, 0.020326624), (4, 0.017051082)]
# [(0, 0.04830252), (1, 0.1867421), (2, 0.42503172), (3, 0.17506064), (4, 0.164863)]
# [(0, 0.5820142), (1, 0.058272887), (2, 0.04418935), (3, 0.2856781), (4, 0.029845493)]
# [(0, 0.224151), (1, 0.12655377), (2, 0.30083272), (3, 0.1373927), (4, 0.2110698)]
# [(0, 0.6333092), (1, 0.1230125), (2, 0.117614925), (3, 0.014213895), (4, 0.11184955)]
# [(0, 0.46664095), (1, 0.045998275), (2, 0.035139333), (3, 0.22855937), (4, 0.22366202)]
# [(0, 0.56786966), (1, 0.057497513), (2, 0.043924138), (3, 0.035534807), (4, 0.29517388)]
# [(0, 0.40446153), (1, 0.038540974), (2, 0.51338917), (3, 0.023715349), (4, 0.019892978)]
# [(0, 0.20067589), (1, 0.033141598), (2, 0.29426068), (3, 0.4548697), (4, 0.017052129)]
# [(0, 0.35900676), (1, 0.057630952), (2, 0.043931827), (3, 0.035680704), (4, 0.5037498)]
# [(0, 0.26638138), (1, 0.24603565), (2, 0.23532379), (3, 0.028427789), (4, 0.22383137)]
# [(0, 0.5554685), (1, 0.038330987), (2, 0.029282272), (3, 0.023689786), (4, 0.35322845)]
# [(0, 0.24477804), (1, 0.27108407), (2, 0.029725075), (3, 0.43451616), (4, 0.019896666)]
# [(0, 0.7774222), (1, 0.07667261), (2, 0.05856976), (3, 0.047379706), (4, 0.039955784)]
# [(0, 0.8887935), (1, 0.038330875), (2, 0.02928218), (3, 0.023689771), (4, 0.019903617)]
# [(0, 0.56649625), (1, 0.058277007), (2, 0.30972862), (3, 0.035611268), (4, 0.029886855)]
# [(0, 0.3019578), (1, 0.3592908), (2, 0.035826813), (3, 0.02853617), (4, 0.27438837)]
# [(0, 0.3607074), (1, 0.057499632), (2, 0.043923892), (3, 0.035534658), (4, 0.5023344)]
# [(0, 0.23360915), (1, 0.32456383), (2, 0.22037748), (3, 0.20951486), (4, 0.011934695)]
# [(0, 0.51026976), (1, 0.046564605), (2, 0.035548497), (3, 0.3837426), (4, 0.023874491)]
# [(0, 0.33296), (1, 0.30769473), (2, 0.043925215), (3, 0.035534963), (4, 0.27988505)]
# [(0, 0.27013633), (1, 0.27489865), (2, 0.17229617), (3, 0.15188175), (4, 0.13078707)]
# [(0, 0.6380992), (1, 0.059847172), (2, 0.23668256), (3, 0.035534676), (4, 0.02983641)]
# [(0, 0.29207906), (2, 0.15576133), (3, 0.2859159), (4, 0.2587468)]
# [(0, 0.27050546), (1, 0.44649455), (2, 0.035139903), (3, 0.028427947), (4, 0.21943212)]
# [(0, 0.7776098), (1, 0.0766632), (2, 0.058565352), (3, 0.047379702), (4, 0.03978189)]
# [(0, 0.4813156), (1, 0.47010407), (2, 0.019521654), (3, 0.015793212), (4, 0.013265414)]
# [(0, 0.5186991), (1, 0.07861677), (2, 0.31528437), (3, 0.047600422), (4, 0.03979933)]
# [(0, 0.44414166), (1, 0.07666487), (2, 0.058566492), (3, 0.04737988), (4, 0.37324712)]
# [(0, 0.8332094), (1, 0.057496298), (2, 0.043923263), (3, 0.03553466), (4, 0.029836409)]
# [(0, 0.11214418), (1, 0.0773681), (2, 0.72323537), (3, 0.04746374), (4, 0.039788645)]
# [(0, 0.33015943), (1, 0.047127903), (2, 0.035963546), (3, 0.028555855), (4, 0.55819327)]
# [(0, 0.77742916), (1, 0.076672606), (2, 0.058569748), (3, 0.047379702), (4, 0.039948788)]
# [(0, 0.33324775), (1, 0.05749808), (2, 0.043924063), (3, 0.2854455), (4, 0.27988464)]
# [(0, 0.35981235), (1, 0.0192927), (2, 0.30881616), (3, 0.011858977), (4, 0.30021977)]
# [(0, 0.26671287), (1, 0.2457037), (2, 0.035139818), (3, 0.4285318), (4, 0.023911789)]
# [(0, 0.08645215), (1, 0.057500426), (2, 0.2943732), (3, 0.28548214), (4, 0.27619213)]
# [(0, 0.5058468), (1, 0.033111695), (2, 0.2687541), (3, 0.02033623), (4, 0.17195119)]
# [(0, 0.721876), (1, 0.038333703), (2, 0.19616076), (3, 0.023697557), (4, 0.019931957)]
# [(0, 0.6589598), (1, 0.019542241), (2, 0.014989264), (3, 0.011889971), (4, 0.2946187)]
# [(0, 0.42245483), (1, 0.03876994), (2, 0.029605053), (3, 0.30136937), (4, 0.2078008)]
# [(0, 0.2289346), (1, 0.22186165), (2, 0.505597), (3, 0.02371385), (4, 0.019892884)]
# [(0, 0.4954978), (1, 0.029650424), (2, 0.28830922), (3, 0.017830487), (4, 0.16871211)]
# [(0, 0.37905002), (1, 0.026049888), (2, 0.019799653), (3, 0.41122153), (4, 0.16387887)]
# [(0, 0.77761227), (1, 0.07666186), (2, 0.058564454), (3, 0.04737956), (4, 0.039781883)]
# [(0, 0.11790785), (1, 0.10713488), (2, 0.32192677), (3, 0.11390416), (4, 0.33912635)]
# [(0, 0.4245566), (1, 0.059744634), (2, 0.045712203), (3, 0.035777923), (4, 0.4342086)]
# [(0, 0.82797587), (1, 0.060212042), (2, 0.046129853), (3, 0.035821013), (4, 0.029861264)]
# [(0, 0.37266913), (1, 0.058777865), (2, 0.19759858), (3, 0.03565674), (4, 0.33529773)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1              1  ...                         [verifikasi, email, kesel]
# 2              2  ...                     [up, money, bilang, manajemen]
# 3              3  ...                                     [iklan, sebal]
# 4              4  ...                    [nonton, ngapa, kesini, melulu]
# ..           ...  ...                                                ...
# 995          995  ...                                  [barang, lengkap]
# 996          996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 997          997  ...                            [tingkat, promo, ehehe]
# 998          998  ...                                 [bags, barang, ny]
# 999          999  ...                             [pesan, cepat, sampai]
#
# [1000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    657
# 1.0     98
# 2.0     62
# 3.0     37
# 4.0    146
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,1000)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_5topics_with_stemming_alpha_asym_eta_sym.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
