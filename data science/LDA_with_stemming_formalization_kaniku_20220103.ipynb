# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.53.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
import numpy as np, pandas as pd
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  review, rating
FROM
  `future-data-track-1.sapporo_staging.app_review`
WHERE
  created_date BETWEEN "2020-11-01 00:00:00" AND "2021-11-30 23:59:59"
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Ture the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0               Sampah, isi alamat aja kaga muncul centang       1
# 1        Pernah instal. Dan skarng saya uninstall... Ga...       1
# 2        Selamat siang. Saya ingin menanyakan kenapa sa...       1
# 3             not recomended for install, realy bad sevice       1
# 4        Aplikasi ga membantu , cs nya pun ga membantu ...       1
# ...                                                    ...     ...
# 1684250                                  Sangat bermanfaat       5
# 1684251                                  Sangat bermanfaat       5
# 1684252                                  Sangat bermanfaat       5
# 1684253                                  Sangat bermanfaat       5
# 1684254                                  Sangat bermanfaat       5
#
# [1684255 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"belum","cuiiihhh","bangt","selamat","begitu","bhineka","situ","loh","deh"
    ,"mah","yaa","tapi","the","karena","padabal","ttep","sopi","ealah","mas"
    ,"kampreeeeet","busetttt","tahi","ah","sich","tokped","lzd","gada","gatau"
    ,"udh","ttep","ehhh","bosss","wkekwk","bajing","laknat","asuuu","ku","woiii"
    ,"gueeee","njerr","waduhhhh","ma","dunk","dunk","untuk","dll","brupa"
    ,"sangatx","niih","bos","eh","smua","gni","bye","ajah","gilee","luu","ndro"
    ,"dg","kga","min","sm","haisshhh","piye","iki","skali","hehehe","ms","juga"
    ,"fff","mamam","inibsangat","andri","yopiyanto","broo","donk","tes","si"
    ,"ter","dech","wow","oh","toped","dahhhh","grab","ijo","oren","ovo","gopay"
    ,"kredivo","sok","david","gaes","dr","ovonya","bbrp","gmna","bbrpa","and"
    ,"uah","uhahhhhhh","topeeed","ngak","kamu","anj","nge","lah","linkaja"
    ,"gosend","sicepat","jne","yah","goto","gofood","goride","prakerja"
    ,"haduhhhh","pediya","kakak","hhe","bro","bismillah","fuulll","goof"
    ,"assalamualaikum","atsu","pea","you","agan","semenjak","gojek","lagiii"
    ,"lagi","bts","kkzara","cog","aaaaa","sich","cih","ciyy","padahal","ad"
    ,"adlh","ahaha","aj","ak","akika","akkoh","akuwh","alow","anjrit","ap2"
    ,"apasih","aps","aq","aqueh","q","asem","ato","awak","bakalan","bangedh"
    ,"bcanda","beud","bg","bgmn","bgt","bkl","bknnya","blum","boljug","boyeh"
    ,"bs","bt","btw","bwt","byk","can","thanks","d","dah","dapet","de","dek"
    ,"deyh","dgn","disono","dkk","dlu","dngn","dongs","dpt","dri","drmn","drtd"
    ,"dst","duh","egp","eke","ane","ente","elu","emangnya","emng","endak"
    ,"enggak","gaada","gag","gaje","gpp","gan","gbs","geje","ghiy","gimana"
    ,"githu","gj","gn","gt","gpny","gr","gtau","guoblok","ha","haha","hallow"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token
# Out:
#                                                     review  rating
# 0                    sampah isi alamat kaga muncul centang       1
# 1                          instal skarng uninstall gara cs       1
# 2                  siang cashback transaksi bayar cash jam       1
# 3                          recomended install realy sevice       1
# 4        aplikasi bantu cs bantu produk jual rekrut org...       1
# ...                                                    ...     ...
# 1682254                                              bantu       5
# 1682255                                              bantu       5
# 1682256                                              bantu       5
# 1682257                                              bantu       5
# 1682258                                              bantu       5
#
# [1145315 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['sampah', 'isi', 'alamat', 'tidak', 'muncul', 'centang'],
#  ['install', 'sekarang', 'uninstall', 'gara', 'customer service'],
#  ['siang', 'cashback', 'transaksi', 'bayar', 'cash', 'jam'],
#  ['recomended', 'install', 'realy', 'sevice'],
#  ['aplikasi',
#   'bantu',
#   'customer service',
#   'bantu',
#   'produk',
#   'jual',
#   'rekrut',
#   'orang',
#   'ditraining',
#   'pokok'],
#  ['aplikasi'],
#  ['beli', 'token', 'beri', 'promo'],
#  ['pokok'],
#  ['alamat', 'simpan', 'isi'],
#  ['belanja'],
#  ['layanan'],
#  ['proses', 'kirim'],
#  ['beli',
#   'laptop',
#   'bohong',
#   'bayar',
#   'pakai',
#   'bca',
#   'nyak',
#   'stok',
#   'laptop',
#   'instagram',
#   'email',
#   'whatsapp',
#   'respon',
#   'balas',
#   'lama',
#   'bilang',
#   'stok',
#   'siap',
#   'kirim',
#   'setelah',
#   'bayar',
#   'barang',
#   'kunjung',
#   'kirim',
#   'barang',
#   'donauyalan',
#   'kosong',
#   'uang',
#   'diblikan',
#   'benar',
#   'dongkol',
#   'harap',
#   'karma',
#   'balas',
#   'instan'],
#  ['segi', 'promo', 'sedia', 'barang', 'tampil'],
#  ['unduh',
#   'kemarin',
#   'kemarin',
#   'beli',
#   'tv',
#   'chat',
#   'mengaku',
#   'mengaku',
#   'nyuruh',
#   'mencet',
#   'link',
#   'inisatif',
#   'telpon',
#   'pusat',
#   'pusat',
#   'bijak',
#   'seperti',
#   'link',
#   'akun',
#   'google',
#   'jebol',
#   'hack',
#   'chat',
#   'seller',
#   'barang',
#   'kirim',
#   'esok',
#   'chat',
#   'stok',
#   'habis',
#   'kirim',
#   'uang',
#   'balik',
#   'benar'],
#  ['respon',
#   'lambak',
#   'proses',
#   'beli',
#   'bayar',
#   'respon',
#   'dibales',
#   'anggap',
#   'beda',
#   'benar',
#   'beda',
#   'buru'],
#  ['proses',
#   'proses',
#   'verifikasi',
#   'bayar',
#   'bom',
#   'kemas',
#   'kemas',
#   'besok',
#   'merah',
#   'chat',
#   'whatsapp',
#   'respon',
#   'telepon',
#   'customer service',
#   'suruh',
#   'tunggu',
#   'kalah',
#   'dropshipper',
#   'palayanan',
#   'no'],
#  ['beli',
#   'token',
#   'listrik',
#   'nomor',
#   'pesan',
#   'pdb',
#   'minggu',
#   'desember',
#   'jam',
#   'sampai',
#   'selasa',
#   'desember',
#   'beli',
#   'terima',
#   'token',
#   'listrik',
#   'token',
#   'listrik',
#   'terima',
#   'desember',
#   'jam'],
#  ['bintang', 'aplikasi', 'respon', 'unduh', 'mutu'],
#  ['uang', 'balik'],
#  ['sekian',
#   'kelas',
#   'commerce',
#   'jenis',
#   'barang',
#   'stock',
#   'pajang',
#   'kalah',
#   'toko',
#   'konfirmasi',
#   'informasi',
#   'barang',
#   'kosong',
#   'mesti',
#   'tombol',
#   'batal',
#   'mesan',
#   'via',
#   'email',
#   'ribet',
#   'erti',
#   'customer',
#   'belanja',
#   'lupa',
#   'umur',
#   'hidup',
#   'rekomendasi',
#   'aplikasi'],
#  ['beli', 'harap', 'stok', 'uang', 'lanjur', 'bayar', 'transaksi', 'batal'],
#  ['isi', 'alamat'],
#  ['kasih',
#   'bintang',
#   'aplikasi',
#   'ringan',
#   'chat',
#   'pesan',
#   'hubung',
#   'lapak',
#   'layan',
#   'customer',
#   'service',
#   'pusat',
#   'benar',
#   'benar',
#   'manajemen',
#   'evaluasi',
#   'kembang',
#   'maju',
#   'tolong',
#   'dukung',
#   'upgrade',
#   'benah',
#   'cari',
#   'cari',
#   'pecah',
#   'tolong',
#   'benar',
#   'luck'],
#  ['tolong',
#   'fitur',
#   'live',
#   'chat',
#   'mudah',
#   'fast',
#   'respon',
#   'produk',
#   'trms'],
#  ['belanja', 'bisnis', 'praktis', 'online'],
#  ['belanja', 'prodiknya', 'asli', 'pick', 'up', 'pokok'],
#  ['online', 'belanja'],
#  ['barang', 'lengkap', 'harga', 'sahabat'],
#  ['aplikasi', 'bantu', 'cari', 'produk'],
#  ['asli'],
#  ['mudah', 'user'],
#  ['barang', 'lengkap'],
#  ['lengkap', 'update'],
#  ['muncul',
#   'pakai',
#   'atur',
#   'bangke',
#   'kawan',
#   'kawan',
#   'konten',
#   'menyebalk',
#   'install',
#   'muncul',
#   'intal',
#   'bangke'],
#  ['pesan',
#   'barang',
#   'kualitas',
#   'sesuai',
#   'gambar',
#   'nekat',
#   'kirim',
#   'pesan',
#   'sesuai',
#   'warna',
#   'pesan',
#   'kemarin',
#   'tunggu',
#   'barang',
#   'barang',
#   'sesuai',
#   'gambar',
#   'kualitas',
#   'makan',
#   'belanja'],
#  ['kama', 'ba', 'get'],
#  ['beli',
#   'barang',
#   'toko',
#   'jam',
#   'wahyu',
#   'order',
#   'ngirim',
#   'jam',
#   'rusak',
#   'aplikasi',
#   'belanja',
#   'online',
#   'recommended',
#   'bnget',
#   'bilang',
#   'barang',
#   'asli',
#   'ngirim',
#   'barang',
#   'cek'],
#  ['iklan'],
#  ['kasik',
#   'bintang',
#   'pakek',
#   'aplikasi',
#   'aplikasi',
#   'bayar',
#   'pakek',
#   'bank',
#   'bni',
#   'bca'],
#  ['pesan',
#   'barang',
#   'kirim',
#   'kirim',
#   'chat',
#   'customer',
#   'agent',
#   'respon',
#   'jual',
#   'nanyak',
#   'kirim',
#   'barang',
#   'susah'],
#  ['iklanya', 'repot', 'nyaman', 'aplikasi', 'gajelass', 'iklanya', 'vulgar'],
#  ['dasar', 'tipu', 'minggu', 'order', 'barang', 'sampai'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['kirim', 'barang', 'lampung', 'minggu', 'hadehhh'],
#  ['tarik'],
#  ['sengaja',
#   'ken',
#   'batal',
#   'produk',
#   'kirim',
#   'kesel',
#   'tolong',
#   'respon',
#   'adminya',
#   'produk',
#   'juala'],
#  ['tahu',
#   'cuman',
#   'kasih',
#   'bintang',
#   'pas',
#   'tulis',
#   'tas',
#   'justice',
#   'muncul',
#   'kaos',
#   'justice',
#   'aneh'],
#  ['provinsi', 'kota', 'nggk', 'tekan', 'woyy'],
#  ['layan',
#   'tindak',
#   'proses',
#   'ngirim',
#   'barang',
#   'status',
#   'kemas',
#   'balas',
#   'silah',
#   'tunggu',
#   'tunggu',
#   'barang',
#   'kirim',
#   'kemas',
#   'hancur',
#   'layan',
#   'kacau',
#   'langgan',
#   'setia',
#   'sekarang'],
#  ['kirim',
#   'sortir',
#   'kelas',
#   'nike',
#   'cacat',
#   'barang',
#   'benang',
#   'lepas',
#   'beli',
#   'produk',
#   'nike',
#   'adidas',
#   'under',
#   'armour',
#   'puma',
#   'kualitas',
#   'beli',
#   'nike',
#   'perna',
#   'sekarang',
#   'rusak',
#   'bahanya'],
#  ['beli',
#   'pakai',
#   'produk',
#   'kirim',
#   'cacat',
#   'bolong',
#   'bolong',
#   'belanja',
#   'dituker',
#   'kembaliin',
#   'produk',
#   'ongkir',
#   'tanggung',
#   'salah',
#   'jual',
#   'beli',
#   'sepatu',
#   'kondisi',
#   'penyot',
#   'penyot',
#   'kirain',
#   'toko',
#   'resmi',
#   'layan'],
#  ['cust',
#   'servicenya',
#   'kok',
#   'susah',
#   'dihubungin',
#   'nanyain',
#   'order',
#   'minggu'],
#  ['online',
#   'shop',
#   'tipu',
#   'transfer',
#   'bayar',
#   'barang',
#   'pesan',
#   'tera',
#   'bayar'],
#  ['tipu'],
#  ['pasang',
#   'iklan',
#   'pikirin',
#   'pakai',
#   'otak',
#   'pasang',
#   'iklan',
#   'aplikasi',
#   'main',
#   'anak',
#   'iklan',
#   'pakai',
#   'dewasa',
#   'bikin',
#   'iklan',
#   'rusak',
#   'generasi'],
#  ['beli', 'mau', 'retur', 'susaaahhhhh', 'harus', 'pakai', 'komputer'],
#  ['produk', 'non', 'sale', 'pakai', 'voucher', 'asik', 'belanja'],
#  ['iklan', 'muncul', 'terus', 'mngganggu'],
#  ['sen',
#   'jam',
#   'tangan',
#   'brand',
#   'biden',
#   'sen',
#   'warna',
#   'merah',
#   'whatsapp',
#   'customer service',
#   'biden',
#   'warna',
#   'merah',
#   'kosong',
#   'hitam',
#   'kabel',
#   'usb',
#   'bilang',
#   'jam',
#   'cacat',
#   'kabel',
#   'usbnya',
#   'chat',
#   'sampai',
#   'chat',
#   'beda',
#   'heran'],
#  ['informasi', 'return'],
#  ['belanja',
#   'online',
#   'tanggung',
#   'sellernya',
#   'toko',
#   'jam',
#   'wahyu',
#   'ngirim',
#   'barang',
#   'rusak',
#   'lebih baik',
#   'aplikasi',
#   'hijau',
#   'trimakasih'],
#  ['aplikasi'],
#  ['aplikasi'],
#  ['belanja',
#   'pas',
#   'diskon',
#   'beli',
#   'kacamata',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'kasih',
#   'diskon',
#   'barang'],
#  ['kurir', 'ganti', 'maaf', 'kurir'],
#  ['voucher',
#   'xalora',
#   'aplikasi',
#   'jag',
#   'pad',
#   'pakai',
#   'kode',
#   'pqke',
#   'colaborasinya'],
#  ['aktip', 'akun', 'nama', 'putri', 'olsop'],
#  ['gara', 'notif', 'pacar', 'marah'],
#  ['stock', 'ukur', 'pakean', 'branded'],
#  ['aplikasi', 'sulit', 'donlowd'],
#  ['aplikasi'],
#  ['mahal'],
#  ['cashback',
#   'tapi',
#   'pas',
#   'belanja',
#   'order',
#   'dibatalin',
#   'jual',
#   'cashback',
#   'hangus'],
#  ['aplikasi', 'busuk', 'dana', 'refund', 'rekening', 'wallet'],
#  ['tolong', 'aplikasi', 'muncul', 'beranda', 'ganggu', 'arah', 'mendownload'],
#  ['iklan', 'anjjj'],
#  ['barang', 'asli', 'beli', 'sepatu', 'dipakek', 'rusak'],
#  ['cod', 'indonesia'],
#  ['kaos',
#   'adidas',
#   'bahan',
#   'keras',
#   'panas',
#   'super',
#   'kaya',
#   'kaos',
#   'imitasi',
#   'deskripsi',
#   'tulis',
#   'bahan',
#   'polyster',
#   'pas',
#   'nyampe',
#   'bahan',
#   'catton',
#   'tebel',
#   'keras',
#   'panas',
#   'bikin',
#   'kapok',
#   'pdhl',
#   'th',
#   'langgan',
#   'beli',
#   'harga',
#   'mahal',
#   'kaos',
#   'buriiikkkkk'],
#  ['beli', 'barang', 'asli', 'barang'],
#  ['maaf',
#   'nihh',
#   'kesel',
#   'pilih',
#   'unduh',
#   'barang',
#   'barang',
#   'mahal',
#   'cari',
#   'baju',
#   'bayi',
#   'baju',
#   'anak',
#   'cari',
#   'lampu',
#   'kelap',
#   'kelip',
#   'malah',
#   'main',
#   'anak',
#   'mahal'],
#  ['beli',
#   'beli',
#   'barang',
#   'dateng',
#   'beda',
#   'gilir',
#   'produk',
#   'barang',
#   'kurir',
#   'sampai',
#   'auto',
#   'uninstal',
#   'aplikasi'],
#  ['alam',
#   'belanja',
#   'lambat',
#   'sen',
#   'hari',
#   'sabtu',
#   'sampai',
#   'selasa',
#   'status',
#   'kirim',
#   'kemas',
#   'pakai',
#   'market',
#   'place',
#   'batal',
#   'otomatis',
#   'menang',
#   'banyak',
#   'bunga',
#   'bank',
#   'nahan',
#   'duit',
#   'orang'],
#  ['tolong', 'ikan', 'akses', 'chat', 'seller', 'kakak'],
#  ['harga',
#   'mahal',
#   'murah',
#   'hoakkkkk',
#   'harga',
#   'turun',
#   'turun',
#   'bikin',
#   'kesel',
#   'beli',
#   'harga',
#   'turun',
#   'stok',
#   'size',
#   'dikit'],
#  ['mahal', 'murah'],
#  ['curang',
#   'tahu',
#   'curang',
#   'beli',
#   'jeans',
#   'brand',
#   'bombboogie',
#   'produk',
#   'pakai',
#   'voucher',
#   'ubah',
#   'produk',
#   'non',
#   'sale',
#   'curang',
#   'iming',
#   'iming',
#   'voucher',
#   'cashback',
#   'harga',
#   'naikin',
#   'harga',
#   'capai',
#   'ribu',
#   'otak',
#   'tadi',
#   'harga',
#   'ribu',
#   'pas',
#   'esok',
#   'ribu',
#   'fantastis',
#   'curang',
#   'viral'],
#  ['barang',
#   'sesuai',
#   'gambar',
#   'asli',
#   'harga',
#   'banding',
#   'barang',
#   'review',
#   'barang',
#   'dana'],
#  ['tolong',
#   'pakai',
#   'jasa',
#   'kirim',
#   'cari',
#   'murah',
#   'pesan',
#   'barang',
#   'minggu',
#   'email',
#   'alamat',
#   'temu',
#   'toko',
#   'online',
#   'ribet'],
#  ['aplikasi', 'unduh', 'buka', 'selalu', 'muncul', 'tulis', 'salah', 'data'],
#  ['brand',
#   'hapus',
#   'branda',
#   'notif',
#   'brand',
#   'acara',
#   'diskon',
#   'nggk',
#   'aplikasi',
#   'bikin'],
#  ['infoin',
#   'no',
#   'telepon',
#   'kurir',
#   'barang',
#   'kirim',
#   'sen',
#   'senin',
#   'jumat',
#   'barang',
#   'bom',
#   'informasi',
#   'kurir',
#   'sebenernya',
#   'bantu',
#   'pandemi',
#   'pengirimanya',
#   'lambat'],
#  ['refaund', 'bikin', 'kesel', 'kelas', 'gede', 'nama'],
#  ['belanja',
#   'seller',
#   'toko',
#   'jam',
#   'wahyu',
#   'ngirim',
#   'barang',
#   'rusak',
#   'tukar'],
#  ['pakai', 'fb', 'program', 'murah', 'kurir', 'pakai', 'ganti', 'cepat'],
#  ['barang', 'asli'],
#  ['kirim', 'beda', 'pes', 'retur', 'tolak', 'salah', 'saller', 'respon'],
#  ['order', 'nyampe', 'wowww', 'aplikasi'],
#  ['order', 'sampai', 'chat', 'fb', 'suruh', 'tunggu'],
#  ['ganggu'],
#  ['harga', 'mahal', 'kualitas'],
#  ['uang', 'hilang', 'hbs', 'bayar', 'barang', 'konfirmasi'],
#  ['barang', 'mahal', 'mahal'],
#  ['aplikasi', 'pesan', 'november', 'barang', 'sampai', 'sampai'],
#  ['indah', 'bayang', 'tipudaya'],
#  ['aplikasi',
#   'belanja',
#   'online',
#   'layan',
#   'bertanggunh',
#   'jawab',
#   'kirim',
#   'barang',
#   'jangan',
#   'makan',
#   'iklan',
#   'hati',
#   'belanja',
#   'just',
#   'informasi'],
#  ['bantu', 'iklan'],
#  ['ulas',
#   'hilang',
#   'memgulas',
#   'diskon',
#   'diskon',
#   'harga',
#   'mahal',
#   'diskon'],
#  ['pesan',
#   'kirim',
#   'alas',
#   'salah',
#   'alamat',
#   'alamat',
#   'komplek',
#   'rumah',
#   'juga',
#   'kenal',
#   'pesan',
#   'alas',
#   'salah',
#   'alamat',
#   'ckckck'],
#  ['email', 'cash', 'back', 'php', 'salah', 'sistem', 'come', 'on'],
#  ['jam',
#   'united',
#   'polo',
#   'club',
#   'harga',
#   'ribu',
#   'kualitas',
#   'jam',
#   'kuaci',
#   'zonkkkk'],
#  ['produk',
#   'kaos',
#   'nike',
#   'tolong',
#   'size',
#   'beda',
#   'beda',
#   'size',
#   'produk',
#   'nike',
#   'beli',
#   'produk',
#   'nike',
#   'salah',
#   'size',
#   'perna',
#   'produk',
#   'nike',
#   'gara',
#   'size',
#   'cingkrang',
#   'produk',
#   'olahraga',
#   'size',
#   'produk',
#   'kaya',
#   'adidas',
#   'under',
#   'armour',
#   'puma',
#   'reebok',
#   'size',
#   'online',
#   'beli',
#   'produk',
#   'nike',
#   'size'],
#  ['barang',
#   'pesan',
#   'kasih',
#   'layan',
#   'konsumen',
#   'kapok',
#   'pakai',
#   'recomended'],
#  ['sen',
#   'dsini',
#   'pesan',
#   'barang',
#   'sampai',
#   'tapi',
#   'uda',
#   'brhari',
#   'sampai',
#   'leeat',
#   'batas',
#   'barang',
#   'kirim',
#   'complain',
#   'zaloranya',
#   'balas',
#   'chat',
#   'otomatis',
#   'customer service',
#   'aplagi',
#   'bner',
#   'benr',
#   'mengerti',
#   'sen',
#   'online',
#   'lebih baik',
#   'pesn',
#   'dsni',
#   'pesan',
#   'olshop',
#   'csnya',
#   'biar',
#   'ditnya',
#   'jwab'],
#  ['aplikasi',
#   'beli',
#   'sepatu',
#   'harga',
#   'total',
#   'ongkir',
#   'ribu',
#   'barang',
#   'hitung',
#   'harga',
#   'ribu',
#   'ribu',
#   'total',
#   'bayar',
#   'ribu',
#   'check',
#   'out',
#   'looh',
#   'harga',
#   'total',
#   'ribu'],
#  ['belanja',
#   'tas',
#   'samsonite',
#   'total',
#   'jt',
#   'batal',
#   'jual',
#   'marketplace',
#   'kapok',
#   'belanja'],
#  ['belanja',
#   'tanggap',
#   'respon',
#   'produk',
#   'hilang',
#   'jatuh',
#   'jalan',
#   'kurir',
#   'produk',
#   'hadiah',
#   'usaha',
#   'produk',
#   'merespon',
#   'uang',
#   'harap',
#   'uang',
#   'produk',
#   'hadiah'],
#  ['cash', 'back', 'cek', 'kosong'],
#  ['aplikasi',
#   'kaya',
#   'anjg',
#   'nga',
#   'nonton',
#   'anime',
#   'karen',
#   'iklan',
#   'aplikasi'],
#  ['barang', 'sampai', 'uda', 'pesan', 'minggu', 'kesel', 'cuk'],
#  ['tolong', 'iklan', 'muncul', 'animelovers', 'skip'],
#  ['install', 'komen'],
#  ['harga',
#   'ubah',
#   'ubah',
#   'kaos',
#   'harga',
#   'kadang',
#   'akal',
#   'pakai',
#   'voucer',
#   'toko',
#   'online',
#   'standar',
#   'haraga',
#   'kaya',
#   'sports',
#   'station',
#   'toko',
#   'banding',
#   'harga',
#   'asli',
#   'kadang',
#   'sangatt',
#   'jauuuhh',
#   'harga'],
#  ['saing', 'paksa', 'factor', 'lucky'],
#  ['ww'],
#  ['beli',
#   'barang',
#   'tunggu',
#   'minggu',
#   'ehh',
#   'batal',
#   'mengerti',
#   'uang',
#   'kmn'],
#  ['prodaknya', 'mahal', 'lagi'],
#  ['kemarin', 'chat', 'live', 'sama', 'customer service', 'tolong'],
#  ['oktober',
#   'bintang',
#   'ubah',
#   'pikir',
#   'maaf',
#   'pesan',
#   'sepatu',
#   'baju',
#   'responsif',
#   'tanggap',
#   'langgan',
#   'pesan'],
#  ['kirim'],
#  ['pesan',
#   'bareng',
#   'tanggal',
#   'pas',
#   'tanggal',
#   'telepon',
#   'paket',
#   'tersesat',
#   'paket',
#   'palembang',
#   'pdhl',
#   'aceh',
#   'pdhl',
#   'bikin',
#   'alamat',
#   'lengkap',
#   'bhkan',
#   'cek',
#   'kabupaten',
#   'indrajaya',
#   'indralaya',
#   'commerse',
#   'bikin',
#   'salah',
#   'fatal',
#   'sekarang',
#   'tanggal',
#   'juga',
#   'datang',
#   'paket',
#   'mmg',
#   'konfirmasi',
#   'email',
#   'tapi',
#   'proses',
#   'tingkat',
#   'teliti',
#   'pdhl',
#   'bayar',
#   'ongkir',
#   'sesuai',
#   'alamat'],
#  ['tipu', 'barang', 'kirim', 'sesuai'],
#  ['berat', 'pesan', 'barang', 'sesuai', 'iklan'],
#  ['tolong',
#   'model',
#   'fashion',
#   'negro',
#   'hitam',
#   'afrika',
#   'risih',
#   'baju',
#   'kes',
#   'ndeso',
#   'baju',
#   'suku',
#   'afrika'],
#  ['unduh', 'buka'],
#  ['langgan',
#   'jamin',
#   'barang',
#   'originalnya',
#   'barang',
#   'sesuai',
#   'gambar',
#   'iming',
#   'barang',
#   'disc',
#   'barang',
#   'murah',
#   'harga',
#   'muahalll',
#   'sesuai',
#   'harga',
#   'beli',
#   'harga',
#   'disc',
#   'direturn',
#   'biaya',
#   'kirim',
#   'bayar',
#   'kirim',
#   'barang',
#   'percaya',
#   'dehh',
#   'barang',
#   'beli',
#   'barang',
#   'harga',
#   'rban',
#   'disc',
#   'barang',
#   'kualitas',
#   'rban',
#   'puaraaaaahhhhhh'],
#  ['filter', 'fungsi'],
#  ['lambat', 'respon', 'nj'],
#  ['sngat', 'dlm', 'kirim', 'brng', 'kecuali', 'negara'],
#  ['lagi',
#   'coba',
#   'buka',
#   'aplikasi',
#   'malam',
#   'bilang',
#   'jaring',
#   'error',
#   'pdhl',
#   'buka',
#   'aplikasi',
#   'tolong',
#   'pesan',
#   'bom',
#   'kirim'],
#  ['barang',
#   'sesuai',
#   'harga',
#   'harga',
#   'mahal',
#   'kelas',
#   'murah',
#   'kelas',
#   'pasar',
#   'belanja'],
#  ['kirim',
#   'cepat',
#   'sayang',
#   'tas',
#   'harga',
#   'sekian',
#   'diskon',
#   'tas',
#   'kaya',
#   'harga',
#   'ribu',
#   'beda',
#   'gambar',
#   'nyeseeelllll'],
#  ['kirim', 'barang', 'cek', 'cacat'],
#  ['sistem'],
#  ['aplikasi',
#   'harap',
#   'perhati',
#   'beli',
#   'produk',
#   'negri',
#   'sepatu',
#   'tulis',
#   'pesan',
#   'gagal',
#   'proses',
#   'kolom',
#   'lacak',
#   'mesan',
#   'barang',
#   'beli',
#   'barang',
#   'terima',
#   'kasih',
#   'ooh',
#   'web',
#   'repot',
#   'login',
#   'facebook'],
#  ['prank'],
#  ['aduh',
#   'diprank',
#   'pesan',
#   'sms',
#   'suruh',
#   'unduh',
#   'kasih',
#   'kode',
#   'voucher',
#   'diskon',
#   'unduh',
#   'beli',
#   'pakai',
#   'voucher',
#   'vouchernya',
#   'bodoh',
#   'sad'],
#  ['jangan', 'pakai', 'ekspedisi', 'rpx', 'milih', 'ekspedisi'],
#  ['ngeluh',
#   'belanja',
#   'jujur',
#   'beli',
#   'barang',
#   'nyampai',
#   'nyampai',
#   'tolong'],
#  ['ongkir', 'mahal', 'potong', 'mesti', 'belanja', 'gratis', 'ongkir'],
#  ['barang',
#   'kirim',
#   'salah',
#   'sesuai',
#   'merk',
#   'tipe',
#   'pes',
#   'profesional',
#   'alami',
#   'belanja'],
#  ['kirim',
#   'bulan',
#   'alam',
#   'salah',
#   'kirim',
#   'barang',
#   'pesan',
#   'bayar',
#   'solusi',
#   'customer service',
#   'arah',
#   'kepada',
#   'proses',
#   'refund',
#   'refund',
#   'refund',
#   'barang',
#   'bayar',
#   'idam',
#   'untuk',
#   'posisi',
#   'customer',
#   'sukses',
#   'untuk'],
#  ['belanja',
#   'order',
#   'sandal',
#   'flip',
#   'zoes',
#   'nomer',
#   'order',
#   'xxx',
#   'sya',
#   'pmbyaran',
#   'hri',
#   'sya',
#   'email',
#   'customer service',
#   'klu',
#   'order',
#   'alami',
#   'hambat',
#   'sistem',
#   'sya',
#   'dapar',
#   'email',
#   'nomer',
#   'order',
#   'xxx',
#   'order',
#   'datang',
#   'kurir',
#   'sya',
#   'buka',
#   'barang',
#   'alami',
#   'rusa',
#   'barang',
#   'putus',
#   'tali',
#   'karet',
#   'belanja',
#   'hati'],
#  ['estimasi', 'kirim', 'minggu'],
#  ['balik',
#   'duit',
#   'return',
#   'status',
#   'barang',
#   'direturn',
#   'customer service',
#   'kamu',
#   'customer service',
#   'robot',
#   'gedek',
#   'aplikasi',
#   'kaya',
#   'gin',
#   'konsultasi',
#   'kasih',
#   'bicara',
#   'robot',
#   'mikir',
#   'kamu',
#   'woey',
#   'kalah',
#   'aplikasi',
#   'customer service',
#   'bicara',
#   'marketplace',
#   'nyadar',
#   'aplikasi',
#   'kamu',
#   'barang',
#   'layan',
#   'rendah'],
#  ['tas', 'terlambat', 'customer service', 'layan', 'telfon', 'tutup'],
#  ['olshop',
#   'andal',
#   'barang',
#   'tunggu',
#   'pick',
#   'up',
#   'udang',
#   'kirim',
#   'alamat',
#   'tahu',
#   'kirim',
#   'gagal',
#   'komfirmasi',
#   'uninstal'],
#  ['kualitas', 'barang'],
#  ['commerce', 'lambat', 'kirim', 'minggu', 'barang', 'kalah', 'belah'],
#  ['bahan',
#   'kayak',
#   'pasar',
#   'brand',
#   'bombboogie',
#   'beli',
#   'tahu',
#   'bahan',
#   'tipis',
#   'kayak',
#   'baju',
#   'partai',
#   'beda',
#   'brand',
#   'oxy',
#   'kemarin',
#   'asli'],
#  ['barang', 'minggu', 'notifnya', 'kemas', 'produk', 'dlm', 'negri'],
#  ['kirim', 'super', 'sesuai', 'jadwal', 'tara', 'uda', 'minggu', 'bom', 'uda'],
#  ['barang', 'kerap', 'salah', 'kirim', 'uang', 'cair'],
#  ['admin', 'kurir', 'surabaya', 'popbox', 'sja', 'pilih', 'kurir'],
#  ['hati', 'jebak', 'hati', 'tanda', 'voucher', 'belanja'],
#  ['update', 'aplikasi', 'gajelas'],
#  ['aplikasi', 'penipuuuu'],
#  ['aplikasi',
#   'pintar',
#   'mebodohi',
#   'beli',
#   'sepatu',
#   'undi',
#   'uang',
#   'tetep',
#   'promo',
#   'total',
#   'uang',
#   'walet',
#   'rekening',
#   'pagi',
#   'temu',
#   'simpul',
#   'uang',
#   'tarik',
#   'ttp',
#   'belanja'],
#  ['belanja',
#   'kayak',
#   'ramayana',
#   'matahari',
#   'diskon',
#   'max',
#   'potong',
#   'ribu',
#   'dagel'],
#  ['inti', 'promo', 'uang', 'voucher', 'belanja'],
#  ['pesan', 'kirim', 'juga', 'pesan', 'november'],
#  ['barang',
#   'sesuai',
#   'gambar',
#   'nomor',
#   'order',
#   'beda',
#   'nggk',
#   'kertas',
#   'barang',
#   'ajar',
#   'rugi',
#   'konsumen'],
#  ['inti', 'pasang', 'aplikasi'],
#  ['kirim',
#   'pesan',
#   'gagal',
#   'pdahal',
#   'beli',
#   'alamat',
#   'susah',
#   'hubung',
#   'bantu',
#   'msalah'],
#  ['ganti',
#   'password',
#   'lupa',
#   'password',
#   'kasih',
#   'instruksi',
#   'muter',
#   'wkwkwkwk',
#   'buka',
#   'email',
#   'dialihin',
#   'webnya',
#   'webnya',
#   'suruh',
#   'buka',
#   'email',
#   'kasih',
#   'link',
#   'ganti',
#   'posisi nyaman',
#   'link',
#   'kasih',
#   'link',
#   'sampai',
#   'jebot',
#   'password',
#   'ganti',
#   'bikin',
#   'paleng'],
#  ['malas', 'update'],
#  ['install', 'tidak', 'aplikasi'],
#  ['minggu',
#   'buka',
#   'aplikasi',
#   'loadingnya',
#   'lamaaa',
#   'mnit',
#   'aplikasi',
#   'aplikasi',
#   'loadingnya',
#   'lamaaaa',
#   'gambar',
#   'lngsung',
#   'buka',
#   'tapi',
#   'tunggu',
#   'minggu',
#   'lolaaa'],
#  ['unduh', 'buka'],
#  ['mahal',
#   'anjim',
#   'kasih',
#   'voucher',
#   'gede',
#   'pakai',
#   'pulsa',
#   'beli',
#   'pulsa'],
#  ['hati',
#   'belanja',
#   'teliti',
#   'barang',
#   'mahal',
#   'sesuai',
#   'dateng',
#   'sampah',
#   'jual',
#   'kasih',
#   'terang',
#   'gambar',
#   'setel',
#   'pas',
#   'dateng',
#   'tipu',
#   'harga',
#   'mahal',
#   'barang',
#   'tipis',
#   'transfaran',
#   'belanja'],
#  ['aplikasi',
#   'chat',
#   'sama',
#   'jual',
#   'ukur',
#   'baju',
#   'ribet',
#   'ulas',
#   'beli',
#   'aplikasi'],
#  ['langgan',
#   'bikin',
#   'benci',
#   'belanja',
#   'belanja',
#   'foundation',
#   'imingi',
#   'promo',
#   'primer',
#   'foundation',
#   'telepon',
#   'customer service',
#   'nyusahin',
#   'beli',
#   'bantu',
#   'email',
#   'bantu',
#   'pesan',
#   'kirim',
#   'sesuai',
#   'promo',
#   'refund',
#   'layan',
#   'benar',
#   'kapok',
#   'beli',
#   'mufe',
#   'foundation'],
#  ['cepetan',
#   'tambahin',
#   'size',
#   'eu',
#   'air',
#   'max',
#   'wolf',
#   'greynya',
#   'ken',
#   'beli',
#   'inih'],
#  ['update',
#   'bikin',
#   'negara',
#   'timor',
#   'leste',
#   'pesan',
#   'bayar',
#   'virtual',
#   'account',
#   'timor',
#   'leste',
#   'tersidia',
#   'bank',
#   'transfer',
#   'komfirmasi',
#   'manual',
#   'tolong',
#   'bantua',
#   'pesan'],
#  ['pesan',
#   'barang',
#   'november',
#   'estimasi',
#   'barang',
#   'desember',
#   'cek',
#   'nomor',
#   'resi',
#   'ditemuka',
#   'data',
#   'kirim',
#   'cek',
#   'pesan',
#   'temu',
#   'data',
#   'pesan',
#   'hubung',
#   'customer',
#   'service',
#   'virtual',
#   'email',
#   'no',
#   'telpon',
#   'bilang',
#   'hubung',
#   'tunggu',
#   'hubung',
#   'hasil',
#   'nihil',
#   'tolong',
#   'main'],
#  ['beli',
#   'hoodie',
#   'champion',
#   'barang',
#   'kirim',
#   'asli',
#   'olshop',
#   'saran',
#   'belanja'],
#  ['barang', 'kirim', 'sesuai', 'pesan', 'aju', 'barang'],
#  ['beri', 'diskon', 'ukur', 'sepatu', 'tinggal', 'no'],
#  ['belanja', 'vlog', 'om', 'baim', 'barang', 'asli'],
#  ['belanja',
#   'branded',
#   'ganti',
#   'alamat',
#   'kalah',
#   'layan',
#   'toko',
#   'belah',
#   'layan',
#   'customer'],
#  ['niat',
#   'tunggu',
#   'produk',
#   'dipakein',
#   'voucher',
#   'lebih baik',
#   'beli',
#   'dipakein',
#   'voucher'],
#  ['cerah', 'aplikasi', 'brand', 'asli'],
#  ['harga',
#   'kualitas',
#   'sesuai',
#   'capek',
#   'belanja',
#   'lebih baik',
#   'belanja',
#   'cocok'],
#  ['sen', 'jam', 'tangan', 'kirim', 'masker', 'tolong', 'kasih'],
#  ['prank', 'lucky', 'uang'],
#  ['barang',
#   'kunjung',
#   'lacak',
#   'pesan',
#   'nomor',
#   'resi',
#   'temu',
#   'customer service',
#   'robot',
#   'aplikasi',
#   'sampah'],
#  ['kirim',
#   'respon',
#   'costumer',
#   'service',
#   'solusi',
#   'proses',
#   'pesan',
#   'kacau',
#   'kirim',
#   'lanjut',
#   'day',
#   'delivery'],
#  ['sen',
#   'gagal',
#   'kirim',
#   'alamat',
#   'temu',
#   'alamat',
#   'lengkap',
#   'tulis',
#   'untung',
#   'cod'],
#  ['belanja',
#   'sesuai',
#   'mesan',
#   'saran',
#   'aplikasi',
#   'barang',
#   'tera',
#   'mahal',
#   'kirim',
#   'sesuai',
#   'pesan'],
#  ['diskon',
#   'kemarin',
#   'beli',
#   'barang',
#   'diskon',
#   'harga',
#   'asli',
#   'diskon',
#   'tarik',
#   'minat',
#   'konsumen',
#   'harga',
#   'lipat',
#   'diskon',
#   'harga',
#   'harga',
#   'diskon',
#   'jual',
#   'jujur',
#   'sanggup',
#   'diskon',
#   'kasih',
#   'harap',
#   'diskon'],
#  ['barang',
#   'bayar',
#   'kirim',
#   'chat',
#   'customer service',
#   'ujung',
#   'nyanuang',
#   'bgst'],
#  ['beli',
#   'celana',
#   'deskripsi',
#   'sesuai',
#   'barang',
#   'hapus',
#   'aplikasi',
#   'terima',
#   'kasih'],
#  ['barang',
#   'pesan',
#   'alamat',
#   'jakarta',
#   'utara',
#   'nrima',
#   'surabaya',
#   'hubung',
#   'seller',
#   'barang'],
#  ['order',
#   'pieces',
#   'barang',
#   'ee',
#   'tangan',
#   'email',
#   'kasih',
#   'keluh',
#   'respon'],
#  ['hubung', 'customer', 'care', 'kirim', 'barang'],
#  ['pas',
#   'harbolnas',
#   'cashback',
#   'layan',
#   'cp',
#   'batal',
#   'pesan',
#   'proses',
#   'lamaaaa',
#   'hubung',
#   'cp',
#   'suruh',
#   'tunggu',
#   'teruss',
#   'layan',
#   'sistem'],
#  ['kasih', 'bintang', 'takut', 'aplikasi'],
#  ['kasih', 'tahu', 'mitra', 'seller', 'kirim', 'barang'],
#  ['pesan', 'proses', 'lambat', 'respon', 'update'],
#  ['aplikasi',
#   'giur',
#   'refund',
#   'mudah',
#   'cepat',
#   'gratis',
#   'bla',
#   'bla',
#   'bla',
#   'refund',
#   'segi',
#   'palayannya',
#   'sepele',
#   'aplikasi',
#   'aplikasi',
#   'sen',
#   'dress',
#   'datang',
#   'kaos',
#   'polos',
#   'aneh',
#   'nyusahin',
#   'urus'],
#  ['aplikasi',
#   'layan',
#   'yanb',
#   'yaak',
#   'undang',
#   'undang',
#   'perlimdungan',
#   'konsumen'],
#  ['ngeleg', 'welcome', 'screennya', 'pering'],
#  ['jelekk'],
#  ['aplikasi',
#   'status',
#   'kirim',
#   'barang',
#   'ngk',
#   'pokok',
#   'belanja',
#   'aplikasi'],
#  ['harga', 'mahal', 'disko'],
#  ['nyesal', 'update', 'bnget'],
#  ['barang',
#   'sesuai',
#   'beli',
#   'beli',
#   'baju',
#   'warna',
#   'biru',
#   'kasih',
#   'hijau',
#   'tolong'],
#  ['filter', 'by', 'ukur', 'buka', 'cari', 'ukur', 'pas', 'nyusahin'],
#  ['jam', 'lecet'],
#  ['promo', 'im', 'tipu'],
#  ['beli', 'mahal', 'mahal', 'kualitas', 'sesuai'],
#  ['beli', 'hadiah', 'barang', 'pesan', 'cancel', 'sungguh'],
#  ['maaf',
#   'beli',
#   'barang',
#   'sampai',
#   'sesuai',
#   'ekspektasi',
#   'sampai',
#   'kaya',
#   'barang',
#   'ribu',
#   'merk',
#   'jam',
#   'kaya',
#   'barang',
#   'imitasi',
#   'packing',
#   'jual',
#   'barang',
#   'imitasi',
#   'makas'],
#  ['belanja', 'tbtb', 'cek', 'out'],
#  ['aplikasi', 'belanja', 'online', 'recommend'],
#  ['belanja',
#   'barang',
#   'cacat',
#   'barang',
#   'bekas',
#   'jahit',
#   'lepas',
#   'muka',
#   'bulu',
#   'kirim',
#   'cek',
#   'kirim'],
#  ['batal'],
#  ['barang', 'jual', 'sayang', 'layan', 'costumernya'],
#  ['filter', 'harga', 'eror', 'rilis', 'update', 'cek', 'seperti', 'fitur'],
#  ['emas', 'dustbag'],
#  ['kemahalen'],
#  ['barang',
#   'pes',
#   'kirim',
#   'harga',
#   'produk',
#   'mahal',
#   'juga',
#   'propesiaonal'],
#  ['rugi',
#   'barang',
#   'terima',
#   'imitasi',
#   'spek',
#   'asli',
#   'kirim',
#   'imitasi',
#   'kapok',
#   'belanja',
#   'tipu'],
#  ['aplikasi', 'barang', 'stok', 'lengkap', 'cashback', 'abal'],
#  ['dw',
#   'aplikasi',
#   'buka',
#   'maslaah',
#   'sinyal',
#   'buk',
#   'yt',
#   'instagram',
#   'lancar',
#   'sebal'],
#  ['belanja',
#   'barang',
#   'kirim',
#   'gilir',
#   'batal',
#   'kirim',
#   'barang',
#   'nntinya',
#   'sya',
#   'terima',
#   'bayar',
#   'barang',
#   'beli',
#   'estimasi',
#   'tapiiii',
#   'kirim',
#   'estimasi',
#   'besok',
#   'besok',
#   'tulis',
#   'paham'],
#  ['pesan',
#   'jam',
#   'tangan',
#   'pcs',
#   'pesan',
#   'tanggal',
#   'sampai',
#   'sekarang',
#   'datang',
#   'cacat',
#   'status',
#   'tulis',
#   'kurir',
#   'tangan',
#   'smpai',
#   'sekarang'],
#  ['barang', 'sesuai', 'harga'],
#  ['kemarin', 'habis', 'baru', 'baru', 'pakai', 'aplikasi', 'zaloranya'],
#  ['unduh',
#   'pas',
#   'komentar',
#   'banyak',
#   'comen',
#   'negatip',
#   'astaga',
#   'untung',
#   'belum',
#   'sempat'],
#  ['layan', 'lambbat', 'return', 'grts', 'odhl', 'bayar'],
#  ['barang', 'minggu', 'nggk', 'nyampe'],
#  ['belanja',
#   'kecewaaa',
#   'beli',
#   'jam',
#   'tangan',
#   'mati',
#   'sengaja',
#   'tahu',
#   'salah',
#   'seller',
#   'tanggung',
#   'customer',
#   'korban',
#   'suruh',
#   'bayar',
#   'ongkir',
#   'refund',
#   'hbs',
#   'kesel'],
#  ['warna',
#   'produk',
#   'kirim',
#   'tdak',
#   'sesuai',
#   'sama',
#   'pes',
#   'suruh',
#   'beli',
#   'harga',
#   'beda'],
#  ['barang',
#   'foto',
#   'beda',
#   'barang',
#   'terima',
#   'return',
#   'tolak',
#   'alas',
#   'barang',
#   'sesuai',
#   'return',
#   'foto',
#   'merk',
#   'mayonette',
#   'barang',
#   'terima',
#   'nga',
#   'merk',
#   'beli',
#   'tas',
#   'harga',
#   'ribu',
#   'asa',
#   'beli',
#   'tas',
#   'ribu',
#   'nama',
#   'tipu'],
#  ['plisss',
#   'beli',
#   'aplikasi',
#   'gamau',
#   'emosi',
#   'dagdigdug',
#   'nungguin',
#   'barang',
#   'aplikasi',
#   'langgan',
#   'customer service',
#   'sekian',
#   'alih',
#   'aplikasi',
#   'hijau',
#   'bobrok',
#   'sistem',
#   'aplikasi'],
#  ['belanja', 'pesan', 'kirim', 'tolong', 'perhati', 'kirim'],
#  ['belanja', 'barang', 'maaf', 'auto', 'uninstal'],
#  ['coba', 'coment', 'negatif'],
#  ['kirim', 'uninstal', 'aplikasi', 'belanja', 'langgan', 'alami', 'alami'],
#  ['aplikasi',
#   'buka',
#   'layar',
#   'putih',
#   'nongol',
#   'kaya',
#   'handphone',
#   'habis',
#   'paket',
#   'internet',
#   'paket',
#   'internet'],
#  ['cari', 'ribet'],
#  ['aplikasi',
#   'aneh',
#   'nulis',
#   'alamat',
#   'ktnye',
#   'wjib',
#   'isi',
#   'alamat',
#   'ny',
#   'pas',
#   'isi',
#   'kgk'],
#  ['update',
#   'versi',
#   'kayak',
#   'compatible',
#   'android',
#   'versi',
#   'dashboard',
#   'kosong',
#   'ketik',
#   'cari',
#   'versi'],
#  ['belanja',
#   'beli',
#   'sepatu',
#   'pas',
#   'paket',
#   'buka',
#   'rusak',
#   'kotor',
#   'debu',
#   'kupas'],
#  ['sekrg',
#   'appny',
#   'paket',
#   'jumat',
#   'sekrg',
#   'sampk',
#   'notifiksi',
#   'kirim',
#   'gagal',
#   'pdhl',
#   'sya',
#   'drmh',
#   'terus',
#   'tunggu',
#   'zalorany',
#   'paket',
#   'kirmny',
#   'sng',
#   'cept',
#   'sekrg',
#   'zong',
#   'bikn',
#   'males',
#   'order',
#   'bayar',
#   'biaya',
#   'paket',
#   'seperti',
#   'gratis'],
#  ['kirim'],
#  ['aslih', 'ngeselin', 'bayar', 'pakai', 'gagal', 'diskon', 'pakai', 'kesel'],
#  ['muncul', 'gambar', 'loading', 'lot'],
#  ['pas', 'cekout', 'isi', 'alamat'],
#  ['langgan',
#   'untuk',
#   'beli',
#   'kemarin',
#   'benar',
#   'order',
#   'sandal',
#   'jepit',
#   'kulit',
#   'winarno',
#   'pasang',
#   'kirim',
#   'cuman',
#   'pasang',
#   'sandal',
#   'harga',
#   'ribu',
#   'kualitas',
#   'pakai',
#   'hancur',
#   'muka',
#   'sandal',
#   'ngelupas',
#   'kiri',
#   'mangap',
#   'lem'],
#  ['aplikasi',
#   'barang',
#   'pilih',
#   'keranjang',
#   'checkout',
#   'bayar',
#   'halaman',
#   'bayar',
#   'layar',
#   'putih',
#   'pilih',
#   'bayar',
#   'pilih',
#   'koreksi',
#   'aplikasi'],
#  ['belanja',
#   'kirim',
#   'cepat',
#   'emas',
#   'safety',
#   'tapiiiii',
#   'barang',
#   'cacat',
#   'kelupas',
#   'maaf',
#   'uninstal',
#   'uang',
#   'repot',
#   'ampun'],
#  ['sen',
#   'tas',
#   'tanggal',
#   'november',
#   'maksdnya',
#   'tolong',
#   'jelasin',
#   'barang'],
#  ['banyak', 'complainan', 'ragu'],
#  ['belanja',
#   'seller',
#   'toko',
#   'jam',
#   'wahyu',
#   'aplikasi',
#   'belanja',
#   'online',
#   'lebih baik',
#   'ngirim',
#   'jam',
#   'rusak',
#   'dituker',
#   'bilang',
#   'seller',
#   'toko',
#   'jam',
#   'wahyu',
#   'ngirim',
#   'barang',
#   'jarum',
#   'jam',
#   'rusak',
#   'suruh',
#   'ngirim',
#   'vidio',
#   'unboxing',
#   'email',
#   'max',
#   'mb',
#   'detik',
#   'ngeunboxing',
#   'paket',
#   'detik',
#   'pantas',
#   'maju',
#   'maju',
#   'aplikasi',
#   'belanja',
#   'online'],
#  ['jelekk',
#   'bangettttt',
#   'ttttttttttttttttttttttttttrttttt',
#   'bangeeeeereeeeeetttttttrtrtt',
#   'bangettttttttttttttt',
#   'bikin',
#   'aplikasi',
#   'nyaamdkdjsjsindbgsgajanabs'],
#  ['aplikasi'],
#  ['iklan', 'kamu', 'maksa', 'ganggu'],
#  ['iklan',
#   'jan',
#   'aplikasi',
#   'iklan',
#   'youtube',
#   'nonton',
#   'anime',
#   'nyuruh',
#   'unduh',
#   'jan',
#   'maksa',
#   'iklan',
#   'skip'],
#  ['pasang', 'iklan', 'isiin', 'tombol', 'exit'],
#  ['aplikasi',
#   'pesan',
#   'tanggal',
#   'feb',
#   'sampai',
#   'skrang',
#   'nympe',
#   'email',
#   'dibatalin',
#   'krna',
#   'kota',
#   'heh',
#   'kurir',
#   'nympe',
#   'kmna',
#   'ngirim',
#   'orang',
#   'kota',
#   'bilang',
#   'kota',
#   'security',
#   'jam',
#   'security',
#   'juga',
#   'lapor',
#   'kurir',
#   'ktmpat',
#   'belanja'],
#  ['aplikasi', 'aplikasi', 'belanja', 'online'],
#  ['status',
#   'pesan',
#   'email',
#   'kabar',
#   'proses',
#   'antre',
#   'kirim',
#   'notif',
#   'pesan',
#   'batal',
#   'telpon',
#   'customer service',
#   'kendala',
#   'kirim',
#   'seller',
#   'pesan',
#   'batal',
#   'bingung',
#   'sellernya',
#   'daerah',
#   'bekas',
#   'jakarta',
#   'timur',
#   'kendala',
#   'vouchernya',
#   'hangus',
#   'kendala',
#   'sellernya'],
#  ['spam', 'iklan', 'kamu', 'gagu'],
#  ['kesini', 'pengirimanya', 'jakarta', 'sampai'],
#  ['pesan', 'bulan', 'nov', 'sampai', 'skrng', 'komplain', 'customer service'],
#  ['mahal', 'ongkir', 'terang', 'cod', 'pas', 'checkout'],
#  ['sayang', 'bayar', 'indomaret', 'bayar', 'indomaret'],
#  ['barang',
#   'branded',
#   'aplikasi',
#   'barang',
#   'beli',
#   'muncul',
#   'itempencarian',
#   'barang',
#   'beli',
#   'susah',
#   'chat',
#   'customer service',
#   'kelua',
#   'robrolan',
#   'detail',
#   'barang',
#   'hilang',
#   'chat',
#   'chat',
#   'customer service'],
#  ['lucu', 'batal', 'ganti', 'size'],
#  ['beri',
#   'harga',
#   'official',
#   'storenya',
#   'kaget',
#   'cek',
#   'harga',
#   'beneran',
#   'rugi',
#   'terima',
#   'kasih'],
#  ['ulas', 'uninstak'],
#  ['sabar'],
#  ['detail',
#   'ukur',
#   'nga',
#   'akurat',
#   'terutama',
#   'untuk',
#   'brand',
#   'adidas',
#   'new',
#   'era',
#   'under',
#   'amour',
#   'sizenya',
#   'gede',
#   'tukar',
#   'males',
#   'ribet',
#   'permak'],
#  ['sdr',
#   'darda',
#   'bayar',
#   'siang',
#   'detik',
#   'konfirmasi',
#   'status',
#   'pesan',
#   'hasil',
#   'cek',
#   'lacak',
#   'pesan',
#   'no',
#   'order'],
#  ['gratis',
#   'ongkir',
#   'malu',
#   'utara',
#   'sedih',
#   'akutuh',
#   'plisss',
#   'gratis',
#   'ongkir'],
#  ['barang', 'bom', 'posisi', 'dijakarta'],
#  ['update', 'home', 'kategori', 'buka'],
#  ['beri', 'bintang', 'beri', 'bintang'],
#  ['saran',
#   'kirim',
#   'pilih',
#   'ratingnya',
#   'ntah',
#   'ntah',
#   'kirim',
#   'nakal',
#   'sellernya',
#   'atur',
#   'tahu',
#   'tolong',
#   'ken',
#   'beli',
#   'mikir'],
#  ['pas',
#   'chat',
#   'tanggap',
#   'customer service',
#   'tanggap',
#   'chatnya',
#   'bot',
#   'kayak',
#   'bicara',
#   'chat',
#   'csnya',
#   'balik',
#   'fitur'],
#  ['hujan', 'ggggg', 'ggggg'],
#  ['belanja', 'barang', 'lamaaaaaaa', 'negeri', 'minggu', 'sampai'],
#  ['apahal', 'model', 'bran', 'sikit'],
#  ['beli',
#   'produk',
#   'bayar',
#   'ongkir',
#   'ehh',
#   'ongkir',
#   'kirim',
#   'total',
#   'ongkir',
#   'hahaha',
#   'tulis',
#   'terang',
#   'ongkir',
#   'gin',
#   'shock'],
#  ['kirim',
#   'gagal',
#   'notif',
#   'bilang',
#   'terima',
#   'gagal',
#   'terima',
#   'kurir',
#   'order',
#   'kurir'],
#  ['blnja',
#   'krna',
#   'free',
#   'ongkir',
#   'skrng',
#   'ongkir',
#   'mahal',
#   'pngiriman',
#   'lma'],
#  ['barang', 'sesuai', 'harap'],
#  ['susah'],
#  ['maaf', 'pilih', 'kurir', 'rinci', 'mudah', 'takut', 'sesuai', 'kurir'],
#  ['komen'],
#  ['beli',
#   'sepatu',
#   'terang',
#   'sepatu',
#   'dus',
#   'plastik',
#   'mlh',
#   'sepatu',
#   'kirim',
#   'lagi',
#   'sya',
#   'bilang',
#   'tukar',
#   'belanja'],
#  ['hai', 'belanja', 'kirim', 'ekspedisi', 'sap', 'sampainnya'],
#  ['event',
#   'discounnya',
#   'sya',
#   'bayar',
#   'barng',
#   'nympk',
#   'sekrng',
#   'kirim',
#   'tipu'],
#  ['aplikasi', 'update', 'nyaman', 'untk', 'belanja'],
#  ['kcl', 'ukur', 'untuk', 'klr', 'beli', 'ukur'],
#  ['mesen', 'barang', 'barang', 'kualitas', 'pny', 'terus', 'cepat', 'nyampex'],
#  ['susah', 'login'],
#  ['aplikasi', 'ngirim', 'barang', 'hongkong'],
#  ['kenapa', 'nggk', 'cek', 'out', 'sihhh', 'ngelag'],
#  ['kemarin',
#   'promo',
#   'barang',
#   'harga',
#   'rp',
#   'undi',
#   'desember',
#   'barang',
#   'untung',
#   'menang',
#   'dana',
#   'akun',
#   'wallet',
#   'nahh',
#   'desember',
#   'informasi',
#   'menang',
#   'jelass',
#   'dana',
#   'promo',
#   'balik',
#   'hati',
#   'hati',
#   'acara',
#   'promo',
#   'tanggung',
#   'ambil',
#   'uang',
#   'konsumen',
#   'janji',
#   'palsu'],
#  ['kadang', 'barang', 'kirim', 'salah', 'warna', 'proses'],
#  ['sya',
#   'cekout',
#   'promo',
#   'tmbhan',
#   'promo',
#   'minimum',
#   'blnja',
#   'pas',
#   'pakai',
#   'hoax',
#   'minim',
#   'blnja',
#   'ribu',
#   'dl',
#   'baru',
#   'pakai',
#   'iklan',
#   'valid'],
#  ['tahu', 'jdd'],
#  ['kemarin', 'diupdate', 'lot', 'buka', 'aplikasi', 'update', 'please', 'bug'],
#  ['customer service', 'hubung', 'tracking', 'barang', 'gerak', 'barang'],
#  ['beli', 'diskon', 'kaos', 'tipis', 'bangett', 'huuff'],
#  ['customer', 'servicenya', 'slowresponnnn'],
#  ['kurir',
#   'salah',
#   'kirim',
#   'alamat',
#   'alamat',
#   'tera',
#   'sayang',
#   'harga',
#   'baju',
#   'juga',
#   'mahal',
#   'salah',
#   'alamat',
#   'untung',
#   'terima',
#   'jujur',
#   'anterin',
#   'alamat',
#   'sulit',
#   'komunikasi',
#   'gmn',
#   'fitur',
#   'chat',
#   'jual',
#   'beli',
#   'chat',
#   'customer service'],
#  ['pakai',
#   'up',
#   'beli',
#   'salah',
#   'shadenya',
#   'pes',
#   'sayang',
#   'produk',
#   'cantik',
#   'refund'],
#  ['keong', 'bangat', 'kirim'],
#  ['barang',
#   'kualitas',
#   'ragu',
#   'tapiiiii',
#   'maaf',
#   'bintang',
#   'proses',
#   'barang',
#   'langgan',
#   'tolong',
#   'bikin',
#   'belanja',
#   'harap',
#   'direfund',
#   'produk',
#   'beli',
#   'mesti',
#   'salah',
#   'produk',
#   'bantu',
#   'proses',
#   'terima',
#   'kasih'],
#  ['pesan',
#   'hari',
#   'ngecewakn',
#   'brang',
#   'sen',
#   'dengn',
#   'model',
#   'poto',
#   'sen',
#   'beda',
#   'sesuai',
#   'bhnypun',
#   'kasar',
#   'jhtan',
#   'rapi',
#   'pdhl',
#   'belanja',
#   'brangny',
#   'memuaskn',
#   'beda',
#   'aplikasi',
#   'sbelah',
#   'barangny',
#   'asliny',
#   'tlong',
#   'prtahankn',
#   'tetep',
#   'bgus'],
#  ['loading', 'aplikasi', 'stuck', 'logo', 'interface', 'bosan'],
#  ['admin',
#   'beli',
#   'jaket',
#   'harga',
#   'ribu',
#   'barang',
#   'kirim',
#   'harga',
#   'ribu',
#   'beli',
#   'produk',
#   'diskon',
#   'tukar',
#   'takut',
#   'kendala'],
#  ['barang',
#   'chating',
#   'admin',
#   'susah',
#   'sx',
#   'urus',
#   'bla',
#   'bla',
#   'bla',
#   'belanja',
#   'puluh',
#   'respon',
#   'admin'],
#  ['adidas', 'samba', 'black', 'whitenya', 'restock', 'domg'],
#  ['upgrade', 'error', 'lot', 'muncul'],
#  ['barang',
#   'pas',
#   'lacak',
#   'simpan',
#   'gudang',
#   'alas',
#   'alamat',
#   'salah',
#   'pdhl',
#   'beli',
#   'nyampe',
#   'barang',
#   'sampai',
#   'tolong'],
#  ['duhhh',
#   'bisa',
#   'lacak',
#   'pesan',
#   'barang',
#   'engga',
#   'sampai',
#   'kaya',
#   'gin',
#   'cek',
#   'status',
#   'aza',
#   'bisa',
#   'aneh',
#   'gin',
#   'yh',
#   'bayar',
#   'tolong',
#   'admin',
#   'ny',
#   'costemer',
#   'servic',
#   'ny',
#   'cek',
#   'statu',
#   'bisa',
#   'tulis',
#   'ny',
#   'kemas'],
#  ['search', 'celana', 'kategori', 'wanita', 'celana', 'pria', 'aneh'],
#  ['alam',
#   'beli',
#   'jaket',
#   'jeans',
#   'harga',
#   'dasar',
#   'mahal',
#   'diskon',
#   'tarik',
#   'beli',
#   'barang',
#   'kayak',
#   'beli',
#   'kucing',
#   'karung'],
#  ['size', 'barang', 'update', 'pdhal', 'uda', 'tunggu'],
#  ['online', 'belanja', 'all', 'shophooligans'],
#  ['beli', 'produk', 'data', 'isi', 'ketik'],
#  ['aplikasi',
#   'aneh',
#   'chating',
#   'jual',
#   'takut',
#   'tipu',
#   'jujur',
#   'tolong',
#   'tambahin',
#   'metode',
#   'bayar',
#   'biar',
#   'takut',
#   'tipu'],
#  ['susah',
#   'konsultasi',
#   'jual',
#   'size',
#   'utama',
#   'ukur',
#   'negri',
#   'fitur',
#   'chat'],
#  ['filter', 'ukur', 'befungsi', 'harap'],
#  ['xdxsssse',
#   'csxxx',
#   'dddcz',
#   'ft',
#   'ggg',
#   'xd',
#   'free',
#   'cewek',
#   'wzwvgt',
#   'see',
#   'xx',
#   'za'],
#  ['habis', 'update', 'produk', 'diwishlist', 'buka', 'ntap'],
#  ['tolong',
#   'aplikasiya',
#   'tingkat',
#   'tukar',
#   'barang',
#   'diaplikasiya',
#   'belanja',
#   'sayang',
#   'sistemya',
#   'bodoh'],
#  ['langgan',
#   'beli',
#   'sepatu',
#   'sepatu',
#   'rusak',
#   'kulit',
#   'sepatu',
#   'pecah',
#   'kadarluarsa',
#   'rugi',
#   'duit',
#   'rugi',
#   'percaya'],
#  ['tampil',
#   'potong',
#   'kategori',
#   'buah',
#   'brand',
#   'tampil',
#   'banner',
#   'brand',
#   'menganggu',
#   'discroll',
#   'banner',
#   'otomatis',
#   'hilang'],
#  ['applikasinya',
#   'update',
#   'lot',
#   'loading',
#   'melulu',
#   'sinyal',
#   'belanja',
#   'kesini',
#   'nyaman',
#   'buka',
#   'tampil',
#   'tampil',
#   'tolong',
#   'biar',
#   'nyaman',
#   'buka',
#   'aplikasi'],
#  ['bgus'],
#  ['alm', 'mm', 'plp'],
#  ['ukur',
#   'aplikasi',
#   'load',
#   'gambar',
#   'pakai',
#   'susah',
#   'buka',
#   'tunggu',
#   'tolong',
#   'mudah',
#   'gambar'],
#  ['voucher', 'barang'],
#  ['belanja',
#   'cod',
#   'pembayaranya',
#   'melaui',
#   'alfa',
#   'indomart',
#   'pembayaranya',
#   'cod'],
#  ['asli', 'barang', 'barang', 'pesan', 'sesuai', 'kirim', 'habis', 'sale'],
#  ['belanja',
#   'dsini',
#   'asli',
#   'barang',
#   'kualitas',
#   'percaya',
#   'cman',
#   'kenapa',
#   'msih',
#   'kasih',
#   'bintang',
#   'spatu',
#   'sya',
#   'ukur',
#   'beda',
#   'return',
#   'aplikasi',
#   'beda',
#   'customer',
#   'service',
#   'ktanya',
#   'return',
#   'suruh',
#   'mnununggu',
#   'cek',
#   'check',
#   'return'],
#  ['bingung'],
#  ['aplikasi',
#   'sngat',
#   'bgus',
#   'tarik',
#   'buka',
#   'harga',
#   'ny',
#   'mahal',
#   'pesan',
#   'gx',
#   'lhat',
#   'pesan',
#   'mna'],
#  ['aplikasi',
#   'susah',
#   'batal',
#   'pesan',
#   'sbnrnya',
#   'batal',
#   'ganti',
#   'ukur',
#   'tapi',
#   'susah'],
#  ['cek', 'order'],
#  ['cashback',
#   'pendek',
#   'kemarin',
#   'smpai',
#   'desak',
#   'beli',
#   'cepat',
#   'cashback',
#   'hangus',
#   'paksa',
#   'sihh',
#   'kritik'],
#  ['tolong', 'barang', 'barang', 'direstok', 'barang', 'kosong'],
#  ['aplikasi', 'bias', 'buka'],
#  ['belanja', 'bangett', 'semogaa', 'ngecewain'],
#  ['thxs'],
#  ['lagi',
#   'diskon',
#   'harga',
#   'sekian',
#   'pas',
#   'barang',
#   'jaitan',
#   'bagaimana',
#   'gtu',
#   'tali',
#   'kes',
#   'tas',
#   'murah'],
#  ['brand', 'matahari'],
#  ['bayar', 'pakai', 'cod', 'cepat', 'bayar', 'transfer', 'minggu'],
#  ['layan', 'castomer', 'layan', 'dana', 'lambat', 'harua', 'ulang', 'tanyain'],
#  ['tolong',
#   'jasa',
#   'kirim',
#   'pakai',
#   'opsi',
#   'pas',
#   'check',
#   'out',
#   'pilih',
#   'lion',
#   'parcel'],
#  ['jual', 'seller'],
#  ['konfigurasi', 'terang'],
#  ['update', 'susah', 'hubung', 'bantu', 'chat'],
#  ['chat',
#   'seller',
#   'barang',
#   'sedia',
#   'bertanya',
#   'ukur',
#   'sedia',
#   'terang',
#   'stock'],
#  ['cuman', 'bilang', 'bayar', 'email'],
#  ['pakai', 'ongkir'],
#  ['produk',
#   'guess',
#   'hilang',
#   'gaiss',
#   'bnyaknya',
#   'tas',
#   'kaos',
#   'jeans',
#   'nyisa',
#   'parfum',
#   'jam',
#   'tangan',
#   'aneh'],
#  ['poko', 'mntaap', 'membantuu'],
#  ['barang', 'palu', 'kirim', 'rpx', 'antar', 'antar'],
#  ['pakai', 'tahu', 'bintang', 'pictures', 'tampil', 'spesifik'],
#  ['tingkat', 'promo', 'aplikasi'],
#  ['tolong',
#   'kirim',
#   'produk',
#   'cek',
#   'produk',
#   'kirim',
#   'produk',
#   'hasil',
#   'costumer',
#   'pesan',
#   'tas',
#   'produk',
#   'kotor',
#   'bekas',
#   'pakai',
#   'lecet',
#   'lubang',
#   'tali',
#   'lubang',
#   'paksa',
#   'sayang',
#   'aju',
#   'acara',
#   'kota'],
#  ['belanja',
#   'krna',
#   'harga',
#   'lbh',
#   'murah',
#   'drpda',
#   'toko',
#   'online',
#   'produk',
#   'updgrade',
#   'handphone',
#   'lagi',
#   'loading',
#   'terus'],
#  ['jujur', 'mahal', 'murahin', 'dikit', 'kaaa'],
#  ['kakak',
#   'saran',
#   'kasih',
#   'fitur',
#   'komen',
#   'kaya',
#   'gin',
#   'beli',
#   'lihat',
#   'pesan',
#   'pes',
#   'barang',
#   'review',
#   'pengaruh',
#   'beli',
#   'takut',
#   'salah',
#   'salah',
#   'beli',
#   'barang',
#   'online',
#   'review'],
#  ['alam',
#   'pribadi',
#   'belanja',
#   'order',
#   'kemarin',
#   'barang',
#   'tunggu',
#   'tunggu',
#   'minggu',
#   'kirim',
#   'uang',
#   'kredit',
#   'wallet',
#   'rekening',
#   'pindah',
#   'uang',
#   'kredit',
#   'wallet',
#   'rekening'],
#  ['asli', 'barang'],
#  ['barang', 'asli'],
#  ['barang',
#   'appnya',
#   'easy',
#   'use',
#   'chat',
#   'bantu',
#   'aplikasi',
#   'tutup',
#   'chat',
#   'hilang',
#   'home',
#   'cari',
#   'barang',
#   'susah',
#   'hilang',
#   'kategori'],
#  ['ribet',
#   'order',
#   'pes',
#   'bayar',
#   'bertanya',
#   'pakai',
#   'akun',
#   'sesuai',
#   'pas',
#   'mesan',
#   'tetep',
#   'data',
#   'pribadi',
#   'aplikasi',
#   'websitenya'],
#  ['sen',
#   'nex',
#   'day',
#   'biar',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'sampai',
#   'luarkota'],
#  ['komplen', 'ribet'],
#  ['cod'],
#  ['fitur',
#   'komen',
#   'ntah',
#   'review',
#   'costumer',
#   'cht',
#   'olshop',
#   'susah',
#   'konsul',
#   'bingung',
#   'chek',
#   'out'],
#  ['barang', 'sesuai', 'pesan', 'zlr', 'online', 'shop', 'asli'],
#  ['mesen',
#   'barabg',
#   'sen',
#   'baju',
#   'mesen',
#   'baju',
#   'ukur',
#   'kasih',
#   'ukur',
#   'mesen',
#   'sendal',
#   'heelsnya',
#   'mesen',
#   'baju',
#   'tolong',
#   'ganti',
#   'ukur'],
#  ['bintang'],
#  ['smntara', 'sgitu'],
#  ['fitur', 'lacak', 'mesan', 'status', 'kirim', 'ubah', 'ubah'],
#  ['pakai',
#   'rating',
#   'toko',
#   'komen',
#   'kualitas',
#   'produk',
#   'terima',
#   'produk',
#   'terima',
#   'cacat'],
#  ['habis', 'update', 'ngbug', 'pakai', 'homescreen', 'muncul'],
#  ['beli',
#   'flanel',
#   'pas',
#   'sampai',
#   'beda',
#   'warna',
#   'order',
#   'tolong',
#   'selalu',
#   'update',
#   'katalog',
#   'kolom',
#   'chat',
#   'rating',
#   'terang',
#   'barang',
#   'kirim',
#   'untuk',
#   'buyer',
#   'biar',
#   'stok',
#   'complain',
#   'deskripsi',
#   'barang',
#   'lengkap'],
#  ['belanja',
#   'cashback',
#   'voucher',
#   'beli',
#   'beli',
#   'sepatu',
#   'sepatu',
#   'asli',
#   'asli',
#   'ukur',
#   'kaki',
#   'asa',
#   'sesak',
#   'aju',
#   'tukar',
#   'pos',
#   'tunggu',
#   'email',
#   'customer service',
#   'beliau',
#   'bilang',
#   'sepatu',
#   'lolos',
#   'qualty',
#   'control',
#   'dikirimin',
#   'foto',
#   'sya',
#   'kaget',
#   'sepatu',
#   'beda',
#   'kemas',
#   'ulang',
#   'salah'],
#  ['fitur', 'lacak', 'pesan', 'mudah', 'lacak', 'gera', 'pesan'],
#  ['puluh',
#   'order',
#   'reword',
#   'langgan',
#   'setia',
#   'langgan',
#   'sa',
#   'poin',
#   'promo',
#   'voucher'],
#  ['nggk', 'opsi', 'batal', 'pesan'],
#  ['filter', 'ukur', 'hapus'],
#  ['aplikasi',
#   'sebenernya',
#   'loading',
#   'buka',
#   'gin',
#   'beli',
#   'gambar',
#   'barang',
#   'muncul',
#   'gegara',
#   'loading',
#   'milik',
#   'kuota',
#   'internet',
#   'buka',
#   'aplikasi',
#   'lancar',
#   'tolong'],
#  ['appsmu',
#   'berat',
#   'buka',
#   'loadingnya',
#   'lamaaaaaa',
#   'bikin',
#   'males',
#   'ram',
#   'handphone',
#   'gb',
#   'think'],
#  ['pelit', 'graris', 'ongkir', 'belanja', 'juta'],
#  ['kalu',
#   'kirim',
#   'barang',
#   'dos',
#   'sepatu',
#   'perhati',
#   'da',
#   'pesan',
#   'pas',
#   'dos',
#   'rusak',
#   'isi',
#   'aman'],
#  ['memuadkan'],
#  ['cashback',
#   'ket',
#   'pemabayan',
#   'ket',
#   'cashback',
#   'sekian',
#   'tapi',
#   'muncul',
#   'cashback'],
#  ['tt', 'hvz', 'nd'],
#  ['aplikasi', 'tukar', 'ukur', 'pilih', 'ukur', 'tukar', 'error'],
#  ['kasi', 'gin', 'baju', 'anime', 'kostum', 'kasi', 'bintang'],
#  ['masukkan', 'alamat', 'alamat', 'provinsi', 'kota', 'klik'],
#  ['tolong',
#   'kasih',
#   'fitur',
#   'chat',
#   'diskusi',
#   'produk',
#   'produk',
#   'beli',
#   'contoh',
#   'aplikasi',
#   'kasih',
#   'fitur',
#   'tracking',
#   'aplikasi',
#   'sistem',
#   'konfirmasi',
#   'mesan',
#   'sistem',
#   'bayar',
#   'bikin',
#   'simple',
#   'aplikasi',
#   'produk',
#   'tahan',
#   'kualitas',
#   'barang',
#   'amanah'],
#  ['tolong',
#   'ukur',
#   'detail',
#   'lingkar',
#   'pinggang',
#   'celana',
#   'biar',
#   'retur'],
#  ['barang', 'mahal'],
#  ['pakai', 'facebook', 'blackscreen'],
#  ['lengkap', 'olah', 'raga', 'sepatu', 'bola', 'biarin', 'hahahaa'],
#  ['batal',
#   'pesan',
#   'buka',
#   'akun',
#   'lacak',
#   'pesan',
#   'batal',
#   'pesan',
#   'menu'],
#  ['konfirmasi', 'barang', 'terima'],
#  ['ratingnya', 'kaya', 'beli'],
#  ['plus',
#   'barang',
#   'jamin',
#   'asli',
#   'retur',
#   'barang',
#   'murah',
#   'toko',
#   'resmi',
#   'cashback',
#   'gede',
#   'minus',
#   'fitur',
#   'komen',
#   'beli',
#   'pilih',
#   'kurir',
#   'ekspedisi',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ribu'],
#  ['barang'],
#  ['she'],
#  ['barang', 'konformasi', 'cashback', 'pakai'],
#  ['force', 'close', 'buka', 'hitam', 'beli'],
#  ['bantu'],
#  ['saran',
#   'gaush',
#   'cashback',
#   'lebih baik',
#   'code',
#   'voucer',
#   'gedein',
#   'klaim',
#   'cashback',
#   'tuker',
#   'barang',
#   'beli',
#   'ganggu'],
#  ['bayar',
#   'virtual',
#   'billing',
#   'mobile',
#   'banking',
#   'muncul',
#   'notifikasi',
#   'billing',
#   'temu',
#   'batal',
#   'tombol',
#   'batal',
#   'pesan'],
#  ['mantaap'],
#  ['kualitas',
#   'asli',
#   'sen',
#   'sepatu',
#   'tinggal',
#   'return',
#   'kendala',
#   'urgent',
#   'tinggal',
#   'dm',
#   'instagram',
#   'cepat',
#   'proses',
#   'customer service',
#   'robot',
#   'bintang',
#   'krna',
#   'rasain',
#   'pas',
#   'barang',
#   'wishlistku',
#   'habis',
#   'klik',
#   'beritahu',
#   'lewar',
#   'email',
#   'barang',
#   'sedia',
#   'email',
#   'ujung',
#   'habis',
#   'barang',
#   'trakhir',
#   'habis',
#   'sepatu',
#   'guess',
#   'breeta',
#   'hitam'],
#  ['well'],
#  ['mga', 'produk', 'murah'],
#  ['barang',
#   'asli',
#   'kaleng',
#   'harga',
#   'murmer',
#   'promo',
#   'tarik',
#   'fitur',
#   'chat',
#   'onlen',
#   'shop',
#   'buyer',
#   'via',
#   'chat'],
#  ['produk',
#   'asli',
#   'belanja',
#   'merk',
#   'muka',
#   'asli',
#   'beda',
#   'no',
#   'brand',
#   'oem',
#   'kelola',
#   'thiongkok'],
#  ['applause',
#   'tim',
#   'proses',
#   'refund',
#   'hasil',
#   'tingkat',
#   'cepat',
#   'proses',
#   'lapor',
#   'usaha',
#   'tukar',
#   'barang',
#   'customer',
#   'sekian'],
#  ['saran',
#   'fitur',
#   'komentar',
#   'customer',
#   'review',
#   'review',
#   'fitur',
#   'chat',
#   'customer',
#   'service',
#   'ajar',
#   'platform',
#   'ecommerce',
#   'customer'],
#  ['belanja', 'layan'],
#  ['nicee'],
#  ['aplikasi',
#   'belanja',
#   'produk',
#   'diskon',
#   'tawar',
#   'gratis',
#   'belanja',
#   'online',
#   'potong',
#   'harga',
#   'produk',
#   'voucher',
#   'diskon',
#   'banyakin',
#   'mudah',
#   'produk',
#   'zara',
#   'uniqlo',
#   'gabung',
#   'terima',
#   'kasih'],
#  ['fitur', 'mudah'],
#  ['tracking', 'akses'],
#  ['kirim',
#   'cepat',
#   'pesan',
#   'sampai',
#   'fitur',
#   'ulas',
#   'beli',
#   'tas',
#   'dapetnya',
#   'kotor',
#   'debu',
#   'noda',
#   'lem',
#   'buka',
#   'produk',
#   'display',
#   'untung',
#   'beli',
#   'diskon',
#   'anggap',
#   'beli',
#   'murah',
#   'sayang'],
#  ['saran', 'tambahlan', 'chat'],
#  ['blnja',
#   'alhmdulillah',
#   'ngecewain',
#   'barng',
#   'muslimahnya',
#   'kurang',
#   'kurang',
#   'variasi',
#   'tuker',
#   'barng',
#   'kekeciln',
#   'prnah',
#   'daerah',
#   'pnukaran',
#   'barng',
#   'order',
#   'prtama',
#   'ribet'],
#  ['tampil', 'bikin', 'pusing', 'tampil'],
#  ['survey'],
#  ['pakai',
#   'ganti',
#   'akun',
#   'kirim',
#   'box',
#   'sepatu',
#   'penyok',
#   'syukur',
#   'barang',
#   'aman',
#   'belanja',
#   'barang',
#   'kirim',
#   'cepat',
#   'perfect'],
# ...
#  ['belanja'],
#  ['produk', 'asli', 'paket', 'kemas', 'apik', 'kirim', 'cepat', 'aman'],
#  ['mudah', 'barang', 'kualitas'],
#  ['proses', 'barang', 'mudah', 'cepat'],
#  ['mantapp'],
#  ['gewd'],
#  ['senag', 'alikasi'],
#  ['baguss', 'dannammamammammama'],
#  ['alhamdulillah',
#   'sekian',
#   'belanja',
#   'alhamdulilah',
#   'utama',
#   'barang',
#   'nggk',
#   'ribet',
#   'mudah',
#   'proses',
#   'alhamdulilah',
#   'layan',
#   'diskon',
#   'diskon'],
#  ['pokok'],
#  ['terima', 'kasih', 'zalira'],
#  ['ahh', 'mantapsss'],
#  ['aplikasi'],
#  ['zaloraharus', 'dibi', 'tang', 'produk', 'produk', 'ngecewain', 'harga'],
#  ['kualitas'],
#  ['aplikasi', 'joss'],
#  ['pakai', 'ny'],
#  ['apik'],
#  ['barang', 'asli', 'kirim', 'dng', 'cepat'],
#  ['nicee'],
#  ['just'],
#  ['barang', 'bangeeet'],
#  ['man', 'tap'],
#  ['puuuas', 'bannnnget'],
#  ['storrrrrrrrrrrrr', 'kaliiiiiiiiiii'],
#  ['barang', 'tabah', 'dengang', 'sarung', 'bhs', 'bhs', 'sutra'],
#  ['surga', 'cari', 'barang', 'branded', 'diskon', 'gede'],
#  ['barang', 'selalu', 'asli', 'bikin', 'blnja', 'tngkatkan', 'layan', 'ny'],
#  ['belanja'],
#  ['barang', 'asli'],
#  ['service', 'quality', 'barang'],
#  ['barang', 'asli'],
#  ['neng', 'sukses'],
#  ['belanja', 'baju', 'sepan', 'barang', 'asli', 'semuah'],
#  ['baguss'],
#  ['belanja'],
#  ['recommend'],
#  ['aplikasi'],
#  ['apik'],
#  ['produk', 'mantaaaaap'],
#  ['cepat', 'nyampe', 'kirim', 'defect'],
#  ['asyik',
#   'belanja',
#   'aman',
#   'pasto',
#   'barang',
#   'retur',
#   'alas',
#   'barang',
#   'pakai'],
#  ['belanja', 'puasss'],
#  ['nyaman', 'terpecaya'],
#  ['aplikasi', 'bantu', 'bantu', 'uras', 'uang', 'wkwkwk'],
#  ['suka'],
#  ['asli', 'bareng', 'gambar', 'belanja', 'percaya', 'bareng', 'branded'],
#  ['belanja', 'hemat'],
#  ['luaarrr',
#   'biassaaa',
#   'layan',
#   'fitur',
#   'free',
#   'sesuai',
#   'alir',
#   'belanja',
#   'mikir',
#   'usul',
#   'saran',
#   'gratis',
#   'ongkir',
#   'luas',
#   'untuk',
#   'brand',
#   'free',
#   'ongkir',
#   'kirim',
#   'handle',
#   'zdex',
#   'customer',
#   'mikir',
#   'ongkir',
#   'lagi'],
#  ['branded', 'harga'],
#  ['bbm',
#   'harga',
#   'nnh',
#   'jb',
#   'pakai',
#   'swab',
#   'junjung',
#   'bhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh',
#   'uji',
#   'uu'],
#  ['like', 'it'],
#  ['diskon', 'tarik', 'barang'],
#  ['kasi', 'banya', 'diskon'],
#  ['belanja'],
#  ['product', 'ory'],
#  ['barang', 'asli'],
#  ['product', 'asli'],
#  ['pernah', 'blnja', 'produk', 'asli'],
#  ['percaya'],
#  ['layan', 'complain', 'ulas', 'beli'],
#  ['lebar', 'aplikasi', 'percaya', 'jual', 'beli', 'barang', 'berkwalitas'],
#  ['kirim', 'cepat', 'terima'],
#  ['belanja'],
#  ['packing', 'pakai', 'double', 'box', 'jugaaa', 'neng'],
#  ['teman', 'prospek', 'untuk', 'jual', 'produk', 'kualitas'],
#  ['belanja'],
#  ['murah', 'asli', 'recommended'],
#  ['beli'],
#  ['mantappppp', 'abisskan', 'duit'],
#  ['asli', 'garansi'],
#  ['sya', 'perdana', 'pesan', 'layan', 'na'],
#  ['crot', 'pokok'],
#  ['godd'],
#  ['bantu', 'temu', 'barang', 'brand', 'nama', 'harga', 'miring'],
#  ['belanja',
#   'barang',
#   'asli',
#   'kualitas',
#   'kemarin',
#   'sempat',
#   'kirim',
#   'garagara',
#   'demo',
#   'ganti',
#   'tunggu',
#   'alhamdulillah',
#   'cashback',
#   'ribu',
#   'alam',
#   'so',
#   'far',
#   'kirim',
#   'cepat',
#   'langgan',
#   'setia',
#   'belanja',
#   'online',
#   'belanja',
#   'kualitas',
#   'produk',
#   'sesuai',
#   'harga',
#   'thankyou',
#   'online',
#   'belanja'],
#  ['produk', 'layan'],
#  ['layan', 'percaya', 'cari', 'barang', 'branded', 'asli', 'discount'],
#  ['bahan'],
#  ['cocok'],
#  ['bantu', 'produk'],
#  ['casback'],
#  ['mantappp', 'belanja', 'barang', 'lanjut', 'order'],
#  ['belanja',
#   'kirim',
#   'cepat',
#   'harga',
#   'jangkau',
#   'dn',
#   'bayar',
#   'tempat',
#   'repot',
#   'harus',
#   'cari',
#   'atm',
#   'cuaca',
#   'hujan'],
#  ['aplikasi', 'gampang'],
#  ['layan', 'verygood'],
#  ['layan', 'tawar', 'diskon', 'kirim'],
#  ['barang', 'sesuai', 'gambar'],
#  ['promo', 'bareng', 'asli', 'cod'],
#  ['bonus', 'berkah', 'usaha', 'amiin'],
#  ['informasi'],
#  ['bingits', 'produk'],
#  ['mantulzzzz', 'kirim', 'cepat', 'barang', 'asli'],
#  ['aplikasi',
#   'friendly',
#   'untuk',
#   'user',
#   'usia',
#   'th',
#   'erti',
#   'belanja',
#   'fitur',
#   'aplikasi',
#   'aplikasi',
#   'retur',
#   'barang',
#   'ribet'],
#  ['barang', 'asli'],
#  ['tahan', 'jual', 'barang', 'asli'],
#  ['cepat', 'kirim'],
#  ['olshop', 'percaya', 'kereeennnn', 'abissss'],
#  ['sesuai', 'brngnya'],
#  ['mantuuul'],
#  ['komen',
#   'cepat',
#   'kilat',
#   'paket',
#   'dateng',
#   'drpd',
#   'toko',
#   'online',
#   'worth'],
#  ['belanja'],
#  ['produk', 'persen', 'asli', 'kualitas', 'pokok', 'belanja'],
#  ['pesan', 'emas', 'rapih', 'pesan', 'sesuai', 'pesan'],
#  ['smoga', 'asli', 'tahan', 'sukses'],
#  ['proses', 'return', 'detail', 'dana', 'cepat', 'juossss'],
#  ['online', 'shop', 'fashion'],
#  ['belanja',
#   'promo',
#   'diskon',
#   'cashbacknya',
#   'teman',
#   'teman',
#   'ragu',
#   'belanja',
#   'produk',
#   'asli',
#   'proses',
#   'kirim',
#   'cepat',
#   'terima',
#   'kasih'],
#  ['barang', 'asli'],
#  ['mantap', 'slur'],
#  ['barang', 'asli', 'asli'],
#  ['produk', 'asli', 'berkuakiatas'],
#  ['sayang', 'ulas', 'produk', 'customer', 'raba', 'raba'],
#  ['bereeeehhh'],
#  ['mantaaaaaaaaaap'],
#  ['barang', 'sesuai', 'retur', 'gin', 'poko', 'lov', 'lov', 'lov'],
#  ['experience'],
#  ['mantepp'],
#  ['markotop'],
#  ['notif',
#   'coba',
#   'beli',
#   'barang',
#   'pakai',
#   'voc',
#   'pot',
#   'lagi',
#   'pkk',
#   'kirim',
#   'cepat',
#   'sekarang',
#   'sen',
#   'besok',
#   'sampai',
#   'drama',
#   'susah',
#   'cari',
#   'alamat'],
#  ['barang'],
#  ['siippp', 'lahhhh'],
#  ['kelas'],
#  ['barang'],
#  ['asli', 'it'],
#  ['barang', 'barang'],
#  ['diskon', 'barang', 'cepat', 'kirim'],
#  ['kasih', 'fitur', 'ulas', 'biar', 'tahu', 'ulas', 'customer'],
#  ['belanja', 'makasiiihh'],
#  ['beli', 'barang', 'asli', 'kirim', 'cepat', 'box', 'lapis'],
#  ['bnyakin', 'promonya'],
#  ['flagship', 'asli'],
#  ['aplikasi'],
#  ['kualitas', 'barang'],
#  ['tingkat', 'ongkir'],
#  ['worth', 'it', 'belanja'],
#  ['its', 'ngabisin', 'duit', 'wkwk'],
#  ['aplikasi', 'commerce'],
#  ['produk', 'sesuai', 'proses', 'ny', 'mudah', 'cepat', 'percaya'],
#  ['mudah',
#   'aman',
#   'belanja',
#   'repot',
#   'transfer',
#   'no',
#   'rekening',
#   'nilai',
#   'transfer',
#   'tinggal',
#   'klik'],
#  ['barang', 'barang'],
#  ['belanja'],
#  ['barang', 'mutu'],
#  ['jamin',
#   'barang',
#   'asli',
#   'seller',
#   'uang',
#   'hukum',
#   'seller',
#   'barang',
#   'asli',
#   'harap',
#   'seller',
#   'tipu',
#   'dberikan',
#   'sanksi'],
#  ['belanja',
#   'fashion',
#   'evoria',
#   'hidup',
#   'gaya',
#   'hidup',
#   'mode',
#   'timbang',
#   'daya',
#   'beli',
#   'dikatan',
#   'hidup',
#   'economi',
#   'biaya',
#   'cotoh',
#   'buah',
#   'tas',
#   'gaya',
#   'harga',
#   'tas'],
#  ['newbie',
#   'ragu',
#   'belanja',
#   'takut',
#   'barang',
#   'halu',
#   'setelah',
#   'bareng',
#   'nyampe',
#   'benar',
#   'barang',
#   'asli',
#   'ekspetasi',
#   'belanja'],
#  ['belanjanda'],
#  ['bagussssd'],
#  ['belanja',
#   'sempat',
#   'ragu',
#   'takut',
#   'barang',
#   'asli',
#   'pesan',
#   'backpack',
#   'terpacking',
#   'rapih',
#   'asli',
#   'lengkap',
#   'tag',
#   'rusak'],
#  ['layan'],
#  ['belanja', 'fashion', 'brand', 'asli', 'lengkap', 'indonesia'],
#  ['barang', 'sesuai', 'harga'],
#  ['simple', 'cari', 'ukur', 'warna', 'mudah'],
#  ['hay',
#   'olshop',
#   'fashion',
#   'asli',
#   'tahu',
#   'uda',
#   'beri',
#   'promo',
#   'tunggu',
#   'gebrak',
#   'promo'],
#  ['online', 'shop', 'percaya', 'langgan', 'sampai', 'setia'],
#  ['suke', 'sukee'],
#  ['tolong', 'mudah', 'lacak', 'kirim'],
#  ['bantu', 'cari', 'originalitas'],
#  ['like'],
#  ['mntap', 'harga'],
#  ['bnyak',
#   'complain',
#   'asa',
#   'belanja',
#   'produk',
#   'jamin',
#   'asli',
#   'diskon',
#   'bareng',
#   'branded',
#   'produk',
#   'guess',
#   'akses'],
#  ['its'],
#  ['barang', 'asli', 'belanja', 'diskon'],
#  ['dabest', 'dahh'],
#  ['mudah', 'belanja'],
#  ['jual', 'jujur', 'cuman', 'harga', 'mahal', 'mahal'],
#  ['baju'],
#  ['kasih', 'cashback'],
#  ['aplikasi'],
#  ['ken', 'cashbak'],
#  ['model', 'produk', 'untuk', 'update'],
#  ['belanja',
#   'barang',
#   'sesuai',
#   'gambar',
#   'kirim',
#   'cepat',
#   'customer service'],
#  ['markotob'],
#  ['real', 'asli'],
#  ['asli'],
#  ['aplikasi',
#   'mudah',
#   'percaya',
#   'barang',
#   'asli',
#   'branded',
#   'harga',
#   'diskon',
#   'wowwww'],
#  ['aplikasi', 'paham', 'mf', 'barang', 'beli', 'tahu', 'boss'],
#  ['markotop'],
#  ['belanja',
#   'barang',
#   'asli',
#   'kirim',
#   'juga',
#   'cepat',
#   'kemas',
#   'rapi',
#   'aman',
#   'meperdulikan',
#   'barang'],
#  ['daebagggg'],
#  ['bantu'],
#  ['barang', 'asli'],
#  ['proses',
#   'beli',
#   'nyaman',
#   'jamin',
#   'asli',
#   'proses',
#   'refund',
#   'mudah',
#   'layan',
#   'proses'],
#  ['pokok'],
#  ['kereeen', 'bingits'],
#  ['gooood'],
#  ['sukses'],
#  ['user', 'friendly'],
#  ['brand', 'kenal', 'cashback'],
#  ['sengaja',
#   'aplikasi',
#   'tinggal',
#   'duduk',
#   'rumah',
#   'layan',
#   'product',
#   'asli',
#   'jual',
#   'kurir',
#   'tpt',
#   'kurir',
#   'tahan',
#   'barang',
#   'subject',
#   'return'],
#  ['barang', 'kualitas', 'belanja'],
#  ['belanja', 'nyaman', 'barang', 'asli', 'belanja', 'kerenn'],
#  ['pilih'],
#  ['belanja',
#   'dsni',
#   'lbh',
#   'praktis',
#   'nemuin',
#   'barang',
#   'lucu',
#   'bnyak',
#   'diskon',
#   'asli',
#   'juga'],
#  ['jamin', 'asli', 'plus', 'disc', 'cashback'],
#  ['beli', 'retur', 'barang', 'jamin'],
#  ['barang',
#   'jual',
#   'lengkap',
#   'pilih',
#   'brand',
#   'bayar',
#   'mudah',
#   'kirim',
#   'cepat',
#   'proses',
#   'barang',
#   'cacat',
#   'tsb',
#   'mjd',
#   'proses',
#   'mudah',
#   'pos',
#   'indonesia',
#   'gratis',
#   'stok',
#   'barang',
#   'ganti',
#   'brand',
#   'leluasa',
#   'pilih',
#   'brand',
#   'biaya',
#   'cashback',
#   'beli'],
#  ['alhamdulillah',
#   'belanja',
#   'aman',
#   'pas',
#   'lebaran',
#   'nyampe',
#   'nyampenya',
#   'cepat',
#   'barang',
#   'cashback',
#   'ribu',
#   'voucher',
#   'diskon',
#   'double',
#   'bonus'],
#  ['alam',
#   'beli',
#   'branded',
#   'asli',
#   'takut',
#   'tipu',
#   'banyak',
#   'disc',
#   'juga'],
#  ['belanja', 'produk', 'asli'],
#  ['belanja',
#   'diskon',
#   'cashback',
#   'ribu',
#   'barang',
#   'jamin',
#   'asli',
#   'brand',
#   'fashion',
#   'favorit',
#   'zalia',
#   'lubna'],
#  ['nyaman', 'belanja'],
#  ['ngebantu'],
#  ['online', 'toko', 'langgan'],
#  ['benar',
#   'benar',
#   'belanja',
#   'barang',
#   'asli',
#   'diskon',
#   'cashback',
#   'recomended'],
#  ['harga', 'turun', 'lagi', 'boss'],
#  ['mantpp'],
#  ['belanja'],
#  ['lagi', 'pandemi', 'gin', 'cari', 'barang', 'asli'],
#  ['alhamdulillah',
#   'belanja',
#   'barang',
#   'harga',
#   'kualitas',
#   'asli',
#   'betah',
#   'belanja'],
#  ['mantao', 'retur', 'bareng', 'gampang', 'dana', 'retur', 'cepat'],
#  ['produk', 'kualitas', 'merk', 'asli', 'barang', 'sesuai', 'pesan'],
#  ['kasi', 'diskon'],
#  ['barang', 'asli'],
#  ['kenal', 'tiktok', 'ikelan', 'yutube'],
#  ['real', 'pick', 'mengcewakan', 'kurir', 'mksh'],
#  ['produk', 'tawar', 'kualitas', 'mutu'],
#  ['its', 'ahh'],
#  ['barang', 'asli'],
#  ['metode', 'bayar', 'cod', 'bayar'],
#  ['belanja', 'fashion', 'asli'],
#  ['bangat'],
#  ['chat', 'jual', 'barang', 'biar', 'barang'],
#  ['sneaker',
#   'strip',
#   'ken',
#   'bnget',
#   'milik',
#   'stok',
#   'iseng',
#   'bnyak',
#   'bnget',
#   'stok',
#   'model',
#   'siap',
#   'bnyak',
#   'diskon',
#   'gede',
#   'belanja',
#   'cepat',
#   'bnget',
#   'nyampe',
#   'respon',
#   'customer service',
#   'ramah',
#   'fashion',
#   'brand',
#   'andal'],
#  ['belanja', 'bayar', 'cod', 'bayar', 'sya', 'belanja'],
#  ['easy', 'apply'],
#  ['pokok', 'belanja'],
#  ['hai',
#   'belanja',
#   'barang',
#   'sesuai',
#   'sekian',
#   'pesan',
#   'baju',
#   'krna',
#   'tahu',
#   'trnyta',
#   'lagi',
#   'yak',
#   'kakak',
#   'waktu',
#   'lagi',
#   'demo',
#   'pesan',
#   'datang',
#   'pas',
#   'datang',
#   'kancing',
#   'kakak',
#   'lagi',
#   'koe',
#   'cash',
#   'back',
#   'kakak'],
#  ['murah', 'discondt'],
#  ['beli', 'barang', 'dizini', 'benar', 'asli', 'diskon'],
#  ['aplikasi', 'uang'],
#  ['barang', 'jamin', 'asli', 'mall'],
#  ['puass'],
#  ['belanja', 'proses', 'retur', 'refund', 'kendala'],
#  ['belanja'],
#  ['barang'],
#  ['bantu', 'dlm', 'belanja'],
#  ['awesome'],
#  ['aplikasi',
#   'utama',
#   'belanja',
#   'online',
#   'pandemi',
#   'recommend',
#   'kasih',
#   'bintang',
#   'belanja',
#   'tingkat',
#   'teus',
#   'layan',
#   'sukses',
#   'tuk',
#   'belanja',
#   'aman',
#   'amanah'],
#  ['asli'],
#  ['kirim',
#   'barang',
#   'cepat',
#   'harga',
#   'produk',
#   'sesuai',
#   'brand',
#   'kualitas'],
#  ['my', 'number', 'one', 'online', 'belanja'],
#  ['online',
#   'shop',
#   'terpecaya',
#   'langgan',
#   'sekarang',
#   'brand',
#   'zara',
#   'tunggu'],
#  ['promo', 'fast', 'shipment', 'process', 'keep', 'aplikasi', 'updated'],
#  ['barang'],
#  ['bantu'],
#  ['kelas'],
#  ['mantaap'],
#  ['hadir',
#   'lengkap',
#   'gowes',
#   'sepatu',
#   'kacamata',
#   'sarung',
#   'tangan',
#   'helm',
#   'baju',
#   'gowes',
#   'mtb',
#   'ribu'],
#  ['belanja'],
#  ['mantaap'],
#  ['promo'],
#  ['barang', 'asli'],
#  ['produk', 'belanja'],
#  ['produk',
#   'asli',
#   'tapi',
#   'setelah',
#   'belanja',
#   'pruduk',
#   'klu',
#   'egk',
#   'salah',
#   'sampek',
#   'uda',
#   'percaya',
#   'reward',
#   'benefit',
#   'langgan',
#   'setia',
#   'maaf',
#   'kasih',
#   'rating',
#   'bintang',
#   'order',
#   'sulit',
#   'mecari',
#   'harga',
#   'diskon',
#   'sesuai',
#   'budget',
#   'terima',
#   'kasih'],
#  ['belanja', 'tukar', 'size', 'mudah', 'barang', 'asli', 'poko'],
#  ['belanja', 'barang', 'asli', 'perna'],
#  ['barang', 'asli', 'sesuai', 'skripsi'],
#  ['belanja',
#   'sabar',
#   'ken',
#   'barang',
#   'branded',
#   'harga',
#   'diskon',
#   'gede',
#   'buru',
#   'checkout',
#   'tunggu',
#   'momen',
#   'pas',
#   'barang',
#   'diskon',
#   'gede'],
#  ['belamja', 'asli', 'reafy', 'stok', 'zise', 'habis', 'tunggu', 'trsedia'],
#  ['beli', 'baju'],
#  ['mantappp'],
#  ['belanja', 'diskon', 'double', 'produk', 'asli'],
#  ['langgan',
#   'alhamdulilah',
#   'barang',
#   'terima',
#   'sesuai',
#   'ekspektasi',
#   'bayar',
#   'via',
#   'transfer',
#   'bank',
#   'cod'],
#  ['order'],
#  ['kualitas', 'produk'],
#  ['sayang', 'untuk', 'tulis', 'note'],
#  ['no',
#   'comen',
#   'poko',
#   'langgan',
#   'saran',
#   'cashback',
#   'coha',
#   'lanjut',
#   'bayar',
#   'latter',
#   'biar',
#   'seru'],
#  ['kualitas',
#   'barang',
#   'sesuai',
#   'deskripsi',
#   'iklan',
#   'kirim',
#   'cepat',
#   'barang',
#   'rusak'],
#  ['belanja', 'nyaman'],
#  ['belanja'],
#  ['penuh', 'harap', 'langgan'],
#  ['recomendation', 'your', 'shoping', 'if', 'need', 'quality'],
#  ['kas',
#   'bintang',
#   'refund',
#   'customer service',
#   'layan',
#   'uang',
#   'refund',
#   'juga',
#   'cepat',
#   'rekening'],
#  ['mua', 'brand', 'favorit'],
#  ['bagusss', 'recomended', 'harga', 'kualitas'],
#  ['leb', 'praktis'],
#  ['siip'],
#  ['barang', 'asli'],
#  ['aplikasi'],
#  ['seru', 'bangett', 'belanja', 'disc'],
#  ['pokok', 'kemarin', 'beli', 'barang', 'retur', 'uang'],
#  ['produk', 'layan'],
#  ['barang', 'asli'],
#  ['pokok'],
#  ['barang', 'barang', 'tawar', 'sesuai', 'kirim', 'cepat'],
#  ['yeaaa',
#   'yyy',
#   'bareng',
#   'cod',
#   'lagiiii',
#   'barang',
#   'negeri',
#   'sekarang',
#   'cod',
#   'lagi',
#   'dl',
#   'free',
#   'ongkir',
#   'jugaa',
#   'neng',
#   'bgtz',
#   'belanja',
#   'lbh',
#   'pilih',
#   'makas'],
#  ['produk', 'asli'],
#  ['promonya'],
#  ['pokok'],
#  ['aplikasi', 'taaapppiiii', 'nabung', 'beli', 'asli', 'beli'],
#  ['mantulllll'],
#  ['amtap'],
#  ['mantappp'],
#  ['respon', 'kualitas', 'jamin'],
#  ['bantu'],
#  ['product', 'asli', 'jamin', 'belanja'],
#  ['barang', 'murah', 'murah', 'asli'],
#  ['kaleeeeeee'],
#  ['buka', 'kah', 'aplikasi'],
#  ['belanja',
#   'aplikasi',
#   'kejam',
#   'saking',
#   'kejam',
#   'gaji',
#   'dompet',
#   'lansung',
#   'bolong',
#   'bikin',
#   'tagih',
#   'branded',
#   'asli',
#   'murah',
#   'lapak',
#   'belah',
#   'toko',
#   'offline',
#   'cod',
#   'diskon',
#   'cashbacknya',
#   'duuuuhh',
#   'kejam',
#   'pokok',
#   'rumah',
#   'tunggu',
#   'istri',
#   'tidur',
#   'buka',
#   'aplikasi',
#   'hapus',
#   'hitoris',
#   'beli',
#   'biar',
#   'lacak',
#   'istri'],
#  ['belanja',
#   'produk',
#   'brgnya',
#   'branded',
#   'nguras',
#   'isi',
#   'kantong',
#   'pokokx',
#   'puassss',
#   'buaaangeett'],
#  ['beri',
#   'voucher',
#   'diskon',
#   'giur',
#   'mantapppppp',
#   'kasih',
#   'voucher',
#   'belanja',
#   'biar',
#   'rajin',
#   'belanja'],
#  ['joss'],
#  ['cashbacknya'],
#  ['aplikasi', 'belanja', 'kren'],
#  ['langgan', 'kuuu'],
#  ['belanja'],
#  ['one', 'ecommerce', 'asli', 'product', 'by', 'seller'],
#  ['diskon', 'mntap'],
#  ['know', 'aplikasi', 'sistem', 'cod', 'like', 'this'],
#  ['belanja', 'produk', 'asli'],
#  ['belanja',
#   'barang',
#   'asli',
#   'kirim',
#   'cepat',
#   'tuker',
#   'size',
#   'proses',
#   'mudah',
#   'pokok',
#   'recommended'],
#  ['belanja', 'barang', 'retur', 'metode', 'uang', 'khawatir', 'benja'],
#  ['barang', 'asli'],
#  ...]

# %%
pd.DataFrame(texts).to_csv("output.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1d9f4ac4d886> in <module>()
# ----> 1 pd.DataFrame(texts).to_csv("output.csv",index=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     706                         columns,
#     707                         dtype=dtype,
# --> 708                         typ=manager,
#     709                     )
#     710                 else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     134     if typ == "block":
#     135         return create_block_manager_from_arrays(
# --> 136             arrays, arr_names, axes, consolidate=consolidate
#     137         )
#     138     elif typ == "array":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1771
#    1772     try:
# -> 1773         blocks = _form_blocks(arrays, names, axes, consolidate)
#    1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _form_blocks(arrays, names, axes, consolidate)
#    1861     if len(items_dict["ObjectBlock"]) > 0:
#    1862         object_blocks = _simple_blockify(
# -> 1863             items_dict["ObjectBlock"], np.object_, consolidate=consolidate
#    1864         )
#    1865         blocks.extend(object_blocks)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _simple_blockify(tuples, dtype, consolidate)
#    1901         return _tuples_to_blocks_no_consolidate(tuples, dtype=dtype)
#    1902
# -> 1903     values, placement = _stack_arrays(tuples, dtype)
#    1904
#    1905     # TODO: CHECK DTYPE?
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _stack_arrays(tuples, dtype)
#    1957     stacked = np.empty(shape, dtype=dtype)
#    1958     for i, arr in enumerate(arrays):
# -> 1959         stacked[i] = arr
#    1960
#    1961     return stacked, placement
#
# KeyboardInterrupt:

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (5, 6):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha=[0.01]*k, eta=[0.01]*len(dictionary.keys()))
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  # print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.37793306), (2, 0.29665834), (3, 0.21033053), (4, 0.1140831)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(2, 0.20708513), (3, 0.78697425)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3082952), (3, 0.42695034), (4, 0.26191756)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(3, 0.98688525)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.98688525)]
# [(0, 0.9920792)]
# [(0, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.790572), (3, 0.20348746)]
# [(1, 0.5474111), (4, 0.44275284)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(1, 0.16694215), (2, 0.6628099), (3, 0.16694215)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.3980198), (4, 0.5960396)]
# [(1, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.5845402), (1, 0.40082568)]
# [(3, 0.9619048)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(1, 0.54759055), (2, 0.4377753)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.4004769), (2, 0.5921157)]
# [(4, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(0, 0.72949475), (3, 0.2655466)]
# [(0, 0.19896767), (2, 0.3909412), (3, 0.4067854)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(1, 0.9804878)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.3322314), (3, 0.6628099)]
# [(0, 0.19025119), (3, 0.80479014)]
# [(2, 0.9804878)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.7940594), (4, 0.19999999)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.45578858), (3, 0.28989047), (4, 0.24938273)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.16694213), (2, 0.49752066), (3, 0.3322314)]
# [(3, 0.9920792)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(1, 0.2493827), (3, 0.49629626), (4, 0.2493827)]
# [(0, 0.49268287), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.74320984), (4, 0.2493827)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(3, 0.9804878)]
# [(0, 0.20429231), (1, 0.24532881), (3, 0.5485689)]
# [(3, 0.99012345)]
# [(0, 0.9619048)]
# [(0, 0.64138275), (1, 0.3439831)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(0, 0.4934284), (3, 0.1710344), (4, 0.3322314)]
# [(3, 0.9619048)]
# [(0, 0.1154753), (1, 0.08847917), (2, 0.5380548), (4, 0.25699574)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(2, 0.8285577), (3, 0.16771558)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.12546584), (1, 0.24968943), (2, 0.49311867), (4, 0.1304838)]
# [(1, 0.28850758), (3, 0.70408505)]
# [(4, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.4859706), (2, 0.2493827), (3, 0.25970837)]
# [(0, 0.9619048)]
# [(1, 0.9619048)]
# [(3, 0.9920792)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.18617266), (1, 0.16903427), (2, 0.3925346), (4, 0.25060555)]
# [(1, 0.3980198), (3, 0.5960396)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.4692738), (3, 0.5233188)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.3245861), (1, 0.17417932), (2, 0.24938273), (3, 0.2493827)]
# [(1, 0.9619048)]
# [(2, 0.7940594), (3, 0.19999999)]
# [(1, 0.15402299), (2, 0.76643), (4, 0.078014396)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2613289), (1, 0.19919033), (2, 0.38175657), (3, 0.15727067)]
# [(3, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(3, 0.98688525)]
# [(0, 0.27257422), (2, 0.4718518), (3, 0.25273708)]
# [(0, 0.73709476), (3, 0.25549784)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.37152496), (1, 0.29949144), (2, 0.21625674), (3, 0.111821875)]
# [(2, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(3, 0.3544498), (4, 0.6357141)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.49268287), (2, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.7940594), (3, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2746988), (1, 0.36202803), (3, 0.22998796), (4, 0.13257344)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.7370874), (3, 0.25550514)]
# [(4, 0.9804878)]
# [(0, 0.20682265), (2, 0.588271), (3, 0.20357738)]
# [(0, 0.42080736), (3, 0.56455845)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(2, 0.9619048)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(0, 0.9619048)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(2, 0.9619048)]
# [(3, 0.98688525)]
# [(2, 0.5830069), (4, 0.41203433)]
# [(2, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.76203376), (3, 0.23202565)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.4210991), (3, 0.56426674)]
# [(2, 0.12546584), (3, 0.87080747)]
# [(2, 0.9619048)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.7055128), (3, 0.29023185)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(1, 0.9804878)]
# [(4, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(1, 0.9619048)]
# [(1, 0.24938273), (4, 0.7432099)]
# [(0, 0.24726637), (1, 0.74289757)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.21711169), (1, 0.19999999), (3, 0.57892793)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.3091073), (3, 0.684952)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.96190476)]
# [(3, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.9619048)]
# [(1, 0.49629626), (3, 0.2493827), (4, 0.2493827)]
# [(3, 0.9619048)]
# [(1, 0.14428025), (2, 0.691072), (3, 0.16322431)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.12913953), (1, 0.31724232), (3, 0.5511337)]
# [(0, 0.9619048)]
# [(1, 0.2493827), (3, 0.49629626), (4, 0.2493827)]
# [(3, 0.96190476)]
# [(0, 0.3095242), (3, 0.6871609)]
# [(3, 0.99012345)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.38039094), (3, 0.61220163)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.3908971), (2, 0.19999999), (3, 0.20712271), (4, 0.19999999)]
# [(0, 0.84724194), (3, 0.14850271)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.25829837), (1, 0.73429424)]
# [(1, 0.9619048)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(3, 0.7432099), (4, 0.2493827)]
# [(0, 0.22209944), (2, 0.3004606), (4, 0.47523)]
# [(4, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.392638), (1, 0.26965708), (2, 0.33114755)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.49737135), (1, 0.1269277), (2, 0.37445483)]
# [(3, 0.9619048)]
# [(0, 0.99012345)]
# [(0, 0.37653607), (1, 0.6175234)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.4604286), (2, 0.41535425), (3, 0.12222707)]
# [(0, 0.99012345)]
# [(1, 0.98688525)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.27282032), (1, 0.5960396), (4, 0.12717968)]
# [(1, 0.42695034), (2, 0.28510636), (3, 0.1432624), (4, 0.14326242)]
# [(0, 0.3322314), (1, 0.3322314), (3, 0.33223143)]
# [(4, 0.9804878)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.73709637), (3, 0.2554963)]
# [(0, 0.99012345)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(0, 0.36350152), (3, 0.6305579)]
# [(0, 0.27730387), (3, 0.7203973)]
# [(3, 0.99012345)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.98688525)]
# [(0, 0.4658942), (3, 0.52426976)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(2, 0.9804878)]
# [(2, 0.59603965), (4, 0.3980198)]
# [(0, 0.48425457), (2, 0.28278276), (3, 0.23130296)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.6660487), (3, 0.32654384)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.44309393), (2, 0.2644939), (3, 0.11160221), (4, 0.17970498)]
# [(1, 0.23540114), (3, 0.6507867), (4, 0.11160221)]
# [(0, 0.9804878)]
# [(0, 0.65901643), (1, 0.33114755)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.11160221), (1, 0.11160221), (2, 0.65527767), (4, 0.12041293)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.6654803), (4, 0.33026436)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.3322314), (2, 0.6628099)]
# [(1, 0.98688525)]
# [(0, 0.2493827), (1, 0.2493827), (2, 0.49629626)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(2, 0.521792), (3, 0.46837193)]
# [(0, 0.27255598), (1, 0.39801982), (3, 0.2), (4, 0.12744401)]
# [(4, 0.9619048)]
# [(1, 0.99012345)]
# [(3, 0.9619048)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(3, 0.9619048)]
# [(3, 0.9804878)]
# [(3, 0.96190476)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(3, 0.9619048)]
# [(1, 0.98688525)]
# [(3, 0.99012345)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.98688525)]
# [(4, 0.9619048)]
# [(1, 0.5471931), (4, 0.44297087)]
# [(0, 0.65901643), (1, 0.33114755)]
# [(3, 0.9619048)]
# [(4, 0.98688525)]
# [(2, 0.49629626), (3, 0.49629626)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.5960396), (2, 0.3980198)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.3322314), (2, 0.16694213), (3, 0.16694213), (4, 0.3322314)]
# [(0, 0.99012345)]
# [(0, 0.10049751), (2, 0.58758515), (4, 0.30992728)]
# [(3, 0.9619048)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(4, 0.9619048)]
# [(0, 0.46926373), (3, 0.5233289)]
# [(4, 0.9619048)]
# [(0, 0.99012345)]
# [(3, 0.9804878)]
# [(3, 0.9920792)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(3, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.32557824), (1, 0.6694631)]
# [(1, 0.74320984), (2, 0.2493827)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.98688525)]
# [(0, 0.98688525)]
# [(1, 0.33117512), (2, 0.07727633), (3, 0.24169563), (4, 0.34926647)]
# [(0, 0.5687943), (4, 0.42695034)]
# [(4, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.42120162), (3, 0.56416416)]
# [(2, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.16694213), (3, 0.8280992)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.6507199), (1, 0.33944407)]
# [(3, 0.99012345)]
# [(2, 0.99012345)]
# [(4, 0.98688525)]
# [(3, 0.9804878)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.4658508), (3, 0.5243131)]
# [(1, 0.49268287), (4, 0.49268293)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.9619048)]
# [(2, 0.09496458), (3, 0.90232044)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.42066738), (3, 0.5646985)]
# [(0, 0.19999999), (3, 0.5960396), (4, 0.19999999)]
# [(0, 0.9804878)]
# [(0, 0.46920997), (3, 0.52338254)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(2, 0.9619048)]
# [(0, 0.18424365), (3, 0.70194423), (4, 0.11160221)]
# [(2, 0.9619048)]
# [(1, 0.21682966), (3, 0.61292243), (4, 0.16694213)]
# [(0, 0.23403822), (2, 0.5848259), (3, 0.17783009)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.6507112), (1, 0.33945277)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.3509127), (1, 0.24453677), (2, 0.31631914), (3, 0.08740156)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.387117), (1, 0.6030469)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(1, 0.98688525)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(1, 0.16694215), (2, 0.20592897), (3, 0.6238231)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(1, 0.1656664), (3, 0.40454635), (4, 0.42695037)]
# [(4, 0.9804878)]
# [(0, 0.9619048)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.2875579), (2, 0.2948498), (3, 0.41578236)]
# [(1, 0.9619048)]
# [(0, 0.30521607), (1, 0.357079), (4, 0.33114755)]
# [(0, 0.49629626), (1, 0.2493827), (2, 0.2493827)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.45175412), (2, 0.33114755), (4, 0.21054098)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.73948264), (1, 0.25311)]
# [(4, 0.9619048)]
# [(0, 0.37285286), (1, 0.24525249), (3, 0.37793428)]
# [(2, 0.22227934), (4, 0.77346534)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(0, 0.28554094), (2, 0.7095004)]
# [(0, 0.44084635), (1, 0.110457934), (2, 0.09327874), (3, 0.35451198)]
# [(3, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(2, 0.9619048)]
# [(3, 0.98688525)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.99012345)]
# [(0, 0.083817415), (2, 0.58174276), (4, 0.33278006)]
# [(0, 0.98688525)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.06317138), (3, 0.49057788), (4, 0.4450777)]
# [(0, 0.41625258), (3, 0.5778068)]
# [(0, 0.38488093), (1, 0.20493653), (3, 0.20820232), (4, 0.19999999)]
# [(0, 0.09395474), (2, 0.18123335), (3, 0.72338843)]
# [(3, 0.99503106)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.9804878)]
# [(0, 0.6574623), (1, 0.3365971)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.98688525)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(1, 0.7940594), (4, 0.19999999)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.6453278), (3, 0.34483615)]
# [(0, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.25182188), (1, 0.26671186), (3, 0.47965628)]
# [(0, 0.1685611), (1, 0.15351155), (2, 0.4976143), (3, 0.17889464)]
# [(2, 0.6244059), (3, 0.36818665)]
# [(1, 0.4267587), (2, 0.5673007)]
# [(1, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.5355371), (1, 0.45705548)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(0, 0.2096388), (1, 0.4282878), (2, 0.2), (4, 0.16009323)]
# [(1, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.6453683), (3, 0.3447956)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(1, 0.28703836), (3, 0.4586406), (4, 0.2493827)]
# [(1, 0.9619048)]
# [(0, 0.7217677), (3, 0.27082488)]
# [(0, 0.42103583), (3, 0.56433004)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.19999999), (4, 0.3980198)]
# [(1, 0.37391302), (2, 0.13656911), (3, 0.48703337)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.40494987), (1, 0.347421), (4, 0.24107179)]
# [(2, 0.9619048)]
# [(1, 0.42695037), (3, 0.5687943)]
# [(0, 0.98688525)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.44960448), (1, 0.3464351), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.99012345)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9804878)]
# [(1, 0.27725205), (2, 0.22151338), (3, 0.49629626)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.44810995), (2, 0.54594946)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.11160221), (3, 0.69596285), (4, 0.19022496)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.15055865), (1, 0.37022293), (3, 0.4763815)]
# [(1, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.16694215), (1, 0.5952407), (3, 0.23451135)]
# [(2, 0.4380521), (3, 0.5473138)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(1, 0.3980198), (3, 0.5960396)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.6413019), (1, 0.3440639)]
# [(1, 0.15055633), (2, 0.56150043), (3, 0.28510636)]
# [(1, 0.14424422), (2, 0.5209492), (3, 0.3325967)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(3, 0.9933884)]
# [(0, 0.45447806), (1, 0.5308878)]
# [(0, 0.73945266), (1, 0.25313988)]
# [(0, 0.9920792)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.9619048)]
# [(1, 0.32694328), (2, 0.27970633), (3, 0.39136034)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.1432624), (1, 0.15164001), (3, 0.70226073)]
# [(1, 0.27856994), (3, 0.71770334)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.31642073), (4, 0.67763865)]
# [(1, 0.16967806), (3, 0.8260666)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(1, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.098515235), (1, 0.18972999), (3, 0.65300435), (4, 0.057984196)]
# [(0, 0.3405726), (1, 0.20307358), (2, 0.11867492), (3, 0.33668387)]
# [(3, 0.99012345)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(1, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.99012345)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.39122823), (3, 0.6028312)]
# [(0, 0.9804878)]
# [(0, 0.18746589), (1, 0.11705792), (3, 0.48564383), (4, 0.20872736)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(2, 0.9619048)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.43897083), (3, 0.5560705)]
# [(1, 0.34047055), (3, 0.6521221)]
# [(0, 0.96190476)]
# [(2, 0.20507918), (3, 0.30906814), (4, 0.4841929)]
# [(0, 0.9619048)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(3, 0.9619048)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.29334328), (3, 0.701698)]
# [(0, 0.0848198), (1, 0.48486435), (2, 0.19013609), (3, 0.1951066), (4, 0.04507319)]
# [(1, 0.2493827), (2, 0.2493827), (4, 0.49629626)]
# [(0, 0.99012345)]
# [(0, 0.06689379), (1, 0.13279606), (2, 0.37457284), (3, 0.36978164), (4, 0.055955682)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.69844913), (3, 0.29414347)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.60498136), (4, 0.3876112)]
# [(0, 0.4377353), (1, 0.557306)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.43264922), (1, 0.22857073), (2, 0.22209947), (3, 0.11557566)]
# [(3, 0.9619048)]
# [(0, 0.3216999), (4, 0.6708927)]
# [(0, 0.67123723), (4, 0.31412864)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.74695563), (2, 0.09475481), (3, 0.15675697)]
# [(0, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.25951272), (2, 0.21737157), (3, 0.37654382), (4, 0.14459163)]
# [(1, 0.5960396), (3, 0.3980198)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.24956618), (3, 0.7461785)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.23237184), (2, 0.12546584), (3, 0.6396779)]
# [(1, 0.33289033), (2, 0.09731601), (3, 0.30268398), (4, 0.26644522)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.07964105), (1, 0.07188612), (2, 0.2563194), (3, 0.27955008), (4, 0.31260332)]
# [(0, 0.42090043), (3, 0.5644654)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.33114755), (1, 0.33114755), (2, 0.33114755)]
# [(3, 0.98688525)]
# [(0, 0.14584869), (2, 0.407447), (3, 0.13766746), (4, 0.30845028)]
# [(1, 0.9619048)]
# [(0, 0.21252257), (2, 0.3980198), (4, 0.38549724)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.98688525)]
# [(3, 0.99012345)]
# [(2, 0.9619048)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.19999999), (4, 0.3980198)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.52529126), (1, 0.46975008)]
# [(1, 0.9619048)]
# [(1, 0.1432624), (2, 0.1432624), (3, 0.56879437), (4, 0.1432624)]
# [(0, 0.27251637), (2, 0.7200762)]
# [(0, 0.9619048)]
# [(3, 0.5471651), (4, 0.4382008)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9920792)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33223143), (2, 0.16694215), (3, 0.49752066)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.9804878)]
# [(0, 0.32488018), (3, 0.67139304)]
# [(0, 0.6449445), (3, 0.3476481)]
# [(4, 0.9619048)]
# [(0, 0.19999999), (1, 0.19999999), (2, 0.37819067), (4, 0.2198291)]
# [(1, 0.96190476)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(3, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.9804878)]
# [(0, 0.98688525)]
# [(0, 0.2707199), (3, 0.7218727)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.15402912), (1, 0.35103524), (3, 0.49209875)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.9933884)]
# [(0, 0.096341245), (3, 0.8104461), (4, 0.09140271)]
# [(2, 0.9619048)]
# [(1, 0.17869963), (2, 0.63363355), (3, 0.18482994)]
# [(2, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.5444044), (3, 0.23972222), (4, 0.21256755)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.22920235), (3, 0.76485705)]
# [(0, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.96190476)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.98688525)]
# [(4, 0.9619048)]
# [(0, 0.250181), (1, 0.31764725), (3, 0.4306392)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.27418885), (3, 0.7159751)]
# [(2, 0.9619048)]
# [(3, 0.9933884)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(0, 0.6407935), (1, 0.34457234)]
# [(3, 0.9619048)]
# [(0, 0.4210564), (3, 0.5643095)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.35200885), (4, 0.63815504)]
# [(1, 0.9804878)]
# [(0, 0.35984534), (1, 0.635196)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.74320984), (4, 0.2493827)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3980198), (2, 0.19999999), (3, 0.3980198)]
# [(0, 0.28294486), (3, 0.37935024), (4, 0.33114755)]
# [(1, 0.24172413), (2, 0.16709884), (3, 0.53675324), (4, 0.05389892)]
# [(0, 0.13746345), (2, 0.50025195), (3, 0.26924962), (4, 0.09179277)]
# [(2, 0.9619048)]
# [(4, 0.96190476)]
# [(3, 0.98688525)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(1, 0.67029834), (3, 0.20175137), (4, 0.12546584)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.4878325), (1, 0.25784644), (2, 0.24938273)]
# [(0, 0.3634943), (3, 0.63056517)]
# [(0, 0.22894712), (3, 0.7685633)]
# [(0, 0.9619048)]
# [(1, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.15272793), (1, 0.6645778), (4, 0.17873392)]
# [(0, 0.6717559), (4, 0.3136099)]
# [(1, 0.9619048)]
# [(1, 0.51523274), (3, 0.3145193), (4, 0.16694213)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(3, 0.98688525)]
# [(4, 0.9619048)]
# [(1, 0.16694213), (3, 0.5212605), (4, 0.3084916)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9920792)]
# [(0, 0.60613513), (4, 0.38402873)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.42090714), (3, 0.5644587)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.12546584), (1, 0.12842786), (2, 0.447616), (3, 0.16861291), (4, 0.12987737)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(0, 0.7905721), (3, 0.20348723)]
# [(1, 0.9804878)]
# [(2, 0.9619048)]
# [(4, 0.96190476)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.76520586), (2, 0.2305388)]
# [(1, 0.9804878)]
# [(2, 0.96190476)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.22332907), (1, 0.12518702), (3, 0.6481781)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.99012345)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(4, 0.9619048)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.9619048)]
# [(0, 0.32464755), (1, 0.17411785), (3, 0.49629626)]
# [(0, 0.67170495), (4, 0.31366092)]
# [(0, 0.3203805), (2, 0.20456144), (3, 0.47222117)]
# [(3, 0.8965174), (4, 0.10049751)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.42980456), (3, 0.5659401)]
# [(0, 0.36892384), (1, 0.23134544), (4, 0.39752075)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9804878)]
# [(1, 0.57784), (4, 0.41232395)]
# [(4, 0.9804878)]
# [(0, 0.37251016), (1, 0.41127717), (3, 0.2122522)]
# [(0, 0.6411609), (1, 0.34420493)]
# [(0, 0.6327411), (3, 0.35262474)]
# [(0, 0.3235005), (1, 0.50001353), (3, 0.17318018)]
# [(0, 0.4289949), (3, 0.5676902)]
# [(1, 0.9619048)]
# [(1, 0.99012345)]
# [(0, 0.33114758), (2, 0.36458358), (3, 0.2977115)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.15974565), (2, 0.066692024), (3, 0.71001095), (4, 0.06292835)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.3499814), (1, 0.37064138), (3, 0.18839426), (4, 0.09015306)]
# [(0, 0.9619048)]
# [(0, 0.99012345)]
# [(3, 0.9804878)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.090912946), (1, 0.16131264), (2, 0.43179768), (3, 0.1479046), (4, 0.16807216)]
# [(1, 0.24432422), (3, 0.7497352)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.2851064), (2, 0.1432624), (3, 0.5687943)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.271075), (3, 0.47460395), (4, 0.2493827)]
# [(1, 0.1500536), (3, 0.845691)]
# [(3, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(1, 0.49752066), (2, 0.16694213), (3, 0.3322314)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.5960396)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.42084807), (3, 0.5645178)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.9804878)]
# [(0, 0.43502238), (2, 0.5575702)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.9619048)]
# [(1, 0.17715482), (3, 0.6767459), (4, 0.1432624)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.08381744), (1, 0.7357807), (2, 0.1787421)]
# [(4, 0.9619048)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(3, 0.9804878)]
# [(0, 0.32469302), (2, 0.66789955)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114752), (2, 0.33114752), (4, 0.33114755)]
# [(0, 0.46601668), (3, 0.5241472)]
# [(1, 0.24968943), (2, 0.13445233), (3, 0.61337376)]
# [(0, 0.30513975), (1, 0.3571553), (2, 0.33114755)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(0, 0.7636504), (2, 0.23040898)]
# [(2, 0.9804878)]
# [(0, 0.49268293), (4, 0.49268287)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(3, 0.99012345)]
# [(4, 0.9804878)]
# [(0, 0.2469967), (1, 0.7431672)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.54745), (4, 0.4427139)]
# [(0, 0.98688525)]
# [(0, 0.2493827), (1, 0.49629626), (3, 0.2493827)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.22175851), (1, 0.77328277)]
# [(0, 0.49850747), (2, 0.49850747)]
# [(1, 0.104094334), (2, 0.08381742), (3, 0.64445335), (4, 0.16680497)]
# [(0, 0.7361326), (1, 0.26014063)]
# [(0, 0.9619048)]
# [(0, 0.28594163), (2, 0.6661178), (3, 0.047172803)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3079993), (1, 0.39446038), (3, 0.2950558)]
# [(3, 0.99012345)]
# [(3, 0.9619048)]
# [(0, 0.1268565), (2, 0.7074675), (3, 0.16283911)]
# [(0, 0.7370967), (3, 0.25549585)]
# [(1, 0.15005101), (3, 0.84569365)]
# [(1, 0.5751676), (3, 0.4198737)]
# [(0, 0.18593478), (1, 0.55974424), (4, 0.2493827)]
# [(3, 0.98688525)]
# [(0, 0.9804878)]
# [(0, 0.33114755), (1, 0.33114755), (4, 0.33114755)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.1521161), (1, 0.1451726), (2, 0.34168246), (3, 0.2368226), (4, 0.124206215)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(0, 0.9804878)]
# [(0, 0.20948558), (2, 0.2599816), (3, 0.52948296)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.57426643), (3, 0.41979295)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(1, 0.98688525)]
# [(3, 0.9920792)]
# [(0, 0.404454), (1, 0.34746128), (4, 0.24152736)]
# [(3, 0.99012345)]
# [(0, 0.96190476)]
# [(1, 0.6590164), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9804878)]
# [(0, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.58445257), (1, 0.40091327)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.26546636), (3, 0.25814703), (4, 0.4714483)]
# [(0, 0.16599548), (2, 0.83170563)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.48124674), (2, 0.5128127)]
# [(0, 0.10594859), (2, 0.5579883), (4, 0.33407304)]
# [(1, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.26441225), (1, 0.24968943), (2, 0.14341655), (3, 0.34123954)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(4, 0.9619048)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.21511894), (1, 0.38284856), (2, 0.39709428)]
# [(1, 0.98688525)]
# [(0, 0.4430939), (1, 0.11160221), (2, 0.31306174), (4, 0.13113716)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(4, 0.96190476)]
# [(3, 0.9804878)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.32325166), (1, 0.6669123)]
# [(0, 0.42074433), (3, 0.5646215)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.5545474), (2, 0.14567861), (3, 0.29693714)]
# [(1, 0.2493827), (2, 0.35817823), (3, 0.38750076)]
# [(3, 0.98688525)]
# [(0, 0.49752066), (1, 0.3322314), (3, 0.16694213)]
# [(2, 0.5687943), (4, 0.42695037)]
# [(0, 0.623795), (3, 0.18908587), (4, 0.18545938)]
# [(2, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.7940594), (4, 0.19999999)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.44684672), (1, 0.5481946)]
# [(0, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.18166997), (2, 0.29950246), (3, 0.33306307), (4, 0.18476948)]
# [(0, 0.13220803), (1, 0.37087214), (4, 0.49361402)]
# [(0, 0.5845461), (1, 0.4008198)]
# [(3, 0.99012345)]
# [(0, 0.359981), (1, 0.23803878), (4, 0.3980198)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.2589059), (1, 0.35446098), (2, 0.2808944), (4, 0.10530484)]
# [(1, 0.9619048)]
# [(0, 0.7370963), (3, 0.25549635)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.6384959), (2, 0.15313397), (3, 0.20637998)]
# [(2, 0.9619048)]
# [(2, 0.7212521), (4, 0.27134046)]
# [(1, 0.9619048)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.3980198), (2, 0.3980198), (4, 0.19999999)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49629626), (4, 0.49629626)]
# [(1, 0.3980198), (2, 0.19999999), (4, 0.3980198)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.98688525)]
# [(1, 0.25670457), (2, 0.35142806), (3, 0.38938284)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9920792)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.45130953), (3, 0.33114755), (4, 0.21098551)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.3735418), (1, 0.10912943), (2, 0.11144364), (3, 0.40489006)]
# [(3, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.09039144), (1, 0.5338493), (2, 0.37476176)]
# [(1, 0.9619048)]
# [(2, 0.22674452), (3, 0.7673149)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.33114758), (3, 0.6590164)]
# [(0, 0.20691822), (2, 0.2650646), (3, 0.35942212), (4, 0.16694213)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.31687915), (3, 0.6757134)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.6201735), (3, 0.36999044)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.9619048)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.37757504), (1, 0.034324147), (2, 0.26957455), (4, 0.31820416)]
# [(1, 0.47289565), (3, 0.5196969)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.6720353), (4, 0.31333056)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.6452437), (3, 0.34492025)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.52521646), (1, 0.27115723), (3, 0.20229737)]
# [(2, 0.9619048)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(3, 0.9619048)]
# [(3, 0.8280992), (4, 0.16694213)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(2, 0.24804085), (3, 0.7460186)]
# [(1, 0.073674686), (2, 0.7187909), (3, 0.20620553)]
# [(0, 0.24328683), (1, 0.5148055), (2, 0.24057873)]
# [(1, 0.9619048)]
# [(0, 0.27283937), (1, 0.3980198), (3, 0.19999999), (4, 0.12716062)]
# [(1, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.2493827), (1, 0.2493827), (2, 0.2493827), (3, 0.2493827)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.9804878)]
# [(1, 0.6371341), (3, 0.3554585)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(1, 0.98688525)]
# [(2, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.26101977), (4, 0.7330396)]
# [(0, 0.74320984), (4, 0.24938273)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(1, 0.33114755), (2, 0.6590164)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(3, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.99012345)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.37401453), (3, 0.6161494)]
# [(0, 0.36757782), (2, 0.1336122), (3, 0.4963255)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.23953046), (1, 0.5082956), (2, 0.24968943)]
# [(3, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.35933715), (3, 0.43670243), (4, 0.19999999)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.47970495), (1, 0.5128876)]
# [(4, 0.96190476)]
# [(1, 0.16694213), (2, 0.16694213), (3, 0.6628099)]
# [(1, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.7940594), (4, 0.19999999)]
# [(3, 0.65901643), (4, 0.33114752)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.9619048)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.9619048)]
# [(1, 0.7940594), (4, 0.19999999)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.45871627), (3, 0.5338763)]
# [(1, 0.7940594), (4, 0.19999999)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(4, 0.9619048)]
# [(1, 0.40524614), (2, 0.31385654), (3, 0.27806047)]
# [(3, 0.99012345)]
# [(4, 0.9619048)]
# [(0, 0.6722145), (4, 0.31315133)]
# [(1, 0.9619048)]
# [(0, 0.98688525)]
# [(2, 0.26809332), (3, 0.7244993)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.33016038), (1, 0.45992568), (2, 0.20707703)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.28370857), (1, 0.42650405), (3, 0.28825477)]
# [(0, 0.6034553), (2, 0.38670862)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(3, 0.9619048)]
# [(2, 0.17284358), (3, 0.82342976)]
# [(0, 0.73031664), (3, 0.2622759)]
# [(0, 0.11864653), (1, 0.19636361), (2, 0.4231149), (3, 0.19665097), (4, 0.06522402)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.3765512), (1, 0.61750823)]
# [(3, 0.9619048)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(3, 0.9804878)]
# [(3, 0.99012345)]
# [(1, 0.99012345)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(0, 0.15847069), (1, 0.46513176), (4, 0.37391302)]
# [(0, 0.29776582), (1, 0.24938273), (2, 0.44791323)]
# [(0, 0.084997565), (1, 0.19468348), (2, 0.57757336), (4, 0.14175057)]
# [(1, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(0, 0.18541892), (3, 0.8096224)]
# [(0, 0.35816857), (3, 0.6319954)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9804878)]
# [(2, 0.45404968), (3, 0.26788053), (4, 0.27313155)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.4203951), (3, 0.56497073)]
# [(0, 0.30245146), (1, 0.16692883), (2, 0.5290871)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.48397824), (3, 0.29178318), (4, 0.21930034)]
# [(1, 0.6344495), (3, 0.25173834), (4, 0.11160221)]
# [(1, 0.2615813), (2, 0.7310112)]
# [(0, 0.99012345)]
# [(2, 0.5710891), (3, 0.258663), (4, 0.16694215)]
# [(4, 0.9619048)]
# [(0, 0.3951679), (1, 0.5988915)]
# [(3, 0.9619048)]
# [(1, 0.46272033), (3, 0.5298722)]
# [(1, 0.3412245), (2, 0.48316815), (4, 0.17230153)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(1, 0.48572177), (3, 0.51228493)]
# [(2, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.9804878)]
# [(0, 0.33451268), (1, 0.29332125), (3, 0.3656087)]
# [(0, 0.3765811), (1, 0.6174783)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(1, 0.61658555), (2, 0.18992211), (3, 0.19128245)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.11979622), (1, 0.4704891), (2, 0.12927176), (4, 0.27902448)]
# [(1, 0.9619048)]
# [(1, 0.35302883), (3, 0.64365625)]
# [(1, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.49629626), (4, 0.49629626)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.36320028), (3, 0.63184106)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.29285818), (1, 0.1911868), (2, 0.4412002), (4, 0.07404309)]
# [(3, 0.98688525)]
# [(0, 0.35924718), (2, 0.3322314), (4, 0.30521563)]
# [(2, 0.9619048)]
# [(3, 0.98688525)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.21879803), (2, 0.23231325), (3, 0.54667884)]
# [(2, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.96190476)]
# [(1, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.28510636), (2, 0.28510636), (4, 0.42695034)]
# [(4, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.9619048)]
# [(2, 0.16694213), (3, 0.8280992)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.5493811), (3, 0.44636357)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.64525265), (3, 0.34491125)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.99012345)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.9619048)]
# [(0, 0.49111208), (1, 0.30689788), (4, 0.19999999)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.17121066), (1, 0.46961352), (4, 0.35736588)]
# [(1, 0.5474502), (4, 0.44271377)]
# [(1, 0.4975207), (2, 0.16694213), (3, 0.3322314)]
# [(1, 0.7940594), (3, 0.19999999)]
# [(0, 0.6453044), (3, 0.34485954)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.3923461), (1, 0.26994896), (2, 0.33114755)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.74320984), (3, 0.2493827)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.16694215), (2, 0.8280992)]
# [(3, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.98688525)]
# [(0, 0.24250004), (1, 0.48833117), (3, 0.2679958)]
# [(3, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(4, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.98688525)]
# [(3, 0.9619048)]
# [(3, 0.99012345)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.66200274), (3, 0.33058977)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.44099343), (2, 0.17006606), (3, 0.38695043)]
# [(0, 0.6452996), (3, 0.3448643)]
# [(1, 0.9619048)]
# [(0, 0.3204156), (2, 0.40244007), (3, 0.27581543)]
# [(0, 0.41772872), (2, 0.28510636), (3, 0.294328)]
# [(0, 0.38023627), (1, 0.4158033), (3, 0.19999999)]
# [(1, 0.45462146), (3, 0.54165184)]
# [(1, 0.5197839), (2, 0.27625567), (4, 0.2)]
# [(0, 0.45487902), (1, 0.35957178), (3, 0.18224344)]
# [(0, 0.9619048)]
# [(0, 0.67162997), (4, 0.31373584)]
# [(1, 0.33525428), (2, 0.3661998), (3, 0.29785746)]
# [(0, 0.671814), (4, 0.31355178)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9920792)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.4200356), (3, 0.56533027)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.161964), (1, 0.19939956), (2, 0.26809344), (3, 0.3697767)]
# [(1, 0.56879437), (2, 0.28510636), (4, 0.1432624)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.64535785), (3, 0.3448061)]
# [(0, 0.2325659), (3, 0.37987337), (4, 0.3836003)]
# [(1, 0.9619048)]
# [(1, 0.3980198), (2, 0.19999999), (4, 0.3980198)]
# [(3, 0.9804878)]
# [(1, 0.8077989), (3, 0.18794578)]
# [(0, 0.14703438), (3, 0.8487103)]
# [(0, 0.3907497), (3, 0.31653664), (4, 0.2907236)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.27379614), (1, 0.314862), (2, 0.2664452), (3, 0.14423217)]
# [(2, 0.9804878)]
# [(0, 0.24703838), (1, 0.74312556)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.9804878)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# ...
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.45463145), (3, 0.5416419)]
# [(3, 0.9619048)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.9804878)]
# [(0, 0.19037807), (2, 0.18207131), (3, 0.6242448)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.32103246), (3, 0.40189257), (4, 0.27574602)]
# [(0, 0.9804878)]
# [(4, 0.96190476)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.33590078), (1, 0.3045908), (2, 0.23065133), (4, 0.12809077)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(1, 0.9619048)]
# [(0, 0.99012345)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.2851064), (2, 0.17925775), (4, 0.53279895)]
# [(4, 0.9619048)]
# [(1, 0.74320984), (2, 0.2493827)]
# [(0, 0.19999999), (1, 0.7940594)]
# [(0, 0.2493827), (1, 0.49629626), (2, 0.2493827)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.48699775), (1, 0.3387699), (3, 0.17092656)]
# [(2, 0.28806442), (3, 0.56583625), (4, 0.1432624)]
# [(0, 0.5875375), (1, 0.39782828)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(0, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.6567763), (3, 0.1729757), (4, 0.16694213)]
# [(3, 0.3980198), (4, 0.5960396)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.42695034), (2, 0.1432624), (4, 0.42695034)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(3, 0.9619048)]
# [(0, 0.2493827), (2, 0.49629626), (3, 0.2493827)]
# [(2, 0.9619048)]
# [(0, 0.35783637), (1, 0.2853152), (3, 0.15437277), (4, 0.20123343)]
# [(0, 0.1494726), (2, 0.37391305), (3, 0.2350595), (4, 0.2403126)]
# [(2, 0.9619048)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3598914), (3, 0.6351499)]
# [(1, 0.9619048)]
# [(2, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(2, 0.5347252), (3, 0.09546778), (4, 0.3683835)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.82670933), (1, 0.16833201)]
# [(0, 0.2493827), (2, 0.47686413), (3, 0.26881483)]
# [(0, 0.16694213), (1, 0.3322314), (2, 0.49752066)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.334511), (1, 0.44117957), (2, 0.22209944)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.28191894), (2, 0.33114755), (3, 0.38037613)]
# [(2, 0.9619048)]
# [(2, 0.19999999), (3, 0.7940594)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.54155684), (4, 0.4486071)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(2, 0.98688525)]
# [(0, 0.9619048)]
# [(1, 0.49629626), (3, 0.27694878), (4, 0.22181667)]
# [(2, 0.9804878)]
# [(4, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2493827), (3, 0.49629626), (4, 0.2493827)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(2, 0.8486178), (4, 0.14765555)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.6453857), (3, 0.34477824)]
# [(0, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49629626), (3, 0.49629632)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.28716147), (3, 0.2), (4, 0.5088782)]
# [(0, 0.99012345)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49629626), (3, 0.2493827), (4, 0.2493827)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.64095414), (1, 0.34441176)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(3, 0.74320984), (4, 0.2493827)]
# [(1, 0.9619048)]
# [(1, 0.2703208), (3, 0.72227174)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.8280992), (3, 0.16694213)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268287), (1, 0.49268293)]
# [(0, 0.55129033), (2, 0.44276902)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(2, 0.9619048)]
# [(0, 0.24968943), (1, 0.5893406), (2, 0.1584855)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(4, 0.9804878)]
# [(1, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.9619048)]
# [(0, 0.98688525)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(0, 0.9804878)]
# [(1, 0.5474344), (4, 0.4427295)]
# [(0, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.35138324), (1, 0.63878065)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(4, 0.9619048)]
# [(0, 0.45170245), (1, 0.33114755), (4, 0.21059266)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(1, 0.3980198), (2, 0.3980198), (4, 0.19999999)]
# [(1, 0.98688525)]
# [(0, 0.29116428), (1, 0.10581129), (2, 0.1569338), (3, 0.34584123), (4, 0.10024937)]
# [(0, 0.46595713), (3, 0.52420676)]
# [(4, 0.9619048)]
# [(0, 0.26029778), (1, 0.13970223), (3, 0.59603965)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3476916), (1, 0.4820605), (2, 0.16694215)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(1, 0.15343286), (2, 0.07693788), (3, 0.60084534), (4, 0.16807215)]
# [(3, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(4, 0.98688525)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(0, 0.23767135), (1, 0.2785385), (3, 0.22169374), (4, 0.26119143)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(0, 0.98688525)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.9619048)]
# [(0, 0.6717116), (4, 0.31365424)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9619048)]
# [(1, 0.2936292), (4, 0.69896346)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(0, 0.9804878)]
# [(3, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.1511952), (3, 0.34123906), (4, 0.5053558)]
# [(0, 0.3980198), (2, 0.19999999), (3, 0.3980198)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(3, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.25548646), (3, 0.7395549)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.7896856), (1, 0.20437376)]
# [(0, 0.9619048)]
# [(0, 0.41604948), (1, 0.2921972), (2, 0.28681505)]
# [(3, 0.9619048)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.5340189), (2, 0.45857376)]
# [(4, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(1, 0.6628099), (4, 0.3322314)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(1, 0.99012345)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.60387), (2, 0.386294)]
# [(4, 0.9619048)]
# [(3, 0.9619048)]
# [(3, 0.9804878)]
# [(3, 0.7940594), (4, 0.19999999)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.43474895), (3, 0.555415)]
# [(2, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.2493827), (2, 0.49629626), (4, 0.2493827)]
# [(0, 0.23033634), (3, 0.28098103), (4, 0.4837444)]
# [(0, 0.1432624), (2, 0.28510636), (3, 0.1432624), (4, 0.42695034)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.98688525)]
# [(0, 0.9619048)]
# [(3, 0.9619048)]
# [(2, 0.6590164), (4, 0.33114755)]
# [(2, 0.99012345)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.31749335), (2, 0.219843), (3, 0.46067357)]
# [(0, 0.53359586), (1, 0.1882351), (2, 0.09140271), (3, 0.09536363), (4, 0.09140271)]
# [(4, 0.9619048)]
# [(0, 0.67156225), (4, 0.31380355)]
# [(0, 0.43609157), (3, 0.55650103)]
# [(0, 0.5366336), (4, 0.455959)]
# [(0, 0.9619048)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(0, 0.9619048)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-a4e5338a8c5f> in <module>()
# ----> 1 df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
#
# <ipython-input-30-5bdcb277d550> in format_topics_sentences(ldamodel, corpus, texts)
#      13         wp = ldamodel.show_topic(topic_num)
#      14         topic_keywords = ", ".join([word for word, prop in wp])
# ---> 15         sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
#      16       else:
#      17         break
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8941             combined_columns = self.columns.append(idx_diff)
#    8942             other = (
# -> 8943                 other.reindex(combined_columns, copy=False)
#    8944                 .to_frame()
#    8945                 .T.infer_objects()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in T(self)
#    3359     @property
#    3360     def T(self) -> DataFrame:
# -> 3361         return self.transpose()
#    3362
#    3363     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in transpose(self, copy, *args)
#    3334                 new_vals = new_vals.copy()
#    3335
# -> 3336             result = self._constructor(new_vals, index=self.columns, columns=self.index)
#    3337
#    3338         elif (
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     676                     dtype=dtype,
#     677                     copy=copy,
# --> 678                     typ=manager,
#     679                 )
#     680
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     373         block_values = []
#     374
# --> 375     return create_block_manager_from_blocks(block_values, [columns, index])
#     376
#     377
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes, consolidate)
#    1749
#    1750     if consolidate:
# -> 1751         mgr._consolidate_inplace()
#    1752     return mgr
#    1753
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     622     def _consolidate_inplace(self) -> None:
#     623         if not self.is_consolidated():
# --> 624             self.blocks = tuple(_consolidate(self.blocks))
#     625             self._is_consolidated = True
#     626             self._known_consolidated = True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1973     for (_can_consolidate, dtype), group_blocks in grouper:
#    1974         merged_blocks = _merge_blocks(
# -> 1975             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1976         )
#    1977         new_blocks = extend_blocks(merged_blocks, new_blocks)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    2005             new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
#    2006
# -> 2007         argsort = np.argsort(new_mgr_locs)
#    2008         new_values = new_values[argsort]
#    2009         new_mgr_locs = new_mgr_locs[argsort]
#
# <__array_function__ internals> in argsort(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...        [atur, jasa, kirim, seller, bagaimana, bos]
# 1              1  ...                         [hepi, ibu, jt, bagaimana]
# 2              2  ...                                               [no]
# 3              3  ...                                            [jelek]
# 4              4  ...  [barang, pesan, kecewa, pesan, tanggal, april,...
# ..           ...  ...                                                ...
# 952          952  ...                              [suram, benar, iklan]
# 953          953  ...  [bayar, rumah, tahu, kls, kalau, beli, toko, m...
# 954          954  ...                         [sangatttttt, lemottttttt]
# 955          955  ...  [lengkap, cari, alat, pancing, muncul, cma, ca...
# 956          956  ...         [kesel, download, download, cepat, pasang]
#
# [957 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    152
# 1.0    207
# 2.0    190
# 3.0    227
# 4.0    181
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500)

plt.show()
