# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install PySastrawi
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
WITH t AS (
  SELECT *
  FROM `future-data-track-1.sapporo_mart.sentiment_analysis`
),
table_stats AS (
  SELECT *, SUM(c) OVER() total 
  FROM (
    SELECT sentiment, COUNT(*) c 
    FROM t
    GROUP BY 1 
    HAVING c>100000)
)
SELECT sample.*
FROM (
SELECT ARRAY_AGG(a ORDER BY RAND() LIMIT 700) cat_samples, sentiment, ANY_VALUE(c) c
FROM t a
JOIN table_stats b
USING(sentiment)
GROUP BY sentiment
), UNNEST(cat_samples) sample WITH OFFSET off;
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                  review  rating  sentiment
# 0                                      Knaoa gagal mulu       1          0
# 1                                              Menyesal       1          0
# 2     Pembelian pakai cc ribet, di tolak terus sama ...       2          0
# 3                                  Klo oke sy tambah lg       2          0
# 4     Kenapa saya tidak bisa verifikasi email saya?!...       1          0
# ...                                                 ...     ...        ...
# 2095                                       Terima kasih       5          2
# 2096                                          Saya puas       4          2
# 2097                         mengatasi segala kebutuhan       5          2
# 2098                                            makasih       5          2
# 2099                          Luar biasa dan bermanfaat       5          2
#
# [2100 rows x 3 columns]

# %%
#df = df.sort_values('created_date').drop_duplicates('review_id',keep='last')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-6cdb0f568005> in <module>()
# ----> 1 df = df.sort_values('created_date').drop_duplicates('review_id',keep='last')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'created_date'

# %%
df
# Out:
#                                                  review  rating  sentiment
# 0                                      Knaoa gagal mulu       1          0
# 1                                              Menyesal       1          0
# 2     Pembelian pakai cc ribet, di tolak terus sama ...       2          0
# 3                                  Klo oke sy tambah lg       2          0
# 4     Kenapa saya tidak bisa verifikasi email saya?!...       1          0
# ...                                                 ...     ...        ...
# 2095                                       Terima kasih       5          2
# 2096                                          Saya puas       4          2
# 2097                         mengatasi segala kebutuhan       5          2
# 2098                                            makasih       5          2
# 2099                          Luar biasa dan bermanfaat       5          2
#
# [2100 rows x 3 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar","buka","lapak"
    ,"terima","kasih","alhamdulillah","pokok"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review_processed'] = processed_values

# %%
df_token.dropna(subset = ["review_processed"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review_processed'].values]]

# %%
df_token.dropna(subset = ["review_processed"], inplace=True)

# %%
df_token
# Out:
#                                                  review  ...                                   review_processed
# 0                                      Knaoa gagal mulu  ...                                   knaoa gagal mulu
# 2     Pembelian pakai cc ribet, di tolak terus sama ...  ...              beli pakai cc ribet tolak sedia layan
# 4     Kenapa saya tidak bisa verifikasi email saya?!...  ...                             verifikasi email kesel
# 5     TOP UP GAK MASUK E MONEY DIBILANG MASUK, MANAJ...  ...                          up money bilang manajemen
# 7                                Iklan nya nyebelin anj  ...                                     iklan nyebelin
# ...                                                 ...  ...                                                ...
# 2090  Belanja aman dan menyenangkan. Topup tanpa bia...  ...  belanja aman topup biaya admin harga murah jan...
# 2091           sip tingkat kan trus aja promo nya ehehe  ...                                tingkat promo ehehe
# 2092                              Murid-murid kebenaran  ...                                        murid murid
# 2093                                     bags barang ny  ...                                     bags barang ny
# 2094                      Pesanan bagus cepat sampe nya  ...                                  pesan cepat sampe
#
# [1305 rows x 4 columns]

# %%
df_token.to_csv('data_ori.csv',  header=["review", "rating", "sentiment", "review_processed"], chunksize=100000, index = False, mode='a')

# %% [markdown]
# ## Passed

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df_token=pd.read_csv('gdrive/MyDrive/save_file/data_ori.csv')

# %%
df_token
# Out:
#                                                 review_id  ...                                   review_processed
# 0       gp:AOqpTOGQsjNT8bCwiF-nwRWz21cSlw0vCqBA6BlDSlN...  ...                                toko belanja online
# 1       gp:AOqpTOFJ-fitPKGHlserqpT5G9aj99zuciR3nWrBIl-...  ...  beli power bank kualitas pdhl ngecas hp penuh ...
# 2       gp:AOqpTOGXwzNkjNd7DXVTBPQZMfmfDn0XUpCjkwwNspA...  ...                                kerennn bikin ribet
# 3       gp:AOqpTOE7aFosjNF6RFfC1UwhOb3GGNWoYi5RzBysn6-...  ...                            aplikasi belanja online
# 4       gp:AOqpTOH-VArcOLh-i_YhEdvhtx1C0GHOQHYA2sLVdjo...  ...                                      mudah belanja
# ...                                                   ...  ...                                                ...
# 759388  gp:AOqpTOGPoYnGeF8zfN6YgxDiKKgUSl7qnv0KwrLIKLs...  ...                                aplikasimya bagusss
# 759389  gp:AOqpTOGG20kk2t8jP_4IHYCRW0BoDKR9FjQRS2JPNgJ...  ...                     produk import asli hoki untung
# 759390  gp:AOqpTOEBo6yR4EBVFYLvEV3ssKrxnQ9cFrsUGyAJu46...  ...                               bantu belanja online
# 759391  gp:AOqpTOE_G8UoxNZi1Y-h3C3woka8dLgeBq2OWL548sj...  ...                   belanja rumah cocok kaum mageran
# 759392  gp:AOqpTOEmlUyh_xkuC58POLj8LmWqCNq_VCxFx-8cRif...  ...        besttttttt aplikasi belanja nomer indonesia
#
# [759393 rows x 5 columns]

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lambat', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lambat', 'buanget'],
#  ['habis',
#   'update',
#   'lambat',
#   'sihh',
#   'shoppenya',
#   'lambat',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lambat',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lambat'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lambat', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lambat', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lambat',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lambat',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lambat',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'bahkan',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'bahkan',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lambat', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lambat',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lambat'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lambat',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lambat',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
# ...
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lambat', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lambat',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_4')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(0, 0.031253938), (1, 0.50241977), (2, 0.30648053), (3, 0.15984577)]
# [(0, 0.06517757), (1, 0.48029712), (2, 0.06377844), (3, 0.3907469)]
# [(0, 0.05042106), (1, 0.051735528), (2, 0.22946894), (3, 0.6683744)]
# [(0, 0.4168805), (1, 0.41279426), (2, 0.08407659), (3, 0.08624864)]
# [(0, 0.25000203), (1, 0.25000134), (2, 0.05028217), (3, 0.44971448)]
# [(0, 0.02273748), (1, 0.111269884), (2, 0.5917134), (3, 0.27427918)]
# [(0, 0.12211232), (1, 0.27231586), (2, 0.29380068), (3, 0.31177115)]
# [(0, 0.027848413), (1, 0.36110866), (2, 0.5832059), (3, 0.027836973)]
# [(0, 0.31249666), (1, 0.06356336), (2, 0.5614395), (3, 0.06250043)]
# [(0, 0.1788637), (1, 0.2105584), (2, 0.27644894), (3, 0.33412892)]
# [(0, 0.21569914), (1, 0.041667018), (2, 0.6988819), (3, 0.04375191)]
# [(0, 0.10719413), (1, 0.2910434), (2, 0.38744608), (3, 0.21431637)]
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#       Document_No  ...                                               Text
# 0               0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1               1  ...                         [verifikasi, email, kesel]
# 2               2  ...                     [up, money, bilang, manajemen]
# 3               3  ...                                     [iklan, sebal]
# 4               4  ...                    [nonton, ngapa, kesini, melulu]
# ...           ...  ...                                                ...
# 1995         1995  ...                                  [barang, lengkap]
# 1996         1996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 1997         1997  ...                            [tingkat, promo, ehehe]
# 1998         1998  ...                                 [bags, barang, ny]
# 1999         1999  ...                             [pesan, cepat, sampai]
#
# [2000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    276
# 1.0    200
# 2.0    806
# 3.0    718
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,1000)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_4topics.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
