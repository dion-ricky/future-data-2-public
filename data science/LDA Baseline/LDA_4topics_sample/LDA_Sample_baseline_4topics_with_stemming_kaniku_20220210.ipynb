# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ### Initial Formalization

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lemot', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lemot', 'buanget'],
#  ['habis',
#   'update',
#   'lemot',
#   'sihh',
#   'shoppenya',
#   'lemot',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lemot',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lemot'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lemot', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lemot', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lemot',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lemot',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lemot',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'malah',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'malah',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lemot', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lemot',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lemot'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lemot',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lemot',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
#   'kaya',
#   'keong',
# ...
#   'jasa',
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lemot', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lemot',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai']]

# %% [markdown]
# ## Modelling

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_4')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = ldamodel.id2word

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(0, 0.03163962), (1, 0.496306), (2, 0.035304636), (3, 0.43674973)]
# [(0, 0.06250004), (1, 0.06250003), (2, 0.062500015), (3, 0.81249994)]
# [(0, 0.050002724), (1, 0.05000203), (2, 0.26253957), (3, 0.63745564)]
# [(0, 0.08333347), (1, 0.083333425), (2, 0.083333395), (3, 0.7499997)]
# [(0, 0.050000086), (1, 0.05000006), (2, 0.050302595), (3, 0.84969723)]
# [(0, 0.113901354), (1, 0.22856142), (2, 0.6345527), (3, 0.02298451)]
# [(0, 0.07002074), (1, 0.27145135), (2, 0.07257286), (3, 0.5859551)]
# [(0, 0.027779669), (1, 0.02836852), (2, 0.8050746), (3, 0.13877721)]
# [(0, 0.3126874), (1, 0.07135123), (2, 0.065351084), (3, 0.5506103)]
# [(0, 0.018408224), (1, 0.2685975), (2, 0.20443656), (3, 0.50855774)]
# [(0, 0.18731232), (1, 0.04166935), (2, 0.45546558), (3, 0.31555274)]
# [(0, 0.02083391), (1, 0.020833945), (2, 0.69341105), (3, 0.26492107)]
# [(0, 0.016996758), (1, 0.015703127), (2, 0.40129346), (3, 0.5660067)]
# [(0, 0.025000867), (1, 0.025000697), (2, 0.41146174), (3, 0.53853667)]
# [(0, 0.01566318), (1, 0.1404132), (2, 0.7367006), (3, 0.10722302)]
# [(0, 0.03425013), (2, 0.6515486), (3, 0.30764514)]
# [(0, 0.10518779), (1, 0.017857453), (2, 0.09213158), (3, 0.7848231)]
# [(0, 0.17856441), (1, 0.03613082), (2, 0.44035485), (3, 0.3449499)]
# [(0, 0.022860164), (1, 0.022801576), (2, 0.79511225), (3, 0.15922597)]
# [(0, 0.6012625), (1, 0.18414734), (2, 0.036019593), (3, 0.17857054)]
# [(0, 0.05000168), (1, 0.24455018), (2, 0.65544677), (3, 0.05000136)]
# [(0, 0.051612157), (1, 0.05555295), (2, 0.83946496), (3, 0.05336995)]
# [(0, 0.08333442), (1, 0.08333409), (2, 0.7499977), (3, 0.08333382)]
# [(0, 0.0357143), (1, 0.03705396), (2, 0.89151734), (3, 0.03571441)]
# [(0, 0.08598804), (1, 0.08561668), (2, 0.7413315), (3, 0.08706376)]
# [(0, 0.3124979), (1, 0.06250004), (2, 0.562502), (3, 0.06250003)]
# [(0, 0.30615717), (1, 0.03237638), (2, 0.16977839), (3, 0.4916881)]
# [(0, 0.14231889), (1, 0.027823918), (2, 0.34974086), (3, 0.4801163)]
# [(0, 0.083333395), (1, 0.08333338), (2, 0.7499998), (3, 0.083333366)]
# [(0, 0.11380418), (1, 0.1136508), (2, 0.48194617), (3, 0.2905989)]
# [(0, 0.018615933), (1, 0.09885373), (2, 0.5615738), (3, 0.32095653)]
# [(0, 0.04175873), (1, 0.20961024), (2, 0.2260074), (3, 0.52262366)]
# [(0, 0.050003696), (1, 0.24962588), (2, 0.6503694), (3, 0.050001018)]
# [(0, 0.027778573), (1, 0.13889733), (2, 0.35629934), (3, 0.4770247)]
# [(0, 0.019065928), (1, 0.15886696), (2, 0.66601324), (3, 0.15605389)]
# [(0, 0.013948432), (1, 0.19766113), (2, 0.6050073), (3, 0.18338312)]
# [(0, 0.011495426), (1, 0.13342534), (2, 0.65409), (3, 0.20098926)]
# [(0, 0.03125042), (1, 0.5150634), (2, 0.032216277), (3, 0.42146984)]
# [(0, 0.74999994), (1, 0.083333366), (2, 0.08333334), (3, 0.08333335)]
# [(0, 0.17860696), (1, 0.17679366), (2, 0.6077955), (3, 0.036803886)]
# [(2, 0.5640918), (3, 0.41666952)]
# [(0, 0.0787217), (1, 0.18009213), (2, 0.6000798), (3, 0.1411064)]
# [(0, 0.062501304), (1, 0.0625004), (2, 0.06330922), (3, 0.8116891)]
# [(0, 0.07735382), (1, 0.10772667), (2, 0.20907998), (3, 0.6058395)]
# [(0, 0.4719368), (1, 0.017962852), (2, 0.11552014), (3, 0.3945802)]
# [(0, 0.025005952), (1, 0.025477976), (2, 0.64750993), (3, 0.30200613)]
# [(0, 0.25003192), (1, 0.6499675), (2, 0.050000273), (3, 0.050000347)]
# [(0, 0.27560595), (1, 0.25327626), (2, 0.04294282), (3, 0.428175)]
# [(0, 0.014140212), (1, 0.014022676), (2, 0.8594157), (3, 0.11242143)]
# [(0, 0.45011622), (1, 0.24985608), (2, 0.050132833), (3, 0.24989489)]
# [(0, 0.036874205), (1, 0.06660253), (2, 0.20058638), (3, 0.69593686)]
# [(0, 0.050011504), (1, 0.2501436), (2, 0.450902), (3, 0.2489429)]
# [(0, 0.01562502), (1, 0.015679406), (2, 0.652318), (3, 0.31637755)]
# [(0, 0.042707488), (1, 0.04238458), (2, 0.04239494), (3, 0.872513)]
# [(0, 0.06250031), (1, 0.8118793), (2, 0.06312028), (3, 0.06250014)]
# [(0, 0.37551463), (1, 0.04166678), (2, 0.04215842), (3, 0.5406602)]
# [(0, 0.3713407), (1, 0.062500015), (2, 0.06396214), (3, 0.50219715)]
# [(0, 0.74989474), (1, 0.083333336), (2, 0.08343862), (3, 0.083333336)]
# [(0, 0.068054944), (1, 0.06250008), (2, 0.063313164), (3, 0.80613184)]
# [(0, 0.045343235), (1, 0.04166683), (2, 0.043779362), (3, 0.86921054)]
# [(0, 0.08333483), (1, 0.083337195), (2, 0.74998266), (3, 0.08334526)]
# [(0, 0.015625097), (1, 0.015816258), (2, 0.7981983), (3, 0.17036034)]
# [(0, 0.02083957), (1, 0.15131094), (2, 0.80684143), (3, 0.021008084)]
# [(0, 0.45144933), (1, 0.44854942), (2, 0.05000121), (3, 0.05)]
# [(0, 0.06250064), (1, 0.06250035), (2, 0.06878392), (3, 0.8062151)]
# [(0, 0.050000004), (1, 0.052094202), (2, 0.8479053), (3, 0.05000058)]
# [(0, 0.03960452), (1, 0.035714358), (2, 0.88896674), (3, 0.03571433)]
# [(0, 0.28263664), (1, 0.19112456), (2, 0.4947623), (3, 0.03147652)]
# [(0, 0.091731116), (1, 0.018133216), (2, 0.17715146), (3, 0.71298414)]
# [(0, 0.3213424), (1, 0.035732318), (2, 0.6026181), (3, 0.04030717)]
# [(0, 0.20833422), (1, 0.2083314), (2, 0.54166764), (3, 0.041666675)]
# [(0, 0.08034142), (2, 0.29087913), (3, 0.6201514)]
# [(0, 0.05049052), (1, 0.05000003), (2, 0.324539), (3, 0.5749704)]
# [(0, 0.06250167), (1, 0.3124959), (2, 0.06250366), (3, 0.5624988)]
# [(0, 0.3124546), (1, 0.062500626), (2, 0.06389087), (3, 0.56115395)]
# [(0, 0.041672632), (1, 0.20728132), (2, 0.041671026), (3, 0.709375)]
# [(0, 0.26066747), (1, 0.05267905), (2, 0.2935457), (3, 0.39310777)]
# [(0, 0.06250001), (1, 0.06283293), (2, 0.8121671), (3, 0.0625)]
# [(0, 0.18759535), (1, 0.020833408), (2, 0.5905116), (3, 0.20105962)]
# [(0, 0.08333374), (1, 0.08731262), (2, 0.74602014), (3, 0.0833335)]
# [(0, 0.04242076), (1, 0.041666698), (2, 0.041903403), (3, 0.87400913)]
# [(0, 0.05000028), (1, 0.8499422), (2, 0.05005753), (3, 0.05)]
# [(0, 0.06473849), (1, 0.06250172), (2, 0.8102597), (3, 0.062500134)]
# [(0, 0.22716261), (1, 0.041723922), (2, 0.68718535), (3, 0.043928087)]
# [(0, 0.20838621), (1, 0.041667104), (2, 0.7082797), (3, 0.041666966)]
# [(0, 0.015914049), (1, 0.14448635), (2, 0.2877271), (3, 0.55187255)]
# [(0, 0.08333412), (1, 0.08333385), (2, 0.08455778), (3, 0.7487743)]
# [(0, 0.050000038), (1, 0.050390884), (2, 0.8496089), (3, 0.05000014)]
# [(0, 0.29258186), (1, 0.39242727), (2, 0.03127664), (3, 0.28371423)]
# [(0, 0.023119627), (1, 0.023109447), (2, 0.7979345), (3, 0.1558365)]
# [(0, 0.09932226), (1, 0.083333395), (2, 0.083333366), (3, 0.734011)]
# [(0, 0.26753142), (1, 0.0501984), (2, 0.050093453), (3, 0.63217676)]
# [(0, 0.098183766), (1, 0.025000164), (2, 0.50689274), (3, 0.36992332)]
# [(0, 0.027778562), (1, 0.1458495), (2, 0.6874816), (3, 0.13889042)]
# [(0, 0.41676447), (1, 0.41656712), (2, 0.08333408), (3, 0.08333432)]
# [(0, 0.08333335), (1, 0.08752746), (2, 0.74580586), (3, 0.08333334)]
# [(0, 0.035928752), (1, 0.035943806), (2, 0.44928995), (3, 0.47883752)]
# [(0, 0.050000023), (1, 0.05000002), (2, 0.05067724), (3, 0.8493227)]
# [(0, 0.65003663), (1, 0.050000258), (2, 0.050247535), (3, 0.2497156)]
# [(0, 0.088137865), (1, 0.50429034), (2, 0.3368793), (3, 0.07069249)]
# [(0, 0.08353374), (1, 0.7495885), (2, 0.08340465), (3, 0.08347308)]
# [(0, 0.36220077), (1, 0.37174323), (2, 0.22978587), (3, 0.036270104)]
# [(0, 0.249194), (1, 0.050530605), (2, 0.64946735), (3, 0.05080802)]
# [(0, 0.0625), (1, 0.81068045), (2, 0.06407947), (3, 0.062740006)]
# [(0, 0.041667104), (1, 0.67414206), (2, 0.2419842), (3, 0.042206664)]
# [(0, 0.050000004), (1, 0.05128478), (2, 0.8487152), (3, 0.05)]
# [(0, 0.04166678), (1, 0.04166835), (2, 0.6618344), (3, 0.25483045)]
# [(0, 0.5143691), (1, 0.064059965), (2, 0.35813025), (3, 0.06344072)]
# [(0, 0.051445745), (1, 0.8466548), (2, 0.051898785), (3, 0.050000656)]
# [(0, 0.062501654), (1, 0.3120972), (2, 0.5629012), (3, 0.06250001)]
# [(0, 0.13889617), (1, 0.25008836), (2, 0.47221258), (3, 0.13880292)]
# [(0, 0.2813105), (1, 0.65563154), (2, 0.031295817), (3, 0.031762194)]
# [(0, 0.042086627), (1, 0.87457967), (2, 0.04166684), (3, 0.0416669)]
# [(0, 0.041675054), (1, 0.041666847), (2, 0.7083193), (3, 0.2083388)]
# [(0, 0.03125021), (1, 0.47625914), (2, 0.4612406), (3, 0.031250004)]
# [(0, 0.050000288), (1, 0.8489351), (2, 0.050363936), (3, 0.050700646)]
# [(0, 0.06250182), (1, 0.8124964), (2, 0.06250079), (3, 0.0625009)]
# [(0, 0.06250001), (1, 0.8125), (2, 0.0625), (3, 0.0625)]
# [(0, 0.0625055), (1, 0.55212814), (2, 0.32245517), (3, 0.06291126)]
# [(0, 0.020833733), (1, 0.19212888), (2, 0.32028666), (3, 0.4667507)]
# [(0, 0.02272931), (1, 0.52602524), (2, 0.4284877), (3, 0.022757791)]
# [(0, 0.24940929), (1, 0.64829695), (2, 0.052292913), (3, 0.050000787)]
# [(0, 0.05000028), (1, 0.84933054), (2, 0.05066923), (3, 0.05)]
# [(0, 0.027777983), (1, 0.029023536), (2, 0.28844616), (3, 0.6547523)]
# [(0, 0.33113968), (1, 0.19854599), (2, 0.051869024), (3, 0.41844526)]
# [(0, 0.25000072), (1, 0.6471098), (2, 0.05288912), (3, 0.050000347)]
# [(0, 0.08333338), (1, 0.08333337), (2, 0.7499999), (3, 0.08333336)]
# [(0, 0.3868635), (1, 0.42876986), (2, 0.016815921), (3, 0.16755076)]
# [(0, 0.3133156), (1, 0.56168294), (2, 0.0625015), (3, 0.06250001)]
# [(0, 0.050001815), (1, 0.050751805), (2, 0.8492462), (3, 0.05000012)]
# [(0, 0.6499025), (1, 0.2500951), (2, 0.05000134), (3, 0.050001048)]
# [(0, 0.06250001), (1, 0.06435199), (2, 0.810648), (3, 0.0625)]
# [(0, 0.062500015), (1, 0.06646353), (2, 0.80853546), (3, 0.06250099)]
# [(0, 0.31253996), (1, 0.5624586), (2, 0.06250151), (3, 0.06250001)]
# [(0, 0.08333432), (1, 0.74999696), (2, 0.08333535), (3, 0.083333336)]
# [(0, 0.02827038), (1, 0.6743872), (2, 0.027895667), (3, 0.2694468)]
# [(0, 0.062502265), (1, 0.31252778), (2, 0.5624692), (3, 0.06250077)]
# [(0, 0.13890049), (1, 0.028702782), (2, 0.6663951), (3, 0.16600162)]
# [(0, 0.46866298), (1, 0.04218847), (2, 0.043544177), (3, 0.4456044)]
# [(0, 0.039101426), (1, 0.74197483), (2, 0.03748104), (3, 0.18144271)]
# [(0, 0.019231092), (1, 0.5319179), (2, 0.3022928), (3, 0.14655817)]
# [(0, 0.08333335), (1, 0.3896896), (2, 0.4436437), (3, 0.08333334)]
# [(0, 0.06250249), (1, 0.8120252), (2, 0.06290386), (3, 0.0625685)]
# [(0, 0.17292082), (1, 0.02814307), (2, 0.5196967), (3, 0.27923936)]
# [(0, 0.05037068), (1, 0.84761614), (2, 0.052013177), (3, 0.05000001)]
# [(0, 0.08460133), (1, 0.37146392), (2, 0.5278372), (3, 0.016097562)]
# [(0, 0.06250004), (1, 0.8090491), (2, 0.06595041), (3, 0.06250045)]
# [(0, 0.04166689), (1, 0.34075046), (2, 0.575916), (3, 0.041666683)]
# [(0, 0.06250048), (1, 0.81249505), (2, 0.06250446), (3, 0.0625)]
# [(0, 0.16416015), (1, 0.40588647), (2, 0.39859268), (3, 0.031360745)]
# [(0, 0.19998705), (1, 0.4909258), (2, 0.1215206), (3, 0.1875666)]
# [(0, 0.031250086), (1, 0.1562477), (2, 0.7789824), (3, 0.033519857)]
# [(0, 0.03125094), (1, 0.15588728), (2, 0.46378818), (3, 0.34907362)]
# [(0, 0.06250001), (1, 0.06283058), (2, 0.8121694), (3, 0.06250001)]
# [(0, 0.31251997), (1, 0.31247953), (2, 0.3125004), (3, 0.06250017)]
# [(0, 0.06315717), (1, 0.8118428), (2, 0.0625), (3, 0.0625)]
# [(0, 0.05446531), (1, 0.0123039745), (2, 0.8314376), (3, 0.101793125)]
# [(0, 0.12851727), (1, 0.2269406), (2, 0.467763), (3, 0.17677908)]
# [(0, 0.06250003), (1, 0.8090487), (2, 0.0659508), (3, 0.06250044)]
# [(0, 0.37135404), (1, 0.5036458), (2, 0.062500104), (3, 0.06250013)]
# [(0, 0.13814755), (1, 0.6827035), (2, 0.15730612), (3, 0.021842815)]
# [(0, 0.08333344), (1, 0.74999976), (2, 0.08333337), (3, 0.08333338)]
# [(0, 0.027777871), (1, 0.027983645), (2, 0.91614574), (3, 0.028092764)]
# [(0, 0.028282447), (1, 0.17517793), (2, 0.7685387), (3, 0.028000904)]
# [(0, 0.22606668), (1, 0.15713224), (2, 0.5905816), (3, 0.026219437)]
# [(0, 0.37577164), (1, 0.5408943), (2, 0.04166731), (3, 0.04166667)]
# [(0, 0.05001725), (1, 0.32993066), (2, 0.5698725), (3, 0.0501796)]
# [(0, 0.027777778), (1, 0.34167904), (2, 0.6027652), (3, 0.027777977)]
# [(0, 0.05000027), (1, 0.8493969), (2, 0.050602756), (3, 0.050000124)]
# [(0, 0.08333431), (1, 0.749997), (2, 0.08333534), (3, 0.08333333)]
# [(0, 0.051023286), (1, 0.52845514), (2, 0.36930758), (3, 0.051214047)]
# [(0, 0.03125033), (1, 0.34551233), (2, 0.5919873), (3, 0.031250022)]
# [(0, 0.08333338), (1, 0.08333337), (2, 0.7499998), (3, 0.083333366)]
# [(0, 0.5625002), (1, 0.3119359), (2, 0.063063875), (3, 0.062500015)]
# [(0, 0.03125449), (1, 0.25161725), (2, 0.68281704), (3, 0.03431121)]
# [(0, 0.08333433), (1, 0.74999666), (2, 0.08333572), (3, 0.083333336)]
# [(0, 0.06250002), (1, 0.8075168), (2, 0.066262305), (3, 0.06372085)]
# [(0, 0.078176245), (1, 0.7729401), (2, 0.014264337), (3, 0.13461933)]
# [(0, 0.08333334), (1, 0.087516695), (2, 0.74581665), (3, 0.083333336)]
# [(0, 0.3357953), (1, 0.3063132), (2, 0.16001673), (3, 0.19787477)]
# [(0, 0.08333432), (1, 0.74999696), (2, 0.08333535), (3, 0.083333336)]
# [(0, 0.19917285), (1, 0.035714347), (2, 0.72581345), (3, 0.039299328)]
# [(0, 0.04166669), (1, 0.041667264), (2, 0.8740902), (3, 0.042575877)]
# [(0, 0.026643585), (1, 0.26291397), (2, 0.1493742), (3, 0.56106824)]
# [(0, 0.40588164), (1, 0.53161794), (2, 0.031250194), (3, 0.03125025)]
# [(0, 0.050376806), (1, 0.8477448), (2, 0.05187835), (3, 0.050000004)]
# [(0, 0.02083383), (1, 0.1265579), (2, 0.56817824), (3, 0.28443003)]
# [(0, 0.4166781), (1, 0.0833337), (2, 0.08333341), (3, 0.41665474)]
# [(0, 0.025000248), (1, 0.48001814), (2, 0.46849212), (3, 0.026489457)]
# [(0, 0.20834601), (1, 0.49607122), (2, 0.25391605), (3, 0.041666668)]
# [(0, 0.28122938), (1, 0.031250548), (2, 0.6554665), (3, 0.03205362)]
# [(0, 0.062506065), (1, 0.81248987), (2, 0.06250168), (3, 0.06250239)]
# [(0, 0.08598565), (1, 0.085616045), (2, 0.74133176), (3, 0.08706655)]
# [(0, 0.02500023), (1, 0.43792352), (2, 0.5120531), (3, 0.02502323)]
# [(0, 0.050001282), (1, 0.050002497), (2, 0.65007555), (3, 0.2499206)]
# [(0, 0.050035574), (1, 0.05000208), (2, 0.6502034), (3, 0.24975893)]
# [(0, 0.041666728), (1, 0.5293283), (2, 0.38428107), (3, 0.04472394)]
# [(0, 0.04177034), (1, 0.041694652), (2, 0.04179208), (3, 0.8747429)]
# [(0, 0.08333432), (1, 0.74999696), (2, 0.08333534), (3, 0.083333336)]
# [(0, 0.20833331), (1, 0.5357823), (2, 0.21421757), (3, 0.041666787)]
# [(0, 0.06250002), (1, 0.06433787), (2, 0.8106621), (3, 0.062500015)]
# [(0, 0.3556554), (1, 0.05257719), (2, 0.2787595), (3, 0.3130079)]
# [(0, 0.3133156), (1, 0.56168294), (2, 0.0625015), (3, 0.06250001)]
# [(0, 0.025932724), (1, 0.025675634), (2, 0.7945268), (3, 0.15386482)]
# [(0, 0.05000021), (1, 0.050001405), (2, 0.6500065), (3, 0.24999186)]
# [(0, 0.06250297), (1, 0.8061403), (2, 0.06885623), (3, 0.062500425)]
# [(0, 0.24998723), (1, 0.029153874), (2, 0.69259614), (3, 0.028262742)]
# [(0, 0.06250028), (1, 0.31250787), (2, 0.5624918), (3, 0.062500134)]
# [(0, 0.05461395), (1, 0.041835107), (2, 0.24600665), (3, 0.6575443)]
# [(0, 0.27994007), (1, 0.6200166), (2, 0.050031893), (3, 0.050011434)]
# [(0, 0.41666678), (1, 0.41666654), (2, 0.083333336), (3, 0.083333336)]
# [(0, 0.027777996), (1, 0.9142118), (2, 0.029813405), (3, 0.028196769)]
# [(0, 0.083355844), (1, 0.7497341), (2, 0.08356752), (3, 0.08334258)]
# [(0, 0.08333334), (1, 0.75), (2, 0.083333336), (3, 0.083333336)]
# [(0, 0.0625), (1, 0.06250151), (2, 0.8124985), (3, 0.0625)]
# [(0, 0.4151652), (1, 0.08333338), (2, 0.41483864), (3, 0.08666277)]
# [(0, 0.25003263), (1, 0.4432109), (2, 0.25675648), (3, 0.05)]
# [(0, 0.08333431), (1, 0.749997), (2, 0.08333534), (3, 0.08333333)]
# [(0, 0.0625001), (1, 0.06250009), (2, 0.8124998), (3, 0.062500045)]
# [(0, 0.021052962), (1, 0.45090687), (2, 0.5050245), (3, 0.023015669)]
# [(0, 0.05062212), (1, 0.055770878), (2, 0.050816726), (3, 0.8427903)]
# [(0, 0.31257293), (1, 0.56065303), (2, 0.06427404), (3, 0.0625)]
# [(0, 0.03858581), (1, 0.03876682), (2, 0.6621577), (3, 0.26048964)]
# [(0, 0.23185645), (1, 0.5187282), (2, 0.20774864), (3, 0.041666683)]
# [(0, 0.28425762), (1, 0.10389235), (2, 0.22548799), (3, 0.38636205)]
# [(0, 0.40144944), (1, 0.041666675), (2, 0.51463217), (3, 0.042251732)]
# [(0, 0.043509502), (1, 0.87180096), (2, 0.042116597), (3, 0.04257291)]
# [(0, 0.033482194), (1, 0.46117532), (2, 0.031500716), (3, 0.47384182)]
# [(0, 0.1388889), (1, 0.03177911), (2, 0.8011888), (3, 0.028143115)]
# [(0, 0.08333337), (1, 0.41615668), (2, 0.41717657), (3, 0.08333334)]
# [(0, 0.09616132), (1, 0.29746658), (2, 0.5869453), (3, 0.019426845)]
# [(0, 0.31110978), (1, 0.27812713), (2, 0.34824952), (3, 0.062513575)]
# [(0, 0.56249124), (1, 0.062505625), (2, 0.31250292), (3, 0.0625002)]
# [(0, 0.062500015), (1, 0.064353414), (2, 0.8091423), (3, 0.06400429)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1              1  ...                         [verifikasi, email, kesel]
# 2              2  ...                     [up, money, bilang, manajemen]
# 3              3  ...                                     [iklan, sebal]
# 4              4  ...                    [nonton, ngapa, kesini, melulu]
# ..           ...  ...                                                ...
# 995          995  ...                                  [barang, lengkap]
# 996          996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 997          997  ...                            [tingkat, promo, ehehe]
# 998          998  ...                                 [bags, barang, ny]
# 999          999  ...                             [pesan, cepat, sampai]
#
# [1000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0     69
# 1.0    144
# 2.0    452
# 3.0    335
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,1000)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_4topics.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
