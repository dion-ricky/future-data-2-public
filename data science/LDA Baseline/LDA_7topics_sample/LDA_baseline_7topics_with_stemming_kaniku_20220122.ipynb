# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install PySastrawi
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama", "lot": "lemot"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'lot': 'lemot',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ## Passed

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_token = pd.read_csv("https://gist.githubusercontent.com/Kaniku/224fce0e62377d27af500cf2ce896360/raw/e3343510a66b1a9c7d555dde4e03da9f243e2ab0/data_sample_1000.csv")

# %%
df_token
# Out:
#                                                 review  ...                                   review_processed
# 0    Pembelian pakai cc ribet, di tolak terus sama ...  ...              beli pakai cc ribet tolak sedia layan
# 1    Kenapa saya tidak bisa verifikasi email saya?!...  ...                             verifikasi email kesel
# 2    TOP UP GAK MASUK E MONEY DIBILANG MASUK, MANAJ...  ...                          up money bilang manajemen
# 3                               Iklan nya nyebelin anj  ...                                     iklan nyebelin
# 4                 Anj..gw mau nonton ngapa kesini mulu  ...                           nonton ngapa kesini mulu
# ..                                                 ...  ...                                                ...
# 995                      Semoga barang semakin lengkap  ...                                     barang lengkap
# 996  Belanja aman dan menyenangkan. Topup tanpa bia...  ...  belanja aman topup biaya admin harga murah jan...
# 997           sip tingkat kan trus aja promo nya ehehe  ...                                tingkat promo ehehe
# 998                                     bags barang ny  ...                                     bags barang ny
# 999                      Pesanan bagus cepat sampe nya  ...                                  pesan cepat sampe
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review_processed']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['beli', 'pakai', 'cc', 'ribet', 'tolak', 'sedia', 'layan'],
#  ['verifikasi', 'email', 'kesel'],
#  ['up', 'money', 'bilang', 'manajemen'],
#  ['iklan', 'sebal'],
#  ['nonton', 'ngapa', 'kesini', 'melulu'],
#  ['belanja',
#   'tipu',
#   'jual',
#   'nakal',
#   'selektif',
#   'nyaring',
#   'jual',
#   'beda',
#   'online',
#   'shop'],
#  ['tolong',
#   'bantu',
#   'kenapa',
#   'sertifikat',
#   'smpai',
#   'skrang',
#   'dashboard',
#   'pdhal',
#   'pihal',
#   'bus',
#   'email',
#   'sertifikat',
#   'tanggal',
#   'september',
#   'smpaj',
#   'tanggal',
#   'dashboard',
#   'pdhal',
#   'jam'],
#  ['kirim',
#   'tanggap',
#   'tenggang',
#   'kirim',
#   'barang',
#   'seller',
#   'langgan',
#   'idiot'],
#  ['aplikasi', 'kaya', 'ribet'],
#  ['pusat',
#   'bantu',
#   'fitur',
#   'live',
#   'cht',
#   'beli',
#   'barang',
#   'lngsung',
#   'nnaya',
#   'bles',
#   'hadehhhh',
#   'macetttt',
#   'trimksih',
#   'beli'],
#  ['pret', 'barang', 'return', 'shope', 'balik'],
#  ['barang',
#   'kirim',
#   'pdhal',
#   'order',
#   'komplain',
#   'katanya',
#   'refund',
#   'smp',
#   'sekarang',
#   'konfirmasi',
#   'lagi'],
#  ['barang',
#   'sampai',
#   'kolom',
#   'benar',
#   'woyy',
#   'nerima',
#   'niat',
#   'jual',
#   'olshop',
#   'bayar',
#   'makan',
#   'duit',
#   'haram',
#   'klean',
#   'itikad',
#   'baiknyaa'],
#  ['cpek', 'bayar', 'eeeh', 'tb', 'pesan', 'tolak', 'sistem', 'dak', 'jls'],
#  ['gratis',
#   'ongkir',
#   'bo',
#   'ong',
#   'bayar',
#   'payleater',
#   'vocher',
#   'gratis',
#   'ongkir',
#   'pakai',
#   'payleater',
#   'shoopie',
#   'kaya',
#   'sblm',
#   'atur'],
#  ['beli',
#   'barang',
#   'barang',
#   'beli',
#   'barang',
#   'komplain',
#   'hasil',
#   'suruh',
#   'telepon',
#   'kurir',
#   'tugas',
#   'sedia',
#   'layan',
#   'mmpertanyaka',
#   'status',
#   'barang',
#   'kurir',
#   'ngusut',
#   'barang',
#   'kurir',
#   'ampe',
#   'tahu',
#   'barang',
#   'kurir',
#   'kantor',
#   'ny',
#   'data',
#   'klaim',
#   'kurir',
#   'ikan',
#   'bukti',
#   'tanda',
#   'tanda',
#   'kurir',
#   'telpon',
#   'mnginfokan',
#   'mes',
#   'barang'],
#  ['daftar',
#   'log',
#   'input',
#   'alamat',
#   'provinsi',
#   'klik',
#   'tulisanya',
#   'error',
#   'jaring',
#   'full',
#   'signal',
#   'benci',
#   'aplikasi'],
#  ['jual', 'hoax', 'admin', 'perhati', 'maaf', 'uninstall'],
#  ['drama',
#   'sesuai',
#   'event',
#   'flashle',
#   'sesuai',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'bahasa',
#   'marketing',
#   'knytaan',
#   'pakai',
#   'shpe',
#   'bayar',
#   'bayar',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'akun',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'potong',
#   'ongkir',
#   'akun',
#   'checkout',
#   'potong',
#   'ribu',
#   'ongkir'],
#  ['unduh', 'terinstal', 'pdhl', 'beli', 'pulsa', 'pakai', 'shopeepay'],
#  ['belanja', 'kurir', 'ramah', 'brng', 'dtng', 'kmsn', 'rapi'],
#  ['it',
#   'kerjasama',
#   'costumer',
#   'janji',
#   'untuk',
#   'complain',
#   'nelp',
#   'solusi'],
#  ['ralat',
#   'bintang',
#   'hati',
#   'pesan',
#   'kado',
#   'anak',
#   'pilih',
#   'kirim',
#   'cepat',
#   'nyampe',
#   'nyampe',
#   'pesan',
#   'barang',
#   'nyampe',
#   'neng',
#   'pakai',
#   'cashback',
#   'gin',
#   'pakai'],
#  ['ilangin', 'banner', 'popup', 'kotak', 'kejut', 'ui', 'ngeganggu', 'tahu'],
#  ['penbohong', 'detik', 'harga'],
#  ['maap', 'bintang', 'benerin', 'bug', 'bug', 'belanja', 'maaf', 'yaaa'],
#  ['lemot', 'aplikasi', 'ngefreeze', 'sinyal', 'storage', 'aman', 'huh'],
#  ['maaf',
#   'dana',
#   'total',
#   'belanja',
#   'cancel',
#   'sistem',
#   'terang',
#   'dana',
#   'hasil',
#   'hubung',
#   'customer service',
#   'no',
#   'respon',
#   'dana'],
#  ['pakai',
#   'layan',
#   'melingdungi',
#   'nilai',
#   'hapus',
#   'beli',
#   'olah',
#   'pikir',
#   'belanja',
#   'beli',
#   'sedia',
#   'layan',
#   'belanja',
#   'online',
#   'dsni'],
#  ['marketplace', 'kirim', 'aplikasi', 'bagong'],
#  ['susah', 'bayar', 'saldo'],
#  ['isi', 'saldo', 'sen', 'barang', 'eror', 'eror', 'melulu'],
#  ['beli',
#   'tv',
#   'aoyama',
#   'toko',
#   'mega',
#   'elektronik',
#   'furnitur',
#   'kirim',
#   'barang',
#   'bekas',
#   'tv',
#   'bau',
#   'angus',
#   'layar',
#   'tv',
#   'merah',
#   'merah',
#   'gar',
#   'garis',
#   'timbul',
#   'suara',
#   'nut',
#   'nuuut',
#   'samping',
#   'tv',
#   'celah',
#   'kondisi',
#   'kardus',
#   'barang',
#   'bekas',
#   'heran',
#   'seller',
#   'lolos',
#   'barang',
#   'refund',
#   'rugi',
#   'beli',
#   'market',
#   'placr',
#   'hati',
#   'hati',
#   'belanja',
#   'elektronik',
#   'jangan',
#   'toko',
#   'tsb'],
#  ['iklan', 'handphone', 'main', 'kalah'],
#  ['susah',
#   'dibukak',
#   'aplikasi',
#   'klap',
#   'klip',
#   'berat',
#   'dikit',
#   'dikit',
#   'ramadan',
#   'sale',
#   'aplikasi',
#   'tutup',
#   'belanja',
#   'susah',
#   'ganggu',
#   'males',
#   'shoppe'],
#  ['barang', 'mahal'],
#  ['jangan', 'iklan', 'melulu'],
#  ['tolong',
#   'pilih',
#   'jasa',
#   'kirimm',
#   'toko',
#   'shope',
#   'pilih',
#   'jasa',
#   'kirim',
#   'toopedia',
#   'kirim',
#   'oper',
#   'anteraja',
#   'lambat',
#   'kirimny',
#   'jakarta',
#   'jakarta'],
#  ['tim', 'nilai', 'produk', 'profesional', 'diskriminatif'],
#  ['deploper',
#   'tolong',
#   'lagi',
#   'segi',
#   'pasilitas',
#   'bonus',
#   'koin',
#   'belanja',
#   'koin',
#   'bonus',
#   'harga'],
#  ['hapus', 'aplikasi', 'playstore'],
#  ['sertifikat', 'skill', 'akademi', 'beli', 'muncul'],
#  ['aneh',
#   'pesan',
#   'barang',
#   'kirim',
#   'barang',
#   'gagal',
#   'tolong',
#   'bangett',
#   'tunggu',
#   'bikin',
#   'beratt'],
#  ['toko',
#   'tipu',
#   'sistem',
#   'samain',
#   'kaya',
#   'shopie',
#   'barang',
#   'aplikasi',
#   'update',
#   'instagram',
#   'iklan',
#   'da',
#   'pemberitahuan',
#   'windows',
#   'kttup',
#   'iklan',
#   'ikan',
#   'lapar',
#   'nyamberin'],
#  ['bertanya',
#   'jam',
#   'sms',
#   'hadiah',
#   'juta',
#   'syarat',
#   'isi',
#   'pulsa',
#   'rp',
#   'fotokopi',
#   'nomor',
#   'rekening',
#   'kah'],
#  ['spaylaterku', 'pdhal', 'lunas', 'bayar', 'wktu', 'jengkel'],
#  ['kirim', 'paket', 'sen', 'sistem', 'cod', 'aplikasi', 'hapus', 'tolong'],
#  ['sdah',
#   'donlod',
#   'ajk',
#   'orang',
#   'orgnya',
#   'donlod',
#   'hadiah',
#   'tarik',
#   'hufffff'],
#  ['pesan', 'barang', 'kirim'],
#  ['unduh', 'memori', 'penuh'],
#  ['pelit', 'gratis', 'ongkir', 'sistem', 'cod'],
#  ['barang', 'kirim', 'dana'],
#  ['aplikasi', 'beratbngt', 'kya', 'aplikasi', 'ringan'],
#  ['solusi', 'pengunaan', 'akun', 'beli', 'beda', 'bintang'],
#  ['gapernah',
#   'rumah',
#   'kurir',
#   'ngajak',
#   'ketemu',
#   'tunggu',
#   'capek',
#   'ketemu',
#   'paket',
#   'retur'],
#  ['toko', 'tipu', 'tipu'],
#  ['habis', 'diupdate', 'lemot', 'buanget'],
#  ['habis',
#   'update',
#   'lemot',
#   'sihh',
#   'shoppenya',
#   'lemot',
#   'sihh',
#   'padahalll',
#   'internet',
#   'sayaa',
#   'lancarr',
#   'kendalaaa',
#   'shoppe',
#   'lemot',
#   'ampun',
#   'jugaaa',
#   'update',
#   'seperti',
#   'gin',
#   'tolongg',
#   'benerinnnn',
#   'secepatnyaaa'],
#  ['toko', 'skr', 'toko', 'tipu', 'seleksi', 'toko', 'alien', 'kah', 'nyaman'],
#  ['jasa', 'kirim', 'barang', 'lemot'],
#  ['shope',
#   'suruh',
#   'hapus',
#   'chace',
#   'tetep',
#   'trys',
#   'suruh',
#   'uninstal',
#   'tetep',
#   'bisal',
#   'blnja',
#   'notivikasi',
#   'pdhl',
#   'data',
#   'lancar'],
#  ['pakai', 'voucher', 'pakai', 'shope', 'bayar'],
#  ['jamin',
#   'asli',
#   'perna',
#   'beli',
#   'memory',
#   'baru',
#   'rusak',
#   'live',
#   'chat',
#   'jarang',
#   'balas',
#   'balas'],
#  ['gratis', 'ongkir', 'pakai', 'kurir', 'antar', 'ampun', 'butuh', 'minggu'],
#  ['turun', 'bintang', 'voc', 'dipake', 'kenapa', 'sihh'],
#  ['abiss',
#   'update',
#   'bnyak',
#   'bug',
#   'harga',
#   'login',
#   'juga',
#   'susah',
#   'pdhal',
#   'login',
#   'gagal',
#   'lebih baik',
#   'klok',
#   'voucer',
#   'abiss',
#   'updat',
#   'kecewaw'],
#  ['bintang', 'sertifikat', 'dasboard', 'mnggu', 'pyelesaian', 'latih'],
#  ['sampai',
#   'tnggal',
#   'pesan',
#   'proses',
#   'jual',
#   'layanan',
#   'kredit',
#   'blokir',
#   'pdhl',
#   'ribu',
#   'saldo',
#   'undang',
#   'teman',
#   'barang',
#   'beli'],
#  ['back', 'loadingnya', 'tolong', 'dongg', 'upgrade', 'bikin', 'sebel'],
#  ['ngntd', 'iklan', 'maksa', 'nonton', 'muncul', 'bngsd'],
#  ['susah', 'update', 'jaring', 'pakai', 'wifi'],
#  ['loading', 'melulu', 'pakai', 'wifi'],
#  ['pakai',
#   'tokpet',
#   'bayar',
#   'alfamat',
#   'transaksi',
#   'hasil',
#   'transaksi',
#   'batal',
#   'tokpet',
#   'alas',
#   'promonya',
#   'pakai',
#   'duit',
#   'duit',
#   'ganti',
#   'saldo',
#   'tokpet',
#   'duit',
#   'transfer',
#   'tidak',
#   'rekening',
#   'lucu',
#   'tokpet',
#   'customer',
#   'serficnya',
#   'respon',
#   'duit',
#   'tarik',
#   'rekening',
#   'perlindingan',
#   'konsumen'],
#  ['gratis',
#   'ongkir',
#   'ndk',
#   'dipamerin',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'pas',
#   'pencet',
#   'ndk',
#   'dikleim',
#   'kesel'],
#  ['up', 'date', 'lambat'],
#  ['ganggu',
#   'antri',
#   'jam',
#   'jam',
#   'indomaret',
#   'kasir',
#   'bilang',
#   'shope',
#   'ganguan',
#   'aplikasi',
#   'minat'],
#  ['rating',
#   'gin',
#   'kirim',
#   'barang',
#   'nyaman',
#   'tracking',
#   'kirim',
#   'barang',
#   'tang',
#   'toko',
#   'belah',
#   'free',
#   'ongkir',
#   'fitur',
#   'pilih',
#   'kurir'],
#  ['krna',
#   'ulang',
#   'kedlm',
#   'akun',
#   'malaa',
#   'tulis',
#   'pdhl',
#   'jringn',
#   'handphone',
#   'sayaa',
#   'lancarr',
#   'lancarr',
#   'sulit',
#   'akun',
#   'pribadi',
#   'trimaksih'],
#  ['johri',
#   'kartu',
#   'beli',
#   'latih',
#   'pakai',
#   'akun',
#   'nnti',
#   'insentif',
#   'bntuannya'],
#  ['saldo', 'rekening', 'toko', 'jual', 'jual', 'belanja'],
#  ['sis',
#   'ksih',
#   'bintang',
#   'gara',
#   'order',
#   'cancel',
#   'hayo',
#   'mengaku',
#   'wkwkwkw'],
#  ['pesan',
#   'pesan',
#   'cepat',
#   'pesan',
#   'pesan',
#   'barang',
#   'sampai',
#   'dateng',
#   'tolong',
#   'kepastiannta',
#   'gi',
#   'mna',
#   'bingung'],
#  ['gratis', 'ongkir', 'syarat'],
#  ['alam',
#   'belanja',
#   'status',
#   'seler',
#   'req',
#   'pickup',
#   'kurir',
#   'dateng',
#   'cancel',
#   'pickup',
#   'barang',
#   'siap',
#   'tolong',
#   'sapa',
#   'bohong',
#   'seler',
#   'kurir'],
#  ['unduh', 'ulas', 'bintang', 'keri'],
#  ['jangan', 'spam', 'muncul', 'aplikasi'],
#  ['appnya', 'update'],
#  ['akun', 'hilang', 'login', 'pdahal', 'msih', 'bayar'],
#  ['harga', 'ongkir', 'produk', 'kirim', 'negeri', 'mahal'],
#  ['ngikutin', 'seret', 'user', 'reward', 'gold'],
#  ['kuranggg', 'bagusss', 'update', 'sebal'],
#  ['berat',
#   'baru',
#   'pakai',
#   'tipu',
#   'barang',
#   'kirim',
#   'sipelapak',
#   'maksa',
#   'konfirmasi',
#   'barang',
#   'kirim',
#   'akun',
#   'sipelapak',
#   'sengaja',
#   'dioff',
#   'komplen',
#   'customer service',
#   'nyelesain',
#   'masalah',
#   'bayar',
#   'paylaternya',
#   'rugi',
#   'duit',
#   'suruh',
#   'bayar'],
#  ['kesini', 'pakai', 'cek', 'aut', 'gagal', 'capek'],
#  ['install',
#   'otomatis',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'voucher',
#   'potong',
#   'ribu',
#   'sekarang',
#   'checkout',
#   'barang',
#   'menit',
#   'notif',
#   'akun',
#   'batas',
#   'telusur',
#   'live',
#   'chat',
#   'akun',
#   'batas',
#   'penyalahgunaan',
#   'voucher',
#   'waras',
#   'voucher',
#   'pakai',
#   'akun',
#   'buru',
#   'batas',
#   'kentara',
#   'voucher',
#   'bohong',
#   'pas',
#   'mengisi',
#   'formulir',
#   'tahu',
#   'logout',
#   'tipu'],
#  ['bayar', 'error'],
#  ['aplikasi', 'scar'],
#  ['perbaruin', 'krna', 'skrng', 'aneh'],
#  ['uang', 'hilang', 'beli'],
#  ['layan', 'codnya'],
#  ['cod', 'kaya', 'barang', 'cod'],
#  ['shoppe',
#   'ongkir',
#   'mahal',
#   'pakai',
#   'vhocher',
#   'gratis',
#   'ongkir',
#   'tetep',
#   'mahal',
#   'kirim',
#   'lambat',
#   'sampai',
#   'smpk',
#   'minggu',
#   'dateng',
#   'astaga'],
#  ['maaf',
#   'bilang',
#   'pakai',
#   'kunci',
#   'sidik',
#   'konfirmasi',
#   'bayar',
#   'sya',
#   'bngun',
#   'shoppe',
#   'bayar',
#   'sya',
#   'transaksi',
#   'ggogle',
#   'play',
#   'pdhal',
#   'bayar',
#   'tgihan',
#   'sangatt',
#   'dana',
#   'uninstall',
#   'bikin',
#   'malas',
#   'pke',
#   'shoppe',
#   'bayar'],
#  ['klau',
#   'layan',
#   'tambahin',
#   'baca',
#   'ulas',
#   'beri',
#   'bintang',
#   'layananya',
#   'toko',
#   'online',
#   'belah',
#   'hapus',
#   'toko',
#   'belah'],
#  ['resend',
#   'voucher',
#   'nomor',
#   'aktif',
#   'gubris',
#   'main',
#   'ubah',
#   'snk',
#   'kirim',
#   'email',
#   'ribu',
#   'layang'],
#  ['bintang',
#   'bintang',
#   'iklan',
#   'google',
#   'play',
#   'henti',
#   'aplikasi',
#   'jengkel',
#   'detik',
#   'muncul',
#   'iklan',
#   'tolong',
#   'henti',
#   'kan',
#   'yoooo'],
#  ['lemot', 'pakai'],
#  ['maaf',
#   'bintang',
#   'aplikasi',
#   'aplikasi',
#   'error',
#   'tolong',
#   'tim',
#   'perbaikin',
#   'aplikasi',
#   'sepi',
#   'belanja'],
#  ['susah', 'didownload', 'penywbabnya'],
#  ['biaya',
#   'tangan',
#   'transaksi',
#   'cod',
#   'transaksi',
#   'biaya',
#   'tangan',
#   'paraaaahhh',
#   'cari',
#   'duit',
#   'mendiny',
#   'olshop',
#   'belah',
#   'murah'],
#  ['sendri', 'tolong', 'nyaman'],
#  ['berat', 'belanja', 'lebih baik', 'zilingo'],
#  ['kirim', 'pesan'],
#  ['kirim',
#   'sekian',
#   'belanja',
#   'kendala',
#   'kirim',
#   'hubung',
#   'operator',
#   'ruwet',
#   'pke',
#   'ekspedisi',
#   'cepat',
#   'kaya',
#   'dipake',
#   'sap'],
#  ['engga',
#   'paket',
#   'sya',
#   'cek',
#   'customer service',
#   'xl',
#   'cek',
#   'my',
#   'xl',
#   'cek',
#   'krim',
#   'bukti',
#   'dana',
#   'tolak',
#   'percuma',
#   'member',
#   'platinum',
#   'seperti',
#   'layan'],
#  ['cepat', 'kirim'],
#  ['belanja', 'tipu', 'mengatasnamakan', 'hubung', 'ditindaklanjuti'],
#  ['kirim', 'barang', 'tinggal', 'dc', 'marunda', 'minggu', 'tanda', 'kirim'],
#  ['tinjau', 'proses', 'transaksi', 'bayar', 'kirim', 'barang'],
#  ['kirim',
#   'sabar',
#   'barang',
#   'kirim',
#   'tanggal',
#   'maret',
#   'april',
#   'tangan',
#   'kapok',
#   'layan'],
#  ['muncul', 'iklan', 'web'],
#  ['hadiah',
#   'handphone',
#   'unduh',
#   'tapi',
#   'dpet',
#   'hadiah',
#   'handphone',
#   'beneran',
#   'engga',
#   'yach'],
#  ['banyak',
#   'seller',
#   'tipu',
#   'sen',
#   'kirim',
#   'narik',
#   'refund',
#   'susah',
#   'setngah',
#   'mati'],
#  ['kemarin',
#   'beli',
#   'jilbab',
#   'minggu',
#   'kirim',
#   'batal',
#   'tolak',
#   'nan',
#   'kirim',
#   'shoppe',
#   'batal',
#   'jual',
#   'capek',
#   'tunggu'],
#  ['sngat', 'bantu', 'bantu', 'belanja', 'rumah'],
#  ['pakai',
#   'kouta',
#   'pakai',
#   'wifi',
#   'kouta',
#   'lancar',
#   'nonton',
#   'youtube',
#   'main',
#   'game',
#   'putih',
#   'uninstall',
#   'unduh',
#   'putih',
#   'layar'],
#  ['mentang', 'kontrak', 'uc', 'browser', 'beri', 'iklan', 'kntl'],
#  ['barang',
#   'complain',
#   'customer service',
#   'keluh',
#   'email',
#   'proses',
#   'dana',
#   'makan',
#   'potong',
#   'biaya',
#   'ongkir',
#   'barang',
#   'tangan'],
#  ['oknum',
#   'tipu',
#   'tindaklanjuti',
#   'tipu',
#   'agen',
#   'sedia',
#   'jasa',
#   'up',
#   'dompet',
#   'digitall'],
#  ['diupdate', 'shopeenya', 'tetep'],
#  ['keselll', 'pas', 'ambil', 'donlod'],
#  ['ongkir', 'mahal', 'bang', 'beda', 'kayak', 'murah', 'murah'],
#  ['promo', 'up', 'via', 'tokovedia'],
#  ['narik', 'uang', 'beli', 'pulsa', 'aplikasi', 'gajelas'],
#  ['tolong',
#   'akun',
#   'seller',
#   'tipu',
#   'tipu',
#   'serba',
#   'serbi',
#   'murah',
#   'foto',
#   'handphone',
#   'asli',
#   'kirim',
#   'gurita',
#   'bantu',
#   'blokir',
#   'habis',
#   'duit',
#   'beli',
#   'kirim',
#   'gurita',
#   'aplikasi',
#   'belanja',
#   'no',
#   'indonesia',
#   'sampah'],
#  ['order', 'kirim'],
#  ['rangin', 'harga', 'ongkir'],
#  ['bijak',
#   'nonaktif',
#   'akun',
#   'pdahal',
#   'akun',
#   'habis',
#   'hack',
#   'rugi',
#   'mlaah',
#   'akun',
#   'nonaktif',
#   'alami',
#   'rugi',
#   'bijak',
#   'nonaktif',
#   'akun',
#   'akun',
#   'tipu',
#   'non',
#   'aktif',
#   'mlaah',
#   'akun',
#   'nonaktif'],
#  ['shopie',
#   'food',
#   'oder',
#   'makan',
#   'kompir',
#   'resto',
#   'kompir',
#   'dleper',
#   'jam',
#   'makan',
#   'kujung',
#   'lokasi',
#   'resto',
#   'dleper',
#   'hubungin',
#   'tolerasi',
#   'chensel'],
#  ['aplikasi',
#   'login',
#   'susah',
#   'ampun',
#   'jaring',
#   'penuh',
#   'lebih baik',
#   'toko',
#   'belah',
#   'ribet',
#   'af',
#   'jodoh'],
#  ['monmaaf', 'knapaya', 'update', 'kayak', 'susah', 'kesal'],
#  ['tolong', 'biaya', 'kirim', 'mahal'],
#  ['beli', 'barang', 'kirim'],
#  ['ny', 'unduh', 'aplikasi', 'tapi', 'komen'],
#  ['paksa', 'unduh', 'muncul', 'iklan', 'ganggu'],
#  ['transaksi', 'gagal', 'melulu', 'munggu', 'batal'],
#  ['barang', 'barang', 'harga'],
#  ['maaf', 'barang', 'order', 'harga', 'murah', 'toko', 'online', 'belah'],
#  ['alam',
#   'belanja',
#   'pakai',
#   'nemu',
#   'jual',
#   'amanah',
#   'sblm',
#   'beli',
#   'chat',
#   'sama',
#   'jual',
#   'barang',
#   'siap',
#   'pesan',
#   'dtng',
#   'brng',
#   'sesuai',
#   'produk',
#   'kenapa',
#   'jual',
#   'nakal',
#   'kenapa',
#   'juga',
#   'sblm',
#   'kirim',
#   'it',
#   'konfirmasi',
#   'klau',
#   'barng',
#   'bilang',
#   'pura',
#   'tapi',
#   'setelah',
#   'beli',
#   'prodak',
#   'depa',
#   'tahu',
#   'it',
#   'jual',
#   'nakal',
#   'klau',
#   'jual',
#   'jujur',
#   'amanah'],
#  ['seller', 'seller', 'buku', 'baja', 'aman', 'aman', 'tindak', 'da'],
#  ['kirim', 'order', 'jabodetabek', 'barang', 'tutup', 'bikin', 'langgan'],
#  ['sayang', 'opsi', 'oembayaran', 'link'],
#  ['besarrr',
#   'langgan',
#   'belanja',
#   'neng',
#   'malahhh',
#   'server',
#   'eror',
#   'belanja',
#   'sistem',
#   'bilang',
#   'silah',
#   'langgan',
#   'alhasil',
#   'beli',
#   'tolong',
#   'sistem',
#   'dibenerin',
#   'kapok',
#   'belanja'],
#  ['tahu', 'shopi', 'gi', 'mna', 'tahu', 'murah', 'tahu', 'engga', 'donglot'],
#  ['sen',
#   'barang',
#   'pakai',
#   'vocher',
#   'cashback',
#   'cashback',
#   'tolong',
#   'vocher',
#   'costumer',
#   'real',
#   'jujur',
#   'tipu',
#   'costumer',
#   'vocher',
#   'cashback',
#   'costumer',
#   'belanja',
#   'cashback',
#   'dichat',
#   'tokopediacare',
#   'alesan',
#   'respon',
#   'dibales',
#   'balas',
#   'chat',
#   'costumer',
#   'uninstal',
#   'pakai',
#   'ecomerce',
#   'cashback',
#   'real'],
#  ['login', 'verivikasi', 'wajah'],
#  ['maaf', 'milik', 'kelola', 'aplikasi', 'kesal', 'aplikasi', 'maaf', 'salah'],
#  ['streaming',
#   'video',
#   'iklan',
#   'akhlak',
#   'tahu',
#   'nongol',
#   'aplikasi',
#   'nora'],
#  ['iklan', 'kesini', 'melulu', 'satt'],
#  ['komplain',
#   'tanggap',
#   'tu',
#   'customer service',
#   'lebih baik',
#   'mati',
#   'manajer'],
#  ['bayar', 'cod', 'kaya', 'akun', 'belah', 'cod', 'sebel'],
#  ['unduh',
#   'tipu',
#   'marketing',
#   'unduh',
#   'hasil',
#   'hadiah',
#   'uang',
#   'pas',
#   'unduh'],
#  ['aplikasi',
#   'tipu',
#   'beli',
#   'online',
#   'cash',
#   'back',
#   'trnyata',
#   'ckckck',
#   'lebih baik',
#   'unistall',
#   'pesan',
#   'call',
#   'center',
#   'hubung'],
#  ['medan', 'ganti', 'status', 'ngapain', 'melulu', 'syukur'],
#  ['transaksi', 'tolong', 'bantu'],
#  ['amanah',
#   'niat',
#   'olshop',
#   'buntung',
#   'untung',
#   'please',
#   'toko',
#   'toko',
#   'amanah',
#   'mesen',
#   'sampai',
#   'barang',
#   'nyampe',
#   'kayak',
#   'aplikasi',
#   'tipu',
#   'bohong',
#   'barang',
#   'bareng',
#   'ribet',
#   'sulit',
#   'bayar',
#   'cod',
#   'dana',
#   'belanja',
#   'shoope',
#   'habis',
#   'ribu',
#   'barang',
#   'dateng',
#   'salah',
#   'kirim',
#   'chat',
#   'akun',
#   'resmi',
#   'ngebantu',
#   'miris'],
#  ['sinyal', 'burik'],
#  ['bug', 'game', 'mgestack', 'salah'],
#  ['namamya',
#   'game',
#   'unduh',
#   'lagu',
#   'toko',
#   'ngeselin',
#   'nengtot',
#   'milik',
#   'takut',
#   'sama',
#   'milik'],
#  ['up',
#   'toll',
#   'brizzi',
#   'tanggal',
#   'juni',
#   'saldo',
#   'komplain',
#   'via',
#   'email',
#   'chatting',
#   'harus',
#   'bukti',
#   'saldo',
#   'deposit',
#   'informasi',
#   'saldo',
#   'susah',
#   'update',
#   'saldo',
#   'via',
#   'fitur',
#   'nfc',
#   'handphone',
#   'hasil',
#   'tetep',
#   'gagal',
#   'customer service',
#   'bri',
#   'informasi',
#   'harus',
#   'konfirm',
#   'bri',
#   'komplain',
#   'syarat',
#   'hadeww',
#   'bulan',
#   'sulit',
#   'sdg',
#   'uang',
#   'potong'],
#  ['penasaran',
#   'unduh',
#   'cari',
#   'cari',
#   'barang',
#   'lenkap',
#   'susah',
#   'pencarianya',
#   'mahal',
#   'mudah',
#   'mudah',
#   'uninstall'],
#  ['harga', 'mahal', 'mahal', 'belah', 'lengkap'],
#  ['jaring',
#   'pesan',
#   'da',
#   'pemberitahuan',
#   'suruh',
#   'muat',
#   'ulang',
#   'kranjang',
#   'pemberitahuan',
#   'pesan',
#   'pesan',
#   'batalkn',
#   'pesan',
#   'bles',
#   'toko',
#   'harus',
#   'bayar'],
#  ['beli',
#   'pulsa',
#   'paket',
#   'data',
#   'suruh',
#   'tunggu',
#   'suruh',
#   'hubung',
#   'potong',
#   'shopepay',
#   'paket',
#   'data',
#   'ajar',
#   'daring',
#   'tangan',
#   'lebih baik',
#   'toko',
#   'belah'],
#  ['ongkir', 'mahal'],
#  ['sulit',
#   'jual',
#   'beli',
#   'main',
#   'iklan',
#   'produk',
#   'muncul',
#   'jual',
#   'nol',
#   'jual',
#   'beli',
#   'saldo',
#   'bukaiklan',
#   'kacau',
#   'ongkir',
#   'sistem',
#   'sesuai',
#   'real',
#   'kurir',
#   'tarif',
#   'reguler',
#   'kota',
#   'kg',
#   'tera',
#   'ongkir',
#   'sistem',
#   'beli',
#   'sayang',
#   'produk',
#   'negeri',
#   'banding',
#   'gampang',
#   'jual',
#   'maaf',
#   'komen',
#   'ngenakin',
#   'ngeluarin',
#   'mual',
#   'hati'],
#  ['belanja',
#   'emas',
#   'butuh',
#   'dilazada',
#   'ongkir',
#   'murah',
#   'kirim',
#   'dm',
#   'toko',
#   'sebentar',
#   'pas',
#   'besok',
#   'kemas',
#   'kemas',
#   'tunggu',
#   'kirim'],
#  ['murah', 'rekomen', 'sh', 'pee', 'aplikasi', 'lemot', 'bikin', 'males'],
#  ['nongol', 'iklan', 'open', 'playstore'],
#  ['uang',
#   'refund',
#   'dana',
#   'dana',
#   'dapak',
#   'transaksi',
#   'kode',
#   'otp',
#   'nomer',
#   'handphone',
#   'hangus',
#   'aktif'],
#  ['aplikasi', 'iklan', 'cod', 'bayar', 'cod', 'aplikasi', 'bagettttttt'],
#  ['bayar', 'rumah'],
#  ['unduh', 'browser', 'tersesat', 'bintang', 'milih', 'bintang', 'nol'],
#  ['meh',
#   'promo',
#   'kirim',
#   'ribet',
#   'sesimple',
#   'biaya',
#   'receh',
#   'potong',
#   'biaya',
#   'admin',
#   'toko',
#   'mahal'],
#  ['ngajuin', 'spaylater', 'pernah', 'acc', 'belanja', 'dsni'],
#  ['pesan', 'batal'],
#  ['tokony', 'tipu'],
#  ['lagi',
#   'cari',
#   'barang',
#   'lagi',
#   'beranda',
#   'males',
#   'cari',
#   'brang',
#   'klik',
#   'juga',
#   'susah'],
#  ['update',
#   'ganti',
#   'nomor',
#   'handphone',
#   'terpkai',
#   'nomor',
#   'akun',
#   'akun',
#   'pernh',
#   'transaksi',
#   'customer service',
#   'bikin',
#   'aplikasi',
#   'kelola',
#   'ganti',
#   'nomor',
#   'tim',
#   'itnya',
#   'sekolah'],
#  ['ny', 'voucher', 'stlah', 'bnar', 'ksh', 'informasi', 'bnar'],
#  ['beli', 'barang', 'kirim'],
#  ['tolong',
#   'tahu',
#   'jual',
#   'harap',
#   'catat',
#   'no',
#   'telepon',
#   'whatsapp',
#   'bayar',
#   'kirim',
#   'no',
#   'telepon',
#   'whatsapp',
#   'kirim',
#   'cepat',
#   'sen',
#   'bom',
#   'kirim',
#   'chat',
#   'balas',
#   'bayar'],
#  ['pesan',
#   'barang',
#   'tanggal',
#   'kecawa',
#   'pakai',
#   'profesional',
#   'tindak',
#   'lemah'],
#  ['jual', 'jual', 'nakal', 'tanggung', 'lapor', 'bnyak', 'tipu'],
#  ['promo', 'ngumpulin', 'stamp', 'hoax', 'kumpul', 'eror'],
#  ['hati',
#   'ber',
#   'belanja',
#   'toko',
#   'jual',
#   'sesuai',
#   'posting',
#   'murah',
#   'barang',
#   'sesuai',
#   'butuh',
#   'hambur',
#   'uang',
#   'uang',
#   'barang',
#   'sesuai',
#   'butuh'],
#  ['iklan', 'kamu', 'ganggu'],
#  ['bayar',
#   'laternya',
#   'nyekek',
#   'biaya',
#   'layan',
#   'uninstal',
#   'biarin',
#   'ngejual'],
#  ['aplikasi', 'cod'],
#  ['event',
#   'php',
#   'sesuai',
#   'deskripsi',
#   'event',
#   'ongkir',
#   'mahal',
#   'shopeepay',
#   'haduh',
#   'hancur'],
#  ['aplikasi',
#   'seller',
#   'curang',
#   'aman',
#   'gakan',
#   'ciduk',
#   'buyer',
#   'bukti',
#   'customer service',
#   'buyer',
#   'kapok',
#   'komplain',
#   'customer service',
#   'dana',
#   'refund',
#   'juga',
#   'dikembaliin',
#   'cash',
#   'cetek',
#   'beuh',
#   'pakai',
#   'voucher',
#   'pakai',
#   'kadaluarsa',
#   'buyer',
#   'pakai',
#   'vc',
#   'hangus',
#   'duit',
#   'milik',
#   'rajin',
#   'bayar',
#   'rating',
#   'seller',
#   'buyer'],
#  ['toko', 'tipu', 'rugi', 'langgan'],
#  ['maaf', 'bintang', 'login', 'kendala', 'server', 'pakai'],
#  ['laen',
#   'bikin',
#   'acara',
#   'televisi',
#   'indonesia',
#   'bentur',
#   'timnas',
#   'indonesia',
#   'ngalah',
#   'negara',
#   'main',
#   'lahir',
#   'bangga',
#   'banggain',
#   'nasionalis',
#   'bangsa'],
#  ['sore',
#   'ijin',
#   'proses',
#   'tari',
#   'reksa',
#   'dana',
#   'rekening',
#   'proses',
#   'tari',
#   'jam',
#   'konfirmasi'],
#  ['bayar',
#   'kartu',
#   'kredit',
#   'bri',
#   'bayar',
#   'bca',
#   'virtual',
#   'acount',
#   'bayar',
#   'uap',
#   'eror',
#   'cek',
#   'sya',
#   'cek',
#   'bayar',
#   'hasil'],
#  ['aplikasi', 'ganggu', 'gala', 'sampai', 'iklan', 'dimanamana'],
#  ['proses', 'jamgan', 'kesel', 'nunggunya'],
#  ['cicil',
#   'home',
#   'credit',
#   'susah',
#   'gtu',
#   'layar',
#   'hank',
#   'putih',
#   'verifikasi',
#   'ktp',
#   'bantu',
#   'konfrimasinya'],
#  ['tolong',
#   'admin',
#   'bantu',
#   'akun',
#   'pakai',
#   'untuak',
#   'jual',
#   'chip',
#   'domino',
#   'akun',
#   'asli',
#   'ramadhan',
#   'junaidi',
#   'akun',
#   'pakai',
#   'nomor',
#   'handphone',
#   'pakai',
#   'tolong',
#   'admin',
#   'bantu',
#   'kirim',
#   'email',
#   'respon'],
#  ['praktis', 'klu', 'butuh'],
#  ['cod', 'wilayah', 'sja', 'pakai', 'bank', 'bank', 'kecewaa', 'njir'],
#  ['istal', 'aplikasi', 'jellleeeeeekk', 'pke'],
#  ['aplikasi',
#   'najis',
#   'sen',
#   'gift',
#   'cards',
#   'roblox',
#   'kirim',
#   'grabexpress',
#   'tunggu',
#   'minggu',
#   'dateng'],
#  ['gabia', 'update'],
#  ['login', 'akun', 'akun', 'kode', 'otp'],
#  ['update', 'jalan', 'jalan', 'ulang'],
#  ['belanja',
#   'online',
#   'barang',
#   'datang',
#   'ecek',
#   'salah',
#   'kirim',
#   'sesuai',
#   'pesan',
#   'benah',
#   'shpee',
#   'rugi'],
#  ['sekrang', 'voucher', 'free', 'ongkir', 'tdak'],
#  ['kesel', 'nonton', 'playstore', 'puasa', 'bikin', 'ngamuk'],
#  ['order',
#   'batal',
#   'otomatis',
#   'tangguh',
#   'hak',
#   'rugi',
#   'posisi',
#   'telepon',
#   'call',
#   'center',
#   'cantum',
#   'dana',
#   'potong',
#   'jngn',
#   'pending',
#   'hak'],
#  ['toko',
#   'penguna',
#   'hadiah',
#   'ambil',
#   'klik',
#   'order',
#   'batal',
#   'otomatis',
#   'jngn',
#   'ambil',
#   'produk',
#   'rupiah',
#   'sebel'],
#  ['kebnyakan',
#   'update',
#   'minggu',
#   'update',
#   'lemot',
#   'ampun',
#   'cari',
#   'barang',
#   'tunggu',
#   'menit',
#   'barang'],
#  ['tolong', 'blokir', 'akun', 'bot'],
#  ['unduh', 'lagu', 'spam', 'iklan', 'klen', 'muncul'],
#  ['barang', 'isi', 'barang', 'sesuai', 'pesan'],
#  ['licik',
#   'bnget',
#   'tunggu',
#   'sore',
#   'sampai',
#   'jam',
#   'pas',
#   'jam',
#   'ngeleg',
#   'pas',
#   'iphone',
#   'habis',
#   'bikin',
#   'ngantuk'],
#  ['kirim',
#   'gratis',
#   'indonesia',
#   'beli',
#   'handphone',
#   'papua',
#   'barat',
#   'kirim',
#   'paket'],
#  ['sesuai', 'janji', 'cicil', 'kartu', 'kredit', 'deteksi', 'bank', 'isi'],
#  ['check',
#   'out',
#   'ggal',
#   'melulu',
#   'sblmnya',
#   'sekarang',
#   'check',
#   'out',
#   'gbsa'],
#  ['semalem', 'updet', 'gambar', 'produk', 'updet', 'eror', 'shope'],
#  ['belanja', 'spesial', 'ramadan'],
#  ['akun',
#   'bajak',
#   'sen',
#   'paket',
#   'ngirim',
#   'paket',
#   'nama',
#   'akun',
#   'aplikasi'],
#  ['belanja', 'onlen', 'alhamdulilah', 'kirim', 'ny', 'selalu', 'lancar'],
#  ['toko', 'merespon', 'suruh', 'tunggu', 'bayar'],
#  ['kacau',
#   'jamin',
#   'asli',
#   'iklan',
#   'beli',
#   'ipad',
#   'mini',
#   'stuck',
#   'logo',
#   'apple'],
#  ['aplikasi',
#   'bnr',
#   'belanja',
#   'pesan',
#   'bayar',
#   'batal',
#   'alas',
#   'customer service',
#   'code',
#   'unik',
#   'digit',
#   'salah',
#   'pdhl',
#   'code',
#   'unik',
#   'copy',
#   'paste',
#   'aplikasi',
#   'duit',
#   'pakai',
#   'alas',
#   'akal'],
#  ['transaksi', 'batal', 'hapus'],
#  ['transfer',
#   'bank',
#   'manual',
#   'rek',
#   'bank',
#   'beli',
#   'bca',
#   'mandiri',
#   'layan',
#   'transakaksi',
#   'bank',
#   'brilink',
#   'transfer',
#   'beda',
#   'bank',
#   'biaya',
#   'mahal',
#   'harap',
#   'bantu'],
#  ['salah', 'koneksi'],
#  ['aplikasi', 'iklan', 'risi', 'sepah', 'iklan'],
#  ['susah', 'beli', 'pulsa', 'bayar', 'pakai', 'shopeepay'],
#  ['barang', 'sesuai', 'deskripsi'],
#  ['maap', 'editing', 'mesan', 'barang', 'kemarin', 'developer'],
#  ['niat', 'sale', 'siih', 'detik', 'barang', 'habis', 'aneeh'],
#  ['cashback', 'seret'],
#  ['lebih baik',
#   'pakai',
#   'shope',
#   'murah',
#   'kirim',
#   'cepat',
#   'mahal',
#   'kirim',
#   'pakai',
#   'ninja',
#   'beet',
#   'barang',
#   'layak',
#   'pakai'],
#  ['update', 'henti', 'jalan', 'sinya', 'wifi', 'kencang'],
#  ['unduh', 'sampai', 'unduh'],
#  ['beli',
#   'octo',
#   'kliks',
#   'tanggal',
#   'agustus',
#   'skitar',
#   'jam',
#   'beli',
#   'hasil',
#   'status',
#   'transaksi',
#   'kosong',
#   'email',
#   'transaksi',
#   'sukses',
#   'saldo',
#   'barang',
#   'kirim',
#   'jual',
#   'informasi',
#   'jual',
#   'nomer',
#   'invoice'],
#  ['aplikasi',
#   'jengkel',
#   'update',
#   'ngabisin',
#   'kuota',
#   'update',
#   'kayak',
#   'minum',
#   'obat'],
#  ['tinggal',
#   'uninstal',
#   'handphone',
#   'butut',
#   'aplikasi',
#   'asa',
#   'beraaaaaat',
#   'belanja',
#   'aplikasi',
#   'susah',
#   'update',
#   'lancar',
#   'nyaman',
#   'belanja',
#   'via',
#   'pindah',
#   'lah',
#   'mudah',
#   'operasi'],
#  ['alas', 'kirim', 'tipu'],
#  ['jual', 'rugi', 'bintang', 'paksa', 'rubah', 'bintang', 'rugi', 'jual'],
#  ['check', 'out', 'dibatalin', 'pakai', 'promo', 'lha', 'promo'],
#  ['login', 'susah', 'susah', 'tolong', 'dibenahin'],
#  ['gilir',
#   'paylater',
#   'bayar',
#   'saldo',
#   'hilang',
#   'hadeh',
#   'gila',
#   'gondrong',
#   'dekil'],
#  ['masukkan',
#   'barang',
#   'keranjang',
#   'beli',
#   'suruh',
#   'log',
#   'out',
#   'log',
#   'maksutnya'],
#  ['malas',
#   'verifikasi',
#   'suruh',
#   'kesini',
#   'ehh',
#   'tahu',
#   'tahu',
#   'tolong',
#   'costumer',
#   'bukin',
#   'ribet',
#   'niat',
#   'belanja',
#   'ehh',
#   'pusing',
#   'verifikasi',
#   'bikin',
#   'ribeeeeeeeeettttt',
#   'tauuuuuuuuu'],
#  ['kadang', 'barang', 'beli', 'sesuai'],
#  ['tari', 'dana', 'shopepay', 'tunggu', 'sampai', 'kualitas', 'mu'],
#  ['sengaja',
#   'bintang',
#   'baca',
#   'kembang',
#   'upload',
#   'video',
#   'mudah',
#   'tetangga',
#   'belah'],
#  ['layan', 'pinjem', 'bagaimana', 'blz'],
#  ['verifikasi', 'data', 'macet', 'lagi', 'aplikasi'],
#  ['akun', 'nonaktif', 'angin', 'hujan'],
#  ['aplikasi', 'narik', 'uang', 'kredit', 'aplikasi'],
#  ['fitur',
#   'beri',
#   'harga',
#   'jual',
#   'handphone',
#   'tokopedianya',
#   'murah',
#   'handphone',
#   'jt',
#   'jual',
#   'ribu',
#   'kondisi',
#   'bilang',
#   'like',
#   'new'],
#  ['pakai',
#   'aplikasi',
#   'nyaman',
#   'kendala',
#   'enjoy',
#   'kayak',
#   'gin',
#   'toko',
#   'muncul',
#   'tulis',
#   'unduh',
#   'proses',
#   'tunggu',
#   'muncul',
#   'tulis',
#   'error',
#   'rumah',
#   'tunggu',
#   'sia',
#   'daritadi',
#   'kupon',
#   'tolong',
#   'developer',
#   'tanggap',
#   'ulas',
#   'pindah',
#   'bukti',
#   'screenshot',
#   'care'],
#  ['bintang',
#   'klok',
#   'ngecewain',
#   'ganti',
#   'bintang',
#   'dh',
#   'banyk',
#   'yng',
#   'kmen',
#   'jlk'],
#  ['please',
#   'tolong',
#   'bayar',
#   'online',
#   'akun',
#   'belanja',
#   'mudah',
#   'bayar',
#   'bayar',
#   'online',
#   'pakai',
#   'tingkat',
#   'bintang',
#   'bintang'],
#  ['bayar',
#   'pesan',
#   'tahu',
#   'tahu',
#   'dana',
#   'hilang',
#   'bukti',
#   'transfer',
#   'respond',
#   'bukti',
#   'pesan',
#   'kirim',
#   'tapi',
#   'proses',
#   'aplikasi'],
#  ['etrt', 'banking', 'bayar', 'ketemu', 'bingung', 'aneh', 'bayar'],
#  ['update', 'ngabisin', 'kuota'],
#  ['blokir', 'akun'],
#  ['pencet',
#   'langung',
#   'playsors',
#   'pas',
#   'main',
#   'game',
#   'iklan',
#   'login',
#   'mut',
#   'main',
#   'game'],
#  ['aplikasi', 'error', 'rating', 'ulas'],
#  ['dompetdibekukan', 'susah', 'bantuanya'],
#  ['barang', 'jarang', 'update', 'lacak', 'tolong', 'ikan', 'polsek'],
#  ['pesan', 'ngembaliin', 'uang', 'susah', 'barang', 'retur'],
#  ['tolong',
#   'adil',
#   'jual',
#   'utama',
#   'lagi',
#   'sllu',
#   'beli',
#   'menang',
#   'jual',
#   'bnar'],
#  ['voucher', 'eror'],
#  ['beri',
#   'promo',
#   'bayar',
#   'tagih',
#   'kaya',
#   'niat',
#   'pas',
#   'jam',
#   'transaksi',
#   'ksalahan',
#   'capcay',
#   'dahhhhh',
#   'pakai',
#   'promo',
#   'lanjar',
#   'zayaaaaaa'],
#  ['lemot',
#   'banding',
#   'laen',
#   'cek',
#   'out',
#   'transfer',
#   'duit',
#   'barang',
#   'pes',
#   'hilang',
#   'aplikasi',
#   'hilang',
#   'duit'],
#  ['unicorn', 'tukang', 'sunat', 'dana', 'refund'],
#  ['mahel', 'ongkir', 'harga', 'barang', 'jabodetabek', 'ntb'],
#  ['ulas',
#   'konsumen',
#   'isi',
#   'kirim',
#   'barang',
#   'bayar',
#   'status',
#   'tunggu',
#   'barang',
#   'indonesia',
#   'jual',
#   'barang',
#   'flash',
#   'sale',
#   'kayak',
#   'keong',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'toko',
#   'belah',
#   'jamin'],
#  ['nomor',
#   'handphone',
#   'login',
#   'aktif',
#   'hubung',
#   'tokpedia',
#   'tanggap',
#   'solusi'],
#  ['tolong',
#   'cepat',
#   'follow',
#   'up',
#   'data',
#   'serfifikat',
#   'muncul',
#   'lambat',
#   'samaa',
#   'tanggung',
#   'update',
#   'kelas',
#   'beli',
#   'beda',
#   'nama',
#   'kelas',
#   'akibat',
#   'update'],
#  ['hati',
#   'hati',
#   'guysss',
#   'banyak',
#   'order',
#   'fiktif',
#   'pernah',
#   'pesan',
#   'brng',
#   'dtng',
#   'alamat',
#   'lngkap',
#   'rumah',
#   'nma',
#   'nomor',
#   'telepon',
#   'dta',
#   'jebol',
#   'guysss',
#   'tipu',
#   'bolak',
#   'kurir',
#   'order',
#   'fiktif',
#   'tolak',
#   'skrng',
#   'uang',
#   'foto',
#   'ktp',
#   'buku',
#   'tabung',
#   'nomer',
#   'rekening',
#   'kasihh',
#   'data',
#   'jebol',
#   'data',
#   'ktp',
#   'buku',
#   'rekening',
#   'hati',
#   'hati'],
#  ['please',
#   'flash',
#   'sale',
#   'handphone',
#   'pakai',
#   'bot',
#   'tolong',
#   'handphone'],
#  ['kasi',
#   'bintang',
#   'tu',
#   'sinyal',
#   'tu',
#   'muter',
#   'alhasil',
#   'sush',
#   'beli',
#   'shoppe'],
#  ['hora', 'niat', 'promo', 'gratis', 'ongkir', 'kaya', 'ongkir', 'gratis'],
#  ['game',
#   'capit',
#   'jalan',
#   'terang',
#   'ganggu',
#   'jaring',
#   'game',
#   'lancar',
#   'pesan',
#   'batal',
#   'checkout'],
#  ['game',
#   'tanam',
#   'pohon',
#   'sya',
#   'goyang',
#   'pohon',
#   'teman',
#   'hitung',
#   'point',
#   'ajja',
#   'hitung',
#   'otomatis',
#   'customer',
#   'kadang',
#   'solusi',
#   'beri',
#   'solusi',
#   'tba',
#   'chatnya',
#   'hilang',
#   'tolong',
#   'sya',
#   'langgan',
#   'setia',
#   'sekarang',
#   'nyaman',
#   'belanja',
#   'nama',
#   'tingkat'],
#  ['tolong',
#   'tagihin',
#   'lunas',
#   'tagih',
#   'hutang',
#   'tagih',
#   'rincian',
#   'beli',
#   'total',
#   'tagih',
#   'bayar',
#   'tolong',
#   'aktifin',
#   'bayar',
#   'lunas',
#   'bayar'],
#  ['minus',
#   'pilih',
#   'minus',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'masih',
#   'pakai',
#   'pilih',
#   'voucher',
#   'order',
#   'murah',
#   'untuk',
#   'sesuai',
#   'ongkir'],
#  ['transaksi',
#   'belanja',
#   'bayar',
#   'briva',
#   'bri',
#   'bayar',
#   'toko',
#   'beda',
#   'transaksi',
#   'otomatis',
#   'uang',
#   'transfer',
#   'dompet',
#   'dana',
#   'beku',
#   'alas',
#   'kirim',
#   'bukti',
#   'transfer',
#   'valid',
#   'aju',
#   'komplain',
#   'uang',
#   'pelang',
#   'tahan',
#   'sulit',
#   'rugi'],
#  ['pakai',
#   'sarang',
#   'samun',
#   'aplikasi',
#   'tipu',
#   'retur',
#   'seller',
#   'selisih',
#   'milih',
#   'hapus',
#   'akun',
#   'permanen',
#   'review',
#   'data',
#   'pribadi',
#   'disalahgunakan'],
#  ['bobol', 'pasword', 'aman', 'data'],
#  ['mahal', 'mahal', 'bok'],
#  ['aplikasi', 'muncul', 'gambar', 'jual', 'produk', 'sinyal'],
#  ['sesal', 'beli', 'latih', 'latih', 'sertefikat', 'kartu'],
#  ['benah',
#   'menu',
#   'feed',
#   'scroll',
#   'produk',
#   'klik',
#   'back',
#   'refresh',
#   'sengaja',
#   'malas',
#   'feed'],
#  ['diupdate', 'bug', 'gratis', 'ongkir', 'kupon', 'hitam', 'barang'],
#  ['aplikasi', 'eror', 'akun', 'blokir', 'alas'],
#  ['aplikasi',
#   'bikin',
#   'handphone',
#   'lemot',
#   'geser',
#   'lyr',
#   'handphone',
#   'jam',
#   'jalan',
#   'bohong'],
#  ['benci',
#   'guwe',
#   'beli',
#   'barang',
#   'ditokopedia',
#   'barang',
#   'nga',
#   'sesuai',
#   'tipu',
#   'huuu'],
#  ['transfer', 'kirim', 'bukti', 'pmbayaran'],
#  ['toko', 'keranjang', 'jaring', 'eror', 'jaring', 'sinyal', 'tolong', 'toko'],
#  ['tolong',
#   'toko',
#   'toko',
#   'jual',
#   'barang',
#   'harga',
#   'sesuai',
#   'barang',
#   'jual',
#   'masak',
#   'ngirim',
#   'beda',
#   'deskripsi',
#   'produk',
#   'kalok',
#   'toko',
#   'tipu',
#   'tolong',
#   'gampangin',
#   'ngelaporin',
#   'lngsung',
#   'sekian',
#   'saran',
#   'maksih'],
#  ['bolak',
#   'daftar',
#   'payletter',
#   'gagal',
#   'mala',
#   'tolak',
#   'seperti',
#   'aplikasi',
#   'sebelh',
#   'beli',
#   'barang',
#   'skarang',
#   'bayar',
#   'mala',
#   'cacat'],
#  ['bintang',
#   'aplikasi',
#   'proses',
#   'transaksi',
#   'mala',
#   'pesan',
#   'batal',
#   'otomatis',
#   'sistem',
#   'langgar',
#   'penuh',
#   'syarat',
#   'indikasi',
#   'manipulasi',
#   'transaksi',
#   'aplikasi',
#   'bilang',
#   'manipulasi',
#   'transaksi'],
#  ['aplikasi',
#   'traktir',
#   'pas',
#   'pilih',
#   'salah',
#   'prodak',
#   'pas',
#   'bayar',
#   'uang',
#   'tolak',
#   'aplikasi',
#   'ajar',
#   'papa',
#   'hapus',
#   'aplikasi',
#   'belanja',
#   'online',
#   'aplikasi',
#   'mudah'],
#  ['habis', 'login', 'username', 'bayar', 'saldo', 'jt'],
#  ['habis', 'update', 'semalem', 'harga', 'barang', 'nol'],
#  ['aplikasi',
#   'ngerusak',
#   'unduh',
#   'aplikasi',
#   'handphone',
#   'macet',
#   'pencet',
#   'aplikasi',
#   'ngerusak'],
#  ['turun',
#   'bintang',
#   'cashback',
#   'point',
#   'notabene',
#   'transaksi',
#   'beli',
#   'jt',
#   'point',
#   'cashback',
#   'pakai',
#   'bayar',
#   'aneh'],
#  ['update',
#   'aplikasi',
#   'berat',
#   'proses',
#   'bayar',
#   'koneksi',
#   'timeout',
#   'melulu',
#   'jaring',
#   'update',
#   'lancar'],
#  ['jual', 'tipu', 'hati', 'hati'],
#  ['bikin',
#   'jasa',
#   'kirim',
#   'shope',
#   'exp',
#   'stndar',
#   'kualitas',
#   'mutu',
#   'alam',
#   'kantor',
#   'masih',
#   'indonesia',
#   'serakah',
#   'marketplace',
#   'jasa',
#   'kirim',
#   'biarin',
#   'alam',
#   'cabang'],
#  ['ongkir', 'mahal', 'pdhl', 'pakai', 'voucher', 'gratis', 'ongkir', 'tolong'],
#  ['layan',
#   'kostumer',
#   'commerce',
#   'alami',
#   'pesan',
#   'batal',
#   'complain',
#   'respon',
#   'main',
#   'batal',
#   'pesan',
#   'hancur',
#   'commerce'],
#  ['kenapa',
#   'banyak',
#   'iklan',
#   'aplikasi',
#   'iklan',
#   'shope',
#   'pdhl',
#   'dimatiin',
#   'notifnya'],
#  ['toloonngg',
#   'mb',
#   'rangin',
#   'mb',
#   'unduh',
#   'aplikasi',
#   'mb',
#   'nggk',
#   'unduh',
#   'aplikasi',
#   'kan',
#   'mb'],
#  ['akun',
#   'tipu',
#   'banned',
#   'report',
#   'ramai',
#   'jual',
#   'nakal',
#   'tipu',
#   'kayak',
#   'banned',
#   'respon'],
#  ['malas', 'pakai', 'toko', 'jujur'],
#  ['potensi',
#   'cashback',
#   'kdng',
#   'menang',
#   'kadang',
#   'aplikasi',
#   'lebih baik',
#   'hancur',
#   'ganti'],
#  ['kash',
#   'bintang',
#   'stela',
#   'barang',
#   'nti',
#   'nyampe',
#   'kash',
#   'ful',
#   'bintang',
#   'klik',
#   'tahu',
#   'brang',
#   'kya'],
#  ['lambat', 'koneksi', 'normal'],
#  ['kirain',
#   'beneran',
#   'undang',
#   'ribu',
#   'sempurna',
#   'capek',
#   'ngundang',
#   'pakai',
#   'ladaza',
#   'sesuai',
#   'harap',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'bukti',
#   'undang',
#   'bberapa',
#   'bayar'],
#  ['mudah', 'akses'],
#  ['murah', 'murah', 'shaa', 'allah', 'pindah', 'aplikasi', 'belanja'],
#  ['gratis', 'ongkir'],
#  ['promo', 'dipake'],
#  ['bhaya',
#   'belanja',
#   'sini',
#   'kmrin',
#   'belanja',
#   'truss',
#   'barang',
#   'beli',
#   'kosong',
#   'batal',
#   'tapi',
#   'uang',
#   'kmblikan',
#   'tipu'],
#  ['jual',
#   'mistery',
#   'box',
#   'tipu',
#   'tolong',
#   'tindak',
#   'seller',
#   'sperti',
#   'rugi',
#   'konsumen'],
#  ['bintang',
#   'sekarang',
#   'bintang',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'ongkir',
#   'drpd',
#   'barang',
#   'layan',
#   'hemat',
#   'engga',
#   'bikin',
#   'cekik',
#   'beli',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'tolong',
#   'layan',
#   'setia',
#   'gin',
#   'pindah',
#   'claim',
#   'ongkir',
#   'bohong',
#   'mahal',
#   'beli',
#   'kota',
#   'desa',
#   'juga',
#   'beli',
#   'terusin',
#   'sepi'],
#  ['belanja',
#   'pesan',
#   'proses',
#   'gagal',
#   'pengirimannnnnnn',
#   'ulang',
#   'minggu',
#   'huhhh',
#   'belanja',
#   'pindah',
#   'belah',
#   'pakek',
#   'kirim',
#   'cepat',
#   'hadehhh',
#   'bagaimana'],
#  ['selamaa',
#   'belanja',
#   'online',
#   'shoppe',
#   'ongkir',
#   'mahal',
#   'voucher',
#   'gratis',
#   'ongkirnyaa',
#   'bantu',
#   'ngurangi',
#   'ongkir',
#   'mahal',
#   'ituu',
#   'sekarang',
#   'mengcapekk',
#   'pot',
#   'ongkir',
#   'sdkit',
#   'koin',
#   'didpt',
#   'sekarang',
#   'doankk',
#   'fix',
#   'shoppe',
#   'asyikk',
#   'dluu'],
#  ['habis',
#   'update',
#   'gambar',
#   'ayam',
#   'telur',
#   'sampai',
#   'pelihara',
#   'server',
#   'berapa'],
#  ['cuman', 'login', 'ribet', 'main', 'puzzle', 'geser', 'puzzle'],
#  ['seller', 'tipu', 'sangsi'],
#  ['uang',
#   'barang',
#   'tercancel',
#   'bulan',
#   'saldo',
#   'kartu',
#   'kredit',
#   'hadeh',
#   'tahu',
#   'pakai',
#   'aplikasi',
#   'belah'],
#  ['aneh',
#   'bett',
#   'bayar',
#   'spaylater',
#   'jatuh',
#   'tempo',
#   'ditelponin',
#   'terus',
#   'aneh',
#   'anehh'],
#  ['sekarang', 'dicancel', 'minggu', 'paketanya', 'dateng'],
#  ['sen',
#   'bom',
#   'sampai',
#   'sampai',
#   'snen',
#   'agustus',
#   'ampe',
#   'kirim',
#   'cepat',
#   'tahu',
#   'gin',
#   'beli',
#   'lebih baik',
#   'kirim',
#   'cepat',
#   'bicara',
#   'kirim',
#   'cepat',
#   'percaya',
#   'kapoook',
#   'belanja',
#   'tolong',
#   'mial',
#   'gx',
#   'niat',
#   'jual',
#   'gx',
#   'jual',
#   'duit',
#   'tollongnminta',
#   'balik',
#   'barang',
#   'gx'],
#  ['dukung',
#   'seller',
#   'seller',
#   'rubah',
#   'harga',
#   'produk',
#   'periksa',
#   'dikit',
#   'dikit',
#   'produk',
#   'periksa',
#   'peeiksa',
#   'sebentar',
#   'produk',
#   'periksa',
#   'sampai',
#   'jam',
#   'praktis',
#   'seller',
#   'lebih baik',
#   'cepat',
#   'cepat',
#   'rubah',
#   'atur',
#   'usaha',
#   'seller',
#   'pindah',
#   'seller',
#   'mudah',
#   'malah',
#   'sulit',
#   'potong',
#   'biaya',
#   'admin',
#   'kenapa',
#   'seller',
#   'malah',
#   'selalu',
#   'sulit'],
#  ['aplikasi',
#   'burik',
#   'nc',
#   'iklan',
#   'mengangu',
#   'link',
#   'ajha',
#   'nga',
#   'lakuyah',
#   'segitunya',
#   'pamer',
#   'iklan',
#   'garis',
#   'onkir',
#   'gratis',
#   'onkir'],
#  ['transaksi',
#   'cashback',
#   'batal',
#   'tuduh',
#   'curang',
#   'curang',
#   'tahu',
#   'curang',
#   'niat',
#   'cashback',
#   'promo',
#   'bela',
#   'bain',
#   'belanja',
#   'cashback',
#   'hapus',
#   'bayar',
#   'transaksi',
#   'cashback',
#   'batal'],
#  ['tulis',
#   'uang',
#   'barang',
#   'asli',
#   'beli',
#   'oli',
#   'mesin',
#   'harga',
#   'ribu',
#   'kirim',
#   'oli',
#   'samping',
#   'harga',
#   'ribu',
#   'uang',
#   'ribet',
#   'alesan'],
#  ['pertayaan',
#   'barang',
#   'beli',
#   'bayar',
#   'pakai',
#   'uang',
#   'pakai',
#   'kartu',
#   'tolong',
#   'jwab',
#   'kasing',
#   'bintang',
#   'aceh'],
#  ['ganggu', 'bayar', 'paket', 'data', 'muncul', 'bayar'],
#  ['payleter',
#   'hilang',
#   'bingung',
#   'bayar',
#   'tagih',
#   'telepon',
#   'transfer',
#   'jaman',
#   'sekarang',
#   'banyak',
#   'tipu',
#   'tolong',
#   'solusi'],
#  ['belanja',
#   'elfania',
#   'sungguh',
#   'ribet',
#   'embel',
#   'discon',
#   'voucher',
#   'ujung',
#   'hitung',
#   'hitung',
#   'diskon',
#   'akal',
#   'akal',
#   'baru',
#   'bintang'],
#  ['order', 'kurir', 'gagal'],
#  ['koneksi',
#   'server',
#   'eror',
#   'jarak',
#   'jabodetabek',
#   'kurir',
#   'pos',
#   'toko',
#   'sedia',
#   'platform',
#   'belah',
#   'voucher',
#   'belanja',
#   'up',
#   'saldo',
#   'bebas',
#   'minimal',
#   'loncat',
#   'platform',
#   'belah',
#   'metode',
#   'topedpay'],
#  ['belanja', 'toko', 'diskon'],
#  ['maaf', 'duga', 'curang', 'sayang', 'transaksi', 'aplikasi'],
#  ['kirim', 'tolong', 'kurir', 'males'],
#  ['upgrade', 'siih', 'ongkir', 'chekout', 'beda', 'tampil'],
#  ['aplikasi', 'bohong', 'aplikasi'],
#  ['chat', 'via', 'akulaku', 'respon', 'chat', 'via', 'putus', 'jalan'],
#  ['log',
#   'out',
#   'hapus',
#   'aplikasi',
#   'kirim',
#   'sms',
#   'email',
#   'seh',
#   'harus',
#   'block',
#   'neh'],
#  ['transfer',
#   'dana',
#   'barang',
#   'pesan',
#   'pesan',
#   'transfer',
#   'sesuai',
#   'nominal',
#   'konfirmasi',
#   'tunggu'],
#  ['aplikasi', 'ongkos', 'kirim', 'mahal', 'harga', 'barang', 'assuuuu'],
#  ['pilih', 'ekspedisi', 'kirim', 'pakai', 'ekspress'],
#  ['nyaman',
#   'belanja',
#   'ongkir',
#   'mahal',
#   'kirim',
#   'expedisi',
#   'cepat',
#   'lenyapp',
#   'tolong',
#   'lgii',
#   'resah'],
#  ['pakai',
#   'salah',
#   'tulis',
#   'email',
#   'ganti',
#   'email',
#   'susah',
#   'syarat',
#   'ribet'],
#  ['alami',
#   'tipu',
#   'pribadi',
#   'adik',
#   'teman',
#   'hilang',
#   'ribu',
#   'pakai',
#   'shoope',
#   'bayar',
#   'kode',
#   'otp',
#   'form',
#   'imbal',
#   'hadiah',
#   'kode',
#   'otp',
#   'pribadi',
#   'hilang',
#   'ribu',
#   'shoope',
#   'bayar',
#   'shoope',
#   'ditindaklanjuti',
#   'wajib',
#   'saran',
#   'shoope',
#   'beli'],
#  ['tipuuu', 'flashsale', 'palsuuu'],
#  ['aplikasi', 'ribet'],
#  ['maaf', 'jaring', 'lemot', 'amanah'],
#  ['rate', 'ges', 'kesel', 'iklanya'],
#  ['barangx', 'asli', 'palsu'],
#  ['pesan', 'cancel'],
#  ['turun',
#   'bintang',
#   'gratis',
#   'ongkir',
#   'ny',
#   'aneh',
#   'sekarang',
#   'batas',
#   'pas',
#   'beli',
#   'pas',
#   'disc',
#   'gratis',
#   'ongkir',
#   'pas',
#   'bayar',
#   'batal',
#   'pas',
#   'beli',
#   'ulang',
#   'ongkir',
#   'ny',
#   'kepake',
#   'aneh',
#   'orang',
#   'batal',
#   'ongkir',
#   'hangus',
#   'sblah',
#   'grtis',
#   'ongkir'],
#  ['tanggung',
#   'profesional',
#   'bisnis',
#   'barang',
#   'kirim',
#   'konsumen',
#   'konsumen',
#   'narik',
#   'uang',
#   'acc',
#   'lepas',
#   'tangan',
#   'konsumen',
#   'raja',
#   'tetep',
#   'campur',
#   'tangan',
#   'sistem',
#   'proses',
#   'tanggung',
#   'ade',
#   'nombok',
#   'bayar',
#   'juta',
#   'gaji',
#   'cuman',
#   'juta',
#   'sistem',
#   'nombok',
#   'ade'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'masak',
#   'nomor',
#   'telpon',
#   'kurangajar',
#   'aplikasi',
#   'pindah',
#   'ahhhh'],
#  ['males', 'ngurusin', 'lebih baik', 'tutup', 'akun', 'pindah', 'ribet'],
#  ['dana', 'balance', 'tarik', 'rekening'],
#  ['sembarang',
#   'toko',
#   'jual',
#   'toko',
#   'tega',
#   'tipu',
#   'konsumen',
#   'alami',
#   'pesan',
#   'mukena',
#   'kirim',
#   'baju',
#   'bekas',
#   'kotor',
#   'mungut',
#   'sampah',
#   'sobek',
#   'bolong',
#   'krahnya',
#   'habis',
#   'saking',
#   'hapus',
#   'handphone',
#   'kirim',
#   'komplenan'],
#  ['asa', 'update', 'salah', 'update'],
#  ['mahalll', 'harga', 'toko'],
#  ['yangka',
#   'barang',
#   'pes',
#   'dbayar',
#   'dibatalin',
#   'ganti',
#   'cuman',
#   'biaya',
#   'pesan',
#   'biaya',
#   'transaksi',
#   'parahh'],
#  ['customer service', 'aktif'],
#  ['saran', 'shoppe', 'ekspres', 'layan', 'cekat', 'paket', 'sortir'],
#  ['pesan', 'barang'],
#  ['akun',
#   'banned',
#   'aplikasi',
#   'gajelas',
#   'unduh',
#   'beneran',
#   'bohong',
#   'sado',
#   'ilng',
#   'cari',
#   'uang',
#   'skrng',
#   'susah',
#   'bangrut',
#   'aminnn'],
#  ['habis', 'diupdate', 'produk', 'sulit', 'temu'],
#  ['order',
#   'produk',
#   'import',
#   'support',
#   'lokal',
#   'produk',
#   'lokal',
#   'mengambil',
#   'pict',
#   'terus',
#   'asli',
#   'harga',
#   'murah',
#   'susah',
#   'cari',
#   'baju',
#   'produk',
#   'terus',
#   'pelit',
#   'kaya',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jarang'],
#  ['fitur',
#   'chat',
#   'misah',
#   'pesan',
#   'barang',
#   'aneh',
#   'toko',
#   'ny',
#   'barang',
#   'bayar',
#   'beli'],
#  ['klu', 'penguna', 'bonus'],
#  ['layan', 'tim', 'care', 'perihal', 'komplain', 'belit', 'belit', 'jujur'],
#  ['respon', 'komplen', 'tunggu', 'jam', 'dproses', 'langgan', 'kabur'],
#  ['komen',
#   'aplikasi',
#   'adminnya',
#   'kaya',
#   'bgtu',
#   'cari',
#   'uang',
#   'rokok',
#   'bgtu',
#   'belanja',
#   'online'],
#  ['harap',
#   'kolom',
#   'cari',
#   'akurat',
#   'hasil',
#   'cari',
#   'cod',
#   'biaya',
#   'tangan',
#   'produk',
#   'cod',
#   'tanam',
#   'lemot',
#   'padaha',
#   'signal'],
#  ['habis',
#   'update',
#   'aplikasi',
#   'user',
#   'friendly',
#   'filter',
#   'urut',
#   'harga',
#   'cari',
#   'barang',
#   'beli',
#   'susah'],
#  ['baru',
#   'pesan',
#   'barang',
#   'sampai',
#   'aplikasi',
#   'ditrima',
#   'sya',
#   'nrima',
#   'bareng',
#   'tindak',
#   'tolong',
#   'usut',
#   'gelap',
#   'kurir',
#   'tolong',
#   'tindak',
#   'pngen',
#   'byak',
#   'konsumen',
#   'pngguna',
#   'maaf',
#   'bntang',
#   'krna',
#   'brang',
#   'adh',
#   'tindak'],
#  ['cantum',
#   'alamat',
#   'susah',
#   'voucher',
#   'toko',
#   'fitur',
#   'chat',
#   'hapus',
#   'akun',
#   'minus',
#   'plus',
#   'asli',
#   'murah',
#   'simpul',
#   'sistematis'],
#  ['jual',
#   'tanggung',
#   'pesan',
#   'cuman',
#   'diplastikin',
#   'barang',
#   'rusak',
#   'penjulnya',
#   'peduli',
#   'bubble',
#   'wrap',
#   'dasar',
#   'jual',
#   'tanggung',
#   'jual',
#   'tanggung',
#   'mlo',
#   'jual',
#   'layan',
#   'buru',
#   'brang',
#   'hancur',
#   'bilang',
#   'peduli',
#   'awas',
#   'lebih baik',
#   'pindah',
#   'percaya',
#   'aman',
#   'jamin'],
#  ['harga', 'barang', 'pas', 'murah', 'mahal'],
#  ['ganggu', 'hubung', 'akun', 'dana'],
#  ['pakai', 'aplikasi', 'lemot'],
#  ['sellenya',
#   'bnyak',
#   'tanggung',
#   'ujung',
#   'sat',
#   'barang',
#   'lngsung',
#   'blok',
#   'tnpa',
#   'proses',
#   'uang',
#   'aplikasi',
#   'beda',
#   'sama',
#   'ungu'],
#  ['kirim',
#   'daerah',
#   'pelosok',
#   'pencil',
#   'daerah',
#   'jabodetabek',
#   'sesuai',
#   'ekspedisi',
#   'ekspedisi',
#   'via',
#   'pos',
#   'customer',
#   'minggu',
#   'daerah',
#   'jateng',
#   'barang',
#   'tolong',
#   'delivery'],
#  ['bonus', 'hadiah'],
#  ['iklan',
#   'promosi',
#   'kalah',
#   'toko',
#   'belah',
#   'iklan',
#   'promosi',
#   'indah',
#   'khabar',
#   'tipu',
#   'belaka',
#   'komunitas',
#   'anggota',
#   'cerita',
#   'bicara',
#   'group',
#   'whatsapp',
#   'iklan',
#   'promosi',
#   'bintang',
#   'iklan',
#   'promosi',
#   'bintang'],
#  ['tolong',
#   'update',
#   'lemot',
#   'kesel',
#   'tahu',
#   'update',
#   'aplikasi',
#   'ny',
#   'lemot',
#   'pdhl',
#   'koneksi',
#   'internet',
#   'lancar',
#   'paket',
#   'juga',
#   'gin'],
#  ['sungguh',
#   'gagal',
#   'melulu',
#   'aplikasi',
#   'tipu',
#   'melulu',
#   'belanja',
#   'masukkan',
#   'kupon',
#   'chasback',
#   'dak',
#   'poin',
#   'kapok',
#   'kapok',
#   'kaya',
#   'aplikasi',
#   'chasback',
#   'koinya',
#   'selesai',
#   'laaaah',
#   'niat',
#   'poin',
#   'dak',
#   'chasbek',
#   'nyemplung',
#   'gooot',
#   'harga',
#   'mahal',
#   'ongkir',
#   'mahal',
#   'wes',
#   'rapopo',
#   'ojolali',
#   'karo',
#   'tipu',
#   'toko'],
#  ['maaf',
#   'turun',
#   'bintang',
#   'kesini',
#   'mahal',
#   'ongkir',
#   'massa',
#   'jakarta',
#   'bogor',
#   'ribu',
#   'ongkir',
#   'kaya',
#   'aplikasi'],
#  ['aplikasi',
#   'toko',
#   'rugi',
#   'belanja',
#   'barang',
#   'jarang',
#   'sesuai',
#   'jual',
#   'jujur'],
#  ['juga',
#   'nasib',
#   'sya',
#   'prank',
#   'olh',
#   'mmberikn',
#   'voucher',
#   'cash',
#   'back',
#   'pesan',
#   'batalkn',
#   'secra',
#   'voucher',
#   'cash',
#   'back',
#   'kmbli',
#   'klau',
#   'tkut',
#   'rugi',
#   'jangan',
#   'mmbrikn',
#   'vcr',
#   'csh',
#   'bck',
#   'sangt',
#   'pdhl',
#   'sambut',
#   'prank',
#   'olh'],
#  ['aplikasi', 'barang', 'bilang', 'tangan', 'kesall'],
#  ['ramai',
#   'bintang',
#   'gratis',
#   'free',
#   'ongkir',
#   'pas',
#   'acara',
#   'sms',
#   'rating',
#   'mampus'],
#  ['kirim',
#   'tanggal',
#   'beli',
#   'tanggal',
#   'agt',
#   'smp',
#   'skr',
#   'smp',
#   'ngendon',
#   'dc',
#   'marunda',
#   'smp',
#   'dc',
#   'surabaya',
#   'juga',
#   'lambat',
#   'kaya',
#   'keong',
# ...
#   'jasa',
#   'customer',
#   'sekarang',
#   'khasus',
#   'cod',
#   'cod',
#   'customernya',
#   'salah',
#   'expedisi',
#   'kasi',
#   'kurir',
#   'sasaraannya'],
#  ['banya',
#   'dagang',
#   'sebal',
#   'nama',
#   'barang',
#   'harga',
#   'ribu',
#   'flash',
#   'sale',
#   'ribu',
#   'clik',
#   'tahu',
#   'barang',
#   'tetep',
#   'harga',
#   'ribu',
#   'ribu',
#   'botol',
#   'bikin',
#   'males',
#   'cari',
#   'mental',
#   'dagang',
#   'indonesia',
#   'hmm',
#   'game',
#   'saran',
#   'ubah',
#   'aplikasi',
#   'game',
#   'live',
#   'streaming'],
#  ['biaya', 'murah'],
#  ['ganti',
#   'no',
#   'handphone',
#   'no',
#   'handphone',
#   'aktif',
#   'keteranganya',
#   'no',
#   'handphone',
#   'latih',
#   'latih',
#   'insentif',
#   'cair',
#   'informasi',
#   'tulis',
#   'ribet',
#   'hubung',
#   'care'],
#  ['sebenernyaa', 'aplikasi', 'tapi', 'tolonglahh', 'ringanin', 'ongkir'],
#  ['tolong', 'minn', 'bararng', 'klau', 'cod', 'bintangnyaa'],
#  ['daftar', 'plis', 'gmn', 'pakai', 'metode', 'google', 'sms', 'whatsapp'],
#  ['tolong',
#   'cashback',
#   'pakai',
#   'akun',
#   'mudah',
#   'pakai',
#   'saldo',
#   'cashback',
#   'ngurangin',
#   'bayar'],
#  ['saran', 'adain', 'tombol', 'report', 'toko', 'tipu', 'ban', 'sekalian'],
#  ['pesan', 'barang', 'bayar', 'bayar', 'bank', 'transfer', 'kartu', 'credit'],
#  ['tolong',
#   'kolom',
#   'varian',
#   'warna',
#   'ukur',
#   'seller',
#   'kesusaham',
#   'pasu',
#   'varian',
#   'warna',
#   'ukur'],
#  ['hbs', 'lemot', 'food', 'loading', 'sampai', 'responding', 'tolong'],
#  ['tidak',
#   'seru',
#   'gratis',
#   'ongkir',
#   'beli',
#   'potong',
#   'cuman',
#   'iyaa',
#   'beli',
#   'ongkir',
#   'gratis',
#   'barang'],
#  ['spaylater',
#   'akses',
#   'untuk',
#   'chekout',
#   'mgg',
#   'beranda',
#   'transaksi',
#   'harus',
#   'clear',
#   'chace',
#   'log',
#   'out',
#   'log',
#   'harus',
#   'update',
#   'versi',
#   'hslnya',
#   'nihil',
#   'pdhl',
#   'bayar',
#   'juga',
#   'terlambat',
#   'detik'],
#  ['belanja', 'member', 'gold', 'dpet', 'bayar', 'latter', 'spinjam', 'yaah'],
#  ['update', 'pas', 'update', 'gerakin', 'hadeeeh'],
#  ['kirim', 'tolong', 'harga', 'konsumen', 'beda', 'sho', 'pe', 'cma', 'smpai'],
#  ['ofc',
#   'aplikasi',
#   'but',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'jangan',
#   'pakai',
#   'shopeepay',
#   'pls',
#   'bayar',
#   'bayar',
#   'ongkir',
#   'mahal',
#   'noted',
#   'banyakin',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'gapake',
#   'shopeepay',
#   'mksh'],
#  ['sbnernya',
#   'tunggu',
#   'aplikasi',
#   'fitur',
#   'bayar',
#   'bayar',
#   'later',
#   'angsur',
#   'bunga',
#   'ringan',
#   'bayar',
#   'bayar',
#   'cash',
#   'biaya',
#   'layan',
#   'baca',
#   'auto',
#   'males'],
#  ['riwayat', 'beli', 'fitur', 'sedia', 'aplikasi', 'berat', 'ribet'],
#  ['tolong',
#   'ringkas',
#   'aplikasi',
#   'ui',
#   'simpel',
#   'aneh',
#   'aplikasi',
#   'food',
#   'pisah',
#   'mb'],
#  ['belnja', 'mudh', 'dn', 'hemat'],
#  ['lancar',
#   'pakai',
#   'rada',
#   'fitur',
#   'it',
#   'seller',
#   'kaya',
#   'ganiat',
#   'jual',
#   'salah',
#   'kirim',
#   'type',
#   'terang',
#   'untung',
#   'return',
#   'turun',
#   'percaya',
#   'beli'],
#  ['terpecaya', 'aman'],
#  ['barang', 'asli', 'tapi', 'kirim', 'barang', 'kemas'],
#  ['bohong', 'hadiah'],
#  ['halaman', 'muncuk', 'aplikasi', 'error'],
#  ['shoppe',
#   'eror',
#   'tanam',
#   'shoppe',
#   'bayar',
#   'koin',
#   'shope',
#   'bayar',
#   'tunggu'],
#  ['belanja', 'ps', 'bayar', 'hasil', 'status', 'barang', 'beli', 'kirim'],
#  ['aplikasi', 'respond'],
#  ['kirim', 'cepat'],
#  ['ganti', 'metode', 'bayar', 'pakai', 'kartu', 'tolong'],
#  ['akun', 'hilang', 'log', 'lagi'],
#  ['bguss', 'bngtt', 'aplikasi', 'msih'],
#  ['beli',
#   'gadget',
#   'bukti',
#   'asli',
#   'kirim',
#   'aman',
#   'cepat',
#   'beli',
#   'butuh',
#   'baby',
#   'harga',
#   'saing',
#   'toko',
#   'retail',
#   'nama',
#   'situs',
#   'belanja',
#   'online',
#   'percaya',
#   'banding',
#   'olshop'],
#  ['sertifikat', 'dhasboard'],
#  ['aman', 'belanja', 'shope', 'olshop', 'tarik', 'cashbacknya'],
#  ['beli', 'barang', 'shoppe', 'unduh'],
#  ['toko', 'maju', 'layan'],
#  ['ikan', 'layan', 'semogaa', 'tahan', 'tingkat'],
#  ['barang', 'asli', 'kirim', 'cepat'],
#  ['sesuai', 'janji', 'barang', 'shopy', 'barang'],
#  ['gratis', 'bonus', 'bqnyak'],
#  ['beli', 'latih', 'lancar', 'luncur'],
#  ['belanja', 'kurir', 'ramah'],
#  ['dng', 'bayar', 'cod', 'percaya', 'barang', 'kirim', 'jamin', 'shoppy'],
#  ['aplikasi', 'anti', 'ribet', 'belanja', 'kenal', 'belanja', 'belanja'],
#  ['latih', 'pra', 'bantu', 'sehat', 'sukses'],
#  ['ulas', 'emas', 'jasa', 'kirim', 'negatif'],
#  ['cepat', 'gratis', 'ongkir', 'banyakin', 'belanja', 'sukses', 'mksh'],
#  ['transaksi', 'belanja', 'praktis', 'murah'],
#  ['traksaksi', 'aman', 'mudah'],
#  ['maju', 'sukses', 'mudah'],
#  ['harap', 'jaga', 'tingkat'],
#  ['gabung',
#   'go',
#   'sukses',
#   'harap',
#   'logo',
#   'jaket',
#   'ubah',
#   'juga',
#   'logo',
#   'go',
#   'jek'],
#  ['latih',
#   'pilih',
#   'bisnis',
#   'online',
#   'tinggal',
#   'praktek',
#   'fast',
#   'respon',
#   'beli',
#   'vouchernya'],
#  ['proses', 'mudah', 'cepat', 'rekomendasi'],
#  ['belanja', 'cepat', 'hemat', 'aman'],
#  ['tolong', 'sedia', 'isi', 'ulang', 'saldo', 'driver', 'driver', 'sepi'],
#  ['aplikasi', 'nursal', 'klau', 'pakai'],
#  ['aplikasi', 'murah', 'riah', 'beli'],
#  ['puuuuuaaaaaassss', 'banyakin', 'ongkir'],
#  ['aplikasi',
#   'ny',
#   'mudah',
#   'belanja',
#   'online',
#   'juga',
#   'mudah',
#   'harus',
#   'unduh',
#   'sii',
#   'aplikasi',
#   'belanja',
#   'online',
#   'nomor',
#   'indonesia'],
#  ['aplikasi', 'belanja', 'online'],
#  ['produk', 'pajang', 'siap', 'stok'],
#  ['nyaman', 'aplikasi', 'tinggkatkan', 'smangat'],
#  ['barang', 'kirim', 'cepat'],
#  ['proses', 'cepat', 'barang'],
#  ['aplikasi', 'mudah', 'belanja'],
#  ['mudah', 'belanja'],
#  ['terrima',
#   'latih',
#   'academy',
#   'kenpa',
#   'sertifikat',
#   'muncul',
#   'didesboard',
#   'bantu'],
#  ['mantabb', 'betull', 'promo'],
#  ['aplikasi', 'sya', 'langgan', 'syang', 'tipu', 'jual', 'barang', 'abal'],
#  ['acara', 'voting', 'grup', 'kpop', 'tampil'],
#  ['berbelanka', 'disni', 'harga', 'murce', 'untuk', 'layan'],
#  ['belanja',
#   'dsini',
#   'butuh',
#   'rumah',
#   'tangga',
#   'komplit',
#   'pngiriman',
#   'cepat',
#   'terus',
#   'tahan',
#   'nyaman',
#   'custemer'],
#  ['murah', 'promo'],
#  ['mudah', 'cari', 'butuh'],
#  ['maling',
#   'kedok',
#   'asuransi',
#   'komplen',
#   'wajib',
#   'asuransi',
#   'nguntungin',
#   'malimg'],
#  ['bantu', 'mudah', 'pilih', 'latih'],
#  ['klaim',
#   'barang',
#   'mudah',
#   'bantu',
#   'usernya',
#   'tanggung',
#   'profesional',
#   'asuransi',
#   'sulit',
#   'profesional',
#   'layan',
#   'asuransi',
#   'smoga',
#   'maju',
#   'jaya'],
#  ['mudah', 'beli', 'latih'],
#  ['gratis', 'ongkir', 'harga', 'saing', 'murah'],
#  ['mudah', 'lengkap', 'belanja'],
#  ['aplikasi', 'belanja', 'online', 'amanah', 'kurir', 'ramah', 'profesional'],
#  ['salasatu',
#   'dukung',
#   'program',
#   'aplikasi',
#   'bantu',
#   'bayar',
#   'transaksi',
#   'alu',
#   'sulit',
#   'sukses',
#   'terimakash'],
#  ['flash', 'sale', 'filter', 'ken', 'serba', 'ribu', 'ongkir'],
#  ['muncul', 'shoope', 'later', 'belanja', 'bayar', 'pas', 'gaji'],
#  ['asli', 'kirim', 'cod'],
#  ['aplikasi', 'banyakin', 'disc'],
#  ['bantu', 'mudah', 'percaya'],
#  ['tolonh',
#   'tingkat',
#   'aplikasi',
#   'kirim',
#   'gratis',
#   'ongkir',
#   'beli',
#   'pilih',
#   'kurir',
#   'jangan',
#   'otomatis',
#   'kedapetan',
#   'kurir',
#   'anteraja',
#   'jakarta',
#   'jakarta',
#   'sampai',
#   'rumah',
#   'pickup',
#   'hapus',
#   'kurir',
#   'anteraja'],
#  ['bantu',
#   'belanja',
#   'pakek',
#   'ribet',
#   'tingal',
#   'pencet',
#   'transfer',
#   'tinggal',
#   'nungu',
#   'rumah',
#   'barang',
#   'beres',
#   'sistem',
#   'cod',
#   'beli',
#   'tunggu',
#   'barang',
#   'bayar'],
#  ['beli', 'latih', 'mudah'],
#  ['baguus', 'aplikasi', 'bantu'],
#  ['thankyou',
#   'kasi',
#   'bintang',
#   'beneran',
#   'area',
#   'jual',
#   'beli',
#   'sarana',
#   'edukasi',
#   'bekerjasama',
#   'latih',
#   'cepat',
#   'dipeoses',
#   'sertifikasi'],
#  ['sama',
#   'aplikasi',
#   'belanja',
#   'benar',
#   'aplikasi',
#   'mudah',
#   'pakai',
#   'kalang',
#   'anak',
#   'muda',
#   'tua'],
#  ['butuh', 'murah'],
#  ['mudah', 'nyaman'],
#  ['aplikasi', 'olshop', 'mudah', 'paham'],
#  ['order', 'gagal'],
#  ['lengkap', 'percaya'],
#  ['barang', 'sulit', 'aktivasi', 'shopeepaylater'],
#  ['belanja', 'mudah', 'promio'],
#  ['bagussss', 'aplikasi', 'nyaaaa', 'yakinnn'],
#  ['bantu', 'latih'],
#  ['harga', 'variatif'],
#  ['aplikasi', 'bantu'],
#  ['bantu', 'beli', 'voucher', 'jaya'],
#  ['belanja', 'cepat', 'nyampe', 'cod', 'sipp'],
#  ['alam', 'setia', 'selalu', 'tingkatin', 'kualitas'],
#  ['bintang',
#   'bintang',
#   'bantu',
#   'beli',
#   'barang',
#   'ribet',
#   'tinggal',
#   'pesan',
#   'kirim'],
#  ['tingkat', 'mutu', 'layan'],
#  ['shopie',
#   'bantu',
#   'belanja',
#   'rumah',
#   'gratis',
#   'ongkir',
#   'harga',
#   'barang',
#   'lbh',
#   'mahal',
#   'banding',
#   'berangkat',
#   'beli',
#   'sendri',
#   'toko'],
#  ['aplikasi', 'wajib', 'hhahhaha'],
#  ['mudah', 'transaksi'],
#  ['ngecewain', 'ongkir', 'jua', 'mantapp'],
#  ['layan', 'terpecaya'],
#  ['mudah', 'karantina', 'mandiri'],
#  ['aplikasi', 'belanja', 'murah', 'respon', 'cepat'],
#  ['barang', 'sesuai', 'pesananan', 'mantaf'],
#  ['latih',
#   'beli',
#   'ajar',
#   'trik',
#   'rangkai',
#   'tarik',
#   'perhati',
#   'customer',
#   'wawas',
#   'dlm',
#   'tingkat',
#   'business',
#   'online',
#   'terima',
#   'ruang',
#   'guru'],
#  ['sesuai', 'deskripsi', 'gambar'],
#  ['profesional', 'cepat', 'trampil'],
#  ['assalauallaikum',
#   'selesei',
#   'skill',
#   'akademy',
#   'trimakasih',
#   'program',
#   'progress',
#   'kelas',
#   'trimakadih',
#   'seminar',
#   'erti',
#   'dam',
#   'paham',
#   'trimakasih'],
#  ['bantu', 'belanja', 'online'],
#  ['serba', 'lengkap'],
#  ['belanja', 'isi', 'pulsa', 'bayar', 'tagih', 'mudah'],
#  ['mudah', 'transaksi'],
#  ['alam',
#   'ajar',
#   'kelas',
#   'motivasi',
#   'entrepreneur',
#   'ilmu',
#   'terap',
#   'usaha',
#   'aplikasi',
#   'canggih',
#   'fitur'],
#  ['jamin', 'terpecaya'],
#  ['mantapp', 'pinter', 'pinter', 'pilih', 'barang', 'jangn', 'tipu', 'jual'],
#  ['alhmdllah', 'beli', 'kirim', 'emas', 'rapi', 'kurir', 'ramah', 'jemppool'],
#  ['smoga',
#   'milik',
#   'anak',
#   'bangsa',
#   'sbagian',
#   'saham',
#   'kadang',
#   'kirim',
#   'cepat'],
#  ['aplikasi', 'sngat', 'mudah', 'belanja', 'online'],
#  ['toko', 'online', 'subsidi', 'ongkir'],
#  ['beli', 'barang', 'mudah', 'murah', 'proses', 'cepat', 'barang', 'sesuai'],
#  ['mitra', 'sedia', 'materi', 'latih'],
#  ['belanja', 'mudah'],
#  ['layan', 'lengganan', 'cod', 'mantafff'],
#  ['belanja', 'elektronik', 'kirim', 'cepat', 'barang', 'jamin', 'asli'],
#  ['voucher', 'otomatis'],
#  ['aplikasi', 'ringan', 'tingkat'],
#  ['kualitas', 'gunain', 'order', 'barang', 'asli', 'kirim', 'sasar'],
#  ['nyaman', 'belanja'],
#  ['proses', 'cepat', 'transaksi'],
#  ['latih',
#   'latih',
#   'mudah',
#   'difahami',
#   'ngebosenin',
#   'belanja',
#   'online',
#   'ajar',
#   'online',
#   'smoga',
#   'sertifikat',
#   'latih',
#   'turun',
#   'jalan',
#   'lancar',
#   'sukses',
#   'terus'],
#  ['kirim', 'cepat'],
#  ['bantu',
#   'belanja',
#   'mhon',
#   'krim',
#   'ny',
#   'jngn',
#   'lm',
#   'brng',
#   'ny',
#   'tunggu',
#   'konsumen',
#   'lancr',
#   'dn',
#   'sukses'],
#  ['belanja', 'aman'],
#  ['aplikasi', 'normal', 'keranjang', 'gambar', 'tulis', 'hitam'],
#  ['minggu', 'pesan', 'barang', 'sesuai', 'foto'],
#  ['bantu',
#   'belanja',
#   'bingung',
#   'dpet',
#   'tiket',
#   'emas',
#   'tidak',
#   'gjlas',
#   'ahahha'],
#  ['ilmu', 'bimbing', 'maju', 'skill', 'anak', 'bangsa', 'maju'],
#  ['bantu', 'jual', 'belanja', 'online'],
#  ['tolong',
#   'kasi',
#   'voucher',
#   'belanja',
#   'gede',
#   'dikit',
#   'kyak',
#   'gtu',
#   'free',
#   'ongkir',
#   'langgan'],
#  ['komplit', 'aplikasi'],
#  ['tolong',
#   'toko',
#   'belanja',
#   'toko',
#   'belanja',
#   'tipu',
#   'langgan',
#   'rugi',
#   'langgan'],
#  ['aplikasi', 'barang', 'lengkap', 'harga', 'murah'],
#  ['bayar', 'cicil', 'bagaimana', 'pas', 'barang', 'nyampe', 'bagaimana'],
#  ['ilmu', 'motivasi', 'trimakasih'],
#  ['diskon', 'tarik'],
#  ['hebat',
#   'murah',
#   'percaya',
#   'barang',
#   'nak',
#   'beli',
#   'mahal',
#   'murah',
#   'ps'],
#  ['lalau', 'sesuai', 'deskripsi', 'barang'],
#  ['belanja',
#   'mudah',
#   'percaya',
#   'proses',
#   'belanja',
#   'bayar',
#   'kirim',
#   'barang',
#   'pantau',
#   'ragu',
#   'belanja',
#   'online',
#   'mudah',
#   'amaaaan'],
#  ['live', 'chat', 'via', 'media', 'susah', 'komunikasi'],
#  ['banyakin', 'promo', 'anak', 'ngab'],
#  ['kualitas', 'harga', 'jangkau', 'kirim', 'cepat'],
#  ['aplikasi', 'tingkat', 'aman'],
#  ['barang', 'kirim', 'cepat'],
#  ['mantapp', 'materi'],
#  ['belanja', 'online', 'lancar', 'kendala', 'neng', 'olshop'],
#  ['beli',
#   'platform',
#   'skill',
#   'academy',
#   'mudah',
#   'paham',
#   'sertifikat',
#   'cepat',
#   'dasboard'],
#  ['mudah', 'menggunakanx', 'percaya'],
#  ['lahhhh',
#   'poko',
#   'kerennn',
#   'prnah',
#   'kcwa',
#   'jangan',
#   'ampe',
#   'mngecewakan'],
#  ['share', 'buy', 'gratis', 'ongkir', 'cod', 'mkn', 'sayang'],
#  ['mudah', 'transaksi'],
#  ['bangttt', 'memmbatu', 'dngan', 'lzada'],
#  ['barang', 'sesuai'],
#  ['siii', 'obat', 'obat', 'males', 'mall'],
#  ['sihh', 'pesan', 'member', 'gold', 'tingkat'],
#  ['aplikasi', 'mudah'],
#  ['aplikasi', 'beli', 'barang', 'gampang', 'promo'],
#  ['mudah', 'cari', 'barang', 'butuh', 'harga', 'murah'],
#  ['bantu',
#   'belanja',
#   'jual',
#   'produc',
#   'rumah',
#   'untung',
#   'koin',
#   'smoga',
#   'untung',
#   'kuota',
#   'gratis',
#   'akses'],
#  ['bantu', 'wawas', 'jual', 'produk', 'skill', 'academy'],
#  ['bonus', 'mantaap', 'tingkat'],
#  ['aplikasi',
#   'bantu',
#   'era',
#   'pandemi',
#   'rumah',
#   'mall',
#   'belanja',
#   'praktis',
#   'dibukalapak'],
#  ['kurir', 'ramah', 'layan'],
#  ['kirim', 'cepat', 'barang', 'beneran', 'sesuai', 'pesan'],
#  ['sen', 'shopeee', 'kirim', 'cepat', 'harga', 'sahabat'],
#  ['serba', 'mudah', 'ribet'],
#  ['isi',
#   'ulas',
#   'bilang',
#   'bom',
#   'beli',
#   'hilang',
#   'topup',
#   'tagih',
#   'tolong',
#   'tindak'],
#  ['diinstal',
#   'pas',
#   'check',
#   'out',
#   'tmpat',
#   'pelosok',
#   'tetangga',
#   'check',
#   'out'],
#  ['kebaxakan', 'barang', 'sesuai', 'postingan'],
#  ['poko', 'pesan', 'toko'],
#  ['aplikasi', 'kepala', 'pusing', 'istri', 'aplikasi'],
#  ['bantu', 'proses', 'bayar', 'skillacademy', 'lancar', 'hambat'],
#  ['belanja', 'online', 'nomor'],
#  ['gratis', 'ongkos', 'kirim', 'coi'],
#  ['tolong', 'tingkat', 'segi', 'barang', 'lengkap'],
#  ['sopiepay', 'meminjm', 'kslhn', 'apa', 'bgtu'],
#  ['mudah', 'belanja'],
#  ['blnja', 'cod', 'repot', 'rumah', 'trimakasih'],
#  ['barang', 'cepat', 'nyampe'],
#  ['bikin', 'latah', 'beli', 'dukung'],
#  ['aplikasi', 'belanja', 'online'],
#  ['bintang',
#   'soalnx',
#   'sekarang',
#   'kirim',
#   'bareng',
#   'sbagian',
#   'produknx',
#   'sesuai',
#   'ekspetasi'],
#  ['barang', 'real', 'pict', 'ngecewain'],
#  ['mudah', 'beli', 'produk'],
#  ['beli', 'barang', 'ringan', 'tinggal', 'klik', 'gambar', 'yng', 'kta'],
#  ['cash', 'back', 'jaya'],
#  ['saran',
#   'adain',
#   'fitur',
#   'spinjam',
#   'sama',
#   'spaylater',
#   'diadain',
#   'nonaktif',
#   'pakai',
#   'iseng',
#   'aktifin',
#   'kepake',
#   'jebol',
#   'akun',
#   'diambilin',
#   'limit',
#   'ujung',
#   'bayar',
#   'ngeri',
#   'bom',
#   'aktifin',
#   'lebih baik',
#   'butuh',
#   'nonaktif',
#   'dipake',
#   'mlh',
#   'dsuruh',
#   'hapus',
#   'akun',
#   'hhhh'],
#  ['bantu', 'unruk', 'online', 'shop'],
#  ['mudah', 'aplikasi'],
#  ['beli', 'latih', 'skill', 'academy', 'mudah', 'erti', 'detail', 'sukses'],
#  ['mudah', 'bertraksaksi'],
#  ['mudah', 'percaya'],
#  ['barang', 'pesan', 'sesuai'],
#  ['rugi', 'unduh'],
#  ['aplikasi', 'belanja', 'murah', 'ongkir'],
#  ['belanja', 'mudah'],
#  ['discount', 'bebas', 'ongkir'],
#  ['belanja',
#   'gratis',
#   'ongkir',
#   'team',
#   'supportnya',
#   'cepat',
#   'tanggap',
#   'masalah',
#   'dana',
#   'aman',
#   'trimakasih'],
#  ['tarik', 'insentif', 'bom', 'cair'],
#  ['belanja', 'harga', 'jangkau'],
#  ['terimhksh', 'mmbrkn', 'harga', 'brng', 'sesuai', 'sya'],
#  ['aplikasi', 'bantu', 'belanja', 'barang', 'dsini'],
#  ['belanja',
#   'aplikasi',
#   'malam',
#   'promo',
#   'krna',
#   'install',
#   'shoope',
#   'lemot',
#   'malam',
#   'jaring',
#   'internet'],
#  ['shope', 'bayar', 'later', 'pakai', 'shope'],
#  ['bekerjasama', 'program', 'lancar', 'jalan', 'program'],
#  ['mntp', 'sajs', 'webinar', 'lancar', 'sertifikasi', 'muncul', 'dashboard'],
#  ['tingkat',
#   'lagi',
#   'customer',
#   'servicenya',
#   'cepat',
#   'merespon',
#   'keluh',
#   'user'],
#  ['barang', 'lengkap'],
#  ['belanja',
#   'aman',
#   'topup',
#   'biaya',
#   'admin',
#   'harga',
#   'murah',
#   'jangkau',
#   'kirim',
#   'cepat',
#   'ongkir',
#   'mahal'],
#  ['tingkat', 'promo', 'ehehe'],
#  ['bags', 'barang', 'ny'],
#  ['pesan', 'cepat', 'sampai']]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel.load('gdrive/MyDrive/save_file/lda_stem_7')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:494: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# [(3, 0.27108064), (5, 0.16179372), (6, 0.53118855)]
# [(0, 0.028571758), (1, 0.2285718), (2, 0.6285707), (3, 0.02857143), (4, 0.02857143), (5, 0.02857143), (6, 0.02857143)]
# [(0, 0.28565213), (1, 0.035714284), (2, 0.035714284), (3, 0.035776485), (4, 0.2857143), (5, 0.035714284), (6, 0.2857142)]
# [(0, 0.017857144), (1, 0.26781535), (2, 0.01789721), (3, 0.11243279), (4, 0.017857144), (5, 0.01789766), (6, 0.5482427)]
# [(1, 0.15327081), (2, 0.027392138), (3, 0.05200465), (4, 0.18193331), (5, 0.17948073), (6, 0.40287018)]
# [(0, 0.22721648), (1, 0.02857161), (2, 0.028571531), (3, 0.4288241), (4, 0.028571581), (5, 0.028571537), (6, 0.22967315)]
# [(0, 0.10068487), (1, 0.06348881), (2, 0.17422666), (3, 0.08224215), (5, 0.272614), (6, 0.2987951)]
# [(0, 0.047619045), (1, 0.38095304), (2, 0.047619045), (3, 0.04761906), (4, 0.047619045), (5, 0.3809517), (6, 0.047619045)]
# [(0, 0.035714295), (1, 0.535627), (2, 0.035714295), (3, 0.28571877), (4, 0.0357143), (5, 0.035797093), (6, 0.03571429)]
# [(1, 0.27204478), (2, 0.40791816), (5, 0.087822735), (6, 0.20829007)]
# [(0, 0.023809528), (1, 0.19041993), (2, 0.21623652), (3, 0.023823699), (4, 0.023809528), (5, 0.023867965), (6, 0.49803284)]
# [(0, 0.10296554), (1, 0.21005411), (2, 0.27498987), (3, 0.011910272), (4, 0.011913087), (5, 0.011910823), (6, 0.37625632)]
# [(0, 0.37140614), (1, 0.03577062), (2, 0.44964153), (3, 0.035915956), (4, 0.035777103), (5, 0.035752166), (6, 0.035736524)]
# [(0, 0.02380953), (1, 0.02398257), (2, 0.19046037), (3, 0.19048077), (4, 0.023809532), (5, 0.19048178), (6, 0.35697547)]
# [(0, 0.011904764), (1, 0.3452443), (2, 0.011931735), (3, 0.10493514), (4, 0.011904764), (5, 0.011904764), (6, 0.50217456)]
# [(1, 0.10713838), (2, 0.2571414), (3, 0.2916677), (4, 0.124861576), (5, 0.0989745), (6, 0.112996615)]
# [(0, 0.010211387), (1, 0.16608216), (2, 0.3400196), (3, 0.19599399), (4, 0.18681836), (5, 0.09066122), (6, 0.010213263)]
# [(0, 0.020408167), (1, 0.020408168), (2, 0.020408167), (3, 0.30612597), (4, 0.16326903), (5, 0.1632671), (6, 0.30611342)]
# [(0, 0.015904354), (1, 0.23895086), (2, 0.12708275), (3, 0.30048797), (4, 0.015908409), (5, 0.01587325), (6, 0.28579244)]
# [(0, 0.0143100545), (1, 0.014285715), (2, 0.22469266), (3, 0.5142145), (4, 0.014289016), (5, 0.20386346), (6, 0.014344582)]
# [(0, 0.035714287), (1, 0.5357101), (2, 0.035808336), (3, 0.2856244), (4, 0.035714287), (5, 0.035714287), (6, 0.035714287)]
# [(0, 0.035714287), (1, 0.2857153), (2, 0.035714287), (3, 0.28571683), (4, 0.2857107), (5, 0.035714287), (6, 0.035714284)]
# [(0, 0.023809524), (1, 0.1904756), (2, 0.023809524), (3, 0.023854971), (4, 0.50909525), (5, 0.023809524), (6, 0.20514558)]
# [(0, 0.035714295), (1, 0.5357146), (2, 0.035771225), (3, 0.03577624), (4, 0.035714287), (5, 0.035714287), (6, 0.28559506)]
# [(0, 0.023810394), (1, 0.19039787), (2, 0.35714218), (3, 0.023809524), (4, 0.35714245), (5, 0.023880763), (6, 0.023816817)]
# [(0, 0.23281632), (1, 0.020487785), (2, 0.02055793), (3, 0.28142685), (4, 0.020462643), (5, 0.22892651), (6, 0.19532196)]
# [(0, 0.013006965), (1, 0.013046595), (2, 0.13519508), (3, 0.13067013), (4, 0.013013554), (5, 0.19902728), (6, 0.49604043)]
# [(0, 0.28565526), (1, 0.5357142), (2, 0.035714287), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.03577339)]
# [(0, 0.02863127), (1, 0.59411156), (2, 0.0285989), (3, 0.028634388), (4, 0.02864343), (5, 0.028600117), (6, 0.26278037)]
# [(0, 0.07924681), (1, 0.07218381), (2, 0.20200863), (3, 0.1408772), (4, 0.23246421), (5, 0.05134311), (6, 0.22187623)]
# [(0, 0.31426772), (1, 0.19918981), (2, 0.014285715), (3, 0.12938155), (4, 0.31428543), (5, 0.014285715), (6, 0.014304103)]
# [(0, 0.028615996), (1, 0.82836485), (2, 0.028592054), (3, 0.028618023), (4, 0.028625581), (5, 0.028592974), (6, 0.028590536)]
# [(0, 0.1288538), (1, 0.11647962), (2, 0.17782666), (3, 0.17004976), (4, 0.15639316), (6, 0.24145564)]
# [(0, 0.023809524), (1, 0.023809524), (2, 0.19047622), (3, 0.023809953), (4, 0.19047624), (5, 0.1904763), (6, 0.35714224)]
# [(0, 0.010994448), (1, 0.010989208), (2, 0.11845429), (3, 0.010994164), (4, 0.10804854), (5, 0.2916327), (6, 0.4488866)]
# [(0, 0.015896026), (1, 0.20202307), (2, 0.015895113), (3, 0.015893077), (4, 0.1822608), (5, 0.18533814), (6, 0.38269374)]
# [(0, 0.020426657), (1, 0.20865437), (2, 0.18527088), (3, 0.35742113), (4, 0.020602908), (5, 0.18720703), (6, 0.02041702)]
# [(1, 0.3412718), (3, 0.2301063), (4, 0.119058594), (5, 0.06349153), (6, 0.23015891)]
# [(0, 0.020408165), (1, 0.16326554), (2, 0.020408165), (3, 0.1632655), (4, 0.16326132), (5, 0.020408165), (6, 0.44898316)]
# [(0, 0.07169934), (1, 0.2598505), (2, 0.15771382), (3, 0.110697486), (5, 0.07154306), (6, 0.31956714)]
# [(0, 0.017919404), (1, 0.1428589), (2, 0.017992258), (3, 0.01785715), (4, 0.01785715), (5, 0.01808803), (6, 0.76742715)]
# [(0, 0.020408165), (1, 0.020408165), (2, 0.30612332), (3, 0.3061223), (4, 0.020408165), (5, 0.020408165), (6, 0.30612168)]
# [(0, 0.024092779), (1, 0.1904774), (2, 0.023809522), (3, 0.35821497), (4, 0.19047526), (5, 0.023809522), (6, 0.18912052)]
# [(0, 0.02857143), (1, 0.22838226), (2, 0.02857143), (3, 0.4302013), (4, 0.02857143), (5, 0.028761592), (6, 0.22694056)]
# [(0, 0.077315114), (1, 0.06702924), (3, 0.22217077), (4, 0.08550012), (5, 0.13376312), (6, 0.40975517)]
# [(0, 0.08788745), (1, 0.22027366), (2, 0.12804379), (3, 0.2227994), (4, 0.16827744), (5, 0.011024109), (6, 0.16169412)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.035824098), (3, 0.035885982), (4, 0.035902232), (5, 0.035714287), (6, 0.7852448)]
# [(0, 0.011904862), (1, 0.011904764), (2, 0.3452408), (3, 0.39139926), (4, 0.011909136), (5, 0.011904762), (6, 0.2157364)]
# [(0, 0.10504777), (1, 0.30298543), (2, 0.06819387), (4, 0.24370165), (5, 0.07358494), (6, 0.198083)]
# [(0, 0.21640536), (1, 0.08208797), (2, 0.0990832), (5, 0.1454458), (6, 0.44012758)]
# [(0, 0.1142876), (1, 0.114288464), (2, 0.25113386), (3, 0.014285939), (4, 0.2493821), (5, 0.1142871), (6, 0.14233494)]
# [(0, 0.020488853), (1, 0.020408165), (2, 0.020408165), (3, 0.020408165), (4, 0.020408165), (5, 0.16326511), (6, 0.73461336)]
# [(0, 0.014285718), (1, 0.014307949), (2, 0.014290291), (3, 0.2142984), (4, 0.121015), (5, 0.121531114), (6, 0.5002715)]
# [(0, 0.010206439), (1, 0.2701111), (2, 0.10275178), (3, 0.4368022), (4, 0.010207338), (5, 0.08424977), (6, 0.085671335)]
# [(0, 0.035714284), (1, 0.28571463), (2, 0.28571305), (3, 0.035714284), (4, 0.28571516), (5, 0.035714284), (6, 0.035714284)]
# [(1, 0.23542595), (3, 0.22062802), (4, 0.06430526), (5, 0.0699412), (6, 0.39382297)]
# [(0, 0.028580735), (1, 0.40840316), (2, 0.028583527), (3, 0.23810168), (4, 0.028710414), (5, 0.23904435), (6, 0.028576141)]
# [(0, 0.22996838), (1, 0.22853443), (2, 0.2272002), (3, 0.22858267), (4, 0.028571451), (5, 0.028571442), (6, 0.028571436)]
# [(0, 0.37504277), (1, 0.04762506), (2, 0.047622498), (3, 0.047794804), (4, 0.3866487), (5, 0.047622748), (6, 0.04764339)]
# [(0, 0.18353398), (1, 0.19902243), (2, 0.020422192), (3, 0.18065941), (4, 0.37552315), (5, 0.020423194), (6, 0.020415619)]
# [(0, 0.020408165), (1, 0.3061217), (2, 0.16325799), (3, 0.16326772), (4, 0.16326949), (5, 0.16326675), (6, 0.020408165)]
# [(0, 0.023809554), (1, 0.19051547), (2, 0.19050172), (3, 0.023810083), (4, 0.023809562), (5, 0.523656), (6, 0.023897612)]
# [(0, 0.28613454), (1, 0.02863118), (2, 0.028605606), (3, 0.028604725), (4, 0.3162548), (5, 0.28313684), (6, 0.028632328)]
# [(0, 0.045110486), (1, 0.25137073), (2, 0.12485508), (3, 0.14405634), (4, 0.16751061), (5, 0.08509367), (6, 0.18200304)]
# [(0, 0.020408167), (1, 0.020491963), (2, 0.30612358), (3, 0.020581385), (4, 0.020408174), (5, 0.30584687), (6, 0.3061399)]
# [(0, 0.10902336), (1, 0.16164063), (2, 0.05640572), (3, 0.13538326), (4, 0.05639032), (5, 0.23782517), (6, 0.24333154)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.7142857), (5, 0.04761905), (6, 0.04761905)]
# [(0, 0.047621127), (1, 0.047619045), (2, 0.380951), (3, 0.3809517), (4, 0.047619045), (5, 0.047619045), (6, 0.047619045)]
# [(0, 0.028571432), (1, 0.028571436), (2, 0.028606435), (3, 0.42854625), (4, 0.028571436), (5, 0.028571432), (6, 0.42856154)]
# [(0, 0.03576618), (1, 0.45753077), (2, 0.035761055), (3, 0.035759833), (4, 0.03578324), (5, 0.3636598), (6, 0.035739087)]
# [(0, 0.7134085), (1, 0.047835216), (2, 0.047737706), (3, 0.047732607), (4, 0.04779425), (5, 0.047744215), (6, 0.047747474)]
# [(0, 0.02857143), (1, 0.22856312), (2, 0.02857143), (3, 0.22857945), (4, 0.028572133), (5, 0.02857143), (6, 0.428571)]
# [(1, 0.22400486), (3, 0.20499447), (4, 0.20296338), (5, 0.20690608), (6, 0.14431535)]
# [(1, 0.116404764), (2, 0.08110126), (3, 0.06751314), (4, 0.19998093), (5, 0.21142122), (6, 0.31828436)]
# [(0, 0.21872276), (1, 0.14062573), (3, 0.148643), (5, 0.20028032), (6, 0.27264032)]
# [(0, 0.011007558), (1, 0.34603512), (2, 0.11021218), (3, 0.1136886), (4, 0.011013628), (5, 0.11766672), (6, 0.2903762)]
# [(1, 0.14899288), (2, 0.22980253), (3, 0.41089275), (6, 0.18351547)]
# [(0, 0.047974966), (1, 0.048228677), (2, 0.04762768), (3, 0.048060473), (4, 0.048003387), (5, 0.047619846), (6, 0.71248496)]
# [(0, 0.011905171), (1, 0.17855948), (2, 0.26190677), (3, 0.178572), (4, 0.095235996), (5, 0.011916991), (6, 0.2619036)]
# [(0, 0.2856798), (1, 0.035714325), (2, 0.03571431), (3, 0.03577674), (4, 0.03571432), (5, 0.035714336), (6, 0.5356862)]
# [(2, 0.17004205), (3, 0.33372298), (5, 0.0884275), (6, 0.3791995)]
# [(0, 0.035714287), (1, 0.28571504), (2, 0.035714287), (3, 0.2857118), (4, 0.285716), (5, 0.035714287), (6, 0.035714287)]
# [(0, 0.02857143), (1, 0.028571432), (2, 0.22857264), (3, 0.42856956), (4, 0.028571432), (5, 0.02857143), (6, 0.22857213)]
# [(0, 0.04761905), (1, 0.38095263), (2, 0.047738437), (3, 0.38083276), (4, 0.04761905), (5, 0.04761905), (6, 0.04761905)]
# [(0, 0.1144136), (1, 0.20804618), (3, 0.09205997), (5, 0.13248056), (6, 0.4339374)]
# [(0, 0.07467348), (2, 0.30054176), (3, 0.26435137), (6, 0.33897436)]
# [(0, 0.047653228), (1, 0.7140928), (2, 0.04764984), (3, 0.047649056), (4, 0.047664538), (5, 0.047652047), (6, 0.047638502)]
# [(0, 0.023812119), (1, 0.3453648), (2, 0.023811866), (3, 0.1930241), (4, 0.023817413), (5, 0.023812033), (6, 0.3663577)]
# [(0, 0.01590931), (1, 0.6584024), (2, 0.015886404), (3, 0.14741978), (4, 0.015902128), (5, 0.01588736), (6, 0.13059264)]
# [(0, 0.020408165), (1, 0.44898257), (2, 0.020408165), (3, 0.020408167), (4, 0.16326599), (5, 0.020408165), (6, 0.30611876)]
# [(0, 0.10372031), (1, 0.37676087), (2, 0.012988236), (3, 0.2857076), (4, 0.19480394), (5, 0.012987015), (6, 0.013032042)]
# [(0, 0.035721015), (1, 0.2647086), (2, 0.03571444), (3, 0.55664235), (4, 0.035730455), (5, 0.035714447), (6, 0.035768736)]
# [(0, 0.19317745), (1, 0.19495672), (2, 0.012987047), (3, 0.32362184), (4, 0.012987063), (5, 0.01298705), (6, 0.24928282)]
# [(0, 0.0131504545), (1, 0.42058828), (2, 0.21448699), (3, 0.19470724), (4, 0.13107352), (5, 0.012987042), (6, 0.013006437)]
# [(1, 0.1605728), (2, 0.3201819), (5, 0.22595194), (6, 0.26464662)]
# [(0, 0.35714307), (1, 0.023809524), (2, 0.023809524), (3, 0.023809524), (4, 0.023809524), (5, 0.19047616), (6, 0.35714266)]
# [(1, 0.07887852), (2, 0.14358613), (3, 0.29570547), (5, 0.14432782), (6, 0.31960166)]
# [(0, 0.61621493), (1, 0.01791027), (2, 0.01786531), (3, 0.15245748), (4, 0.017869148), (5, 0.15977614), (6, 0.01790675)]
# [(0, 0.010206329), (1, 0.2959248), (2, 0.088351674), (3, 0.29397312), (4, 0.17198421), (5, 0.010206175), (6, 0.12935364)]
# [(0, 0.1114333), (1, 0.33191562), (2, 0.20787774), (3, 0.21209218), (4, 0.11068089), (5, 0.012992736), (6, 0.013007519)]
# [(0, 0.03584569), (1, 0.42701492), (2, 0.035832513), (3, 0.03582937), (4, 0.03588983), (5, 0.035841126), (6, 0.39374658)]
# [(0, 0.028574597), (1, 0.028572312), (2, 0.028576225), (3, 0.63165), (4, 0.22548239), (5, 0.028572703), (6, 0.028571809)]
# [(0, 0.017883796), (1, 0.23411794), (2, 0.01788116), (3, 0.17813836), (4, 0.2095006), (5, 0.1832368), (6, 0.15924138)]
# [(0, 0.028612867), (1, 0.36716917), (2, 0.028732026), (3, 0.028610513), (4, 0.028626487), (5, 0.028611451), (6, 0.48963746)]
# [(0, 0.020408591), (1, 0.3059052), (2, 0.30625314), (3, 0.16329357), (4, 0.020408237), (5, 0.16332306), (6, 0.020408189)]
# [(0, 0.20051661), (1, 0.2528782), (2, 0.095895104), (3, 0.24437499), (5, 0.047905866), (6, 0.15292734)]
# [(0, 0.04761905), (1, 0.7141449), (2, 0.04761905), (3, 0.04761905), (4, 0.047651768), (5, 0.047653984), (6, 0.047692258)]
# [(0, 0.03571429), (1, 0.28570244), (2, 0.035714287), (3, 0.03571429), (4, 0.28572315), (5, 0.03571429), (6, 0.28571722)]
# [(0, 0.3096115), (1, 0.4699869), (3, 0.053207006), (4, 0.05692218), (5, 0.05387771), (6, 0.050437916)]
# [(1, 0.063497335), (2, 0.23017342), (3, 0.26971957), (4, 0.23915331), (5, 0.11904536), (6, 0.07047444)]
# [(0, 0.110789746), (1, 0.22283152), (2, 0.096298516), (3, 0.19367376), (4, 0.010989013), (5, 0.16483136), (6, 0.20058611)]
# [(0, 0.16341904), (1, 0.30681708), (2, 0.02040832), (3, 0.020445114), (4, 0.16410632), (5, 0.16378577), (6, 0.16101836)]
# [(0, 0.02857143), (1, 0.42857423), (2, 0.22856931), (3, 0.02857143), (4, 0.02857143), (5, 0.22857074), (6, 0.02857143)]
# [(0, 0.035714284), (1, 0.5357142), (2, 0.035714284), (3, 0.035714287), (4, 0.035714284), (5, 0.28571433), (6, 0.035714284)]
# [(0, 0.023838377), (1, 0.27090007), (2, 0.30383953), (3, 0.023872247), (4, 0.023847116), (5, 0.023836868), (6, 0.3298658)]
# [(0, 0.023809524), (1, 0.19047375), (2, 0.023809524), (3, 0.35719037), (4, 0.023809528), (5, 0.02399122), (6, 0.35691607)]
# [(0, 0.023809524), (1, 0.023887238), (2, 0.02387286), (3, 0.023927093), (4, 0.023809524), (5, 0.35706556), (6, 0.52362823)]
# [(0, 0.035714287), (1, 0.78571427), (2, 0.035714287), (3, 0.035714295), (4, 0.03571429), (5, 0.035714287), (6, 0.035714287)]
# [(0, 0.13752133), (1, 0.40896732), (2, 0.01588074), (3, 0.26011133), (4, 0.015889706), (5, 0.14569727), (6, 0.015932322)]
# [(1, 0.14215732), (2, 0.13150035), (3, 0.13207544), (4, 0.05175403), (5, 0.1855886), (6, 0.35374734)]
# [(0, 0.015873017), (1, 0.23809725), (2, 0.23809655), (3, 0.4602213), (4, 0.015894448), (5, 0.015873017), (6, 0.015944446)]
# [(0, 0.017857147), (1, 0.3412122), (2, 0.017915307), (3, 0.017878968), (4, 0.26052204), (5, 0.017885305), (6, 0.326729)]
# [(0, 0.028571505), (1, 0.19429073), (2, 0.028571507), (3, 0.26265055), (4, 0.028680315), (5, 0.028571501), (6, 0.4286639)]
# [(0, 0.05713588), (1, 0.057142187), (3, 0.24228819), (4, 0.07477853), (5, 0.10714282), (6, 0.45435777)]
# [(0, 0.13120261), (1, 0.014305441), (2, 0.12909117), (3, 0.19474745), (4, 0.014302771), (5, 0.014297831), (6, 0.5020527)]
# [(0, 0.19949947), (1, 0.19132055), (2, 0.14215916), (3, 0.07146478), (4, 0.040154383), (5, 0.038023878), (6, 0.31737775)]
# [(0, 0.035714313), (1, 0.28574413), (2, 0.03571431), (3, 0.28573602), (4, 0.03571432), (5, 0.03571431), (6, 0.2856626)]
# [(0, 0.015873598), (1, 0.01587302), (2, 0.23809907), (3, 0.34920737), (4, 0.01587302), (5, 0.12698576), (6, 0.23808816)]
# [(0, 0.015884455), (1, 0.01589012), (2, 0.13926965), (3, 0.3950381), (4, 0.28495067), (5, 0.01588348), (6, 0.13308355)]
# [(0, 0.02857143), (1, 0.5229659), (2, 0.02857143), (3, 0.33410713), (4, 0.028571432), (5, 0.028641203), (6, 0.028571432)]
# [(0, 0.017984958), (1, 0.14285702), (2, 0.017857146), (3, 0.14285097), (4, 0.14285953), (5, 0.017857146), (6, 0.5177333)]
# [(0, 0.14285749), (1, 0.017857144), (2, 0.017857144), (3, 0.14285642), (4, 0.14316031), (5, 0.1428574), (6, 0.3925541)]
# [(0, 0.014375672), (1, 0.5142373), (2, 0.0142857265), (3, 0.2143178), (4, 0.014285733), (5, 0.11420615), (6, 0.114291646)]
# [(1, 0.14285864), (2, 0.17135544), (3, 0.15379141), (5, 0.2095245), (6, 0.30342218)]
# [(0, 0.020429233), (1, 0.21809192), (2, 0.020427266), (3, 0.5015112), (4, 0.020436035), (5, 0.020502986), (6, 0.19860135)]
# [(0, 0.28571674), (1, 0.28571674), (2, 0.03571429), (3, 0.03571429), (4, 0.03571429), (5, 0.03571429), (6, 0.28570935)]
# [(0, 0.04573514), (1, 0.27770394), (2, 0.22692756), (4, 0.05108636), (6, 0.391024)]
# [(0, 0.04761907), (1, 0.04761908), (2, 0.047619063), (3, 0.047619063), (4, 0.38096726), (5, 0.04761907), (6, 0.38093743)]
# [(0, 0.02857143), (1, 0.22857077), (2, 0.02857143), (3, 0.02857143), (4, 0.028571432), (5, 0.22857234), (6, 0.42857116)]
# [(0, 0.011952982), (1, 0.0952369), (2, 0.17856902), (3, 0.10006305), (4, 0.09523931), (5, 0.0952397), (6, 0.42369905)]
# [(0, 0.08104811), (1, 0.06906443), (2, 0.1802544), (3, 0.062250905), (4, 0.09057605), (5, 0.08626661), (6, 0.4305395)]
# [(0, 0.01103182), (1, 0.16482951), (2, 0.010989012), (3, 0.37503034), (4, 0.010989014), (5, 0.0879121), (6, 0.33921817)]
# [(0, 0.02380953), (1, 0.19045524), (2, 0.02380994), (3, 0.02380953), (4, 0.19047953), (5, 0.52382666), (6, 0.023809528)]
# [(1, 0.06838982), (2, 0.31363353), (3, 0.29335544), (4, 0.12883574), (6, 0.17985088)]
# [(0, 0.13877977), (1, 0.06015393), (3, 0.16540767), (4, 0.06015521), (5, 0.112787634), (6, 0.45519695)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.38095304), (5, 0.38095173), (6, 0.04761905)]
# [(2, 0.12532437), (3, 0.16970675), (4, 0.26542908), (5, 0.09305782), (6, 0.33933023)]
# [(1, 0.1782495), (3, 0.077002324), (4, 0.24469681), (5, 0.078237556), (6, 0.40496698)]
# [(0, 0.015901003), (1, 0.015916744), (2, 0.1404936), (3, 0.015902614), (4, 0.3901187), (5, 0.01588398), (6, 0.40578333)]
# [(0, 0.028608944), (1, 0.028609592), (2, 0.028626908), (3, 0.2600549), (4, 0.5969163), (5, 0.028597051), (6, 0.028586304)]
# [(0, 0.2659981), (1, 0.19094728), (2, 0.010998562), (3, 0.10097312), (4, 0.011030495), (5, 0.0109941885), (6, 0.40905827)]
# [(0, 0.017857796), (1, 0.14285547), (2, 0.26785743), (3, 0.14285614), (4, 0.14334205), (5, 0.017857144), (6, 0.26737398)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.3809528), (5, 0.04761905), (6, 0.3809519)]
# [(0, 0.14288688), (1, 0.1429038), (2, 0.017857172), (3, 0.37395853), (4, 0.017859936), (5, 0.16166714), (6, 0.14286657)]
# [(0, 0.011116744), (1, 0.30722854), (2, 0.16483945), (3, 0.08791395), (4, 0.087914184), (5, 0.17669073), (6, 0.1642964)]
# [(0, 0.020424057), (1, 0.39542708), (2, 0.35056058), (3, 0.02042212), (4, 0.02042925), (5, 0.020423517), (6, 0.1723134)]
# [(0, 0.047619045), (1, 0.047619045), (2, 0.047747396), (3, 0.7141117), (4, 0.047619045), (5, 0.047619045), (6, 0.047664754)]
# [(0, 0.04761905), (1, 0.38095227), (2, 0.38095245), (3, 0.04761905), (4, 0.04761905), (5, 0.04761905), (6, 0.04761905)]
# [(0, 0.29116043), (1, 0.20960134), (2, 0.0119103445), (3, 0.011914932), (4, 0.011954643), (5, 0.011917632), (6, 0.45154068)]
# [(0, 0.1567726), (2, 0.3054859), (3, 0.107153915), (4, 0.05715357), (5, 0.107099846), (6, 0.25913358)]
# [(0, 0.017857175), (1, 0.36275688), (2, 0.017901361), (3, 0.14940083), (4, 0.017857179), (5, 0.1663726), (6, 0.267854)]
# [(0, 0.035714287), (1, 0.53571427), (2, 0.035714287), (3, 0.03571429), (4, 0.035714287), (5, 0.28571433), (6, 0.035714287)]
# [(1, 0.25472668), (2, 0.061903145), (3, 0.12035098), (4, 0.11424463), (5, 0.16125646), (6, 0.2810206)]
# [(0, 0.015873022), (1, 0.17152931), (2, 0.015887927), (3, 0.25676197), (4, 0.015873017), (5, 0.12697938), (6, 0.39709535)]
# [(0, 0.017857147), (1, 0.14286223), (2, 0.017857147), (3, 0.017865265), (4, 0.15084982), (5, 0.14285763), (6, 0.50985074)]
# [(0, 0.020408165), (1, 0.16326603), (2, 0.020408165), (3, 0.020408165), (4, 0.16325806), (5, 0.30612624), (6, 0.30612513)]
# [(0, 0.11118947), (1, 0.25260007), (2, 0.23181465), (3, 0.12458488), (5, 0.13572685), (6, 0.13614453)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.035714287), (3, 0.28574264), (4, 0.035714287), (5, 0.035714287), (6, 0.5356859)]
# [(0, 0.17750566), (1, 0.015873028), (2, 0.12744133), (3, 0.015890848), (4, 0.23809569), (5, 0.015873019), (6, 0.40932047)]
# [(0, 0.04762113), (1, 0.04761905), (2, 0.38094994), (3, 0.04761905), (4, 0.047620457), (5, 0.04761905), (6, 0.38095132)]
# [(0, 0.0129989525), (1, 0.013005808), (2, 0.22986217), (3, 0.012997494), (4, 0.50088745), (5, 0.119426675), (6, 0.11082144)]
# [(0, 0.14233755), (1, 0.12346852), (2, 0.10607965), (3, 0.07058424), (4, 0.13531332), (5, 0.036600377), (6, 0.3856163)]
# [(0, 0.2803737), (1, 0.33156446), (2, 0.2735161), (3, 0.028602323), (4, 0.02861817), (5, 0.028605422), (6, 0.028719837)]
# [(0, 0.16326211), (1, 0.16325733), (2, 0.020408167), (3, 0.30661228), (4, 0.020408168), (5, 0.020408167), (6, 0.3056438)]
# [(1, 0.30073503), (2, 0.13934444), (4, 0.08849287), (5, 0.19616868), (6, 0.25844288)]
# [(0, 0.011904762), (1, 0.34523872), (2, 0.09919241), (3, 0.011908366), (4, 0.09608861), (5, 0.095237695), (6, 0.34042943)]
# [(2, 0.42016536), (3, 0.067170046), (4, 0.24370044), (6, 0.24369787)]
# [(0, 0.020436274), (1, 0.22159433), (2, 0.1904017), (3, 0.18954363), (4, 0.020450607), (5, 0.020429334), (6, 0.33714414)]
# [(0, 0.028807208), (1, 0.42857057), (2, 0.028571427), (3, 0.028571427), (4, 0.028571427), (5, 0.42833647), (6, 0.028571427)]
# [(0, 0.42299163), (1, 0.011013442), (2, 0.22038141), (3, 0.115569316), (4, 0.011069525), (5, 0.121424794), (6, 0.09754987)]
# [(0, 0.25777), (1, 0.12612882), (2, 0.09805072), (3, 0.04631983), (4, 0.052522305), (5, 0.046799455), (6, 0.37240887)]
# [(0, 0.035715353), (1, 0.035714287), (2, 0.035714287), (3, 0.035714287), (4, 0.035714287), (5, 0.28571376), (6, 0.5357138)]
# [(0, 0.015873019), (1, 0.015873019), (2, 0.015928183), (3, 0.01587332), (4, 0.01587306), (5, 0.015873019), (6, 0.9047064)]
# [(0, 0.028722947), (1, 0.028588112), (2, 0.25356552), (3, 0.02859036), (4, 0.028585518), (5, 0.24038097), (6, 0.39156657)]
# [(0, 0.011924137), (1, 0.2890378), (2, 0.22637309), (3, 0.22301555), (4, 0.12936194), (5, 0.011919379), (6, 0.1083681)]
# [(0, 0.38095102), (1, 0.047619052), (2, 0.047619045), (3, 0.047619045), (4, 0.38095373), (5, 0.047619045), (6, 0.047619045)]
# [(0, 0.5238206), (1, 0.19046362), (2, 0.023809528), (3, 0.19047774), (4, 0.023809528), (5, 0.023809528), (6, 0.023809528)]
# [(0, 0.02857143), (1, 0.02857143), (2, 0.22857277), (3, 0.028571427), (4, 0.22857137), (5, 0.42857012), (6, 0.028571427)]
# [(0, 0.010994194), (1, 0.2824238), (2, 0.11792374), (3, 0.11298692), (4, 0.010995881), (5, 0.010994017), (6, 0.45368144)]
# [(0, 0.1904832), (1, 0.19043265), (2, 0.023809532), (3, 0.02381024), (4, 0.19048996), (5, 0.3571649), (6, 0.02380953)]
# [(0, 0.18747547), (1, 0.020426586), (2, 0.40420842), (3, 0.020419642), (4, 0.020428983), (5, 0.020459305), (6, 0.32658157)]
# [(0, 0.2126359), (1, 0.18787618), (4, 0.1115885), (5, 0.10123038), (6, 0.36981657)]
# [(0, 0.13135357), (1, 0.010230465), (2, 0.17884925), (3, 0.29074305), (4, 0.01021568), (5, 0.010214073), (6, 0.36839393)]
# [(0, 0.011915682), (1, 0.24510594), (2, 0.011909755), (3, 0.18322906), (4, 0.22377022), (5, 0.011909973), (6, 0.31215936)]
# [(0, 0.23488295), (1, 0.23286091), (2, 0.0285736), (3, 0.23091856), (4, 0.028574621), (5, 0.028573755), (6, 0.21561559)]
# [(0, 0.16326709), (1, 0.16326469), (2, 0.16325524), (3, 0.44898847), (4, 0.020408167), (5, 0.020408165), (6, 0.020408165)]
# [(0, 0.023809524), (1, 0.35714293), (2, 0.5236691), (3, 0.023929203), (4, 0.023809524), (5, 0.023809524), (6, 0.02383016)]
# [(1, 0.0844425), (2, 0.34806502), (3, 0.17143375), (4, 0.08297972), (6, 0.29401615)]
# [(0, 0.11241897), (1, 0.31460854), (2, 0.21439996), (3, 0.014285758), (4, 0.0142857805), (5, 0.11433742), (6, 0.21566358)]
# [(0, 0.12684709), (1, 0.12701468), (2, 0.43587297), (3, 0.015873034), (4, 0.015874237), (5, 0.015873035), (6, 0.26264495)]
# [(0, 0.014285715), (1, 0.114204526), (2, 0.014285715), (3, 0.014285715), (4, 0.21428637), (5, 0.014367963), (6, 0.614284)]
# [(0, 0.017857147), (1, 0.01785715), (2, 0.2678591), (3, 0.017857147), (4, 0.26786482), (5, 0.14284615), (6, 0.26785854)]
# [(0, 0.03571429), (1, 0.03571429), (2, 0.2857136), (3, 0.03571429), (4, 0.03571429), (5, 0.28571373), (6, 0.28571555)]
# [(0, 0.21463688), (1, 0.014285736), (2, 0.4139072), (3, 0.10403047), (4, 0.014285731), (5, 0.0142857265), (6, 0.22456828)]
# [(0, 0.017868387), (1, 0.48720458), (2, 0.20257422), (3, 0.017867018), (4, 0.017872052), (5, 0.017868005), (6, 0.23874576)]
# [(0, 0.023975747), (1, 0.02380954), (2, 0.19044834), (3, 0.023809532), (4, 0.1904877), (5, 0.023809532), (6, 0.52365965)]
# [(0, 0.013038858), (1, 0.012999673), (2, 0.36806867), (3, 0.3614367), (4, 0.013058931), (5, 0.21832542), (6, 0.013071727)]
# [(0, 0.093410075), (1, 0.093256116), (2, 0.25469318), (3, 0.18482867), (4, 0.09324499), (5, 0.09321586), (6, 0.18735114)]
# [(0, 0.03581868), (1, 0.035715383), (2, 0.035764333), (3, 0.49186903), (4, 0.03571495), (5, 0.035715073), (6, 0.3294025)]
# [(0, 0.065307066), (2, 0.08591656), (3, 0.17137668), (5, 0.11796858), (6, 0.5451347)]
# [(0, 0.3809531), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.04761905), (5, 0.04761905), (6, 0.38095164)]
# [(0, 0.023810573), (1, 0.023809535), (2, 0.19048154), (3, 0.523789), (4, 0.19044559), (5, 0.023854284), (6, 0.023809528)]
# [(0, 0.020630607), (1, 0.020408165), (2, 0.020408165), (3, 0.3063775), (4, 0.1632679), (5, 0.16326728), (6, 0.30564037)]
# [(0, 0.035714284), (1, 0.28571427), (2, 0.53571427), (3, 0.035714295), (4, 0.035714284), (5, 0.035714284), (6, 0.035714284)]
# [(0, 0.020439995), (1, 0.39094293), (2, 0.3443555), (3, 0.18290028), (4, 0.020503229), (5, 0.02044212), (6, 0.02041594)]
# [(0, 0.017892694), (1, 0.330521), (2, 0.017889423), (3, 0.017888473), (4, 0.2436018), (5, 0.20608018), (6, 0.16612644)]
# [(0, 0.047619045), (1, 0.3809523), (2, 0.047619045), (3, 0.047619045), (4, 0.047619052), (5, 0.047619045), (6, 0.38095245)]
# [(1, 0.3310974), (2, 0.08626131), (3, 0.24807449), (5, 0.08713997), (6, 0.22835949)]
# [(0, 0.16326354), (1, 0.020408168), (2, 0.30612782), (3, 0.16326274), (4, 0.16326736), (5, 0.16326222), (6, 0.020408167)]
# [(0, 0.03571429), (1, 0.535714), (2, 0.03571429), (3, 0.03571429), (4, 0.03571429), (5, 0.03571429), (6, 0.28571463)]
# [(0, 0.048016544), (1, 0.10487416), (2, 0.22913241), (3, 0.16354491), (5, 0.09035242), (6, 0.35812664)]
# [(0, 0.014285879), (1, 0.114286795), (2, 0.3142843), (3, 0.21428323), (4, 0.21428831), (5, 0.014285716), (6, 0.11428578)]
# [(0, 0.115803696), (1, 0.07078041), (2, 0.42516184), (3, 0.091696545), (4, 0.13476157), (6, 0.15464728)]
# [(0, 0.28571424), (1, 0.5357143), (2, 0.035714287), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.035714287)]
# [(0, 0.015904155), (1, 0.015922211), (2, 0.015901066), (3, 0.35261658), (4, 0.01591444), (5, 0.015945733), (6, 0.5677958)]
# [(0, 0.017857146), (1, 0.26786068), (2, 0.14285813), (3, 0.017857227), (4, 0.017857146), (5, 0.017857146), (6, 0.51785254)]
# [(0, 0.35711166), (1, 0.35713878), (2, 0.023809524), (3, 0.023843786), (4, 0.023809627), (5, 0.19041036), (6, 0.02387623)]
# [(0, 0.24204257), (1, 0.13412252), (2, 0.124498904), (3, 0.124217294), (4, 0.13037881), (5, 0.12534013), (6, 0.11939982)]
# [(0, 0.014301568), (1, 0.31961524), (2, 0.13406824), (3, 0.014299631), (4, 0.014306763), (5, 0.2665904), (6, 0.23681816)]
# [(0, 0.06995449), (1, 0.1703077), (2, 0.26665288), (3, 0.10157279), (6, 0.37720266)]
# [(0, 0.028571438), (1, 0.2285796), (2, 0.22858128), (3, 0.22854257), (4, 0.028571445), (5, 0.22858158), (6, 0.028572101)]
# [(0, 0.01785715), (1, 0.017857151), (2, 0.017860549), (3, 0.017887425), (4, 0.14324546), (5, 0.01785715), (6, 0.76743513)]
# [(0, 0.014285715), (1, 0.014285715), (2, 0.24641064), (3, 0.41428185), (4, 0.014285715), (5, 0.1142866), (6, 0.18216373)]
# [(0, 0.282507), (1, 0.02863636), (2, 0.574365), (3, 0.028607553), (4, 0.028626123), (5, 0.028611187), (6, 0.028646708)]
# [(0, 0.61176753), (1, 0.023890233), (2, 0.26891682), (3, 0.02385406), (4, 0.023877693), (5, 0.02385957), (6, 0.023834107)]
# [(0, 0.42858252), (1, 0.22857907), (2, 0.028681869), (3, 0.028571436), (4, 0.028571436), (5, 0.028571436), (6, 0.22844219)]
# [(0, 0.023810066), (1, 0.18972696), (2, 0.69122434), (3, 0.023809658), (4, 0.023809718), (5, 0.023809666), (6, 0.023809595)]
# [(0, 0.16487616), (1, 0.22789331), (4, 0.10198424), (6, 0.4784165)]
# [(0, 0.06755718), (1, 0.1944455), (2, 0.0817642), (3, 0.10871961), (4, 0.16466828), (6, 0.37805927)]
# [(0, 0.012987017), (1, 0.103897594), (2, 0.012987017), (3, 0.19481093), (4, 0.23764463), (5, 0.012987017), (6, 0.42468578)]
# [(0, 0.07619108), (1, 0.07618969), (3, 0.29459867), (4, 0.20952727), (6, 0.32444566)]
# [(0, 0.14443316), (1, 0.15054221), (2, 0.14246984), (3, 0.109296024), (4, 0.088792175), (6, 0.35553142)]
# [(0, 0.16249758), (1, 0.01788058), (2, 0.017870538), (3, 0.1597035), (4, 0.33622405), (5, 0.017871525), (6, 0.2879522)]
# [(0, 0.03571429), (1, 0.03571429), (2, 0.53571254), (3, 0.03571429), (4, 0.28571603), (5, 0.03571429), (6, 0.035714287)]
# [(0, 0.3913987), (1, 0.04762533), (2, 0.047622636), (3, 0.047622543), (4, 0.04762432), (5, 0.04762289), (6, 0.3704836)]
# [(0, 0.09523674), (1, 0.09523059), (2, 0.09524187), (3, 0.17857933), (4, 0.011904768), (5, 0.17858095), (6, 0.34522572)]
# [(0, 0.028577853), (1, 0.028614938), (2, 0.23643386), (3, 0.028576031), (4, 0.41768536), (5, 0.028576488), (6, 0.23153548)]
# [(0, 0.7856983), (1, 0.03571429), (2, 0.03571429), (3, 0.035730284), (4, 0.03571429), (5, 0.03571429), (6, 0.03571429)]
# [(0, 0.14283937), (1, 0.26786584), (2, 0.01785715), (3, 0.14286402), (4, 0.14285879), (5, 0.267841), (6, 0.017873853)]
# [(0, 0.30624247), (1, 0.30586582), (2, 0.30609038), (3, 0.020576661), (4, 0.020408232), (5, 0.020408215), (6, 0.020408189)]
# [(0, 0.11286561), (1, 0.23148823), (2, 0.110901766), (3, 0.11164887), (4, 0.012996608), (5, 0.21560854), (6, 0.20449036)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.04761905), (5, 0.3809525), (6, 0.38095224)]
# [(1, 0.33289376), (2, 0.18498066), (3, 0.12614077), (4, 0.06722787), (6, 0.27193952)]
# [(0, 0.010217176), (1, 0.12074374), (2, 0.1972497), (3, 0.20498177), (4, 0.2701452), (5, 0.010239319), (6, 0.18642308)]
# [(0, 0.02380955), (1, 0.19039102), (2, 0.26950434), (3, 0.27795443), (4, 0.19044574), (5, 0.023809543), (6, 0.024085416)]
# [(0, 0.020408215), (1, 0.30637378), (2, 0.16292615), (3, 0.19381113), (4, 0.27566436), (5, 0.0204082), (6, 0.020408181)]
# [(1, 0.34840673), (2, 0.06707081), (4, 0.06250425), (5, 0.15033765), (6, 0.35919908)]
# [(0, 0.21649055), (1, 0.14285704), (2, 0.19242284), (3, 0.015881505), (4, 0.015879076), (5, 0.015877325), (6, 0.40059167)]
# [(0, 0.1170058), (1, 0.18314797), (2, 0.08074157), (3, 0.121597), (4, 0.15397023), (5, 0.11670461), (6, 0.22683282)]
# [(0, 0.12402661), (1, 0.1155248), (2, 0.024833236), (3, 0.21480256), (5, 0.14763741), (6, 0.36982116)]
# [(0, 0.2745885), (1, 0.15489872), (2, 0.01588398), (3, 0.14078817), (4, 0.015889196), (5, 0.14221014), (6, 0.25574127)]
# [(0, 0.103891835), (1, 0.012987016), (2, 0.012987016), (3, 0.19480807), (4, 0.19480212), (5, 0.19480789), (6, 0.2857161)]
# [(0, 0.12698524), (1, 0.3492101), (2, 0.01587335), (3, 0.12702997), (4, 0.23809814), (5, 0.015873017), (6, 0.1269302)]
# [(0, 0.011910095), (1, 0.2045276), (2, 0.011937491), (3, 0.17720717), (4, 0.10407234), (5, 0.37802258), (6, 0.11232269)]
# [(1, 0.05759971), (2, 0.14088018), (3, 0.14533928), (4, 0.28782496), (5, 0.08953869), (6, 0.27405035)]
# [(1, 0.17099011), (3, 0.071510494), (4, 0.35021147), (5, 0.072167285), (6, 0.31830594)]
# [(1, 0.18098551), (2, 0.20685974), (4, 0.29624608), (5, 0.21920943), (6, 0.0788371)]
# [(0, 0.09671589), (1, 0.119317055), (2, 0.13272306), (3, 0.08467279), (4, 0.13864695), (5, 0.04154725), (6, 0.386377)]
# [(0, 0.1579552), (1, 0.06748684), (2, 0.36058983), (3, 0.13428995), (4, 0.19369633), (6, 0.077568896)]
# [(0, 0.28106287), (1, 0.33177373), (2, 0.028603366), (3, 0.27274722), (4, 0.02861849), (5, 0.028605655), (6, 0.028588673)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.035714287), (3, 0.2857144), (4, 0.035714287), (5, 0.5357142), (6, 0.035714287)]
# [(0, 0.02040854), (1, 0.020408168), (2, 0.30612665), (3, 0.16326748), (4, 0.16325568), (5, 0.020408168), (6, 0.30612534)]
# [(0, 0.020408172), (1, 0.35542062), (2, 0.16695559), (3, 0.020442605), (4, 0.02041676), (5, 0.39591366), (6, 0.020442631)]
# [(0, 0.012001388), (1, 0.011992726), (2, 0.47797334), (3, 0.21724592), (4, 0.011922768), (5, 0.011917419), (6, 0.2569464)]
# [(0, 0.017857144), (1, 0.39285678), (2, 0.017934222), (3, 0.017857146), (4, 0.2802928), (5, 0.01789055), (6, 0.25531134)]
# [(0, 0.36493084), (1, 0.023810795), (2, 0.18844765), (3, 0.02381023), (4, 0.02381059), (5, 0.023810303), (6, 0.3513796)]
# [(0, 0.24058808), (1, 0.01300905), (2, 0.25359148), (3, 0.1291526), (4, 0.013001788), (5, 0.103958055), (6, 0.24669895)]
# [(0, 0.012987014), (1, 0.28571647), (2, 0.1913321), (3, 0.012987017), (4, 0.103896186), (5, 0.10390239), (6, 0.28917882)]
# [(0, 0.22857201), (1, 0.22857244), (2, 0.028662777), (3, 0.028590625), (4, 0.028710935), (5, 0.028627992), (6, 0.4282632)]
# [(0, 0.20315525), (1, 0.3494276), (2, 0.015873047), (3, 0.015873047), (4, 0.12701054), (5, 0.12663876), (6, 0.16202173)]
# [(1, 0.25791582), (2, 0.16885512), (3, 0.046646934), (4, 0.101911046), (6, 0.41320828)]
# [(0, 0.13410573), (1, 0.13393387), (2, 0.25870943), (4, 0.104737125), (5, 0.13393024), (6, 0.2256261)]
# [(0, 0.066544995), (1, 0.07419274), (2, 0.28671294), (3, 0.2745818), (6, 0.2836576)]
# [(1, 0.056235366), (2, 0.25754312), (3, 0.34662408), (4, 0.08282369), (5, 0.05722975), (6, 0.19239616)]
# [(0, 0.020425271), (1, 0.20397213), (2, 0.020423587), (3, 0.020423185), (4, 0.38461754), (5, 0.020424688), (6, 0.32971358)]
# [(0, 0.02042365), (1, 0.39228603), (2, 0.020422129), (3, 0.020421768), (4, 0.19179074), (5, 0.18260007), (6, 0.17205559)]
# [(0, 0.12469788), (1, 0.13499048), (2, 0.4690124), (3, 0.014293907), (4, 0.014297999), (5, 0.014295099), (6, 0.22841227)]
# [(0, 0.010204096), (1, 0.08106477), (2, 0.010204087), (3, 0.08166284), (4, 0.22502531), (5, 0.08163869), (6, 0.5102002)]
# [(0, 0.100973584), (1, 0.29669595), (2, 0.19009842), (3, 0.0119087985), (4, 0.29065245), (5, 0.011923908), (6, 0.09774686)]
# [(0, 0.028571432), (1, 0.22857514), (2, 0.028571432), (3, 0.428567), (4, 0.028571432), (5, 0.028571432), (6, 0.22857217)]
# [(0, 0.061741672), (1, 0.24800399), (2, 0.116938725), (4, 0.18202356), (6, 0.37699947)]
# [(0, 0.015873017), (1, 0.3492067), (2, 0.015873017), (3, 0.01587336), (4, 0.23809583), (5, 0.23809488), (6, 0.12698315)]
# [(0, 0.010265203), (1, 0.010226263), (2, 0.160663), (3, 0.37171945), (4, 0.1326475), (5, 0.10596017), (6, 0.2085184)]
# [(0, 0.0142858345), (1, 0.21428618), (2, 0.41428453), (3, 0.21428585), (4, 0.014285716), (5, 0.11428616), (6, 0.014285715)]
# [(0, 0.010989115), (1, 0.16483256), (2, 0.5417171), (3, 0.08791207), (4, 0.010989013), (5, 0.010989012), (6, 0.17257112)]
# [(0, 0.09523943), (1, 0.26191267), (2, 0.09522795), (3, 0.011909044), (4, 0.09938964), (5, 0.011904764), (6, 0.4244165)]
# [(0, 0.3135236), (1, 0.02857143), (2, 0.22857109), (3, 0.028571773), (4, 0.02857143), (5, 0.02857143), (6, 0.3436193)]
# [(0, 0.0143064065), (1, 0.014317702), (2, 0.14204198), (3, 0.27760562), (4, 0.16289678), (5, 0.14425683), (6, 0.24457467)]
# [(0, 0.0102109965), (1, 0.1901778), (2, 0.010210317), (3, 0.17138892), (4, 0.41018826), (5, 0.0102121625), (6, 0.19761157)]
# [(0, 0.285716), (1, 0.03571429), (2, 0.03571429), (3, 0.03571429), (4, 0.03603253), (5, 0.03571429), (6, 0.5353943)]
# [(0, 0.0625491), (1, 0.29533613), (2, 0.1360777), (3, 0.19043522), (4, 0.06320772), (5, 0.11802652), (6, 0.13436761)]
# [(0, 0.04761907), (1, 0.04761908), (2, 0.047619063), (3, 0.38094035), (4, 0.38096428), (5, 0.04761907), (6, 0.04761906)]
# [(0, 0.017889485), (1, 0.017909069), (2, 0.3848188), (3, 0.38023144), (4, 0.01790024), (5, 0.017888172), (6, 0.16336282)]
# [(0, 0.04761905), (1, 0.38095203), (2, 0.04761905), (3, 0.04761905), (4, 0.38095272), (5, 0.04761905), (6, 0.04761905)]
# [(0, 0.047701743), (1, 0.7138221), (2, 0.047693998), (3, 0.047691386), (4, 0.04773296), (5, 0.0476996), (6, 0.047658194)]
# [(0, 0.1428841), (1, 0.2760947), (2, 0.08632713), (3, 0.11124354), (5, 0.07620338), (6, 0.2977233)]
# [(0, 0.012993377), (1, 0.2263093), (2, 0.11082008), (3, 0.20037833), (4, 0.22060579), (5, 0.11136737), (6, 0.117525786)]
# [(1, 0.12571533), (2, 0.03294943), (3, 0.10109124), (4, 0.34694993), (5, 0.24263123), (6, 0.14656201)]
# [(1, 0.27068815), (2, 0.21317156), (4, 0.15450016), (5, 0.14530642), (6, 0.19948272)]
# [(0, 0.042942174), (1, 0.084811665), (2, 0.1192183), (3, 0.10379728), (4, 0.2824313), (5, 0.23582587), (6, 0.13097338)]
# [(0, 0.12532637), (1, 0.014299525), (2, 0.014293643), (3, 0.014293435), (4, 0.3737074), (5, 0.12490539), (6, 0.33317426)]
# [(0, 0.01785715), (1, 0.49758613), (2, 0.017979987), (3, 0.14258665), (4, 0.017950887), (5, 0.01785715), (6, 0.28818208)]
# [(0, 0.03576688), (1, 0.46344027), (2, 0.35774377), (3, 0.035760444), (4, 0.035784174), (5, 0.035765085), (6, 0.03573942)]
# [(0, 0.010994083), (1, 0.18855166), (2, 0.26230663), (3, 0.010993427), (4, 0.010995593), (5, 0.26393694), (6, 0.25222164)]
# [(0, 0.012995151), (1, 0.12152919), (2, 0.32060337), (3, 0.012994158), (4, 0.11820065), (5, 0.01300919), (6, 0.40066832)]
# [(0, 0.02383623), (1, 0.26311257), (2, 0.023833565), (3, 0.023832953), (4, 0.24647368), (5, 0.023835277), (6, 0.39507568)]
# [(0, 0.09790295), (1, 0.2339304), (2, 0.0348786), (3, 0.097501434), (4, 0.03554106), (5, 0.18448706), (6, 0.31575847)]
# [(1, 0.13901877), (2, 0.33681113), (3, 0.058164585), (5, 0.030919695), (6, 0.42793876)]
# [(0, 0.07504948), (1, 0.15828031), (2, 0.13883299), (3, 0.34672692), (6, 0.26428995)]
# [(0, 0.19244736), (1, 0.05847451), (3, 0.10529358), (4, 0.0577693), (5, 0.056397125), (6, 0.5228073)]
# [(0, 0.07060939), (1, 0.503016), (2, 0.06470151), (5, 0.11924631), (6, 0.22653627)]
# [(0, 0.081626974), (1, 0.2243409), (2, 0.15310256), (3, 0.08705903), (4, 0.08165852), (5, 0.08165127), (6, 0.29056072)]
# [(0, 0.16250865), (1, 0.020408165), (2, 0.020408165), (3, 0.1632806), (4, 0.30612317), (5, 0.020408165), (6, 0.30686307)]
# [(0, 0.010209341), (1, 0.37556568), (2, 0.010231855), (3, 0.18035865), (4, 0.2317819), (5, 0.095975354), (6, 0.0958772)]
# [(1, 0.10854688), (3, 0.093209945), (4, 0.21635868), (5, 0.25277516), (6, 0.31124613)]
# [(0, 0.035714287), (1, 0.035832237), (2, 0.035718877), (3, 0.035714287), (4, 0.035742234), (5, 0.035771415), (6, 0.78550667)]
# [(0, 0.18917906), (1, 0.10841648), (2, 0.12656486), (3, 0.1982026), (5, 0.16239063), (6, 0.2090149)]
# [(0, 0.03596819), (1, 0.035714287), (2, 0.035714287), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.78546035)]
# [(0, 0.16436295), (1, 0.020710688), (2, 0.16238967), (3, 0.4482558), (4, 0.020559063), (5, 0.020408262), (6, 0.16331355)]
# [(0, 0.02857143), (1, 0.42857343), (2, 0.028577304), (3, 0.02857143), (4, 0.02857143), (5, 0.028607119), (6, 0.4285279)]
# [(0, 0.16399615), (1, 0.020409347), (2, 0.30059895), (3, 0.020408863), (4, 0.30340508), (5, 0.020408848), (6, 0.17077278)]
# [(0, 0.03571559), (1, 0.035714287), (2, 0.53571284), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.28571448)]
# [(0, 0.16178884), (1, 0.015908321), (2, 0.31987616), (3, 0.14538895), (4, 0.18101352), (5, 0.1601285), (6, 0.015895663)]
# [(0, 0.01194043), (1, 0.122892946), (2, 0.20971315), (3, 0.21329385), (4, 0.23506905), (5, 0.011915154), (6, 0.1951754)]
# [(0, 0.012987014), (1, 0.10389555), (2, 0.39510736), (3, 0.013076389), (4, 0.13611336), (5, 0.012996214), (6, 0.32582408)]
# [(0, 0.017867777), (1, 0.47777683), (2, 0.29550678), (3, 0.01786623), (4, 0.017870858), (5, 0.15524948), (6, 0.017862104)]
# [(0, 0.023809524), (1, 0.19047765), (2, 0.35714075), (3, 0.023809738), (4, 0.023809524), (5, 0.023809524), (6, 0.35714328)]
# [(0, 0.011907609), (1, 0.31744325), (2, 0.098185204), (3, 0.09808662), (4, 0.27890173), (5, 0.09840436), (6, 0.097071216)]
# [(0, 0.014396982), (1, 0.014333652), (2, 0.11430105), (3, 0.31447676), (4, 0.014327397), (5, 0.11402704), (6, 0.41413718)]
# [(0, 0.082478136), (1, 0.16380472), (2, 0.19905654), (3, 0.16894294), (4, 0.08688251), (5, 0.082174756), (6, 0.21666038)]
# [(0, 0.03572232), (1, 0.30060792), (2, 0.035741538), (3, 0.25893265), (4, 0.035764325), (5, 0.035722036), (6, 0.29750922)]
# [(0, 0.04762113), (1, 0.38082048), (2, 0.38095555), (3, 0.047619045), (4, 0.047619045), (5, 0.047619045), (6, 0.047745675)]
# [(0, 0.028609425), (1, 0.3497668), (2, 0.22963369), (3, 0.3062207), (4, 0.028612316), (5, 0.02857152), (6, 0.028585589)]
# [(0, 0.34248245), (1, 0.028633147), (2, 0.02863592), (3, 0.028605808), (4, 0.028623456), (5, 0.5144051), (6, 0.02861416)]
# [(0, 0.03579428), (1, 0.035716984), (2, 0.035729285), (3, 0.03572823), (4, 0.53364736), (5, 0.28755286), (6, 0.035830956)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.047859564), (3, 0.3808225), (4, 0.04761905), (5, 0.04761905), (6, 0.38084176)]
# [(1, 0.14245978), (2, 0.053656086), (3, 0.25501728), (4, 0.24316819), (5, 0.16607374), (6, 0.13515931)]
# [(0, 0.03779385), (1, 0.18658935), (2, 0.07257346), (3, 0.21220309), (4, 0.2277741), (5, 0.15841109), (6, 0.1046551)]
# [(0, 0.012987138), (1, 0.1036596), (2, 0.37664846), (3, 0.37665367), (4, 0.10407686), (5, 0.01298702), (6, 0.012987209)]
# [(0, 0.14285997), (1, 0.01791709), (2, 0.14286262), (3, 0.14285217), (4, 0.018028926), (5, 0.01793745), (6, 0.51754177)]
# [(0, 0.19082493), (1, 0.02857143), (2, 0.028616067), (3, 0.028737655), (4, 0.26620448), (5, 0.2285717), (6, 0.22847378)]
# [(0, 0.18461937), (1, 0.14795886), (2, 0.050274026), (3, 0.23828505), (4, 0.096139036), (5, 0.13605271), (6, 0.14667097)]
# [(0, 0.02857143), (1, 0.028571432), (2, 0.22856379), (3, 0.02857143), (4, 0.42858005), (5, 0.02857143), (6, 0.22857045)]
# [(0, 0.28567123), (1, 0.28571653), (2, 0.28569523), (3, 0.0357143), (4, 0.035714302), (5, 0.03571433), (6, 0.03577412)]
# [(0, 0.010989013), (1, 0.08790515), (2, 0.29667658), (3, 0.15841733), (4, 0.19325355), (5, 0.010989013), (6, 0.2417694)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.04761905), (5, 0.04761905), (6, 0.7142857)]
# [(0, 0.017951004), (1, 0.017878978), (2, 0.017870301), (3, 0.017963083), (4, 0.16856547), (5, 0.16026957), (6, 0.5995016)]
# [(0, 0.04761905), (1, 0.38093802), (2, 0.047738444), (3, 0.38084736), (4, 0.04761905), (5, 0.04761905), (6, 0.04761905)]
# [(0, 0.10523), (1, 0.25880152), (2, 0.075527616), (3, 0.28362107), (4, 0.071442306), (6, 0.19644895)]
# [(0, 0.02383902), (1, 0.27645037), (2, 0.22848815), (3, 0.023835413), (4, 0.023848694), (5, 0.02383801), (6, 0.3997004)]
# [(1, 0.16563588), (2, 0.13696277), (3, 0.19702868), (4, 0.19439484), (5, 0.12535682), (6, 0.17488004)]
# [(0, 0.011994905), (1, 0.1785648), (2, 0.13299926), (3, 0.15928964), (4, 0.17857231), (5, 0.09523795), (6, 0.24334116)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.035714287), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.78571427)]
# [(0, 0.01596855), (1, 0.15949193), (2, 0.015885867), (3, 0.27549988), (4, 0.015891023), (5, 0.015952837), (6, 0.50130993)]
# [(0, 0.01787184), (1, 0.17755741), (2, 0.26417947), (3, 0.15949492), (4, 0.17051779), (5, 0.017871339), (6, 0.19250719)]
# [(0, 0.011911196), (1, 0.3089625), (2, 0.10173503), (3, 0.1312045), (4, 0.011912663), (5, 0.01191052), (6, 0.42236355)]
# [(0, 0.10794614), (2, 0.17632887), (3, 0.11255156), (6, 0.57617253)]
# [(0, 0.011102521), (1, 0.18964025), (2, 0.20028268), (3, 0.17779435), (4, 0.096347585), (5, 0.09382759), (6, 0.23100498)]
# [(1, 0.22751677), (2, 0.083924286), (3, 0.25289714), (4, 0.13887416), (6, 0.2861998)]
# [(0, 0.269069), (2, 0.10521287), (3, 0.094982214), (4, 0.23969272), (5, 0.075274915), (6, 0.20683448)]
# [(0, 0.047449786), (1, 0.17625727), (2, 0.101651385), (3, 0.111535415), (5, 0.12391701), (6, 0.4345657)]
# [(0, 0.023829771), (1, 0.47478247), (2, 0.023827776), (3, 0.2135572), (4, 0.023836387), (5, 0.21634717), (6, 0.023819223)]
# [(0, 0.22857288), (1, 0.02857143), (2, 0.028583001), (3, 0.02858374), (4, 0.028571744), (5, 0.02857143), (6, 0.6285458)]
# [(0, 0.03597958), (1, 0.03617462), (2, 0.29299963), (3, 0.036041208), (4, 0.035998948), (5, 0.03571488), (6, 0.52709115)]
# [(0, 0.21191745), (1, 0.21897778), (2, 0.07962656), (3, 0.15432589), (5, 0.14231412), (6, 0.1839056)]
# [(1, 0.54937917), (2, 0.12619969), (3, 0.12573907), (6, 0.17606665)]
# [(0, 0.047619045), (1, 0.047619045), (2, 0.047619045), (3, 0.38095254), (4, 0.047619045), (5, 0.047619045), (6, 0.38095224)]
# [(0, 0.19267215), (1, 0.05027179), (3, 0.35633162), (4, 0.059143245), (5, 0.25722146), (6, 0.07840605)]
# [(0, 0.15144905), (1, 0.34584898), (2, 0.1528639), (4, 0.15582757), (6, 0.17718661)]
# [(1, 0.23570336), (2, 0.16328526), (3, 0.20064892), (4, 0.03356303), (5, 0.12572563), (6, 0.23720285)]
# [(0, 0.010211932), (1, 0.2162436), (2, 0.09022658), (3, 0.3158991), (4, 0.18613836), (5, 0.095426425), (6, 0.085853994)]
# [(0, 0.014376486), (1, 0.14018618), (2, 0.24554995), (3, 0.014295531), (4, 0.014300542), (5, 0.014333648), (6, 0.5569577)]
# [(0, 0.05694026), (1, 0.19575235), (2, 0.14579743), (3, 0.13163783), (5, 0.14812781), (6, 0.31697667)]
# [(0, 0.19158596), (1, 0.19047727), (2, 0.18933214), (3, 0.3571055), (4, 0.023838865), (5, 0.023809535), (6, 0.02385073)]
# [(0, 0.108233236), (1, 0.19572283), (2, 0.104535334), (3, 0.24265662), (4, 0.22050649), (5, 0.012988057), (6, 0.11535742)]
# [(1, 0.2872971), (3, 0.16209929), (4, 0.1493046), (5, 0.16347082), (6, 0.22419782)]
# [(0, 0.020409057), (1, 0.16326843), (2, 0.1636114), (3, 0.16285571), (4, 0.44897512), (5, 0.020408167), (6, 0.020472128)]
# [(0, 0.07548578), (1, 0.22217792), (2, 0.07505448), (3, 0.22000867), (6, 0.3894082)]
# [(0, 0.035715852), (1, 0.28571215), (2, 0.28571376), (3, 0.035714287), (4, 0.03571429), (5, 0.28562295), (6, 0.0358067)]
# [(0, 0.012987026), (1, 0.10391452), (2, 0.11503117), (3, 0.19991964), (4, 0.2333325), (5, 0.013057221), (6, 0.3217579)]
# [(0, 0.020408168), (1, 0.30611092), (2, 0.020421306), (3, 0.44898304), (4, 0.16326019), (5, 0.020408168), (6, 0.020408167)]
# [(0, 0.023810333), (1, 0.023809524), (2, 0.22563471), (3, 0.023883564), (4, 0.32187802), (5, 0.19047542), (6, 0.19050844)]
# [(0, 0.08393384), (1, 0.3166759), (2, 0.08606639), (3, 0.010207755), (4, 0.010209625), (5, 0.16467173), (6, 0.32823473)]
# [(0, 0.28619942), (1, 0.03571444), (2, 0.53522867), (3, 0.035714373), (4, 0.035714414), (5, 0.03571438), (6, 0.035714336)]
# [(1, 0.52906436), (2, 0.07601639), (3, 0.14460841), (4, 0.22351189)]
# [(0, 0.014285991), (1, 0.11430021), (2, 0.21431641), (3, 0.21464252), (4, 0.014285734), (5, 0.214202), (6, 0.21396713)]
# [(1, 0.12097326), (2, 0.07671751), (3, 0.26706648), (4, 0.2809661), (5, 0.07684428), (6, 0.16789648)]
# [(0, 0.18146227), (1, 0.0991904), (2, 0.08664184), (3, 0.2255924), (4, 0.18201095), (5, 0.010989039), (6, 0.2141131)]
# [(0, 0.12998016), (1, 0.35514018), (3, 0.16923793), (4, 0.07037207), (5, 0.12923832), (6, 0.13850757)]
# [(0, 0.04761905), (1, 0.38095295), (2, 0.04761905), (3, 0.04761905), (4, 0.04761905), (5, 0.38095176), (6, 0.04761905)]
# [(0, 0.42170691), (1, 0.03582842), (2, 0.39934552), (3, 0.035777226), (4, 0.035809856), (5, 0.035783585), (6, 0.035748504)]
# [(2, 0.23693651), (3, 0.09163144), (4, 0.33338732), (5, 0.23133841), (6, 0.08989308)]
# [(2, 0.6341625), (5, 0.16645811), (6, 0.16124716)]
# [(0, 0.26459172), (1, 0.098104514), (2, 0.17402764), (3, 0.046189576), (4, 0.048578404), (6, 0.36321375)]
# [(0, 0.02040829), (1, 0.02040836), (2, 0.16338734), (3, 0.30575046), (4, 0.020408487), (5, 0.020408286), (6, 0.44922873)]
# [(0, 0.1261934), (1, 0.23833121), (2, 0.23791426), (3, 0.23820297), (4, 0.015873093), (5, 0.015873073), (6, 0.12761198)]
# [(0, 0.028571432), (1, 0.028571432), (2, 0.4772059), (3, 0.02877387), (4, 0.028571432), (5, 0.028571432), (6, 0.3797345)]
# [(0, 0.057739355), (1, 0.2173043), (3, 0.21239108), (4, 0.3838501), (5, 0.06597207), (6, 0.055937868)]
# [(0, 0.023809528), (1, 0.19046064), (2, 0.023809524), (3, 0.3571631), (4, 0.023809528), (5, 0.023809524), (6, 0.35713816)]
# [(0, 0.1062056), (1, 0.20563564), (2, 0.051922195), (3, 0.141298), (4, 0.35207883), (6, 0.13756177)]
# [(0, 0.028572684), (1, 0.028571436), (2, 0.22857562), (3, 0.42858535), (4, 0.02857144), (5, 0.028571432), (6, 0.22855201)]
# [(0, 0.047619045), (1, 0.38095295), (2, 0.047619045), (3, 0.047619045), (4, 0.047619045), (5, 0.047619045), (6, 0.38095176)]
# [(0, 0.067239635), (1, 0.18489367), (2, 0.13681278), (4, 0.20989315), (5, 0.3212966), (6, 0.071459785)]
# [(0, 0.028886512), (1, 0.22859502), (2, 0.028571445), (3, 0.42837566), (4, 0.02857146), (5, 0.028571445), (6, 0.22842845)]
# [(0, 0.17053859), (1, 0.16409063), (2, 0.020460833), (3, 0.16368592), (4, 0.020645862), (5, 0.020409921), (6, 0.44016826)]
# [(0, 0.012987015), (1, 0.19480772), (2, 0.10389697), (3, 0.2856961), (4, 0.28571713), (5, 0.10389671), (6, 0.0129983965)]
# ...
# [(0, 0.047702074), (1, 0.71382284), (2, 0.047693413), (3, 0.047691505), (4, 0.047733128), (5, 0.04769886), (6, 0.047658186)]
# [(0, 0.38325238), (1, 0.047619045), (2, 0.37865233), (3, 0.047619045), (4, 0.047619045), (5, 0.047619045), (6, 0.047619045)]
# [(0, 0.28891438), (1, 0.028633242), (2, 0.028606767), (3, 0.02860584), (4, 0.028623521), (5, 0.5680261), (6, 0.028590173)]
# [(0, 0.023838766), (1, 0.02392166), (2, 0.023835883), (3, 0.023835192), (4, 0.3373331), (5, 0.023837768), (6, 0.5433976)]
# [(0, 0.023809528), (1, 0.19046678), (2, 0.023809528), (3, 0.023809528), (4, 0.5238201), (5, 0.023809528), (6, 0.19047505)]
# [(0, 0.114304624), (1, 0.4142109), (2, 0.0142949), (3, 0.31432194), (4, 0.014285719), (5, 0.11428974), (6, 0.014292193)]
# [(0, 0.03586264), (1, 0.035714332), (2, 0.035716362), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.7855638)]
# [(0, 0.10507286), (1, 0.19642535), (3, 0.071425386), (4, 0.19643106), (5, 0.13393044), (6, 0.28778636)]
# [(0, 0.03580868), (1, 0.03586254), (2, 0.46900958), (3, 0.035796385), (4, 0.035838958), (5, 0.035804663), (6, 0.3518792)]
# [(0, 0.04761906), (1, 0.04761907), (2, 0.04761906), (3, 0.3809483), (4, 0.047619067), (5, 0.04761906), (6, 0.38095635)]
# [(0, 0.028602913), (1, 0.028621007), (2, 0.26784268), (3, 0.028599065), (4, 0.589146), (5, 0.028601836), (6, 0.028586496)]
# [(0, 0.7142286), (1, 0.047619253), (2, 0.047621027), (3, 0.04761914), (4, 0.04761919), (5, 0.04761915), (6, 0.04767364)]
# [(0, 0.03571659), (1, 0.035717897), (2, 0.22322685), (3, 0.5979848), (4, 0.03583925), (5, 0.03572631), (6, 0.035788324)]
# [(0, 0.02386274), (1, 0.023952119), (2, 0.280029), (3, 0.023855653), (4, 0.3943867), (5, 0.023860317), (6, 0.23005344)]
# [(0, 0.028571438), (1, 0.22858791), (2, 0.4285826), (3, 0.028572436), (4, 0.22845347), (5, 0.028642952), (6, 0.028589189)]
# [(1, 0.06727512), (2, 0.2378395), (3, 0.16332443), (4, 0.07219166), (5, 0.16857782), (6, 0.2823529)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.5357164), (3, 0.035714287), (4, 0.035714287), (5, 0.035714287), (6, 0.28571215)]
# [(0, 0.035803985), (1, 0.03607261), (2, 0.45870432), (3, 0.035848524), (4, 0.03583378), (5, 0.035800893), (6, 0.3619359)]
# [(0, 0.081925206), (1, 0.2521057), (2, 0.15554047), (3, 0.082489386), (4, 0.33625287), (5, 0.08214848)]
# [(0, 0.28571433), (1, 0.03571429), (2, 0.03571429), (3, 0.035914093), (4, 0.03571429), (5, 0.03571429), (6, 0.5355145)]
# [(0, 0.38095248), (1, 0.047619045), (2, 0.04761986), (3, 0.047619045), (4, 0.38095146), (5, 0.047619045), (6, 0.047619045)]
# [(0, 0.020408168), (1, 0.02040817), (2, 0.02048574), (3, 0.3061115), (4, 0.16327122), (5, 0.020408168), (6, 0.44890705)]
# [(0, 0.047619063), (1, 0.047619075), (2, 0.047619063), (3, 0.38094833), (4, 0.04761907), (5, 0.047619063), (6, 0.38095632)]
# [(0, 0.011914526), (1, 0.22454698), (2, 0.106033616), (3, 0.011912943), (4, 0.43743446), (5, 0.011913762), (6, 0.19624369)]
# [(0, 0.3808148), (1, 0.04761946), (2, 0.047803253), (3, 0.047784105), (4, 0.04761939), (5, 0.047619298), (6, 0.38073972)]
# [(0, 0.015873019), (1, 0.23810087), (2, 0.23808922), (3, 0.01587302), (4, 0.015873019), (5, 0.015873019), (6, 0.46031782)]
# [(0, 0.1269884), (1, 0.12699085), (2, 0.015874121), (3, 0.01587302), (4, 0.015873022), (5, 0.13465889), (6, 0.5637417)]
# [(0, 0.014297743), (1, 0.34890792), (2, 0.014296604), (3, 0.24738328), (4, 0.12364285), (5, 0.12965745), (6, 0.12181412)]
# [(0, 0.023810571), (1, 0.02380953), (2, 0.19047761), (3, 0.3148466), (4, 0.02380953), (5, 0.19047944), (6, 0.23276673)]
# [(0, 0.22852042), (1, 0.02857143), (2, 0.02857143), (3, 0.22846732), (4, 0.42856994), (5, 0.02857143), (6, 0.028728027)]
# [(0, 0.01588483), (1, 0.52996945), (2, 0.14056689), (3, 0.14010149), (4, 0.01588869), (5, 0.14170961), (6, 0.01587903)]
# [(0, 0.02857143), (1, 0.42857513), (2, 0.02857143), (3, 0.2285682), (4, 0.028571432), (5, 0.22857094), (6, 0.02857143)]
# [(0, 0.047619063), (1, 0.04761907), (2, 0.04761906), (3, 0.38094595), (4, 0.047619063), (5, 0.04761906), (6, 0.3809587)]
# [(0, 0.02879429), (1, 0.42871323), (2, 0.028574085), (3, 0.028571432), (4, 0.028571784), (5, 0.028571432), (6, 0.42820376)]
# [(0, 0.017878566), (1, 0.37089977), (2, 0.017877927), (3, 0.017876435), (4, 0.01788384), (5, 0.017910019), (6, 0.5396735)]
# [(0, 0.04761905), (1, 0.04761905), (2, 0.04761905), (3, 0.04761905), (4, 0.04761905), (5, 0.38095376), (6, 0.38095102)]
# [(0, 0.035715852), (1, 0.03571429), (2, 0.285714), (3, 0.035714287), (4, 0.28571677), (5, 0.03571429), (6, 0.2857105)]
# [(0, 0.017884817), (1, 0.35321125), (2, 0.1489384), (3, 0.01786199), (4, 0.0178964), (5, 0.15075478), (6, 0.29345238)]
# [(0, 0.047619045), (1, 0.047619045), (2, 0.047619045), (3, 0.047619045), (4, 0.38095242), (5, 0.047619045), (6, 0.38095233)]
# [(0, 0.03573915), (1, 0.5186628), (2, 0.035736706), (3, 0.03573612), (4, 0.035747267), (5, 0.035738304), (6, 0.3026397)]
# [(1, 0.31514764), (2, 0.06589684), (3, 0.25945866), (5, 0.0660735), (6, 0.27754498)]
# [(0, 0.04765321), (1, 0.71409297), (2, 0.047649834), (3, 0.04764904), (4, 0.047664415), (5, 0.047652036), (6, 0.047638502)]
# [(0, 0.17312548), (2, 0.106714286), (3, 0.3139273), (6, 0.3776262)]
# [(0, 0.047619045), (1, 0.38095245), (2, 0.047619045), (3, 0.047619045), (4, 0.047619045), (5, 0.047619045), (6, 0.3809523)]
# [(0, 0.020409085), (1, 0.02040821), (2, 0.16329251), (3, 0.020408189), (4, 0.19451267), (5, 0.27479333), (6, 0.306176)]
# [(0, 0.023834286), (1, 0.25541753), (2, 0.25935027), (3, 0.38988683), (4, 0.023842394), (5, 0.02383344), (6, 0.023835251)]
# [(0, 0.21429014), (1, 0.014285718), (2, 0.014285716), (3, 0.21428911), (4, 0.014285718), (5, 0.11428229), (6, 0.4142813)]
# [(0, 0.017857153), (1, 0.14282231), (2, 0.017857153), (3, 0.14287099), (4, 0.5178263), (5, 0.1428569), (6, 0.017909221)]
# [(0, 0.22857146), (1, 0.02857143), (2, 0.02857143), (3, 0.028667262), (4, 0.02857143), (5, 0.02857143), (6, 0.62847555)]
# [(0, 0.11380231), (1, 0.13059394), (2, 0.01194547), (3, 0.21665846), (4, 0.122581005), (5, 0.112987034), (6, 0.29143178)]
# [(0, 0.04762115), (1, 0.047623385), (2, 0.38096723), (3, 0.047619063), (4, 0.3809307), (5, 0.047619063), (6, 0.047619388)]
# [(0, 0.014383775), (1, 0.2683004), (2, 0.014327139), (3, 0.01429447), (4, 0.014298936), (5, 0.014295345), (6, 0.66009986)]
# [(0, 0.023829535), (1, 0.46575907), (2, 0.2131623), (3, 0.023826316), (4, 0.22577612), (5, 0.023827994), (6, 0.023818685)]
# [(0, 0.17006844), (1, 0.20898333), (2, 0.017877314), (3, 0.17078654), (4, 0.39650097), (5, 0.017878758), (6, 0.017904656)]
# [(0, 0.035714287), (1, 0.035714287), (2, 0.035714287), (3, 0.035714317), (4, 0.78570056), (5, 0.035714287), (6, 0.035727974)]
# [(0, 0.38069877), (1, 0.04761905), (2, 0.04761905), (3, 0.047830593), (4, 0.047661204), (5, 0.04761905), (6, 0.38095233)]
# [(0, 0.13702165), (1, 0.15769401), (2, 0.014300068), (3, 0.1335243), (4, 0.14470804), (5, 0.39845866), (6, 0.0142933335)]
# [(0, 0.028605739), (1, 0.32417998), (2, 0.53279865), (3, 0.02860191), (4, 0.02862143), (5, 0.028604534), (6, 0.028587732)]
# [(0, 0.07620664), (1, 0.2763308), (2, 0.073897965), (3, 0.25747424), (4, 0.07621981), (6, 0.23034672)]
# [(0, 0.020602163), (1, 0.020447437), (2, 0.19526327), (3, 0.38076502), (4, 0.020441279), (5, 0.020432249), (6, 0.34204862)]
# [(0, 0.028571432), (1, 0.22857146), (2, 0.22857182), (3, 0.22857241), (4, 0.028571432), (5, 0.02857143), (6, 0.22857003)]
# [(0, 0.023819553), (1, 0.50788206), (2, 0.023818567), (3, 0.02381833), (4, 0.023822824), (5, 0.023819214), (6, 0.3730195)]
# [(0, 0.035715852), (1, 0.2857173), (2, 0.28571394), (3, 0.035714287), (4, 0.03571429), (5, 0.035714287), (6, 0.28571004)]
# [(0, 0.03573031), (1, 0.7856239), (2, 0.035728734), (3, 0.03572836), (4, 0.03573554), (5, 0.035729766), (6, 0.035723425)]
# [(0, 0.047619056), (1, 0.04761906), (2, 0.38094756), (3, 0.047619056), (4, 0.047619056), (5, 0.38095722), (6, 0.047619056)]
# [(0, 0.020436976), (1, 0.020453578), (2, 0.02043413), (3, 0.2873838), (4, 0.020447198), (5, 0.020435993), (6, 0.6104083)]
# [(0, 0.014290567), (1, 0.2586144), (2, 0.014290092), (3, 0.22624946), (4, 0.23302147), (5, 0.11980017), (6, 0.13373384)]
# [(0, 0.42377758), (1, 0.03582913), (2, 0.0357796), (3, 0.39726955), (4, 0.03581099), (5, 0.0357843), (6, 0.035748854)]
# [(0, 0.12766813), (1, 0.23401324), (2, 0.015873577), (3, 0.12944013), (4, 0.12789725), (5, 0.22983259), (6, 0.13527507)]
# [(0, 0.017857375), (1, 0.2341392), (2, 0.14287691), (3, 0.017862432), (4, 0.17750682), (5, 0.26768643), (6, 0.14207083)]
# [(0, 0.047619063), (1, 0.047619075), (2, 0.047619063), (3, 0.3809483), (4, 0.04761907), (5, 0.047619063), (6, 0.38095638)]
# [(0, 0.028571432), (1, 0.22857395), (2, 0.028571432), (3, 0.028571432), (4, 0.028571432), (5, 0.22857328), (6, 0.42856708)]
# [(0, 0.047619052), (1, 0.38095236), (2, 0.3809524), (3, 0.047619067), (4, 0.047619052), (5, 0.047619052), (6, 0.047619052)]
# [(0, 0.023842398), (1, 0.02386136), (2, 0.23431839), (3, 0.45988718), (4, 0.023853216), (5, 0.023841275), (6, 0.21039616)]
# [(0, 0.023809621), (1, 0.023809677), (2, 0.023834037), (3, 0.35710636), (4, 0.024046922), (5, 0.19013016), (6, 0.35726324)]
# [(0, 0.047621142), (1, 0.047619067), (2, 0.38096222), (3, 0.38094038), (4, 0.04761906), (5, 0.047619056), (6, 0.047619052)]
# [(0, 0.023830585), (1, 0.47424638), (2, 0.21419127), (3, 0.023827242), (4, 0.023836298), (5, 0.21624905), (6, 0.023819191)]
# [(0, 0.020425104), (1, 0.4000614), (2, 0.020423034), (3, 0.18185443), (4, 0.020430047), (5, 0.18412393), (6, 0.17268205)]
# [(0, 0.087914124), (1, 0.24176428), (2, 0.31840616), (3, 0.010989012), (4, 0.087891735), (5, 0.010989014), (6, 0.24204567)]
# [(0, 0.16326651), (1, 0.27539173), (2, 0.30611768), (3, 0.020408165), (4, 0.020408167), (5, 0.020408167), (6, 0.1939996)]
# [(0, 0.285709), (1, 0.035714295), (2, 0.03571429), (3, 0.03571429), (4, 0.035714295), (5, 0.03571429), (6, 0.5357196)]
# [(0, 0.13035898), (1, 0.141358), (2, 0.12689379), (3, 0.014295856), (4, 0.13590746), (5, 0.014296872), (6, 0.43688902)]
# [(0, 0.48487866), (1, 0.035714313), (2, 0.035729323), (3, 0.035714287), (4, 0.035714287), (5, 0.035795204), (6, 0.33645397)]
# [(0, 0.020414282), (1, 0.5764159), (2, 0.32137254), (3, 0.020555299), (4, 0.02041627), (5, 0.020414073), (6, 0.020411655)]
# [(0, 0.3283237), (1, 0.41860938), (2, 0.020415246), (3, 0.17139399), (4, 0.020418579), (5, 0.020415751), (6, 0.020423336)]
# [(0, 0.28572705), (1, 0.28562495), (2, 0.035714295), (3, 0.28568843), (4, 0.035714295), (5, 0.035714295), (6, 0.03581667)]
# [(0, 0.11827019), (1, 0.20631929), (2, 0.0130326245), (3, 0.18396002), (4, 0.013050274), (5, 0.11776245), (6, 0.34760517)]
# [(0, 0.014297396), (1, 0.014304152), (2, 0.24716194), (3, 0.24612784), (4, 0.014301313), (5, 0.014296999), (6, 0.44951034)]
# [(0, 0.02857143), (1, 0.22857426), (2, 0.42857167), (3, 0.028571436), (4, 0.02857143), (5, 0.22856832), (6, 0.028571427)]
# [(0, 0.53568995), (1, 0.035714287), (2, 0.035804003), (3, 0.28562465), (4, 0.035714287), (5, 0.035714287), (6, 0.035738524)]
# [(0, 0.023837335), (1, 0.023852669), (2, 0.65695643), (3, 0.22384906), (4, 0.023845892), (5, 0.023835976), (6, 0.023822626)]
# [(0, 0.2018734), (1, 0.4947695), (2, 0.020431492), (3, 0.020430882), (4, 0.22162606), (5, 0.020433163), (6, 0.020435493)]
# [(0, 0.035714444), (1, 0.03571431), (2, 0.27821973), (3, 0.03590761), (4, 0.03571431), (5, 0.035714302), (6, 0.54301536)]
# [(0, 0.028600419), (1, 0.6117348), (2, 0.02859756), (3, 0.028596878), (4, 0.028609928), (5, 0.028599428), (6, 0.245261)]
# [(0, 0.023809524), (1, 0.35714594), (2, 0.023809945), (3, 0.023809528), (4, 0.19047493), (5, 0.023809524), (6, 0.35714063)]
# [(0, 0.29202417), (1, 0.023891365), (2, 0.023863407), (3, 0.023854913), (4, 0.3857683), (5, 0.0238595), (6, 0.22673835)]
# [(0, 0.047619063), (1, 0.04761907), (2, 0.04761906), (3, 0.38094595), (4, 0.047619063), (5, 0.04761906), (6, 0.3809587)]
# [(0, 0.023809524), (1, 0.023809524), (2, 0.19047634), (3, 0.02380961), (4, 0.024010777), (5, 0.19047593), (6, 0.52360827)]
# [(0, 0.035739128), (1, 0.51875335), (2, 0.035736684), (3, 0.035736103), (4, 0.03593688), (5, 0.035738282), (6, 0.3023596)]
# [(0, 0.028571436), (1, 0.028571442), (2, 0.028571436), (3, 0.028571447), (4, 0.22858143), (5, 0.22858098), (6, 0.42855182)]
# [(0, 0.03571585), (1, 0.035714287), (2, 0.28571188), (3, 0.03591427), (4, 0.035714287), (5, 0.035714287), (6, 0.5355152)]
# [(0, 0.014299451), (1, 0.4298407), (2, 0.1288711), (3, 0.12841582), (4, 0.2699836), (5, 0.014297645), (6, 0.014291629)]
# [(0, 0.028624196), (1, 0.46807426), (2, 0.028618967), (3, 0.028617721), (4, 0.38884583), (5, 0.028622385), (6, 0.02859661)]
# [(0, 0.035714295), (1, 0.035714302), (2, 0.2857196), (3, 0.28569728), (4, 0.0357143), (5, 0.2857259), (6, 0.035714287)]
# [(0, 0.015883397), (1, 0.2928249), (2, 0.015882364), (3, 0.138301), (4, 0.14534524), (5, 0.13960035), (6, 0.25216275)]
# [(0, 0.035841532), (1, 0.035921663), (2, 0.035850223), (3, 0.035825618), (4, 0.03588513), (5, 0.035837136), (6, 0.7848387)]
# [(0, 0.102388516), (1, 0.11887742), (2, 0.100215286), (3, 0.18381786), (4, 0.19562712), (5, 0.14731105), (6, 0.15176277)]
# [(0, 0.22861595), (1, 0.028571492), (2, 0.22860415), (3, 0.22849993), (4, 0.028571486), (5, 0.22845502), (6, 0.028682005)]
# [(0, 0.047621142), (1, 0.047619067), (2, 0.38096222), (3, 0.38094038), (4, 0.04761906), (5, 0.047619056), (6, 0.047619052)]
# [(0, 0.01587302), (1, 0.34921792), (2, 0.23810264), (3, 0.23806098), (4, 0.015873022), (5, 0.12698758), (6, 0.015884839)]
# [(0, 0.047619063), (1, 0.04761907), (2, 0.047619063), (3, 0.38094106), (4, 0.04761907), (5, 0.38096365), (6, 0.047619056)]
# [(0, 0.3809661), (1, 0.04761907), (2, 0.04761906), (3, 0.38093862), (4, 0.047619063), (5, 0.047619063), (6, 0.047619056)]
# [(0, 0.03571429), (1, 0.28571436), (2, 0.53542644), (3, 0.03600211), (4, 0.03571429), (5, 0.03571429), (6, 0.03571429)]
# [(0, 0.047702335), (1, 0.71382356), (2, 0.047693588), (3, 0.04769153), (4, 0.04773216), (5, 0.04769866), (6, 0.047658198)]
# [(0, 0.028616225), (1, 0.028640714), (2, 0.2896955), (3, 0.02860995), (4, 0.34009534), (5, 0.028613824), (6, 0.25572845)]
# [(0, 0.047619063), (1, 0.04761907), (2, 0.04761906), (3, 0.380946), (4, 0.047619063), (5, 0.04761906), (6, 0.3809587)]
# [(0, 0.035774022), (1, 0.035808552), (2, 0.37202168), (3, 0.0357667), (4, 0.44911423), (5, 0.035771977), (6, 0.035742808)]
# [(0, 0.012017094), (1, 0.26696056), (2, 0.0119161755), (3, 0.21645467), (4, 0.18676113), (5, 0.011913125), (6, 0.29397726)]
# [(0, 0.028703596), (1, 0.22858378), (2, 0.028571438), (3, 0.40615463), (4, 0.25068855), (5, 0.028571438), (6, 0.028726554)]
# [(0, 0.035714295), (1, 0.2857062), (2, 0.03571429), (3, 0.035714295), (4, 0.035714295), (5, 0.035714295), (6, 0.5357223)]
# [(0, 0.020427443), (1, 0.21149537), (2, 0.18643604), (3, 0.18558356), (4, 0.20109138), (5, 0.020532992), (6, 0.17443319)]
# [(0, 0.19163024), (1, 0.1904756), (2, 0.18932223), (3, 0.023809532), (4, 0.19047648), (5, 0.023809524), (6, 0.1904764)]
# [(0, 0.011912469), (1, 0.21933238), (2, 0.26271817), (3, 0.20782538), (4, 0.011912912), (5, 0.011904784), (6, 0.2743939)]
# [(0, 0.023809532), (1, 0.023862874), (2, 0.35715783), (3, 0.02383318), (4, 0.35704836), (5, 0.023809532), (6, 0.19047874)]
# [(0, 0.023887578), (1, 0.023955941), (2, 0.023882562), (3, 0.023888456), (4, 0.02396994), (5, 0.5562773), (6, 0.32413825)]
# [(0, 0.16786978), (1, 0.017885925), (2, 0.017873412), (3, 0.31916395), (4, 0.017881297), (5, 0.16124818), (6, 0.29807743)]
# [(0, 0.16455044), (1, 0.015936924), (2, 0.3165279), (3, 0.15840715), (4, 0.18557404), (5, 0.015895804), (6, 0.14310774)]
# [(0, 0.047619045), (1, 0.38095236), (2, 0.047619876), (3, 0.04761906), (4, 0.38095152), (5, 0.047619045), (6, 0.047619045)]
# [(0, 0.09652814), (1, 0.3424435), (2, 0.095659345), (3, 0.010995086), (4, 0.10008527), (5, 0.1005426), (6, 0.25374606)]
# [(0, 0.035771705), (1, 0.4995839), (2, 0.035766896), (3, 0.035766628), (4, 0.035790607), (5, 0.035770003), (6, 0.3215503)]
# [(0, 0.035771612), (1, 0.49989066), (2, 0.035891276), (3, 0.03576459), (4, 0.03579048), (5, 0.03576965), (6, 0.32112172)]
# [(0, 0.035805993), (1, 0.03607726), (2, 0.035844058), (3, 0.45298612), (4, 0.035836473), (5, 0.035802834), (6, 0.36764726)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#      Document_No  ...                                               Text
# 0              0  ...      [beli, pakai, cc, ribet, tolak, sedia, layan]
# 1              1  ...                         [verifikasi, email, kesel]
# 2              2  ...                     [up, money, bilang, manajemen]
# 3              3  ...                                     [iklan, sebal]
# 4              4  ...                    [nonton, ngapa, kesini, melulu]
# ..           ...  ...                                                ...
# 995          995  ...                                  [barang, lengkap]
# 996          996  ...  [belanja, aman, topup, biaya, admin, harga, mu...
# 997          997  ...                            [tingkat, promo, ehehe]
# 998          998  ...                                 [bags, barang, ny]
# 999          999  ...                             [pesan, cepat, sampai]
#
# [1000 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0     57
# 1.0    247
# 2.0    113
# 3.0    118
# 4.0    122
# 5.0     47
# 6.0    296
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500)

plt.show()

# %%
result = pd.concat([df_token, df_dominant_topic], axis=1)

# %%
result.to_csv('data_processed_7topics.csv',  header=["review", "rating", "sentiment", "review_processed", 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text'], chunksize=100000, index = False, mode='a')
