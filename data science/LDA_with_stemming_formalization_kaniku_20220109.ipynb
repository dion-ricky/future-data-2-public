# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.53.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  *
FROM
  `future-data-track-1.sapporo_mart.topic_modelling`
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0                                     IKLAN NYA GANGGU AS*       1
# 1        Pihak lazada tolong di mengerti masa saya pesa...       1
# 2                            Iklan trossssssss, ganggu aja       1
# 3        Lazada Ruwet anjir. Mau menggunakan metode pem...       1
# 4        Dih jangan dwon ni aplikasi tempat para penipu...       1
# ...                                                    ...     ...
# 1695878                                    Sangat membantu       5
# 1695879                                    Sangat membantu       5
# 1695880                                    Sangat membantu       5
# 1695881                                    Sangat membantu       5
# 1695882                                    Sangat membantu       5
#
# [1695883 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar","buka","lapak"
    ,"terima","kasih"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review'].values]]

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token
# Out:
#                                                     review  rating
# 0                                          iklan ganggu as       1
# 1                                  tolong erti pesan pesan       1
# 2                                 iklan trossssssss ganggu       1
# 3        ruwet metode bayar indomart mlh cod aplikasi v...       1
# 4        dih dwon aplikasi tipu order giveaway hp perca...       1
# ...                                                    ...     ...
# 1475049  belanja shoppe bantu temu barang dng cepat har...       5
# 1475050    sampe skrg pake alhamdulilah gapernah ngecewain       5
# 1475052     enk blanja shopeee tigkatkn gratis ongkir psan       5
# 1475053                                  belanja kirim cpt       5
# 1475055                               layan belanja shoope       5
#
# [780796 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['iklan', 'ganggu', 'as'],
#  ['tolong', 'erti', 'pesan', 'pesan'],
#  ['iklan', 'trossssssss', 'ganggu'],
#  ['ruwet', 'metode', 'bayar', 'indomart', 'mlh', 'cod', 'aplikasi', 'voucher'],
#  ['dih',
#   'dwon',
#   'aplikasi',
#   'tipu',
#   'order',
#   'giveaway',
#   'handphone',
#   'percaya',
#   'dateng',
#   'kawat',
#   'bayar',
#   'ribu',
#   'masak',
#   'kasi',
#   'kawat',
#   'untung',
#   'gin',
#   'tipu',
#   'bgettt',
#   'yaaa',
#   'gesss',
#   'aman',
#   'percaya',
#   'tukang',
#   'tipu',
#   'kaya',
#   'hapus',
#   'lgsung',
#   'aplikasi'],
#  ['cashbacknya', 'dapetnya', 'kirim', 'dikit', 'serius', 'bikin', 'promo'],
#  ['bnrn',
#   'sya',
#   'menang',
#   'untung',
#   'undi',
#   'handphone',
#   'ip',
#   'kirim',
#   'alamat',
#   'tinggal',
#   'sya',
#   'kp',
#   'rawahingkik',
#   'rt',
#   'rw',
#   'cileungsi',
#   'bogor',
#   'ichat'],
#  ['keluh', 'langgan', 'tanggung'],
#  ['pocer', 'tapi', 'ngk'],
#  ['ui', 'ribet'],
#  ['aplikasi', 'pesan', 'barang', 'bayar', 'barang', 'pesan', 'nyampe'],
#  ['keluan',
#   'setelah',
#   'bc',
#   'komntr',
#   'apa',
#   'banyak',
#   'penipuny',
#   'pelyananya'],
#  ['transaksi', 'tranfer', 'uang'],
#  ['cok', 'asyifa'],
#  ['ampuh', 'sehat', 'aman', 'damai'],
#  ['males', 'belanja', 'shope', 'lebih baik', 'toko', 'belah'],
#  ['maf',
#   'aplikasi',
#   'sayah',
#   'terimna',
#   'hadiah',
#   'puter',
#   'katnya',
#   'hadiah',
#   'uang',
#   'tapi',
#   'bacan',
#   'ambil',
#   'uang',
#   'sama',
#   'hadia',
#   'sayah',
#   'terimna',
#   'aplikasi',
#   'nga',
#   'bisin',
#   'kuota',
#   'bantu',
#   'jawap',
#   'kenah',
#   'ambil'],
#  ['beli', 'barang', 'sesuai', 'boykot'],
#  ['tolong', 'cepat'],
#  ['membaii', 'layanan'],
#  ['ban', 'ban', 'bekas'],
#  ['toko', 'beli', 'gantung', 'tas', 'nggkak', 'kirim', 'kirim'],
#  ['cod', 'transfer', 'proses', 'bikin', 'ribet'],
#  ['rupiah', 'ongkir', 'bayar'],
#  ['gratis',
#   'ongkir',
#   'promo',
#   'cashback',
#   'juga',
#   'hilang',
#   'pindah',
#   'aplikasi',
#   'nihh'],
#  ['kode',
#   'verifikasi',
#   'otp',
#   'sulit',
#   'verifikasi',
#   'whatsapp',
#   'nomer',
#   'via',
#   'telepon',
#   'nyampe',
#   'gin',
#   'bikin',
#   'sulit',
#   'daftar',
#   'shoppe',
#   'bayar',
#   'maaf',
#   'lanjur',
#   'harap',
#   'sistem',
#   'verifikasi',
#   'kode',
#   'otp',
#   'ribet',
#   'cuman',
#   'ganti',
#   'pasword',
#   'simple',
#   'maju',
#   'kayak',
#   'gin'],
#  ['belanja',
#   'barang',
#   'dateng',
#   'lapor',
#   'terima',
#   'kirim',
#   'alhasil',
#   'bolak',
#   'ekspedisi',
#   'plus',
#   'debat',
#   'jual',
#   'uang',
#   'hilang',
#   'barang',
#   'nyampe',
#   'jujur',
#   'ekspedisi',
#   'expres'],
#  ['akun',
#   'nonaktif',
#   'order',
#   'bayar',
#   'shopeepay',
#   'nonaktif',
#   'jlskan',
#   'salah'],
#  ['proses',
#   'rim',
#   'padhal',
#   'update',
#   'tepaksa',
#   'batal',
#   'prises',
#   'kirim',
#   'tolong',
#   'dibantuh'],
#  ['paylater', 'beku', 'limit', 'terlambat', 'bayar', 'solusi'],
#  ['aplikasi',
#   'ndk',
#   'masak',
#   'beli',
#   'speaker',
#   'gantung',
#   'kunci',
#   'tolong',
#   'kasih',
#   'tok',
#   'bossku',
#   'aplikasi',
#   'rusak',
#   'serius'],
#  ['terkadang', 'dilazada', 'barang', 'sesuai'],
#  ['tukang',
#   'tipu',
#   'aplikasi',
#   'kawan',
#   'kawan',
#   'jngan',
#   'unduh',
#   'aplikasi',
#   'modus',
#   'tipu',
#   'iming',
#   'iming',
#   'hadiah',
#   'lebih baik',
#   'unduh',
#   'bonus'],
#  ['dtipu',
#   'muncul',
#   'pembritahuan',
#   'memdapat',
#   'hadiah',
#   'cmn',
#   'suruh',
#   'install',
#   'aplikasi',
#   'tempek'],
#  ['error', 'yaaaaaaa'],
#  ['iklan', 'akeh', 'cok'],
#  ['idexpress', 'hapus', 'paket', 'regelur', 'sampai'],
#  ['unduh', 'bantu'],
#  ['susah', 'memasukkn', 'otp', 'kirim'],
#  ['ngk', 'aplikasi'],
#  ['install', 'anjenk'],
#  ['emosi',
#   'internet',
#   'aplikasi',
#   'buka',
#   'lancar',
#   'pas',
#   'buka',
#   'shope',
#   'ketik',
#   'cari',
#   'pencet',
#   'enter',
#   'emosi',
#   'jam',
#   'seperti',
#   'besok',
#   'seperti',
#   'loading',
#   'pas',
#   'loading',
#   'produk',
#   'temu',
#   'tahu',
#   'barang',
#   'cari',
#   'iseng',
#   'sia',
#   'sia',
#   'tunggu'],
#  ['saldo',
#   'blokir',
#   'tolong',
#   'customer',
#   'care',
#   'aktifin',
#   'saldo',
#   'terima',
#   'kasih'],
#  ['jangan',
#   'belanja',
#   'tipu',
#   'pesan',
#   'kirim',
#   'pakai',
#   'metode',
#   'bayar',
#   'cod',
#   'kurir',
#   'bilang',
#   'bayar',
#   'jual',
#   'prnah',
#   'beli',
#   'bareng',
#   'sesuai',
#   'pas',
#   'cod',
#   'buka',
#   'dpn',
#   'kurir',
#   'kurir',
#   'sendiri',
#   'inisiatif',
#   'bilang',
#   'jual',
#   'basa',
#   'basi',
#   'rugi',
#   'tipu',
#   'berkah',
#   'makan',
#   'tu',
#   'duit',
#   'haram',
#   'ikhlas',
#   'dunia',
#   'akhirat'],
#  ['pesan',
#   'balik',
#   'gudang',
#   'lagi',
#   'kurir',
#   'wilayah',
#   'kirim',
#   'suruh',
#   'tunggu',
#   'lagi',
#   'sesuai',
#   'wilayah',
#   'kirim'],
#  ['iklanya', 'lindung', 'handphone', 'mu', 'viruz', 'pas', 'pencet', 'malak'],
#  ['tipu', 'tolong', 'pantau', 'jual', 'tipu', 'tolak'],
#  ['aplikasi',
#   'taiii',
#   'mesen',
#   'sampai',
#   'pas',
#   'sampai',
#   'barang',
#   'sampai',
#   'cancel',
#   'costumer'],
#  ['loading', 'berat', 'susahhhh'],
#  ['njirrr', 'selancar', 'alih', 'ksini', 'vanke'],
#  ['pesan',
#   'photocard',
#   'taehyung',
#   'eror',
#   'ulang',
#   'pas',
#   'checkout',
#   'notif',
#   'barang',
#   'saldo',
#   'potong',
#   'tolong',
#   'jngn',
#   'sperti'],
#  ['aplikasi', 'iklan', 'ngotak', 'mentang', 'duit', 'bikin', 'iklan'],
#  ['sebal',
#   'kesini',
#   'akun',
#   'apain',
#   'gagal',
#   'checkout',
#   'alas',
#   'curiga',
#   'janggal',
#   'ngeselin',
#   'pakai',
#   'shopeepay',
#   'gilir',
#   'pakai',
#   'bayar',
#   'gratis',
#   'ongkir',
#   'cashback',
#   'dipake',
#   'shopeepay',
#   'tolong',
#   'bikin',
#   'ribet'],
#  ['milih',
#   'jasa',
#   'ekspedisi',
#   'monopoli',
#   'express',
#   'cepat',
#   'sukur',
#   'paket',
#   'kirim',
#   'jakarta',
#   'estimasi',
#   'terima',
#   'oktober',
#   'karawang',
#   'alih',
#   'toko'],
#  ['iklan', 'muncul', 'konttttttoooooooollllllllllll'],
#  ['kesel',
#   'update',
#   'diupdate',
#   'februari',
#   'besok',
#   'update',
#   'event',
#   'tanggal',
#   'februari',
#   'berat',
#   'handphone',
#   'handphone',
#   'kentang',
#   'ngebul',
#   'kuat',
#   'pakai',
#   'aplikasi',
#   'proses',
#   'belanja',
#   'gampang'],
#  ['pelit', 'ongkir', 'belanja', 'aplikasi', 'sedih', 'epribadi'],
#  ['iklan', 'muncul', 'ng'],
#  ['beli',
#   'sadar',
#   'barang',
#   'beli',
#   'beda',
#   'berat',
#   'lapak',
#   'tulis',
#   'berat',
#   'berat',
#   'sesunguhnya',
#   'berat',
#   'kg',
#   'lapak',
#   'tulis',
#   'kg',
#   'bayar',
#   'kg',
#   'kg',
#   'beli',
#   'ambil',
#   'lapak',
#   'bonus',
#   'beli',
#   'beli',
#   'cari',
#   'berat',
#   'barang',
#   'wajar',
#   'berat',
#   'sesuai',
#   'beda',
#   'kg',
#   'wajar',
#   'beda',
#   'kg',
#   'ajar'],
#  ['aplokasi', 'ribet', 'mau', 'jual', 'susah'],
#  ['member', 'platinum', 'shopepay', 'later', 'aktif', 'payahhh'],
#  ['spaylater',
#   'mesti',
#   'verifikasi',
#   'wajah',
#   'gagal',
#   'bayar',
#   'cicil',
#   'cicil',
#   'pakek',
#   'spaylater',
#   'malas',
#   'atm',
#   'sistem',
#   'bayar',
#   'sms',
#   'banking',
#   'kendala',
#   'malas',
#   'belanja',
#   'dishopee'],
#  ['seperti', 'ngk'],
#  ['ngapain', 'nongol', 'melulu', 'iklan', 'aplikasi', 'ganggu'],
#  ['unduh', 'update', 'hahaha', 'untung'],
#  ['hapus',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'hapus',
#   'bantu'],
#  ['sistem', 'beli', 'pulsa', 'uang', 'cepat', 'bangkrut', 'amin'],
#  ['dindownliad', 'hapus'],
#  ['isi',
#   'saldo',
#   'shoopepay',
#   'pas',
#   'klik',
#   'bank',
#   'virtual',
#   'account',
#   'blank',
#   'layar',
#   'handphone',
#   'putih',
#   'refresh',
#   'tetep',
#   'adehhhh',
#   'transaksi',
#   'njengggg'],
#  ['olshop',
#   'hancur',
#   'jasa',
#   'ekpedisi',
#   'kurir',
#   'amanh',
#   'smoga',
#   'benah',
#   'olshop',
#   'bagaimna',
#   'prioritas',
#   'customer'],
#  ['beli',
#   'handphone',
#   'barang',
#   'sesuai',
#   'retur',
#   'handphone',
#   'terima',
#   'jual',
#   'uang',
#   'bantu',
#   'admin'],
#  ['toko', 'bnyak', 'tipu'],
#  ['aplikasi',
#   'tipu',
#   'program',
#   'promo',
#   'cashback',
#   'bodoh',
#   'rugi',
#   'nyesal',
#   'pokok'],
#  ['amanah',
#   'bayar',
#   'dibatalin',
#   'sistem',
#   'dana',
#   'dikembaliin',
#   'juga',
#   'belanja',
#   'tolong',
#   'cari',
#   'uang',
#   'susah',
#   'fikembalikan',
#   'cepat'],
#  ['sapi',
#   'lajanda',
#   'ribet',
#   'akun',
#   'cuman',
#   'handphone',
#   'ttp',
#   'batal',
#   'sistem',
#   'busul'],
#  ['shoope', 'pesan', 'dibatalin', 'tampa', 'konfirmasi'],
#  ['aplikasi', 'lambat', 'unduh'],
#  ['cari', 'tahu', 'tahu'],
#  ['kurir',
#   'buka',
#   'expres',
#   'mahal',
#   'beda',
#   'kurir',
#   'ribu',
#   'pakai',
#   'buka',
#   'expres',
#   'ribu',
#   'pakai',
#   'voucher',
#   'no',
#   'ongkir',
#   'tetep',
#   'biaya',
#   'ongkir'],
#  ['tanam',
#   'blank',
#   'eror',
#   'update',
#   'cache',
#   'uninstall',
#   'install',
#   'begtu'],
#  ['proses',
#   'bayar',
#   'btl',
#   'seller',
#   'tolong',
#   'bayar',
#   'cepat',
#   'cod',
#   'tindak',
#   'lh',
#   'mksh'],
#  ['toko',
#   'jual',
#   'barang',
#   'sesuai',
#   'klik',
#   'pesan',
#   'bantu',
#   'solusi',
#   'tertawa'],
#  ['daftar', 'susah'],
#  ['belanja', 'barang', 'batal', 'otomatis', 'terssss', 'kezeellllll'],
#  ['susah',
#   'cari',
#   'barang',
#   'isi',
#   'lapak',
#   'barang',
#   'pasang',
#   'harga',
#   'perut',
#   'efek',
#   'gampang',
#   'bikin',
#   'lapak',
#   'bahan',
#   'timbang',
#   'bikin',
#   'betah',
#   'buyer'],
#  ['shopeepay', 'later', 'jngan', 'bayar', 'sllu'],
#  ['ganggu', 'jual', 'murah', 'iklaaaan', 'terusss', 'kamorer'],
#  ['loginnya', 'login', 'pakai', 'no', 'telepon', 'error'],
#  ['bnyak',
#   'seller',
#   'tipu',
#   'hati',
#   'ditelfon',
#   'seller',
#   'remote',
#   'akun',
#   'shopeenya',
#   'tolong',
#   'aplikasiny',
#   'update',
#   'refund',
#   'jangan',
#   'bgitu',
#   'batal',
#   'refund',
#   'uang',
#   'tunggu',
#   'hari'],
#  ['aplikasi', 'ongkir', 'bayar'],
#  ['iklan', 'melulu'],
#  ['update', 'pas', 'update', 'error', 'komplain', 'fast', 'respon', 'solusi'],
#  ['engga',
#   'kapok',
#   'layan',
#   'super',
#   'dengar',
#   'komplain',
#   'langgan',
#   'langgan',
#   'kompalin',
#   'tetbaik',
#   'dengar',
#   'terkadang',
#   'fiturr',
#   'chat',
#   'mati',
#   'layan'],
#  ['maaf',
#   'kenape',
#   'verifikasi',
#   'sms',
#   'susah',
#   'bug',
#   'verifikasi',
#   'sms',
#   'auto',
#   'mengisi',
#   'salah',
#   'kode',
#   'kode',
#   'tulis',
#   'ulang',
#   'hapus',
#   'keyboard',
#   'ngetik',
#   'angka',
#   'bug',
#   'ganggu',
#   'asli',
#   'ampas',
#   'aplikasi',
#   'tolong',
#   'kasi',
#   'hadeh',
#   'ecommerce',
#   'indonesia',
#   'gin',
#   'ampas',
#   'hadeuh'],
#  ['barang',
#   'bilang',
#   'siap',
#   'pas',
#   'transfer',
#   'chat',
#   'balas',
#   'aplikasi',
#   'jual'],
#  ['maaf', 'toko', 'kirim', 'sesuai', 'pesan', 'ulang', 'ulang'],
#  ['iklan', 'melulu', 'aplikasi', 'droppppp'],
#  ['toko', 'tipu'],
#  ['belanja',
#   'dilazada',
#   'garansi',
#   'uang',
#   'hoaks',
#   'barang',
#   'sesuai',
#   'tahu',
#   'return',
#   'dh'],
#  ['eror', 'kode', 'io', 'buin'],
#  ['aplikasi', 'ganggu'],
#  ['livenya',
#   'rekam',
#   'diposting',
#   'minggu',
#   'baju',
#   'postingan',
#   'minggu',
#   'blackpink',
#   'ulang',
#   'please',
#   'fans',
#   'mengatasnamakan',
#   'live',
#   'blackpink'],
#  ['sring',
#   'kcewa',
#   'ditoped',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'tolak',
#   'seller',
#   'sellernya',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'bareng',
#   'nanggung',
#   'ongkir',
#   'pdhl',
#   'ksalahan',
#   'seller',
#   'bareng',
#   'bukan',
#   'ssuai',
#   'deskripsi',
#   'lagi',
#   'brgnya',
#   'palsu',
#   'kmbalikan',
#   'bareng',
#   'proses',
#   'rumit',
#   'waktu',
#   'garis',
#   'bsarnya',
#   'seller',
#   'mrugikan',
#   'scara',
#   'materi',
#   'energi',
#   'waktu',
#   'heran',
#   'tu',
#   'seller',
#   'sampai',
#   'hari',
#   'masih',
#   'bebas',
#   'jual',
#   'bareng',
#   'palsu',
#   'pdhl',
#   'bukti'],
#  ['aplikasi', 'aneh', 'search', 'produk', 'muncul'],
#  ['aplikasi',
#   'cek',
#   'pesan',
#   'gagal',
#   'antre',
#   'internet',
#   'offline',
#   'buka',
#   'lancar',
#   'sesal',
#   'dowload',
#   'aplikasi'],
#  ['tanggung',
#   'koin',
#   'pakai',
#   'koin',
#   'kemarin',
#   'tanam',
#   'koin',
#   'siram',
#   'koin',
#   'koin',
#   'tolong',
#   'gin',
#   'pakai',
#   'jujur',
#   'pakai',
#   'pokok',
#   'koin',
#   'nama',
#   'glowindo'],
#  ['maaf', 'mesen', 'powerbank', 'pas', 'powerbank', 'rusak'],
#  ['error',
#   'main',
#   'game',
#   'segercep',
#   'kemarin',
#   'promo',
#   'cashbacknya',
#   'tarik',
#   'kemarin',
#   'harga',
#   'barang',
#   'murah',
#   'aplikasi',
#   'belah',
#   'pdhl',
#   'langgan',
#   'pakai',
#   'males',
#   'belanja',
#   'seru',
#   'promo',
#   'up',
#   'shopeepay',
#   'ribu',
#   'juta',
#   'hadiah',
#   'perak',
#   'gilir',
#   'orang',
#   'up',
#   'ribu',
#   'hadiah',
#   'voucher',
#   'emas',
#   'hadeuhh',
#   'fair'],
#  ['marketplace',
#   'kaku',
#   'atur',
#   'ubah',
#   'bikin',
#   'nyaman',
#   'jual',
#   'beli',
#   'kesini',
#   'ribet',
#   'sombong',
#   'maaf',
#   'berat',
#   'uninstall',
#   'makan',
#   'tu',
#   'atur',
#   'kamu'],
#  ['cod', 'cod', 'baku', 'hantam'],
#  ['bertanya', 'dowlod', 'nii'],
#  ['agen', 'call', 'center'],
#  ['tipu', 'aplikasi', 'yes', 'do', 'najis'],
#  ['sabar', 'matket', 'place', 'ribet', 'ribet', 'percaya'],
#  ['sen', 'paket', 'kont'],
#  ['maf',
#   'dowlod',
#   'aplikasi',
#   'garagara',
#   'misi',
#   'penhasil',
#   'saldo',
#   'andai',
#   'aduh',
#   'malas',
#   'dowlod'],
#  ['unduh', 'unduh', 'hidup', 'data', 'seluler', 'unduh', 'hapus'],
#  ['aplikasi',
#   'sengaja',
#   'hapus',
#   'unduh',
#   'lagi',
#   'gagal',
#   'terus',
#   'gmn',
#   'tolong',
#   'solusi',
#   'bayar',
#   'bayar',
#   'later'],
#  ['ongkir',
#   'gede',
#   'beli',
#   'barang',
#   'diskon',
#   'ongkir',
#   'nama',
#   'ongkir',
#   'barang',
#   'lebih baik',
#   'belah'],
#  ['bela',
#   'beli',
#   'wkwk',
#   'sayang',
#   'kaya',
#   'lapak',
#   'belah',
#   'prioritas',
#   'beli',
#   'tahu',
#   'beli',
#   'raja',
#   'layan',
#   'komplain',
#   'shope',
#   'banyak',
#   'alesan',
#   'gilir',
#   'ajak',
#   'debat',
#   'skak',
#   'ehh',
#   'cht',
#   'wkwkwkkw'],
#  ['jatuh',
#   'tempo',
#   'telpon',
#   'bayar',
#   'jam',
#   'bayar',
#   'bayar',
#   'apaaa',
#   'kesini',
#   'galogis',
#   'gaaakan',
#   'pakai',
#   'gituan',
#   'ribet'],
#  ['aju', 'paylater', 'tolak', 'loyal', 'aplikasi'],
#  ['voucher', 'gratis', 'ongkir', 'dipake', 'kntl'],
#  ['bayar',
#   'tagih',
#   'suruh',
#   'tunggu',
#   'proses',
#   'dana',
#   'salah',
#   'suruh',
#   'tunggu',
#   'dana'],
#  ['saldo',
#   'dana',
#   'beku',
#   'yabg',
#   'rp',
#   'ribu',
#   'tolong',
#   'akun',
#   'lapor',
#   'polisi',
#   'tolong',
#   'kirim',
#   'pesan',
#   'eamil',
#   'stolong',
#   'cepat',
#   'uang',
#   'tarik',
#   'pas',
#   'uang',
#   'beku',
#   'pas',
#   'beku',
#   'uang',
#   'pakai',
#   'butuh',
#   'gajelas'],
#  ['kesal', 'iklan'],
#  ['emangggg', 'tooopppp', 'margotop'],
#  ['order', 'batal', 'sistem'],
#  ['setia',
#   'aplikasi',
#   'aplikasi',
#   'banyak',
#   'mslah',
#   'lot',
#   'error',
#   'alih',
#   'kta',
#   'aplikasi',
#   'baca',
#   'ulas',
#   'tntg',
#   'males',
#   'untuk',
#   'install',
#   'hapus',
#   'sja'],
#  ['aplikasi',
#   'sampah',
#   'nyusahin',
#   'ribet',
#   'bget',
#   'promo',
#   'ikln',
#   'sesuai',
#   'pulsa',
#   'data',
#   'mahal',
#   'asliny'],
#  ['aplikasi', 'lot', 'berat', 'desain', 'ribet', 'beda', 'simpel', 'ringan'],
#  ['aplikasi', 'bgst', 'palir', 'tukang', 'ulah', 'babulu'],
#  ['goyang', 'knph', 'yh', 'klik', 'muncul'],
#  ['bikin', 'akun', 'username', 'salah', 'benar', 'username'],
#  ['kayak', 'siput'],
#  ['ongkir', 'mahal', 'barang', 'mahal', 'belah'],
#  ['saldo', 'juta', 'hangus'],
#  ['hoax', 'habisin', 'paket', 'data'],
#  ['bisa', 'diundh'],
#  ['iklan', 'muncul'],
#  ['kode', 'otp', 'terima', 'order', 'order', 'verifikasi', 'no', 'telpon'],
#  ['sama', 'iklan'],
#  ['sekar',
#   'seringkali',
#   'belanja',
#   'reward',
#   'gold',
#   'aktif',
#   'shopeepaylater',
#   'mesti',
#   'suruh',
#   'topup',
#   'lagi',
#   'beribet',
#   'konfirmasi'],
#  ['males', 'iklan', 'melulu'],
#  ['maaf',
#   'kirim',
#   'nama',
#   'hj',
#   'leni',
#   'kebeneran',
#   'sen',
#   'aneh',
#   'yahhh',
#   'nmer',
#   'handphone',
#   'nmer',
#   'tapi',
#   'nama',
#   'alamat',
#   'persis',
#   'tapi',
#   'pribadi',
#   'kirim',
#   'misterius',
#   'sya',
#   'bayar',
#   'pdhl',
#   'sen',
#   'diambio',
#   'bayar',
#   'kasi',
#   'kulir',
#   'nyaaaa'],
#  ['sen',
#   'apa',
#   'paket',
#   'dateng',
#   'rumah',
#   'adek',
#   'tindaktegas',
#   'jual',
#   'nakal'],
#  ['masukkan',
#   'kode',
#   'verifikasi',
#   'angka',
#   'smsnya',
#   'masukkan',
#   'dftr',
#   'failed'],
#  ['pilih',
#   'halaman',
#   'search',
#   'produk',
#   'tekan',
#   'back',
#   'kemarin',
#   'tombol',
#   'pojok',
#   'kanan',
#   'versi',
#   'akmask',
#   'mobile',
#   'pakai',
#   'wifi',
#   'sulit',
#   'koneksi',
#   'pakai',
#   'koneksi',
#   'data',
#   'lancar',
#   'tolong',
#   'tim'],
#  ['voucher', 'gratis', 'ongkir', 'tapi', 'pke', 'hedehh'],
#  ['maaf',
#   'jatuh',
#   'aplikasi',
#   'beritahu',
#   'admin',
#   'undi',
#   'hadiah',
#   'malah',
#   'korban',
#   'tipu',
#   'bnyak',
#   'ber',
#   'nama',
#   'jebak'],
#  ['eta', 'da'],
#  ['biaya', 'admin', 'mahal', 'jual', 'raih', 'untung', 'star', 'seller'],
#  ['up',
#   'dana',
#   'saldo',
#   'pindah',
#   'buka',
#   'dompet',
#   'saldo',
#   'buka',
#   'dompet',
#   'beku'],
#  ['tolong',
#   'tingkat',
#   'kait',
#   'proses',
#   'aju',
#   'food',
#   'proses',
#   'makan',
#   'optimal',
#   'kait',
#   'makan',
#   'barang'],
#  ['kaya',
#   'harga',
#   'diskon',
#   'pas',
#   'harga',
#   'diskon',
#   'harga',
#   'diskon',
#   'cek',
#   'out',
#   'harga',
#   'diskon',
#   'keranjang',
#   'harga',
#   'diskon',
#   'harga',
#   'beda',
#   'keranjang',
#   'keranjang',
#   'harga',
#   'asli',
#   'coret',
#   'cek',
#   'out',
#   'hargane',
#   'utuh',
#   'diskon',
#   'malesin'],
#  ['mem', 'beli', 'akun', 'bayar', 'beda', 'gambar', 'toko'],
#  ['rate', 'sesuai', 'alam', 'beli', 'sembunyi', 'seller', 'tanggung'],
#  ['unduh', 'pulsa', 'ribu', 'promo', 'dikit', 'pulsa'],
#  ['susa', 'membebahari'],
#  ['fitur', 'pilih', 'jasa', 'kirim'],
#  ['barang', 'akun', 'blok'],
#  ['kendala',
#   'spaylater',
#   'hubung',
#   'agen',
#   'bantu',
#   'lunas',
#   'cicil',
#   'sisa',
#   'sukses'],
#  ['aplikasi', 'belanja', 'akurat', 'percaya'],
#  ['kirim', 'tera', 'maksimal', 'terima', 'tanggal', 'kirim', 'tanggal'],
#  ['ulas',
#   'bintang',
#   'ikutin',
#   'karnakan',
#   'aplikasi',
#   'bangkrut',
#   'layan',
#   'langgan',
#   'ulas',
#   'ulas',
#   'mudah',
#   'retas',
#   'beli',
#   'topeng',
#   'mahal',
#   'ongkir',
#   'habis',
#   'topeng'],
#  ['daftar', 'belanja', 'bisaaa'],
#  ['konyol',
#   'beli',
#   'jam',
#   'salah',
#   'klik',
#   'terima',
#   'barang',
#   'barang',
#   'terima',
#   'duit',
#   'hangus',
#   'customer service',
#   'susah',
#   'hubung'],
#  ['ongkos', 'dilembalikan'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['belanja', 'stock', 'kosong'],
#  ['aplikasi', 'rena', 'voucher', 'alas', 'pesan'],
#  ['aplikasi', 'jellllekkkkk', 'akun', 'member', 'daftar', 'spaylater', 'akun'],
#  ['aplikasi', 'lambat'],
#  ['maaf',
#   'kasih',
#   'unduh',
#   'ulang',
#   'verifikasi',
#   'emain',
#   'no',
#   'tlf',
#   'pakek',
#   'hilang',
#   'aktif',
#   'cek',
#   'aplikasi',
#   'mytelkomsel',
#   'aktif',
#   'no',
#   'tlf',
#   'november',
#   'tolong',
#   'kasih',
#   'akal'],
#  ['balance', 'belanja', 'susah', 'dirarik'],
#  ['belanja',
#   'simpan',
#   'troli',
#   'bayar',
#   'jarak',
#   'update',
#   'updatenya',
#   'kelar',
#   'aplikasi',
#   'pakai',
#   'belanja',
#   'saldo',
#   'dana',
#   'bayar'],
#  ['nyaman',
#   'pakai',
#   'ehk',
#   'kesal',
#   'pesan',
#   'bareng',
#   'brngnya',
#   'slh',
#   'ktnya',
#   'tanggung',
#   'ehk',
#   'ngilang',
#   'tanggung'],
#  ['aplikasi', 'benar', 'njir'],
#  ['shopi', 'cod'],
#  ['sekian',
#   'pakai',
#   'ken',
#   'pakai',
#   'gegara',
#   'bosen',
#   'aplikasi',
#   'belah',
#   'pas',
#   'login',
#   'nomor',
#   'nonaktif',
#   'tolong',
#   'mudah',
#   'daftar',
#   'pakai',
#   'mail',
#   'konfirmasi',
#   'kasih',
#   'pilih',
#   'opsi',
#   'pakai',
#   'verifikasi',
#   'mail',
#   'google',
#   'account',
#   'seperti',
#   'gin',
#   'bingung',
#   'alhasil',
#   'bikin',
#   'account',
#   'males'],
#  ['lambat', 'lemod'],
#  ['order',
#   'barang',
#   'bom',
#   'sampai',
#   'samday',
#   'hilang',
#   'males',
#   'belanja',
#   'pagi',
#   'order',
#   'sore',
#   'sampai',
#   'pagi',
#   'order',
#   'bom',
#   'sampai'],
#  ['voucher', 'manipulasi', 'biji'],
#  ['super',
#   'lambat',
#   'jember',
#   'magelang',
#   'toko',
#   'cileduk',
#   'magelang',
#   'kapok',
#   'belanja'],
#  ['sayang',
#   'fitur',
#   'paylater',
#   'beli',
#   'barang',
#   'pulsa',
#   'tagih',
#   'listrik',
#   'pdam',
#   'tv',
#   'kabel'],
#  ['akun',
#   'block',
#   'ban',
#   'kah',
#   'akun',
#   'hilang',
#   'saldo',
#   'shoppe',
#   'hilang',
#   'beli',
#   'barang',
#   'impi',
#   'tua',
#   'smartphone'],
#  ['bintang',
#   'menu',
#   'bayar',
#   'later',
#   'kredit',
#   'aplikasi',
#   'shopeeku',
#   'smtra',
#   'orang',
#   'paylater',
#   'solusi',
#   'ditambahin',
#   'belanja',
#   'bayar',
#   'laternya',
#   'tolong',
#   'jangan',
#   'beda',
#   'langgan',
#   'juga',
#   'sring',
#   'mesan',
#   'smtr',
#   'teman',
#   'mesan',
#   'bayar',
#   'later'],
#  ['anjink', 'aplikasi', 'iklan', 'ganggu', 'tahu'],
#  ['ongkir', 'horor', 'iklan', 'bebas', 'ongkir', 'ongkir', 'keri'],
#  ['flassale', 'beli', 'reload', 'taikkkkkkkkkkkk'],
#  ['toko',
#   'filter',
#   'toko',
#   'toko',
#   'nakal',
#   'beli',
#   'mobil',
#   'remot',
#   'gantung'],
#  ['unduh', 'gagal', 'unduh', 'huh', 'belanja'],
#  ['dana',
#   'smp',
#   'skrng',
#   'transfer',
#   'rekening',
#   'telfon',
#   'customer',
#   'service',
#   'selalu',
#   'suruh',
#   'tunggu',
#   'sdah',
#   'hmpir',
#   'trnsferan',
#   'rekening',
#   'nunngu'],
#  ['belanja',
#   'pesan',
#   'sepatu',
#   'baju',
#   'aju',
#   'dana',
#   'barang',
#   'pesan',
#   'terima',
#   'aju',
#   'dana',
#   'tingkat',
#   'kualitas',
#   'layan',
#   'hack'],
#  ['basi',
#   'keluarga',
#   'akun',
#   'promo',
#   'alas',
#   'alamat',
#   'keluarga',
#   'rumah',
#   'alamat',
#   'pakai',
#   'alamat',
#   'tetangga',
#   'pakai',
#   'bacot'],
#  ['kuis', 'aplikasi', 'ram', 'ruang', 'kasih', 'hadiah', 'capek'],
#  ['maaf', 'lebe', 'ongkir'],
#  ['ken',
#   'login',
#   'akun',
#   'susah',
#   'tunggu',
#   'sms',
#   'smsnya',
#   'bangke',
#   'capek',
#   'nungguin'],
#  ['tolong', 'bebas', 'milih', 'ekspedisi', 'jnt'],
#  ['kolom', 'cari', 'ngebug', 'melulu', 'anjg'],
#  ['tolong',
#   'kirim',
#   'layan',
#   'express',
#   'kur',
#   'barang',
#   'kasih',
#   'asing',
#   'konfirmasi',
#   'terima',
#   'barang',
#   'elektronik',
#   'harga'],
#  ['shopeepay',
#   'emas',
#   'kirim',
#   'minimal',
#   'minggu',
#   'aneh',
#   'pakai',
#   'cod',
#   'why',
#   'perbaikin',
#   'tolong',
#   'reseller',
#   'tipu',
#   'tindak',
#   'bnyak',
#   'korban',
#   'beli'],
#  ['versi',
#   'ringan',
#   'update',
#   'versi',
#   'buka',
#   'bin',
#   'lot',
#   'pakai',
#   'internet',
#   'cepat',
#   'mbps',
#   'bayangin',
#   'cepat',
#   'aplikasi',
#   'belanja',
#   'konten',
#   'buka',
#   'nongol',
#   'alias',
#   'susah',
#   'buka',
#   'update',
#   'versi',
#   'sekarang',
#   'auto',
#   'aplikasi',
#   'kaliyan',
#   'yuk',
#   'komentar',
#   'aplikasi'],
#  ['kurir', 'kirim', 'timika', 'papua', 'belanja', 'uninstal'],
#  ['barang', 'sampah'],
#  ['tolong',
#   'verifikasi',
#   'ganti',
#   'akun',
#   'mudah',
#   'akun',
#   'email',
#   'no',
#   'handphone',
#   'ganti',
#   'akun',
#   'double',
#   'akun',
#   'hadehh'],
#  ['seler',
#   'tolong',
#   'kasih',
#   'atur',
#   'ketat',
#   'order',
#   'barang',
#   'transfer',
#   'barang',
#   'jalan',
#   'cancel',
#   'uang',
#   'jangka',
#   'sampai',
#   'minggu'],
#  ['maap', 'sekarng', 'buka', 'aplikasi', 'yoko', 'tida', 'mwnanggapi'],
#  ['devolepor',
#   'mesti',
#   'tipu',
#   'cashback',
#   'gratis',
#   'ongkir',
#   'iklan',
#   'tv',
#   'gratis',
#   'ongkir',
#   'minimum',
#   'belanja',
#   'belanja'],
#  ['easi',
#   'soping',
#   'pt',
#   'karisma',
#   'bahana',
#   'gemilang',
#   'tipu',
#   'suruh',
#   'mutar',
#   'lotery',
#   'lucki',
#   'miliader',
#   'rodah',
#   'henti',
#   'angka',
#   'miliard',
#   'hasil',
#   'rezeki',
#   'bukti',
#   'hoaks',
#   'tahu',
#   'almat',
#   'easi',
#   'soping',
#   'pulsa',
#   'informasi',
#   'hitung',
#   'buta',
#   'hukum',
#   'hak',
#   'tuhan',
#   'yesus',
#   'kutuk',
#   'cilakalah',
#   'binasa',
#   'kru',
#   'easy',
#   'soping',
#   'musiba',
#   'tabrak',
#   'maut',
#   'do',
#   'putra',
#   'flores',
#   'korban',
#   'tipu',
#   'amin',
#   'easi',
#   'soping',
#   'utang',
#   'timor'],
#  ['kode', 'otp', 'kirim', 'checkout'],
#  ['waaah',
#   'shoppi',
#   'benar',
#   'kirim',
#   'srkng',
#   'kesel',
#   'tunggu',
#   'jakarta',
#   'palembang',
#   'kemarin',
#   'kadang',
#   'sampai',
#   'sik',
#   'jasa',
#   'kirim',
#   'hadeh',
#   'langgan',
#   'pindah',
#   'aplikasi',
#   'tolong',
#   'seperti',
#   'jasa',
#   'kirim',
#   'yok',
#   'yok',
#   'seperti',
#   'jasa',
#   'kirim'],
#  ['bikin', 'emosi', 'tombal', 'batal', 'transaksi'],
#  ['pelit',
#   'gara',
#   'score',
#   'game',
#   'menu',
#   'bilang',
#   'main',
#   'normal',
#   'normal',
#   'ranking',
#   'voucher'],
#  ['kirim', 'lambattt', 'sen'],
#  ['platform', 'jaz'],
#  ['tunggu', 'jam', 'terintal', 'intal'],
#  ['tipu',
#   'hadiah',
#   'google',
#   'chrom',
#   'ujung',
#   'sruh',
#   'donlot',
#   'aplikasi',
#   'tapi',
#   'hadiah',
#   'bisa',
#   'ambil',
#   'dasar',
#   'tukang',
#   'tipu',
#   'pngen',
#   'bnyak',
#   'pngguna',
#   'tapi',
#   'pakai',
#   'mutu'],
#  ['aplikasi', 'nyaa', 'bagetttt', 'boooooggg'],
#  ['aplikasi', 'lihah', 'kopon', 'lodingnya'],
#  ['sesuai',
#   'iklan',
#   'iklan',
#   'promo',
#   'diskon',
#   'bebas',
#   'ongkir',
#   'promo',
#   'bayar',
#   'cod',
#   'bayar',
#   'bikin'],
#  ['kemarin',
#   'kasi',
#   'bintang',
#   'skarang',
#   'ganti',
#   'respon',
#   'pas',
#   'dana',
#   'barang',
#   'kirim',
#   'kasi',
#   'kabar',
#   'dana',
#   'jual',
#   'barang',
#   'terima',
#   'uang',
#   'kontak',
#   'jual',
#   'hati',
#   'kirim'],
#  ['hancur',
#   'tokopoint',
#   'daerah',
#   'pakai',
#   'kupon',
#   'diskon',
#   'batal',
#   'transfer',
#   'alas',
#   'langgar',
#   'klu',
#   'jangan',
#   'kupon',
#   'diskon',
#   'pdahal',
#   'hancur',
#   'updatenya',
#   'maaf',
#   'uninstal',
#   'pindah',
#   'toko',
#   'belah',
#   'lebih baik'],
#  ['uninstal', 'dominan', 'toko', 'orange'],
#  ['unduh', 'kenapa', 'pas', 'taut', 'suruh', 'dwonload'],
#  ['layan',
#   'tunggu',
#   'pesan',
#   'tampa',
#   'update',
#   'kirim',
#   'batal',
#   'kirim',
#   'tampa',
#   'terang'],
#  ['bodo', 'aplikasi', 'gratis', 'ongkir', 'bayar', 'ongkir', 'mahal'],
#  ['tol', 'aplikasi'],
#  ['update',
#   'aplikasi',
#   'selalu',
#   'ngeblank',
#   'ngetik',
#   'cari',
#   'barang',
#   'susah',
#   'brng',
#   'keranjang',
#   'bisa',
#   'hapus',
#   'msih',
#   'banyak',
#   'setelah',
#   'update',
#   'perbaikin',
#   'bug'],
#  ['limit', 'spaylater', 'bayar', 'jatuh', 'tempo'],
#  ['mahal', 'beda', 'selisih', 'bangetttttt'],
#  ['maaf', 'transaksi', 'shopeepay', 'shopeepay', 'later', 'limit'],
#  ['minimal',
#   'belanja',
#   'ribu',
#   'free',
#   'ongkir',
#   'kaget',
#   'belanja',
#   'butuh',
#   'rumah',
#   'ongkir',
#   'langit',
#   'alih',
#   'pindah',
#   'belanja',
#   'toko',
#   'belah',
#   'free',
#   'ongkir'],
#  ['sembako', 'kupon', 'utuh'],
#  ['beli', 'paket', 'sertifikat', 'dashboard'],
#  ['kemarin',
#   'pesan',
#   'pesan',
#   'batal',
#   'dana',
#   'transfer',
#   'untuk',
#   'dana',
#   'tolong',
#   'rekening',
#   'akun',
#   'nama',
#   'masukkan',
#   'rekening',
#   'seller',
#   'aktif'],
#  ['dana',
#   'pesan',
#   'batal',
#   'dana',
#   'rekening',
#   'perhati',
#   'langgan',
#   'sulit',
#   'uang',
#   'hak',
#   'tolong',
#   'dana'],
#  ['deret', 'ssrx', 'det', 'er'],
#  ['mecahin',
#   'telur',
#   'update',
#   'koin',
#   'update',
#   'gratis',
#   'ongkir',
#   'update',
#   'update',
#   'padal',
#   'update',
#   'tetep',
#   'update',
#   'kuota',
#   'habis',
#   'update',
#   'aplikasi',
#   'ginian',
#   'tolong',
#   'perintah',
#   'update',
#   'rang'],
#  ['jgan',
#   'belanja',
#   'barang',
#   'pesan',
#   'barang',
#   'ngk',
#   'sesuai',
#   'sya',
#   'mesan',
#   'baju',
#   'celana',
#   'bokser',
#   'pendek'],
#  ['beri',
#   'kupon',
#   'diskon',
#   'pas',
#   'belanja',
#   'pesan',
#   'batal',
#   'otomatis',
#   'kupon',
#   'pakai',
#   'lagi',
#   'kasih',
#   'kupon',
#   'diskon',
#   'rugi'],
#  ['tracking',
#   'paket',
#   'jalan',
#   'web',
#   'kurir',
#   'cek',
#   'jalan',
#   'asa',
#   'belanja',
#   'gin'],
#  ['aplikasi',
#   'go',
#   'internasional',
#   'urus',
#   'tagih',
#   'spaylatter',
#   'spinjam',
#   'nada',
#   'bicara',
#   'pesan',
#   'ngalahin',
#   'rentenir',
#   'mkn',
#   'bangku',
#   'sekolah',
#   'bunga',
#   'gede',
#   'dibyr',
#   'cicil',
#   'masih',
#   'orang',
#   'peres',
#   'layak',
#   'hutang',
#   'ratus',
#   'juta',
#   'miris',
#   'gaji',
#   'krywn',
#   'hasil',
#   'paksa',
#   'pinjam',
#   'ksh',
#   'kenal',
#   'lagi',
#   'zaman',
#   'lagi',
#   'covid',
#   'tegang',
#   'aplikasi',
#   'sblh',
#   'move',
#   'on'],
#  ['aplikasi', 'mahal', 'ongkir', 'harga', 'normal'],
#  ['lot', 'loading', 'terusssss'],
#  ['beli',
#   'dishopee',
#   'jual',
#   'tanggung',
#   'barang',
#   'kirim',
#   'salah',
#   'dana',
#   'barang'],
#  ['iklan', 'paksa', 'resah', 'hadeh'],
#  ['bayar', 'pakai', 'dana', 'unistal'],
#  ['iklanya', 'menggangu'],
#  ['mh', 'transaksi', 'ny', 'eror', 'terusssssss'],
#  ['akun',
#   'non',
#   'aktif',
#   'beku',
#   'langgar',
#   'atur',
#   'aplikasi',
#   'banned',
#   'kominfo',
#   'beli',
#   'latih',
#   'aplikasi',
#   'lulus',
#   'sertifikat',
#   'skill',
#   'academy',
#   'lapor',
#   'instansi',
#   'taung',
#   'bekerjasama',
#   'aplikasi',
#   'sertifikat',
#   'latih',
#   'muncul',
#   'dashboard',
#   'akun',
#   'tipu',
#   'publik'],
#  ['penguna', 'ambil', 'rp', 'kocak'],
#  ['jelekkk',
#   'bangett',
#   'voucher',
#   'beli',
#   'kaos',
#   'toko',
#   'dibatalinn',
#   'uang',
#   'balik',
#   'kejebakk',
#   'saldo',
#   'ambil',
#   'gabisaa',
#   'pakai',
#   'dana',
#   'pakeovo',
#   'gabisaa',
#   'gabanyakk',
#   'namnaya',
#   'uang'],
#  ['daftar', 'kode', 'frivikasi', 'muncul', 'muncul'],
#  ['aplikasi',
#   'bohong',
#   'pakai',
#   'sopepay',
#   'susah',
#   'kode',
#   'otp',
#   'kirim',
#   'bonuss',
#   'akun',
#   'saldo',
#   'ribu',
#   'tipu'],
#  ['habisin', 'kuota', 'update', 'profil', 'sampai', 'kiamat'],
#  ['pesan',
#   'cancel',
#   'kirim',
#   'kirim',
#   'gmn',
#   'jual',
#   'verifikasi',
#   'sopenya',
#   'solusi',
#   'gmn'],
#  ['limit', 'shopeepaylater', 'rp', 'cicil', 'lunas'],
#  ['spaylater', 'diaktivasi', 'gagal'],
#  ['kirain',
#   'harga',
#   'murah',
#   'wkwkwkwk',
#   'diskon',
#   'pelit',
#   'maaf',
#   'auto',
#   'uninstal'],
#  ['cashback',
#   'bukareksa',
#   'promo',
#   'reksajul',
#   'reksajul',
#   'reksaaug',
#   'reksaaug',
#   'hitung',
#   'cashback',
#   'komplain',
#   'ulang',
#   'tunggu',
#   'seninggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'tahan',
#   'dana',
#   'jual'],
#  ['update', 'susah', 'buka'],
#  ['barang', 'manaaaaa'],
#  ['rugi', 'beli', 'realpeack'],
#  ['aplikasi', 'nyampah'],
#  ['terimah', 'kasih', 'pesan', 'barangx', 'cepat', 'kirim'],
#  ['lindung',
#   'konsumen',
#   'tipu',
#   'seller',
#   'kayak',
#   'barang',
#   'butuh',
#   'minggu'],
#  ['buka',
#   'akun',
#   'transaksi',
#   'kemarin',
#   'beli',
#   'promo',
#   'klaim',
#   'langgar',
#   'pdhal',
#   'transaksi',
#   'aju',
#   'kpan',
#   'langgar',
#   'internal',
#   'customer',
#   'bukti'],
#  ['kesini', 'aplikasi', 'kok', 'bayar', 'eror', 'gakda', 'solusi', 'aplikasi'],
#  ['update',
#   'versi',
#   'hubung',
#   'ulang',
#   'kolom',
#   'feed',
#   'buka',
#   'tolong',
#   'nyaman',
#   'handphone',
#   'samsung',
#   'profesional',
#   'terima',
#   'kasih'],
#  ['tarik', 'dana'],
#  ['aplikasi', 'layan'],
#  ['bnayak', 'update'],
#  ['sistem', 'error'],
#  ['bertanya',
#   'event',
#   'paket',
#   'data',
#   'pulsa',
#   'perak',
#   'tu',
#   'boongan',
#   'ubah',
#   'bintang',
#   'kecuali',
#   'please'],
#  ['sanggat', 'kecewaa'],
#  ['aju', 'hapus', 'akun', 'ribet'],
#  ['rugi', 'tolong', 'uang'],
#  ['krkurangan',
#   'transaksi',
#   'aplikasi',
#   'tampil',
#   'wahhh',
#   'sistem',
#   'transaksi',
#   'normal'],
#  ['barang', 'rusak', 'jual', 'gemanay'],
#  ['uda', 'bayar', 'bom', 'sampai'],
#  ['transfer', 'airpayinternal', 'beli', 'barang', 'batal', 'dana', 'tidak'],
#  ['jangan',
#   'unduh',
#   'bnyak',
#   'pnipuan',
#   'jual',
#   'buukn',
#   'brang',
#   'asli',
#   'rport',
#   'smaa',
#   'bnyak',
#   'unsur',
#   'penipuann'],
#  ['transaksi', 'batal', 'aplikasi', 'jelasssss'],
#  ['belanja',
#   'gilir',
#   'belanja',
#   'poin',
#   'ktanya',
#   'cod',
#   'isi',
#   'pdhl',
#   'pakai',
#   'ongkir',
#   'bebas',
#   'ongkir',
#   'moduss',
#   'kopeeet'],
#  ['saldo', 'hasil', 'refund', 'belanja'],
#  ['aplikasi', 'bohong', 'diskon', 'pas', 'tunggu', 'tunggu', 'unduh'],
#  ['ribet',
#   'jual',
#   'cair',
#   'dana',
#   'beli',
#   'sesuai',
#   'terang',
#   'terang',
#   'sampai',
#   'oktober',
#   'konfirmasi',
#   'beli',
#   'dana',
#   'otomatis',
#   'jual',
#   'oktober',
#   'dana',
#   'tahan',
#   'kasih',
#   'terang',
#   'bikin',
#   'jual',
#   'harap'],
#  ['kaya', 'massa', 'pesan', 'barang'],
#  ['komentar',
#   'hapus',
#   'nanti',
#   'ketik',
#   'pergi',
#   'hibur',
#   'nanti',
#   'ketik',
#   'komen',
#   'hapus',
#   'shoope',
#   'asw',
#   'salin',
#   'komen',
#   'hapus',
#   'tinggal',
#   'paste',
#   'dikomen',
#   'sembuyikan',
#   'komen',
#   'hapus',
#   'komen',
#   'ketik',
#   'salin',
#   'komen',
#   'hapus',
#   'shoope',
#   'update',
#   'macet',
#   'pantang',
#   'nyerah',
#   'ubah',
#   'santet',
#   'balesanya',
#   'santet'],
#  ['aplikasi', 'unduh'],
#  ['ongkir', 'mahal', 'tolong', 'murahin', 'kayak', 'pandemi', 'uang'],
#  ['komplain', 'ribet'],
#  ['freeong',
#   'belanja',
#   'ribu',
#   'freeong',
#   'belanja',
#   'freeong',
#   'pindah',
#   'market',
#   'place'],
#  ['belanja',
#   'beli',
#   'jual',
#   'biaya',
#   'adminnya',
#   'toko',
#   'dibanned',
#   'pajak',
#   'negara',
#   'ken',
#   'untung',
#   'buntung'],
#  ['ambisi', 'unt', 'unduh', 'iklan', 'muntah', 'tarik', 'belanja', 'turun'],
#  ['bayar', 'sayang', 'bayar'],
#  ['cuman', 'aplikasi', 'gilir', 'girim'],
#  ['aplikasi', 'rancang', 'tipu'],
#  ['aplikasi', 'maksa', 'ta', 'ekkkkkkkkkkkk', 'anjinkkkkkkkkk'],
#  ['iklan', 'asli', 'jlek', 'tipu', 'belanja', 'batal', 'otomatis'],
#  ['update', 'ui', 'user', 'friendly'],
#  ['sesuai', 'iklan'],
#  ['reses', 'iklan', 'bikin', 'risih', 'unduh'],
#  ['shoope',
#   'iklan',
#   'spam',
#   'melulu',
#   'renti',
#   'seperti',
#   'lagi',
#   'main',
#   'ml',
#   'iklan',
#   'shoope'],
#  ['kesini', 'lambat', 'njir', 'buka', 'pakai', 'wifi', 'ram'],
#  ['iklan', 'ngabisin', 'kuota'],
#  ['sponsor', 'broser', 'unduh', 'aplikasi', 'melulu', 'susah', 'pusing'],
#  ['tiktok',
#   'iklan',
#   'toko',
#   'terus',
#   'diam',
#   'jan',
#   'ganggu',
#   'seru',
#   'nonton',
#   'tiktokk'],
#  ['update', 'koneksi', 'bikin', 'kesel'],
#  ['aju', 'tolak', 'spaylaternya', 'hadeh', 'kasih', 'bintang', 'atulah'],
#  ['ongkos',
#   'kirim',
#   'ribu',
#   'voucernya',
#   'sus',
#   'sope',
#   'bayar',
#   'cod',
#   'voucer',
#   'gratis',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'beli',
#   'kasi',
#   'voucher',
#   'sisa',
#   'rebut',
#   'icon',
#   'free',
#   'ogkir',
#   'hilang'],
#  ['aplikasi',
#   'nyampe',
#   'tangal',
#   'nyampenya',
#   'tangal',
#   'aplikasi',
#   'bohong',
#   'install',
#   'aplikasi',
#   'dasar',
#   'aplikasi',
#   'penbohong'],
#  ['beli',
#   'case',
#   'handphone',
#   'negeri',
#   'cari',
#   'produk',
#   'negeri',
#   'cari',
#   'case',
#   'negeri',
#   'negeri',
#   'gmn',
#   'solusi'],
#  ['bayar', 'suruh', 'tunggu', 'jam', 'jam', 'akun', 'blokirr', 'tanggung'],
#  ['susah', 'unduh'],
#  ['mengambil',
#   'gratis',
#   'ongkir',
#   'nominal',
#   'ongkir',
#   'ny',
#   'gede',
#   'sedih',
#   'kadang',
#   'barang',
#   'pes',
#   'mahal',
#   'ongkir'],
#  ['jual',
#   'ragu',
#   'waswas',
#   'sampai',
#   'opsi',
#   'pilih',
#   'asuransi',
#   'halaman',
#   'cek',
#   'out',
#   'produk',
#   'kalah',
#   'toko',
#   'online',
#   'belah',
#   'opsi',
#   'asuransi',
#   'pas',
#   'kantor',
#   'ribet',
#   'karyawan',
#   'admin',
#   'paham',
#   'menbahkan',
#   'asuransi',
#   'profesional',
#   'kacau'],
#  ['jual', 'buku', 'baja', 'liar', 'belanja', 'nyaman'],
#  ['kesini', 'pas', 'unduh', 'video', 'gugel'],
#  ['beli',
#   'produk',
#   'pas',
#   'gilir',
#   'beli',
#   'kamera',
#   'oppo',
#   'nyala',
#   'tolong',
#   'tindak',
#   'lanjutin',
#   'jual'],
#  ['dagang',
#   'nakal',
#   'daripahda',
#   'bikin',
#   'promo',
#   'tv',
#   'lebih baik',
#   'aplikasi'],
#  ['respon',
#   'tolong',
#   'toko',
#   'toko',
#   'amanah',
#   'jual',
#   'respon',
#   'makan',
#   'pergi',
#   'hilang',
#   'konsumen',
#   'keluh',
#   'diam'],
#  ['iklan',
#   'lebih baik',
#   'pas',
#   'nonton',
#   'youtube',
#   'nonton',
#   'halaman',
#   'utama',
#   'layar',
#   'tolong',
#   'iklan'],
#  ['beli',
#   'tas',
#   'gunung',
#   'minggu',
#   'sepatu',
#   'roda',
#   'tipu',
#   'amanah',
#   'pesan',
#   'tas',
#   'kamu',
#   'sepatu',
#   'roda',
#   'gin',
#   'hapus',
#   'aplikashi',
#   'amanah'],
#  ['plis',
#   'batal',
#   'pesan',
#   'ubah',
#   'pikir',
#   'kirimm',
#   'allah',
#   'tolong',
#   'rugi',
#   'bangett'],
#  ['update', 'melulu'],
#  ['from', 'zero', 'hero'],
#  ['ngk', 'gratis', 'ongir'],
#  ['customer',
#   'service',
#   'layan',
#   'nelpon',
#   'butuh',
#   'customer service',
#   'sopan',
#   'santun',
#   'mati',
#   'panggil',
#   'pulsa'],
#  ['buka', 'aplikasi'],
#  ['aman',
#   'aman',
#   'gilir',
#   'kirim',
#   'barang',
#   'tim',
#   'ehh',
#   'hasil',
#   'nol',
#   'konfirmasi',
#   'bukti',
#   'adu',
#   'tim',
#   'jangan',
#   'harap'],
#  ['staff', 'tolong', 'profesional', 'beda', 'gratis', 'ongkir', 'sedih'],
#  ['ongkir', 'mahal'],
#  ['belanja',
#   'komplain',
#   'sanggup',
#   'sarat',
#   'berat',
#   'bangat',
#   'suruh',
#   'bikin',
#   'video',
#   'youtuber',
#   'nomor',
#   'seri',
#   'bukti',
#   'foto',
#   'lanjur',
#   'buka',
#   'paket',
#   'wuish',
#   'nang',
#   'beli'],
#  ['shope', 'bayar', 'qd', 'blokir', 'salah'],
#  ['muncul', 'iklan', 'internet', 'otomatis', 'kesini', 'orang', 'maksa'],
#  ['maaf', 'sen', 'apa', 'dateng', 'tolong'],
#  ['jangan', 'kirim', 'promo', 'handphone', 'tarik', 'ganggu'],
#  ['erti', 'beli', 'latih', 'kartu', 'gagal', 'tipu', 'kayak', 'gin'],
#  ['jan', 'maksa', 'install'],
#  ['mntep', 'shopefood'],
#  ['cobakalau',
#   'promosi',
#   'tipu',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ongkir',
#   'gede',
#   'harga',
#   'barang'],
#  ['kesini', 'gara', 'google', 'crome', 'ribu'],
#  ['update', 'klik', 'toko'],
#  ['cerita', 'shopi', 'hoax'],
#  ['curang', 'event', 'event', 'sistem', 'talu', 'lot', 'sistem', 'jadul'],
#  ['kirim', 'pesan', 'kayak', 'buka', 'kirim', 'dikit', 'tinggal', 'buka'],
#  ['ualah', 'tahu', 'cod', 'biaya', 'nang', 'xixixixixididi'],
#  ['apdead', 'paylater'],
#  ['aplikasi',
#   'belanja',
#   'seller',
#   'blokir',
#   'toko',
#   'tanggung',
#   'rugi',
#   'beli'],
#  ['aplikasi', 'cuman', 'iklan', 'ganggu', 'anjeng'],
#  ['trooble', 'tuuuerruusss'],
#  ['berat',
#   'beli',
#   'setia',
#   'beli',
#   'barang',
#   'harga',
#   'juta',
#   'tipu',
#   'beli',
#   'ebook',
#   'tips',
#   'jitu',
#   'isi',
#   'screen',
#   'shot',
#   'kirim',
#   'biji',
#   'admin',
#   'tolak',
#   'adu',
#   'sungguh',
#   'menang',
#   'tipu',
#   'kayak',
#   'gin',
#   'lebih baik',
#   'unistall',
#   'jamin',
#   'aman',
#   'beli',
#   'tipu',
#   'bukalapa'],
#  ['tolong',
#   'buka',
#   'aplikasi',
#   'muslim',
#   'profesional',
#   'solat',
#   'iklan',
#   'menganggu',
#   'muslim',
#   'profesional',
#   'tutup',
#   'aplikasi',
#   'kesel',
#   'maaf',
#   'ulas',
#   'salah',
#   'salah',
#   'seller',
#   'tanggung',
#   'tindak'],
#  ['benar',
#   'bikin',
#   'murka',
#   'pesan',
#   'sya',
#   'sesuai',
#   'chat',
#   'seller',
#   'tidak',
#   'etikad',
#   'baca',
#   'tolong',
#   'smpein',
#   'toko',
#   'ling',
#   'hong',
#   'jual',
#   'amanah'],
#  ['harga',
#   'dimainin',
#   'aplikasi',
#   'pilih',
#   'warna',
#   'size',
#   'harga',
#   'ubah',
#   'tertawa',
#   'capek',
#   'capek',
#   'milih',
#   'mlototin',
#   'order',
#   'harga',
#   'sesuai',
#   'tema',
#   'stop',
#   'gunain'],
#  ['aplikasi', 'aneh', 'barang', 'bayar', 'batal', 'aplikasi'],
#  ['buka', 'susah', 'loadingnya'],
#  ['shope',
#   'plis',
#   'mengundng',
#   'teman',
#   'verif',
#   'ktp',
#   'teman',
#   'bom',
#   'bikin',
#   'ktf',
#   'macam',
#   'plis',
#   'rakyat',
#   'indonesia',
#   'even'],
#  ['daya', 'bayar', 'ngeblank'],
#  ['kada', 'baikk'],
#  ['akun',
#   'hack',
#   'atm',
#   'akun',
#   'pinjam',
#   'uang',
#   'jt',
#   'block',
#   'aplikasi',
#   'aman'],
#  ['masak',
#   'aju',
#   'spaylater',
#   'bayar',
#   'kartu',
#   'kredit',
#   'mengunakan',
#   'aplikasi',
#   'shoppee',
#   'lah',
#   'kartu',
#   'kredit',
#   'ngk',
#   'shopeepay',
#   'aneh',
#   'shoppe',
#   'limit',
#   'ngk'],
#  ['ribet', 'sen', 'gratis', 'ongkir'],
#  ['sesal', 'nang', 'akun', 'blok'],
#  ['sama',
#   'aplikasi',
#   'pilih',
#   'transaksi',
#   'batalakan',
#   'dn',
#   'belah',
#   'transaksi',
#   'sampai',
#   'tunggu',
#   'minggu',
#   'uang'],
#  ['sakit', 'killik', 'kirim', 'barang'],
#  ['hapus',
#   'aju',
#   'phaylater',
#   'tolak',
#   'muncul',
#   'tawar',
#   'phaylater',
#   'aju',
#   'tolak'],
#  ['maaf',
#   'pakai',
#   'aplikasi',
#   'ajh',
#   'gratis',
#   'ongkir',
#   'minggu',
#   'ganti',
#   'handphone',
#   'unduh',
#   'teman',
#   'kenapa',
#   'potong',
#   'ongkir'],
#  ['aplikasi', 'sempurna'],
#  ['sen',
#   'barang',
#   'dilazada',
#   'tahu',
#   'tahu',
#   'kurir',
#   'dateng',
#   'rumah',
#   'tas',
#   'slempang',
#   'bayar',
#   'sen',
#   'sen',
#   'dateng',
#   'gmn',
#   'hapus',
#   'akun'],
#  ['transaksi',
#   'batal',
#   'recommended',
#   'belanja',
#   'lebih baik',
#   'pakai',
#   'mudah',
#   'aman',
#   'ribet',
#   'iming',
#   'gratis',
#   'ongkir',
#   'tahu',
#   'fiktif',
#   'google',
#   'mereview',
#   'aplikasi',
#   'ngrugiin'],
#  ['kirim',
#   'lambattt',
#   'bngettt',
#   'proses',
#   'toko',
#   'belah',
#   'cepat',
#   'tolong',
#   'koreksi'],
#  ['aneh', 'transaksi', 'anggap', 'pesan', 'batal', 'alas', 'nila', 'fitnah'],
#  ['toko', 'ngentodddd'],
#  ['cepat',
#   'install',
#   'oo',
#   'penuh',
#   'lah',
#   'simpan',
#   'takbisa',
#   'ookesel',
#   'capek',
#   'huudan',
#   'baguss',
#   'oooooooooo'],
#  ['bangke', 'beli', 'paket', 'data', 'suruh', 'tunggu', 'tutup'],
#  ['klaim', 'barang', 'rp'],
#  ['susah', 'cek', 'out', 'lancar'],
#  ['aplikasi',
#   'cantemer',
#   'servis',
#   'sms',
#   'alibi',
#   'aju',
#   'pinjam',
#   'dana',
#   'aju',
#   'pinjam',
#   'dana',
#   'aplikasi',
#   'telepon',
#   'sms',
#   'ganggu'],
#  ['belanja', 'mudah'],
#  ['toko',
#   'vavio',
#   'acc',
#   'jual',
#   'chip',
#   'high',
#   'domino',
#   'tolong',
#   'band',
#   'sdah',
#   'bayar',
#   'suruh',
#   'batal',
#   'transaksi',
#   'aplikasi',
#   'skrng',
#   'tunggu',
#   'dana'],
#  ['bingung',
#   'jual',
#   'jujur',
#   'bilang',
#   'langgar',
#   'akun',
#   'batas',
#   'dana',
#   'beli',
#   'saldo',
#   'jual',
#   'beli',
#   'setia',
#   'hapus',
#   'bilang',
#   'curiga',
#   'toko',
#   'curiga',
#   'lancar',
#   'bayar',
#   'barang',
#   'beli',
#   'dishopee',
#   'bijak',
#   'kasih',
#   'seperti',
#   'sp',
#   'timbang'],
#  ['saring', 'jual', 'tipu', 'tayiiiilahhh'],
#  ['kanapa', 'barang', 'data', 'ng', 'sedangkab', 'mes', 'tipu'],
#  ['install',
#   'aplikasi',
#   'keamananya',
#   'kemarin',
#   'paket',
#   'tersesat',
#   'akun',
#   'mesan',
#   'log',
#   'out',
#   'akun',
#   'unistal',
#   'tahu',
#   'paket',
#   'ajar',
#   'real',
#   'alam',
#   'tolong',
#   'perhati'],
#  ['aplikasi', 'jlas', 'kirim', 'akun', 'cek', 'kosong'],
#  ['aplikasi', 'sungguh', 'sulit', 'paham', 'barang', 'batal', 'otomatis'],
#  ['tolong',
#   'dijelasin',
#   'aplikasi',
#   'klik',
#   'tapi',
#   'kluar',
#   'klik',
#   'kluar',
#   'lagi',
#   'klik',
#   'kluar',
#   'lagi',
#   'orang',
#   'belanja',
#   'tidak'],
#  ['sistem', 'jual', 'ekspedisi', 'ubah', 'rubah', 'ekspedisi'],
#  ['nggk', 'update', 'gim'],
#  ['balik', 'jasa', 'kirim'],
#  ['flash', 'sale', 'ngadat', 'anjeng'],
#  ['bayar', 'latter', 'bayar', 'sekarang', 'gabiisaa', 'butuh', 'baaanget'],
#  ['batas',
#   'kirim',
#   'seller',
#   'sistem',
#   'cod',
#   'kadang',
#   'kurir',
#   'rumah',
#   'rumah',
#   'kasihan',
#   'kurir',
#   'bolak',
#   'ngekost',
#   'titip',
#   'tetangga',
#   'tetangga'],
#  ['minggu', 'juga', 'pesan', 'detail', 'kirim', 'akurat'],
#  ['seller',
#   'nd',
#   'respon',
#   'proses',
#   'jual',
#   'kirim',
#   'kurir',
#   'nd',
#   'kayak',
#   'lari',
#   'dehh'],
#  ['ngeselin',
#   'aplikasi',
#   'beli',
#   'kirim',
#   'cepat',
#   'tapi',
#   'ngeselin',
#   'brli',
#   'barang',
#   'pengirimanya',
#   'minggu',
#   'kirim',
#   'tutup',
#   'batal',
#   'barang',
#   'begi',
#   'pindah',
#   'toko',
#   'online',
#   'belah',
#   'tolong',
#   'ekspedisi',
#   'instan',
#   'aktif',
#   'cepat',
#   'respon',
#   'auto',
#   'uninstal'],
#  ['benci', 'ygjadi', 'bintang', 'iklan', 'cowok', 'cowok', 'cantik'],
#  ['aplikasi',
#   'sesal',
#   'unduh',
#   'gratis',
#   'traktir',
#   'pas',
#   'pesan',
#   'dibatalin',
#   'langgar',
#   'langgar',
#   'pesan',
#   'kaya',
#   'aplikasi'],
#  ['rp',
#   'ambil',
#   'stok',
#   'habis',
#   'ambil',
#   'stok',
#   'habis',
#   'gilir',
#   'jarak',
#   'pilih',
#   'jasa',
#   'kirim',
#   'harga',
#   'beli',
#   'uninstall'],
#  ['voucher',
#   'jt',
#   'tapi',
#   'tu',
#   'saldo',
#   'toko',
#   'bohong',
#   'mnta',
#   'ampun',
#   'unduh'],
#  ['iklan', 'nongol', 'ganggu'],
#  ['ribet',
#   'ganti',
#   'nomer',
#   'telpon',
#   'susah',
#   'benar',
#   'kirim',
#   'sulit',
#   'kamera',
#   'handphone',
#   'telpon',
#   'customer service',
#   'ngebantunya'],
#  ['kesel', 'harga', 'ongkir', 'mahal', 'skrng', 'ongkir'],
#  ['gratis', 'ongkir', 'boongan'],
#  ['unduh', 'handphone', 'handphone'],
#  ['susah',
#   'flash',
#   'sale',
#   'barang',
#   'mewah',
#   'klik',
#   'terang',
#   'stok',
#   'habis',
#   'barang',
#   'murah',
#   'habis',
#   'stok',
#   'flash',
#   'sale',
#   'kaya',
#   'flash',
#   'sale',
#   'atur',
#   'antri',
#   'aplikasi',
#   'barang',
#   'flash',
#   'sale',
#   'atur',
#   'sistem',
#   'stel',
#   'beda',
#   'pkoknya',
#   'habis',
#   'kaya',
#   'atur',
#   'sistem',
#   'pokok',
#   'buyer',
#   'habis'],
#  ['kirim', 'cepat', 'terpercsya', 'tunggu', 'tidak', 'kirim'],
#  ['aplikasi', 'kirim', 'cepat', 'pokok'],
#  ['shope', 'aneh'],
#  ['bintang', 'pesan'],
#  ['aplikasi',
#   'tolong',
#   'bantu',
#   'masak',
#   'saldo',
#   'hilang',
#   'kasih',
#   'bintang'],
#  ['aplikasi', 'bujang', 'mahal', 'beda', 'tetangga', 'laz'],
#  ['buka', 'lapak', 'sya', 'bayar', 'status', 'belanja', 'ubah', 'bayar'],
#  ['cocok', 'kulit', 'pakai', 'aloe', 'vera', 'pesan'],
#  ['sen',
#   'kirim',
#   'pesan',
#   'barang',
#   'cancel',
#   'jual',
#   'tolong',
#   'laa',
#   'bikin'],
#  ['ambil', 'aplikasi', 'pakai', 'jengkel', 'muncul'],
#  ['iklan', 'resah'],
#  ['cashback', 'rp', 'hilang', 'rugi', 'gin'],
#  ['cod', 'gratis', 'ongkir', 'bohong', 'nihhh'],
#  ['danta',
#   'paket',
#   'donwload',
#   'bekal',
#   'mentang',
#   'isi',
#   'paket',
#   'pakai',
#   'paket',
#   'mahal',
#   'sesuai',
#   'gadantaaaawwa'],
#  ['pindah', 'masak', 'kurir', 'anggap', 'budak'],
#  ['klaim',
#   'diskon',
#   'ribu',
#   'jam',
#   'voucher',
#   'hilang',
#   'refresh',
#   'ttp',
#   'ngadain',
#   'diskon',
#   'leg'],
#  ['agent',
#   'chat',
#   'live',
#   'shoppe',
#   'jk',
#   'bantu',
#   'chat',
#   'putus',
#   'paket',
#   'ydk',
#   'kirim',
#   'minta',
#   'dana',
#   'toko',
#   'tolak',
#   'aplikasi',
#   'lepas',
#   'tangan'],
#  ['driver',
#   'shope',
#   'food',
#   'pakai',
#   'fake',
#   'gps',
#   'tuyul',
#   'aplikasi',
#   'larang',
#   'tindak',
#   'jangan',
#   'mlh',
#   'kasihan',
#   'driver',
#   'jujur',
#   'driver',
#   'order',
#   'pakai',
#   'tuyul',
#   'suspend',
#   'pakai',
#   'aplikasi',
#   'aman',
#   'maju',
#   'jaya'],
#  ['beli', 'barang', 'paket', 'kosong', 'dana'],
#  ['iklan', 'otomatis', 'amit', 'lebih baik', 'shopie', 'olx'],
#  ['gratis',
#   'ongkir',
#   'belanja',
#   'ribu',
#   'ribu',
#   'sesuai',
#   'tema',
#   'lebih baik'],
#  ['seller', 'cetak', 'print', 'alamat', 'kirim', 'aplikasi'],
#  ['tipu',
#   'jgan',
#   'kayak',
#   'gin',
#   'percaya',
#   'sama',
#   'permai',
#   'pesan',
#   'batal',
#   'saldo',
#   'direfund',
#   'bisa',
#   'belanja',
#   'uang',
#   'bisa',
#   'tarik',
#   'capek',
#   'capek',
#   'alfamidi',
#   'bayar',
#   'uang',
#   'admin',
#   'batal',
#   'saldo',
#   'refund',
#   'pakai',
#   'tarik',
#   'malu',
#   'maluin'],
#  ['pesan',
#   'barang',
#   'oct',
#   'tngl',
#   'barang',
#   'terima',
#   'kirim',
#   'terima',
#   'barang',
#   'juga',
#   'belum',
#   'barang',
#   'kirim',
#   'kacau',
#   'toko',
#   'barang',
#   'belum',
#   'terima',
#   'kirim',
#   'kurir',
#   'nelpon',
#   'tidak',
#   'barang',
#   'sampai',
#   'no',
#   'handphone',
#   'customer service',
#   'ninja',
#   'exxpres',
#   'beres',
#   'atw',
#   'pm',
#   'kurir'],
#  ['kasih', 'bintang'],
#  ['ongkir', 'mahal', 'barang', 'beli', 'ribu', 'ongkir'],
#  ['lot', 'parahh', 'sinyal', 'wifi', 'gambar', 'polos', 'notificationnya'],
#  ['check', 'out', 'hubungi', 'customer service'],
#  ['unduh',
#   'aplikasi',
#   'aplikasi',
#   'pesan',
#   'terima',
#   'sampai',
#   'sampai',
#   'tangan',
#   'tungguin',
#   'tetep',
#   'datang',
#   'datang',
#   'belanja',
#   'mengecewaken',
#   'gabakal',
#   'belanja',
#   'rim',
#   'konsisten'],
#  ['log', 'nomor', 'blokir', 'pdhl', 'pakai', 'order', 'jual'],
#  ['aplikasi', 'php'],
#  ['aplikasi',
#   'akun',
#   'sya',
#   'blokir',
#   'sya',
#   'sarankn',
#   'dwonload',
#   'jangan',
#   'dwnload',
#   'nyeseel'],
#  ['bayar', 'link'],
#  ['belanja',
#   'pesan',
#   'bayar',
#   'tanggal',
#   'nov',
#   'tanda',
#   'kirim',
#   'catat',
#   'proses',
#   'kemas',
#   'gilir',
#   'chat',
#   'customer service',
#   'muter',
#   'karuan'],
#  ['iklan', 'melulu', 'kntol', 'aplikasi', 'anjng'],
#  ['seller', 'bodoh'],
#  ['kirim', 'kayak', 'toko'],
#  ['tolong',
#   'skrng',
#   'ongkir',
#   'pisah',
#   'pisah',
#   'ongkir',
#   'distuin',
#   'sdkit',
#   'tolong',
#   'satuin',
#   'ongkir'],
#  ['sayang',
#   'cicil',
#   'kartu',
#   'kredit',
#   'toko',
#   'belah',
#   'kredit',
#   'kartu',
#   'kredit'],
#  ['terkadang',
#   'masuk',
#   'fitur',
#   'siram',
#   'tanam',
#   'lngsng',
#   'freeze',
#   'baru',
#   'restart',
#   'ulang',
#   'handphone',
#   'khawarir',
#   'rebout',
#   'handphone',
#   'tolong',
#   'lagi',
#   'memori',
#   'masih',
#   'seger',
#   'ram',
#   'juga',
#   'masih',
#   'sisa',
#   'gb',
#   'lbh',
#   'gb',
#   'handphone',
#   'juga',
#   'bukan',
#   'kentang',
#   'aplikasi',
#   'berat',
#   'fitur',
#   'selalu',
#   'lin'],
#  ['aplikasi', 'gun', 'tipu'],
#  ['belanja',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'extra',
#   'susah',
#   'check',
#   'out',
#   'bolak'],
#  ['syah', 'bayar', 'expres'],
#  ['jelekkk',
#   'main',
#   'game',
#   'minecrft',
#   'nama',
#   'survival',
#   'na',
#   'muncul',
#   'ikkelan',
#   'pencet',
#   'skip',
#   'mati',
#   'iiih',
#   'jelekk'],
#  ['bug', 'bnerin'],
#  ['shope', 'gimmick', 'flashsale', 'iphone', 'kirim', 'batal', 'hahaha'],
#  ['beres',
#   'aplikasi',
#   'unduh',
#   'aplikasi',
#   'ken',
#   'coba',
#   'belanja',
#   'kayak',
#   'ny',
#   'checkout',
#   'payung',
#   'harga',
#   'ongkir',
#   'akal',
#   'tanggerang',
#   'jambi',
#   'ongkir',
#   'rp',
#   'benar',
#   'harga',
#   'payung'],
#  ['team',
#   'buka',
#   'lapak',
#   'becus',
#   'cie',
#   'nanganin',
#   'custamer',
#   'transaksi',
#   'tanggal',
#   'nov',
# ...
#  ['minggu', 'barng', 'terima', 'uang', 'komplain', 'tutup', 'tnpa'],
#  ['belum',
#   'tanggap',
#   'beli',
#   'pulsa',
#   'kedaluwarsa',
#   'bayar',
#   'status',
#   'kadaluwarsa',
#   'baru',
#   'bayar',
#   'terima',
#   'kasih'],
#  ['belanja', 'tipu', 'lebih baik', 'uninstal'],
#  ['berbsngga', 'hati', 'samsung'],
#  ['kasih', 'sampai'],
#  ['adminlu',
#   'naekin',
#   'presentase',
#   'cashback',
#   'diturunin',
#   'naekin',
#   'tolong',
#   'dinaekkn',
#   'merger',
#   'suramm'],
#  ['aplikasi',
#   'anjig',
#   'pdahal',
#   'install',
#   'promo',
#   'batal',
#   'sen',
#   'voucher',
#   'ongkir',
#   'hilang',
#   'tlol'],
#  ['aplikasi',
#   'produk',
#   'sesuai',
#   'pesan',
#   'sayang',
#   'ongkir',
#   'mahal',
#   'diskon',
#   'voucer',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'mengambil',
#   'ribu'],
#  ['promo',
#   'mancing',
#   'awam',
#   'pengaruh',
#   'promo',
#   'fitur',
#   'aplikasi',
#   'kaku',
#   'saldo',
#   'dipake',
#   'bayar',
#   'ambil',
#   'lebih baik'],
#  ['gratis',
#   'ongkir',
#   'dwnlod',
#   'pesan',
#   'barang',
#   'langgan',
#   'knk',
#   'cas',
#   'ribu',
#   'ongkir',
#   'kelimapuluh',
#   'kabupaten',
#   'batubara',
#   'harga',
#   'mahal',
#   'bnding',
#   'murah',
#   'ongkir',
#   'cmn',
#   'ribu',
#   'gratis',
#   'ongkir',
#   'pulau',
#   'jawa',
#   'kesumut',
#   'ribu',
#   'gilaaak',
#   'klen',
#   'seperti',
#   'gmn',
#   'banyak',
#   'plnggnnya',
#   'blnj',
#   'berat',
#   'diongkir',
#   'hrg',
#   'mahal',
#   'banding',
#   'aplikasi',
#   'ttngga'],
#  ['keluarin', 'iklan', 'boss', 'kesel', 'iklan', 'nyaman'],
#  ['up', 'kemarin', 'indomart', 'sukses', 'saldo'],
#  ['aplikasi',
#   'commerce',
#   'bikin',
#   'bingung',
#   'masukkan',
#   'nomor',
#   'rekening',
#   'susah'],
#  ['sinyal', 'butuh'],
#  ['maaf',
#   'bri',
#   'bintang',
#   'ea',
#   'nnti',
#   'klau',
#   'brng',
#   'smpai',
#   'baru',
#   'ksih',
#   'bintang',
#   'lagi'],
#  ['lambat', 'downloadnya'],
#  ['organisasi', 'birokrasi'],
#  ['gin',
#   'dowanload',
#   'lagu',
#   'chrome',
#   'ngapain',
#   'unduh',
#   'bilang',
#   'macam',
#   'macam',
#   'poromo',
#   'case',
#   'back',
#   'bikin',
#   'repot',
#   'perasaandah'],
#  ['iklan', 'ganggu', 'tolong', 'jangan', 'iklan', 'sembarang'],
#  ['beli',
#   'bayar',
#   'batal',
#   'promo',
#   'promo',
#   'sisa',
#   'promo',
#   'batal',
#   'transaksi',
#   'kupon',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'ribu',
#   'kupon',
#   'cashback',
#   'ribu',
#   'hilang',
#   'pagi',
#   'sisa',
#   'aju',
#   'care',
#   'balas',
#   'sesuai',
#   'prosedur',
#   'langgar',
#   'tolong'],
#  ['lapak', 'barang', 'siap', 'order', 'kirim', 'kirim', 'batal', 'konfirmasi'],
#  ['takut', 'jahat', 'ngrim', 'alamat'],
#  ['tmpat', 'tinggal', 'camat', 'grong', 'kabupaten', 'pidie', 'kota', 'sigli'],
#  ['tutup', 'akun', 'tanda', 'sistem', 'shoppe', 'kualitas'],
#  ['gratis',
#   'ongkir',
#   'pakai',
#   'sekal',
#   'cari',
#   'toko',
#   'label',
#   'gratis',
#   'ongkir',
#   'toko',
#   'barang',
#   'cari',
#   'pakai',
#   'toko',
#   'kacau',
#   'tolong'],
#  ['lot', 'bnget', 'bayar', 'susah', 'kesini', 'mkin', 'mles', 'lot'],
#  ['lma',
#   'lot',
#   'sebentar',
#   'logout',
#   'sendiri',
#   'pdhal',
#   'ram',
#   'msih',
#   'nyukup',
#   'ntah',
#   'berat',
#   'game',
#   'ny',
#   'tolong'],
#  ['unduh', 'komplen'],
#  ['aplikasi', 'eror', 'terus', 'pdhl', 'update', 'pke', 'pers', 'tetep'],
#  ['budug', 'rehan'],
#  ['gratis', 'ongkir'],
#  ['mola',
#   'minggu',
#   'malam',
#   'kirim',
#   'hadiah',
#   'menang',
#   'nga',
#   'nyampe',
#   'coi',
#   'hadiah',
#   'palsu'],
#  ['barang', 'sesuai'],
#  ['klu',
#   'setock',
#   'barang',
#   'jangan',
#   'pajang',
#   'pajang',
#   'gambar',
#   'pesan',
#   'baju',
#   'batas',
#   'proses',
#   'proses',
#   'potong',
#   'biayamah',
#   'cepat',
#   'kirim',
#   'susah',
#   'puayah'],
#  ['notifikasi', 'kirim', 'cepat', 'fakta', 'kaya', 'bulus', 'lot', 'estimasi'],
#  ['jual',
#   'amanah',
#   'aplikasi',
#   'proses',
#   'barang',
#   'salah',
#   'kirim',
#   'sulit',
#   'seler',
#   'amanah',
#   'tindak',
#   'sebenernya',
#   'rugi',
#   'aplikasi',
#   'customer',
#   'alih',
#   'aplikasi',
#   'lbh',
#   'amanah',
#   'lbh',
#   'mudah',
#   'proses',
#   'pengembalaian',
#   'barang'],
#  ['game', 'jual', 'ayig'],
#  ['toko', 'handal'],
#  ['tolong',
#   'bantu',
#   'foto',
#   'jual',
#   'ratus',
#   'muncul',
#   'tarik',
#   'pelang',
#   'barang',
#   'gudang',
#   'muncul',
#   'pantas',
#   'jual',
#   'terus'],
#  ['aplikasi',
#   'sihh',
#   'kmarin',
#   'apdet',
#   'isi',
#   'saldo',
#   'ribu',
#   'suruh',
#   'ngapdet',
#   'apdet',
#   'kok',
#   'uang',
#   'koin',
#   'koinya',
#   'hilang',
#   'rugi',
#   'dongg',
#   'erti'],
#  ['update',
#   'asa',
#   'gratis',
#   'ongkir',
#   'update',
#   'layar',
#   'putih',
#   'gambar',
#   'gapernah',
#   'gratis',
#   'ongkir',
#   'cod',
#   'why'],
#  ['tipu',
#   'promo',
#   'flash',
#   'sale',
#   'ken',
#   'hapus',
#   'aplikasi',
#   'standby',
#   'sblm',
#   'pkl',
#   'pesan',
#   'stock',
#   'habis',
#   'terang',
#   'jual',
#   'stock',
#   'kosong',
#   'jam',
#   'saran',
#   'klu',
#   'masih',
#   'banyak',
#   'tipu',
#   'promo',
#   'sesuai'],
#  ['update',
#   'bayar',
#   'chat',
#   'customer service',
#   'hang',
#   'restart',
#   'aplikasi'],
#  ['berat',
#   'aplikasi',
#   'respon',
#   'pencet',
#   'berat',
#   'beda',
#   'ringan',
#   'smooth'],
#  ['ongkir',
#   'mahal',
#   'brooo',
#   'hadeuh',
#   'hadeuh',
#   'ganti',
#   'opsi',
#   'kurir',
#   'harga',
#   'up',
#   'up',
#   'mahal',
#   'customer service',
#   'bot',
#   'mlu',
#   'jwbannya',
#   'ktnya',
#   'unicorn',
#   'customer service',
#   'bot'],
#  ['virus', 'iklan', 'handphone', 'eror'],
#  ['aplikasi',
#   'bela',
#   'seller',
#   'beli',
#   'please',
#   'be',
#   'careful',
#   'skripsi',
#   'sesat',
#   'seller',
#   'utama',
#   'dropship',
#   'seller',
#   'modal'],
#  ['chekout',
#   'pin',
#   'salah',
#   'pdhl',
#   'benar',
#   'sampai',
#   'blokir',
#   'tolong',
#   'gimanain'],
#  ['haraga', 'barang', 'beli'],
#  ['toko', 'tanggung', 'kirim', 'barang', 'sesuai', 'pesan', 'barang'],
#  ['kemarin',
#   'aktif',
#   'kredit',
#   'isi',
#   'data',
#   'data',
#   'hapus',
#   'nama',
#   'tika',
#   'aprilia',
#   'triyanto',
#   'kredit',
#   'handphone',
#   'counter',
#   'bantu',
#   'hapus',
#   'data'],
#  ['tipu', 'barang', 'sesuai', 'tokony', 'bawa', 'rezeky', 'usaha', 'tipu'],
#  ['beli', 'pulsa', 'refund', 'melulu', 'anjimmm', 'kaya'],
#  ['unduh', 'tunggu', 'hati', 'riang', 'gembira', 'tbtb', 'gagal'],
#  ['aplikasi', 'jelekk', 'login', 'pke', 'verifikasi', 'wajah', 'upgrade'],
#  ['aplikasi',
#   'hancur',
#   'ran',
#   'ribet',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'dasar'],
#  ['verrsi',
#   'android',
#   'hambat',
#   'tunanetra',
#   'menu',
#   'food',
#   'akses',
#   'searching',
#   'lokasi',
#   'resto',
#   'menu',
#   'keranjang',
#   'tulis',
#   'salah',
#   'tindak'],
#  ['lindung',
#   'garansi',
#   'bintang',
#   'bicara',
#   'tim',
#   'jual',
#   'jual',
#   'amanah',
#   'jual',
#   'jujur',
#   'tim',
#   'bantuin',
#   'keluh',
#   'mbelinya'],
#  ['jasa', 'kirim', 'sedia'],
#  ['scar', 'tri'],
#  ['engga',
#   'up',
#   'logika',
#   'up',
#   'akun',
#   'ngendap',
#   'bank',
#   'konvensional',
#   'tranfer',
#   'ganggu',
#   'jam',
#   'kelas',
#   'bank',
#   'aplikasi',
#   'urus',
#   'up',
#   'engga',
#   'tunggu'],
#  ['kasih', 'bintang', 'pakek', 'amplikasi', 'iklan', 'muncul', 'handphone'],
#  ['baru',
#   'pakai',
#   'order',
#   'ngecewain',
#   'batal',
#   'jasa',
#   'kirim',
#   'baru',
#   'tahu',
#   'js',
#   'pgriman',
#   'batal',
#   'kirim',
#   'jam',
#   'bareng',
#   'kirim',
#   'alamat',
#   'jm',
#   'sore',
#   'untuk',
#   'siapkn',
#   'uang',
#   'sstm',
#   'bayar',
#   'ttpi',
#   'jm',
#   'mlm',
#   'pmbritahuan',
#   'bareng',
#   'gagal',
#   'kirim',
#   'curiga',
#   'psnan',
#   'mysteri',
#   'box',
#   'nominal',
#   'paham',
#   'kan',
#   'kcurigaan',
#   'aneh',
#   'jsa',
#   'pgirimannya',
#   'sam',
#   'lx',
#   'tlglah',
#   'lbh',
#   'selektif',
#   'dlm',
#   'pilih',
#   'jasa',
#   'kirim',
#   'amatir',
#   'model',
#   'gtu'],
#  ['cod', 'toko', 'tipu', 'hadeeeee'],
#  ['unduh', 'lagu'],
#  ['aplikasi',
#   'browsing',
#   'tonton',
#   'drakor',
#   'ehh',
#   'suruh',
#   'unduh',
#   'aplikasi',
#   'aplikasi'],
#  ['iklan', 'anjim'],
#  ['aplikasi', 'tipu'],
#  ['semerawut',
#   'sen',
#   'bareng',
#   'tunggu',
#   'dibatalin',
#   'lagi',
#   'sellernya',
#   'kapok',
#   'blja',
#   'dsni',
#   'beli',
#   'sepele',
#   'uninstall',
#   'az',
#   'puzink'],
#  ['beli',
#   'platihan',
#   'status',
#   'transaksi',
#   'batal',
#   'status',
#   'platihan',
#   'aktif',
#   'terima',
#   'voucher',
#   'pltihan',
#   'beli',
#   'hambat',
#   'beli',
#   'platihan',
#   'aktif',
#   'email',
#   'pusat',
#   'bantu',
#   'refand',
#   'ribet',
#   'hambat',
#   'karir'],
#  ['aplikasi',
#   'cekout',
#   'rupiah',
#   'pas',
#   'cek',
#   'out',
#   'batal',
#   'coba',
#   'ganti',
#   'nomer',
#   'batal',
#   'donlut',
#   'aplikasi',
#   'males',
#   'php',
#   'kaya',
#   'toko',
#   'pilih',
#   'barang',
#   'rupiah',
#   'batal'],
#  ['anteraja', 'dipake', 'laaah', 'bikin', 'layan'],
#  ['promo',
#   'pakai',
#   'coin',
#   'dahh',
#   'benar',
#   'promo',
#   'potong',
#   'ongkir',
#   'pakai',
#   'pakai',
#   'point',
#   'evektif'],
#  ['susah',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'online',
#   'tarik',
#   'murah',
#   'ongkir'],
#  ['pakai', 'trsnsaksi'],
#  ['kirim', 'kuno', 'instan'],
#  ['update', 'mennggapi'],
#  ['bintang',
#   'rena',
#   'install',
#   'ulang',
#   'sampai',
#   'akun',
#   'hapus',
#   'pindah',
#   'pakai',
#   'aplikasi',
#   'ribet'],
#  ['akun',
#   'shoppe',
#   'login',
#   'costumer',
#   'service',
#   'tolong',
#   'bantu',
#   'bayar',
#   'shoppepaylatter'],
#  ['aowkwowkwok', 'aplikasi', 'mandang', 'handphone'],
#  ['aneh', 'pesan', 'barang', 'nama', 'kirim'],
#  ['ganggu', 'link', 'unduh'],
#  ['tipu',
#   'toko',
#   'nakal',
#   'kirim',
#   'barang',
#   'cod',
#   'pesan',
#   'barang',
#   'filter',
#   'tipu'],
#  ['aplikasi', 'prank', 'konten'],
#  ['barang',
#   'dikirm',
#   'nggk',
#   'sesuai',
#   'mau',
#   'barang',
#   'proses',
#   'ribet',
#   'banding',
#   'toko',
#   'online',
#   'belah',
#   'nggk',
#   'kaya',
#   'gin'],
#  ['iklan', 'mental', 'play', 'toko'],
#  ['sampai',
#   'sertifikat',
#   'bom',
#   'muncul',
#   'dasbor',
#   'prakerjaaaaaaaa',
#   'tolong',
#   'cepat'],
#  ['sore',
#   'aplikasi',
#   'burik',
#   'loading',
#   'gagal',
#   'muat',
#   'pdahal',
#   'jaringal'],
#  ['bikin', 'promo', 'diskon', 'gilir', 'dipake', 'anggap', 'menyalaho'],
#  ['aplikasi', 'sen', 'paket', 'hancur', 'kirim', 'hancurrrrrrr'],
#  ['pilih', 'jasa', 'kirim', 'sinyal'],
#  ['aneh', 'dh', 'diupdate', 'ttp', 'ilangin', 'ganggu'],
#  ['bisa', 'downlod'],
#  ['woyy',
#   'bangke',
#   'cari',
#   'lot',
#   'bangkee',
#   'update',
#   'aplikasi',
#   'sinyal',
#   'tahi',
#   'laah'],
#  ['ngadain',
#   'cashback',
#   'cashback',
#   'jarang',
#   'aplikasi',
#   'tembah',
#   'lot',
#   'mitra',
#   'curang',
#   'males',
#   'beli',
#   'belanja',
#   'pakai',
#   'pindah',
#   'toko'],
#  ['tolong', 'tolong', 'up', 'snack', 'vidio', 'uang'],
#  ['kecewaaa',
#   'bangett',
#   'sntadar',
#   'ekpress',
#   'kirim',
#   'bangett',
#   'banding',
#   'kirim',
#   'reguler',
#   'lai',
#   'lebih baik',
#   'ituu',
#   'hedhhh'],
#  ['live', 'chat', 'susah'],
#  ['tolong', 'bantu', 'saldo', 'hubung', 'dana'],
#  ['ribet',
#   'dipake',
#   'lockout',
#   'verivikasi',
#   'belibet',
#   'muter',
#   'auto',
#   'un',
#   'install',
#   'ao',
#   'gin'],
#  ['aplikasi',
#   'pngiriman',
#   'bnyak',
#   'pnjual',
#   'jelassss',
#   'paket',
#   'dateng',
#   'lgsung',
#   'uinstal',
#   'bkal',
#   'dowlnd',
#   'lh'],
#  ['aplikasi',
#   'tipu',
#   'sen',
#   'box',
#   'dateng',
#   'cincin',
#   'harga',
#   'ribu',
#   'pantau',
#   'toko',
#   'toko',
#   'amanah',
#   'korban',
#   'aplikasi'],
#  ['baca',
#   'editor',
#   'notice',
#   'kasih',
#   'bintang',
#   'cuman',
#   'saran',
#   'letak',
#   'gambar',
#   'produk',
#   'sejajar',
#   'judul',
#   'produk',
#   'tulis',
#   'kecilin',
#   'mudah',
#   'gambar',
#   'contolah',
#   'akun',
#   'shope',
#   'belah',
#   'gambar',
#   'iklan',
#   'nyaingin',
#   'toko',
#   'belah',
#   'fitur',
#   'tampil',
#   'tarik',
#   'toko',
#   'belah',
#   'notice',
#   'baca'],
#  ['kurir',
#   'alamat',
#   'tera',
#   'cantum',
#   'terima',
#   'nama',
#   'orang',
#   'belanja',
#   'setelah',
#   'komplain',
#   'tuntas',
#   'tutup',
#   'beli',
#   'rugi',
#   'barang',
#   'hilang'],
#  ['sayang',
#   'pesan',
#   'rupiah',
#   'beli',
#   'eror',
#   'bilang',
#   'pesan',
#   'sdngkan',
#   'dengn',
#   'bareng',
#   'kecewaa'],
#  ['gratis', 'ongkir', 'kya'],
#  ['tulis', 'kolom', 'cari', 'eror'],
#  ['tolong',
#   'benah',
#   'kurir',
#   'shoope',
#   'express',
#   'pesan',
#   'hold',
#   'jarak',
#   'kirim',
#   'lokasi',
#   'kirim'],
#  ['chat', 'eror', 'connect', 'jaring'],
#  ['mengisi', 'shopay', 'saldo', 'atm', 'duit'],
#  ['verivikasi', 'bikin', 'ribet'],
#  ['dear',
#   'mimin',
#   'kendala',
#   'checkout',
#   'checkout',
#   'pesan',
#   'checkout',
#   'gagal',
#   'risih',
#   'pesan',
#   'pesan',
#   'otomatis',
#   'checkout',
#   'pesan',
#   'harga',
#   'barang',
#   'beli',
#   'sesuai',
#   'voucher',
#   'voucher',
#   'tolong',
#   'mimin',
#   'mudah',
#   'checkout',
#   'tolong',
#   'checkout',
#   'gagal'],
#  ['belanja', 'kli', 'isi', 'pakrtnya', 'bodoh'],
#  ['iklan', 'spam', 'google', 'nonton', 'film', 'skip', 'heran'],
#  ['belanja',
#   'bayar',
#   'alfa',
#   'indomaret',
#   'barang',
#   'cod',
#   'malas',
#   'pakai',
#   'aplikasi',
#   'tolong',
#   'informasi'],
#  ['bintang', 'pilih', 'kurir', 'besok', 'tunggu', 'kurir', 'lamban'],
#  ['mantaaaa', 'belanja', 'tipu', 'belanja', 'pesan', 'sesuai', 'terima'],
#  ['sampah', 'selalu', 'ganggu'],
#  ['aplikasi', 'serius'],
#  ['mahal', 'ongkir', 'beli', 'kirim', 'hadehhh', 'gaze'],
#  ['commerce',
#   'gajelas',
#   'pakai',
#   'voucher',
#   'promo',
#   'dipake',
#   'pas',
#   'dipake',
#   'transaksi',
#   'batal',
#   'otomatis',
#   'transaksi',
#   'akun',
#   'tahu',
#   'akun',
#   'bertanya',
#   'costumer',
#   'service',
#   'kasih',
#   'solusi'],
#  ['aplikasi',
#   'aman',
#   'hubung',
#   'akun',
#   'informasi',
#   'kartu',
#   'kredit',
#   'link',
#   'fintech',
#   'otp',
#   'login',
#   'perangkat',
#   'pin',
#   'transaksi',
#   'fintech',
#   'retas',
#   'alami',
#   'sendir',
#   'akun',
#   'retas',
#   'topup',
#   'money',
#   'koneksi',
#   'akun',
#   'bertanggungjawab',
#   'rubah',
#   'pin',
#   'password',
#   'rutin',
#   'hubung',
#   'bayar'],
#  ['donlod', 'chekout', 'aneh'],
#  ['pliss',
#   'data',
#   'cur',
#   'ganti',
#   'rugi',
#   'jt',
#   'lapor',
#   'shoppe',
#   'polisi',
#   'titik'],
#  ['benar',
#   'order',
#   'proses',
#   'kirim',
#   'kasih',
#   'toleransi',
#   'jual',
#   'kirim',
#   'recommended',
#   'order',
#   'kuciwa'],
#  ['bayar', 'cok'],
#  ['aduhh',
#   'maaf',
#   'isi',
#   'alamat',
#   'kecamatan',
#   'kota',
#   'salah',
#   'pdhal',
#   'ulang',
#   'ulang'],
#  ['menu',
#   'utama',
#   'mesti',
#   'pencet',
#   'salah',
#   'gimna',
#   'sen',
#   'haduh',
#   'makane',
#   'sebel',
#   'pakai',
#   'shoopee',
#   'gin',
#   'tolong',
#   'bantu',
#   'dibenerin',
#   'gimna'],
#  ['barang', 'bnyak', 'sesuai', 'kirim'],
#  ['gimn', 'belanja', 'sistem', 'cod'],
#  ['toko', 'tipu', 'tolong', 'banned', 'toko', 'tipu', 'periksa', 'lagiiiii'],
#  ['daftar', 'akun', 'sulit', 'mnding', 'toko', 'belah'],
#  ['tolong',
#   'aplikasi',
#   'beli',
#   'kouta',
#   'aplikasi',
#   'tapi',
#   'buka',
#   'ny',
#   'aplikasi'],
#  ['pakai', 'pakai', 'voucher'],
#  ['bayar', 'link', 'enggk'],
#  ['daftar', 'ngabis', 'kuota'],
#  ['aplikasi', 'lot'],
#  ['pesan', 'sini', 'pesn', 'sini', 'barang', 'proses', 'bayar', 'hadeeeeee'],
#  ['suruh',
#   'kritik',
#   'keritik',
#   'ber',
#   'diam',
#   'ubah',
#   'kirim',
#   'lempar',
#   'xpres',
#   'lot',
#   'sap',
#   'expres',
#   'bangke',
#   'benar',
#   'kirim',
#   'area',
#   'jawa',
#   'makan',
#   'full'],
#  ['buka', 'gambar', 'ampas'],
#  ['maaf',
#   'masak',
#   'muncul',
#   'detik',
#   'muncul',
#   'detik',
#   'muncul',
#   'tolong',
#   'menit',
#   'seperti',
#   'menit',
#   'tibul',
#   'timbul',
#   'jengkel',
#   'cek',
#   'maaf',
#   'hoak'],
#  ['tolong',
#   'iklan',
#   'menggangu',
#   'nyaman',
#   'jelajah',
#   'internet',
#   'hapus',
#   'aplikasi',
#   'ganggu'],
#  ['unduh', 'aplikasi', 'tipu'],
#  ['beri',
#   'rating',
#   'tanggung',
#   'dsb',
#   'kerjain',
#   'nyuruh',
#   'hubung',
#   'hubung',
#   'puter',
#   'puter',
#   'lagi',
#   'orang',
#   'beri',
#   'kritik',
#   'ketidakpuasan',
#   'cepat',
#   'tanganin',
#   'nyuruh',
#   'hubung',
#   'gambar',
#   'tampil',
#   'pending',
#   'bingung',
#   'internet',
#   'pasang',
#   'gb',
#   'handphone',
#   'redmi',
#   'note',
#   'apalalagi',
#   'salah'],
#  ['install', 'aplikasi', 'hadiah', 'jangan', 'bohong', 'aje'],
#  ['tawarin',
#   'rupiah',
#   'pas',
#   'cek',
#   'tetep',
#   'beli',
#   'mahal',
#   'aplikasi',
#   'shopy'],
#  ['terlambat',
#   'bayar',
#   'shopeepaylater',
#   'tlponin',
#   'puluh',
#   'kayak',
#   'hutang',
#   'puluh',
#   'juta',
#   'ngk',
#   'bayar',
#   'bom',
#   'gaji',
#   'gaji',
#   'undur',
#   'nelponin',
#   'ngk',
#   'paut',
#   'tunggak',
#   'bayar',
#   'kasi',
#   'teman',
#   'diganguin',
#   'melulu',
#   'kayak',
#   'teror',
#   'ganggu',
#   'tolong',
#   'baca',
#   'tolong',
#   'erti'],
#  ['tari',
#   'saldo',
#   'even',
#   'bayar',
#   'kumpulun',
#   'kawan',
#   'susah',
#   'tolong',
#   'ikan'],
#  ['cod', 'cash', 'or', 'duel'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (5, 6):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha='asymmetric', eta='symmetric')
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# 5 -7.573519581800564 0.356606933774381
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(0, 0.4442735), (1, 0.076661736), (2, 0.05856434), (3, 0.047379542), (4, 0.3731209)]
# [(0, 0.3331725), (1, 0.057496417), (2, 0.2939385), (3, 0.28555617), (4, 0.029836413)]
# [(0, 0.042291224), (1, 0.5024824), (2, 0.21552865), (3, 0.017767353), (4, 0.22193041)]
# [(0, 0.18042065), (1, 0.7647614), (2, 0.022132419), (3, 0.01776733), (4, 0.014918204)]
# [(0, 0.041604817), (1, 0.15371215), (2, 0.39697838), (3, 0.14277314), (4, 0.26493153)]
# [(0, 0.77761257), (1, 0.076661706), (2, 0.058564324), (3, 0.047379535), (4, 0.039781872)]
# [(0, 0.27810237), (1, 0.27026072), (2, 0.09802843), (3, 0.095243804), (4, 0.25836468)]
# [(0, 0.083209395), (1, 0.8074963), (2, 0.043923248), (3, 0.035534654), (4, 0.029836407)]
# [(0, 0.7763789), (1, 0.07666193), (2, 0.059797708), (3, 0.047379572), (4, 0.039781887)]
# [(0, 0.2665686), (1, 0.6459959), (2, 0.035138607), (3, 0.028427726), (4, 0.023869127)]
# [(0, 0.11094588), (1, 0.7433284), (2, 0.058564335), (3, 0.047379542), (4, 0.03978188)]
# [(0, 0.33317906), (1, 0.30748808), (2, 0.2939295), (3, 0.03553466), (4, 0.029868696)]
# [(0, 0.8332094), (1, 0.057496283), (2, 0.04392325), (3, 0.035534658), (4, 0.029836409)]
# [(0, 0
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#         Document_No  ...                                               Text
# 0                 0  ...                                [iklan, ganggu, as]
# 1                 1  ...                       [tolong, erti, pesan, pesan]
# 2                 2  ...                       [iklan, trossssssss, ganggu]
# 3                 3  ...  [ruwet, metode, bayar, indomart, mlh, cod, apl...
# 4                 4  ...  [dih, dwon, aplikasi, tipu, order, giveaway, h...
# ...             ...  ...                                                ...
# 780791       780791  ...  [belanja, shoppe, bantu, temu, barang, dng, ce...
# 780792       780792  ...  [sampai, sekarang, pakai, alhamdulilah, gapern...
# 780793       780793  ...  [enk, belanja, shopeee, tigkatkn, gratis, ongk...
# 780794       780794  ...                            [belanja, kirim, cepat]
# 780795       780795  ...                           [layan, belanja, shoope]
#
# [780796 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    331735
# 1.0    207947
# 2.0     97380
# 3.0     89615
# 4.0     54119
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500000)

plt.show()
