# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.53.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  *
FROM
  `future-data-track-1.sapporo_mart.topic_modelling`
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0                                     IKLAN NYA GANGGU AS*       1
# 1        Pihak lazada tolong di mengerti masa saya pesa...       1
# 2                            Iklan trossssssss, ganggu aja       1
# 3        Lazada Ruwet anjir. Mau menggunakan metode pem...       1
# 4        Dih jangan dwon ni aplikasi tempat para penipu...       1
# ...                                                    ...     ...
# 1695878                                    Sangat membantu       5
# 1695879                                    Sangat membantu       5
# 1695880                                    Sangat membantu       5
# 1695881                                    Sangat membantu       5
# 1695882                                    Sangat membantu       5
#
# [1695883 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"belum","cuiiihhh","bangt","selamat","begitu","bhineka","situ","loh","deh"
    ,"mah","yaa","tapi","the","karena","padabal","ttep","sopi","ealah","mas"
    ,"kampreeeeet","busetttt","tahi","ah","sich","tokped","lzd","gada","gatau"
    ,"udh","ttep","ehhh","bosss","wkekwk","bajing","laknat","asuuu","ku","woiii"
    ,"gueeee","njerr","waduhhhh","ma","dunk","dunk","untuk","dll","brupa"
    ,"sangatx","niih","bos","eh","smua","gni","bye","ajah","gilee","luu","ndro"
    ,"dg","kga","min","sm","haisshhh","piye","iki","skali","hehehe","ms","juga"
    ,"fff","mamam","inibsangat","andri","yopiyanto","broo","donk","tes","si"
    ,"ter","dech","wow","oh","toped","dahhhh","grab","ijo","oren","ovo","gopay"
    ,"kredivo","sok","david","gaes","dr","ovonya","bbrp","gmna","bbrpa","and"
    ,"uah","uhahhhhhh","topeeed","ngak","kamu","anj","nge","lah","linkaja"
    ,"gosend","sicepat","jne","yah","goto","gofood","goride","prakerja"
    ,"haduhhhh","pediya","kakak","hhe","bro","bismillah","fuulll","goof"
    ,"assalamualaikum","atsu","pea","you","agan","semenjak","gojek","lagiii"
    ,"lagi","bts","kkzara","cog","aaaaa","sich","cih","ciyy","padahal","ad"
    ,"adlh","ahaha","aj","ak","akika","akkoh","akuwh","alow","anjrit","ap2"
    ,"apasih","aps","aq","aqueh","q","asem","ato","awak","bakalan","bangedh"
    ,"bcanda","beud","bg","bgmn","bgt","bkl","bknnya","blum","boljug","boyeh"
    ,"bs","bt","btw","bwt","byk","can","thanks","d","dah","dapet","de","dek"
    ,"deyh","dgn","disono","dkk","dlu","dngn","dongs","dpt","dri","drmn","drtd"
    ,"dst","duh","egp","eke","ane","ente","elu","emangnya","emng","endak"
    ,"enggak","gaada","gag","gaje","gpp","gan","gbs","geje","ghiy","gimana"
    ,"githu","gj","gn","gt","gpny","gr","gtau","guoblok","ha","haha","hallow"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review'].values]]

# %%
df_token.dropna(subset = ["review"], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_token
# Out:
#                                                     review  rating
# 0                                          iklan ganggu as       1
# 1                                  tolong erti pesan pesan       1
# 2                                 iklan trossssssss ganggu       1
# 3        ruwet metode bayar indomart mlh cod aplikasi v...       1
# 4        dih dwon aplikasi tipu order giveaway hp perca...       1
# ...                                                    ...     ...
# 1475049  belanja shoppe bantu temu barang dng cepat har...       5
# 1475050    sampe skrg pake alhamdulilah gapernah ngecewain       5
# 1475052     enk blanja shopeee tigkatkn gratis ongkir psan       5
# 1475053                                  belanja kirim cpt       5
# 1475055                               layan belanja shoope       5
#
# [780796 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['iklan', 'ganggu', 'as'],
#  ['tolong', 'erti', 'pesan', 'pesan'],
#  ['iklan', 'trossssssss', 'ganggu'],
#  ['ruwet', 'metode', 'bayar', 'indomart', 'mlh', 'cod', 'aplikasi', 'voucher'],
#  ['dih',
#   'dwon',
#   'aplikasi',
#   'tipu',
#   'order',
#   'giveaway',
#   'handphone',
#   'percaya',
#   'dateng',
#   'kawat',
#   'bayar',
#   'ribu',
#   'masak',
#   'kasi',
#   'kawat',
#   'untung',
#   'gin',
#   'tipu',
#   'bgettt',
#   'yaaa',
#   'gesss',
#   'aman',
#   'percaya',
#   'tukang',
#   'tipu',
#   'kaya',
#   'hapus',
#   'lgsung',
#   'aplikasi'],
#  ['cashbacknya', 'dapetnya', 'kirim', 'dikit', 'serius', 'bikin', 'promo'],
#  ['bnrn',
#   'sya',
#   'menang',
#   'untung',
#   'undi',
#   'handphone',
#   'ip',
#   'kirim',
#   'alamat',
#   'tinggal',
#   'sya',
#   'kp',
#   'rawahingkik',
#   'rt',
#   'rw',
#   'cileungsi',
#   'bogor',
#   'ichat'],
#  ['keluh', 'langgan', 'tanggung'],
#  ['pocer', 'tapi', 'ngk'],
#  ['ui', 'ribet'],
#  ['aplikasi', 'pesan', 'barang', 'bayar', 'barang', 'pesan', 'nyampe'],
#  ['keluan',
#   'setelah',
#   'bc',
#   'komntr',
#   'apa',
#   'banyak',
#   'penipuny',
#   'pelyananya'],
#  ['transaksi', 'tranfer', 'uang'],
#  ['cok', 'asyifa'],
#  ['ampuh', 'sehat', 'aman', 'damai'],
#  ['males', 'belanja', 'shope', 'lebih baik', 'toko', 'belah'],
#  ['maf',
#   'aplikasi',
#   'sayah',
#   'terimna',
#   'hadiah',
#   'puter',
#   'katnya',
#   'hadiah',
#   'uang',
#   'tapi',
#   'bacan',
#   'ambil',
#   'uang',
#   'sama',
#   'hadia',
#   'sayah',
#   'terimna',
#   'aplikasi',
#   'nga',
#   'bisin',
#   'kuota',
#   'bantu',
#   'jawap',
#   'kenah',
#   'ambil'],
#  ['beli', 'barang', 'sesuai', 'boykot'],
#  ['tolong', 'cepat'],
#  ['membaii', 'layanan'],
#  ['ban', 'ban', 'bekas'],
#  ['toko', 'beli', 'gantung', 'tas', 'nggkak', 'kirim', 'kirim'],
#  ['cod', 'transfer', 'proses', 'bikin', 'ribet'],
#  ['rupiah', 'ongkir', 'bayar'],
#  ['gratis',
#   'ongkir',
#   'promo',
#   'cashback',
#   'juga',
#   'hilang',
#   'pindah',
#   'aplikasi',
#   'nihh'],
#  ['kode',
#   'verifikasi',
#   'otp',
#   'sulit',
#   'verifikasi',
#   'whatsapp',
#   'nomer',
#   'via',
#   'telepon',
#   'nyampe',
#   'gin',
#   'bikin',
#   'sulit',
#   'daftar',
#   'shoppe',
#   'bayar',
#   'maaf',
#   'lanjur',
#   'harap',
#   'sistem',
#   'verifikasi',
#   'kode',
#   'otp',
#   'ribet',
#   'cuman',
#   'ganti',
#   'pasword',
#   'simple',
#   'maju',
#   'kayak',
#   'gin'],
#  ['belanja',
#   'barang',
#   'dateng',
#   'lapor',
#   'terima',
#   'kirim',
#   'alhasil',
#   'bolak',
#   'ekspedisi',
#   'plus',
#   'debat',
#   'jual',
#   'uang',
#   'hilang',
#   'barang',
#   'nyampe',
#   'jujur',
#   'ekspedisi',
#   'expres'],
#  ['akun',
#   'nonaktif',
#   'order',
#   'bayar',
#   'shopeepay',
#   'nonaktif',
#   'jlskan',
#   'salah'],
#  ['proses',
#   'rim',
#   'padhal',
#   'update',
#   'tepaksa',
#   'batal',
#   'prises',
#   'kirim',
#   'tolong',
#   'dibantuh'],
#  ['paylater', 'beku', 'limit', 'terlambat', 'bayar', 'solusi'],
#  ['aplikasi',
#   'ndk',
#   'masak',
#   'beli',
#   'speaker',
#   'gantung',
#   'kunci',
#   'tolong',
#   'kasih',
#   'tok',
#   'bossku',
#   'aplikasi',
#   'rusak',
#   'serius'],
#  ['terkadang', 'dilazada', 'barang', 'sesuai'],
#  ['tukang',
#   'tipu',
#   'aplikasi',
#   'kawan',
#   'kawan',
#   'jngan',
#   'unduh',
#   'aplikasi',
#   'modus',
#   'tipu',
#   'iming',
#   'iming',
#   'hadiah',
#   'lebih baik',
#   'unduh',
#   'bonus'],
#  ['dtipu',
#   'muncul',
#   'pembritahuan',
#   'memdapat',
#   'hadiah',
#   'cmn',
#   'suruh',
#   'install',
#   'aplikasi',
#   'tempek'],
#  ['error', 'yaaaaaaa'],
#  ['iklan', 'akeh', 'cok'],
#  ['idexpress', 'hapus', 'paket', 'regelur', 'sampai'],
#  ['unduh', 'bantu'],
#  ['susah', 'memasukkn', 'otp', 'kirim'],
#  ['ngk', 'aplikasi'],
#  ['install', 'anjenk'],
#  ['emosi',
#   'internet',
#   'aplikasi',
#   'buka',
#   'lancar',
#   'pas',
#   'buka',
#   'shope',
#   'ketik',
#   'cari',
#   'pencet',
#   'enter',
#   'emosi',
#   'jam',
#   'seperti',
#   'besok',
#   'seperti',
#   'loading',
#   'pas',
#   'loading',
#   'produk',
#   'temu',
#   'tahu',
#   'barang',
#   'cari',
#   'iseng',
#   'sia',
#   'sia',
#   'tunggu'],
#  ['saldo',
#   'blokir',
#   'tolong',
#   'customer',
#   'care',
#   'aktifin',
#   'saldo',
#   'terima',
#   'kasih'],
#  ['jangan',
#   'belanja',
#   'tipu',
#   'pesan',
#   'kirim',
#   'pakai',
#   'metode',
#   'bayar',
#   'cod',
#   'kurir',
#   'bilang',
#   'bayar',
#   'jual',
#   'prnah',
#   'beli',
#   'bareng',
#   'sesuai',
#   'pas',
#   'cod',
#   'buka',
#   'dpn',
#   'kurir',
#   'kurir',
#   'sendiri',
#   'inisiatif',
#   'bilang',
#   'jual',
#   'basa',
#   'basi',
#   'rugi',
#   'tipu',
#   'berkah',
#   'makan',
#   'tu',
#   'duit',
#   'haram',
#   'ikhlas',
#   'dunia',
#   'akhirat'],
#  ['pesan',
#   'balik',
#   'gudang',
#   'lagi',
#   'kurir',
#   'wilayah',
#   'kirim',
#   'suruh',
#   'tunggu',
#   'lagi',
#   'sesuai',
#   'wilayah',
#   'kirim'],
#  ['iklanya', 'lindung', 'handphone', 'mu', 'viruz', 'pas', 'pencet', 'malak'],
#  ['tipu', 'tolong', 'pantau', 'jual', 'tipu', 'tolak'],
#  ['aplikasi',
#   'taiii',
#   'mesen',
#   'sampai',
#   'pas',
#   'sampai',
#   'barang',
#   'sampai',
#   'cancel',
#   'costumer'],
#  ['loading', 'berat', 'susahhhh'],
#  ['njirrr', 'selancar', 'alih', 'ksini', 'vanke'],
#  ['pesan',
#   'photocard',
#   'taehyung',
#   'eror',
#   'ulang',
#   'pas',
#   'checkout',
#   'notif',
#   'barang',
#   'saldo',
#   'potong',
#   'tolong',
#   'jngn',
#   'sperti'],
#  ['aplikasi', 'iklan', 'ngotak', 'mentang', 'duit', 'bikin', 'iklan'],
#  ['sebal',
#   'kesini',
#   'akun',
#   'apain',
#   'gagal',
#   'checkout',
#   'alas',
#   'curiga',
#   'janggal',
#   'ngeselin',
#   'pakai',
#   'shopeepay',
#   'gilir',
#   'pakai',
#   'bayar',
#   'gratis',
#   'ongkir',
#   'cashback',
#   'dipake',
#   'shopeepay',
#   'tolong',
#   'bikin',
#   'ribet'],
#  ['milih',
#   'jasa',
#   'ekspedisi',
#   'monopoli',
#   'express',
#   'cepat',
#   'sukur',
#   'paket',
#   'kirim',
#   'jakarta',
#   'estimasi',
#   'terima',
#   'oktober',
#   'karawang',
#   'alih',
#   'toko'],
#  ['iklan', 'muncul', 'konttttttoooooooollllllllllll'],
#  ['kesel',
#   'update',
#   'diupdate',
#   'februari',
#   'besok',
#   'update',
#   'event',
#   'tanggal',
#   'februari',
#   'berat',
#   'handphone',
#   'handphone',
#   'kentang',
#   'ngebul',
#   'kuat',
#   'pakai',
#   'aplikasi',
#   'proses',
#   'belanja',
#   'gampang'],
#  ['pelit', 'ongkir', 'belanja', 'aplikasi', 'sedih', 'epribadi'],
#  ['iklan', 'muncul', 'ng'],
#  ['beli',
#   'sadar',
#   'barang',
#   'beli',
#   'beda',
#   'berat',
#   'lapak',
#   'tulis',
#   'berat',
#   'berat',
#   'sesunguhnya',
#   'berat',
#   'kg',
#   'lapak',
#   'tulis',
#   'kg',
#   'bayar',
#   'kg',
#   'kg',
#   'beli',
#   'ambil',
#   'lapak',
#   'bonus',
#   'beli',
#   'beli',
#   'cari',
#   'berat',
#   'barang',
#   'wajar',
#   'berat',
#   'sesuai',
#   'beda',
#   'kg',
#   'wajar',
#   'beda',
#   'kg',
#   'ajar'],
#  ['aplokasi', 'ribet', 'mau', 'jual', 'susah'],
#  ['member', 'platinum', 'shopepay', 'later', 'aktif', 'payahhh'],
#  ['spaylater',
#   'mesti',
#   'verifikasi',
#   'wajah',
#   'gagal',
#   'bayar',
#   'cicil',
#   'cicil',
#   'pakek',
#   'spaylater',
#   'malas',
#   'atm',
#   'sistem',
#   'bayar',
#   'sms',
#   'banking',
#   'kendala',
#   'malas',
#   'belanja',
#   'dishopee'],
#  ['seperti', 'ngk'],
#  ['ngapain', 'nongol', 'melulu', 'iklan', 'aplikasi', 'ganggu'],
#  ['unduh', 'update', 'hahaha', 'untung'],
#  ['hapus',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'hapus',
#   'bantu'],
#  ['sistem', 'beli', 'pulsa', 'uang', 'cepat', 'bangkrut', 'amin'],
#  ['dindownliad', 'hapus'],
#  ['isi',
#   'saldo',
#   'shoopepay',
#   'pas',
#   'klik',
#   'bank',
#   'virtual',
#   'account',
#   'blank',
#   'layar',
#   'handphone',
#   'putih',
#   'refresh',
#   'tetep',
#   'adehhhh',
#   'transaksi',
#   'njengggg'],
#  ['olshop',
#   'hancur',
#   'jasa',
#   'ekpedisi',
#   'kurir',
#   'amanh',
#   'smoga',
#   'benah',
#   'olshop',
#   'bagaimna',
#   'prioritas',
#   'customer'],
#  ['beli',
#   'handphone',
#   'barang',
#   'sesuai',
#   'retur',
#   'handphone',
#   'terima',
#   'jual',
#   'uang',
#   'bantu',
#   'admin'],
#  ['toko', 'bnyak', 'tipu'],
#  ['aplikasi',
#   'tipu',
#   'program',
#   'promo',
#   'cashback',
#   'bodoh',
#   'rugi',
#   'nyesal',
#   'pokok'],
#  ['amanah',
#   'bayar',
#   'dibatalin',
#   'sistem',
#   'dana',
#   'dikembaliin',
#   'juga',
#   'belanja',
#   'tolong',
#   'cari',
#   'uang',
#   'susah',
#   'fikembalikan',
#   'cepat'],
#  ['sapi',
#   'lajanda',
#   'ribet',
#   'akun',
#   'cuman',
#   'handphone',
#   'ttp',
#   'batal',
#   'sistem',
#   'busul'],
#  ['shoope', 'pesan', 'dibatalin', 'tampa', 'konfirmasi'],
#  ['aplikasi', 'lambat', 'unduh'],
#  ['cari', 'tahu', 'tahu'],
#  ['kurir',
#   'buka',
#   'expres',
#   'mahal',
#   'beda',
#   'kurir',
#   'ribu',
#   'pakai',
#   'buka',
#   'expres',
#   'ribu',
#   'pakai',
#   'voucher',
#   'no',
#   'ongkir',
#   'tetep',
#   'biaya',
#   'ongkir'],
#  ['tanam',
#   'blank',
#   'eror',
#   'update',
#   'cache',
#   'uninstall',
#   'install',
#   'begtu'],
#  ['proses',
#   'bayar',
#   'btl',
#   'seller',
#   'tolong',
#   'bayar',
#   'cepat',
#   'cod',
#   'tindak',
#   'lh',
#   'mksh'],
#  ['toko',
#   'jual',
#   'barang',
#   'sesuai',
#   'klik',
#   'pesan',
#   'bantu',
#   'solusi',
#   'tertawa'],
#  ['daftar', 'susah'],
#  ['belanja', 'barang', 'batal', 'otomatis', 'terssss', 'kezeellllll'],
#  ['susah',
#   'cari',
#   'barang',
#   'isi',
#   'lapak',
#   'barang',
#   'pasang',
#   'harga',
#   'perut',
#   'efek',
#   'gampang',
#   'bikin',
#   'lapak',
#   'bahan',
#   'timbang',
#   'bikin',
#   'betah',
#   'buyer'],
#  ['shopeepay', 'later', 'jngan', 'bayar', 'sllu'],
#  ['ganggu', 'jual', 'murah', 'iklaaaan', 'terusss', 'kamorer'],
#  ['loginnya', 'login', 'pakai', 'no', 'telepon', 'error'],
#  ['bnyak',
#   'seller',
#   'tipu',
#   'hati',
#   'ditelfon',
#   'seller',
#   'remote',
#   'akun',
#   'shopeenya',
#   'tolong',
#   'aplikasiny',
#   'update',
#   'refund',
#   'jangan',
#   'bgitu',
#   'batal',
#   'refund',
#   'uang',
#   'tunggu',
#   'hari'],
#  ['aplikasi', 'ongkir', 'bayar'],
#  ['iklan', 'melulu'],
#  ['update', 'pas', 'update', 'error', 'komplain', 'fast', 'respon', 'solusi'],
#  ['engga',
#   'kapok',
#   'layan',
#   'super',
#   'dengar',
#   'komplain',
#   'langgan',
#   'langgan',
#   'kompalin',
#   'tetbaik',
#   'dengar',
#   'terkadang',
#   'fiturr',
#   'chat',
#   'mati',
#   'layan'],
#  ['maaf',
#   'kenape',
#   'verifikasi',
#   'sms',
#   'susah',
#   'bug',
#   'verifikasi',
#   'sms',
#   'auto',
#   'mengisi',
#   'salah',
#   'kode',
#   'kode',
#   'tulis',
#   'ulang',
#   'hapus',
#   'keyboard',
#   'ngetik',
#   'angka',
#   'bug',
#   'ganggu',
#   'asli',
#   'ampas',
#   'aplikasi',
#   'tolong',
#   'kasi',
#   'hadeh',
#   'ecommerce',
#   'indonesia',
#   'gin',
#   'ampas',
#   'hadeuh'],
#  ['barang',
#   'bilang',
#   'siap',
#   'pas',
#   'transfer',
#   'chat',
#   'balas',
#   'aplikasi',
#   'jual'],
#  ['maaf', 'toko', 'kirim', 'sesuai', 'pesan', 'ulang', 'ulang'],
#  ['iklan', 'melulu', 'aplikasi', 'droppppp'],
#  ['toko', 'tipu'],
#  ['belanja',
#   'dilazada',
#   'garansi',
#   'uang',
#   'hoaks',
#   'barang',
#   'sesuai',
#   'tahu',
#   'return',
#   'dh'],
#  ['eror', 'kode', 'io', 'buin'],
#  ['aplikasi', 'ganggu'],
#  ['livenya',
#   'rekam',
#   'diposting',
#   'minggu',
#   'baju',
#   'postingan',
#   'minggu',
#   'blackpink',
#   'ulang',
#   'please',
#   'fans',
#   'mengatasnamakan',
#   'live',
#   'blackpink'],
#  ['sring',
#   'kcewa',
#   'ditoped',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'tolak',
#   'seller',
#   'sellernya',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'bareng',
#   'nanggung',
#   'ongkir',
#   'pdhl',
#   'ksalahan',
#   'seller',
#   'bareng',
#   'bukan',
#   'ssuai',
#   'deskripsi',
#   'lagi',
#   'brgnya',
#   'palsu',
#   'kmbalikan',
#   'bareng',
#   'proses',
#   'rumit',
#   'waktu',
#   'garis',
#   'bsarnya',
#   'seller',
#   'mrugikan',
#   'scara',
#   'materi',
#   'energi',
#   'waktu',
#   'heran',
#   'tu',
#   'seller',
#   'sampai',
#   'hari',
#   'masih',
#   'bebas',
#   'jual',
#   'bareng',
#   'palsu',
#   'pdhl',
#   'bukti'],
#  ['aplikasi', 'aneh', 'search', 'produk', 'muncul'],
#  ['aplikasi',
#   'cek',
#   'pesan',
#   'gagal',
#   'antre',
#   'internet',
#   'offline',
#   'buka',
#   'lancar',
#   'sesal',
#   'dowload',
#   'aplikasi'],
#  ['tanggung',
#   'koin',
#   'pakai',
#   'koin',
#   'kemarin',
#   'tanam',
#   'koin',
#   'siram',
#   'koin',
#   'koin',
#   'tolong',
#   'gin',
#   'pakai',
#   'jujur',
#   'pakai',
#   'pokok',
#   'koin',
#   'nama',
#   'glowindo'],
#  ['maaf', 'mesen', 'powerbank', 'pas', 'powerbank', 'rusak'],
#  ['error',
#   'main',
#   'game',
#   'segercep',
#   'kemarin',
#   'promo',
#   'cashbacknya',
#   'tarik',
#   'kemarin',
#   'harga',
#   'barang',
#   'murah',
#   'aplikasi',
#   'belah',
#   'pdhl',
#   'langgan',
#   'pakai',
#   'males',
#   'belanja',
#   'seru',
#   'promo',
#   'up',
#   'shopeepay',
#   'ribu',
#   'juta',
#   'hadiah',
#   'perak',
#   'gilir',
#   'orang',
#   'up',
#   'ribu',
#   'hadiah',
#   'voucher',
#   'emas',
#   'hadeuhh',
#   'fair'],
#  ['marketplace',
#   'kaku',
#   'atur',
#   'ubah',
#   'bikin',
#   'nyaman',
#   'jual',
#   'beli',
#   'kesini',
#   'ribet',
#   'sombong',
#   'maaf',
#   'berat',
#   'uninstall',
#   'makan',
#   'tu',
#   'atur',
#   'kamu'],
#  ['cod', 'cod', 'baku', 'hantam'],
#  ['bertanya', 'dowlod', 'nii'],
#  ['agen', 'call', 'center'],
#  ['tipu', 'aplikasi', 'yes', 'do', 'najis'],
#  ['sabar', 'matket', 'place', 'ribet', 'ribet', 'percaya'],
#  ['sen', 'paket', 'kont'],
#  ['maf',
#   'dowlod',
#   'aplikasi',
#   'garagara',
#   'misi',
#   'penhasil',
#   'saldo',
#   'andai',
#   'aduh',
#   'malas',
#   'dowlod'],
#  ['unduh', 'unduh', 'hidup', 'data', 'seluler', 'unduh', 'hapus'],
#  ['aplikasi',
#   'sengaja',
#   'hapus',
#   'unduh',
#   'lagi',
#   'gagal',
#   'terus',
#   'gmn',
#   'tolong',
#   'solusi',
#   'bayar',
#   'bayar',
#   'later'],
#  ['ongkir',
#   'gede',
#   'beli',
#   'barang',
#   'diskon',
#   'ongkir',
#   'nama',
#   'ongkir',
#   'barang',
#   'lebih baik',
#   'belah'],
#  ['bela',
#   'beli',
#   'wkwk',
#   'sayang',
#   'kaya',
#   'lapak',
#   'belah',
#   'prioritas',
#   'beli',
#   'tahu',
#   'beli',
#   'raja',
#   'layan',
#   'komplain',
#   'shope',
#   'banyak',
#   'alesan',
#   'gilir',
#   'ajak',
#   'debat',
#   'skak',
#   'ehh',
#   'cht',
#   'wkwkwkkw'],
#  ['jatuh',
#   'tempo',
#   'telpon',
#   'bayar',
#   'jam',
#   'bayar',
#   'bayar',
#   'apaaa',
#   'kesini',
#   'galogis',
#   'gaaakan',
#   'pakai',
#   'gituan',
#   'ribet'],
#  ['aju', 'paylater', 'tolak', 'loyal', 'aplikasi'],
#  ['voucher', 'gratis', 'ongkir', 'dipake', 'kntl'],
#  ['bayar',
#   'tagih',
#   'suruh',
#   'tunggu',
#   'proses',
#   'dana',
#   'salah',
#   'suruh',
#   'tunggu',
#   'dana'],
#  ['saldo',
#   'dana',
#   'beku',
#   'yabg',
#   'rp',
#   'ribu',
#   'tolong',
#   'akun',
#   'lapor',
#   'polisi',
#   'tolong',
#   'kirim',
#   'pesan',
#   'eamil',
#   'stolong',
#   'cepat',
#   'uang',
#   'tarik',
#   'pas',
#   'uang',
#   'beku',
#   'pas',
#   'beku',
#   'uang',
#   'pakai',
#   'butuh',
#   'gajelas'],
#  ['kesal', 'iklan'],
#  ['emangggg', 'tooopppp', 'margotop'],
#  ['order', 'batal', 'sistem'],
#  ['setia',
#   'aplikasi',
#   'aplikasi',
#   'banyak',
#   'mslah',
#   'lot',
#   'error',
#   'alih',
#   'kta',
#   'aplikasi',
#   'baca',
#   'ulas',
#   'tntg',
#   'males',
#   'untuk',
#   'install',
#   'hapus',
#   'sja'],
#  ['aplikasi',
#   'sampah',
#   'nyusahin',
#   'ribet',
#   'bget',
#   'promo',
#   'ikln',
#   'sesuai',
#   'pulsa',
#   'data',
#   'mahal',
#   'asliny'],
#  ['aplikasi', 'lot', 'berat', 'desain', 'ribet', 'beda', 'simpel', 'ringan'],
#  ['aplikasi', 'bgst', 'palir', 'tukang', 'ulah', 'babulu'],
#  ['goyang', 'knph', 'yh', 'klik', 'muncul'],
#  ['bikin', 'akun', 'username', 'salah', 'benar', 'username'],
#  ['kayak', 'siput'],
#  ['ongkir', 'mahal', 'barang', 'mahal', 'belah'],
#  ['saldo', 'juta', 'hangus'],
#  ['hoax', 'habisin', 'paket', 'data'],
#  ['bisa', 'diundh'],
#  ['iklan', 'muncul'],
#  ['kode', 'otp', 'terima', 'order', 'order', 'verifikasi', 'no', 'telpon'],
#  ['sama', 'iklan'],
#  ['sekar',
#   'seringkali',
#   'belanja',
#   'reward',
#   'gold',
#   'aktif',
#   'shopeepaylater',
#   'mesti',
#   'suruh',
#   'topup',
#   'lagi',
#   'beribet',
#   'konfirmasi'],
#  ['males', 'iklan', 'melulu'],
#  ['maaf',
#   'kirim',
#   'nama',
#   'hj',
#   'leni',
#   'kebeneran',
#   'sen',
#   'aneh',
#   'yahhh',
#   'nmer',
#   'handphone',
#   'nmer',
#   'tapi',
#   'nama',
#   'alamat',
#   'persis',
#   'tapi',
#   'pribadi',
#   'kirim',
#   'misterius',
#   'sya',
#   'bayar',
#   'pdhl',
#   'sen',
#   'diambio',
#   'bayar',
#   'kasi',
#   'kulir',
#   'nyaaaa'],
#  ['sen',
#   'apa',
#   'paket',
#   'dateng',
#   'rumah',
#   'adek',
#   'tindaktegas',
#   'jual',
#   'nakal'],
#  ['masukkan',
#   'kode',
#   'verifikasi',
#   'angka',
#   'smsnya',
#   'masukkan',
#   'dftr',
#   'failed'],
#  ['pilih',
#   'halaman',
#   'search',
#   'produk',
#   'tekan',
#   'back',
#   'kemarin',
#   'tombol',
#   'pojok',
#   'kanan',
#   'versi',
#   'akmask',
#   'mobile',
#   'pakai',
#   'wifi',
#   'sulit',
#   'koneksi',
#   'pakai',
#   'koneksi',
#   'data',
#   'lancar',
#   'tolong',
#   'tim'],
#  ['voucher', 'gratis', 'ongkir', 'tapi', 'pke', 'hedehh'],
#  ['maaf',
#   'jatuh',
#   'aplikasi',
#   'beritahu',
#   'admin',
#   'undi',
#   'hadiah',
#   'malah',
#   'korban',
#   'tipu',
#   'bnyak',
#   'ber',
#   'nama',
#   'jebak'],
#  ['eta', 'da'],
#  ['biaya', 'admin', 'mahal', 'jual', 'raih', 'untung', 'star', 'seller'],
#  ['up',
#   'dana',
#   'saldo',
#   'pindah',
#   'buka',
#   'dompet',
#   'saldo',
#   'buka',
#   'dompet',
#   'beku'],
#  ['tolong',
#   'tingkat',
#   'kait',
#   'proses',
#   'aju',
#   'food',
#   'proses',
#   'makan',
#   'optimal',
#   'kait',
#   'makan',
#   'barang'],
#  ['kaya',
#   'harga',
#   'diskon',
#   'pas',
#   'harga',
#   'diskon',
#   'harga',
#   'diskon',
#   'cek',
#   'out',
#   'harga',
#   'diskon',
#   'keranjang',
#   'harga',
#   'diskon',
#   'harga',
#   'beda',
#   'keranjang',
#   'keranjang',
#   'harga',
#   'asli',
#   'coret',
#   'cek',
#   'out',
#   'hargane',
#   'utuh',
#   'diskon',
#   'malesin'],
#  ['mem', 'beli', 'akun', 'bayar', 'beda', 'gambar', 'toko'],
#  ['rate', 'sesuai', 'alam', 'beli', 'sembunyi', 'seller', 'tanggung'],
#  ['unduh', 'pulsa', 'ribu', 'promo', 'dikit', 'pulsa'],
#  ['susa', 'membebahari'],
#  ['fitur', 'pilih', 'jasa', 'kirim'],
#  ['barang', 'akun', 'blok'],
#  ['kendala',
#   'spaylater',
#   'hubung',
#   'agen',
#   'bantu',
#   'lunas',
#   'cicil',
#   'sisa',
#   'sukses'],
#  ['aplikasi', 'belanja', 'akurat', 'percaya'],
#  ['kirim', 'tera', 'maksimal', 'terima', 'tanggal', 'kirim', 'tanggal'],
#  ['ulas',
#   'bintang',
#   'ikutin',
#   'karnakan',
#   'aplikasi',
#   'bangkrut',
#   'layan',
#   'langgan',
#   'ulas',
#   'ulas',
#   'mudah',
#   'retas',
#   'beli',
#   'topeng',
#   'mahal',
#   'ongkir',
#   'habis',
#   'topeng'],
#  ['daftar', 'belanja', 'bisaaa'],
#  ['konyol',
#   'beli',
#   'jam',
#   'salah',
#   'klik',
#   'terima',
#   'barang',
#   'barang',
#   'terima',
#   'duit',
#   'hangus',
#   'customer service',
#   'susah',
#   'hubung'],
#  ['ongkos', 'dilembalikan'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['belanja', 'stock', 'kosong'],
#  ['aplikasi', 'rena', 'voucher', 'alas', 'pesan'],
#  ['aplikasi', 'jellllekkkkk', 'akun', 'member', 'daftar', 'spaylater', 'akun'],
#  ['aplikasi', 'lambat'],
#  ['maaf',
#   'kasih',
#   'unduh',
#   'ulang',
#   'verifikasi',
#   'emain',
#   'no',
#   'tlf',
#   'pakek',
#   'hilang',
#   'aktif',
#   'cek',
#   'aplikasi',
#   'mytelkomsel',
#   'aktif',
#   'no',
#   'tlf',
#   'november',
#   'tolong',
#   'kasih',
#   'akal'],
#  ['balance', 'belanja', 'susah', 'dirarik'],
#  ['belanja',
#   'simpan',
#   'troli',
#   'bayar',
#   'jarak',
#   'update',
#   'updatenya',
#   'kelar',
#   'aplikasi',
#   'pakai',
#   'belanja',
#   'saldo',
#   'dana',
#   'bayar'],
#  ['nyaman',
#   'pakai',
#   'ehk',
#   'kesal',
#   'pesan',
#   'bareng',
#   'brngnya',
#   'slh',
#   'ktnya',
#   'tanggung',
#   'ehk',
#   'ngilang',
#   'tanggung'],
#  ['aplikasi', 'benar', 'njir'],
#  ['shopi', 'cod'],
#  ['sekian',
#   'pakai',
#   'ken',
#   'pakai',
#   'gegara',
#   'bosen',
#   'aplikasi',
#   'belah',
#   'pas',
#   'login',
#   'nomor',
#   'nonaktif',
#   'tolong',
#   'mudah',
#   'daftar',
#   'pakai',
#   'mail',
#   'konfirmasi',
#   'kasih',
#   'pilih',
#   'opsi',
#   'pakai',
#   'verifikasi',
#   'mail',
#   'google',
#   'account',
#   'seperti',
#   'gin',
#   'bingung',
#   'alhasil',
#   'bikin',
#   'account',
#   'males'],
#  ['lambat', 'lemod'],
#  ['order',
#   'barang',
#   'bom',
#   'sampai',
#   'samday',
#   'hilang',
#   'males',
#   'belanja',
#   'pagi',
#   'order',
#   'sore',
#   'sampai',
#   'pagi',
#   'order',
#   'bom',
#   'sampai'],
#  ['voucher', 'manipulasi', 'biji'],
#  ['super',
#   'lambat',
#   'jember',
#   'magelang',
#   'toko',
#   'cileduk',
#   'magelang',
#   'kapok',
#   'belanja'],
#  ['sayang',
#   'fitur',
#   'paylater',
#   'beli',
#   'barang',
#   'pulsa',
#   'tagih',
#   'listrik',
#   'pdam',
#   'tv',
#   'kabel'],
#  ['akun',
#   'block',
#   'ban',
#   'kah',
#   'akun',
#   'hilang',
#   'saldo',
#   'shoppe',
#   'hilang',
#   'beli',
#   'barang',
#   'impi',
#   'tua',
#   'smartphone'],
#  ['bintang',
#   'menu',
#   'bayar',
#   'later',
#   'kredit',
#   'aplikasi',
#   'shopeeku',
#   'smtra',
#   'orang',
#   'paylater',
#   'solusi',
#   'ditambahin',
#   'belanja',
#   'bayar',
#   'laternya',
#   'tolong',
#   'jangan',
#   'beda',
#   'langgan',
#   'juga',
#   'sring',
#   'mesan',
#   'smtr',
#   'teman',
#   'mesan',
#   'bayar',
#   'later'],
#  ['anjink', 'aplikasi', 'iklan', 'ganggu', 'tahu'],
#  ['ongkir', 'horor', 'iklan', 'bebas', 'ongkir', 'ongkir', 'keri'],
#  ['flassale', 'beli', 'reload', 'taikkkkkkkkkkkk'],
#  ['toko',
#   'filter',
#   'toko',
#   'toko',
#   'nakal',
#   'beli',
#   'mobil',
#   'remot',
#   'gantung'],
#  ['unduh', 'gagal', 'unduh', 'huh', 'belanja'],
#  ['dana',
#   'smp',
#   'skrng',
#   'transfer',
#   'rekening',
#   'telfon',
#   'customer',
#   'service',
#   'selalu',
#   'suruh',
#   'tunggu',
#   'sdah',
#   'hmpir',
#   'trnsferan',
#   'rekening',
#   'nunngu'],
#  ['belanja',
#   'pesan',
#   'sepatu',
#   'baju',
#   'aju',
#   'dana',
#   'barang',
#   'pesan',
#   'terima',
#   'aju',
#   'dana',
#   'tingkat',
#   'kualitas',
#   'layan',
#   'hack'],
#  ['basi',
#   'keluarga',
#   'akun',
#   'promo',
#   'alas',
#   'alamat',
#   'keluarga',
#   'rumah',
#   'alamat',
#   'pakai',
#   'alamat',
#   'tetangga',
#   'pakai',
#   'bacot'],
#  ['kuis', 'aplikasi', 'ram', 'ruang', 'kasih', 'hadiah', 'capek'],
#  ['maaf', 'lebe', 'ongkir'],
#  ['ken',
#   'login',
#   'akun',
#   'susah',
#   'tunggu',
#   'sms',
#   'smsnya',
#   'bangke',
#   'capek',
#   'nungguin'],
#  ['tolong', 'bebas', 'milih', 'ekspedisi', 'jnt'],
#  ['kolom', 'cari', 'ngebug', 'melulu', 'anjg'],
#  ['tolong',
#   'kirim',
#   'layan',
#   'express',
#   'kur',
#   'barang',
#   'kasih',
#   'asing',
#   'konfirmasi',
#   'terima',
#   'barang',
#   'elektronik',
#   'harga'],
#  ['shopeepay',
#   'emas',
#   'kirim',
#   'minimal',
#   'minggu',
#   'aneh',
#   'pakai',
#   'cod',
#   'why',
#   'perbaikin',
#   'tolong',
#   'reseller',
#   'tipu',
#   'tindak',
#   'bnyak',
#   'korban',
#   'beli'],
#  ['versi',
#   'ringan',
#   'update',
#   'versi',
#   'buka',
#   'bin',
#   'lot',
#   'pakai',
#   'internet',
#   'cepat',
#   'mbps',
#   'bayangin',
#   'cepat',
#   'aplikasi',
#   'belanja',
#   'konten',
#   'buka',
#   'nongol',
#   'alias',
#   'susah',
#   'buka',
#   'update',
#   'versi',
#   'sekarang',
#   'auto',
#   'aplikasi',
#   'kaliyan',
#   'yuk',
#   'komentar',
#   'aplikasi'],
#  ['kurir', 'kirim', 'timika', 'papua', 'belanja', 'uninstal'],
#  ['barang', 'sampah'],
#  ['tolong',
#   'verifikasi',
#   'ganti',
#   'akun',
#   'mudah',
#   'akun',
#   'email',
#   'no',
#   'handphone',
#   'ganti',
#   'akun',
#   'double',
#   'akun',
#   'hadehh'],
#  ['seler',
#   'tolong',
#   'kasih',
#   'atur',
#   'ketat',
#   'order',
#   'barang',
#   'transfer',
#   'barang',
#   'jalan',
#   'cancel',
#   'uang',
#   'jangka',
#   'sampai',
#   'minggu'],
#  ['maap', 'sekarng', 'buka', 'aplikasi', 'yoko', 'tida', 'mwnanggapi'],
#  ['devolepor',
#   'mesti',
#   'tipu',
#   'cashback',
#   'gratis',
#   'ongkir',
#   'iklan',
#   'tv',
#   'gratis',
#   'ongkir',
#   'minimum',
#   'belanja',
#   'belanja'],
#  ['easi',
#   'soping',
#   'pt',
#   'karisma',
#   'bahana',
#   'gemilang',
#   'tipu',
#   'suruh',
#   'mutar',
#   'lotery',
#   'lucki',
#   'miliader',
#   'rodah',
#   'henti',
#   'angka',
#   'miliard',
#   'hasil',
#   'rezeki',
#   'bukti',
#   'hoaks',
#   'tahu',
#   'almat',
#   'easi',
#   'soping',
#   'pulsa',
#   'informasi',
#   'hitung',
#   'buta',
#   'hukum',
#   'hak',
#   'tuhan',
#   'yesus',
#   'kutuk',
#   'cilakalah',
#   'binasa',
#   'kru',
#   'easy',
#   'soping',
#   'musiba',
#   'tabrak',
#   'maut',
#   'do',
#   'putra',
#   'flores',
#   'korban',
#   'tipu',
#   'amin',
#   'easi',
#   'soping',
#   'utang',
#   'timor'],
#  ['kode', 'otp', 'kirim', 'checkout'],
#  ['waaah',
#   'shoppi',
#   'benar',
#   'kirim',
#   'srkng',
#   'kesel',
#   'tunggu',
#   'jakarta',
#   'palembang',
#   'kemarin',
#   'kadang',
#   'sampai',
#   'sik',
#   'jasa',
#   'kirim',
#   'hadeh',
#   'langgan',
#   'pindah',
#   'aplikasi',
#   'tolong',
#   'seperti',
#   'jasa',
#   'kirim',
#   'yok',
#   'yok',
#   'seperti',
#   'jasa',
#   'kirim'],
#  ['bikin', 'emosi', 'tombal', 'batal', 'transaksi'],
#  ['pelit',
#   'gara',
#   'score',
#   'game',
#   'menu',
#   'bilang',
#   'main',
#   'normal',
#   'normal',
#   'ranking',
#   'voucher'],
#  ['kirim', 'lambattt', 'sen'],
#  ['platform', 'jaz'],
#  ['tunggu', 'jam', 'terintal', 'intal'],
#  ['tipu',
#   'hadiah',
#   'google',
#   'chrom',
#   'ujung',
#   'sruh',
#   'donlot',
#   'aplikasi',
#   'tapi',
#   'hadiah',
#   'bisa',
#   'ambil',
#   'dasar',
#   'tukang',
#   'tipu',
#   'pngen',
#   'bnyak',
#   'pngguna',
#   'tapi',
#   'pakai',
#   'mutu'],
#  ['aplikasi', 'nyaa', 'bagetttt', 'boooooggg'],
#  ['aplikasi', 'lihah', 'kopon', 'lodingnya'],
#  ['sesuai',
#   'iklan',
#   'iklan',
#   'promo',
#   'diskon',
#   'bebas',
#   'ongkir',
#   'promo',
#   'bayar',
#   'cod',
#   'bayar',
#   'bikin'],
#  ['kemarin',
#   'kasi',
#   'bintang',
#   'skarang',
#   'ganti',
#   'respon',
#   'pas',
#   'dana',
#   'barang',
#   'kirim',
#   'kasi',
#   'kabar',
#   'dana',
#   'jual',
#   'barang',
#   'terima',
#   'uang',
#   'kontak',
#   'jual',
#   'hati',
#   'kirim'],
#  ['hancur',
#   'tokopoint',
#   'daerah',
#   'pakai',
#   'kupon',
#   'diskon',
#   'batal',
#   'transfer',
#   'alas',
#   'langgar',
#   'klu',
#   'jangan',
#   'kupon',
#   'diskon',
#   'pdahal',
#   'hancur',
#   'updatenya',
#   'maaf',
#   'uninstal',
#   'pindah',
#   'toko',
#   'belah',
#   'lebih baik'],
#  ['uninstal', 'dominan', 'toko', 'orange'],
#  ['unduh', 'kenapa', 'pas', 'taut', 'suruh', 'dwonload'],
#  ['layan',
#   'tunggu',
#   'pesan',
#   'tampa',
#   'update',
#   'kirim',
#   'batal',
#   'kirim',
#   'tampa',
#   'terang'],
#  ['bodo', 'aplikasi', 'gratis', 'ongkir', 'bayar', 'ongkir', 'mahal'],
#  ['tol', 'aplikasi'],
#  ['update',
#   'aplikasi',
#   'selalu',
#   'ngeblank',
#   'ngetik',
#   'cari',
#   'barang',
#   'susah',
#   'brng',
#   'keranjang',
#   'bisa',
#   'hapus',
#   'msih',
#   'banyak',
#   'setelah',
#   'update',
#   'perbaikin',
#   'bug'],
#  ['limit', 'spaylater', 'bayar', 'jatuh', 'tempo'],
#  ['mahal', 'beda', 'selisih', 'bangetttttt'],
#  ['maaf', 'transaksi', 'shopeepay', 'shopeepay', 'later', 'limit'],
#  ['minimal',
#   'belanja',
#   'ribu',
#   'free',
#   'ongkir',
#   'kaget',
#   'belanja',
#   'butuh',
#   'rumah',
#   'ongkir',
#   'langit',
#   'alih',
#   'pindah',
#   'belanja',
#   'toko',
#   'belah',
#   'free',
#   'ongkir'],
#  ['sembako', 'kupon', 'utuh'],
#  ['beli', 'paket', 'sertifikat', 'dashboard'],
#  ['kemarin',
#   'pesan',
#   'pesan',
#   'batal',
#   'dana',
#   'transfer',
#   'untuk',
#   'dana',
#   'tolong',
#   'rekening',
#   'akun',
#   'nama',
#   'masukkan',
#   'rekening',
#   'seller',
#   'aktif'],
#  ['dana',
#   'pesan',
#   'batal',
#   'dana',
#   'rekening',
#   'perhati',
#   'langgan',
#   'sulit',
#   'uang',
#   'hak',
#   'tolong',
#   'dana'],
#  ['deret', 'ssrx', 'det', 'er'],
#  ['mecahin',
#   'telur',
#   'update',
#   'koin',
#   'update',
#   'gratis',
#   'ongkir',
#   'update',
#   'update',
#   'padal',
#   'update',
#   'tetep',
#   'update',
#   'kuota',
#   'habis',
#   'update',
#   'aplikasi',
#   'ginian',
#   'tolong',
#   'perintah',
#   'update',
#   'rang'],
#  ['jgan',
#   'belanja',
#   'barang',
#   'pesan',
#   'barang',
#   'ngk',
#   'sesuai',
#   'sya',
#   'mesan',
#   'baju',
#   'celana',
#   'bokser',
#   'pendek'],
#  ['beri',
#   'kupon',
#   'diskon',
#   'pas',
#   'belanja',
#   'pesan',
#   'batal',
#   'otomatis',
#   'kupon',
#   'pakai',
#   'lagi',
#   'kasih',
#   'kupon',
#   'diskon',
#   'rugi'],
#  ['tracking',
#   'paket',
#   'jalan',
#   'web',
#   'kurir',
#   'cek',
#   'jalan',
#   'asa',
#   'belanja',
#   'gin'],
#  ['aplikasi',
#   'go',
#   'internasional',
#   'urus',
#   'tagih',
#   'spaylatter',
#   'spinjam',
#   'nada',
#   'bicara',
#   'pesan',
#   'ngalahin',
#   'rentenir',
#   'mkn',
#   'bangku',
#   'sekolah',
#   'bunga',
#   'gede',
#   'dibyr',
#   'cicil',
#   'masih',
#   'orang',
#   'peres',
#   'layak',
#   'hutang',
#   'ratus',
#   'juta',
#   'miris',
#   'gaji',
#   'krywn',
#   'hasil',
#   'paksa',
#   'pinjam',
#   'ksh',
#   'kenal',
#   'lagi',
#   'zaman',
#   'lagi',
#   'covid',
#   'tegang',
#   'aplikasi',
#   'sblh',
#   'move',
#   'on'],
#  ['aplikasi', 'mahal', 'ongkir', 'harga', 'normal'],
#  ['lot', 'loading', 'terusssss'],
#  ['beli',
#   'dishopee',
#   'jual',
#   'tanggung',
#   'barang',
#   'kirim',
#   'salah',
#   'dana',
#   'barang'],
#  ['iklan', 'paksa', 'resah', 'hadeh'],
#  ['bayar', 'pakai', 'dana', 'unistal'],
#  ['iklanya', 'menggangu'],
#  ['mh', 'transaksi', 'ny', 'eror', 'terusssssss'],
#  ['akun',
#   'non',
#   'aktif',
#   'beku',
#   'langgar',
#   'atur',
#   'aplikasi',
#   'banned',
#   'kominfo',
#   'beli',
#   'latih',
#   'aplikasi',
#   'lulus',
#   'sertifikat',
#   'skill',
#   'academy',
#   'lapor',
#   'instansi',
#   'taung',
#   'bekerjasama',
#   'aplikasi',
#   'sertifikat',
#   'latih',
#   'muncul',
#   'dashboard',
#   'akun',
#   'tipu',
#   'publik'],
#  ['penguna', 'ambil', 'rp', 'kocak'],
#  ['jelekkk',
#   'bangett',
#   'voucher',
#   'beli',
#   'kaos',
#   'toko',
#   'dibatalinn',
#   'uang',
#   'balik',
#   'kejebakk',
#   'saldo',
#   'ambil',
#   'gabisaa',
#   'pakai',
#   'dana',
#   'pakeovo',
#   'gabisaa',
#   'gabanyakk',
#   'namnaya',
#   'uang'],
#  ['daftar', 'kode', 'frivikasi', 'muncul', 'muncul'],
#  ['aplikasi',
#   'bohong',
#   'pakai',
#   'sopepay',
#   'susah',
#   'kode',
#   'otp',
#   'kirim',
#   'bonuss',
#   'akun',
#   'saldo',
#   'ribu',
#   'tipu'],
#  ['habisin', 'kuota', 'update', 'profil', 'sampai', 'kiamat'],
#  ['pesan',
#   'cancel',
#   'kirim',
#   'kirim',
#   'gmn',
#   'jual',
#   'verifikasi',
#   'sopenya',
#   'solusi',
#   'gmn'],
#  ['limit', 'shopeepaylater', 'rp', 'cicil', 'lunas'],
#  ['spaylater', 'diaktivasi', 'gagal'],
#  ['kirain',
#   'harga',
#   'murah',
#   'wkwkwkwk',
#   'diskon',
#   'pelit',
#   'maaf',
#   'auto',
#   'uninstal'],
#  ['cashback',
#   'bukareksa',
#   'promo',
#   'reksajul',
#   'reksajul',
#   'reksaaug',
#   'reksaaug',
#   'hitung',
#   'cashback',
#   'komplain',
#   'ulang',
#   'tunggu',
#   'seninggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'tahan',
#   'dana',
#   'jual'],
#  ['update', 'susah', 'buka'],
#  ['barang', 'manaaaaa'],
#  ['rugi', 'beli', 'realpeack'],
#  ['aplikasi', 'nyampah'],
#  ['terimah', 'kasih', 'pesan', 'barangx', 'cepat', 'kirim'],
#  ['lindung',
#   'konsumen',
#   'tipu',
#   'seller',
#   'kayak',
#   'barang',
#   'butuh',
#   'minggu'],
#  ['buka',
#   'akun',
#   'transaksi',
#   'kemarin',
#   'beli',
#   'promo',
#   'klaim',
#   'langgar',
#   'pdhal',
#   'transaksi',
#   'aju',
#   'kpan',
#   'langgar',
#   'internal',
#   'customer',
#   'bukti'],
#  ['kesini', 'aplikasi', 'kok', 'bayar', 'eror', 'gakda', 'solusi', 'aplikasi'],
#  ['update',
#   'versi',
#   'hubung',
#   'ulang',
#   'kolom',
#   'feed',
#   'buka',
#   'tolong',
#   'nyaman',
#   'handphone',
#   'samsung',
#   'profesional',
#   'terima',
#   'kasih'],
#  ['tarik', 'dana'],
#  ['aplikasi', 'layan'],
#  ['bnayak', 'update'],
#  ['sistem', 'error'],
#  ['bertanya',
#   'event',
#   'paket',
#   'data',
#   'pulsa',
#   'perak',
#   'tu',
#   'boongan',
#   'ubah',
#   'bintang',
#   'kecuali',
#   'please'],
#  ['sanggat', 'kecewaa'],
#  ['aju', 'hapus', 'akun', 'ribet'],
#  ['rugi', 'tolong', 'uang'],
#  ['krkurangan',
#   'transaksi',
#   'aplikasi',
#   'tampil',
#   'wahhh',
#   'sistem',
#   'transaksi',
#   'normal'],
#  ['barang', 'rusak', 'jual', 'gemanay'],
#  ['uda', 'bayar', 'bom', 'sampai'],
#  ['transfer', 'airpayinternal', 'beli', 'barang', 'batal', 'dana', 'tidak'],
#  ['jangan',
#   'unduh',
#   'bnyak',
#   'pnipuan',
#   'jual',
#   'buukn',
#   'brang',
#   'asli',
#   'rport',
#   'smaa',
#   'bnyak',
#   'unsur',
#   'penipuann'],
#  ['transaksi', 'batal', 'aplikasi', 'jelasssss'],
#  ['belanja',
#   'gilir',
#   'belanja',
#   'poin',
#   'ktanya',
#   'cod',
#   'isi',
#   'pdhl',
#   'pakai',
#   'ongkir',
#   'bebas',
#   'ongkir',
#   'moduss',
#   'kopeeet'],
#  ['saldo', 'hasil', 'refund', 'belanja'],
#  ['aplikasi', 'bohong', 'diskon', 'pas', 'tunggu', 'tunggu', 'unduh'],
#  ['ribet',
#   'jual',
#   'cair',
#   'dana',
#   'beli',
#   'sesuai',
#   'terang',
#   'terang',
#   'sampai',
#   'oktober',
#   'konfirmasi',
#   'beli',
#   'dana',
#   'otomatis',
#   'jual',
#   'oktober',
#   'dana',
#   'tahan',
#   'kasih',
#   'terang',
#   'bikin',
#   'jual',
#   'harap'],
#  ['kaya', 'massa', 'pesan', 'barang'],
#  ['komentar',
#   'hapus',
#   'nanti',
#   'ketik',
#   'pergi',
#   'hibur',
#   'nanti',
#   'ketik',
#   'komen',
#   'hapus',
#   'shoope',
#   'asw',
#   'salin',
#   'komen',
#   'hapus',
#   'tinggal',
#   'paste',
#   'dikomen',
#   'sembuyikan',
#   'komen',
#   'hapus',
#   'komen',
#   'ketik',
#   'salin',
#   'komen',
#   'hapus',
#   'shoope',
#   'update',
#   'macet',
#   'pantang',
#   'nyerah',
#   'ubah',
#   'santet',
#   'balesanya',
#   'santet'],
#  ['aplikasi', 'unduh'],
#  ['ongkir', 'mahal', 'tolong', 'murahin', 'kayak', 'pandemi', 'uang'],
#  ['komplain', 'ribet'],
#  ['freeong',
#   'belanja',
#   'ribu',
#   'freeong',
#   'belanja',
#   'freeong',
#   'pindah',
#   'market',
#   'place'],
#  ['belanja',
#   'beli',
#   'jual',
#   'biaya',
#   'adminnya',
#   'toko',
#   'dibanned',
#   'pajak',
#   'negara',
#   'ken',
#   'untung',
#   'buntung'],
#  ['ambisi', 'unt', 'unduh', 'iklan', 'muntah', 'tarik', 'belanja', 'turun'],
#  ['bayar', 'sayang', 'bayar'],
#  ['cuman', 'aplikasi', 'gilir', 'girim'],
#  ['aplikasi', 'rancang', 'tipu'],
#  ['aplikasi', 'maksa', 'ta', 'ekkkkkkkkkkkk', 'anjinkkkkkkkkk'],
#  ['iklan', 'asli', 'jlek', 'tipu', 'belanja', 'batal', 'otomatis'],
#  ['update', 'ui', 'user', 'friendly'],
#  ['sesuai', 'iklan'],
#  ['reses', 'iklan', 'bikin', 'risih', 'unduh'],
#  ['shoope',
#   'iklan',
#   'spam',
#   'melulu',
#   'renti',
#   'seperti',
#   'lagi',
#   'main',
#   'ml',
#   'iklan',
#   'shoope'],
#  ['kesini', 'lambat', 'njir', 'buka', 'pakai', 'wifi', 'ram'],
#  ['iklan', 'ngabisin', 'kuota'],
#  ['sponsor', 'broser', 'unduh', 'aplikasi', 'melulu', 'susah', 'pusing'],
#  ['tiktok',
#   'iklan',
#   'toko',
#   'terus',
#   'diam',
#   'jan',
#   'ganggu',
#   'seru',
#   'nonton',
#   'tiktokk'],
#  ['update', 'koneksi', 'bikin', 'kesel'],
#  ['aju', 'tolak', 'spaylaternya', 'hadeh', 'kasih', 'bintang', 'atulah'],
#  ['ongkos',
#   'kirim',
#   'ribu',
#   'voucernya',
#   'sus',
#   'sope',
#   'bayar',
#   'cod',
#   'voucer',
#   'gratis',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'beli',
#   'kasi',
#   'voucher',
#   'sisa',
#   'rebut',
#   'icon',
#   'free',
#   'ogkir',
#   'hilang'],
#  ['aplikasi',
#   'nyampe',
#   'tangal',
#   'nyampenya',
#   'tangal',
#   'aplikasi',
#   'bohong',
#   'install',
#   'aplikasi',
#   'dasar',
#   'aplikasi',
#   'penbohong'],
#  ['beli',
#   'case',
#   'handphone',
#   'negeri',
#   'cari',
#   'produk',
#   'negeri',
#   'cari',
#   'case',
#   'negeri',
#   'negeri',
#   'gmn',
#   'solusi'],
#  ['bayar', 'suruh', 'tunggu', 'jam', 'jam', 'akun', 'blokirr', 'tanggung'],
#  ['susah', 'unduh'],
#  ['mengambil',
#   'gratis',
#   'ongkir',
#   'nominal',
#   'ongkir',
#   'ny',
#   'gede',
#   'sedih',
#   'kadang',
#   'barang',
#   'pes',
#   'mahal',
#   'ongkir'],
#  ['jual',
#   'ragu',
#   'waswas',
#   'sampai',
#   'opsi',
#   'pilih',
#   'asuransi',
#   'halaman',
#   'cek',
#   'out',
#   'produk',
#   'kalah',
#   'toko',
#   'online',
#   'belah',
#   'opsi',
#   'asuransi',
#   'pas',
#   'kantor',
#   'ribet',
#   'karyawan',
#   'admin',
#   'paham',
#   'menbahkan',
#   'asuransi',
#   'profesional',
#   'kacau'],
#  ['jual', 'buku', 'baja', 'liar', 'belanja', 'nyaman'],
#  ['kesini', 'pas', 'unduh', 'video', 'gugel'],
#  ['beli',
#   'produk',
#   'pas',
#   'gilir',
#   'beli',
#   'kamera',
#   'oppo',
#   'nyala',
#   'tolong',
#   'tindak',
#   'lanjutin',
#   'jual'],
#  ['dagang',
#   'nakal',
#   'daripahda',
#   'bikin',
#   'promo',
#   'tv',
#   'lebih baik',
#   'aplikasi'],
#  ['respon',
#   'tolong',
#   'toko',
#   'toko',
#   'amanah',
#   'jual',
#   'respon',
#   'makan',
#   'pergi',
#   'hilang',
#   'konsumen',
#   'keluh',
#   'diam'],
#  ['iklan',
#   'lebih baik',
#   'pas',
#   'nonton',
#   'youtube',
#   'nonton',
#   'halaman',
#   'utama',
#   'layar',
#   'tolong',
#   'iklan'],
#  ['beli',
#   'tas',
#   'gunung',
#   'minggu',
#   'sepatu',
#   'roda',
#   'tipu',
#   'amanah',
#   'pesan',
#   'tas',
#   'kamu',
#   'sepatu',
#   'roda',
#   'gin',
#   'hapus',
#   'aplikashi',
#   'amanah'],
#  ['plis',
#   'batal',
#   'pesan',
#   'ubah',
#   'pikir',
#   'kirimm',
#   'allah',
#   'tolong',
#   'rugi',
#   'bangett'],
#  ['update', 'melulu'],
#  ['from', 'zero', 'hero'],
#  ['ngk', 'gratis', 'ongir'],
#  ['customer',
#   'service',
#   'layan',
#   'nelpon',
#   'butuh',
#   'customer service',
#   'sopan',
#   'santun',
#   'mati',
#   'panggil',
#   'pulsa'],
#  ['buka', 'aplikasi'],
#  ['aman',
#   'aman',
#   'gilir',
#   'kirim',
#   'barang',
#   'tim',
#   'ehh',
#   'hasil',
#   'nol',
#   'konfirmasi',
#   'bukti',
#   'adu',
#   'tim',
#   'jangan',
#   'harap'],
#  ['staff', 'tolong', 'profesional', 'beda', 'gratis', 'ongkir', 'sedih'],
#  ['ongkir', 'mahal'],
#  ['belanja',
#   'komplain',
#   'sanggup',
#   'sarat',
#   'berat',
#   'bangat',
#   'suruh',
#   'bikin',
#   'video',
#   'youtuber',
#   'nomor',
#   'seri',
#   'bukti',
#   'foto',
#   'lanjur',
#   'buka',
#   'paket',
#   'wuish',
#   'nang',
#   'beli'],
#  ['shope', 'bayar', 'qd', 'blokir', 'salah'],
#  ['muncul', 'iklan', 'internet', 'otomatis', 'kesini', 'orang', 'maksa'],
#  ['maaf', 'sen', 'apa', 'dateng', 'tolong'],
#  ['jangan', 'kirim', 'promo', 'handphone', 'tarik', 'ganggu'],
#  ['erti', 'beli', 'latih', 'kartu', 'gagal', 'tipu', 'kayak', 'gin'],
#  ['jan', 'maksa', 'install'],
#  ['mntep', 'shopefood'],
#  ['cobakalau',
#   'promosi',
#   'tipu',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ongkir',
#   'gede',
#   'harga',
#   'barang'],
#  ['kesini', 'gara', 'google', 'crome', 'ribu'],
#  ['update', 'klik', 'toko'],
#  ['cerita', 'shopi', 'hoax'],
#  ['curang', 'event', 'event', 'sistem', 'talu', 'lot', 'sistem', 'jadul'],
#  ['kirim', 'pesan', 'kayak', 'buka', 'kirim', 'dikit', 'tinggal', 'buka'],
#  ['ualah', 'tahu', 'cod', 'biaya', 'nang', 'xixixixixididi'],
#  ['apdead', 'paylater'],
#  ['aplikasi',
#   'belanja',
#   'seller',
#   'blokir',
#   'toko',
#   'tanggung',
#   'rugi',
#   'beli'],
#  ['aplikasi', 'cuman', 'iklan', 'ganggu', 'anjeng'],
#  ['trooble', 'tuuuerruusss'],
#  ['berat',
#   'beli',
#   'setia',
#   'beli',
#   'barang',
#   'harga',
#   'juta',
#   'tipu',
#   'beli',
#   'ebook',
#   'tips',
#   'jitu',
#   'isi',
#   'screen',
#   'shot',
#   'kirim',
#   'biji',
#   'admin',
#   'tolak',
#   'adu',
#   'sungguh',
#   'menang',
#   'tipu',
#   'kayak',
#   'gin',
#   'lebih baik',
#   'unistall',
#   'jamin',
#   'aman',
#   'beli',
#   'tipu',
#   'bukalapa'],
#  ['tolong',
#   'buka',
#   'aplikasi',
#   'muslim',
#   'profesional',
#   'solat',
#   'iklan',
#   'menganggu',
#   'muslim',
#   'profesional',
#   'tutup',
#   'aplikasi',
#   'kesel',
#   'maaf',
#   'ulas',
#   'salah',
#   'salah',
#   'seller',
#   'tanggung',
#   'tindak'],
#  ['benar',
#   'bikin',
#   'murka',
#   'pesan',
#   'sya',
#   'sesuai',
#   'chat',
#   'seller',
#   'tidak',
#   'etikad',
#   'baca',
#   'tolong',
#   'smpein',
#   'toko',
#   'ling',
#   'hong',
#   'jual',
#   'amanah'],
#  ['harga',
#   'dimainin',
#   'aplikasi',
#   'pilih',
#   'warna',
#   'size',
#   'harga',
#   'ubah',
#   'tertawa',
#   'capek',
#   'capek',
#   'milih',
#   'mlototin',
#   'order',
#   'harga',
#   'sesuai',
#   'tema',
#   'stop',
#   'gunain'],
#  ['aplikasi', 'aneh', 'barang', 'bayar', 'batal', 'aplikasi'],
#  ['buka', 'susah', 'loadingnya'],
#  ['shope',
#   'plis',
#   'mengundng',
#   'teman',
#   'verif',
#   'ktp',
#   'teman',
#   'bom',
#   'bikin',
#   'ktf',
#   'macam',
#   'plis',
#   'rakyat',
#   'indonesia',
#   'even'],
#  ['daya', 'bayar', 'ngeblank'],
#  ['kada', 'baikk'],
#  ['akun',
#   'hack',
#   'atm',
#   'akun',
#   'pinjam',
#   'uang',
#   'jt',
#   'block',
#   'aplikasi',
#   'aman'],
#  ['masak',
#   'aju',
#   'spaylater',
#   'bayar',
#   'kartu',
#   'kredit',
#   'mengunakan',
#   'aplikasi',
#   'shoppee',
#   'lah',
#   'kartu',
#   'kredit',
#   'ngk',
#   'shopeepay',
#   'aneh',
#   'shoppe',
#   'limit',
#   'ngk'],
#  ['ribet', 'sen', 'gratis', 'ongkir'],
#  ['sesal', 'nang', 'akun', 'blok'],
#  ['sama',
#   'aplikasi',
#   'pilih',
#   'transaksi',
#   'batalakan',
#   'dn',
#   'belah',
#   'transaksi',
#   'sampai',
#   'tunggu',
#   'minggu',
#   'uang'],
#  ['sakit', 'killik', 'kirim', 'barang'],
#  ['hapus',
#   'aju',
#   'phaylater',
#   'tolak',
#   'muncul',
#   'tawar',
#   'phaylater',
#   'aju',
#   'tolak'],
#  ['maaf',
#   'pakai',
#   'aplikasi',
#   'ajh',
#   'gratis',
#   'ongkir',
#   'minggu',
#   'ganti',
#   'handphone',
#   'unduh',
#   'teman',
#   'kenapa',
#   'potong',
#   'ongkir'],
#  ['aplikasi', 'sempurna'],
#  ['sen',
#   'barang',
#   'dilazada',
#   'tahu',
#   'tahu',
#   'kurir',
#   'dateng',
#   'rumah',
#   'tas',
#   'slempang',
#   'bayar',
#   'sen',
#   'sen',
#   'dateng',
#   'gmn',
#   'hapus',
#   'akun'],
#  ['transaksi',
#   'batal',
#   'recommended',
#   'belanja',
#   'lebih baik',
#   'pakai',
#   'mudah',
#   'aman',
#   'ribet',
#   'iming',
#   'gratis',
#   'ongkir',
#   'tahu',
#   'fiktif',
#   'google',
#   'mereview',
#   'aplikasi',
#   'ngrugiin'],
#  ['kirim',
#   'lambattt',
#   'bngettt',
#   'proses',
#   'toko',
#   'belah',
#   'cepat',
#   'tolong',
#   'koreksi'],
#  ['aneh', 'transaksi', 'anggap', 'pesan', 'batal', 'alas', 'nila', 'fitnah'],
#  ['toko', 'ngentodddd'],
#  ['cepat',
#   'install',
#   'oo',
#   'penuh',
#   'lah',
#   'simpan',
#   'takbisa',
#   'ookesel',
#   'capek',
#   'huudan',
#   'baguss',
#   'oooooooooo'],
#  ['bangke', 'beli', 'paket', 'data', 'suruh', 'tunggu', 'tutup'],
#  ['klaim', 'barang', 'rp'],
#  ['susah', 'cek', 'out', 'lancar'],
#  ['aplikasi',
#   'cantemer',
#   'servis',
#   'sms',
#   'alibi',
#   'aju',
#   'pinjam',
#   'dana',
#   'aju',
#   'pinjam',
#   'dana',
#   'aplikasi',
#   'telepon',
#   'sms',
#   'ganggu'],
#  ['belanja', 'mudah'],
#  ['toko',
#   'vavio',
#   'acc',
#   'jual',
#   'chip',
#   'high',
#   'domino',
#   'tolong',
#   'band',
#   'sdah',
#   'bayar',
#   'suruh',
#   'batal',
#   'transaksi',
#   'aplikasi',
#   'skrng',
#   'tunggu',
#   'dana'],
#  ['bingung',
#   'jual',
#   'jujur',
#   'bilang',
#   'langgar',
#   'akun',
#   'batas',
#   'dana',
#   'beli',
#   'saldo',
#   'jual',
#   'beli',
#   'setia',
#   'hapus',
#   'bilang',
#   'curiga',
#   'toko',
#   'curiga',
#   'lancar',
#   'bayar',
#   'barang',
#   'beli',
#   'dishopee',
#   'bijak',
#   'kasih',
#   'seperti',
#   'sp',
#   'timbang'],
#  ['saring', 'jual', 'tipu', 'tayiiiilahhh'],
#  ['kanapa', 'barang', 'data', 'ng', 'sedangkab', 'mes', 'tipu'],
#  ['install',
#   'aplikasi',
#   'keamananya',
#   'kemarin',
#   'paket',
#   'tersesat',
#   'akun',
#   'mesan',
#   'log',
#   'out',
#   'akun',
#   'unistal',
#   'tahu',
#   'paket',
#   'ajar',
#   'real',
#   'alam',
#   'tolong',
#   'perhati'],
#  ['aplikasi', 'jlas', 'kirim', 'akun', 'cek', 'kosong'],
#  ['aplikasi', 'sungguh', 'sulit', 'paham', 'barang', 'batal', 'otomatis'],
#  ['tolong',
#   'dijelasin',
#   'aplikasi',
#   'klik',
#   'tapi',
#   'kluar',
#   'klik',
#   'kluar',
#   'lagi',
#   'klik',
#   'kluar',
#   'lagi',
#   'orang',
#   'belanja',
#   'tidak'],
#  ['sistem', 'jual', 'ekspedisi', 'ubah', 'rubah', 'ekspedisi'],
#  ['nggk', 'update', 'gim'],
#  ['balik', 'jasa', 'kirim'],
#  ['flash', 'sale', 'ngadat', 'anjeng'],
#  ['bayar', 'latter', 'bayar', 'sekarang', 'gabiisaa', 'butuh', 'baaanget'],
#  ['batas',
#   'kirim',
#   'seller',
#   'sistem',
#   'cod',
#   'kadang',
#   'kurir',
#   'rumah',
#   'rumah',
#   'kasihan',
#   'kurir',
#   'bolak',
#   'ngekost',
#   'titip',
#   'tetangga',
#   'tetangga'],
#  ['minggu', 'juga', 'pesan', 'detail', 'kirim', 'akurat'],
#  ['seller',
#   'nd',
#   'respon',
#   'proses',
#   'jual',
#   'kirim',
#   'kurir',
#   'nd',
#   'kayak',
#   'lari',
#   'dehh'],
#  ['ngeselin',
#   'aplikasi',
#   'beli',
#   'kirim',
#   'cepat',
#   'tapi',
#   'ngeselin',
#   'brli',
#   'barang',
#   'pengirimanya',
#   'minggu',
#   'kirim',
#   'tutup',
#   'batal',
#   'barang',
#   'begi',
#   'pindah',
#   'toko',
#   'online',
#   'belah',
#   'tolong',
#   'ekspedisi',
#   'instan',
#   'aktif',
#   'cepat',
#   'respon',
#   'auto',
#   'uninstal'],
#  ['benci', 'ygjadi', 'bintang', 'iklan', 'cowok', 'cowok', 'cantik'],
#  ['aplikasi',
#   'sesal',
#   'unduh',
#   'gratis',
#   'traktir',
#   'pas',
#   'pesan',
#   'dibatalin',
#   'langgar',
#   'langgar',
#   'pesan',
#   'kaya',
#   'aplikasi'],
#  ['rp',
#   'ambil',
#   'stok',
#   'habis',
#   'ambil',
#   'stok',
#   'habis',
#   'gilir',
#   'jarak',
#   'pilih',
#   'jasa',
#   'kirim',
#   'harga',
#   'beli',
#   'uninstall'],
#  ['voucher',
#   'jt',
#   'tapi',
#   'tu',
#   'saldo',
#   'toko',
#   'bohong',
#   'mnta',
#   'ampun',
#   'unduh'],
#  ['iklan', 'nongol', 'ganggu'],
#  ['ribet',
#   'ganti',
#   'nomer',
#   'telpon',
#   'susah',
#   'benar',
#   'kirim',
#   'sulit',
#   'kamera',
#   'handphone',
#   'telpon',
#   'customer service',
#   'ngebantunya'],
#  ['kesel', 'harga', 'ongkir', 'mahal', 'skrng', 'ongkir'],
#  ['gratis', 'ongkir', 'boongan'],
#  ['unduh', 'handphone', 'handphone'],
#  ['susah',
#   'flash',
#   'sale',
#   'barang',
#   'mewah',
#   'klik',
#   'terang',
#   'stok',
#   'habis',
#   'barang',
#   'murah',
#   'habis',
#   'stok',
#   'flash',
#   'sale',
#   'kaya',
#   'flash',
#   'sale',
#   'atur',
#   'antri',
#   'aplikasi',
#   'barang',
#   'flash',
#   'sale',
#   'atur',
#   'sistem',
#   'stel',
#   'beda',
#   'pkoknya',
#   'habis',
#   'kaya',
#   'atur',
#   'sistem',
#   'pokok',
#   'buyer',
#   'habis'],
#  ['kirim', 'cepat', 'terpercsya', 'tunggu', 'tidak', 'kirim'],
#  ['aplikasi', 'kirim', 'cepat', 'pokok'],
#  ['shope', 'aneh'],
#  ['bintang', 'pesan'],
#  ['aplikasi',
#   'tolong',
#   'bantu',
#   'masak',
#   'saldo',
#   'hilang',
#   'kasih',
#   'bintang'],
#  ['aplikasi', 'bujang', 'mahal', 'beda', 'tetangga', 'laz'],
#  ['buka', 'lapak', 'sya', 'bayar', 'status', 'belanja', 'ubah', 'bayar'],
#  ['cocok', 'kulit', 'pakai', 'aloe', 'vera', 'pesan'],
#  ['sen',
#   'kirim',
#   'pesan',
#   'barang',
#   'cancel',
#   'jual',
#   'tolong',
#   'laa',
#   'bikin'],
#  ['ambil', 'aplikasi', 'pakai', 'jengkel', 'muncul'],
#  ['iklan', 'resah'],
#  ['cashback', 'rp', 'hilang', 'rugi', 'gin'],
#  ['cod', 'gratis', 'ongkir', 'bohong', 'nihhh'],
#  ['danta',
#   'paket',
#   'donwload',
#   'bekal',
#   'mentang',
#   'isi',
#   'paket',
#   'pakai',
#   'paket',
#   'mahal',
#   'sesuai',
#   'gadantaaaawwa'],
#  ['pindah', 'masak', 'kurir', 'anggap', 'budak'],
#  ['klaim',
#   'diskon',
#   'ribu',
#   'jam',
#   'voucher',
#   'hilang',
#   'refresh',
#   'ttp',
#   'ngadain',
#   'diskon',
#   'leg'],
#  ['agent',
#   'chat',
#   'live',
#   'shoppe',
#   'jk',
#   'bantu',
#   'chat',
#   'putus',
#   'paket',
#   'ydk',
#   'kirim',
#   'minta',
#   'dana',
#   'toko',
#   'tolak',
#   'aplikasi',
#   'lepas',
#   'tangan'],
#  ['driver',
#   'shope',
#   'food',
#   'pakai',
#   'fake',
#   'gps',
#   'tuyul',
#   'aplikasi',
#   'larang',
#   'tindak',
#   'jangan',
#   'mlh',
#   'kasihan',
#   'driver',
#   'jujur',
#   'driver',
#   'order',
#   'pakai',
#   'tuyul',
#   'suspend',
#   'pakai',
#   'aplikasi',
#   'aman',
#   'maju',
#   'jaya'],
#  ['beli', 'barang', 'paket', 'kosong', 'dana'],
#  ['iklan', 'otomatis', 'amit', 'lebih baik', 'shopie', 'olx'],
#  ['gratis',
#   'ongkir',
#   'belanja',
#   'ribu',
#   'ribu',
#   'sesuai',
#   'tema',
#   'lebih baik'],
#  ['seller', 'cetak', 'print', 'alamat', 'kirim', 'aplikasi'],
#  ['tipu',
#   'jgan',
#   'kayak',
#   'gin',
#   'percaya',
#   'sama',
#   'permai',
#   'pesan',
#   'batal',
#   'saldo',
#   'direfund',
#   'bisa',
#   'belanja',
#   'uang',
#   'bisa',
#   'tarik',
#   'capek',
#   'capek',
#   'alfamidi',
#   'bayar',
#   'uang',
#   'admin',
#   'batal',
#   'saldo',
#   'refund',
#   'pakai',
#   'tarik',
#   'malu',
#   'maluin'],
#  ['pesan',
#   'barang',
#   'oct',
#   'tngl',
#   'barang',
#   'terima',
#   'kirim',
#   'terima',
#   'barang',
#   'juga',
#   'belum',
#   'barang',
#   'kirim',
#   'kacau',
#   'toko',
#   'barang',
#   'belum',
#   'terima',
#   'kirim',
#   'kurir',
#   'nelpon',
#   'tidak',
#   'barang',
#   'sampai',
#   'no',
#   'handphone',
#   'customer service',
#   'ninja',
#   'exxpres',
#   'beres',
#   'atw',
#   'pm',
#   'kurir'],
#  ['kasih', 'bintang'],
#  ['ongkir', 'mahal', 'barang', 'beli', 'ribu', 'ongkir'],
#  ['lot', 'parahh', 'sinyal', 'wifi', 'gambar', 'polos', 'notificationnya'],
#  ['check', 'out', 'hubungi', 'customer service'],
#  ['unduh',
#   'aplikasi',
#   'aplikasi',
#   'pesan',
#   'terima',
#   'sampai',
#   'sampai',
#   'tangan',
#   'tungguin',
#   'tetep',
#   'datang',
#   'datang',
#   'belanja',
#   'mengecewaken',
#   'gabakal',
#   'belanja',
#   'rim',
#   'konsisten'],
#  ['log', 'nomor', 'blokir', 'pdhl', 'pakai', 'order', 'jual'],
#  ['aplikasi', 'php'],
#  ['aplikasi',
#   'akun',
#   'sya',
#   'blokir',
#   'sya',
#   'sarankn',
#   'dwonload',
#   'jangan',
#   'dwnload',
#   'nyeseel'],
#  ['bayar', 'link'],
#  ['belanja',
#   'pesan',
#   'bayar',
#   'tanggal',
#   'nov',
#   'tanda',
#   'kirim',
#   'catat',
#   'proses',
#   'kemas',
#   'gilir',
#   'chat',
#   'customer service',
#   'muter',
#   'karuan'],
#  ['iklan', 'melulu', 'kntol', 'aplikasi', 'anjng'],
#  ['seller', 'bodoh'],
#  ['kirim', 'kayak', 'toko'],
#  ['tolong',
#   'skrng',
#   'ongkir',
#   'pisah',
#   'pisah',
#   'ongkir',
#   'distuin',
#   'sdkit',
#   'tolong',
#   'satuin',
#   'ongkir'],
#  ['sayang',
#   'cicil',
#   'kartu',
#   'kredit',
#   'toko',
#   'belah',
#   'kredit',
#   'kartu',
#   'kredit'],
#  ['terkadang',
#   'masuk',
#   'fitur',
#   'siram',
#   'tanam',
#   'lngsng',
#   'freeze',
#   'baru',
#   'restart',
#   'ulang',
#   'handphone',
#   'khawarir',
#   'rebout',
#   'handphone',
#   'tolong',
#   'lagi',
#   'memori',
#   'masih',
#   'seger',
#   'ram',
#   'juga',
#   'masih',
#   'sisa',
#   'gb',
#   'lbh',
#   'gb',
#   'handphone',
#   'juga',
#   'bukan',
#   'kentang',
#   'aplikasi',
#   'berat',
#   'fitur',
#   'selalu',
#   'lin'],
#  ['aplikasi', 'gun', 'tipu'],
#  ['belanja',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'extra',
#   'susah',
#   'check',
#   'out',
#   'bolak'],
#  ['syah', 'bayar', 'expres'],
#  ['jelekkk',
#   'main',
#   'game',
#   'minecrft',
#   'nama',
#   'survival',
#   'na',
#   'muncul',
#   'ikkelan',
#   'pencet',
#   'skip',
#   'mati',
#   'iiih',
#   'jelekk'],
#  ['bug', 'bnerin'],
#  ['shope', 'gimmick', 'flashsale', 'iphone', 'kirim', 'batal', 'hahaha'],
#  ['beres',
#   'aplikasi',
#   'unduh',
#   'aplikasi',
#   'ken',
#   'coba',
#   'belanja',
#   'kayak',
#   'ny',
#   'checkout',
#   'payung',
#   'harga',
#   'ongkir',
#   'akal',
#   'tanggerang',
#   'jambi',
#   'ongkir',
#   'rp',
#   'benar',
#   'harga',
#   'payung'],
#  ['team',
#   'buka',
#   'lapak',
#   'becus',
#   'cie',
#   'nanganin',
#   'custamer',
#   'transaksi',
#   'tanggal',
#   'nov',
# ...
#  ['minggu', 'barng', 'terima', 'uang', 'komplain', 'tutup', 'tnpa'],
#  ['belum',
#   'tanggap',
#   'beli',
#   'pulsa',
#   'kedaluwarsa',
#   'bayar',
#   'status',
#   'kadaluwarsa',
#   'baru',
#   'bayar',
#   'terima',
#   'kasih'],
#  ['belanja', 'tipu', 'lebih baik', 'uninstal'],
#  ['berbsngga', 'hati', 'samsung'],
#  ['kasih', 'sampai'],
#  ['adminlu',
#   'naekin',
#   'presentase',
#   'cashback',
#   'diturunin',
#   'naekin',
#   'tolong',
#   'dinaekkn',
#   'merger',
#   'suramm'],
#  ['aplikasi',
#   'anjig',
#   'pdahal',
#   'install',
#   'promo',
#   'batal',
#   'sen',
#   'voucher',
#   'ongkir',
#   'hilang',
#   'tlol'],
#  ['aplikasi',
#   'produk',
#   'sesuai',
#   'pesan',
#   'sayang',
#   'ongkir',
#   'mahal',
#   'diskon',
#   'voucer',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'mengambil',
#   'ribu'],
#  ['promo',
#   'mancing',
#   'awam',
#   'pengaruh',
#   'promo',
#   'fitur',
#   'aplikasi',
#   'kaku',
#   'saldo',
#   'dipake',
#   'bayar',
#   'ambil',
#   'lebih baik'],
#  ['gratis',
#   'ongkir',
#   'dwnlod',
#   'pesan',
#   'barang',
#   'langgan',
#   'knk',
#   'cas',
#   'ribu',
#   'ongkir',
#   'kelimapuluh',
#   'kabupaten',
#   'batubara',
#   'harga',
#   'mahal',
#   'bnding',
#   'murah',
#   'ongkir',
#   'cmn',
#   'ribu',
#   'gratis',
#   'ongkir',
#   'pulau',
#   'jawa',
#   'kesumut',
#   'ribu',
#   'gilaaak',
#   'klen',
#   'seperti',
#   'gmn',
#   'banyak',
#   'plnggnnya',
#   'blnj',
#   'berat',
#   'diongkir',
#   'hrg',
#   'mahal',
#   'banding',
#   'aplikasi',
#   'ttngga'],
#  ['keluarin', 'iklan', 'boss', 'kesel', 'iklan', 'nyaman'],
#  ['up', 'kemarin', 'indomart', 'sukses', 'saldo'],
#  ['aplikasi',
#   'commerce',
#   'bikin',
#   'bingung',
#   'masukkan',
#   'nomor',
#   'rekening',
#   'susah'],
#  ['sinyal', 'butuh'],
#  ['maaf',
#   'bri',
#   'bintang',
#   'ea',
#   'nnti',
#   'klau',
#   'brng',
#   'smpai',
#   'baru',
#   'ksih',
#   'bintang',
#   'lagi'],
#  ['lambat', 'downloadnya'],
#  ['organisasi', 'birokrasi'],
#  ['gin',
#   'dowanload',
#   'lagu',
#   'chrome',
#   'ngapain',
#   'unduh',
#   'bilang',
#   'macam',
#   'macam',
#   'poromo',
#   'case',
#   'back',
#   'bikin',
#   'repot',
#   'perasaandah'],
#  ['iklan', 'ganggu', 'tolong', 'jangan', 'iklan', 'sembarang'],
#  ['beli',
#   'bayar',
#   'batal',
#   'promo',
#   'promo',
#   'sisa',
#   'promo',
#   'batal',
#   'transaksi',
#   'kupon',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'ribu',
#   'kupon',
#   'cashback',
#   'ribu',
#   'hilang',
#   'pagi',
#   'sisa',
#   'aju',
#   'care',
#   'balas',
#   'sesuai',
#   'prosedur',
#   'langgar',
#   'tolong'],
#  ['lapak', 'barang', 'siap', 'order', 'kirim', 'kirim', 'batal', 'konfirmasi'],
#  ['takut', 'jahat', 'ngrim', 'alamat'],
#  ['tmpat', 'tinggal', 'camat', 'grong', 'kabupaten', 'pidie', 'kota', 'sigli'],
#  ['tutup', 'akun', 'tanda', 'sistem', 'shoppe', 'kualitas'],
#  ['gratis',
#   'ongkir',
#   'pakai',
#   'sekal',
#   'cari',
#   'toko',
#   'label',
#   'gratis',
#   'ongkir',
#   'toko',
#   'barang',
#   'cari',
#   'pakai',
#   'toko',
#   'kacau',
#   'tolong'],
#  ['lot', 'bnget', 'bayar', 'susah', 'kesini', 'mkin', 'mles', 'lot'],
#  ['lma',
#   'lot',
#   'sebentar',
#   'logout',
#   'sendiri',
#   'pdhal',
#   'ram',
#   'msih',
#   'nyukup',
#   'ntah',
#   'berat',
#   'game',
#   'ny',
#   'tolong'],
#  ['unduh', 'komplen'],
#  ['aplikasi', 'eror', 'terus', 'pdhl', 'update', 'pke', 'pers', 'tetep'],
#  ['budug', 'rehan'],
#  ['gratis', 'ongkir'],
#  ['mola',
#   'minggu',
#   'malam',
#   'kirim',
#   'hadiah',
#   'menang',
#   'nga',
#   'nyampe',
#   'coi',
#   'hadiah',
#   'palsu'],
#  ['barang', 'sesuai'],
#  ['klu',
#   'setock',
#   'barang',
#   'jangan',
#   'pajang',
#   'pajang',
#   'gambar',
#   'pesan',
#   'baju',
#   'batas',
#   'proses',
#   'proses',
#   'potong',
#   'biayamah',
#   'cepat',
#   'kirim',
#   'susah',
#   'puayah'],
#  ['notifikasi', 'kirim', 'cepat', 'fakta', 'kaya', 'bulus', 'lot', 'estimasi'],
#  ['jual',
#   'amanah',
#   'aplikasi',
#   'proses',
#   'barang',
#   'salah',
#   'kirim',
#   'sulit',
#   'seler',
#   'amanah',
#   'tindak',
#   'sebenernya',
#   'rugi',
#   'aplikasi',
#   'customer',
#   'alih',
#   'aplikasi',
#   'lbh',
#   'amanah',
#   'lbh',
#   'mudah',
#   'proses',
#   'pengembalaian',
#   'barang'],
#  ['game', 'jual', 'ayig'],
#  ['toko', 'handal'],
#  ['tolong',
#   'bantu',
#   'foto',
#   'jual',
#   'ratus',
#   'muncul',
#   'tarik',
#   'pelang',
#   'barang',
#   'gudang',
#   'muncul',
#   'pantas',
#   'jual',
#   'terus'],
#  ['aplikasi',
#   'sihh',
#   'kmarin',
#   'apdet',
#   'isi',
#   'saldo',
#   'ribu',
#   'suruh',
#   'ngapdet',
#   'apdet',
#   'kok',
#   'uang',
#   'koin',
#   'koinya',
#   'hilang',
#   'rugi',
#   'dongg',
#   'erti'],
#  ['update',
#   'asa',
#   'gratis',
#   'ongkir',
#   'update',
#   'layar',
#   'putih',
#   'gambar',
#   'gapernah',
#   'gratis',
#   'ongkir',
#   'cod',
#   'why'],
#  ['tipu',
#   'promo',
#   'flash',
#   'sale',
#   'ken',
#   'hapus',
#   'aplikasi',
#   'standby',
#   'sblm',
#   'pkl',
#   'pesan',
#   'stock',
#   'habis',
#   'terang',
#   'jual',
#   'stock',
#   'kosong',
#   'jam',
#   'saran',
#   'klu',
#   'masih',
#   'banyak',
#   'tipu',
#   'promo',
#   'sesuai'],
#  ['update',
#   'bayar',
#   'chat',
#   'customer service',
#   'hang',
#   'restart',
#   'aplikasi'],
#  ['berat',
#   'aplikasi',
#   'respon',
#   'pencet',
#   'berat',
#   'beda',
#   'ringan',
#   'smooth'],
#  ['ongkir',
#   'mahal',
#   'brooo',
#   'hadeuh',
#   'hadeuh',
#   'ganti',
#   'opsi',
#   'kurir',
#   'harga',
#   'up',
#   'up',
#   'mahal',
#   'customer service',
#   'bot',
#   'mlu',
#   'jwbannya',
#   'ktnya',
#   'unicorn',
#   'customer service',
#   'bot'],
#  ['virus', 'iklan', 'handphone', 'eror'],
#  ['aplikasi',
#   'bela',
#   'seller',
#   'beli',
#   'please',
#   'be',
#   'careful',
#   'skripsi',
#   'sesat',
#   'seller',
#   'utama',
#   'dropship',
#   'seller',
#   'modal'],
#  ['chekout',
#   'pin',
#   'salah',
#   'pdhl',
#   'benar',
#   'sampai',
#   'blokir',
#   'tolong',
#   'gimanain'],
#  ['haraga', 'barang', 'beli'],
#  ['toko', 'tanggung', 'kirim', 'barang', 'sesuai', 'pesan', 'barang'],
#  ['kemarin',
#   'aktif',
#   'kredit',
#   'isi',
#   'data',
#   'data',
#   'hapus',
#   'nama',
#   'tika',
#   'aprilia',
#   'triyanto',
#   'kredit',
#   'handphone',
#   'counter',
#   'bantu',
#   'hapus',
#   'data'],
#  ['tipu', 'barang', 'sesuai', 'tokony', 'bawa', 'rezeky', 'usaha', 'tipu'],
#  ['beli', 'pulsa', 'refund', 'melulu', 'anjimmm', 'kaya'],
#  ['unduh', 'tunggu', 'hati', 'riang', 'gembira', 'tbtb', 'gagal'],
#  ['aplikasi', 'jelekk', 'login', 'pke', 'verifikasi', 'wajah', 'upgrade'],
#  ['aplikasi',
#   'hancur',
#   'ran',
#   'ribet',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'dasar'],
#  ['verrsi',
#   'android',
#   'hambat',
#   'tunanetra',
#   'menu',
#   'food',
#   'akses',
#   'searching',
#   'lokasi',
#   'resto',
#   'menu',
#   'keranjang',
#   'tulis',
#   'salah',
#   'tindak'],
#  ['lindung',
#   'garansi',
#   'bintang',
#   'bicara',
#   'tim',
#   'jual',
#   'jual',
#   'amanah',
#   'jual',
#   'jujur',
#   'tim',
#   'bantuin',
#   'keluh',
#   'mbelinya'],
#  ['jasa', 'kirim', 'sedia'],
#  ['scar', 'tri'],
#  ['engga',
#   'up',
#   'logika',
#   'up',
#   'akun',
#   'ngendap',
#   'bank',
#   'konvensional',
#   'tranfer',
#   'ganggu',
#   'jam',
#   'kelas',
#   'bank',
#   'aplikasi',
#   'urus',
#   'up',
#   'engga',
#   'tunggu'],
#  ['kasih', 'bintang', 'pakek', 'amplikasi', 'iklan', 'muncul', 'handphone'],
#  ['baru',
#   'pakai',
#   'order',
#   'ngecewain',
#   'batal',
#   'jasa',
#   'kirim',
#   'baru',
#   'tahu',
#   'js',
#   'pgriman',
#   'batal',
#   'kirim',
#   'jam',
#   'bareng',
#   'kirim',
#   'alamat',
#   'jm',
#   'sore',
#   'untuk',
#   'siapkn',
#   'uang',
#   'sstm',
#   'bayar',
#   'ttpi',
#   'jm',
#   'mlm',
#   'pmbritahuan',
#   'bareng',
#   'gagal',
#   'kirim',
#   'curiga',
#   'psnan',
#   'mysteri',
#   'box',
#   'nominal',
#   'paham',
#   'kan',
#   'kcurigaan',
#   'aneh',
#   'jsa',
#   'pgirimannya',
#   'sam',
#   'lx',
#   'tlglah',
#   'lbh',
#   'selektif',
#   'dlm',
#   'pilih',
#   'jasa',
#   'kirim',
#   'amatir',
#   'model',
#   'gtu'],
#  ['cod', 'toko', 'tipu', 'hadeeeee'],
#  ['unduh', 'lagu'],
#  ['aplikasi',
#   'browsing',
#   'tonton',
#   'drakor',
#   'ehh',
#   'suruh',
#   'unduh',
#   'aplikasi',
#   'aplikasi'],
#  ['iklan', 'anjim'],
#  ['aplikasi', 'tipu'],
#  ['semerawut',
#   'sen',
#   'bareng',
#   'tunggu',
#   'dibatalin',
#   'lagi',
#   'sellernya',
#   'kapok',
#   'blja',
#   'dsni',
#   'beli',
#   'sepele',
#   'uninstall',
#   'az',
#   'puzink'],
#  ['beli',
#   'platihan',
#   'status',
#   'transaksi',
#   'batal',
#   'status',
#   'platihan',
#   'aktif',
#   'terima',
#   'voucher',
#   'pltihan',
#   'beli',
#   'hambat',
#   'beli',
#   'platihan',
#   'aktif',
#   'email',
#   'pusat',
#   'bantu',
#   'refand',
#   'ribet',
#   'hambat',
#   'karir'],
#  ['aplikasi',
#   'cekout',
#   'rupiah',
#   'pas',
#   'cek',
#   'out',
#   'batal',
#   'coba',
#   'ganti',
#   'nomer',
#   'batal',
#   'donlut',
#   'aplikasi',
#   'males',
#   'php',
#   'kaya',
#   'toko',
#   'pilih',
#   'barang',
#   'rupiah',
#   'batal'],
#  ['anteraja', 'dipake', 'laaah', 'bikin', 'layan'],
#  ['promo',
#   'pakai',
#   'coin',
#   'dahh',
#   'benar',
#   'promo',
#   'potong',
#   'ongkir',
#   'pakai',
#   'pakai',
#   'point',
#   'evektif'],
#  ['susah',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'online',
#   'tarik',
#   'murah',
#   'ongkir'],
#  ['pakai', 'trsnsaksi'],
#  ['kirim', 'kuno', 'instan'],
#  ['update', 'mennggapi'],
#  ['bintang',
#   'rena',
#   'install',
#   'ulang',
#   'sampai',
#   'akun',
#   'hapus',
#   'pindah',
#   'pakai',
#   'aplikasi',
#   'ribet'],
#  ['akun',
#   'shoppe',
#   'login',
#   'costumer',
#   'service',
#   'tolong',
#   'bantu',
#   'bayar',
#   'shoppepaylatter'],
#  ['aowkwowkwok', 'aplikasi', 'mandang', 'handphone'],
#  ['aneh', 'pesan', 'barang', 'nama', 'kirim'],
#  ['ganggu', 'link', 'unduh'],
#  ['tipu',
#   'toko',
#   'nakal',
#   'kirim',
#   'barang',
#   'cod',
#   'pesan',
#   'barang',
#   'filter',
#   'tipu'],
#  ['aplikasi', 'prank', 'konten'],
#  ['barang',
#   'dikirm',
#   'nggk',
#   'sesuai',
#   'mau',
#   'barang',
#   'proses',
#   'ribet',
#   'banding',
#   'toko',
#   'online',
#   'belah',
#   'nggk',
#   'kaya',
#   'gin'],
#  ['iklan', 'mental', 'play', 'toko'],
#  ['sampai',
#   'sertifikat',
#   'bom',
#   'muncul',
#   'dasbor',
#   'prakerjaaaaaaaa',
#   'tolong',
#   'cepat'],
#  ['sore',
#   'aplikasi',
#   'burik',
#   'loading',
#   'gagal',
#   'muat',
#   'pdahal',
#   'jaringal'],
#  ['bikin', 'promo', 'diskon', 'gilir', 'dipake', 'anggap', 'menyalaho'],
#  ['aplikasi', 'sen', 'paket', 'hancur', 'kirim', 'hancurrrrrrr'],
#  ['pilih', 'jasa', 'kirim', 'sinyal'],
#  ['aneh', 'dh', 'diupdate', 'ttp', 'ilangin', 'ganggu'],
#  ['bisa', 'downlod'],
#  ['woyy',
#   'bangke',
#   'cari',
#   'lot',
#   'bangkee',
#   'update',
#   'aplikasi',
#   'sinyal',
#   'tahi',
#   'laah'],
#  ['ngadain',
#   'cashback',
#   'cashback',
#   'jarang',
#   'aplikasi',
#   'tembah',
#   'lot',
#   'mitra',
#   'curang',
#   'males',
#   'beli',
#   'belanja',
#   'pakai',
#   'pindah',
#   'toko'],
#  ['tolong', 'tolong', 'up', 'snack', 'vidio', 'uang'],
#  ['kecewaaa',
#   'bangett',
#   'sntadar',
#   'ekpress',
#   'kirim',
#   'bangett',
#   'banding',
#   'kirim',
#   'reguler',
#   'lai',
#   'lebih baik',
#   'ituu',
#   'hedhhh'],
#  ['live', 'chat', 'susah'],
#  ['tolong', 'bantu', 'saldo', 'hubung', 'dana'],
#  ['ribet',
#   'dipake',
#   'lockout',
#   'verivikasi',
#   'belibet',
#   'muter',
#   'auto',
#   'un',
#   'install',
#   'ao',
#   'gin'],
#  ['aplikasi',
#   'pngiriman',
#   'bnyak',
#   'pnjual',
#   'jelassss',
#   'paket',
#   'dateng',
#   'lgsung',
#   'uinstal',
#   'bkal',
#   'dowlnd',
#   'lh'],
#  ['aplikasi',
#   'tipu',
#   'sen',
#   'box',
#   'dateng',
#   'cincin',
#   'harga',
#   'ribu',
#   'pantau',
#   'toko',
#   'toko',
#   'amanah',
#   'korban',
#   'aplikasi'],
#  ['baca',
#   'editor',
#   'notice',
#   'kasih',
#   'bintang',
#   'cuman',
#   'saran',
#   'letak',
#   'gambar',
#   'produk',
#   'sejajar',
#   'judul',
#   'produk',
#   'tulis',
#   'kecilin',
#   'mudah',
#   'gambar',
#   'contolah',
#   'akun',
#   'shope',
#   'belah',
#   'gambar',
#   'iklan',
#   'nyaingin',
#   'toko',
#   'belah',
#   'fitur',
#   'tampil',
#   'tarik',
#   'toko',
#   'belah',
#   'notice',
#   'baca'],
#  ['kurir',
#   'alamat',
#   'tera',
#   'cantum',
#   'terima',
#   'nama',
#   'orang',
#   'belanja',
#   'setelah',
#   'komplain',
#   'tuntas',
#   'tutup',
#   'beli',
#   'rugi',
#   'barang',
#   'hilang'],
#  ['sayang',
#   'pesan',
#   'rupiah',
#   'beli',
#   'eror',
#   'bilang',
#   'pesan',
#   'sdngkan',
#   'dengn',
#   'bareng',
#   'kecewaa'],
#  ['gratis', 'ongkir', 'kya'],
#  ['tulis', 'kolom', 'cari', 'eror'],
#  ['tolong',
#   'benah',
#   'kurir',
#   'shoope',
#   'express',
#   'pesan',
#   'hold',
#   'jarak',
#   'kirim',
#   'lokasi',
#   'kirim'],
#  ['chat', 'eror', 'connect', 'jaring'],
#  ['mengisi', 'shopay', 'saldo', 'atm', 'duit'],
#  ['verivikasi', 'bikin', 'ribet'],
#  ['dear',
#   'mimin',
#   'kendala',
#   'checkout',
#   'checkout',
#   'pesan',
#   'checkout',
#   'gagal',
#   'risih',
#   'pesan',
#   'pesan',
#   'otomatis',
#   'checkout',
#   'pesan',
#   'harga',
#   'barang',
#   'beli',
#   'sesuai',
#   'voucher',
#   'voucher',
#   'tolong',
#   'mimin',
#   'mudah',
#   'checkout',
#   'tolong',
#   'checkout',
#   'gagal'],
#  ['belanja', 'kli', 'isi', 'pakrtnya', 'bodoh'],
#  ['iklan', 'spam', 'google', 'nonton', 'film', 'skip', 'heran'],
#  ['belanja',
#   'bayar',
#   'alfa',
#   'indomaret',
#   'barang',
#   'cod',
#   'malas',
#   'pakai',
#   'aplikasi',
#   'tolong',
#   'informasi'],
#  ['bintang', 'pilih', 'kurir', 'besok', 'tunggu', 'kurir', 'lamban'],
#  ['mantaaaa', 'belanja', 'tipu', 'belanja', 'pesan', 'sesuai', 'terima'],
#  ['sampah', 'selalu', 'ganggu'],
#  ['aplikasi', 'serius'],
#  ['mahal', 'ongkir', 'beli', 'kirim', 'hadehhh', 'gaze'],
#  ['commerce',
#   'gajelas',
#   'pakai',
#   'voucher',
#   'promo',
#   'dipake',
#   'pas',
#   'dipake',
#   'transaksi',
#   'batal',
#   'otomatis',
#   'transaksi',
#   'akun',
#   'tahu',
#   'akun',
#   'bertanya',
#   'costumer',
#   'service',
#   'kasih',
#   'solusi'],
#  ['aplikasi',
#   'aman',
#   'hubung',
#   'akun',
#   'informasi',
#   'kartu',
#   'kredit',
#   'link',
#   'fintech',
#   'otp',
#   'login',
#   'perangkat',
#   'pin',
#   'transaksi',
#   'fintech',
#   'retas',
#   'alami',
#   'sendir',
#   'akun',
#   'retas',
#   'topup',
#   'money',
#   'koneksi',
#   'akun',
#   'bertanggungjawab',
#   'rubah',
#   'pin',
#   'password',
#   'rutin',
#   'hubung',
#   'bayar'],
#  ['donlod', 'chekout', 'aneh'],
#  ['pliss',
#   'data',
#   'cur',
#   'ganti',
#   'rugi',
#   'jt',
#   'lapor',
#   'shoppe',
#   'polisi',
#   'titik'],
#  ['benar',
#   'order',
#   'proses',
#   'kirim',
#   'kasih',
#   'toleransi',
#   'jual',
#   'kirim',
#   'recommended',
#   'order',
#   'kuciwa'],
#  ['bayar', 'cok'],
#  ['aduhh',
#   'maaf',
#   'isi',
#   'alamat',
#   'kecamatan',
#   'kota',
#   'salah',
#   'pdhal',
#   'ulang',
#   'ulang'],
#  ['menu',
#   'utama',
#   'mesti',
#   'pencet',
#   'salah',
#   'gimna',
#   'sen',
#   'haduh',
#   'makane',
#   'sebel',
#   'pakai',
#   'shoopee',
#   'gin',
#   'tolong',
#   'bantu',
#   'dibenerin',
#   'gimna'],
#  ['barang', 'bnyak', 'sesuai', 'kirim'],
#  ['gimn', 'belanja', 'sistem', 'cod'],
#  ['toko', 'tipu', 'tolong', 'banned', 'toko', 'tipu', 'periksa', 'lagiiiii'],
#  ['daftar', 'akun', 'sulit', 'mnding', 'toko', 'belah'],
#  ['tolong',
#   'aplikasi',
#   'beli',
#   'kouta',
#   'aplikasi',
#   'tapi',
#   'buka',
#   'ny',
#   'aplikasi'],
#  ['pakai', 'pakai', 'voucher'],
#  ['bayar', 'link', 'enggk'],
#  ['daftar', 'ngabis', 'kuota'],
#  ['aplikasi', 'lot'],
#  ['pesan', 'sini', 'pesn', 'sini', 'barang', 'proses', 'bayar', 'hadeeeeee'],
#  ['suruh',
#   'kritik',
#   'keritik',
#   'ber',
#   'diam',
#   'ubah',
#   'kirim',
#   'lempar',
#   'xpres',
#   'lot',
#   'sap',
#   'expres',
#   'bangke',
#   'benar',
#   'kirim',
#   'area',
#   'jawa',
#   'makan',
#   'full'],
#  ['buka', 'gambar', 'ampas'],
#  ['maaf',
#   'masak',
#   'muncul',
#   'detik',
#   'muncul',
#   'detik',
#   'muncul',
#   'tolong',
#   'menit',
#   'seperti',
#   'menit',
#   'tibul',
#   'timbul',
#   'jengkel',
#   'cek',
#   'maaf',
#   'hoak'],
#  ['tolong',
#   'iklan',
#   'menggangu',
#   'nyaman',
#   'jelajah',
#   'internet',
#   'hapus',
#   'aplikasi',
#   'ganggu'],
#  ['unduh', 'aplikasi', 'tipu'],
#  ['beri',
#   'rating',
#   'tanggung',
#   'dsb',
#   'kerjain',
#   'nyuruh',
#   'hubung',
#   'hubung',
#   'puter',
#   'puter',
#   'lagi',
#   'orang',
#   'beri',
#   'kritik',
#   'ketidakpuasan',
#   'cepat',
#   'tanganin',
#   'nyuruh',
#   'hubung',
#   'gambar',
#   'tampil',
#   'pending',
#   'bingung',
#   'internet',
#   'pasang',
#   'gb',
#   'handphone',
#   'redmi',
#   'note',
#   'apalalagi',
#   'salah'],
#  ['install', 'aplikasi', 'hadiah', 'jangan', 'bohong', 'aje'],
#  ['tawarin',
#   'rupiah',
#   'pas',
#   'cek',
#   'tetep',
#   'beli',
#   'mahal',
#   'aplikasi',
#   'shopy'],
#  ['terlambat',
#   'bayar',
#   'shopeepaylater',
#   'tlponin',
#   'puluh',
#   'kayak',
#   'hutang',
#   'puluh',
#   'juta',
#   'ngk',
#   'bayar',
#   'bom',
#   'gaji',
#   'gaji',
#   'undur',
#   'nelponin',
#   'ngk',
#   'paut',
#   'tunggak',
#   'bayar',
#   'kasi',
#   'teman',
#   'diganguin',
#   'melulu',
#   'kayak',
#   'teror',
#   'ganggu',
#   'tolong',
#   'baca',
#   'tolong',
#   'erti'],
#  ['tari',
#   'saldo',
#   'even',
#   'bayar',
#   'kumpulun',
#   'kawan',
#   'susah',
#   'tolong',
#   'ikan'],
#  ['cod', 'cash', 'or', 'duel'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (5, 6):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha=[0.01]*k, eta=[0.01]*len(dictionary.keys()))
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(1, 0.9804878)]
# [(2, 0.98688525)]
# [(1, 0.9920792)]
# [(3, 0.44692558), (4, 0.5471338)]
# [(1, 0.78513676), (4, 0.20892262)]
# [(3, 0.9804878)]
# [(0, 0.25725055), (1, 0.34078473), (3, 0.23911569), (4, 0.16174401)]
# [(1, 0.35982862), (3, 0.63033533)]
# [(2, 0.9619048)]
# [(3, 0.99012345)]
# [(3, 0.9804878)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.98688525)]
# [(2, 0.4441846), (4, 0.5498748)]
# [(4, 0.98688525)]
# [(0, 0.2493827), (1, 0.46949235), (2, 0.27618665)]
# [(1, 0.7940594), (2, 0.19999999)]
# [(0, 0.13681272), (3, 0.18530808), (4, 0.6756693)]
# [(1, 0.2851064), (3, 0.5547844), (4, 0.15727231)]
# [(1, 0.5194417), (3, 0.47461763)]
# [(1, 0.9619048)]
# [(0, 0.9619048)]
# [(1, 0.09096867), (2, 0.31790546), (3, 0.58946615)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(1, 0.99012345)]
# [(1, 0.68923557), (2, 0.10631892), (4, 0.20245548)]
# [(1, 0.6863748), (2, 0.17231642), (4, 0.13882434)]
# [(1, 0.9619048)]
# [(0, 0.14673822), (1, 0.5512184), (2, 0.14839166), (3, 0.15223329)]
# [(0, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.9619048)]
# [(0, 0.74320984), (3, 0.2493827)]
# [(2, 0.9804878)]
# [(1, 0.45024192), (3, 0.539922)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(1, 0.43609568), (2, 0.27414182), (3, 0.2848242)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.5195037), (3, 0.47455567)]
# [(0, 0.98688525)]
# [(0, 0.49629626), (3, 0.49629626)]
# [(0, 0.5851255), (3, 0.41114774)]
# [(1, 0.08896625), (2, 0.30203244), (3, 0.6073415)]
# [(0, 0.16694213), (1, 0.42843258), (2, 0.22691716), (4, 0.1760552)]
# [(1, 0.98688525)]
# [(0, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.12546584), (1, 0.49813667), (2, 0.12546584), (3, 0.24968943)]
# [(2, 0.9619048)]
# [(3, 0.9619048)]
# [(0, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.15140839), (3, 0.6972613), (4, 0.1491204)]
# [(3, 0.98688525)]
# [(2, 0.2493827), (3, 0.74320984)]
# [(0, 0.0892698), (1, 0.07109153), (2, 0.24282356), (3, 0.08480411), (4, 0.512011)]
# [(4, 0.9619048)]
# [(0, 0.5960396), (1, 0.3980198)]
# [(0, 0.19999999), (1, 0.47798952), (3, 0.31805006)]
# [(2, 0.49268287), (4, 0.49268293)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.5343564), (1, 0.09587037), (2, 0.24250554), (3, 0.1266447)]
# [(4, 0.9920792)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.98688525)]
# [(4, 0.9619048)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.7106383), (1, 0.2851064)]
# [(1, 0.9619048)]
# [(0, 0.23531912), (1, 0.20426524), (3, 0.5588831)]
# [(0, 0.16694215), (1, 0.6268617), (3, 0.20289038)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.9619048)]
# [(3, 0.99432623)]
# [(4, 0.98688525)]
# [(2, 0.20285213), (3, 0.24209446), (4, 0.552569)]
# [(4, 0.9804878)]
# [(2, 0.41891208), (3, 0.24968943), (4, 0.32891396)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(2, 0.3980198), (4, 0.5960396)]
# [(1, 0.9619048)]
# [(0, 0.14596094), (1, 0.36989605), (3, 0.3509843), (4, 0.13191643)]
# [(1, 0.99012345)]
# [(3, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9920792)]
# [(2, 0.98688525)]
# [(0, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.5530885), (1, 0.44392645)]
# [(2, 0.9619048)]
# [(1, 0.15745051), (2, 0.15076429), (3, 0.5497066), (4, 0.14152466)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.99012345)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.49629626), (2, 0.2493827), (4, 0.2493827)]
# [(2, 0.52207726), (3, 0.47366735)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.98688525)]
# [(3, 0.99432623)]
# [(4, 0.9619048)]
# [(0, 0.3980198), (1, 0.3980198), (4, 0.19999999)]
# [(0, 0.21553963), (1, 0.24997593), (2, 0.20060013), (3, 0.3322314)]
# [(0, 0.14326242), (1, 0.5286304), (3, 0.32527035)]
# [(0, 0.29908657), (1, 0.24938273), (2, 0.44659242)]
# [(3, 0.4008058), (4, 0.59587926)]
# [(1, 0.9804878)]
# [(2, 0.7290295), (3, 0.2635631)]
# [(0, 0.2493827), (1, 0.2493827), (3, 0.49629626)]
# [(0, 0.5330016), (2, 0.45716232)]
# [(3, 0.98688525)]
# [(0, 0.07380116), (1, 0.09372467), (4, 0.8310507)]
# [(0, 0.65901643), (1, 0.33114755)]
# [(2, 0.9804878)]
# [(0, 0.5214407), (3, 0.4639252)]
# [(1, 0.16694215), (2, 0.19709638), (3, 0.43599486), (4, 0.19831374)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(0, 0.9619048)]
# [(0, 0.5960396), (2, 0.3980198)]
# [(0, 0.2), (2, 0.5243642), (3, 0.2716754)]
# [(3, 0.98688525)]
# [(4, 0.9619048)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.30493802), (3, 0.46828464), (4, 0.22394048)]
# [(2, 0.7084302), (3, 0.28562927)]
# [(0, 0.9804878)]
# [(1, 0.9619048)]
# [(4, 0.98688525)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(4, 0.99012345)]
# [(2, 0.58725953), (4, 0.4029044)]
# [(2, 0.9804878)]
# [(3, 0.9804878)]
# [(3, 0.9619048)]
# [(2, 0.14326242), (3, 0.34893328), (4, 0.50496745)]
# [(3, 0.779631), (4, 0.21541028)]
# [(4, 0.98688525)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.65901643), (4, 0.33114755)]
# [(3, 0.45590183), (4, 0.5381575)]
# [(4, 0.9804878)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(0, 0.9804878)]
# [(2, 0.98688525)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.19999999), (3, 0.7940594)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(2, 0.98688525)]
# [(2, 0.15849835), (3, 0.45783573), (4, 0.3820062)]
# [(1, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.3980198), (4, 0.5960396)]
# [(0, 0.3980198), (4, 0.59603965)]
# [(2, 0.9619048)]
# [(1, 0.9804878)]
# [(0, 0.9804878)]
# [(0, 0.41177413), (1, 0.31010973), (3, 0.27686995)]
# [(4, 0.98688525)]
# [(0, 0.12546584), (1, 0.5075963), (4, 0.36445335)]
# [(2, 0.25418195), (3, 0.7408594)]
# [(1, 0.19898075), (2, 0.79830426)]
# [(1, 0.1431815), (3, 0.75712657), (4, 0.09748202)]
# [(0, 0.39286172), (1, 0.2851064), (2, 0.16525468), (4, 0.15535876)]
# [(0, 0.36376086), (2, 0.15569302), (3, 0.4777092)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.98688525)]
# [(1, 0.5329861), (2, 0.46107325)]
# [(3, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.5341424), (2, 0.45602152)]
# [(3, 0.6270631), (4, 0.36699623)]
# [(2, 0.5413838), (4, 0.4526756)]
# [(3, 0.9804878)]
# [(0, 0.43844), (3, 0.2898296), (4, 0.2692459)]
# [(0, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.33578542), (2, 0.6568071)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.1826849), (2, 0.5488636), (3, 0.2669189)]
# [(0, 0.27789402), (1, 0.032890208), (2, 0.10656308), (3, 0.58233064)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.2851064), (3, 0.5472469), (4, 0.16480985)]
# [(4, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(1, 0.9619048)]
# [(0, 0.342873), (1, 0.15763986), (2, 0.32798794), (3, 0.17008075)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(0, 0.12546586), (3, 0.5370233), (4, 0.3350264)]
# [(3, 0.26909783), (4, 0.7271754)]
# [(2, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.6166675), (4, 0.37349644)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114752), (2, 0.65901643)]
# [(2, 0.98688525)]
# [(3, 0.9920792)]
# [(3, 0.9804878)]
# [(3, 0.98688525)]
# [(2, 0.9619048)]
# [(3, 0.9300982), (4, 0.0684055)]
# [(1, 0.44887987), (4, 0.54371274)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.3980198), (3, 0.5960396)]
# [(1, 0.2500212), (3, 0.74403816)]
# [(2, 0.51694655), (3, 0.47879812)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(2, 0.98688525)]
# [(1, 0.98688525)]
# [(2, 0.9804878)]
# [(3, 0.98688525)]
# [(1, 0.62226063), (4, 0.3679033)]
# [(4, 0.9804878)]
# [(3, 0.3565947), (4, 0.63356924)]
# [(3, 0.99012345)]
# [(1, 0.9619048)]
# [(4, 0.9804878)]
# [(3, 0.98688525)]
# [(1, 0.3556511), (3, 0.22327311), (4, 0.41711536)]
# [(1, 0.19999999), (3, 0.5641438), (4, 0.23189582)]
# [(3, 0.66552913), (4, 0.32853025)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.22442122), (4, 0.7722638)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(1, 0.98688525)]
# [(2, 0.62638324), (3, 0.36378068)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(4, 0.98688525)]
# [(4, 0.9933884)]
# [(2, 0.2493827), (4, 0.74320984)]
# [(2, 0.62523127), (3, 0.3649327)]
# [(3, 0.49752066), (4, 0.49752066)]
# [(0, 0.18958342), (2, 0.4086166), (3, 0.2640987), (4, 0.136459)]
# [(4, 0.9619048)]
# [(0, 0.13003504), (1, 0.19265099), (2, 0.17424817), (3, 0.39296785), (4, 0.11009797)]
# [(3, 0.9804878)]
# [(2, 0.78606594), (3, 0.20799346)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.4408735), (4, 0.5541678)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(1, 0.30131027), (3, 0.34877756), (4, 0.34707528)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.6198624), (3, 0.37517893)]
# [(0, 0.24968943), (1, 0.24968943), (2, 0.12546584), (3, 0.24968943), (4, 0.12546584)]
# [(1, 0.2652897), (2, 0.14238642), (3, 0.58983946)]
# [(4, 0.9804878)]
# [(0, 0.9804878)]
# [(1, 0.49893337), (2, 0.49123058)]
# [(4, 0.9619048)]
# [(1, 0.5451677), (3, 0.4449963)]
# [(0, 0.84735715), (3, 0.14838758)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.531478), (1, 0.19802965), (3, 0.2680079)]
# [(1, 0.64528185), (4, 0.34488204)]
# [(2, 0.2765769), (4, 0.71748245)]
# [(1, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(0, 0.33114755), (1, 0.33114755), (4, 0.33114755)]
# [(1, 0.0992022), (3, 0.89808285)]
# [(0, 0.47208872), (3, 0.5132772)]
# [(1, 0.9804878)]
# [(2, 0.16694213), (3, 0.8280992)]
# [(0, 0.3801218), (1, 0.61491954)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.70500547), (4, 0.2875871)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2493827), (2, 0.2493827), (4, 0.49629626)]
# [(2, 0.6259204), (4, 0.3698243)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(3, 0.9804878)]
# [(2, 0.99012345)]
# [(2, 0.98688525)]
# [(4, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.99432623)]
# [(2, 0.38071877), (4, 0.61187375)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.11688736), (1, 0.6768666), (2, 0.10475348), (4, 0.10049752)]
# [(0, 0.24938273), (1, 0.74320984)]
# [(3, 0.99012345)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.19999999), (4, 0.7940594)]
# [(1, 0.9804878)]
# [(2, 0.65901643), (4, 0.33114755)]
# [(4, 0.98688525)]
# [(4, 0.9619048)]
# [(1, 0.124151155), (3, 0.8728637)]
# [(0, 0.26286185), (2, 0.18248567), (3, 0.29642275), (4, 0.25770482)]
# [(2, 0.9804878)]
# [(1, 0.19631691), (2, 0.14020994), (3, 0.6609886)]
# [(2, 0.9804878)]
# [(1, 0.40028033), (2, 0.12271185), (3, 0.47479787)]
# [(2, 0.9804878)]
# [(4, 0.9619048)]
# [(3, 0.5991616), (4, 0.39343092)]
# [(4, 0.9804878)]
# [(1, 0.9933884)]
# [(1, 0.24938273), (2, 0.2460019), (3, 0.4996771)]
# [(4, 0.9804878)]
# [(4, 0.9804878)]
# [(3, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.67886394), (3, 0.31688073)]
# [(0, 0.9804878)]
# [(1, 0.38701132), (3, 0.6031526)]
# [(2, 0.9619048)]
# [(0, 0.13879903), (2, 0.07940165), (4, 0.78037584)]
# [(2, 0.59895885), (3, 0.39608246)]
# [(0, 0.41705933), (1, 0.21424693), (2, 0.12376475), (4, 0.24426457)]
# [(1, 0.72225666), (3, 0.27033585)]
# [(3, 0.9619048)]
# [(1, 0.91645485), (3, 0.08140991)]
# [(1, 0.9920792)]
# [(4, 0.9804878)]
# [(4, 0.98688525)]
# [(0, 0.16694213), (1, 0.6628099), (4, 0.16694213)]
# [(1, 0.9804878)]
# [(2, 0.2493827), (4, 0.74320984)]
# [(1, 0.9619048)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(4, 0.98688525)]
# [(1, 0.98688525)]
# [(1, 0.9920792)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(4, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.43358383), (4, 0.5565801)]
# [(3, 0.99012345)]
# [(0, 0.23002197), (2, 0.19999999), (4, 0.5660176)]
# [(3, 0.9804878)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(2, 0.24938273), (4, 0.74320984)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.31077653), (1, 0.1879889), (2, 0.49629626)]
# [(2, 0.9804878)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.62218946), (4, 0.36797443)]
# [(1, 0.62010914), (4, 0.37005478)]
# [(1, 0.9804878)]
# [(0, 0.49629626), (3, 0.49629626)]
# [(1, 0.98688525)]
# [(0, 0.19999999), (4, 0.7940594)]
# [(0, 0.7049861), (1, 0.2890733)]
# [(1, 0.19850732), (3, 0.796534)]
# [(0, 0.31757763), (1, 0.67816705)]
# [(3, 0.9804878)]
# [(0, 0.2493827), (2, 0.44292098), (3, 0.302758)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.35057244), (1, 0.33114755), (3, 0.31172264)]
# [(0, 0.31275195), (1, 0.28898573), (3, 0.39660254)]
# [(2, 0.99012345)]
# [(2, 0.9619048)]
# [(2, 0.3325967), (3, 0.66408837)]
# [(0, 0.13326669), (2, 0.642839), (3, 0.21993396)]
# [(1, 0.9619048)]
# [(1, 0.7192801), (3, 0.27331245)]
# [(3, 0.7099316), (4, 0.28266093)]
# [(4, 0.98688525)]
# [(1, 0.2951556), (2, 0.69890374)]
# [(1, 0.29650638), (3, 0.7001787)]
# [(0, 0.44162768), (1, 0.31545845), (4, 0.2389535)]
# [(1, 0.9619048)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(0, 0.43033078), (2, 0.56226176)]
# [(0, 0.8007273), (2, 0.19431399)]
# [(0, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.44207934), (3, 0.5519801)]
# [(2, 0.9804878)]
# [(3, 0.7130846), (4, 0.2836005)]
# [(1, 0.38001588), (2, 0.6101481)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.10049751), (2, 0.22694664), (3, 0.22699374), (4, 0.44456708)]
# [(2, 0.40233007), (3, 0.5902626)]
# [(4, 0.9804878)]
# [(0, 0.13318622), (3, 0.08855269), (4, 0.7764512)]
# [(0, 0.65162385), (1, 0.3409687)]
# [(0, 0.379325), (1, 0.61326754)]
# [(2, 0.3239817), (3, 0.6700777)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(1, 0.9804878)]
# [(3, 0.8379611), (4, 0.15778361)]
# [(1, 0.9920792)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.56015307), (2, 0.42521277)]
# [(1, 0.13863699), (3, 0.8576363)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.37391302), (3, 0.49813667), (4, 0.12546584)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(2, 0.25139183), (3, 0.09583257), (4, 0.6511159)]
# [(4, 0.98688525)]
# [(1, 0.7509216), (2, 0.13182764), (3, 0.11504078)]
# [(0, 0.1285462), (3, 0.86772704)]
# [(2, 0.2493827), (3, 0.26859692), (4, 0.47708207)]
# [(0, 0.32224226), (1, 0.4347149), (3, 0.24123283)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(1, 0.57250243), (2, 0.41766152)]
# [(0, 0.19999999), (1, 0.19999999), (2, 0.5960396)]
# [(1, 0.04394658), (2, 0.3179732), (3, 0.3190437), (4, 0.31862068)]
# [(1, 0.9804878)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(2, 0.9804878)]
# [(0, 0.34192866), (2, 0.3426137), (4, 0.31262073)]
# [(3, 0.9619048)]
# [(0, 0.40374854), (2, 0.5864154)]
# [(1, 0.9804878)]
# [(4, 0.9804878)]
# [(2, 0.9804878)]
# [(4, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.4373266), (1, 0.11160221), (2, 0.22209944), (3, 0.22786675)]
# [(4, 0.98688525)]
# [(1, 0.9804878)]
# [(4, 0.99012345)]
# [(1, 0.9804878)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.19999999), (3, 0.34722215), (4, 0.44881743)]
# [(2, 0.14274496), (4, 0.8539401)]
# [(4, 0.9804878)]
# [(0, 0.2171613), (1, 0.1432624), (2, 0.1432624), (3, 0.49489543)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(4, 0.9619048)]
# [(4, 0.9920792)]
# [(0, 0.60425156), (2, 0.3859124)]
# [(0, 0.9619048)]
# [(0, 0.52733666), (4, 0.46282724)]
# [(0, 0.9619048)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(3, 0.98688525)]
# [(1, 0.9619048)]
# [(2, 0.9933884)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.34378368), (3, 0.64880896)]
# [(2, 0.9804878)]
# [(3, 0.9920792)]
# [(3, 0.98688525)]
# [(1, 0.98688525)]
# [(2, 0.9619048)]
# [(3, 0.99012345)]
# [(3, 0.98688525)]
# [(0, 0.489744), (3, 0.24938273), (4, 0.255935)]
# [(2, 0.13687453), (3, 0.32991526), (4, 0.53100026)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(0, 0.32593635), (1, 0.11160221), (3, 0.25367334), (4, 0.30768314)]
# [(4, 0.98688525)]
# [(0, 0.1432624), (4, 0.85248226)]
# [(2, 0.62613887), (3, 0.36402503)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(1, 0.57236373), (2, 0.4178002)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.98688525)]
# [(1, 0.72228265), (3, 0.27030995)]
# [(4, 0.98688525)]
# [(2, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.45796475), (3, 0.3542689), (4, 0.18446057)]
# [(3, 0.49566618), (4, 0.4983932)]
# [(0, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.07625785), (1, 0.35648283), (2, 0.33402812), (3, 0.23251946)]
# [(1, 0.98688525)]
# [(1, 0.9933884)]
# [(2, 0.52725947), (4, 0.46848518)]
# [(0, 0.2493827), (1, 0.2493827), (3, 0.49629626)]
# [(0, 0.33114755), (4, 0.6590164)]
# [(3, 0.9804878)]
# [(3, 0.98688525)]
# [(2, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.44060764), (3, 0.55198497)]
# [(0, 0.6988641), (1, 0.29688057)]
# [(2, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.6055341), (4, 0.38462985)]
# [(4, 0.9804878)]
# [(1, 0.36851776), (3, 0.2493827), (4, 0.37716126)]
# [(4, 0.9804878)]
# [(0, 0.9619048)]
# [(4, 0.9804878)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(2, 0.9619048)]
# [(3, 0.9619048)]
# [(2, 0.74320984), (3, 0.24938273)]
# [(2, 0.38071367), (4, 0.61187893)]
# [(3, 0.5299057), (4, 0.4651356)]
# [(2, 0.77778333), (4, 0.21627605)]
# [(3, 0.49629626), (4, 0.49629626)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.5877965), (4, 0.40236744)]
# [(3, 0.99012345)]
# [(2, 0.9619048)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.3099413), (2, 0.47379464), (3, 0.21230364)]
# [(3, 0.99012345)]
# [(2, 0.49629626), (4, 0.49629632)]
# [(0, 0.4481659), (1, 0.5419981)]
# [(4, 0.9804878)]
# [(1, 0.6234735), (2, 0.36669043)]
# [(2, 0.9804878)]
# [(0, 0.38978592), (3, 0.60525537)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.21571326), (2, 0.1432624), (4, 0.63818747)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(0, 0.39494884), (1, 0.19999999), (3, 0.40109077)]
# [(1, 0.9920792)]
# [(2, 0.98688525)]
# [(1, 0.4653996), (2, 0.52719295)]
# [(2, 0.74852633), (4, 0.24553312)]
# [(4, 0.9804878)]
# [(0, 0.14273639), (1, 0.15754992), (2, 0.17404187), (3, 0.38104406), (4, 0.14462778)]
# [(2, 0.5673317), (3, 0.42672768)]
# [(4, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(2, 0.98688525)]
# [(0, 0.32059187), (1, 0.16525811), (2, 0.08022915), (4, 0.43315458)]
# [(0, 0.9804878)]
# [(4, 0.9804878)]
# [(2, 0.6724788), (4, 0.32011384)]
# [(2, 0.9804878)]
# [(1, 0.28400716), (2, 0.4388058), (3, 0.27224872)]
# [(0, 0.12636723), (1, 0.13120417), (2, 0.036530104), (3, 0.59548837), (4, 0.11041012)]
# [(1, 0.38005567), (2, 0.61010826)]
# [(2, 0.44495898), (3, 0.55078566)]
# [(1, 0.9933884)]
# [(0, 0.96190476)]
# [(1, 0.9619048)]
# [(3, 0.9933884)]
# [(2, 0.1432624), (4, 0.85248226)]
# [(4, 0.9619048)]
# [(0, 0.74320984), (4, 0.2493827)]
# [(3, 0.49629626), (4, 0.49629626)]
# [(1, 0.9619048)]
# [(0, 0.19999999), (1, 0.3980198), (3, 0.3980198)]
# [(0, 0.25203425), (2, 0.17935392), (4, 0.5671884)]
# [(1, 0.35988405), (3, 0.6302799)]
# [(3, 0.4082737), (4, 0.5818903)]
# [(0, 0.32257646), (1, 0.42917785), (3, 0.24493991)]
# [(0, 0.6883676), (1, 0.22996578), (2, 0.080243096)]
# [(1, 0.9804878)]
# [(1, 0.99012345)]
# [(4, 0.99503106)]
# [(3, 0.9619048)]
# [(0, 0.6590164), (3, 0.33114758)]
# [(3, 0.98688525)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(1, 0.3980198), (2, 0.3980198), (3, 0.19999999)]
# [(1, 0.98688525)]
# [(3, 0.99012345)]
# [(0, 0.45372802), (1, 0.4967915), (4, 0.048612796)]
# [(4, 0.98688525)]
# [(4, 0.98688525)]
# [(0, 0.74320984), (3, 0.2493827)]
# [(0, 0.47569042), (1, 0.18688242), (2, 0.049017563), (3, 0.09035225), (4, 0.19805732)]
# [(1, 0.21493076), (4, 0.7827704)]
# [(0, 0.31614515), (2, 0.09670227), (3, 0.4179818), (4, 0.16850631)]
# [(2, 0.98688525)]
# [(0, 0.06326749), (3, 0.18166324), (4, 0.7540194)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.72905356), (3, 0.263539)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(1, 0.9619048)]
# [(3, 0.49629626), (4, 0.49629626)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.3796137), (2, 0.6105502)]
# [(0, 0.27801576), (1, 0.1176813), (3, 0.6027703)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.18536527), (1, 0.38589266), (2, 0.096027665), (3, 0.3320026)]
# [(2, 0.5877399), (4, 0.40242398)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.33114755), (4, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.98688525)]
# [(1, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.34267974), (2, 0.6474842)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.4988443), (1, 0.19098295), (4, 0.30836278)]
# [(4, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.5960396), (1, 0.19999999), (4, 0.19999999)]
# [(1, 0.9920792)]
# [(0, 0.18325533), (2, 0.13882823), (3, 0.29107955), (4, 0.3864211)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(4, 0.99012345)]
# [(4, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.6054896), (4, 0.3846743)]
# [(0, 0.9804878)]
# [(0, 0.2493827), (1, 0.48595372), (4, 0.25972527)]
# [(1, 0.2549668), (2, 0.2789733), (3, 0.46322298)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.37956652), (2, 0.61059743)]
# [(0, 0.9804878)]
# [(2, 0.9804878)]
# [(3, 0.98688525)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.28510636), (2, 0.20496896), (4, 0.50708777)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(2, 0.5877466), (4, 0.4024173)]
# [(3, 0.98688525)]
# [(0, 0.6830313), (4, 0.3095612)]
# [(1, 0.98688525)]
# [(4, 0.98688525)]
# [(4, 0.9619048)]
# [(0, 0.7278961), (2, 0.2646965)]
# [(0, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.25579378), (3, 0.14343855), (4, 0.5985577)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.37996006), (2, 0.61020386)]
# [(3, 0.9804878)]
# [(1, 0.5453485), (3, 0.4448154)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.98688525)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.55173904), (2, 0.098420925), (3, 0.34818026)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2939242), (3, 0.70111716)]
# [(3, 0.9920792)]
# [(0, 0.22180468), (1, 0.17005509), (2, 0.3773564), (4, 0.22936541)]
# [(1, 0.9804878)]
# [(0, 0.12546584), (2, 0.16476233), (4, 0.7072874)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.98688525)]
# [(0, 0.9804878)]
# [(1, 0.12546584), (3, 0.6464761), (4, 0.22557358)]
# [(4, 0.98688525)]
# [(0, 0.65432197), (2, 0.09840959), (3, 0.11916947), (4, 0.12762389)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(0, 0.7433479), (1, 0.2507115)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.3322314), (1, 0.16694213), (2, 0.3322314), (3, 0.16694213)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.99012345)]
# [(3, 0.98688525)]
# [(1, 0.19999999), (2, 0.19999999), (3, 0.5960396)]
# [(0, 0.6549936), (1, 0.34075105)]
# [(1, 0.27157542), (3, 0.3215697), (4, 0.40191662)]
# [(1, 0.609056), (3, 0.38110796)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(0, 0.3125524), (4, 0.68413264)]
# [(1, 0.49629626), (4, 0.49629632)]
# [(1, 0.545285), (3, 0.4448789)]
# [(1, 0.49629626), (4, 0.49629626)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.22209944), (3, 0.77458566)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.11160221), (1, 0.53825873), (2, 0.13735475), (3, 0.21167932)]
# [(1, 0.6628099), (3, 0.16694213), (4, 0.16694213)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.98688525)]
# [(1, 0.4803143), (3, 0.51374507)]
# [(0, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.62617004), (3, 0.36399388)]
# [(2, 0.9804878)]
# [(1, 0.37964886), (2, 0.61051506)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.4392246), (4, 0.553368)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.3322314), (3, 0.6628099)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(1, 0.9804878)]
# [(2, 0.6261731), (3, 0.36399087)]
# [(1, 0.98688525)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(3, 0.98688525)]
# [(1, 0.9619048)]
# [(1, 0.49629626), (2, 0.49629626)]
# [(2, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.9804878)]
# [(4, 0.98688525)]
# [(2, 0.9804878)]
# [(1, 0.4859763), (2, 0.509065)]
# [(0, 0.18623322), (2, 0.14765106), (3, 0.6628099)]
# [(0, 0.12896484), (2, 0.184791), (3, 0.14361024), (4, 0.54139173)]
# [(0, 0.5139668), (2, 0.098382264), (3, 0.19616033), (4, 0.19066074)]
# [(1, 0.9619048)]
# [(0, 0.14030541), (2, 0.17142205), (3, 0.6857881)]
# [(0, 0.20507497), (1, 0.24255615), (3, 0.5501589)]
# [(4, 0.9920792)]
# [(2, 0.9619048)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(2, 0.98688525)]
# [(4, 0.98688525)]
# [(3, 0.445214), (4, 0.55105925)]
# [(2, 0.5873114), (4, 0.40285254)]
# [(0, 0.12690176), (3, 0.35025325), (4, 0.5203605)]
# [(0, 0.16661184), (1, 0.44670078), (3, 0.3838505)]
# [(2, 0.62620485), (3, 0.3639591)]
# [(1, 0.2499819), (2, 0.38524288), (3, 0.17615846), (4, 0.18696384)]
# [(0, 0.53313625), (2, 0.45702767)]
# [(0, 0.7614431), (1, 0.23261636)]
# [(0, 0.44834787), (1, 0.54181606)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(2, 0.9804878)]
# [(2, 0.98688525)]
# [(0, 0.481916), (2, 0.22140351), (3, 0.12621835), (4, 0.16969585)]
# [(4, 0.9804878)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.16229397), (1, 0.44312537), (4, 0.39174378)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(1, 0.5219501), (2, 0.21948503), (4, 0.25525907)]
# [(2, 0.9804878)]
# [(2, 0.9804878)]
# [(1, 0.7823427), (3, 0.21171677)]
# [(0, 0.2493827), (2, 0.74320984)]
# [(1, 0.98688525)]
# [(0, 0.9804878)]
# [(3, 0.7272962), (4, 0.26529643)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.1336521), (2, 0.29246277), (3, 0.46145526), (4, 0.11160003)]
# [(2, 0.9804878)]
# [(0, 0.39718723), (1, 0.59540534)]
# [(2, 0.4323511), (4, 0.5626902)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(4, 0.98688525)]
# [(2, 0.5297868), (3, 0.46648645)]
# [(2, 0.4034172), (3, 0.22709401), (4, 0.366183)]
# [(4, 0.99012345)]
# [(1, 0.9804878)]
# [(2, 0.6590164), (4, 0.33114758)]
# [(0, 0.28510642), (1, 0.3888116), (2, 0.32324514)]
# [(2, 0.98688525)]
# [(1, 0.6133959), (4, 0.37919667)]
# [(4, 0.99432623)]
# [(2, 0.9804878)]
# [(4, 0.98688525)]
# [(1, 0.9619048)]
# [(2, 0.4971616), (3, 0.20987672), (4, 0.2911517)]
# [(0, 0.9619048)]
# [(0, 0.5496466), (2, 0.43571925)]
# [(2, 0.98688525)]
# [(1, 0.9933884)]
# [(1, 0.98688525)]
# [(0, 0.6512113), (1, 0.34138128)]
# [(1, 0.81235707), (3, 0.18268424)]
# [(1, 0.69711107), (2, 0.2986336)]
# [(0, 0.5338773), (3, 0.45628667)]
# [(1, 0.9804878)]
# [(1, 0.2493827), (2, 0.2493827), (3, 0.49629626)]
# [(2, 0.6263426), (3, 0.36382136)]
# [(0, 0.33570096), (2, 0.6568916)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.98688525)]
# [(1, 0.25269473), (2, 0.5433558), (3, 0.20064367)]
# [(0, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.27481523), (2, 0.26737693), (4, 0.45286956)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.49629626), (3, 0.49629626)]
# [(1, 0.6464915), (2, 0.17379534), (3, 0.17640735)]
# [(1, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.4981366), (1, 0.12546584), (2, 0.24968943), (3, 0.12546584)]
# [(2, 0.98688525)]
# [(1, 0.34330928), (3, 0.6492833)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.19204795), (1, 0.80299336)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.99012345)]
# [(2, 0.9619048)]
# [(1, 0.47323465), (2, 0.52251)]
# [(1, 0.24938273), (2, 0.2970172), (4, 0.44866186)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(3, 0.9933884)]
# [(4, 0.98688525)]
# [(1, 0.38385364), (3, 0.6063103)]
# [(1, 0.99012345)]
# [(2, 0.9804878)]
# [(2, 0.9619048)]
# [(2, 0.9804878)]
# [(4, 0.9804878)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(4, 0.98688525)]
# [(4, 0.9619048)]
# [(2, 0.7861348), (3, 0.2079246)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(1, 0.6091328), (3, 0.38103107)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(3, 0.98688525)]
# [(4, 0.9804878)]
# [(3, 0.67558247), (4, 0.31701016)]
# [(4, 0.9804878)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.98688525)]
# [(2, 0.9804878)]
# [(3, 0.99503106)]
# [(0, 0.23562796), (1, 0.27291456), (2, 0.27463895), (3, 0.06553049), (4, 0.15128803)]
# [(4, 0.9804878)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(2, 0.96190476)]
# [(1, 0.98688525)]
# [(1, 0.99012345)]
# [(0, 0.25557354), (1, 0.13845465), (2, 0.29586986), (3, 0.17653202), (4, 0.1335699)]
# [(0, 0.53307325), (2, 0.45709065)]
# [(0, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.53794533), (2, 0.45611402)]
# [(3, 0.98688525)]
# [(0, 0.358918), (2, 0.2716697), (4, 0.36657545)]
# [(0, 0.9804878)]
# [(0, 0.98688525)]
# [(0, 0.9804878)]
# [(2, 0.62643903), (3, 0.3637249)]
# [(0, 0.47867396), (3, 0.24968943), (4, 0.2691521)]
# [(1, 0.9804878)]
# [(0, 0.9804878)]
# [(2, 0.9619048)]
# [(0, 0.23154423), (1, 0.071635574), (2, 0.22763039), (3, 0.08687385), (4, 0.382316)]
# [(4, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.20836431), (1, 0.46183828), (3, 0.32758743)]
# [(1, 0.9804878)]
# [(1, 0.12540072), (2, 0.16045693), (3, 0.103343405), (4, 0.6098939)]
# [(2, 0.98688525)]
# [(1, 0.61180323), (4, 0.37836072)]
# [(0, 0.2493827), (1, 0.49629626), (2, 0.2493827)]
# [(2, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(2, 0.2758166), (3, 0.5189825), (4, 0.2029909)]
# [(0, 0.11160221), (2, 0.11160221), (3, 0.77458566)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.39204335), (2, 0.39935946), (4, 0.2052914)]
# [(0, 0.98688525)]
# [(1, 0.76595366), (4, 0.23106128)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.46089825), (2, 0.30156112), (4, 0.2350562)]
# [(1, 0.34379265), (3, 0.6487999)]
# [(1, 0.4194384), (4, 0.56592745)]
# [(2, 0.99012345)]
# [(2, 0.9619048)]
# [(2, 0.49466154), (3, 0.49550238)]
# [(1, 0.98688525)]
# [(3, 0.99012345)]
# [(1, 0.2642558), (3, 0.72833675)]
# [(3, 0.98688525)]
# [(3, 0.38036284), (4, 0.6136966)]
# [(3, 0.98688525)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(1, 0.85248226), (4, 0.1432624)]
# [(1, 0.98688525)]
# [(2, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.21578883), (2, 0.569547), (3, 0.21070376)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.3195939), (2, 0.6744655)]
# [(3, 0.9804878)]
# [(1, 0.5895999), (2, 0.40056404)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(0, 0.69675124), (3, 0.29899338)]
# [(1, 0.9804878)]
# [(0, 0.98688525)]
# [(3, 0.98688525)]
# [(1, 0.98688525)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.9619048)]
# [(0, 0.17678107), (2, 0.65297097), (4, 0.16694215)]
# [(0, 0.22133647), (1, 0.3609454), (2, 0.12784512), (4, 0.28887793)]
# [(4, 0.9619048)]
# [(0, 0.18190044), (3, 0.479241), (4, 0.3370486)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.28824908), (2, 0.32428327), (4, 0.38350728)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(2, 0.43620738), (3, 0.36008802), (4, 0.20189464)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.98688525)]
# [(2, 0.98688525)]
# [(2, 0.9804878)]
# [(4, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.58967996), (2, 0.400484)]
# [(2, 0.9920792)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(0, 0.7940594), (3, 0.19999999)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(4, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.29120657), (1, 0.34031525), (2, 0.08703248), (3, 0.28106177)]
# [(3, 0.40782365), (4, 0.58792096)]
# [(4, 0.98688525)]
# [(1, 0.7432099), (4, 0.2493827)]
# [(1, 0.98688525)]
# [(0, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.23115209), (1, 0.08400489), (3, 0.46691802), (4, 0.21721329)]
# [(0, 0.08650856), (1, 0.36492115), (2, 0.09028183), (3, 0.45757672)]
# [(0, 0.49752066), (1, 0.4975207)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.29367483), (3, 0.44185227), (4, 0.261636)]
# [(2, 0.9804878)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(1, 0.42059356), (2, 0.2428074), (3, 0.33329323)]
# [(1, 0.33223143), (3, 0.6628099)]
# [(3, 0.99012345)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(4, 0.98688525)]
# [(1, 0.6793084), (3, 0.31475097)]
# [(1, 0.9619048)]
# [(0, 0.22648832), (1, 0.65969956), (4, 0.11160221)]
# [(2, 0.9804878)]
# [(0, 0.49280763), (1, 0.3771263), (3, 0.12807596)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.2493827), (2, 0.2493827), (4, 0.49629626)]
# [(3, 0.9804878)]
# [(0, 0.28510636), (1, 0.31398985), (2, 0.39806685)]
# [(1, 0.99012345)]
# [(4, 0.9619048)]
# [(4, 0.98688525)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.45401213), (2, 0.29166687), (4, 0.2493827)]
# [(1, 0.42402464), (3, 0.57003474)]
# [(0, 0.8368806), (4, 0.15939264)]
# [(3, 0.99012345)]
# [(3, 0.7699544), (4, 0.22508697)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(2, 0.49813667), (3, 0.36657333), (4, 0.13280551)]
# [(1, 0.9920792)]
# [(3, 0.98688525)]
# [(2, 0.40040016), (3, 0.58976376)]
# [(1, 0.9933884)]
# [(1, 0.24938273), (3, 0.74320984)]
# [(2, 0.99012345)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.5089262), (2, 0.27487406), (3, 0.21336286)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(1, 0.41848972), (2, 0.2595372), (3, 0.31866726)]
# [(2, 0.9804878)]
# [(0, 0.105700165), (1, 0.15599759), (3, 0.7367697)]
# [(0, 0.2474367), (2, 0.5776155), (3, 0.17211089)]
# [(0, 0.19577327), (1, 0.14679433), (3, 0.25377056), (4, 0.40299737)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(2, 0.62636226), (3, 0.36380166)]
# [(1, 0.3076539), (2, 0.48838568), (3, 0.19999999)]
# [(0, 0.74320984), (2, 0.2493827)]
# [(1, 0.9619048)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.9804878)]
# [(0, 0.19697855), (2, 0.7980628)]
# [(2, 0.17711641), (3, 0.23307979), (4, 0.5891597)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.3980198), (4, 0.5960396)]
# [(1, 0.2554313), (2, 0.31179062), (3, 0.29799977), (4, 0.13378336)]
# [(1, 0.74320984), (3, 0.2493827)]
# [(2, 0.98688525)]
# [(0, 0.9619048)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(1, 0.3838131), (3, 0.60635084)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.98688525)]
# [(0, 0.9804878)]
# [(0, 0.16672015), (1, 0.22077525), (2, 0.24562852), (3, 0.18514906), (4, 0.18172704)]
# [(3, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.9619048)]
# [(2, 0.32425782), (3, 0.6698016)]
# [(0, 0.9079827), (4, 0.08952765)]
# [(3, 0.9619048)]
# [(4, 0.9804878)]
# [(3, 0.9619048)]
# [(3, 0.9804878)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(3, 0.99012345)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(3, 0.9933884)]
# [(4, 0.99012345)]
# [(2, 0.1432624), (3, 0.5319576), (4, 0.32194304)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.44351482), (2, 0.55317026)]
# [(1, 0.58597076), (4, 0.4066218)]
# [(0, 0.40761033), (2, 0.33278006), (3, 0.17267121), (4, 0.08610848)]
# [(2, 0.6871556), (4, 0.30911765)]
# [(0, 0.9920792)]
# [(2, 0.9920792)]
# [(3, 0.9933884)]
# [(2, 0.9804878)]
# [(0, 0.6949347), (1, 0.17711504), (3, 0.12546584)]
# [(0, 0.98688525)]
# [(1, 0.9619048)]
# [(3, 0.9933884)]
# [(2, 0.77979463), (3, 0.21426474)]
# [(0, 0.7040514), (3, 0.29169324)]
# [(0, 0.24059802), (4, 0.7495659)]
# [(1, 0.44265354), (2, 0.3319432), (4, 0.22209746)]
# [(0, 0.25648552), (1, 0.58882827), (3, 0.1535132)]
# [(1, 0.98688525)]
# [(4, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.98688525)]
# [(4, 0.98688525)]
# [(1, 0.27310732), (4, 0.7231659)]
# [(2, 0.9619048)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.19999999), (1, 0.7940594)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9619048)]
# [(0, 0.07301327), (1, 0.19546887), (3, 0.57317424), (4, 0.15763184)]
# [(2, 0.2493827), (3, 0.74320984)]
# [(1, 0.9804878)]
# [(1, 0.6733271), (3, 0.16971219), (4, 0.15542814)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.0806664), (1, 0.1270111), (2, 0.6626945), (3, 0.12863292)]
# [(1, 0.9933884)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.6942928), (3, 0.30145183)]
# [(1, 0.8280992), (3, 0.16694213)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.98688525)]
# [(1, 0.5287133), (4, 0.4614506)]
# [(1, 0.9804878)]
# [(0, 0.9619048)]
# [(1, 0.36303705), (2, 0.6271269)]
# [(0, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(0, 0.16694213), (1, 0.16694213), (3, 0.6628099)]
# [(1, 0.9804878)]
# [(0, 0.25511), (2, 0.7406347)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.99012345)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(4, 0.9804878)]
# [(1, 0.76932347), (3, 0.22473595)]
# [(0, 0.19999999), (3, 0.7940594)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.19999999), (3, 0.7940594)]
# [(1, 0.99012345)]
# [(4, 0.9804878)]
# [(3, 0.98688525)]
# [(3, 0.9804878)]
# [(0, 0.2493827), (1, 0.43189928), (3, 0.3137797)]
# [(1, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.28510636), (1, 0.7106383)]
# [(1, 0.6938507), (2, 0.30020872)]
# [(1, 0.9804878)]
# [(0, 0.129812), (2, 0.44324782), (3, 0.07352471), (4, 0.35279235)]
# [(1, 0.20834027), (3, 0.7857191)]
# [(2, 0.98688525)]
# [(2, 0.9619048)]
# [(2, 0.99012345)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.9804878)]
# [(2, 0.74320984), (3, 0.2493827)]
# [(3, 0.99012345)]
# [(0, 0.5744005), (4, 0.41576344)]
# [(0, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49661332), (3, 0.4974461)]
# [(4, 0.98688525)]
# [(0, 0.9804878)]
# [(2, 0.98688525)]
# [(2, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.9619048)]
# [(4, 0.98688525)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.27450588), (3, 0.19324496), (4, 0.52976465)]
# [(4, 0.98688525)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(1, 0.9619048)]
# [(2, 0.9619048)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(1, 0.98688525)]
# [(2, 0.5879459), (3, 0.40611345)]
# [(2, 0.9804878)]
# [(0, 0.5138922), (2, 0.48016727)]
# [(0, 0.2493827), (1, 0.2493827), (3, 0.49629626)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(4, 0.98688525)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.9920792)]
# [(3, 0.693201), (4, 0.30184028)]
# [(1, 0.9619048)]
# [(1, 0.25917813), (2, 0.19203927), (3, 0.15142807), (4, 0.39593607)]
# [(0, 0.6054662), (4, 0.3846977)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(2, 0.9920792)]
# [(1, 0.539641), (4, 0.4554003)]
# [(2, 0.38070545), (4, 0.6118871)]
# [(1, 0.99012345)]
# [(1, 0.16604392), (3, 0.82970077)]
# [(1, 0.37994218), (2, 0.61022174)]
# [(1, 0.70127267), (4, 0.29131988)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(2, 0.9619048)]
# [(1, 0.28510636), (4, 0.7106383)]
# [(3, 0.98688525)]
# [(4, 0.9619048)]
# [(1, 0.9619048)]
# [(1, 0.44088528), (2, 0.5517073)]
# [(4, 0.98688525)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.54438287), (1, 0.20233512), (2, 0.18017414), (3, 0.07244338)]
# [(2, 0.9804878)]
# [(2, 0.98688525)]
# [(1, 0.1393348), (2, 0.14611466), (3, 0.1044162), (4, 0.6091393)]
# [(2, 0.9804878)]
# [(3, 0.6107105), (4, 0.3863044)]
# [(1, 0.9804878)]
# [(3, 0.99012345)]
# [(1, 0.26980433), (2, 0.7227882)]
# [(3, 0.9619048)]
# [(0, 0.7936847), (2, 0.20135656)]
# [(0, 0.98688525)]
# [(3, 0.99012345)]
# [(1, 0.98688525)]
# [(4, 0.9804878)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(0, 0.33575654), (2, 0.65683603)]
# [(3, 0.9804878)]
# [(0, 0.15697645), (1, 0.6126154), (2, 0.22757128)]
# [(1, 0.98688525)]
# [(0, 0.05314641), (2, 0.19290744), (3, 0.6665705), (4, 0.08695991)]
# [(1, 0.28858727), (2, 0.21058628), (3, 0.4975207)]
# [(4, 0.9619048)]
# [(0, 0.3761239), (3, 0.40097666), (4, 0.21893899)]
# [(1, 0.16694213), (3, 0.8280992)]
# [(3, 0.9619048)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(4, 0.9804878)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.49618205), (1, 0.31212115), (2, 0.0546831), (3, 0.06463991), (4, 0.072373755)]
# [(2, 0.98688525)]
# [(0, 0.9804878)]
# [(0, 0.623429), (2, 0.36673495)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(1, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.99012345)]
# [(2, 0.6261634), (3, 0.36400047)]
# [(0, 0.10046092), (1, 0.49404013), (2, 0.2142124), (4, 0.19038157)]
# [(0, 0.2493827), (3, 0.74320984)]
# [(2, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(4, 0.9804878)]
# [(1, 0.33114755), (3, 0.33114755), (4, 0.33114755)]
# [(3, 0.9804878)]
# [(2, 0.29243284), (3, 0.7001597)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(4, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(1, 0.6117743), (4, 0.3783896)]
# [(1, 0.29737195), (2, 0.20180161), (4, 0.4975207)]
# [(3, 0.44777927), (4, 0.5479654)]
# [(4, 0.99012345)]
# [(1, 0.15670934), (2, 0.32234457), (4, 0.5187362)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(2, 0.58734447), (4, 0.40281948)]
# [(0, 0.7511599), (4, 0.245855)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(2, 0.46470484), (4, 0.5278878)]
# [(2, 0.99012345)]
# [(4, 0.99012345)]
# [(4, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.9920792)]
# [(0, 0.07911554), (3, 0.33369148), (4, 0.58602)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(4, 0.9619048)]
# [(2, 0.9619048)]
# [(4, 0.9619048)]
# [(1, 0.6919846), (2, 0.30207476)]
# [(1, 0.9804878)]
# [(1, 0.9920792)]
# [(0, 0.49813667), (1, 0.37391302), (4, 0.12546586)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(0, 0.16956897), (2, 0.09914177), (4, 0.72962946)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(2, 0.9804878)]
# [(0, 0.99012345)]
# [(0, 0.109746635), (2, 0.26694122), (3, 0.19272105), (4, 0.43000457)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.98688525)]
# [(3, 0.98688525)]
# [(3, 0.75824827), (4, 0.23679306)]
# [(1, 0.41180098), (2, 0.30993995), (4, 0.27332073)]
# [(2, 0.98688525)]
# [(2, 0.9804878)]
# [(2, 0.33114755), (4, 0.65901643)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.5337359), (3, 0.46130544)]
# [(0, 0.6055093), (4, 0.3846546)]
# [(1, 0.98688525)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(2, 0.5406265), (3, 0.4534329)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.99432623)]
# [(3, 0.9619048)]
# [(2, 0.2493827), (3, 0.74320984)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.09140271), (1, 0.46057135), (2, 0.44621602)]
# [(2, 0.3808305), (4, 0.61176217)]
# [(1, 0.99432623)]
# [(1, 0.36555997), (2, 0.62703264)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(3, 0.2604736), (4, 0.73211896)]
# [(1, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.98688525)]
# [(0, 0.46093985), (3, 0.52442604)]
# [(3, 0.98688525)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(1, 0.31942394), (2, 0.67463547)]
# [(1, 0.9804878)]
# [(1, 0.38285026), (2, 0.38461614), (3, 0.23054352)]
# [(2, 0.3980198), (3, 0.5960396)]
# [(2, 0.1134667), (3, 0.8832184)]
# [(0, 0.49752066), (3, 0.31043932), (4, 0.18873425)]
# [(3, 0.98688525)]
# [(0, 0.49629626), (2, 0.49629626)]
# [(3, 0.9804878)]
# [(2, 0.9619048)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(1, 0.43376747), (2, 0.5588252)]
# [(4, 0.9933884)]
# [(1, 0.98688525)]
# [(1, 0.5627318), (4, 0.43132758)]
# [(0, 0.6468318), (4, 0.34985328)]
# [(1, 0.9804878)]
# [(0, 0.12546584), (1, 0.33952007), (3, 0.38257116), (4, 0.15120067)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(4, 0.99012345)]
# [(3, 0.9920792)]
# [(1, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.9804878)]
# [(1, 0.2698478), (2, 0.72274476)]
# [(0, 0.51940304), (1, 0.12546584), (2, 0.13386893), (3, 0.22001995)]
# [(2, 0.6050045), (3, 0.3851595)]
# [(0, 0.16694213), (1, 0.5791769), (2, 0.25057518)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.62656546), (2, 0.3635985)]
# [(0, 0.49629626), (1, 0.49629632)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(2, 0.4326137), (3, 0.55997884)]
# [(1, 0.99432623)]
# [(2, 0.9804878)]
# [(0, 0.8364879), (2, 0.15925679)]
# [(0, 0.29885224), (3, 0.16691235), (4, 0.53139853)]
# [(0, 0.5141707), (1, 0.2839521), (2, 0.14510989), (4, 0.056102928)]
# [(1, 0.9619048)]
# [(1, 0.54477334), (4, 0.45191178)]
# [(0, 0.98688525)]
# [(1, 0.3586098), (2, 0.27007592), (3, 0.24452743), (4, 0.12628813)]
# [(3, 0.98688525)]
# [(2, 0.9804878)]
# [(3, 0.7111211), (4, 0.2839202)]
# [(0, 0.99012345)]
# [(4, 0.9804878)]
# [(3, 0.33114755), (4, 0.65901643)]
# [(4, 0.9619048)]
# [(0, 0.1432624), (3, 0.3952612), (4, 0.45863947)]
# [(0, 0.3296339), (2, 0.2204194), (4, 0.4474623)]
# [(4, 0.99012345)]
# [(1, 0.6116685), (4, 0.3784954)]
# [(4, 0.98688525)]
# [(0, 0.44826445), (1, 0.5418995)]
# [(0, 0.9619048)]
# [(1, 0.49629626), (4, 0.49629626)]
# [(2, 0.43801174), (3, 0.16879995), (4, 0.3909783)]
# [(1, 0.38385728), (3, 0.6063066)]
# [(2, 0.33114758), (4, 0.6590164)]
# [(1, 0.9804878)]
# [(2, 0.98688525)]
# [(4, 0.98688525)]
# [(0, 0.30520403), (4, 0.6905406)]
# [(0, 0.6686913), (1, 0.2162176), (3, 0.11355851)]
# [(2, 0.44262338), (3, 0.17083028), (4, 0.38324055)]
# [(1, 0.4102182), (3, 0.57994574)]
# [(1, 0.4921267), (3, 0.5019327)]
# [(1, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(0, 0.346477), (1, 0.22989014), (3, 0.42142287)]
# [(4, 0.9804878)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(3, 0.25510827), (4, 0.73748434)]
# [(3, 0.7940594), (4, 0.19999999)]
# [(0, 0.33114758), (4, 0.6590164)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(3, 0.99012345)]
# [(0, 0.48329982), (3, 0.3390647), (4, 0.1743297)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(3, 0.98688525)]
# [(1, 0.6601692), (2, 0.2672955), (4, 0.0712064)]
# [(1, 0.9804878)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(3, 0.9804878)]
# [(0, 0.40454102), (1, 0.10876441), (3, 0.4847045)]
# [(2, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.9619048)]
# [(1, 0.6464803), (2, 0.17379712), (3, 0.17641674)]
# [(1, 0.30754706), (2, 0.4884925), (3, 0.19999999)]
# [(0, 0.9619048)]
# [(0, 0.44101506), (1, 0.3161088), (2, 0.24003923)]
# [(1, 0.98688525)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(1, 0.9804878)]
# [(0, 0.40720537), (1, 0.13237317), (2, 0.06292834), (3, 0.27136347), (4, 0.12612961)]
# [(1, 0.9804878)]
# [(3, 0.26049423), (4, 0.7320983)]
# [(0, 0.39759868), (1, 0.43215337), (3, 0.16694213)]
# [(0, 0.3220988), (1, 0.15554523), (2, 0.11166413), (3, 0.20201293), (4, 0.20867895)]
# [(1, 0.24938273), (2, 0.29707733), (4, 0.44860166)]
# [(2, 0.6886022), (4, 0.30714247)]
# [(3, 0.98688525)]
# [(3, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.9804878)]
# [(1, 0.98688525)]
# [(1, 0.9619048)]
# [(0, 0.15627824), (1, 0.6817885), (2, 0.15909638)]
# [(2, 0.9804878)]
# [(1, 0.98688525)]
# [(0, 0.6223602), (1, 0.373913)]
# [(1, 0.9619048)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(3, 0.99012345)]
# [(1, 0.26479396), (2, 0.18958865), (3, 0.19584212), (4, 0.34894538)]
# [(3, 0.9804878)]
# [(1, 0.37966928), (2, 0.6104946)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.29572734), (1, 0.6968653)]
# [(3, 0.47987112), (4, 0.5151702)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.49268293), (2, 0.49268287)]
# [(3, 0.9804878)]
# [(4, 0.99012345)]
# [(0, 0.38321775), (2, 0.6125269)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(1, 0.9619048)]
# [(3, 0.9804878)]
# [(3, 0.33114755), (4, 0.65901643)]
# [(0, 0.2665164), (1, 0.727543)]
# [(0, 0.2493827), (3, 0.49629626), (4, 0.2493827)]
# [(0, 0.49629632), (4, 0.49629626)]
# [(2, 0.7135779), (4, 0.27901465)]
# [(1, 0.98688525)]
# [(1, 0.25187737), (3, 0.742182)]
# [(1, 0.2916187), (2, 0.26101744), (3, 0.33182982), (4, 0.11453902)]
# [(1, 0.2519645), (3, 0.74209493)]
# [(1, 0.33114755), (4, 0.65901643)]
# [(0, 0.2493827), (2, 0.3403574), (3, 0.40532157)]
# [(2, 0.9804878)]
# [(0, 0.12903696), (1, 0.24995412), (2, 0.25283283), (3, 0.2259131), (4, 0.142263)]
# [(1, 0.98688525)]
# [(4, 0.9804878)]
# [(0, 0.40734094), (2, 0.27710775), (3, 0.1432624), (4, 0.17087047)]
# [(0, 0.46423572), (2, 0.16752394), (3, 0.21768175), (4, 0.14993557)]
# [(4, 0.9619048)]
# [(3, 0.7849895), (4, 0.20760311)]
# [(1, 0.28510642), (3, 0.28510636), (4, 0.42695034)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.98688525)]
# [(3, 0.9804878)]
# [(4, 0.9619048)]
# [(0, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(2, 0.3663681), (3, 0.15250699), (4, 0.47931498)]
# [(3, 0.24938273), (4, 0.74320984)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.9619048)]
# [(2, 0.9920792)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(1, 0.99012345)]
# [(4, 0.9804878)]
# [(3, 0.9619048)]
# [(0, 0.33114755), (1, 0.33114755), (4, 0.33114755)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.21231343), (3, 0.781746)]
# [(1, 0.9804878)]
# [(0, 0.65901643), (1, 0.33114755)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.1432624), (2, 0.19738212), (3, 0.6565186)]
# [(3, 0.9804878)]
# [(1, 0.65901643), (4, 0.33114755)]
# [(3, 0.98688525)]
# [(1, 0.34378782), (3, 0.6488047)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(1, 0.98688525)]
# [(0, 0.4145086), (2, 0.21575451), (3, 0.36752695)]
# [(2, 0.9804878)]
# ...
# [(1, 0.4080717), (3, 0.58452094)]
# [(1, 0.44734722), (4, 0.5428167)]
# [(1, 0.6983887), (2, 0.297356)]
# [(1, 0.21777606), (2, 0.23092446), (4, 0.54846257)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.23107636), (3, 0.7615162)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49268293), (4, 0.49268293)]
# [(2, 0.5081215), (4, 0.48204243)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(3, 0.67803407), (4, 0.31602538)]
# [(2, 0.9804878)]
# [(1, 0.9619048)]
# [(0, 0.98688525)]
# [(1, 0.71218145), (3, 0.28356323)]
# [(3, 0.9804878)]
# [(0, 0.43906525), (2, 0.2724418), (3, 0.28355464)]
# [(4, 0.9920792)]
# [(1, 0.3459651), (3, 0.32877892), (4, 0.3224191)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(4, 0.9804878)]
# [(0, 0.7285239), (1, 0.2640687)]
# [(4, 0.9619048)]
# [(3, 0.9804878)]
# [(1, 0.9804878)]
# [(3, 0.9619048)]
# [(1, 0.2143697), (3, 0.7806716)]
# [(3, 0.9619048)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(2, 0.61982334), (3, 0.37034062)]
# [(2, 0.9804878)]
# [(1, 0.98688525)]
# [(4, 0.9804878)]
# [(2, 0.33114755), (4, 0.65901643)]
# [(0, 0.2474391), (2, 0.7466203)]
# [(1, 0.2493827), (4, 0.74320984)]
# [(4, 0.98688525)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(0, 0.3980198), (3, 0.5960396)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.07535299), (3, 0.70645535), (4, 0.21620163)]
# [(2, 0.58713347), (4, 0.40303048)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.55967265), (1, 0.19999999), (2, 0.23636697)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(3, 0.2493827), (4, 0.74320984)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.49629626), (1, 0.49629626)]
# [(1, 0.22448246), (2, 0.32016164), (3, 0.2162621), (4, 0.23711357)]
# [(0, 0.9619048)]
# [(0, 0.9619048)]
# [(0, 0.98688525)]
# [(1, 0.16694213), (4, 0.8280992)]
# [(2, 0.9804878)]
# [(2, 0.62619144), (3, 0.36397246)]
# [(4, 0.98688525)]
# [(0, 0.1603789), (1, 0.24968943), (4, 0.5874471)]
# [(1, 0.9804878)]
# [(0, 0.4474204), (1, 0.54274356)]
# [(0, 0.3980198), (1, 0.19999999), (3, 0.3980198)]
# [(1, 0.4197127), (4, 0.56565315)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.13583721), (1, 0.5718067), (2, 0.2898715)]
# [(0, 0.98688525)]
# [(3, 0.71974885), (4, 0.27431056)]
# [(1, 0.077394634), (3, 0.49856153), (4, 0.42251125)]
# [(0, 0.49268293), (3, 0.49268293)]
# [(0, 0.33114755), (4, 0.65901643)]
# [(1, 0.2493827), (2, 0.47605366), (3, 0.2696253)]
# [(1, 0.9619048)]
# [(2, 0.4347454), (3, 0.5578472)]
# [(2, 0.9619048)]
# [(0, 0.2493827), (1, 0.50423807), (3, 0.24144089)]
# [(1, 0.65578747), (3, 0.33680508)]
# [(1, 0.81581753), (2, 0.17922378)]
# [(0, 0.33114755), (1, 0.65901643)]
# [(0, 0.9619048)]
# [(4, 0.99012345)]
# [(0, 0.5829918), (1, 0.23121922), (2, 0.18379898)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(1, 0.6101772), (2, 0.26029366), (4, 0.12704466)]
# [(1, 0.99012345)]
# [(0, 0.9804878)]
# [(1, 0.42695037), (2, 0.25553444), (3, 0.3146783)]
# [(1, 0.7854925), (2, 0.20856689)]
# [(3, 0.8702277), (4, 0.12645744)]
# [(3, 0.9619048)]
# [(1, 0.98688525)]
# [(3, 0.82180905), (4, 0.17393559)]
# [(4, 0.98688525)]
# [(2, 0.9619048)]
# [(3, 0.9804878)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(1, 0.5550389), (3, 0.43902045)]
# [(1, 0.5960396), (2, 0.3980198)]
# [(1, 0.68125015), (2, 0.31576473)]
# [(4, 0.98688525)]
# [(1, 0.9804878)]
# [(3, 0.21733923), (4, 0.77672017)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(1, 0.2493827), (3, 0.74320984)]
# [(0, 0.6511038), (1, 0.3414888)]
# [(3, 0.8184495), (4, 0.1765918)]
# [(2, 0.9619048)]
# [(0, 0.16694216), (1, 0.16694213), (3, 0.6628099)]
# [(1, 0.96190476)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.3176598), (3, 0.47980553), (4, 0.19969773)]
# [(4, 0.9804878)]
# [(0, 0.2094672), (2, 0.19280033), (3, 0.34990433), (4, 0.24737461)]
# [(1, 0.98688525)]
# [(0, 0.16370212), (1, 0.47669524), (3, 0.35676572)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.34501085), (1, 0.29375198), (2, 0.1676096), (3, 0.19197468)]
# [(2, 0.6535666), (3, 0.339026)]
# [(1, 0.38626316), (2, 0.36460763), (3, 0.24664474)]
# [(1, 0.3174778), (2, 0.6751148)]
# [(1, 0.5828113), (2, 0.4097813)]
# [(0, 0.38223064), (1, 0.07462706), (2, 0.35956547), (4, 0.18302284)]
# [(0, 0.9804878)]
# [(4, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.19999999), (2, 0.25098768), (3, 0.54505193)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(4, 0.9804878)]
# [(3, 0.40831733), (4, 0.5818466)]
# [(4, 0.9619048)]
# [(2, 0.58725303), (4, 0.40291086)]
# [(4, 0.9619048)]
# [(2, 0.74320984), (3, 0.2493827)]
# [(0, 0.2626844), (1, 0.102865316), (3, 0.16950624), (4, 0.46435753)]
# [(1, 0.19999999), (3, 0.7940594)]
# [(4, 0.9804878)]
# [(3, 0.99012345)]
# [(4, 0.9619048)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(1, 0.54639673), (2, 0.4486446)]
# [(4, 0.9920792)]
# [(0, 0.24968943), (4, 0.7465839)]
# [(3, 0.9619048)]
# [(2, 0.98688525)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.37391302), (1, 0.28190792), (2, 0.13503112), (3, 0.20790567)]
# [(0, 0.19999999), (1, 0.19999999), (2, 0.59603965)]
# [(1, 0.2917078), (2, 0.47067624), (3, 0.122882105), (4, 0.113628894)]
# [(2, 0.9619048)]
# [(2, 0.99012345)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.33114755), (2, 0.33114755), (4, 0.33114755)]
# [(1, 0.98688525)]
# [(3, 0.9619048)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.073411204), (2, 0.07744208), (3, 0.847487)]
# [(0, 0.28476685), (1, 0.15452322), (2, 0.40779352), (3, 0.15149797)]
# [(0, 0.12546584), (1, 0.40166098), (3, 0.47038868)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9804878)]
# [(3, 0.37771598), (4, 0.61634344)]
# [(2, 0.5412157), (4, 0.4528437)]
# [(3, 0.9920792)]
# [(2, 0.9804878)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.49752066), (1, 0.2973223), (2, 0.20185125)]
# [(3, 0.9619048)]
# [(2, 0.587306), (4, 0.4028579)]
# [(4, 0.99012345)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.55815244), (1, 0.43913266)]
# [(0, 0.14482416), (3, 0.6900093), (4, 0.16268207)]
# [(3, 0.9920792)]
# [(4, 0.9619048)]
# [(0, 0.104508564), (1, 0.21144454), (3, 0.50966406), (4, 0.17338787)]
# [(3, 0.98688525)]
# [(2, 0.65901643), (3, 0.33114755)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(1, 0.638377), (3, 0.35666433)]
# [(1, 0.31963214), (2, 0.6744273)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.6234431), (2, 0.3667208)]
# [(1, 0.9804878)]
# [(1, 0.31333664), (2, 0.36355332), (3, 0.32027316)]
# [(1, 0.38289732), (3, 0.6137877)]
# [(1, 0.9619048)]
# [(1, 0.71491325), (4, 0.27767932)]
# [(4, 0.9804878)]
# [(0, 0.37171963), (1, 0.17522117), (2, 0.45139945)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.60806805), (3, 0.38209587)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.9619048)]
# [(1, 0.2612611), (3, 0.51260036), (4, 0.22414848)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.9804878)]
# [(3, 0.9804878)]
# [(0, 0.32370442), (2, 0.27550521), (4, 0.39682996)]
# [(1, 0.49629626), (2, 0.2493827), (3, 0.2493827)]
# [(3, 0.44739637), (4, 0.546663)]
# [(2, 0.9619048)]
# [(1, 0.9804878)]
# [(0, 0.27209717), (3, 0.7204954)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (2, 0.49268293)]
# [(0, 0.65901643), (4, 0.33114755)]
# [(0, 0.5338885), (2, 0.4562754)]
# [(3, 0.9619048)]
# [(0, 0.22209944), (1, 0.15862589), (2, 0.6170647)]
# [(0, 0.9619048)]
# [(1, 0.3838687), (3, 0.6062952)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(2, 0.9619048)]
# [(0, 0.9619048)]
# [(3, 0.78139067), (4, 0.21266879)]
# [(3, 0.6251391), (4, 0.36502483)]
# [(0, 0.25534075), (1, 0.2858527), (4, 0.45659658)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(3, 0.98688525)]
# [(0, 0.33114755), (3, 0.65901643)]
# [(1, 0.11160221), (3, 0.65659314), (4, 0.22959466)]
# [(0, 0.4388782), (1, 0.06840476), (2, 0.14931075), (3, 0.087501995), (4, 0.25590435)]
# [(2, 0.53463185), (3, 0.45942754)]
# [(3, 0.9804878)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(0, 0.7940594), (2, 0.19999999)]
# [(0, 0.33114755), (2, 0.33114755), (3, 0.33114755)]
# [(4, 0.9619048)]
# [(2, 0.4566047), (3, 0.33375132), (4, 0.20633818)]
# [(2, 0.9619048)]
# [(0, 0.2861929), (1, 0.4213501), (3, 0.29121086)]
# [(1, 0.3980198), (4, 0.5960396)]
# [(0, 0.70490944), (1, 0.1432624), (2, 0.1489913)]
# [(0, 0.31967002), (3, 0.502939), (4, 0.17490654)]
# [(3, 0.98688525)]
# [(0, 0.13498484), (2, 0.26702514), (3, 0.5946842)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.22337683), (3, 0.46134296), (4, 0.31410715)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(0, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.9804878)]
# [(3, 0.9804878)]
# [(3, 0.9920792)]
# [(1, 0.65062636), (4, 0.34196627)]
# [(0, 0.27031514), (1, 0.06710963), (2, 0.66124636)]
# [(1, 0.3322314), (3, 0.6628099)]
# [(0, 0.4106542), (1, 0.10557522), (2, 0.21313605), (4, 0.26963946)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.99012345)]
# [(0, 0.49268293), (1, 0.49268293)]
# [(1, 0.23014167), (3, 0.7639177)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(4, 0.9804878)]
# [(1, 0.33750707), (3, 0.65823764)]
# [(0, 0.12093734), (1, 0.32235882), (2, 0.45845637), (3, 0.0974176)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.24938273), (1, 0.45872566), (3, 0.2869534)]
# [(4, 0.99012345)]
# [(1, 0.7148197), (2, 0.2777728)]
# [(2, 0.33114755), (4, 0.65901643)]
# [(3, 0.9619048)]
# [(2, 0.98688525)]
# [(1, 0.9619048)]
# [(2, 0.9804878)]
# [(0, 0.5783302), (1, 0.17935677), (2, 0.24120498)]
# [(0, 0.45251915), (4, 0.53284675)]
# [(3, 0.9804878)]
# [(2, 0.9804878)]
# [(1, 0.9619048)]
# [(4, 0.9804878)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.2493827), (2, 0.49629626), (3, 0.2493827)]
# [(1, 0.9619048)]
# [(1, 0.9804878)]
# [(2, 0.35863346), (4, 0.6371112)]
# [(3, 0.7940594), (4, 0.19999999)]
# [(3, 0.99432623)]
# [(3, 0.99012345)]
# [(4, 0.9804878)]
# [(4, 0.9619048)]
# [(2, 0.73031306), (3, 0.26374632)]
# [(3, 0.49268293), (4, 0.49268293)]
# [(1, 0.9920792)]
# [(1, 0.7755266), (2, 0.22148834)]
# [(0, 0.33525053), (2, 0.6573421)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.9619048)]
# [(1, 0.8163057), (2, 0.17873563)]
# [(0, 0.14927284), (1, 0.84647185)]
# [(1, 0.8486136), (2, 0.14713104)]
# [(2, 0.9804878)]
# [(1, 0.9619048)]
# [(3, 0.9619048)]
# [(1, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.5453819), (3, 0.44478202)]
# [(2, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.5831098), (3, 0.11232705), (4, 0.30257317)]
# [(1, 0.15240821), (3, 0.45697647), (4, 0.38956547)]
# [(1, 0.9619048)]
# [(0, 0.9804878)]
# [(0, 0.65901643), (2, 0.33114755)]
# [(1, 0.62340987), (2, 0.36675406)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(1, 0.5399447), (3, 0.4502192)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(3, 0.29419452), (4, 0.7015501)]
# [(4, 0.98688525)]
# [(4, 0.9804878)]
# [(1, 0.6981326), (3, 0.29445994)]
# [(1, 0.9804878)]
# [(1, 0.9804878)]
# [(3, 0.99012345)]
# [(3, 0.98688525)]
# [(3, 0.99012345)]
# [(1, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(0, 0.34157977), (1, 0.08442904), (2, 0.053532116), (3, 0.5200599)]
# [(1, 0.5306867), (4, 0.45947722)]
# [(0, 0.5723959), (2, 0.17224592), (3, 0.25369838)]
# [(2, 0.49268293), (3, 0.49268293)]
# [(2, 0.33653983), (3, 0.4908042), (4, 0.17066589)]
# [(1, 0.8696355), (4, 0.12663782)]
# [(1, 0.30342057), (4, 0.69359434)]
# [(2, 0.7552282), (4, 0.23883115)]
# [(0, 0.29041004), (1, 0.22382183), (2, 0.17237101), (3, 0.31284308)]
# [(3, 0.98688525)]
# [(2, 0.9619048)]
# [(4, 0.9804878)]
# [(2, 0.3535769), (3, 0.31437972), (4, 0.3300533)]
# [(2, 0.9804878)]
# [(0, 0.9804878)]
# [(2, 0.4208414), (3, 0.250922), (4, 0.3232983)]
# [(3, 0.99012345)]
# [(0, 0.49268293), (2, 0.49268293)]
# [(0, 0.99012345)]
# [(1, 0.9619048)]
# [(4, 0.9804878)]
# [(0, 0.3322314), (1, 0.49752066), (2, 0.16694213)]
# [(1, 0.33114755), (2, 0.65901643)]
# [(0, 0.093504176), (1, 0.069688365), (2, 0.201705), (3, 0.3492579), (4, 0.2858446)]
# [(4, 0.9619048)]
# [(4, 0.98688525)]
# [(1, 0.23130563), (2, 0.27346453), (4, 0.49126938)]
# [(0, 0.55069214), (3, 0.4394718)]
# [(0, 0.5454719), (4, 0.44469205)]
# [(2, 0.9619048)]
# [(0, 0.28510636), (3, 0.7106383)]
# [(0, 0.4344941), (1, 0.31555706), (3, 0.156606), (4, 0.092576556)]
# [(1, 0.8163013), (2, 0.17874004)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(2, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(1, 0.433714), (2, 0.16024776), (4, 0.40382823)]
# [(3, 0.9619048)]
# [(4, 0.9619048)]
# [(2, 0.9804878)]
# [(1, 0.35119122), (3, 0.6438501)]
# [(1, 0.9804878)]
# [(4, 0.98688525)]
# [(4, 0.9619048)]
# [(3, 0.99012345)]
# [(0, 0.15156919), (1, 0.26150712), (2, 0.0710917), (3, 0.2214781), (4, 0.29435384)]
# [(0, 0.19999999), (2, 0.30506438), (4, 0.49097526)]
# [(4, 0.99432623)]
# [(1, 0.4861349), (3, 0.50792444)]
# [(1, 0.9619048)]
# [(0, 0.4511909), (1, 0.5341749)]
# [(0, 0.2594605), (1, 0.30727968), (3, 0.43172723)]
# [(0, 0.19999999), (2, 0.3980198), (3, 0.3980198)]
# [(3, 0.6269906), (4, 0.36706877)]
# [(1, 0.22287577), (2, 0.47327837), (3, 0.30100894)]
# [(1, 0.33114755), (3, 0.65901643)]
# [(0, 0.33114755), (1, 0.33114755), (3, 0.33114755)]
# [(3, 0.99012345)]
# [(3, 0.9933884)]
# [(4, 0.9920792)]
# [(1, 0.2729057), (2, 0.18086073), (3, 0.12234397), (4, 0.4231778)]
# [(1, 0.9804878)]
# [(2, 0.9920792)]
# [(0, 0.25046977), (1, 0.28130388), (2, 0.3325967), (3, 0.13452466)]
# [(1, 0.65901643), (3, 0.33114755)]
# [(1, 0.9933884)]
# [(0, 0.3980198), (1, 0.19999999), (2, 0.19999999), (3, 0.19999999)]
# [(1, 0.9804878)]
# [(0, 0.2493827), (1, 0.74320984)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(2, 0.9619048)]
# [(1, 0.99012345)]
# [(1, 0.9804878)]
# [(1, 0.39730656), (4, 0.59773475)]
# [(1, 0.5897524), (2, 0.40041152)]
# [(0, 0.11904604), (1, 0.24077682), (2, 0.20688395), (3, 0.4328181)]
# [(1, 0.9804878)]
# [(1, 0.65901643), (2, 0.33114755)]
# [(1, 0.9804878)]
# [(4, 0.9804878)]
# [(0, 0.1432624), (1, 0.35207072), (3, 0.50183)]
# [(4, 0.98688525)]
# [(1, 0.2714175), (3, 0.7211751)]
# [(1, 0.39265388), (3, 0.60140556)]
# [(3, 0.9804878)]
# [(1, 0.9619048)]
# [(2, 0.33114755), (3, 0.65901643)]
# [(4, 0.9804878)]
# [(2, 0.9804878)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(3, 0.9619048)]
# [(1, 0.9619048)]
# [(2, 0.49629626), (4, 0.49629626)]
# [(2, 0.7744163), (3, 0.21964313)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.6981753), (3, 0.2944172)]
# [(4, 0.9804878)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(2, 0.50189775), (3, 0.49216163)]
# [(3, 0.9804878)]
# [(3, 0.33114755), (4, 0.65901643)]
# [(0, 0.70875466), (2, 0.28383788)]
# [(2, 0.49268293), (4, 0.49268293)]
# [(1, 0.46972033), (3, 0.2493827), (4, 0.27595863)]
# [(0, 0.2889432), (2, 0.6057621), (3, 0.103304654)]
# [(0, 0.33114755), (2, 0.65901643)]
# [(0, 0.9619048)]
# [(0, 0.33114758), (4, 0.6590164)]
# [(1, 0.49629626), (3, 0.49629626)]
# [(2, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.9804878)]
# [(0, 0.17831711), (1, 0.10081912), (2, 0.06710963), (3, 0.3053705), (4, 0.34838364)]
# [(0, 0.65901643), (3, 0.33114755)]
# [(2, 0.98688525)]
# [(1, 0.49268293), (3, 0.49268293)]
# [(1, 0.71487516), (2, 0.27771747)]
# [(3, 0.98688525)]
# [(2, 0.4350004), (3, 0.55759215)]
# [(0, 0.32642055), (4, 0.66763884)]
# [(0, 0.16252965), (2, 0.3921665), (3, 0.11656868), (4, 0.32763016)]
# [(2, 0.587257), (4, 0.40290692)]
# [(3, 0.40192467), (4, 0.59066784)]
# [(3, 0.9804878)]
# [(3, 0.9804878)]
# [(1, 0.3980198), (2, 0.3980198), (3, 0.19999999)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]
# [(1, 0.9804878)]
# [(0, 0.34586567), (1, 0.25464907), (3, 0.39617944)]
# [(2, 0.9804878)]
# [(4, 0.9804878)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(4, 0.98688525)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.49268293), (4, 0.49268293)]
# [(1, 0.99012345)]
# [(2, 0.98688525)]
# [(4, 0.9619048)]
# [(3, 0.98688525)]
# [(0, 0.17709757), (2, 0.4798154), (3, 0.07404576), (4, 0.26867157)]
# [(3, 0.9619048)]
# [(0, 0.19846395), (1, 0.128014), (2, 0.3467729), (4, 0.3262504)]
# [(2, 0.44494295), (4, 0.54911643)]
# [(4, 0.9804878)]
# [(1, 0.2874731), (2, 0.11511138), (3, 0.419547), (4, 0.17696354)]
# [(3, 0.99012345)]
# [(3, 0.9619048)]
# [(3, 0.9804878)]
# [(0, 0.9804878)]
# [(4, 0.9804878)]
# [(2, 0.74320984), (3, 0.2493827)]
# [(2, 0.40055004), (3, 0.41281313), (4, 0.1848269)]
# [(2, 0.49047315), (3, 0.22975884), (4, 0.277558)]
# [(0, 0.4963201), (3, 0.4977393)]
# [(0, 0.24938273), (4, 0.74320984)]
# [(3, 0.98688525)]
# [(3, 0.42169708), (4, 0.56846684)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#         Document_No  ...                                               Text
# 0                 0  ...                                [iklan, ganggu, as]
# 1                 1  ...                       [tolong, erti, pesan, pesan]
# 2                 2  ...                       [iklan, trossssssss, ganggu]
# 3                 3  ...  [ruwet, metode, bayar, indomart, mlh, cod, apl...
# 4                 4  ...  [dih, dwon, aplikasi, tipu, order, giveaway, h...
# ...             ...  ...                                                ...
# 780791       780791  ...  [belanja, shoppe, bantu, temu, barang, dng, ce...
# 780792       780792  ...  [sampai, sekarang, pakai, alhamdulilah, gapern...
# 780793       780793  ...  [enk, belanja, shopeee, tigkatkn, gratis, ongk...
# 780794       780794  ...                            [belanja, kirim, cepat]
# 780795       780795  ...                           [layan, belanja, shoope]
#
# [780796 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    193171
# 1.0    166184
# 2.0    130020
# 3.0    167292
# 4.0    124129
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,300000)

plt.show()
