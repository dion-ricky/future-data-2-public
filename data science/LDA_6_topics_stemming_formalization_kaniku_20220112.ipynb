# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.54.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  *
FROM
  `future-data-track-1.sapporo_mart.topic_modelling`
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0                                     IKLAN NYA GANGGU AS*       1
# 1        Pihak lazada tolong di mengerti masa saya pesa...       1
# 2                            Iklan trossssssss, ganggu aja       1
# 3        Lazada Ruwet anjir. Mau menggunakan metode pem...       1
# 4        Dih jangan dwon ni aplikasi tempat para penipu...       1
# ...                                                    ...     ...
# 1695878                                    Sangat membantu       5
# 1695879                                    Sangat membantu       5
# 1695880                                    Sangat membantu       5
# 1695881                                    Sangat membantu       5
# 1695882                                    Sangat membantu       5
#
# [1695883 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"belum","cuiiihhh","bangt","selamat","begitu","bhineka","situ","loh","deh"
    ,"mah","yaa","tapi","the","karena","padabal","ttep","sopi","ealah","mas"
    ,"kampreeeeet","busetttt","tahi","ah","sich","tokped","lzd","gada","gatau"
    ,"udh","ttep","ehhh","bosss","wkekwk","bajing","laknat","asuuu","ku","woiii"
    ,"gueeee","njerr","waduhhhh","ma","dunk","dunk","untuk","dll","brupa"
    ,"sangatx","niih","bos","eh","smua","gni","bye","ajah","gilee","luu","ndro"
    ,"dg","kga","min","sm","haisshhh","piye","iki","skali","hehehe","ms","juga"
    ,"fff","mamam","inibsangat","andri","yopiyanto","broo","donk","tes","si"
    ,"ter","dech","wow","oh","toped","dahhhh","grab","ijo","oren","ovo","gopay"
    ,"kredivo","sok","david","gaes","dr","ovonya","bbrp","gmna","bbrpa","and"
    ,"uah","uhahhhhhh","topeeed","ngak","kamu","anj","nge","lah","linkaja"
    ,"gosend","sicepat","jne","yah","goto","gofood","goride","prakerja"
    ,"haduhhhh","pediya","kakak","hhe","bro","bismillah","fuulll","goof"
    ,"assalamualaikum","atsu","pea","you","agan","semenjak","gojek","lagiii"
    ,"lagi","bts","kkzara","cog","aaaaa","sich","cih","ciyy","padahal","ad"
    ,"adlh","ahaha","aj","ak","akika","akkoh","akuwh","alow","anjrit","ap2"
    ,"apasih","aps","aq","aqueh","q","asem","ato","awak","bakalan","bangedh"
    ,"bcanda","beud","bg","bgmn","bgt","bkl","bknnya","blum","boljug","boyeh"
    ,"bs","bt","btw","bwt","byk","can","thanks","d","dah","dapet","de","dek"
    ,"deyh","dgn","disono","dkk","dlu","dngn","dongs","dpt","dri","drmn","drtd"
    ,"dst","duh","egp","eke","ane","ente","elu","emangnya","emng","endak"
    ,"enggak","gaada","gag","gaje","gpp","gan","gbs","geje","ghiy","gimana"
    ,"githu","gj","gn","gt","gpny","gr","gtau","guoblok","ha","haha","hallow"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar","buka","lapak"
    ,"terima","kasih","alhamdulillah","pokok"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review'].values]]

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token
# Out:
#                                                     review  rating
# 0                                          iklan ganggu as       1
# 1                                  tolong erti pesan pesan       1
# 2                                 iklan trossssssss ganggu       1
# 3        ruwet metode bayar indomart mlh cod aplikasi v...       1
# 4        dih dwon aplikasi tipu order giveaway hp perca...       1
# ...                                                    ...     ...
# 1475049  belanja shoppe bantu temu barang dng cepat har...       5
# 1475050    sampe skrg pake alhamdulilah gapernah ngecewain       5
# 1475052     enk blanja shopeee tigkatkn gratis ongkir psan       5
# 1475053                                  belanja kirim cpt       5
# 1475055                               layan belanja shoope       5
#
# [761730 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['iklan', 'ganggu', 'as'],
#  ['tolong', 'erti', 'pesan', 'pesan'],
#  ['iklan', 'trossssssss', 'ganggu'],
#  ['ruwet', 'metode', 'bayar', 'indomart', 'mlh', 'cod', 'aplikasi', 'voucher'],
#  ['dih',
#   'dwon',
#   'aplikasi',
#   'tipu',
#   'order',
#   'giveaway',
#   'handphone',
#   'percaya',
#   'dateng',
#   'kawat',
#   'bayar',
#   'ribu',
#   'masak',
#   'kasi',
#   'kawat',
#   'untung',
#   'gin',
#   'tipu',
#   'bgettt',
#   'yaaa',
#   'gesss',
#   'aman',
#   'percaya',
#   'tukang',
#   'tipu',
#   'kaya',
#   'hapus',
#   'lgsung',
#   'aplikasi'],
#  ['cashbacknya', 'dapetnya', 'kirim', 'dikit', 'serius', 'bikin', 'promo'],
#  ['bnrn',
#   'sya',
#   'menang',
#   'untung',
#   'undi',
#   'handphone',
#   'ip',
#   'kirim',
#   'alamat',
#   'tinggal',
#   'sya',
#   'kp',
#   'rawahingkik',
#   'rt',
#   'rw',
#   'cileungsi',
#   'bogor',
#   'ichat'],
#  ['keluh', 'langgan', 'tanggung'],
#  ['pocer', 'tapi', 'ngk'],
#  ['ui', 'ribet'],
#  ['aplikasi', 'pesan', 'barang', 'bayar', 'barang', 'pesan', 'nyampe'],
#  ['keluan',
#   'setelah',
#   'bc',
#   'komntr',
#   'apa',
#   'banyak',
#   'penipuny',
#   'pelyananya'],
#  ['transaksi', 'tranfer', 'uang'],
#  ['cok', 'asyifa'],
#  ['ampuh', 'sehat', 'aman', 'damai'],
#  ['males', 'belanja', 'shope', 'lebih baik', 'toko', 'belah'],
#  ['maf',
#   'aplikasi',
#   'sayah',
#   'terimna',
#   'hadiah',
#   'puter',
#   'katnya',
#   'hadiah',
#   'uang',
#   'tapi',
#   'bacan',
#   'ambil',
#   'uang',
#   'sama',
#   'hadia',
#   'sayah',
#   'terimna',
#   'aplikasi',
#   'nga',
#   'bisin',
#   'kuota',
#   'bantu',
#   'jawap',
#   'kenah',
#   'ambil'],
#  ['beli', 'barang', 'sesuai', 'boykot'],
#  ['tolong', 'cepat'],
#  ['membaii', 'layanan'],
#  ['ban', 'ban', 'bekas'],
#  ['toko', 'beli', 'gantung', 'tas', 'nggkak', 'kirim', 'kirim'],
#  ['cod', 'transfer', 'proses', 'bikin', 'ribet'],
#  ['rupiah', 'ongkir', 'bayar'],
#  ['gratis',
#   'ongkir',
#   'promo',
#   'cashback',
#   'juga',
#   'hilang',
#   'pindah',
#   'aplikasi',
#   'nihh'],
#  ['kode',
#   'verifikasi',
#   'otp',
#   'sulit',
#   'verifikasi',
#   'whatsapp',
#   'nomer',
#   'via',
#   'telepon',
#   'nyampe',
#   'gin',
#   'bikin',
#   'sulit',
#   'daftar',
#   'shoppe',
#   'bayar',
#   'maaf',
#   'lanjur',
#   'harap',
#   'sistem',
#   'verifikasi',
#   'kode',
#   'otp',
#   'ribet',
#   'cuman',
#   'ganti',
#   'pasword',
#   'simple',
#   'maju',
#   'kayak',
#   'gin'],
#  ['belanja',
#   'barang',
#   'dateng',
#   'lapor',
#   'kirim',
#   'alhasil',
#   'bolak',
#   'ekspedisi',
#   'plus',
#   'debat',
#   'jual',
#   'uang',
#   'hilang',
#   'barang',
#   'nyampe',
#   'jujur',
#   'ekspedisi',
#   'expres'],
#  ['akun',
#   'nonaktif',
#   'order',
#   'bayar',
#   'shopeepay',
#   'nonaktif',
#   'jlskan',
#   'salah'],
#  ['proses',
#   'rim',
#   'padhal',
#   'update',
#   'tepaksa',
#   'batal',
#   'prises',
#   'kirim',
#   'tolong',
#   'dibantuh'],
#  ['paylater', 'beku', 'limit', 'terlambat', 'bayar', 'solusi'],
#  ['aplikasi',
#   'ndk',
#   'masak',
#   'beli',
#   'speaker',
#   'gantung',
#   'kunci',
#   'tolong',
#   'tok',
#   'bossku',
#   'aplikasi',
#   'rusak',
#   'serius'],
#  ['terkadang', 'dilazada', 'barang', 'sesuai'],
#  ['tukang',
#   'tipu',
#   'aplikasi',
#   'kawan',
#   'kawan',
#   'jngan',
#   'unduh',
#   'aplikasi',
#   'modus',
#   'tipu',
#   'iming',
#   'iming',
#   'hadiah',
#   'lebih baik',
#   'unduh',
#   'bonus'],
#  ['dtipu',
#   'muncul',
#   'pembritahuan',
#   'memdapat',
#   'hadiah',
#   'cmn',
#   'suruh',
#   'install',
#   'aplikasi',
#   'tempek'],
#  ['error', 'yaaaaaaa'],
#  ['iklan', 'akeh', 'cok'],
#  ['idexpress', 'hapus', 'paket', 'regelur', 'sampai'],
#  ['unduh', 'bantu'],
#  ['susah', 'memasukkn', 'otp', 'kirim'],
#  ['ngk', 'aplikasi'],
#  ['install', 'anjenk'],
#  ['emosi',
#   'internet',
#   'aplikasi',
#   'lancar',
#   'pas',
#   'shope',
#   'ketik',
#   'cari',
#   'pencet',
#   'enter',
#   'emosi',
#   'jam',
#   'seperti',
#   'besok',
#   'seperti',
#   'loading',
#   'pas',
#   'loading',
#   'produk',
#   'temu',
#   'tahu',
#   'barang',
#   'cari',
#   'iseng',
#   'sia',
#   'sia',
#   'tunggu'],
#  ['saldo', 'blokir', 'tolong', 'customer', 'care', 'aktifin', 'saldo'],
#  ['jangan',
#   'belanja',
#   'tipu',
#   'pesan',
#   'kirim',
#   'pakai',
#   'metode',
#   'bayar',
#   'cod',
#   'kurir',
#   'bilang',
#   'bayar',
#   'jual',
#   'prnah',
#   'beli',
#   'bareng',
#   'sesuai',
#   'pas',
#   'cod',
#   'dpn',
#   'kurir',
#   'kurir',
#   'sendiri',
#   'inisiatif',
#   'bilang',
#   'jual',
#   'basa',
#   'basi',
#   'rugi',
#   'tipu',
#   'berkah',
#   'makan',
#   'tu',
#   'duit',
#   'haram',
#   'ikhlas',
#   'dunia',
#   'akhirat'],
#  ['pesan',
#   'balik',
#   'gudang',
#   'lagi',
#   'kurir',
#   'wilayah',
#   'kirim',
#   'suruh',
#   'tunggu',
#   'lagi',
#   'sesuai',
#   'wilayah',
#   'kirim'],
#  ['iklanya', 'lindung', 'handphone', 'mu', 'viruz', 'pas', 'pencet', 'malak'],
#  ['tipu', 'tolong', 'pantau', 'jual', 'tipu', 'tolak'],
#  ['aplikasi',
#   'taiii',
#   'mesen',
#   'sampai',
#   'pas',
#   'sampai',
#   'barang',
#   'sampai',
#   'cancel',
#   'costumer'],
#  ['loading', 'berat', 'susahhhh'],
#  ['njirrr', 'selancar', 'alih', 'ksini', 'vanke'],
#  ['pesan',
#   'photocard',
#   'taehyung',
#   'eror',
#   'ulang',
#   'pas',
#   'checkout',
#   'notif',
#   'barang',
#   'saldo',
#   'potong',
#   'tolong',
#   'jngn',
#   'sperti'],
#  ['aplikasi', 'iklan', 'ngotak', 'mentang', 'duit', 'bikin', 'iklan'],
#  ['sebal',
#   'kesini',
#   'akun',
#   'apain',
#   'gagal',
#   'checkout',
#   'alas',
#   'curiga',
#   'janggal',
#   'ngeselin',
#   'pakai',
#   'shopeepay',
#   'gilir',
#   'pakai',
#   'bayar',
#   'gratis',
#   'ongkir',
#   'cashback',
#   'dipake',
#   'shopeepay',
#   'tolong',
#   'bikin',
#   'ribet'],
#  ['milih',
#   'jasa',
#   'ekspedisi',
#   'monopoli',
#   'express',
#   'cepat',
#   'sukur',
#   'paket',
#   'kirim',
#   'jakarta',
#   'estimasi',
#   'oktober',
#   'karawang',
#   'alih',
#   'toko'],
#  ['iklan', 'muncul', 'konttttttoooooooollllllllllll'],
#  ['kesel',
#   'update',
#   'diupdate',
#   'februari',
#   'besok',
#   'update',
#   'event',
#   'tanggal',
#   'februari',
#   'berat',
#   'handphone',
#   'handphone',
#   'kentang',
#   'ngebul',
#   'kuat',
#   'pakai',
#   'aplikasi',
#   'proses',
#   'belanja',
#   'gampang'],
#  ['pelit', 'ongkir', 'belanja', 'aplikasi', 'sedih', 'epribadi'],
#  ['iklan', 'muncul', 'ng'],
#  ['beli',
#   'sadar',
#   'barang',
#   'beli',
#   'beda',
#   'berat',
#   'tulis',
#   'berat',
#   'berat',
#   'sesunguhnya',
#   'berat',
#   'kg',
#   'tulis',
#   'kg',
#   'bayar',
#   'kg',
#   'kg',
#   'beli',
#   'ambil',
#   'bonus',
#   'beli',
#   'beli',
#   'cari',
#   'berat',
#   'barang',
#   'wajar',
#   'berat',
#   'sesuai',
#   'beda',
#   'kg',
#   'wajar',
#   'beda',
#   'kg',
#   'ajar'],
#  ['aplokasi', 'ribet', 'mau', 'jual', 'susah'],
#  ['member', 'platinum', 'shopepay', 'later', 'aktif', 'payahhh'],
#  ['spaylater',
#   'mesti',
#   'verifikasi',
#   'wajah',
#   'gagal',
#   'bayar',
#   'cicil',
#   'cicil',
#   'pakek',
#   'spaylater',
#   'malas',
#   'atm',
#   'sistem',
#   'bayar',
#   'sms',
#   'banking',
#   'kendala',
#   'malas',
#   'belanja',
#   'dishopee'],
#  ['seperti', 'ngk'],
#  ['ngapain', 'nongol', 'melulu', 'iklan', 'aplikasi', 'ganggu'],
#  ['unduh', 'update', 'hahaha', 'untung'],
#  ['hapus',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'hapus',
#   'bantu'],
#  ['sistem', 'beli', 'pulsa', 'uang', 'cepat', 'bangkrut', 'amin'],
#  ['dindownliad', 'hapus'],
#  ['isi',
#   'saldo',
#   'shoopepay',
#   'pas',
#   'klik',
#   'bank',
#   'virtual',
#   'account',
#   'blank',
#   'layar',
#   'handphone',
#   'putih',
#   'refresh',
#   'tetep',
#   'adehhhh',
#   'transaksi',
#   'njengggg'],
#  ['olshop',
#   'hancur',
#   'jasa',
#   'ekpedisi',
#   'kurir',
#   'amanh',
#   'smoga',
#   'benah',
#   'olshop',
#   'bagaimna',
#   'prioritas',
#   'customer'],
#  ['beli',
#   'handphone',
#   'barang',
#   'sesuai',
#   'retur',
#   'handphone',
#   'jual',
#   'uang',
#   'bantu',
#   'admin'],
#  ['toko', 'bnyak', 'tipu'],
#  ['aplikasi',
#   'tipu',
#   'program',
#   'promo',
#   'cashback',
#   'bodoh',
#   'rugi',
#   'nyesal'],
#  ['amanah',
#   'bayar',
#   'dibatalin',
#   'sistem',
#   'dana',
#   'dikembaliin',
#   'juga',
#   'belanja',
#   'tolong',
#   'cari',
#   'uang',
#   'susah',
#   'fikembalikan',
#   'cepat'],
#  ['sapi',
#   'lajanda',
#   'ribet',
#   'akun',
#   'cuman',
#   'handphone',
#   'ttp',
#   'batal',
#   'sistem',
#   'busul'],
#  ['shoope', 'pesan', 'dibatalin', 'tampa', 'konfirmasi'],
#  ['aplikasi', 'lambat', 'unduh'],
#  ['cari', 'tahu', 'tahu'],
#  ['kurir',
#   'expres',
#   'mahal',
#   'beda',
#   'kurir',
#   'ribu',
#   'pakai',
#   'expres',
#   'ribu',
#   'pakai',
#   'voucher',
#   'no',
#   'ongkir',
#   'tetep',
#   'biaya',
#   'ongkir'],
#  ['tanam',
#   'blank',
#   'eror',
#   'update',
#   'cache',
#   'uninstall',
#   'install',
#   'begtu'],
#  ['proses',
#   'bayar',
#   'btl',
#   'seller',
#   'tolong',
#   'bayar',
#   'cepat',
#   'cod',
#   'tindak',
#   'lh',
#   'mksh'],
#  ['toko',
#   'jual',
#   'barang',
#   'sesuai',
#   'klik',
#   'pesan',
#   'bantu',
#   'solusi',
#   'tertawa'],
#  ['daftar', 'susah'],
#  ['belanja', 'barang', 'batal', 'otomatis', 'terssss', 'kezeellllll'],
#  ['susah',
#   'cari',
#   'barang',
#   'isi',
#   'barang',
#   'pasang',
#   'harga',
#   'perut',
#   'efek',
#   'gampang',
#   'bikin',
#   'bahan',
#   'timbang',
#   'bikin',
#   'betah',
#   'buyer'],
#  ['shopeepay', 'later', 'jngan', 'bayar', 'sllu'],
#  ['ganggu', 'jual', 'murah', 'iklaaaan', 'terusss', 'kamorer'],
#  ['loginnya', 'login', 'pakai', 'no', 'telepon', 'error'],
#  ['bnyak',
#   'seller',
#   'tipu',
#   'hati',
#   'ditelfon',
#   'seller',
#   'remote',
#   'akun',
#   'shopeenya',
#   'tolong',
#   'aplikasiny',
#   'update',
#   'refund',
#   'jangan',
#   'bgitu',
#   'batal',
#   'refund',
#   'uang',
#   'tunggu',
#   'hari'],
#  ['aplikasi', 'ongkir', 'bayar'],
#  ['iklan', 'melulu'],
#  ['update', 'pas', 'update', 'error', 'komplain', 'fast', 'respon', 'solusi'],
#  ['engga',
#   'kapok',
#   'layan',
#   'super',
#   'dengar',
#   'komplain',
#   'langgan',
#   'langgan',
#   'kompalin',
#   'tetbaik',
#   'dengar',
#   'terkadang',
#   'fiturr',
#   'chat',
#   'mati',
#   'layan'],
#  ['maaf',
#   'kenape',
#   'verifikasi',
#   'sms',
#   'susah',
#   'bug',
#   'verifikasi',
#   'sms',
#   'auto',
#   'mengisi',
#   'salah',
#   'kode',
#   'kode',
#   'tulis',
#   'ulang',
#   'hapus',
#   'keyboard',
#   'ngetik',
#   'angka',
#   'bug',
#   'ganggu',
#   'asli',
#   'ampas',
#   'aplikasi',
#   'tolong',
#   'kasi',
#   'hadeh',
#   'ecommerce',
#   'indonesia',
#   'gin',
#   'ampas',
#   'hadeuh'],
#  ['barang',
#   'bilang',
#   'siap',
#   'pas',
#   'transfer',
#   'chat',
#   'balas',
#   'aplikasi',
#   'jual'],
#  ['maaf', 'toko', 'kirim', 'sesuai', 'pesan', 'ulang', 'ulang'],
#  ['iklan', 'melulu', 'aplikasi', 'droppppp'],
#  ['toko', 'tipu'],
#  ['belanja',
#   'dilazada',
#   'garansi',
#   'uang',
#   'hoaks',
#   'barang',
#   'sesuai',
#   'tahu',
#   'return',
#   'dh'],
#  ['eror', 'kode', 'io', 'buin'],
#  ['aplikasi', 'ganggu'],
#  ['livenya',
#   'rekam',
#   'diposting',
#   'minggu',
#   'baju',
#   'postingan',
#   'minggu',
#   'blackpink',
#   'ulang',
#   'please',
#   'fans',
#   'mengatasnamakan',
#   'live',
#   'blackpink'],
#  ['sring',
#   'kcewa',
#   'ditoped',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'tolak',
#   'seller',
#   'sellernya',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'bareng',
#   'nanggung',
#   'ongkir',
#   'pdhl',
#   'ksalahan',
#   'seller',
#   'bareng',
#   'bukan',
#   'ssuai',
#   'deskripsi',
#   'lagi',
#   'brgnya',
#   'palsu',
#   'kmbalikan',
#   'bareng',
#   'proses',
#   'rumit',
#   'waktu',
#   'garis',
#   'bsarnya',
#   'seller',
#   'mrugikan',
#   'scara',
#   'materi',
#   'energi',
#   'waktu',
#   'heran',
#   'tu',
#   'seller',
#   'sampai',
#   'hari',
#   'masih',
#   'bebas',
#   'jual',
#   'bareng',
#   'palsu',
#   'pdhl',
#   'bukti'],
#  ['aplikasi', 'aneh', 'search', 'produk', 'muncul'],
#  ['aplikasi',
#   'cek',
#   'pesan',
#   'gagal',
#   'antre',
#   'internet',
#   'offline',
#   'lancar',
#   'sesal',
#   'dowload',
#   'aplikasi'],
#  ['tanggung',
#   'koin',
#   'pakai',
#   'koin',
#   'kemarin',
#   'tanam',
#   'koin',
#   'siram',
#   'koin',
#   'koin',
#   'tolong',
#   'gin',
#   'pakai',
#   'jujur',
#   'pakai',
#   'koin',
#   'nama',
#   'glowindo'],
#  ['maaf', 'mesen', 'powerbank', 'pas', 'powerbank', 'rusak'],
#  ['error',
#   'main',
#   'game',
#   'segercep',
#   'kemarin',
#   'promo',
#   'cashbacknya',
#   'tarik',
#   'kemarin',
#   'harga',
#   'barang',
#   'murah',
#   'aplikasi',
#   'belah',
#   'pdhl',
#   'langgan',
#   'pakai',
#   'males',
#   'belanja',
#   'seru',
#   'promo',
#   'up',
#   'shopeepay',
#   'ribu',
#   'juta',
#   'hadiah',
#   'perak',
#   'gilir',
#   'orang',
#   'up',
#   'ribu',
#   'hadiah',
#   'voucher',
#   'emas',
#   'hadeuhh',
#   'fair'],
#  ['marketplace',
#   'kaku',
#   'atur',
#   'ubah',
#   'bikin',
#   'nyaman',
#   'jual',
#   'beli',
#   'kesini',
#   'ribet',
#   'sombong',
#   'maaf',
#   'berat',
#   'uninstall',
#   'makan',
#   'tu',
#   'atur',
#   'kamu'],
#  ['cod', 'cod', 'baku', 'hantam'],
#  ['bertanya', 'dowlod', 'nii'],
#  ['agen', 'call', 'center'],
#  ['tipu', 'aplikasi', 'yes', 'do', 'najis'],
#  ['sabar', 'matket', 'place', 'ribet', 'ribet', 'percaya'],
#  ['sen', 'paket', 'kont'],
#  ['maf',
#   'dowlod',
#   'aplikasi',
#   'garagara',
#   'misi',
#   'penhasil',
#   'saldo',
#   'andai',
#   'aduh',
#   'malas',
#   'dowlod'],
#  ['unduh', 'unduh', 'hidup', 'data', 'seluler', 'unduh', 'hapus'],
#  ['aplikasi',
#   'sengaja',
#   'hapus',
#   'unduh',
#   'lagi',
#   'gagal',
#   'terus',
#   'gmn',
#   'tolong',
#   'solusi',
#   'bayar',
#   'bayar',
#   'later'],
#  ['ongkir',
#   'gede',
#   'beli',
#   'barang',
#   'diskon',
#   'ongkir',
#   'nama',
#   'ongkir',
#   'barang',
#   'lebih baik',
#   'belah'],
#  ['bela',
#   'beli',
#   'wkwk',
#   'sayang',
#   'kaya',
#   'belah',
#   'prioritas',
#   'beli',
#   'tahu',
#   'beli',
#   'raja',
#   'layan',
#   'komplain',
#   'shope',
#   'banyak',
#   'alesan',
#   'gilir',
#   'ajak',
#   'debat',
#   'skak',
#   'ehh',
#   'cht',
#   'wkwkwkkw'],
#  ['jatuh',
#   'tempo',
#   'telpon',
#   'bayar',
#   'jam',
#   'bayar',
#   'bayar',
#   'apaaa',
#   'kesini',
#   'galogis',
#   'gaaakan',
#   'pakai',
#   'gituan',
#   'ribet'],
#  ['aju', 'paylater', 'tolak', 'loyal', 'aplikasi'],
#  ['voucher', 'gratis', 'ongkir', 'dipake', 'kntl'],
#  ['bayar',
#   'tagih',
#   'suruh',
#   'tunggu',
#   'proses',
#   'dana',
#   'salah',
#   'suruh',
#   'tunggu',
#   'dana'],
#  ['saldo',
#   'dana',
#   'beku',
#   'yabg',
#   'rp',
#   'ribu',
#   'tolong',
#   'akun',
#   'lapor',
#   'polisi',
#   'tolong',
#   'kirim',
#   'pesan',
#   'eamil',
#   'stolong',
#   'cepat',
#   'uang',
#   'tarik',
#   'pas',
#   'uang',
#   'beku',
#   'pas',
#   'beku',
#   'uang',
#   'pakai',
#   'butuh',
#   'gajelas'],
#  ['kesal', 'iklan'],
#  ['emangggg', 'tooopppp', 'margotop'],
#  ['order', 'batal', 'sistem'],
#  ['setia',
#   'aplikasi',
#   'aplikasi',
#   'banyak',
#   'mslah',
#   'lot',
#   'error',
#   'alih',
#   'kta',
#   'aplikasi',
#   'baca',
#   'ulas',
#   'tntg',
#   'males',
#   'untuk',
#   'install',
#   'hapus',
#   'sja'],
#  ['aplikasi',
#   'sampah',
#   'nyusahin',
#   'ribet',
#   'bget',
#   'promo',
#   'ikln',
#   'sesuai',
#   'pulsa',
#   'data',
#   'mahal',
#   'asliny'],
#  ['aplikasi', 'lot', 'berat', 'desain', 'ribet', 'beda', 'simpel', 'ringan'],
#  ['aplikasi', 'bgst', 'palir', 'tukang', 'ulah', 'babulu'],
#  ['goyang', 'knph', 'yh', 'klik', 'muncul'],
#  ['bikin', 'akun', 'username', 'salah', 'benar', 'username'],
#  ['kayak', 'siput'],
#  ['ongkir', 'mahal', 'barang', 'mahal', 'belah'],
#  ['saldo', 'juta', 'hangus'],
#  ['hoax', 'habisin', 'paket', 'data'],
#  ['bisa', 'diundh'],
#  ['iklan', 'muncul'],
#  ['kode', 'otp', 'order', 'order', 'verifikasi', 'no', 'telpon'],
#  ['sama', 'iklan'],
#  ['sekar',
#   'seringkali',
#   'belanja',
#   'reward',
#   'gold',
#   'aktif',
#   'shopeepaylater',
#   'mesti',
#   'suruh',
#   'topup',
#   'lagi',
#   'beribet',
#   'konfirmasi'],
#  ['males', 'iklan', 'melulu'],
#  ['maaf',
#   'kirim',
#   'nama',
#   'hj',
#   'leni',
#   'kebeneran',
#   'sen',
#   'aneh',
#   'yahhh',
#   'nmer',
#   'handphone',
#   'nmer',
#   'tapi',
#   'nama',
#   'alamat',
#   'persis',
#   'tapi',
#   'pribadi',
#   'kirim',
#   'misterius',
#   'sya',
#   'bayar',
#   'pdhl',
#   'sen',
#   'diambio',
#   'bayar',
#   'kasi',
#   'kulir',
#   'nyaaaa'],
#  ['sen',
#   'apa',
#   'paket',
#   'dateng',
#   'rumah',
#   'adek',
#   'tindaktegas',
#   'jual',
#   'nakal'],
#  ['masukkan',
#   'kode',
#   'verifikasi',
#   'angka',
#   'smsnya',
#   'masukkan',
#   'dftr',
#   'failed'],
#  ['pilih',
#   'halaman',
#   'search',
#   'produk',
#   'tekan',
#   'back',
#   'kemarin',
#   'tombol',
#   'pojok',
#   'kanan',
#   'versi',
#   'akmask',
#   'mobile',
#   'pakai',
#   'wifi',
#   'sulit',
#   'koneksi',
#   'pakai',
#   'koneksi',
#   'data',
#   'lancar',
#   'tolong',
#   'tim'],
#  ['voucher', 'gratis', 'ongkir', 'tapi', 'pke', 'hedehh'],
#  ['maaf',
#   'jatuh',
#   'aplikasi',
#   'beritahu',
#   'admin',
#   'undi',
#   'hadiah',
#   'malah',
#   'korban',
#   'tipu',
#   'bnyak',
#   'ber',
#   'nama',
#   'jebak'],
#  ['eta', 'da'],
#  ['biaya', 'admin', 'mahal', 'jual', 'raih', 'untung', 'star', 'seller'],
#  ['up', 'dana', 'saldo', 'pindah', 'dompet', 'saldo', 'dompet', 'beku'],
#  ['tolong',
#   'tingkat',
#   'kait',
#   'proses',
#   'aju',
#   'food',
#   'proses',
#   'makan',
#   'optimal',
#   'kait',
#   'makan',
#   'barang'],
#  ['kaya',
#   'harga',
#   'diskon',
#   'pas',
#   'harga',
#   'diskon',
#   'harga',
#   'diskon',
#   'cek',
#   'out',
#   'harga',
#   'diskon',
#   'keranjang',
#   'harga',
#   'diskon',
#   'harga',
#   'beda',
#   'keranjang',
#   'keranjang',
#   'harga',
#   'asli',
#   'coret',
#   'cek',
#   'out',
#   'hargane',
#   'utuh',
#   'diskon',
#   'malesin'],
#  ['mem', 'beli', 'akun', 'bayar', 'beda', 'gambar', 'toko'],
#  ['rate', 'sesuai', 'alam', 'beli', 'sembunyi', 'seller', 'tanggung'],
#  ['unduh', 'pulsa', 'ribu', 'promo', 'dikit', 'pulsa'],
#  ['susa', 'membebahari'],
#  ['fitur', 'pilih', 'jasa', 'kirim'],
#  ['barang', 'akun', 'blok'],
#  ['kendala',
#   'spaylater',
#   'hubung',
#   'agen',
#   'bantu',
#   'lunas',
#   'cicil',
#   'sisa',
#   'sukses'],
#  ['aplikasi', 'belanja', 'akurat', 'percaya'],
#  ['kirim', 'tera', 'maksimal', 'tanggal', 'kirim', 'tanggal'],
#  ['ulas',
#   'bintang',
#   'ikutin',
#   'karnakan',
#   'aplikasi',
#   'bangkrut',
#   'layan',
#   'langgan',
#   'ulas',
#   'ulas',
#   'mudah',
#   'retas',
#   'beli',
#   'topeng',
#   'mahal',
#   'ongkir',
#   'habis',
#   'topeng'],
#  ['daftar', 'belanja', 'bisaaa'],
#  ['konyol',
#   'beli',
#   'jam',
#   'salah',
#   'klik',
#   'barang',
#   'barang',
#   'duit',
#   'hangus',
#   'customer service',
#   'susah',
#   'hubung'],
#  ['ongkos', 'dilembalikan'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['belanja', 'stock', 'kosong'],
#  ['aplikasi', 'rena', 'voucher', 'alas', 'pesan'],
#  ['aplikasi', 'jellllekkkkk', 'akun', 'member', 'daftar', 'spaylater', 'akun'],
#  ['aplikasi', 'lambat'],
#  ['maaf',
#   'unduh',
#   'ulang',
#   'verifikasi',
#   'emain',
#   'no',
#   'tlf',
#   'pakek',
#   'hilang',
#   'aktif',
#   'cek',
#   'aplikasi',
#   'mytelkomsel',
#   'aktif',
#   'no',
#   'tlf',
#   'november',
#   'tolong',
#   'akal'],
#  ['balance', 'belanja', 'susah', 'dirarik'],
#  ['belanja',
#   'simpan',
#   'troli',
#   'bayar',
#   'jarak',
#   'update',
#   'updatenya',
#   'kelar',
#   'aplikasi',
#   'pakai',
#   'belanja',
#   'saldo',
#   'dana',
#   'bayar'],
#  ['nyaman',
#   'pakai',
#   'ehk',
#   'kesal',
#   'pesan',
#   'bareng',
#   'brngnya',
#   'slh',
#   'ktnya',
#   'tanggung',
#   'ehk',
#   'ngilang',
#   'tanggung'],
#  ['aplikasi', 'benar', 'njir'],
#  ['shopi', 'cod'],
#  ['sekian',
#   'pakai',
#   'ken',
#   'pakai',
#   'gegara',
#   'bosen',
#   'aplikasi',
#   'belah',
#   'pas',
#   'login',
#   'nomor',
#   'nonaktif',
#   'tolong',
#   'mudah',
#   'daftar',
#   'pakai',
#   'mail',
#   'konfirmasi',
#   'pilih',
#   'opsi',
#   'pakai',
#   'verifikasi',
#   'mail',
#   'google',
#   'account',
#   'seperti',
#   'gin',
#   'bingung',
#   'alhasil',
#   'bikin',
#   'account',
#   'males'],
#  ['lambat', 'lemod'],
#  ['order',
#   'barang',
#   'bom',
#   'sampai',
#   'samday',
#   'hilang',
#   'males',
#   'belanja',
#   'pagi',
#   'order',
#   'sore',
#   'sampai',
#   'pagi',
#   'order',
#   'bom',
#   'sampai'],
#  ['voucher', 'manipulasi', 'biji'],
#  ['super',
#   'lambat',
#   'jember',
#   'magelang',
#   'toko',
#   'cileduk',
#   'magelang',
#   'kapok',
#   'belanja'],
#  ['sayang',
#   'fitur',
#   'paylater',
#   'beli',
#   'barang',
#   'pulsa',
#   'tagih',
#   'listrik',
#   'pdam',
#   'tv',
#   'kabel'],
#  ['akun',
#   'block',
#   'ban',
#   'kah',
#   'akun',
#   'hilang',
#   'saldo',
#   'shoppe',
#   'hilang',
#   'beli',
#   'barang',
#   'impi',
#   'tua',
#   'smartphone'],
#  ['bintang',
#   'menu',
#   'bayar',
#   'later',
#   'kredit',
#   'aplikasi',
#   'shopeeku',
#   'smtra',
#   'orang',
#   'paylater',
#   'solusi',
#   'ditambahin',
#   'belanja',
#   'bayar',
#   'laternya',
#   'tolong',
#   'jangan',
#   'beda',
#   'langgan',
#   'juga',
#   'sring',
#   'mesan',
#   'smtr',
#   'teman',
#   'mesan',
#   'bayar',
#   'later'],
#  ['anjink', 'aplikasi', 'iklan', 'ganggu', 'tahu'],
#  ['ongkir', 'horor', 'iklan', 'bebas', 'ongkir', 'ongkir', 'keri'],
#  ['flassale', 'beli', 'reload', 'taikkkkkkkkkkkk'],
#  ['toko',
#   'filter',
#   'toko',
#   'toko',
#   'nakal',
#   'beli',
#   'mobil',
#   'remot',
#   'gantung'],
#  ['unduh', 'gagal', 'unduh', 'huh', 'belanja'],
#  ['dana',
#   'smp',
#   'skrng',
#   'transfer',
#   'rekening',
#   'telfon',
#   'customer',
#   'service',
#   'selalu',
#   'suruh',
#   'tunggu',
#   'sdah',
#   'hmpir',
#   'trnsferan',
#   'rekening',
#   'nunngu'],
#  ['belanja',
#   'pesan',
#   'sepatu',
#   'baju',
#   'aju',
#   'dana',
#   'barang',
#   'pesan',
#   'aju',
#   'dana',
#   'tingkat',
#   'kualitas',
#   'layan',
#   'hack'],
#  ['basi',
#   'keluarga',
#   'akun',
#   'promo',
#   'alas',
#   'alamat',
#   'keluarga',
#   'rumah',
#   'alamat',
#   'pakai',
#   'alamat',
#   'tetangga',
#   'pakai',
#   'bacot'],
#  ['kuis', 'aplikasi', 'ram', 'ruang', 'hadiah', 'capek'],
#  ['maaf', 'lebe', 'ongkir'],
#  ['ken',
#   'login',
#   'akun',
#   'susah',
#   'tunggu',
#   'sms',
#   'smsnya',
#   'bangke',
#   'capek',
#   'nungguin'],
#  ['tolong', 'bebas', 'milih', 'ekspedisi', 'jnt'],
#  ['kolom', 'cari', 'ngebug', 'melulu', 'anjg'],
#  ['tolong',
#   'kirim',
#   'layan',
#   'express',
#   'kur',
#   'barang',
#   'asing',
#   'konfirmasi',
#   'barang',
#   'elektronik',
#   'harga'],
#  ['shopeepay',
#   'emas',
#   'kirim',
#   'minimal',
#   'minggu',
#   'aneh',
#   'pakai',
#   'cod',
#   'why',
#   'perbaikin',
#   'tolong',
#   'reseller',
#   'tipu',
#   'tindak',
#   'bnyak',
#   'korban',
#   'beli'],
#  ['versi',
#   'ringan',
#   'update',
#   'versi',
#   'bin',
#   'lot',
#   'pakai',
#   'internet',
#   'cepat',
#   'mbps',
#   'bayangin',
#   'cepat',
#   'aplikasi',
#   'belanja',
#   'konten',
#   'nongol',
#   'alias',
#   'susah',
#   'update',
#   'versi',
#   'sekarang',
#   'auto',
#   'aplikasi',
#   'kaliyan',
#   'yuk',
#   'komentar',
#   'aplikasi'],
#  ['kurir', 'kirim', 'timika', 'papua', 'belanja', 'uninstal'],
#  ['barang', 'sampah'],
#  ['tolong',
#   'verifikasi',
#   'ganti',
#   'akun',
#   'mudah',
#   'akun',
#   'email',
#   'no',
#   'handphone',
#   'ganti',
#   'akun',
#   'double',
#   'akun',
#   'hadehh'],
#  ['seler',
#   'tolong',
#   'atur',
#   'ketat',
#   'order',
#   'barang',
#   'transfer',
#   'barang',
#   'jalan',
#   'cancel',
#   'uang',
#   'jangka',
#   'sampai',
#   'minggu'],
#  ['maap', 'sekarng', 'aplikasi', 'yoko', 'tida', 'mwnanggapi'],
#  ['devolepor',
#   'mesti',
#   'tipu',
#   'cashback',
#   'gratis',
#   'ongkir',
#   'iklan',
#   'tv',
#   'gratis',
#   'ongkir',
#   'minimum',
#   'belanja',
#   'belanja'],
#  ['easi',
#   'soping',
#   'pt',
#   'karisma',
#   'bahana',
#   'gemilang',
#   'tipu',
#   'suruh',
#   'mutar',
#   'lotery',
#   'lucki',
#   'miliader',
#   'rodah',
#   'henti',
#   'angka',
#   'miliard',
#   'hasil',
#   'rezeki',
#   'bukti',
#   'hoaks',
#   'tahu',
#   'almat',
#   'easi',
#   'soping',
#   'pulsa',
#   'informasi',
#   'hitung',
#   'buta',
#   'hukum',
#   'hak',
#   'tuhan',
#   'yesus',
#   'kutuk',
#   'cilakalah',
#   'binasa',
#   'kru',
#   'easy',
#   'soping',
#   'musiba',
#   'tabrak',
#   'maut',
#   'do',
#   'putra',
#   'flores',
#   'korban',
#   'tipu',
#   'amin',
#   'easi',
#   'soping',
#   'utang',
#   'timor'],
#  ['kode', 'otp', 'kirim', 'checkout'],
#  ['waaah',
#   'shoppi',
#   'benar',
#   'kirim',
#   'srkng',
#   'kesel',
#   'tunggu',
#   'jakarta',
#   'palembang',
#   'kemarin',
#   'kadang',
#   'sampai',
#   'sik',
#   'jasa',
#   'kirim',
#   'hadeh',
#   'langgan',
#   'pindah',
#   'aplikasi',
#   'tolong',
#   'seperti',
#   'jasa',
#   'kirim',
#   'yok',
#   'yok',
#   'seperti',
#   'jasa',
#   'kirim'],
#  ['bikin', 'emosi', 'tombal', 'batal', 'transaksi'],
#  ['pelit',
#   'gara',
#   'score',
#   'game',
#   'menu',
#   'bilang',
#   'main',
#   'normal',
#   'normal',
#   'ranking',
#   'voucher'],
#  ['kirim', 'lambattt', 'sen'],
#  ['platform', 'jaz'],
#  ['tunggu', 'jam', 'terintal', 'intal'],
#  ['tipu',
#   'hadiah',
#   'google',
#   'chrom',
#   'ujung',
#   'sruh',
#   'donlot',
#   'aplikasi',
#   'tapi',
#   'hadiah',
#   'bisa',
#   'ambil',
#   'dasar',
#   'tukang',
#   'tipu',
#   'pngen',
#   'bnyak',
#   'pngguna',
#   'tapi',
#   'pakai',
#   'mutu'],
#  ['aplikasi', 'nyaa', 'bagetttt', 'boooooggg'],
#  ['aplikasi', 'lihah', 'kopon', 'lodingnya'],
#  ['sesuai',
#   'iklan',
#   'iklan',
#   'promo',
#   'diskon',
#   'bebas',
#   'ongkir',
#   'promo',
#   'bayar',
#   'cod',
#   'bayar',
#   'bikin'],
#  ['kemarin',
#   'kasi',
#   'bintang',
#   'skarang',
#   'ganti',
#   'respon',
#   'pas',
#   'dana',
#   'barang',
#   'kirim',
#   'kasi',
#   'kabar',
#   'dana',
#   'jual',
#   'barang',
#   'uang',
#   'kontak',
#   'jual',
#   'hati',
#   'kirim'],
#  ['hancur',
#   'tokopoint',
#   'daerah',
#   'pakai',
#   'kupon',
#   'diskon',
#   'batal',
#   'transfer',
#   'alas',
#   'langgar',
#   'klu',
#   'jangan',
#   'kupon',
#   'diskon',
#   'pdahal',
#   'hancur',
#   'updatenya',
#   'maaf',
#   'uninstal',
#   'pindah',
#   'toko',
#   'belah',
#   'lebih baik'],
#  ['uninstal', 'dominan', 'toko', 'orange'],
#  ['unduh', 'kenapa', 'pas', 'taut', 'suruh', 'dwonload'],
#  ['layan',
#   'tunggu',
#   'pesan',
#   'tampa',
#   'update',
#   'kirim',
#   'batal',
#   'kirim',
#   'tampa',
#   'terang'],
#  ['bodo', 'aplikasi', 'gratis', 'ongkir', 'bayar', 'ongkir', 'mahal'],
#  ['tol', 'aplikasi'],
#  ['update',
#   'aplikasi',
#   'selalu',
#   'ngeblank',
#   'ngetik',
#   'cari',
#   'barang',
#   'susah',
#   'brng',
#   'keranjang',
#   'bisa',
#   'hapus',
#   'msih',
#   'banyak',
#   'setelah',
#   'update',
#   'perbaikin',
#   'bug'],
#  ['limit', 'spaylater', 'bayar', 'jatuh', 'tempo'],
#  ['mahal', 'beda', 'selisih', 'bangetttttt'],
#  ['maaf', 'transaksi', 'shopeepay', 'shopeepay', 'later', 'limit'],
#  ['minimal',
#   'belanja',
#   'ribu',
#   'free',
#   'ongkir',
#   'kaget',
#   'belanja',
#   'butuh',
#   'rumah',
#   'ongkir',
#   'langit',
#   'alih',
#   'pindah',
#   'belanja',
#   'toko',
#   'belah',
#   'free',
#   'ongkir'],
#  ['sembako', 'kupon', 'utuh'],
#  ['beli', 'paket', 'sertifikat', 'dashboard'],
#  ['kemarin',
#   'pesan',
#   'pesan',
#   'batal',
#   'dana',
#   'transfer',
#   'untuk',
#   'dana',
#   'tolong',
#   'rekening',
#   'akun',
#   'nama',
#   'masukkan',
#   'rekening',
#   'seller',
#   'aktif'],
#  ['dana',
#   'pesan',
#   'batal',
#   'dana',
#   'rekening',
#   'perhati',
#   'langgan',
#   'sulit',
#   'uang',
#   'hak',
#   'tolong',
#   'dana'],
#  ['deret', 'ssrx', 'det', 'er'],
#  ['mecahin',
#   'telur',
#   'update',
#   'koin',
#   'update',
#   'gratis',
#   'ongkir',
#   'update',
#   'update',
#   'padal',
#   'update',
#   'tetep',
#   'update',
#   'kuota',
#   'habis',
#   'update',
#   'aplikasi',
#   'ginian',
#   'tolong',
#   'perintah',
#   'update',
#   'rang'],
#  ['jgan',
#   'belanja',
#   'barang',
#   'pesan',
#   'barang',
#   'ngk',
#   'sesuai',
#   'sya',
#   'mesan',
#   'baju',
#   'celana',
#   'bokser',
#   'pendek'],
#  ['beri',
#   'kupon',
#   'diskon',
#   'pas',
#   'belanja',
#   'pesan',
#   'batal',
#   'otomatis',
#   'kupon',
#   'pakai',
#   'lagi',
#   'kupon',
#   'diskon',
#   'rugi'],
#  ['tracking',
#   'paket',
#   'jalan',
#   'web',
#   'kurir',
#   'cek',
#   'jalan',
#   'asa',
#   'belanja',
#   'gin'],
#  ['aplikasi',
#   'go',
#   'internasional',
#   'urus',
#   'tagih',
#   'spaylatter',
#   'spinjam',
#   'nada',
#   'bicara',
#   'pesan',
#   'ngalahin',
#   'rentenir',
#   'mkn',
#   'bangku',
#   'sekolah',
#   'bunga',
#   'gede',
#   'dibyr',
#   'cicil',
#   'masih',
#   'orang',
#   'peres',
#   'layak',
#   'hutang',
#   'ratus',
#   'juta',
#   'miris',
#   'gaji',
#   'krywn',
#   'hasil',
#   'paksa',
#   'pinjam',
#   'ksh',
#   'kenal',
#   'lagi',
#   'zaman',
#   'lagi',
#   'covid',
#   'tegang',
#   'aplikasi',
#   'sblh',
#   'move',
#   'on'],
#  ['aplikasi', 'mahal', 'ongkir', 'harga', 'normal'],
#  ['lot', 'loading', 'terusssss'],
#  ['beli',
#   'dishopee',
#   'jual',
#   'tanggung',
#   'barang',
#   'kirim',
#   'salah',
#   'dana',
#   'barang'],
#  ['iklan', 'paksa', 'resah', 'hadeh'],
#  ['bayar', 'pakai', 'dana', 'unistal'],
#  ['iklanya', 'menggangu'],
#  ['mh', 'transaksi', 'ny', 'eror', 'terusssssss'],
#  ['akun',
#   'non',
#   'aktif',
#   'beku',
#   'langgar',
#   'atur',
#   'aplikasi',
#   'banned',
#   'kominfo',
#   'beli',
#   'latih',
#   'aplikasi',
#   'lulus',
#   'sertifikat',
#   'skill',
#   'academy',
#   'lapor',
#   'instansi',
#   'taung',
#   'bekerjasama',
#   'aplikasi',
#   'sertifikat',
#   'latih',
#   'muncul',
#   'dashboard',
#   'akun',
#   'tipu',
#   'publik'],
#  ['penguna', 'ambil', 'rp', 'kocak'],
#  ['jelekkk',
#   'bangett',
#   'voucher',
#   'beli',
#   'kaos',
#   'toko',
#   'dibatalinn',
#   'uang',
#   'balik',
#   'kejebakk',
#   'saldo',
#   'ambil',
#   'gabisaa',
#   'pakai',
#   'dana',
#   'pakeovo',
#   'gabisaa',
#   'gabanyakk',
#   'namnaya',
#   'uang'],
#  ['daftar', 'kode', 'frivikasi', 'muncul', 'muncul'],
#  ['aplikasi',
#   'bohong',
#   'pakai',
#   'sopepay',
#   'susah',
#   'kode',
#   'otp',
#   'kirim',
#   'bonuss',
#   'akun',
#   'saldo',
#   'ribu',
#   'tipu'],
#  ['habisin', 'kuota', 'update', 'profil', 'sampai', 'kiamat'],
#  ['pesan',
#   'cancel',
#   'kirim',
#   'kirim',
#   'gmn',
#   'jual',
#   'verifikasi',
#   'sopenya',
#   'solusi',
#   'gmn'],
#  ['limit', 'shopeepaylater', 'rp', 'cicil', 'lunas'],
#  ['spaylater', 'diaktivasi', 'gagal'],
#  ['kirain',
#   'harga',
#   'murah',
#   'wkwkwkwk',
#   'diskon',
#   'pelit',
#   'maaf',
#   'auto',
#   'uninstal'],
#  ['cashback',
#   'bukareksa',
#   'promo',
#   'reksajul',
#   'reksajul',
#   'reksaaug',
#   'reksaaug',
#   'hitung',
#   'cashback',
#   'komplain',
#   'ulang',
#   'tunggu',
#   'seninggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'tahan',
#   'dana',
#   'jual'],
#  ['update', 'susah'],
#  ['barang', 'manaaaaa'],
#  ['rugi', 'beli', 'realpeack'],
#  ['aplikasi', 'nyampah'],
#  ['terimah', 'pesan', 'barangx', 'cepat', 'kirim'],
#  ['lindung',
#   'konsumen',
#   'tipu',
#   'seller',
#   'kayak',
#   'barang',
#   'butuh',
#   'minggu'],
#  ['akun',
#   'transaksi',
#   'kemarin',
#   'beli',
#   'promo',
#   'klaim',
#   'langgar',
#   'pdhal',
#   'transaksi',
#   'aju',
#   'kpan',
#   'langgar',
#   'internal',
#   'customer',
#   'bukti'],
#  ['kesini', 'aplikasi', 'kok', 'bayar', 'eror', 'gakda', 'solusi', 'aplikasi'],
#  ['update',
#   'versi',
#   'hubung',
#   'ulang',
#   'kolom',
#   'feed',
#   'tolong',
#   'nyaman',
#   'handphone',
#   'samsung',
#   'profesional'],
#  ['tarik', 'dana'],
#  ['aplikasi', 'layan'],
#  ['bnayak', 'update'],
#  ['sistem', 'error'],
#  ['bertanya',
#   'event',
#   'paket',
#   'data',
#   'pulsa',
#   'perak',
#   'tu',
#   'boongan',
#   'ubah',
#   'bintang',
#   'kecuali',
#   'please'],
#  ['sanggat', 'kecewaa'],
#  ['aju', 'hapus', 'akun', 'ribet'],
#  ['rugi', 'tolong', 'uang'],
#  ['krkurangan',
#   'transaksi',
#   'aplikasi',
#   'tampil',
#   'wahhh',
#   'sistem',
#   'transaksi',
#   'normal'],
#  ['barang', 'rusak', 'jual', 'gemanay'],
#  ['uda', 'bayar', 'bom', 'sampai'],
#  ['transfer', 'airpayinternal', 'beli', 'barang', 'batal', 'dana', 'tidak'],
#  ['jangan',
#   'unduh',
#   'bnyak',
#   'pnipuan',
#   'jual',
#   'buukn',
#   'brang',
#   'asli',
#   'rport',
#   'smaa',
#   'bnyak',
#   'unsur',
#   'penipuann'],
#  ['transaksi', 'batal', 'aplikasi', 'jelasssss'],
#  ['belanja',
#   'gilir',
#   'belanja',
#   'poin',
#   'ktanya',
#   'cod',
#   'isi',
#   'pdhl',
#   'pakai',
#   'ongkir',
#   'bebas',
#   'ongkir',
#   'moduss',
#   'kopeeet'],
#  ['saldo', 'hasil', 'refund', 'belanja'],
#  ['aplikasi', 'bohong', 'diskon', 'pas', 'tunggu', 'tunggu', 'unduh'],
#  ['ribet',
#   'jual',
#   'cair',
#   'dana',
#   'beli',
#   'sesuai',
#   'terang',
#   'terang',
#   'sampai',
#   'oktober',
#   'konfirmasi',
#   'beli',
#   'dana',
#   'otomatis',
#   'jual',
#   'oktober',
#   'dana',
#   'tahan',
#   'terang',
#   'bikin',
#   'jual',
#   'harap'],
#  ['kaya', 'massa', 'pesan', 'barang'],
#  ['komentar',
#   'hapus',
#   'nanti',
#   'ketik',
#   'pergi',
#   'hibur',
#   'nanti',
#   'ketik',
#   'komen',
#   'hapus',
#   'shoope',
#   'asw',
#   'salin',
#   'komen',
#   'hapus',
#   'tinggal',
#   'paste',
#   'dikomen',
#   'sembuyikan',
#   'komen',
#   'hapus',
#   'komen',
#   'ketik',
#   'salin',
#   'komen',
#   'hapus',
#   'shoope',
#   'update',
#   'macet',
#   'pantang',
#   'nyerah',
#   'ubah',
#   'santet',
#   'balesanya',
#   'santet'],
#  ['aplikasi', 'unduh'],
#  ['ongkir', 'mahal', 'tolong', 'murahin', 'kayak', 'pandemi', 'uang'],
#  ['komplain', 'ribet'],
#  ['freeong',
#   'belanja',
#   'ribu',
#   'freeong',
#   'belanja',
#   'freeong',
#   'pindah',
#   'market',
#   'place'],
#  ['belanja',
#   'beli',
#   'jual',
#   'biaya',
#   'adminnya',
#   'toko',
#   'dibanned',
#   'pajak',
#   'negara',
#   'ken',
#   'untung',
#   'buntung'],
#  ['ambisi', 'unt', 'unduh', 'iklan', 'muntah', 'tarik', 'belanja', 'turun'],
#  ['bayar', 'sayang', 'bayar'],
#  ['cuman', 'aplikasi', 'gilir', 'girim'],
#  ['aplikasi', 'rancang', 'tipu'],
#  ['aplikasi', 'maksa', 'ta', 'ekkkkkkkkkkkk', 'anjinkkkkkkkkk'],
#  ['iklan', 'asli', 'jlek', 'tipu', 'belanja', 'batal', 'otomatis'],
#  ['update', 'ui', 'user', 'friendly'],
#  ['sesuai', 'iklan'],
#  ['reses', 'iklan', 'bikin', 'risih', 'unduh'],
#  ['shoope',
#   'iklan',
#   'spam',
#   'melulu',
#   'renti',
#   'seperti',
#   'lagi',
#   'main',
#   'ml',
#   'iklan',
#   'shoope'],
#  ['kesini', 'lambat', 'njir', 'pakai', 'wifi', 'ram'],
#  ['iklan', 'ngabisin', 'kuota'],
#  ['sponsor', 'broser', 'unduh', 'aplikasi', 'melulu', 'susah', 'pusing'],
#  ['tiktok',
#   'iklan',
#   'toko',
#   'terus',
#   'diam',
#   'jan',
#   'ganggu',
#   'seru',
#   'nonton',
#   'tiktokk'],
#  ['update', 'koneksi', 'bikin', 'kesel'],
#  ['aju', 'tolak', 'spaylaternya', 'hadeh', 'bintang', 'atulah'],
#  ['ongkos',
#   'kirim',
#   'ribu',
#   'voucernya',
#   'sus',
#   'sope',
#   'bayar',
#   'cod',
#   'voucer',
#   'gratis',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'beli',
#   'kasi',
#   'voucher',
#   'sisa',
#   'rebut',
#   'icon',
#   'free',
#   'ogkir',
#   'hilang'],
#  ['aplikasi',
#   'nyampe',
#   'tangal',
#   'nyampenya',
#   'tangal',
#   'aplikasi',
#   'bohong',
#   'install',
#   'aplikasi',
#   'dasar',
#   'aplikasi',
#   'penbohong'],
#  ['beli',
#   'case',
#   'handphone',
#   'negeri',
#   'cari',
#   'produk',
#   'negeri',
#   'cari',
#   'case',
#   'negeri',
#   'negeri',
#   'gmn',
#   'solusi'],
#  ['bayar', 'suruh', 'tunggu', 'jam', 'jam', 'akun', 'blokirr', 'tanggung'],
#  ['susah', 'unduh'],
#  ['mengambil',
#   'gratis',
#   'ongkir',
#   'nominal',
#   'ongkir',
#   'ny',
#   'gede',
#   'sedih',
#   'kadang',
#   'barang',
#   'pes',
#   'mahal',
#   'ongkir'],
#  ['jual',
#   'ragu',
#   'waswas',
#   'sampai',
#   'opsi',
#   'pilih',
#   'asuransi',
#   'halaman',
#   'cek',
#   'out',
#   'produk',
#   'kalah',
#   'toko',
#   'online',
#   'belah',
#   'opsi',
#   'asuransi',
#   'pas',
#   'kantor',
#   'ribet',
#   'karyawan',
#   'admin',
#   'paham',
#   'menbahkan',
#   'asuransi',
#   'profesional',
#   'kacau'],
#  ['jual', 'buku', 'baja', 'liar', 'belanja', 'nyaman'],
#  ['kesini', 'pas', 'unduh', 'video', 'gugel'],
#  ['beli',
#   'produk',
#   'pas',
#   'gilir',
#   'beli',
#   'kamera',
#   'oppo',
#   'nyala',
#   'tolong',
#   'tindak',
#   'lanjutin',
#   'jual'],
#  ['dagang',
#   'nakal',
#   'daripahda',
#   'bikin',
#   'promo',
#   'tv',
#   'lebih baik',
#   'aplikasi'],
#  ['respon',
#   'tolong',
#   'toko',
#   'toko',
#   'amanah',
#   'jual',
#   'respon',
#   'makan',
#   'pergi',
#   'hilang',
#   'konsumen',
#   'keluh',
#   'diam'],
#  ['iklan',
#   'lebih baik',
#   'pas',
#   'nonton',
#   'youtube',
#   'nonton',
#   'halaman',
#   'utama',
#   'layar',
#   'tolong',
#   'iklan'],
#  ['beli',
#   'tas',
#   'gunung',
#   'minggu',
#   'sepatu',
#   'roda',
#   'tipu',
#   'amanah',
#   'pesan',
#   'tas',
#   'kamu',
#   'sepatu',
#   'roda',
#   'gin',
#   'hapus',
#   'aplikashi',
#   'amanah'],
#  ['plis',
#   'batal',
#   'pesan',
#   'ubah',
#   'pikir',
#   'kirimm',
#   'allah',
#   'tolong',
#   'rugi',
#   'bangett'],
#  ['update', 'melulu'],
#  ['from', 'zero', 'hero'],
#  ['ngk', 'gratis', 'ongir'],
#  ['customer',
#   'service',
#   'layan',
#   'nelpon',
#   'butuh',
#   'customer service',
#   'sopan',
#   'santun',
#   'mati',
#   'panggil',
#   'pulsa'],
#  ['aman',
#   'aman',
#   'gilir',
#   'kirim',
#   'barang',
#   'tim',
#   'ehh',
#   'hasil',
#   'nol',
#   'konfirmasi',
#   'bukti',
#   'adu',
#   'tim',
#   'jangan',
#   'harap'],
#  ['staff', 'tolong', 'profesional', 'beda', 'gratis', 'ongkir', 'sedih'],
#  ['ongkir', 'mahal'],
#  ['belanja',
#   'komplain',
#   'sanggup',
#   'sarat',
#   'berat',
#   'bangat',
#   'suruh',
#   'bikin',
#   'video',
#   'youtuber',
#   'nomor',
#   'seri',
#   'bukti',
#   'foto',
#   'lanjur',
#   'paket',
#   'wuish',
#   'nang',
#   'beli'],
#  ['shope', 'bayar', 'qd', 'blokir', 'salah'],
#  ['muncul', 'iklan', 'internet', 'otomatis', 'kesini', 'orang', 'maksa'],
#  ['maaf', 'sen', 'apa', 'dateng', 'tolong'],
#  ['jangan', 'kirim', 'promo', 'handphone', 'tarik', 'ganggu'],
#  ['erti', 'beli', 'latih', 'kartu', 'gagal', 'tipu', 'kayak', 'gin'],
#  ['jan', 'maksa', 'install'],
#  ['mntep', 'shopefood'],
#  ['cobakalau',
#   'promosi',
#   'tipu',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ongkir',
#   'gede',
#   'harga',
#   'barang'],
#  ['kesini', 'gara', 'google', 'crome', 'ribu'],
#  ['update', 'klik', 'toko'],
#  ['cerita', 'shopi', 'hoax'],
#  ['curang', 'event', 'event', 'sistem', 'talu', 'lot', 'sistem', 'jadul'],
#  ['kirim', 'pesan', 'kayak', 'buka', 'kirim', 'dikit', 'tinggal', 'buka'],
#  ['ualah', 'tahu', 'cod', 'biaya', 'nang', 'xixixixixididi'],
#  ['apdead', 'paylater'],
#  ['aplikasi',
#   'belanja',
#   'seller',
#   'blokir',
#   'toko',
#   'tanggung',
#   'rugi',
#   'beli'],
#  ['aplikasi', 'cuman', 'iklan', 'ganggu', 'anjeng'],
#  ['trooble', 'tuuuerruusss'],
#  ['berat',
#   'beli',
#   'setia',
#   'beli',
#   'barang',
#   'harga',
#   'juta',
#   'tipu',
#   'beli',
#   'ebook',
#   'tips',
#   'jitu',
#   'isi',
#   'screen',
#   'shot',
#   'kirim',
#   'biji',
#   'admin',
#   'tolak',
#   'adu',
#   'sungguh',
#   'menang',
#   'tipu',
#   'kayak',
#   'gin',
#   'lebih baik',
#   'unistall',
#   'jamin',
#   'aman',
#   'beli',
#   'tipu',
#   'bukalapa'],
#  ['tolong',
#   'aplikasi',
#   'muslim',
#   'profesional',
#   'solat',
#   'iklan',
#   'menganggu',
#   'muslim',
#   'profesional',
#   'tutup',
#   'aplikasi',
#   'kesel',
#   'maaf',
#   'ulas',
#   'salah',
#   'salah',
#   'seller',
#   'tanggung',
#   'tindak'],
#  ['benar',
#   'bikin',
#   'murka',
#   'pesan',
#   'sya',
#   'sesuai',
#   'chat',
#   'seller',
#   'tidak',
#   'etikad',
#   'baca',
#   'tolong',
#   'smpein',
#   'toko',
#   'ling',
#   'hong',
#   'jual',
#   'amanah'],
#  ['harga',
#   'dimainin',
#   'aplikasi',
#   'pilih',
#   'warna',
#   'size',
#   'harga',
#   'ubah',
#   'tertawa',
#   'capek',
#   'capek',
#   'milih',
#   'mlototin',
#   'order',
#   'harga',
#   'sesuai',
#   'tema',
#   'stop',
#   'gunain'],
#  ['aplikasi', 'aneh', 'barang', 'bayar', 'batal', 'aplikasi'],
#  ['susah', 'loadingnya'],
#  ['shope',
#   'plis',
#   'mengundng',
#   'teman',
#   'verif',
#   'ktp',
#   'teman',
#   'bom',
#   'bikin',
#   'ktf',
#   'macam',
#   'plis',
#   'rakyat',
#   'indonesia',
#   'even'],
#  ['daya', 'bayar', 'ngeblank'],
#  ['kada', 'baikk'],
#  ['akun',
#   'hack',
#   'atm',
#   'akun',
#   'pinjam',
#   'uang',
#   'jt',
#   'block',
#   'aplikasi',
#   'aman'],
#  ['masak',
#   'aju',
#   'spaylater',
#   'bayar',
#   'kartu',
#   'kredit',
#   'mengunakan',
#   'aplikasi',
#   'shoppee',
#   'lah',
#   'kartu',
#   'kredit',
#   'ngk',
#   'shopeepay',
#   'aneh',
#   'shoppe',
#   'limit',
#   'ngk'],
#  ['ribet', 'sen', 'gratis', 'ongkir'],
#  ['sesal', 'nang', 'akun', 'blok'],
#  ['sama',
#   'aplikasi',
#   'pilih',
#   'transaksi',
#   'batalakan',
#   'dn',
#   'belah',
#   'transaksi',
#   'sampai',
#   'tunggu',
#   'minggu',
#   'uang'],
#  ['sakit', 'killik', 'kirim', 'barang'],
#  ['hapus',
#   'aju',
#   'phaylater',
#   'tolak',
#   'muncul',
#   'tawar',
#   'phaylater',
#   'aju',
#   'tolak'],
#  ['maaf',
#   'pakai',
#   'aplikasi',
#   'ajh',
#   'gratis',
#   'ongkir',
#   'minggu',
#   'ganti',
#   'handphone',
#   'unduh',
#   'teman',
#   'kenapa',
#   'potong',
#   'ongkir'],
#  ['aplikasi', 'sempurna'],
#  ['sen',
#   'barang',
#   'dilazada',
#   'tahu',
#   'tahu',
#   'kurir',
#   'dateng',
#   'rumah',
#   'tas',
#   'slempang',
#   'bayar',
#   'sen',
#   'sen',
#   'dateng',
#   'gmn',
#   'hapus',
#   'akun'],
#  ['transaksi',
#   'batal',
#   'recommended',
#   'belanja',
#   'lebih baik',
#   'pakai',
#   'mudah',
#   'aman',
#   'ribet',
#   'iming',
#   'gratis',
#   'ongkir',
#   'tahu',
#   'fiktif',
#   'google',
#   'mereview',
#   'aplikasi',
#   'ngrugiin'],
#  ['kirim',
#   'lambattt',
#   'bngettt',
#   'proses',
#   'toko',
#   'belah',
#   'cepat',
#   'tolong',
#   'koreksi'],
#  ['aneh', 'transaksi', 'anggap', 'pesan', 'batal', 'alas', 'nila', 'fitnah'],
#  ['toko', 'ngentodddd'],
#  ['cepat',
#   'install',
#   'oo',
#   'penuh',
#   'lah',
#   'simpan',
#   'takbisa',
#   'ookesel',
#   'capek',
#   'huudan',
#   'baguss',
#   'oooooooooo'],
#  ['bangke', 'beli', 'paket', 'data', 'suruh', 'tunggu', 'tutup'],
#  ['klaim', 'barang', 'rp'],
#  ['susah', 'cek', 'out', 'lancar'],
#  ['aplikasi',
#   'cantemer',
#   'servis',
#   'sms',
#   'alibi',
#   'aju',
#   'pinjam',
#   'dana',
#   'aju',
#   'pinjam',
#   'dana',
#   'aplikasi',
#   'telepon',
#   'sms',
#   'ganggu'],
#  ['belanja', 'mudah'],
#  ['toko',
#   'vavio',
#   'acc',
#   'jual',
#   'chip',
#   'high',
#   'domino',
#   'tolong',
#   'band',
#   'sdah',
#   'bayar',
#   'suruh',
#   'batal',
#   'transaksi',
#   'aplikasi',
#   'skrng',
#   'tunggu',
#   'dana'],
#  ['bingung',
#   'jual',
#   'jujur',
#   'bilang',
#   'langgar',
#   'akun',
#   'batas',
#   'dana',
#   'beli',
#   'saldo',
#   'jual',
#   'beli',
#   'setia',
#   'hapus',
#   'bilang',
#   'curiga',
#   'toko',
#   'curiga',
#   'lancar',
#   'bayar',
#   'barang',
#   'beli',
#   'dishopee',
#   'bijak',
#   'seperti',
#   'sp',
#   'timbang'],
#  ['saring', 'jual', 'tipu', 'tayiiiilahhh'],
#  ['kanapa', 'barang', 'data', 'ng', 'sedangkab', 'mes', 'tipu'],
#  ['install',
#   'aplikasi',
#   'keamananya',
#   'kemarin',
#   'paket',
#   'tersesat',
#   'akun',
#   'mesan',
#   'log',
#   'out',
#   'akun',
#   'unistal',
#   'tahu',
#   'paket',
#   'ajar',
#   'real',
#   'alam',
#   'tolong',
#   'perhati'],
#  ['aplikasi', 'jlas', 'kirim', 'akun', 'cek', 'kosong'],
#  ['aplikasi', 'sungguh', 'sulit', 'paham', 'barang', 'batal', 'otomatis'],
#  ['tolong',
#   'dijelasin',
#   'aplikasi',
#   'klik',
#   'tapi',
#   'kluar',
#   'klik',
#   'kluar',
#   'lagi',
#   'klik',
#   'kluar',
#   'lagi',
#   'orang',
#   'belanja',
#   'tidak'],
#  ['sistem', 'jual', 'ekspedisi', 'ubah', 'rubah', 'ekspedisi'],
#  ['nggk', 'update', 'gim'],
#  ['balik', 'jasa', 'kirim'],
#  ['flash', 'sale', 'ngadat', 'anjeng'],
#  ['bayar', 'latter', 'bayar', 'sekarang', 'gabiisaa', 'butuh', 'baaanget'],
#  ['batas',
#   'kirim',
#   'seller',
#   'sistem',
#   'cod',
#   'kadang',
#   'kurir',
#   'rumah',
#   'rumah',
#   'kasihan',
#   'kurir',
#   'bolak',
#   'ngekost',
#   'titip',
#   'tetangga',
#   'tetangga'],
#  ['minggu', 'juga', 'pesan', 'detail', 'kirim', 'akurat'],
#  ['seller',
#   'nd',
#   'respon',
#   'proses',
#   'jual',
#   'kirim',
#   'kurir',
#   'nd',
#   'kayak',
#   'lari',
#   'dehh'],
#  ['ngeselin',
#   'aplikasi',
#   'beli',
#   'kirim',
#   'cepat',
#   'tapi',
#   'ngeselin',
#   'brli',
#   'barang',
#   'pengirimanya',
#   'minggu',
#   'kirim',
#   'tutup',
#   'batal',
#   'barang',
#   'begi',
#   'pindah',
#   'toko',
#   'online',
#   'belah',
#   'tolong',
#   'ekspedisi',
#   'instan',
#   'aktif',
#   'cepat',
#   'respon',
#   'auto',
#   'uninstal'],
#  ['benci', 'ygjadi', 'bintang', 'iklan', 'cowok', 'cowok', 'cantik'],
#  ['aplikasi',
#   'sesal',
#   'unduh',
#   'gratis',
#   'traktir',
#   'pas',
#   'pesan',
#   'dibatalin',
#   'langgar',
#   'langgar',
#   'pesan',
#   'kaya',
#   'aplikasi'],
#  ['rp',
#   'ambil',
#   'stok',
#   'habis',
#   'ambil',
#   'stok',
#   'habis',
#   'gilir',
#   'jarak',
#   'pilih',
#   'jasa',
#   'kirim',
#   'harga',
#   'beli',
#   'uninstall'],
#  ['voucher',
#   'jt',
#   'tapi',
#   'tu',
#   'saldo',
#   'toko',
#   'bohong',
#   'mnta',
#   'ampun',
#   'unduh'],
#  ['iklan', 'nongol', 'ganggu'],
#  ['ribet',
#   'ganti',
#   'nomer',
#   'telpon',
#   'susah',
#   'benar',
#   'kirim',
#   'sulit',
#   'kamera',
#   'handphone',
#   'telpon',
#   'customer service',
#   'ngebantunya'],
#  ['kesel', 'harga', 'ongkir', 'mahal', 'skrng', 'ongkir'],
#  ['gratis', 'ongkir', 'boongan'],
#  ['unduh', 'handphone', 'handphone'],
#  ['susah',
#   'flash',
#   'sale',
#   'barang',
#   'mewah',
#   'klik',
#   'terang',
#   'stok',
#   'habis',
#   'barang',
#   'murah',
#   'habis',
#   'stok',
#   'flash',
#   'sale',
#   'kaya',
#   'flash',
#   'sale',
#   'atur',
#   'antri',
#   'aplikasi',
#   'barang',
#   'flash',
#   'sale',
#   'atur',
#   'sistem',
#   'stel',
#   'beda',
#   'pkoknya',
#   'habis',
#   'kaya',
#   'atur',
#   'sistem',
#   'buyer',
#   'habis'],
#  ['kirim', 'cepat', 'terpercsya', 'tunggu', 'tidak', 'kirim'],
#  ['aplikasi', 'kirim', 'cepat'],
#  ['shope', 'aneh'],
#  ['bintang', 'pesan'],
#  ['aplikasi', 'tolong', 'bantu', 'masak', 'saldo', 'hilang', 'bintang'],
#  ['aplikasi', 'bujang', 'mahal', 'beda', 'tetangga', 'laz'],
#  ['sya', 'bayar', 'status', 'belanja', 'ubah', 'bayar'],
#  ['cocok', 'kulit', 'pakai', 'aloe', 'vera', 'pesan'],
#  ['sen',
#   'kirim',
#   'pesan',
#   'barang',
#   'cancel',
#   'jual',
#   'tolong',
#   'laa',
#   'bikin'],
#  ['ambil', 'aplikasi', 'pakai', 'jengkel', 'muncul'],
#  ['iklan', 'resah'],
#  ['cashback', 'rp', 'hilang', 'rugi', 'gin'],
#  ['cod', 'gratis', 'ongkir', 'bohong', 'nihhh'],
#  ['danta',
#   'paket',
#   'donwload',
#   'bekal',
#   'mentang',
#   'isi',
#   'paket',
#   'pakai',
#   'paket',
#   'mahal',
#   'sesuai',
#   'gadantaaaawwa'],
#  ['pindah', 'masak', 'kurir', 'anggap', 'budak'],
#  ['klaim',
#   'diskon',
#   'ribu',
#   'jam',
#   'voucher',
#   'hilang',
#   'refresh',
#   'ttp',
#   'ngadain',
#   'diskon',
#   'leg'],
#  ['agent',
#   'chat',
#   'live',
#   'shoppe',
#   'jk',
#   'bantu',
#   'chat',
#   'putus',
#   'paket',
#   'ydk',
#   'kirim',
#   'minta',
#   'dana',
#   'toko',
#   'tolak',
#   'aplikasi',
#   'lepas',
#   'tangan'],
#  ['driver',
#   'shope',
#   'food',
#   'pakai',
#   'fake',
#   'gps',
#   'tuyul',
#   'aplikasi',
#   'larang',
#   'tindak',
#   'jangan',
#   'mlh',
#   'kasihan',
#   'driver',
#   'jujur',
#   'driver',
#   'order',
#   'pakai',
#   'tuyul',
#   'suspend',
#   'pakai',
#   'aplikasi',
#   'aman',
#   'maju',
#   'jaya'],
#  ['beli', 'barang', 'paket', 'kosong', 'dana'],
#  ['iklan', 'otomatis', 'amit', 'lebih baik', 'shopie', 'olx'],
#  ['gratis',
#   'ongkir',
#   'belanja',
#   'ribu',
#   'ribu',
#   'sesuai',
#   'tema',
#   'lebih baik'],
#  ['seller', 'cetak', 'print', 'alamat', 'kirim', 'aplikasi'],
#  ['tipu',
#   'jgan',
#   'kayak',
#   'gin',
#   'percaya',
#   'sama',
#   'permai',
#   'pesan',
#   'batal',
#   'saldo',
#   'direfund',
#   'bisa',
#   'belanja',
#   'uang',
#   'bisa',
#   'tarik',
#   'capek',
#   'capek',
#   'alfamidi',
#   'bayar',
#   'uang',
#   'admin',
#   'batal',
#   'saldo',
#   'refund',
#   'pakai',
#   'tarik',
#   'malu',
#   'maluin'],
#  ['pesan',
#   'barang',
#   'oct',
#   'tngl',
#   'barang',
#   'kirim',
#   'barang',
#   'juga',
#   'belum',
#   'barang',
#   'kirim',
#   'kacau',
#   'toko',
#   'barang',
#   'belum',
#   'kirim',
#   'kurir',
#   'nelpon',
#   'tidak',
#   'barang',
#   'sampai',
#   'no',
#   'handphone',
#   'customer service',
#   'ninja',
#   'exxpres',
#   'beres',
#   'atw',
#   'pm',
#   'kurir'],
#  ['ongkir', 'mahal', 'barang', 'beli', 'ribu', 'ongkir'],
#  ['lot', 'parahh', 'sinyal', 'wifi', 'gambar', 'polos', 'notificationnya'],
#  ['check', 'out', 'hubungi', 'customer service'],
#  ['unduh',
#   'aplikasi',
#   'aplikasi',
#   'pesan',
#   'sampai',
#   'sampai',
#   'tangan',
#   'tungguin',
#   'tetep',
#   'datang',
#   'datang',
#   'belanja',
#   'mengecewaken',
#   'gabakal',
#   'belanja',
#   'rim',
#   'konsisten'],
#  ['log', 'nomor', 'blokir', 'pdhl', 'pakai', 'order', 'jual'],
#  ['aplikasi', 'php'],
#  ['aplikasi',
#   'akun',
#   'sya',
#   'blokir',
#   'sya',
#   'sarankn',
#   'dwonload',
#   'jangan',
#   'dwnload',
#   'nyeseel'],
#  ['bayar', 'link'],
#  ['belanja',
#   'pesan',
#   'bayar',
#   'tanggal',
#   'nov',
#   'tanda',
#   'kirim',
#   'catat',
#   'proses',
#   'kemas',
#   'gilir',
#   'chat',
#   'customer service',
#   'muter',
#   'karuan'],
#  ['iklan', 'melulu', 'kntol', 'aplikasi', 'anjng'],
#  ['seller', 'bodoh'],
#  ['kirim', 'kayak', 'toko'],
#  ['tolong',
#   'skrng',
#   'ongkir',
#   'pisah',
#   'pisah',
#   'ongkir',
#   'distuin',
#   'sdkit',
#   'tolong',
#   'satuin',
#   'ongkir'],
#  ['sayang',
#   'cicil',
#   'kartu',
#   'kredit',
#   'toko',
#   'belah',
#   'kredit',
#   'kartu',
#   'kredit'],
#  ['terkadang',
#   'masuk',
#   'fitur',
#   'siram',
#   'tanam',
#   'lngsng',
#   'freeze',
#   'baru',
#   'restart',
#   'ulang',
#   'handphone',
#   'khawarir',
#   'rebout',
#   'handphone',
#   'tolong',
#   'lagi',
#   'memori',
#   'masih',
#   'seger',
#   'ram',
#   'juga',
#   'masih',
#   'sisa',
#   'gb',
#   'lbh',
#   'gb',
#   'handphone',
#   'juga',
#   'bukan',
#   'kentang',
#   'aplikasi',
#   'berat',
#   'fitur',
#   'selalu',
#   'lin'],
#  ['aplikasi', 'gun', 'tipu'],
#  ['belanja',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'extra',
#   'susah',
#   'check',
#   'out',
#   'bolak'],
#  ['syah', 'bayar', 'expres'],
#  ['jelekkk',
#   'main',
#   'game',
#   'minecrft',
#   'nama',
#   'survival',
#   'na',
#   'muncul',
#   'ikkelan',
#   'pencet',
#   'skip',
#   'mati',
#   'iiih',
#   'jelekk'],
#  ['bug', 'bnerin'],
#  ['shope', 'gimmick', 'flashsale', 'iphone', 'kirim', 'batal', 'hahaha'],
#  ['beres',
#   'aplikasi',
#   'unduh',
#   'aplikasi',
#   'ken',
#   'coba',
#   'belanja',
#   'kayak',
#   'ny',
#   'checkout',
#   'payung',
#   'harga',
#   'ongkir',
#   'akal',
#   'tanggerang',
#   'jambi',
#   'ongkir',
#   'rp',
#   'benar',
#   'harga',
#   'payung'],
#  ['team',
#   'becus',
#   'cie',
#   'nanganin',
#   'custamer',
#   'transaksi',
#   'tanggal',
#   'nov',
#   'sampai',
#   'tanggal',
#   'nov',
#   'biarin',
#   'komplian',
#   'pakai',
#   'mesin',
#   'tolong',
#   'bantu',
#   'jual',
#   'pinter',
#   'barang',
#   'kirim',
#   'retur',
#   'kurir',
#   'tolong',
#   'bantu',
#   'dana',
#   'belanja'],
#  ['kenal',
#   'toko',
#   'sukses',
#   'beli',
#   'barang',
#   'sesuai',
#   'foto',
#   'beli',
#   'barang',
#   'rusak',
#   'kan',
#   'anjig'],
#  ['ribet', 'beli', 'shpee'],
#  ['recomended',
#   'aplikasi',
#   'belanja',
#   'pesan',
#   'akun',
#   'mes',
#   'lemari',
#   'harga',
#   'heboh',
#   'keluarga',
#   'batal',
#   'pesan',
#   'handphone',
#   'jam',
#   'pakai',
#   'ajar',
#   'kirim',
#   'kirim',
#   'alamat',
#   'bilang',
#   'pesan',
#   'kirim',
#   'men',
#   'percaya',
#   'cari',
#   'google'],
#  ['maaf',
#   'uninstal',
#   'tipu',
#   'tipu',
#   'komplen',
#   'gubris',
#   'maaf',
# ...
#   'diturunin',
#   'naekin',
#   'tolong',
#   'dinaekkn',
#   'merger',
#   'suramm'],
#  ['aplikasi',
#   'anjig',
#   'pdahal',
#   'install',
#   'promo',
#   'batal',
#   'sen',
#   'voucher',
#   'ongkir',
#   'hilang',
#   'tlol'],
#  ['aplikasi',
#   'produk',
#   'sesuai',
#   'pesan',
#   'sayang',
#   'ongkir',
#   'mahal',
#   'diskon',
#   'voucer',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'mengambil',
#   'ribu'],
#  ['promo',
#   'mancing',
#   'awam',
#   'pengaruh',
#   'promo',
#   'fitur',
#   'aplikasi',
#   'kaku',
#   'saldo',
#   'dipake',
#   'bayar',
#   'ambil',
#   'lebih baik'],
#  ['gratis',
#   'ongkir',
#   'dwnlod',
#   'pesan',
#   'barang',
#   'langgan',
#   'knk',
#   'cas',
#   'ribu',
#   'ongkir',
#   'kelimapuluh',
#   'kabupaten',
#   'batubara',
#   'harga',
#   'mahal',
#   'bnding',
#   'murah',
#   'ongkir',
#   'cmn',
#   'ribu',
#   'gratis',
#   'ongkir',
#   'pulau',
#   'jawa',
#   'kesumut',
#   'ribu',
#   'gilaaak',
#   'klen',
#   'seperti',
#   'gmn',
#   'banyak',
#   'plnggnnya',
#   'blnj',
#   'berat',
#   'diongkir',
#   'hrg',
#   'mahal',
#   'banding',
#   'aplikasi',
#   'ttngga'],
#  ['keluarin', 'iklan', 'boss', 'kesel', 'iklan', 'nyaman'],
#  ['up', 'kemarin', 'indomart', 'sukses', 'saldo'],
#  ['aplikasi',
#   'commerce',
#   'bikin',
#   'bingung',
#   'masukkan',
#   'nomor',
#   'rekening',
#   'susah'],
#  ['sinyal', 'butuh'],
#  ['maaf',
#   'bri',
#   'bintang',
#   'ea',
#   'nnti',
#   'klau',
#   'brng',
#   'smpai',
#   'baru',
#   'ksih',
#   'bintang',
#   'lagi'],
#  ['lambat', 'downloadnya'],
#  ['organisasi', 'birokrasi'],
#  ['gin',
#   'dowanload',
#   'lagu',
#   'chrome',
#   'ngapain',
#   'unduh',
#   'bilang',
#   'macam',
#   'macam',
#   'poromo',
#   'case',
#   'back',
#   'bikin',
#   'repot',
#   'perasaandah'],
#  ['iklan', 'ganggu', 'tolong', 'jangan', 'iklan', 'sembarang'],
#  ['beli',
#   'bayar',
#   'batal',
#   'promo',
#   'promo',
#   'sisa',
#   'promo',
#   'batal',
#   'transaksi',
#   'kupon',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'ribu',
#   'kupon',
#   'cashback',
#   'ribu',
#   'hilang',
#   'pagi',
#   'sisa',
#   'aju',
#   'care',
#   'balas',
#   'sesuai',
#   'prosedur',
#   'langgar',
#   'tolong'],
#  ['barang', 'siap', 'order', 'kirim', 'kirim', 'batal', 'konfirmasi'],
#  ['takut', 'jahat', 'ngrim', 'alamat'],
#  ['tmpat', 'tinggal', 'camat', 'grong', 'kabupaten', 'pidie', 'kota', 'sigli'],
#  ['tutup', 'akun', 'tanda', 'sistem', 'shoppe', 'kualitas'],
#  ['gratis',
#   'ongkir',
#   'pakai',
#   'sekal',
#   'cari',
#   'toko',
#   'label',
#   'gratis',
#   'ongkir',
#   'toko',
#   'barang',
#   'cari',
#   'pakai',
#   'toko',
#   'kacau',
#   'tolong'],
#  ['lot', 'bnget', 'bayar', 'susah', 'kesini', 'mkin', 'mles', 'lot'],
#  ['lma',
#   'lot',
#   'sebentar',
#   'logout',
#   'sendiri',
#   'pdhal',
#   'ram',
#   'msih',
#   'nyukup',
#   'ntah',
#   'berat',
#   'game',
#   'ny',
#   'tolong'],
#  ['unduh', 'komplen'],
#  ['aplikasi', 'eror', 'terus', 'pdhl', 'update', 'pke', 'pers', 'tetep'],
#  ['budug', 'rehan'],
#  ['gratis', 'ongkir'],
#  ['mola',
#   'minggu',
#   'malam',
#   'kirim',
#   'hadiah',
#   'menang',
#   'nga',
#   'nyampe',
#   'coi',
#   'hadiah',
#   'palsu'],
#  ['barang', 'sesuai'],
#  ['klu',
#   'setock',
#   'barang',
#   'jangan',
#   'pajang',
#   'pajang',
#   'gambar',
#   'pesan',
#   'baju',
#   'batas',
#   'proses',
#   'proses',
#   'potong',
#   'biayamah',
#   'cepat',
#   'kirim',
#   'susah',
#   'puayah'],
#  ['notifikasi', 'kirim', 'cepat', 'fakta', 'kaya', 'bulus', 'lot', 'estimasi'],
#  ['jual',
#   'amanah',
#   'aplikasi',
#   'proses',
#   'barang',
#   'salah',
#   'kirim',
#   'sulit',
#   'seler',
#   'amanah',
#   'tindak',
#   'sebenernya',
#   'rugi',
#   'aplikasi',
#   'customer',
#   'alih',
#   'aplikasi',
#   'lbh',
#   'amanah',
#   'lbh',
#   'mudah',
#   'proses',
#   'pengembalaian',
#   'barang'],
#  ['game', 'jual', 'ayig'],
#  ['toko', 'handal'],
#  ['tolong',
#   'bantu',
#   'foto',
#   'jual',
#   'ratus',
#   'muncul',
#   'tarik',
#   'pelang',
#   'barang',
#   'gudang',
#   'muncul',
#   'pantas',
#   'jual',
#   'terus'],
#  ['aplikasi',
#   'sihh',
#   'kmarin',
#   'apdet',
#   'isi',
#   'saldo',
#   'ribu',
#   'suruh',
#   'ngapdet',
#   'apdet',
#   'kok',
#   'uang',
#   'koin',
#   'koinya',
#   'hilang',
#   'rugi',
#   'dongg',
#   'erti'],
#  ['update',
#   'asa',
#   'gratis',
#   'ongkir',
#   'update',
#   'layar',
#   'putih',
#   'gambar',
#   'gapernah',
#   'gratis',
#   'ongkir',
#   'cod',
#   'why'],
#  ['tipu',
#   'promo',
#   'flash',
#   'sale',
#   'ken',
#   'hapus',
#   'aplikasi',
#   'standby',
#   'sblm',
#   'pkl',
#   'pesan',
#   'stock',
#   'habis',
#   'terang',
#   'jual',
#   'stock',
#   'kosong',
#   'jam',
#   'saran',
#   'klu',
#   'masih',
#   'banyak',
#   'tipu',
#   'promo',
#   'sesuai'],
#  ['update',
#   'bayar',
#   'chat',
#   'customer service',
#   'hang',
#   'restart',
#   'aplikasi'],
#  ['berat',
#   'aplikasi',
#   'respon',
#   'pencet',
#   'berat',
#   'beda',
#   'ringan',
#   'smooth'],
#  ['ongkir',
#   'mahal',
#   'brooo',
#   'hadeuh',
#   'hadeuh',
#   'ganti',
#   'opsi',
#   'kurir',
#   'harga',
#   'up',
#   'up',
#   'mahal',
#   'customer service',
#   'bot',
#   'mlu',
#   'jwbannya',
#   'ktnya',
#   'unicorn',
#   'customer service',
#   'bot'],
#  ['virus', 'iklan', 'handphone', 'eror'],
#  ['aplikasi',
#   'bela',
#   'seller',
#   'beli',
#   'please',
#   'be',
#   'careful',
#   'skripsi',
#   'sesat',
#   'seller',
#   'utama',
#   'dropship',
#   'seller',
#   'modal'],
#  ['chekout',
#   'pin',
#   'salah',
#   'pdhl',
#   'benar',
#   'sampai',
#   'blokir',
#   'tolong',
#   'gimanain'],
#  ['haraga', 'barang', 'beli'],
#  ['toko', 'tanggung', 'kirim', 'barang', 'sesuai', 'pesan', 'barang'],
#  ['kemarin',
#   'aktif',
#   'kredit',
#   'isi',
#   'data',
#   'data',
#   'hapus',
#   'nama',
#   'tika',
#   'aprilia',
#   'triyanto',
#   'kredit',
#   'handphone',
#   'counter',
#   'bantu',
#   'hapus',
#   'data'],
#  ['tipu', 'barang', 'sesuai', 'tokony', 'bawa', 'rezeky', 'usaha', 'tipu'],
#  ['beli', 'pulsa', 'refund', 'melulu', 'anjimmm', 'kaya'],
#  ['unduh', 'tunggu', 'hati', 'riang', 'gembira', 'tbtb', 'gagal'],
#  ['aplikasi', 'jelekk', 'login', 'pke', 'verifikasi', 'wajah', 'upgrade'],
#  ['aplikasi',
#   'hancur',
#   'ran',
#   'ribet',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'dasar'],
#  ['verrsi',
#   'android',
#   'hambat',
#   'tunanetra',
#   'menu',
#   'food',
#   'akses',
#   'searching',
#   'lokasi',
#   'resto',
#   'menu',
#   'keranjang',
#   'tulis',
#   'salah',
#   'tindak'],
#  ['lindung',
#   'garansi',
#   'bintang',
#   'bicara',
#   'tim',
#   'jual',
#   'jual',
#   'amanah',
#   'jual',
#   'jujur',
#   'tim',
#   'bantuin',
#   'keluh',
#   'mbelinya'],
#  ['jasa', 'kirim', 'sedia'],
#  ['scar', 'tri'],
#  ['engga',
#   'up',
#   'logika',
#   'up',
#   'akun',
#   'ngendap',
#   'bank',
#   'konvensional',
#   'tranfer',
#   'ganggu',
#   'jam',
#   'kelas',
#   'bank',
#   'aplikasi',
#   'urus',
#   'up',
#   'engga',
#   'tunggu'],
#  ['bintang', 'pakek', 'amplikasi', 'iklan', 'muncul', 'handphone'],
#  ['baru',
#   'pakai',
#   'order',
#   'ngecewain',
#   'batal',
#   'jasa',
#   'kirim',
#   'baru',
#   'tahu',
#   'js',
#   'pgriman',
#   'batal',
#   'kirim',
#   'jam',
#   'bareng',
#   'kirim',
#   'alamat',
#   'jm',
#   'sore',
#   'untuk',
#   'siapkn',
#   'uang',
#   'sstm',
#   'bayar',
#   'ttpi',
#   'jm',
#   'mlm',
#   'pmbritahuan',
#   'bareng',
#   'gagal',
#   'kirim',
#   'curiga',
#   'psnan',
#   'mysteri',
#   'box',
#   'nominal',
#   'paham',
#   'kan',
#   'kcurigaan',
#   'aneh',
#   'jsa',
#   'pgirimannya',
#   'sam',
#   'lx',
#   'tlglah',
#   'lbh',
#   'selektif',
#   'dlm',
#   'pilih',
#   'jasa',
#   'kirim',
#   'amatir',
#   'model',
#   'gtu'],
#  ['cod', 'toko', 'tipu', 'hadeeeee'],
#  ['unduh', 'lagu'],
#  ['aplikasi',
#   'browsing',
#   'tonton',
#   'drakor',
#   'ehh',
#   'suruh',
#   'unduh',
#   'aplikasi',
#   'aplikasi'],
#  ['iklan', 'anjim'],
#  ['aplikasi', 'tipu'],
#  ['semerawut',
#   'sen',
#   'bareng',
#   'tunggu',
#   'dibatalin',
#   'lagi',
#   'sellernya',
#   'kapok',
#   'blja',
#   'dsni',
#   'beli',
#   'sepele',
#   'uninstall',
#   'az',
#   'puzink'],
#  ['beli',
#   'platihan',
#   'status',
#   'transaksi',
#   'batal',
#   'status',
#   'platihan',
#   'aktif',
#   'voucher',
#   'pltihan',
#   'beli',
#   'hambat',
#   'beli',
#   'platihan',
#   'aktif',
#   'email',
#   'pusat',
#   'bantu',
#   'refand',
#   'ribet',
#   'hambat',
#   'karir'],
#  ['aplikasi',
#   'cekout',
#   'rupiah',
#   'pas',
#   'cek',
#   'out',
#   'batal',
#   'coba',
#   'ganti',
#   'nomer',
#   'batal',
#   'donlut',
#   'aplikasi',
#   'males',
#   'php',
#   'kaya',
#   'toko',
#   'pilih',
#   'barang',
#   'rupiah',
#   'batal'],
#  ['anteraja', 'dipake', 'laaah', 'bikin', 'layan'],
#  ['promo',
#   'pakai',
#   'coin',
#   'dahh',
#   'benar',
#   'promo',
#   'potong',
#   'ongkir',
#   'pakai',
#   'pakai',
#   'point',
#   'evektif'],
#  ['susah',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'online',
#   'tarik',
#   'murah',
#   'ongkir'],
#  ['pakai', 'trsnsaksi'],
#  ['kirim', 'kuno', 'instan'],
#  ['update', 'mennggapi'],
#  ['bintang',
#   'rena',
#   'install',
#   'ulang',
#   'sampai',
#   'akun',
#   'hapus',
#   'pindah',
#   'pakai',
#   'aplikasi',
#   'ribet'],
#  ['akun',
#   'shoppe',
#   'login',
#   'costumer',
#   'service',
#   'tolong',
#   'bantu',
#   'bayar',
#   'shoppepaylatter'],
#  ['aowkwowkwok', 'aplikasi', 'mandang', 'handphone'],
#  ['aneh', 'pesan', 'barang', 'nama', 'kirim'],
#  ['ganggu', 'link', 'unduh'],
#  ['tipu',
#   'toko',
#   'nakal',
#   'kirim',
#   'barang',
#   'cod',
#   'pesan',
#   'barang',
#   'filter',
#   'tipu'],
#  ['aplikasi', 'prank', 'konten'],
#  ['barang',
#   'dikirm',
#   'nggk',
#   'sesuai',
#   'mau',
#   'barang',
#   'proses',
#   'ribet',
#   'banding',
#   'toko',
#   'online',
#   'belah',
#   'nggk',
#   'kaya',
#   'gin'],
#  ['iklan', 'mental', 'play', 'toko'],
#  ['sampai',
#   'sertifikat',
#   'bom',
#   'muncul',
#   'dasbor',
#   'prakerjaaaaaaaa',
#   'tolong',
#   'cepat'],
#  ['sore',
#   'aplikasi',
#   'burik',
#   'loading',
#   'gagal',
#   'muat',
#   'pdahal',
#   'jaringal'],
#  ['bikin', 'promo', 'diskon', 'gilir', 'dipake', 'anggap', 'menyalaho'],
#  ['aplikasi', 'sen', 'paket', 'hancur', 'kirim', 'hancurrrrrrr'],
#  ['pilih', 'jasa', 'kirim', 'sinyal'],
#  ['aneh', 'dh', 'diupdate', 'ttp', 'ilangin', 'ganggu'],
#  ['bisa', 'downlod'],
#  ['woyy',
#   'bangke',
#   'cari',
#   'lot',
#   'bangkee',
#   'update',
#   'aplikasi',
#   'sinyal',
#   'tahi',
#   'laah'],
#  ['ngadain',
#   'cashback',
#   'cashback',
#   'jarang',
#   'aplikasi',
#   'tembah',
#   'lot',
#   'mitra',
#   'curang',
#   'males',
#   'beli',
#   'belanja',
#   'pakai',
#   'pindah',
#   'toko'],
#  ['tolong', 'tolong', 'up', 'snack', 'vidio', 'uang'],
#  ['kecewaaa',
#   'bangett',
#   'sntadar',
#   'ekpress',
#   'kirim',
#   'bangett',
#   'banding',
#   'kirim',
#   'reguler',
#   'lai',
#   'lebih baik',
#   'ituu',
#   'hedhhh'],
#  ['live', 'chat', 'susah'],
#  ['tolong', 'bantu', 'saldo', 'hubung', 'dana'],
#  ['ribet',
#   'dipake',
#   'lockout',
#   'verivikasi',
#   'belibet',
#   'muter',
#   'auto',
#   'un',
#   'install',
#   'ao',
#   'gin'],
#  ['aplikasi',
#   'pngiriman',
#   'bnyak',
#   'pnjual',
#   'jelassss',
#   'paket',
#   'dateng',
#   'lgsung',
#   'uinstal',
#   'bkal',
#   'dowlnd',
#   'lh'],
#  ['aplikasi',
#   'tipu',
#   'sen',
#   'box',
#   'dateng',
#   'cincin',
#   'harga',
#   'ribu',
#   'pantau',
#   'toko',
#   'toko',
#   'amanah',
#   'korban',
#   'aplikasi'],
#  ['baca',
#   'editor',
#   'notice',
#   'bintang',
#   'cuman',
#   'saran',
#   'letak',
#   'gambar',
#   'produk',
#   'sejajar',
#   'judul',
#   'produk',
#   'tulis',
#   'kecilin',
#   'mudah',
#   'gambar',
#   'contolah',
#   'akun',
#   'shope',
#   'belah',
#   'gambar',
#   'iklan',
#   'nyaingin',
#   'toko',
#   'belah',
#   'fitur',
#   'tampil',
#   'tarik',
#   'toko',
#   'belah',
#   'notice',
#   'baca'],
#  ['kurir',
#   'alamat',
#   'tera',
#   'cantum',
#   'nama',
#   'orang',
#   'belanja',
#   'setelah',
#   'komplain',
#   'tuntas',
#   'tutup',
#   'beli',
#   'rugi',
#   'barang',
#   'hilang'],
#  ['sayang',
#   'pesan',
#   'rupiah',
#   'beli',
#   'eror',
#   'bilang',
#   'pesan',
#   'sdngkan',
#   'dengn',
#   'bareng',
#   'kecewaa'],
#  ['gratis', 'ongkir', 'kya'],
#  ['tulis', 'kolom', 'cari', 'eror'],
#  ['tolong',
#   'benah',
#   'kurir',
#   'shoope',
#   'express',
#   'pesan',
#   'hold',
#   'jarak',
#   'kirim',
#   'lokasi',
#   'kirim'],
#  ['chat', 'eror', 'connect', 'jaring'],
#  ['mengisi', 'shopay', 'saldo', 'atm', 'duit'],
#  ['verivikasi', 'bikin', 'ribet'],
#  ['dear',
#   'mimin',
#   'kendala',
#   'checkout',
#   'checkout',
#   'pesan',
#   'checkout',
#   'gagal',
#   'risih',
#   'pesan',
#   'pesan',
#   'otomatis',
#   'checkout',
#   'pesan',
#   'harga',
#   'barang',
#   'beli',
#   'sesuai',
#   'voucher',
#   'voucher',
#   'tolong',
#   'mimin',
#   'mudah',
#   'checkout',
#   'tolong',
#   'checkout',
#   'gagal'],
#  ['belanja', 'kli', 'isi', 'pakrtnya', 'bodoh'],
#  ['iklan', 'spam', 'google', 'nonton', 'film', 'skip', 'heran'],
#  ['belanja',
#   'bayar',
#   'alfa',
#   'indomaret',
#   'barang',
#   'cod',
#   'malas',
#   'pakai',
#   'aplikasi',
#   'tolong',
#   'informasi'],
#  ['bintang', 'pilih', 'kurir', 'besok', 'tunggu', 'kurir', 'lamban'],
#  ['mantaaaa', 'belanja', 'tipu', 'belanja', 'pesan', 'sesuai'],
#  ['sampah', 'selalu', 'ganggu'],
#  ['aplikasi', 'serius'],
#  ['mahal', 'ongkir', 'beli', 'kirim', 'hadehhh', 'gaze'],
#  ['commerce',
#   'gajelas',
#   'pakai',
#   'voucher',
#   'promo',
#   'dipake',
#   'pas',
#   'dipake',
#   'transaksi',
#   'batal',
#   'otomatis',
#   'transaksi',
#   'akun',
#   'tahu',
#   'akun',
#   'bertanya',
#   'costumer',
#   'service',
#   'solusi'],
#  ['aplikasi',
#   'aman',
#   'hubung',
#   'akun',
#   'informasi',
#   'kartu',
#   'kredit',
#   'link',
#   'fintech',
#   'otp',
#   'login',
#   'perangkat',
#   'pin',
#   'transaksi',
#   'fintech',
#   'retas',
#   'alami',
#   'sendir',
#   'akun',
#   'retas',
#   'topup',
#   'money',
#   'koneksi',
#   'akun',
#   'bertanggungjawab',
#   'rubah',
#   'pin',
#   'password',
#   'rutin',
#   'hubung',
#   'bayar'],
#  ['donlod', 'chekout', 'aneh'],
#  ['pliss',
#   'data',
#   'cur',
#   'ganti',
#   'rugi',
#   'jt',
#   'lapor',
#   'shoppe',
#   'polisi',
#   'titik'],
#  ['benar',
#   'order',
#   'proses',
#   'kirim',
#   'toleransi',
#   'jual',
#   'kirim',
#   'recommended',
#   'order',
#   'kuciwa'],
#  ['bayar', 'cok'],
#  ['aduhh',
#   'maaf',
#   'isi',
#   'alamat',
#   'kecamatan',
#   'kota',
#   'salah',
#   'pdhal',
#   'ulang',
#   'ulang'],
#  ['menu',
#   'utama',
#   'mesti',
#   'pencet',
#   'salah',
#   'gimna',
#   'sen',
#   'haduh',
#   'makane',
#   'sebel',
#   'pakai',
#   'shoopee',
#   'gin',
#   'tolong',
#   'bantu',
#   'dibenerin',
#   'gimna'],
#  ['barang', 'bnyak', 'sesuai', 'kirim'],
#  ['gimn', 'belanja', 'sistem', 'cod'],
#  ['toko', 'tipu', 'tolong', 'banned', 'toko', 'tipu', 'periksa', 'lagiiiii'],
#  ['daftar', 'akun', 'sulit', 'mnding', 'toko', 'belah'],
#  ['tolong', 'aplikasi', 'beli', 'kouta', 'aplikasi', 'tapi', 'ny', 'aplikasi'],
#  ['pakai', 'pakai', 'voucher'],
#  ['bayar', 'link', 'enggk'],
#  ['daftar', 'ngabis', 'kuota'],
#  ['aplikasi', 'lot'],
#  ['pesan', 'sini', 'pesn', 'sini', 'barang', 'proses', 'bayar', 'hadeeeeee'],
#  ['suruh',
#   'kritik',
#   'keritik',
#   'ber',
#   'diam',
#   'ubah',
#   'kirim',
#   'lempar',
#   'xpres',
#   'lot',
#   'sap',
#   'expres',
#   'bangke',
#   'benar',
#   'kirim',
#   'area',
#   'jawa',
#   'makan',
#   'full'],
#  ['gambar', 'ampas'],
#  ['maaf',
#   'masak',
#   'muncul',
#   'detik',
#   'muncul',
#   'detik',
#   'muncul',
#   'tolong',
#   'menit',
#   'seperti',
#   'menit',
#   'tibul',
#   'timbul',
#   'jengkel',
#   'cek',
#   'maaf',
#   'hoak'],
#  ['tolong',
#   'iklan',
#   'menggangu',
#   'nyaman',
#   'jelajah',
#   'internet',
#   'hapus',
#   'aplikasi',
#   'ganggu'],
#  ['unduh', 'aplikasi', 'tipu'],
#  ['beri',
#   'rating',
#   'tanggung',
#   'dsb',
#   'kerjain',
#   'nyuruh',
#   'hubung',
#   'hubung',
#   'puter',
#   'puter',
#   'lagi',
#   'orang',
#   'beri',
#   'kritik',
#   'ketidakpuasan',
#   'cepat',
#   'tanganin',
#   'nyuruh',
#   'hubung',
#   'gambar',
#   'tampil',
#   'pending',
#   'bingung',
#   'internet',
#   'pasang',
#   'gb',
#   'handphone',
#   'redmi',
#   'note',
#   'apalalagi',
#   'salah'],
#  ['install', 'aplikasi', 'hadiah', 'jangan', 'bohong', 'aje'],
#  ['tawarin',
#   'rupiah',
#   'pas',
#   'cek',
#   'tetep',
#   'beli',
#   'mahal',
#   'aplikasi',
#   'shopy'],
#  ['terlambat',
#   'bayar',
#   'shopeepaylater',
#   'tlponin',
#   'puluh',
#   'kayak',
#   'hutang',
#   'puluh',
#   'juta',
#   'ngk',
#   'bayar',
#   'bom',
#   'gaji',
#   'gaji',
#   'undur',
#   'nelponin',
#   'ngk',
#   'paut',
#   'tunggak',
#   'bayar',
#   'kasi',
#   'teman',
#   'diganguin',
#   'melulu',
#   'kayak',
#   'teror',
#   'ganggu',
#   'tolong',
#   'baca',
#   'tolong',
#   'erti'],
#  ['tari',
#   'saldo',
#   'even',
#   'bayar',
#   'kumpulun',
#   'kawan',
#   'susah',
#   'tolong',
#   'ikan'],
#  ['cod', 'cash', 'or', 'duel'],
#  ['akun',
#   'alami',
#   'janggal',
#   'live',
#   'chat',
#   'sulit',
#   'tombol',
#   'live',
#   'chat',
#   'unduh'],
#  ['setia', 'sllu', 'sperti', 'vocher', 'valid', 'vocher', 'msih'],
#  ['maaf', 'bri', 'dl', 'baru'],
#  ['iklan',
#   'amplikasi',
#   'ganggu',
#   'donlod',
#   'musik',
#   'tadi',
#   'muncul',
#   'handphone',
#   'teruss',
#   'bikin',
#   'emosi'],
#  ['aplikasi',
#   'nggk',
#   'install',
#   'unduh',
#   'berualang',
#   'ulang',
#   'kuota',
#   'hangus',
#   'bgtu',
#   'gara',
#   'unduh',
#   'tapi',
#   'terinstal'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (6, 7):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha='asymmetric', eta='symmetric')
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(0, 0.09750264), (1, 0.7359035), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.09750268), (1, 0.06923684), (2, 0.053676214), (3, 0.3771613), (4, 0.3703628), (5, 0.032060143)]
# [(0, 0.7150151), (1, 0.03461842), (2, 0.027238727), (3, 0.021913217), (4, 0.18518223), (5, 0.016032314)]
# [(0, 0.8815339), (1, 0.035165537), (2, 0.026838109), (3, 0.021913217), (4, 0.018519145), (5, 0.016030071)]
# [(0, 0.12253396), (1, 0.018882772), (2, 0.014638966), (3, 0.19376887), (4, 0.64143175)]
# [(0, 0.3357919), (1, 0.11528715), (2, 0.011502159), (3, 0.44194272), (5, 0.08754043)]
# [(0, 0.22400261), (1, 0.5159108), (2, 0.02683817), (3, 0.19870277), (4, 0.018515553), (5, 0.016030071)]
# [(0, 0.3231516), (1, 0.30176166), (2, 0.040257256), (3, 0.032869834), (4, 0.027773328), (5, 0.27418634)]
# [(0, 0.4308364), (1, 0.072327115), (2, 0.053676207), (3, 0.043826435), (4, 0.3672737), (5, 0.032060143)]
# [(0, 0.42954466), (1, 0.070528165), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.3653935)]
# [(0, 0.4990539), (1, 0.041542467), (2, 0.032205872), (3, 0.02629587), (4, 0.38166577), (5, 0.019236086)]
# [(0, 0.085026994), (1, 0.7900173), (2, 0.040257152), (3, 0.032869827), (4, 0.027783623), (5, 0.024045106)]
# [(0, 0.058501583), (1, 0.041607063), (2, 0.032205723), (3, 0.8262309), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.7932806), (1, 0.15117922), (2, 0.017892072), (3, 0.01461441), (4, 0.012347034), (5, 0.010686714)]
# [(0, 0.43082234), (1, 0.40258375), (2, 0.053676262), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.097502634), (1, 0.4025702), (2, 0.0536762), (3, 0.3771597), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.7641652), (1, 0.069240265), (2, 0.053676818), (3, 0.043826446), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.5731205), (1, 0.05192769), (2, 0.04025719), (3, 0.28287622), (4, 0.027773326), (5, 0.024045106)]
# [(0, 0.76359177), (1, 0.06981433), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.43075666), (1, 0.4025701), (2, 0.053676203), (3, 0.043905843), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.76356983), (1, 0.06983628), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.33610126), (1, 0.05283127), (2, 0.5263792), (3, 0.032869834), (4, 0.027773328), (5, 0.024045108)]
# [(0, 0.5721643), (1, 0.052885503), (2, 0.040257156), (3, 0.03286983), (4, 0.027778395), (5, 0.27404487)]
# [(0, 0.09750265), (1, 0.069389686), (2, 0.053676207), (3, 0.71034026), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.43083188), (1, 0.4025742), (2, 0.05367622), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.23986752), (1, 0.35062695), (2, 0.09675729), (3, 0.2954754)]
# [(0, 0.715186), (1, 0.03461841), (2, 0.027069664), (3, 0.021913216), (4, 0.18518263), (5, 0.01603007)]
# [(0, 0.2584933), (1, 0.04154212), (2, 0.032205738), (3, 0.6263041), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.09750304), (1, 0.06923699), (2, 0.38702402), (3, 0.043826446), (4, 0.037031103), (5, 0.3653784)]
# [(0, 0.65849805), (1, 0.041542105), (2, 0.23220785), (3, 0.026295861), (4, 0.02222006), (5, 0.019236084)]
# [(0, 0.28391343), (1, 0.04154215), (2, 0.032205753), (3, 0.60088396), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.45945626), (1, 0.041542143), (2, 0.032205746), (3, 0.026295865), (4, 0.022218661), (5, 0.41828132)]
# [(0, 0.7635785), (1, 0.06982761), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.5965879), (1, 0.02122649), (2, 0.21610324), (3, 0.14533493), (4, 0.0111281)]
# [(0, 0.058502227), (1, 0.04167078), (2, 0.3908889), (3, 0.46748334), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.1846488), (1, 0.31538126), (2, 0.023004118), (3, 0.16157208), (4, 0.015895184), (5, 0.2994986)]
# [(0, 0.32314408), (1, 0.05192776), (2, 0.04025722), (3, 0.032869834), (4, 0.2777973), (5, 0.27400386)]
# [(0, 0.26715243), (1, 0.3757256), (2, 0.023004092), (3, 0.16164072), (4, 0.015885502), (5, 0.15659168)]
# [(0, 0.88205266), (1, 0.03461842), (2, 0.026838103), (3, 0.02194523), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.38197467), (1, 0.36795413), (2, 0.026931806), (3, 0.021930654), (4, 0.18517862), (5, 0.01603007)]
# [(0, 0.050210476), (1, 0.41270557), (2, 0.026838101), (3, 0.30903366), (4, 0.1851821), (5, 0.016030071)]
# [(0, 0.036563903), (1, 0.31430495), (2, 0.19219998), (3, 0.16325061), (4, 0.13081995), (5, 0.16286066)]
# [(0, 0.20331891), (1, 0.02967307), (2, 0.023004146), (3, 0.520251), (4, 0.015870472), (5, 0.20788239)]
# [(0, 0.7641693), (1, 0.06923683), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.04875138), (1, 0.5346274), (2, 0.026838116), (3, 0.35523757), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.09783176), (1, 0.07011882), (2, 0.053676277), (3, 0.37596393), (4, 0.037031103), (5, 0.3653781)]
# [(0, 0.24680069), (1, 0.5613313), (3, 0.037109427), (4, 0.08776856), (5, 0.0623807)]
# [(0, 0.32312354), (1, 0.051927615), (2, 0.040257152), (3, 0.032869823), (4, 0.5277767), (5, 0.024045102)]
# [(0, 0.05850159), (1, 0.24154112), (2, 0.032205723), (3, 0.42629084), (4, 0.022224072), (5, 0.21923666)]
# [(0, 0.036563493), (1, 0.02596381), (2, 0.14512782), (3, 0.76643527), (4, 0.013887078), (5, 0.012022553)]
# [(0, 0.8225008), (1, 0.05247761), (2, 0.040257152), (3, 0.032926943), (4, 0.027792357), (5, 0.024045106)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.7203429), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.77507526), (1, 0.014836502), (2, 0.10444861), (5, 0.088306874)]
# [(0, 0.27662873), (1, 0.023647124), (2, 0.01789207), (3, 0.5476935), (4, 0.123451866), (5, 0.010686714)]
# [(0, 0.4308363), (1, 0.06923682), (2, 0.053676203), (3, 0.37715948), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.045325823), (1, 0.8832733), (2, 0.023004087), (3, 0.01878276), (4, 0.015873935), (5, 0.013740061)]
# [(0, 0.14361188), (1, 0.35641086), (2, 0.01789207), (3, 0.4590533), (4, 0.0123437), (5, 0.010688141)]
# [(0, 0.044786748), (1, 0.8838112), (2, 0.023004089), (3, 0.01878746), (4, 0.015870472), (5, 0.013740062)]
# [(0, 0.04875289), (1, 0.7396616), (2, 0.026840787), (3, 0.021944577), (4, 0.14676301), (5, 0.016037164)]
# [(0, 0.25849196), (1, 0.3780092), (2, 0.03220574), (3, 0.28983834), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.0123358155), (1, 0.25199986), (3, 0.62653327), (5, 0.09779161)]
# [(0, 0.43083394), (1, 0.40246543), (2, 0.053676214), (3, 0.04393321), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.068151586), (1, 0.01093221), (2, 0.6620273), (3, 0.058997877), (4, 0.13550119), (5, 0.064389884)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.4308355), (1, 0.40257066), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.4294964), (1, 0.07057657), (2, 0.053676203), (3, 0.37715957), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.763577), (1, 0.06982914), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.0775626), (1, 0.051927958), (2, 0.45688194), (3, 0.03286983), (4, 0.027773326), (5, 0.35298434)]
# [(0, 0.3231579), (1, 0.051928114), (2, 0.040257227), (3, 0.28436726), (4, 0.27624443), (5, 0.02404511)]
# [(0, 0.09750275), (1, 0.06923687), (2, 0.38702306), (3, 0.37714607), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.12924297), (1, 0.020863596), (2, 0.21610627), (3, 0.5130617), (4, 0.01110933), (5, 0.10961616)]
# [(0, 0.32215774), (1, 0.05289701), (2, 0.040257152), (3, 0.5328697), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.43083522), (1, 0.06923685), (2, 0.053676218), (3, 0.37716052), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.57300407), (1, 0.05192771), (2, 0.040397648), (3, 0.03286983), (4, 0.27775565), (5, 0.024045106)]
# [(0, 0.3274858), (1, 0.60109407), (2, 0.023004085), (3, 0.018805474), (4, 0.01587047), (5, 0.01374006)]
# [(0, 0.4086482), (1, 0.020854969), (2, 0.016102877), (3, 0.33363613), (4, 0.111121714), (5, 0.10963613)]
# [(0, 0.49410918), (1, 0.017400531), (2, 0.013419061), (3, 0.2911442), (4, 0.09258021), (5, 0.09134683)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312714), (1, 0.051927682), (2, 0.54029876), (3, 0.03286983), (4, 0.27773154), (5, 0.024045106)]
# [(0, 0.37820002), (1, 0.2007142), (2, 0.11756268), (3, 0.19376239), (4, 0.0100993905), (5, 0.09966127)]
# [(0, 0.43083456), (1, 0.06923686), (2, 0.05367622), (3, 0.043826435), (4, 0.0370311), (5, 0.36539483)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.37036443), (5, 0.032060143)]
# [(0, 0.07312699), (1, 0.30192664), (2, 0.5402581), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.34317046), (1, 0.051927675), (2, 0.5202112), (3, 0.032872263), (4, 0.027773328), (5, 0.024045108)]
# [(0, 0.08059502), (1, 0.7943359), (2, 0.040257152), (3, 0.032993525), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.25850415), (1, 0.041542124), (2, 0.23220952), (3, 0.4262894), (4, 0.02221866), (5, 0.019236082)]
# [(0, 0.048751324), (1, 0.03461841), (2, 0.026838103), (3, 0.85522044), (4, 0.018541636), (5, 0.016030071)]
# [(0, 0.47035298), (1, 0.45823425), (2, 0.023004087), (3, 0.018792609), (4, 0.01587047), (5, 0.0137456)]
# [(0, 0.0585016), (1, 0.6884266), (2, 0.03228507), (3, 0.026326254), (4, 0.1752244), (5, 0.019236084)]
# [(0, 0.65850145), (1, 0.042109143), (2, 0.032205723), (3, 0.026295861), (4, 0.22165176), (5, 0.019236084)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.040257152), (3, 0.7828698), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.82285565), (1, 0.052198928), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.7641693), (1, 0.06923683), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.3867051), (1, 0.029866917), (2, 0.02300409), (3, 0.39120093), (4, 0.01587047), (5, 0.15335247)]
# [(0, 0.038117427), (1, 0.02604356), (2, 0.020128587), (3, 0.6397946), (4, 0.2638933), (5, 0.012022553)]
# [(0, 0.14361177), (1, 0.2500862), (2, 0.017892068), (3, 0.5653796), (4, 0.0123437), (5, 0.010686714)]
# [(0, 0.073127), (1, 0.80192757), (2, 0.040257156), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.09750266), (1, 0.07169668), (2, 0.053676207), (3, 0.37469974), (4, 0.37036458), (5, 0.032060143)]
# [(0, 0.09750265), (1, 0.06923682), (2, 0.7203429), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.76416516), (1, 0.0692403), (2, 0.05367684), (3, 0.04382645), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.32312688), (1, 0.05260418), (2, 0.28958032), (3, 0.28287017), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.5729433), (1, 0.051927794), (2, 0.04025725), (3, 0.032869834), (4, 0.027773328), (5, 0.2742285)]
# [(0, 0.10486117), (1, 0.06986415), (2, 0.054348797), (3, 0.43626013), (4, 0.0370311), (5, 0.29763463)]
# [(0, 0.6585016), (1, 0.04154209), (2, 0.032205723), (3, 0.22629583), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.20262063), (1, 0.12622713), (2, 0.12340769), (3, 0.15014963), (4, 0.3922498)]
# [(0, 0.13771327), (1, 0.22883311), (2, 0.023004135), (3, 0.35696593), (4, 0.2397435), (5, 0.013740061)]
# [(0, 0.6291868), (1, 0.04154209), (2, 0.032205723), (3, 0.25561062), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.3275288), (1, 0.15367924), (2, 0.013419068), (3, 0.010956611), (4, 0.39531326), (5, 0.099103)]
# [(0, 0.29931986), (1, 0.20376644), (2, 0.10554875), (3, 0.01196771), (4, 0.27974936), (5, 0.09964783)]
# [(0, 0.058501583), (1, 0.04154209), (2, 0.032205723), (3, 0.82629585), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.097502775), (1, 0.40256488), (2, 0.053676233), (3, 0.37716487), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.47030914), (1, 0.069237255), (2, 0.053676415), (3, 0.04382646), (4, 0.3308875), (5, 0.032063287)]
# [(0, 0.057959754), (1, 0.35878012), (2, 0.026838122), (3, 0.021913221), (4, 0.018535426), (5, 0.5159734)]
# [(0, 0.028080363), (1, 0.8286087), (2, 0.014638979), (3, 0.011952665), (4, 0.010099392), (5, 0.10661988)]
# [(0, 0.5731204), (1, 0.05192764), (2, 0.29026368), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.058501583), (1, 0.4974865), (2, 0.032205723), (3, 0.026295861), (4, 0.36627427), (5, 0.019236084)]
# [(0, 0.05691741), (1, 0.40609983), (2, 0.19350506), (3, 0.021913217), (4, 0.3055334), (5, 0.016031083)]
# [(0, 0.5726892), (1, 0.05236548), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.27404505)]
# [(0, 0.07312706), (1, 0.3019294), (2, 0.54025525), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.6582786), (1, 0.041756183), (2, 0.032205723), (3, 0.026307851), (4, 0.22220671), (5, 0.019244988)]
# [(0, 0.65828335), (1, 0.041758966), (2, 0.032205723), (3, 0.22629586), (4, 0.022219984), (5, 0.019236084)]
# [(0, 0.4308354), (1, 0.06923684), (2, 0.05367621), (3, 0.37716034), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.3231271), (1, 0.051927615), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.524045)]
# [(0, 0.069328055), (1, 0.04154209), (2, 0.032205723), (3, 0.41546932), (4, 0.02221866), (5, 0.41923612)]
# [(0, 0.04235804), (1, 0.3522132), (2, 0.55703497), (3, 0.01878276), (4, 0.01587047), (5, 0.013740537)]
# [(0, 0.32750076), (1, 0.355349), (2, 0.023004087), (3, 0.01878276), (4, 0.26162335), (5, 0.013740061)]
# [(0, 0.098632574), (1, 0.40141475), (2, 0.05367636), (3, 0.37718505), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.058501847), (1, 0.44121394), (2, 0.4325336), (3, 0.026295867), (4, 0.022218663), (5, 0.019236084)]
# [(0, 0.058501583), (1, 0.041582342), (2, 0.032205723), (3, 0.8262556), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.039433308), (1, 0.27307075), (2, 0.020152397), (3, 0.016434914), (4, 0.22316062), (5, 0.427748)]
# [(0, 0.51690924), (1, 0.3580966), (2, 0.040257152), (3, 0.032918572), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.295123), (1, 0.20491679), (2, 0.0230041), (3, 0.304504), (4, 0.15871203), (5, 0.01374006)]
# [(0, 0.32313135), (1, 0.051927682), (2, 0.04025719), (3, 0.2828733), (4, 0.027773328), (5, 0.2740372)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.38700998), (3, 0.3771593), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.5731243), (1, 0.051927634), (2, 0.040257163), (3, 0.032869827), (4, 0.277776), (5, 0.024045106)]
# [(0, 0.037967965), (1, 0.02609665), (2, 0.24435386), (3, 0.43893018), (4, 0.013886661), (5, 0.23876467)]
# [(0, 0.21989568), (1, 0.21516474), (2, 0.020128584), (3, 0.39390996), (4, 0.01388666), (5, 0.13701433)]
# [(0, 0.29910788), (1, 0.025963813), (2, 0.38258147), (3, 0.016435064), (4, 0.013886662), (5, 0.2620251)]
# [(0, 0.120049335), (1, 0.7133568), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.19106835), (1, 0.18405604), (2, 0.096924536), (3, 0.093400545), (4, 0.34315768), (5, 0.091392845)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.040257152), (3, 0.7828698), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.43084216), (1, 0.40256393), (2, 0.053676244), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.058501594), (1, 0.0417535), (2, 0.032205723), (3, 0.42629686), (4, 0.42200628), (5, 0.019236084)]
# [(0, 0.09750265), (1, 0.06923682), (2, 0.053676207), (3, 0.7104906), (4, 0.03703359), (5, 0.032060143)]
# [(0, 0.3231269), (1, 0.051927622), (2, 0.040257156), (3, 0.032869827), (4, 0.2777718), (5, 0.27404666)]
# [(0, 0.8221945), (1, 0.05285358), (2, 0.040257152), (3, 0.032869827), (4, 0.027779875), (5, 0.024045106)]
# [(0, 0.50315076), (1, 0.41355228), (2, 0.026838101), (3, 0.021913217), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.25848198), (1, 0.6415616), (2, 0.03220574), (3, 0.026295865), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.6582045), (1, 0.04225559), (2, 0.23171748), (3, 0.026365852), (4, 0.022218661), (5, 0.019237917)]
# [(0, 0.048751388), (1, 0.03461844), (2, 0.69353646), (3, 0.021913221), (4, 0.018515551), (5, 0.18266495)]
# [(0, 0.15536974), (1, 0.6946439), (2, 0.016102882), (3, 0.11315123), (4, 0.01111417)]
# [(0, 0.5755778), (1, 0.18152073), (2, 0.023004089), (3, 0.018790554), (4, 0.18736626), (5, 0.01374054)]
# [(0, 0.32212377), (1, 0.053054597), (2, 0.040257152), (3, 0.532741), (4, 0.02777835), (5, 0.024045106)]
# [(0, 0.4308366), (1, 0.4025695), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.0487516), (1, 0.86795145), (2, 0.02683812), (3, 0.02191322), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.11391906), (1, 0.21869047), (2, 0.013419052), (3, 0.5462536), (5, 0.09845845)]
# [(0, 0.073126994), (1, 0.051927622), (2, 0.040257156), (3, 0.7828698), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.755956), (1, 0.029761786), (2, 0.023004094), (3, 0.018788397), (4, 0.01587047), (5, 0.15661928)]
# [(0, 0.51339644), (1, 0.01298193), (2, 0.07868688), (3, 0.23953064), (4, 0.081948854), (5, 0.07345531)]
# [(0, 0.5310413), (1, 0.014866911), (2, 0.17533699), (3, 0.17400038), (5, 0.096817456)]
# [(0, 0.43083546), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.365394)]
# [(0, 0.38990664), (1, 0.017309256), (2, 0.013419128), (3, 0.010960371), (4, 0.24085802), (5, 0.3275466)]
# [(0, 0.09751027), (1, 0.73589563), (2, 0.053676385), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.32312843), (1, 0.051927637), (2, 0.29025397), (3, 0.2828696), (4, 0.027775232), (5, 0.024045106)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.4309125), (1, 0.06923723), (2, 0.053676356), (3, 0.37708268), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.6585004), (1, 0.041542105), (2, 0.032205727), (3, 0.22629707), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.43083605), (1, 0.06923682), (2, 0.3870095), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312698), (1, 0.052891105), (2, 0.040257152), (3, 0.78190637), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.040257152), (3, 0.78286666), (4, 0.027776469), (5, 0.024045106)]
# [(0, 0.09425193), (1, 0.05192762), (2, 0.040257152), (3, 0.7617444), (4, 0.027773831), (5, 0.024045106)]
# [(0, 0.823127), (1, 0.05192764), (2, 0.040257163), (3, 0.03286983), (4, 0.027773328), (5, 0.02404511)]
# [(0, 0.76416516), (1, 0.06924028), (2, 0.05367683), (3, 0.043826446), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.33244455), (1, 0.051928136), (2, 0.04025737), (3, 0.032981675), (4, 0.027773332), (5, 0.514615)]
# [(0, 0.6291975), (1, 0.04154209), (2, 0.032205723), (3, 0.25559992), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.37715974), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750274), (1, 0.40256536), (2, 0.05367622), (3, 0.37716445), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.097504675), (1, 0.06923707), (2, 0.72034055), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.2577246), (1, 0.042319093), (2, 0.23220572), (3, 0.42629585), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.3231271), (1, 0.5519069), (2, 0.040257156), (3, 0.03286983), (4, 0.027793964), (5, 0.024045108)]
# [(0, 0.0585016), (1, 0.041542098), (2, 0.2322022), (3, 0.19005701), (4, 0.45846105), (5, 0.019236084)]
# [(0, 0.30134088), (1, 0.152441), (2, 0.26421773), (3, 0.26315543), (4, 0.010101329)]
# [(0, 0.2652952), (1, 0.11755778), (2, 0.0100643085), (3, 0.37230143), (4, 0.1633262), (5, 0.07145511)]
# [(0, 0.411548), (1, 0.1509615), (2, 0.1451275), (3, 0.016451921), (4, 0.013886662), (5, 0.26202446)]
# [(0, 0.08653498), (1, 0.051927615), (2, 0.040257152), (3, 0.5194618), (4, 0.027773324), (5, 0.27404514)]
# [(0, 0.4017492), (1, 0.041542165), (2, 0.032205764), (3, 0.026295865), (4, 0.47897094), (5, 0.019236084)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.36539352)]
# [(0, 0.38204604), (1, 0.1429728), (2, 0.01789207), (3, 0.4340587), (4, 0.0123437), (5, 0.010686714)]
# [(0, 0.43083617), (1, 0.06923684), (2, 0.053676207), (3, 0.3771595), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750296), (1, 0.06923693), (2, 0.7203424), (3, 0.04382644), (4, 0.0370311), (5, 0.03206014)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.4308379), (1, 0.4025682), (2, 0.053676218), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750265), (1, 0.06923682), (2, 0.7203429), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.5724388), (1, 0.052616492), (2, 0.29025647), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.104915746), (1, 0.3181733), (2, 0.012386824), (3, 0.46661198), (4, 0.09051371)]
# [(0, 0.08980485), (1, 0.53525794), (2, 0.040257167), (3, 0.28286165), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.2585016), (1, 0.041542094), (2, 0.032205723), (3, 0.62629586), (4, 0.022218661), (5, 0.019236086)]
# [(0, 0.30484426), (1, 0.43929315), (4, 0.0796499), (5, 0.15899198)]
# [(0, 0.4567326), (1, 0.03461848), (2, 0.193519), (3, 0.2805843), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.5485669), (1, 0.034802537), (2, 0.026838101), (3, 0.35524687), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.43083608), (1, 0.4025538), (2, 0.053676203), (3, 0.043826435), (4, 0.03704738), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.070639774), (2, 0.053676203), (3, 0.39442813), (4, 0.35169312), (5, 0.032060143)]
# [(0, 0.097504996), (1, 0.06925539), (2, 0.7203211), (3, 0.043826472), (4, 0.037031848), (5, 0.032060165)]
# [(0, 0.27175578), (1, 0.0122182695), (3, 0.07628735), (4, 0.40858963), (5, 0.2216245)]
# [(0, 0.18462671), (1, 0.5926265), (2, 0.023041684), (3, 0.17008989), (4, 0.015875135), (5, 0.013740061)]
# [(0, 0.0975048), (1, 0.41037306), (2, 0.37920448), (3, 0.043826446), (4, 0.037031103), (5, 0.03206015)]
# [(0, 0.058501713), (1, 0.641569), (2, 0.03220575), (3, 0.22626881), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.43083617), (1, 0.06923682), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.36539325)]
# [(0, 0.43083698), (1, 0.06923684), (2, 0.05367621), (3, 0.37715873), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.55021864), (1, 0.026425699), (2, 0.020279692), (3, 0.016434914), (4, 0.37461826), (5, 0.012022816)]
# [(0, 0.073127665), (1, 0.051927708), (2, 0.04025904), (3, 0.032869842), (4, 0.027773334), (5, 0.7740424)]
# [(0, 0.16817355), (1, 0.015289585), (2, 0.011503207), (3, 0.45135662), (4, 0.34680519)]
# [(0, 0.89884764), (1, 0.029746346), (2, 0.023004083), (3, 0.018787423), (4, 0.015874436), (5, 0.013740059)]
# [(0, 0.43083525), (1, 0.06923682), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.3653942)]
# [(0, 0.43074945), (1, 0.06923682), (2, 0.053676203), (3, 0.04391296), (4, 0.0370311), (5, 0.3653935)]
# [(0, 0.43082824), (1, 0.06923687), (2, 0.05367622), (3, 0.043826435), (4, 0.3703699), (5, 0.032062303)]
# [(0, 0.09432736), (1, 0.23330852), (2, 0.020128576), (3, 0.6263262), (4, 0.013886806), (5, 0.012022553)]
# [(0, 0.7632065), (1, 0.07019963), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.4084948), (1, 0.33727872), (2, 0.016102862), (3, 0.217383), (4, 0.011119855)]
# [(0, 0.073126994), (1, 0.31585047), (2, 0.040257152), (3, 0.51894695), (4, 0.02777332), (5, 0.024045102)]
# [(0, 0.21126722), (1, 0.11981057), (2, 0.06547286), (3, 0.13455689), (5, 0.4630344)]
# [(0, 0.11976948), (1, 0.71363664), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.7607214), (1, 0.072665714), (2, 0.053676203), (3, 0.043826435), (4, 0.037050173), (5, 0.032060143)]
# [(0, 0.25178018), (1, 0.36795178), (2, 0.026838101), (3, 0.31888428), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.43083847), (1, 0.06923685), (2, 0.387007), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.5880582), (1, 0.13418749), (2, 0.01789207), (3, 0.23683193), (4, 0.0123437), (5, 0.010686714)]
# [(0, 0.46214983), (1, 0.05248777), (2, 0.040257152), (3, 0.39328682), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.25850332), (1, 0.04154213), (2, 0.23221445), (3, 0.42628533), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.7635882), (1, 0.06981792), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.43082222), (1, 0.0692369), (2, 0.053676236), (3, 0.043826442), (4, 0.037031103), (5, 0.3654071)]
# [(0, 0.50311154), (1, 0.41359147), (2, 0.026838101), (3, 0.021913217), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.57270616), (1, 0.05234844), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.2740451)]
# [(0, 0.07628006), (1, 0.79777837), (2, 0.0412431), (3, 0.03286984), (4, 0.027783541), (5, 0.024045108)]
# [(0, 0.1043533), (1, 0.06923682), (2, 0.053676203), (3, 0.3703089), (4, 0.0370311), (5, 0.36539364)]
# [(0, 0.52902955), (1, 0.02167416), (2, 0.016123695), (3, 0.13028921), (4, 0.29326534)]
# [(0, 0.26119715), (1, 0.041542187), (2, 0.62951005), (3, 0.026295865), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.23661652), (1, 0.27541384), (2, 0.04644523), (3, 0.3941634), (5, 0.0430882)]
# [(0, 0.09750386), (1, 0.069237), (2, 0.053676262), (3, 0.04382644), (4, 0.0370311), (5, 0.69872534)]
# [(0, 0.38206813), (1, 0.53463495), (2, 0.026838118), (3, 0.021913221), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.097502634), (1, 0.4025702), (2, 0.0536762), (3, 0.3771597), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.2585016), (1, 0.04154209), (2, 0.032205723), (3, 0.62629586), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.5729873), (1, 0.30192703), (2, 0.040397402), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.32312968), (1, 0.3019319), (2, 0.040257175), (3, 0.28286287), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.6132499), (1, 0.026243117), (2, 0.020128576), (3, 0.18946292), (4, 0.013892862), (5, 0.13702269)]
# [(0, 0.09750265), (1, 0.4025699), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.36539373)]
# [(0, 0.05909037), (1, 0.6292001), (2, 0.032205775), (3, 0.238049), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.16156319), (1, 0.026169568), (2, 0.020128576), (3, 0.76622826), (4, 0.013887846), (5, 0.012022553)]
# [(0, 0.04178935), (1, 0.17277011), (2, 0.73704726), (3, 0.01878276), (4, 0.01587047), (5, 0.013740061)]
# [(0, 0.21540661), (1, 0.201281), (2, 0.026838118), (3, 0.20527546), (4, 0.33516872), (5, 0.016030071)]
# [(0, 0.53656334), (1, 0.02596381), (2, 0.020128576), (3, 0.39143506), (4, 0.013886662), (5, 0.012022553)]
# [(0, 0.39015952), (1, 0.018954987), (2, 0.10555038), (3, 0.466492), (4, 0.01009939)]
# [(0, 0.8580511), (1, 0.0419651), (2, 0.032205723), (3, 0.026300889), (4, 0.022241099), (5, 0.019236084)]
# [(0, 0.027539212), (1, 0.48249015), (2, 0.014638964), (3, 0.45648202), (4, 0.01010599)]
# [(0, 0.7641333), (1, 0.06923682), (2, 0.053676203), (3, 0.04386245), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.65828073), (1, 0.041755892), (2, 0.032205723), (3, 0.22629586), (4, 0.02221866), (5, 0.019243121)]
# [(0, 0.21541792), (1, 0.03461841), (2, 0.19350457), (3, 0.52191347), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.823127), (1, 0.051927615), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.05850163), (1, 0.24153498), (2, 0.03220573), (3, 0.62630254), (4, 0.022219053), (5, 0.019236084)]
# [(0, 0.289656), (1, 0.24990508), (2, 0.082929336), (3, 0.1890117), (4, 0.18162782)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.040257152), (3, 0.032869827), (4, 0.52777314), (5, 0.2740453)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.37036443), (5, 0.032060143)]
# [(0, 0.42801127), (1, 0.07206078), (2, 0.3870103), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.28656015), (1, 0.025963878), (2, 0.1451385), (3, 0.14137344), (4, 0.38894153), (5, 0.012022555)]
# [(0, 0.5731272), (1, 0.05192762), (2, 0.29025695), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.4585072), (1, 0.24154118), (2, 0.032205746), (3, 0.22629113), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.5028444), (1, 0.023160966), (2, 0.017892104), (3, 0.014612718), (4, 0.3055761), (5, 0.13591379)]
# [(0, 0.38668436), (1, 0.025963837), (2, 0.020294525), (3, 0.20423351), (4, 0.22579592), (5, 0.13702786)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.040257152), (3, 0.5263336), (4, 0.28430963), (5, 0.024045106)]
# [(0, 0.097502805), (1, 0.40256318), (2, 0.053676236), (3, 0.37716654), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.07312698), (1, 0.051927615), (2, 0.79025716), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.10839621), (1, 0.07006463), (2, 0.053676203), (3, 0.3654383), (4, 0.0370311), (5, 0.36539355)]
# [(0, 0.28634256), (1, 0.026184773), (2, 0.020128576), (3, 0.64143485), (4, 0.013886662), (5, 0.012022553)]
# [(0, 0.18378721), (1, 0.12077235), (2, 0.116104506), (3, 0.25409314), (4, 0.011114691), (5, 0.31412807)]
# [(0, 0.43083763), (1, 0.06923684), (2, 0.38700783), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.32607463), (1, 0.05192792), (2, 0.33771223), (3, 0.03286984), (4, 0.027773414), (5, 0.22364198)]
# [(0, 0.09008244), (1, 0.53497225), (2, 0.040257152), (3, 0.032869827), (4, 0.27777323), (5, 0.024045106)]
# [(0, 0.6585014), (1, 0.041542094), (2, 0.032205723), (3, 0.22629604), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.76357865), (1, 0.06982744), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.7635439), (1, 0.06979927), (2, 0.053676203), (3, 0.043889374), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.76358247), (1, 0.06982366), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750282), (1, 0.06923688), (2, 0.053676236), (3, 0.71049285), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.17841758), (1, 0.3752872), (2, 0.02012858), (3, 0.40025592), (4, 0.013888192), (5, 0.012022553)]
# [(0, 0.039032366), (1, 0.25862086), (2, 0.02012858), (3, 0.656309), (4, 0.013886663), (5, 0.012022554)]
# [(0, 0.07312698), (1, 0.055154417), (2, 0.040257152), (3, 0.53050137), (4, 0.27691495), (5, 0.024045106)]
# [(0, 0.573133), (1, 0.3019216), (2, 0.040257182), (3, 0.032869834), (4, 0.027773328), (5, 0.024045108)]
# [(0, 0.09750273), (1, 0.40256974), (2, 0.053676218), (3, 0.04382643), (4, 0.37036473), (5, 0.03206014)]
# [(0, 0.07312698), (1, 0.30192763), (2, 0.040257152), (3, 0.5328698), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.34440166), (1, 0.23896812), (2, 0.026838103), (3, 0.35524654), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.430836), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.3703644), (5, 0.032060143)]
# [(0, 0.45850152), (1, 0.04154209), (2, 0.032205723), (3, 0.22629268), (4, 0.022221692), (5, 0.21923628)]
# [(0, 0.25849646), (1, 0.041542105), (2, 0.63221085), (3, 0.026295861), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.823127), (1, 0.05192762), (2, 0.040257156), (3, 0.03286983), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.0536762), (3, 0.37715888), (4, 0.037031095), (5, 0.36539432)]
# [(0, 0.43083543), (1, 0.06923682), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.365394)]
# [(0, 0.18463738), (1, 0.18839106), (2, 0.023004092), (3, 0.018820997), (4, 0.4285493), (5, 0.15659714)]
# [(0, 0.57312566), (1, 0.3019289), (2, 0.04025716), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.51714873), (1, 0.029810097), (2, 0.40464783), (3, 0.01878277), (4, 0.01587047), (5, 0.01374007)]
# [(0, 0.21438584), (1, 0.33201694), (2, 0.011502057), (3, 0.42728993)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.3653935)]
# [(0, 0.09750274), (1, 0.40256226), (2, 0.3870173), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.038067117), (1, 0.7551337), (2, 0.020238044), (3, 0.016434914), (4, 0.013886662), (5, 0.15623961)]
# [(0, 0.38208148), (1, 0.53462154), (2, 0.026838103), (3, 0.021913217), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.7641652), (1, 0.069240265), (2, 0.053676825), (3, 0.043826446), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.57269865), (1, 0.05236464), (2, 0.040257175), (3, 0.03286983), (4, 0.27776465), (5, 0.024045106)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.021529514), (1, 0.2137818), (2, 0.34280393), (3, 0.19270714), (5, 0.22175953)]
# [(0, 0.44088522), (1, 0.45915836), (2, 0.032205824), (3, 0.026295867), (4, 0.022218663), (5, 0.019236084)]
# [(0, 0.63844955), (1, 0.14187053), (2, 0.017892066), (3, 0.014638756), (4, 0.012349093), (5, 0.17479996)]
# [(0, 0.3272465), (1, 0.029927567), (2, 0.023004087), (3, 0.59021133), (4, 0.01587047), (5, 0.013740061)]
# [(0, 0.5475611), (1, 0.01604035), (2, 0.012475281), (3, 0.086947456), (4, 0.21875818), (5, 0.11821764)]
# [(0, 0.1292493), (1, 0.020915266), (2, 0.11610242), (3, 0.7130056), (4, 0.01110933)]
# [(0, 0.045108918), (1, 0.02998047), (2, 0.15712646), (3, 0.018782761), (4, 0.56169766), (5, 0.18730368)]
# [(0, 0.32832444), (1, 0.023468155), (2, 0.12892587), (3, 0.34798968), (4, 0.16060516), (5, 0.010686714)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.37715948), (4, 0.0370311), (5, 0.36539376)]
# [(0, 0.5727024), (1, 0.05234941), (2, 0.040257167), (3, 0.28287256), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.82284915), (1, 0.052205466), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.5153882), (1, 0.029673059), (2, 0.02300413), (3, 0.018787136), (4, 0.1922903), (5, 0.22085713)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750594), (1, 0.73590004), (2, 0.053676333), (3, 0.04382644), (4, 0.0370311), (5, 0.03206014)]
# [(0, 0.041787136), (1, 0.5225793), (2, 0.023004118), (3, 0.018782761), (4, 0.38010666), (5, 0.013740061)]
# [(0, 0.09750365), (1, 0.40254223), (2, 0.3870364), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.5731264), (1, 0.05256072), (2, 0.2896224), (3, 0.03286983), (4, 0.027773326), (5, 0.02404741)]
# [(0, 0.04875132), (1, 0.2658495), (2, 0.026838101), (3, 0.62401545), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.6254898), (1, 0.023650685), (2, 0.01789213), (3, 0.30993658), (4, 0.012344101), (5, 0.010686712)]
# [(0, 0.7628259), (1, 0.07053801), (2, 0.053676203), (3, 0.043826435), (4, 0.037073344), (5, 0.032060143)]
# [(0, 0.40631208), (1, 0.014840708), (2, 0.011502055), (3, 0.08362234), (4, 0.4038371), (5, 0.079885736)]
# [(0, 0.7641685), (1, 0.06923744), (2, 0.053676378), (3, 0.043826442), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.029251022), (1, 0.02077112), (2, 0.22467978), (3, 0.0131479325), (4, 0.01110933), (5, 0.70104074)]
# [(0, 0.097502686), (1, 0.40257168), (2, 0.38700798), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.2585017), (1, 0.041542094), (2, 0.032205723), (3, 0.026295861), (4, 0.22221789), (5, 0.41923672)]
# [(0, 0.097502686), (1, 0.06923684), (2, 0.053676214), (3, 0.043826435), (4, 0.0370311), (5, 0.6987267)]
# [(0, 0.27187708), (1, 0.014985916), (2, 0.011502045), (3, 0.26184073), (4, 0.2831699), (5, 0.15662438)]
# [(2, 0.065436244), (3, 0.17828725), (4, 0.6774963), (5, 0.06351379)]
# [(0, 0.4308366), (1, 0.40256953), (2, 0.053676218), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.09750298), (1, 0.4025866), (2, 0.053676277), (3, 0.37714288), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.7627443), (1, 0.07066179), (2, 0.053676207), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.03439429), (1, 0.36582386), (2, 0.017892081), (3, 0.44777477), (4, 0.012343863), (5, 0.12177118)]
# [(0, 0.7634896), (1, 0.06990909), (2, 0.05367682), (3, 0.04382645), (4, 0.03703789), (5, 0.032060146)]
# [(0, 0.822853), (1, 0.05220155), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.43083408), (1, 0.06923683), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.36539534)]
# [(0, 0.38681486), (1, 0.026107829), (2, 0.020128576), (3, 0.14143504), (4, 0.41349116), (5, 0.012022553)]
# [(0, 0.32312533), (1, 0.05192763), (2, 0.5402588), (3, 0.03286983), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.36539343)]
# [(0, 0.40356943), (1, 0.023702439), (2, 0.017892072), (3, 0.42069304), (4, 0.0123437), (5, 0.12179935)]
# [(0, 0.03413781), (1, 0.5681307), (2, 0.017892066), (3, 0.35680896), (4, 0.012343698), (5, 0.010686712)]
# [(0, 0.76360744), (1, 0.06979866), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09752044), (1, 0.06923739), (2, 0.053676456), (3, 0.31226793), (4, 0.037031107), (5, 0.43026668)]
# [(0, 0.21724556), (1, 0.20800497), (2, 0.026838174), (3, 0.021913223), (4, 0.509968), (5, 0.016030071)]
# [(0, 0.430836), (1, 0.06923682), (2, 0.053676203), (3, 0.3771597), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312699), (1, 0.052190777), (2, 0.5053263), (3, 0.032869827), (4, 0.31243998), (5, 0.024046158)]
# [(0, 0.45813766), (1, 0.04189595), (2, 0.03220573), (3, 0.026295861), (4, 0.02221866), (5, 0.41924614)]
# [(0, 0.04875132), (1, 0.03461841), (2, 0.026838101), (3, 0.85524654), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312699), (1, 0.05192762), (2, 0.040257156), (3, 0.78286934), (4, 0.027773816), (5, 0.024045108)]
# [(0, 0.42954066), (1, 0.07053214), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.36539343)]
# [(0, 0.013473042), (1, 0.058012437), (3, 0.79900306), (4, 0.0673676), (5, 0.054824367)]
# [(0, 0.85834265), (1, 0.041701056), (2, 0.032205723), (3, 0.026295861), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.76416934), (1, 0.069236815), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.37405872), (1, 0.025963886), (2, 0.020178817), (3, 0.5538894), (4, 0.013886663), (5, 0.012022553)]
# [(0, 0.048781913), (1, 0.034696717), (2, 0.026838101), (3, 0.686533), (4, 0.1871202), (5, 0.016030071)]
# [(0, 0.36558664), (1, 0.023327036), (2, 0.017892068), (3, 0.4590523), (4, 0.012343698), (5, 0.12179821)]
# [(0, 0.43083814), (1, 0.40256798), (2, 0.05367623), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.3653935)]
# [(0, 0.82312703), (1, 0.051927615), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.764151), (1, 0.069236815), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03207847)]
# [(0, 0.51235473), (1, 0.051927615), (2, 0.040257152), (3, 0.343633), (4, 0.027782433), (5, 0.024045106)]
# [(0, 0.57312745), (1, 0.30183458), (2, 0.04025716), (3, 0.03295257), (4, 0.027783196), (5, 0.024045108)]
# [(0, 0.43083474), (1, 0.4025714), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312698), (1, 0.054001056), (2, 0.29025704), (3, 0.53079146), (4, 0.027778374), (5, 0.024045106)]
# [(0, 0.25768107), (1, 0.04272783), (2, 0.032205723), (3, 0.6259306), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.57312757), (1, 0.051927637), (2, 0.040257163), (3, 0.28286925), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.07312699), (1, 0.5519288), (2, 0.040257152), (3, 0.032869823), (4, 0.02777332), (5, 0.27404386)]
# [(0, 0.32211617), (1, 0.05293843), (2, 0.040257156), (3, 0.5328699), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.512965), (1, 0.23707807), (2, 0.116110824), (3, 0.013147931), (4, 0.01110933), (5, 0.109588794)]
# [(0, 0.26381567), (1, 0.17597413), (2, 0.17702998), (3, 0.36014712), (4, 0.012346388), (5, 0.010686714)]
# [(0, 0.22397548), (1, 0.2369491), (2, 0.026838174), (3, 0.47769162), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.27505675), (1, 0.041542135), (2, 0.032205746), (3, 0.026295865), (4, 0.34739637), (5, 0.27750313)]
# [(0, 0.030660888), (1, 0.27023295), (2, 0.016102862), (3, 0.4622748), (4, 0.21110937)]
# [(0, 0.8228017), (1, 0.052193135), (2, 0.040257156), (3, 0.032929607), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.5730985), (1, 0.05192762), (2, 0.040257156), (3, 0.032898314), (4, 0.027773326), (5, 0.27404517)]
# [(0, 0.38180327), (1, 0.034949347), (2, 0.026838109), (3, 0.52186364), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.763493), (1, 0.06979235), (2, 0.053676203), (3, 0.04394719), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.6585007), (1, 0.041638397), (2, 0.032205723), (3, 0.02632401), (4, 0.22209513), (5, 0.019236084)]
# [(0, 0.3741697), (1, 0.5258211), (2, 0.032205727), (3, 0.02634873), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.04178685), (1, 0.030149857), (2, 0.16586101), (3, 0.73259175), (4, 0.01587047), (5, 0.013740061)]
# [(0, 0.45850143), (1, 0.0432986), (2, 0.032205723), (3, 0.4245395), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.32215983), (1, 0.05289485), (2, 0.040257152), (3, 0.032869827), (4, 0.277773), (5, 0.27404538)]
# [(0, 0.041786846), (1, 0.45824435), (2, 0.023004087), (3, 0.44735417), (4, 0.01587047), (5, 0.013740061)]
# [(0, 0.25961632), (1, 0.31526306), (2, 0.10109159), (3, 0.010956611), (5, 0.30381212)]
# [(0, 0.43083605), (1, 0.06923684), (2, 0.053676214), (3, 0.043826435), (4, 0.0370311), (5, 0.36539337)]
# [(0, 0.0864289), (1, 0.15926714), (2, 0.088455044), (3, 0.2703566), (4, 0.3575838), (5, 0.037908524)]
# [(0, 0.48193973), (1, 0.04185769), (2, 0.03220577), (3, 0.026295865), (4, 0.022218661), (5, 0.3954823)]
# [(0, 0.6031526), (1, 0.034777794), (2, 0.0268381), (3, 0.021913216), (4, 0.018515548), (5, 0.29480273)]
# [(0, 0.5731263), (1, 0.30192828), (2, 0.04025716), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.2583422), (1, 0.12898457), (2, 0.14328605), (3, 0.44865817), (4, 0.011110997)]
# [(0, 0.7641652), (1, 0.069240265), (2, 0.05367683), (3, 0.043826446), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312727), (1, 0.051927682), (2, 0.7902568), (3, 0.03286983), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.4345182), (1, 0.069238156), (2, 0.053676296), (3, 0.04382649), (4, 0.037031103), (5, 0.3617098)]
# [(0, 0.22924969), (1, 0.38315672), (2, 0.016102903), (3, 0.35076332), (4, 0.0111093335)]
# [(0, 0.09750412), (1, 0.06923704), (2, 0.05367628), (3, 0.043826446), (4, 0.037031103), (5, 0.69872504)]
# [(0, 0.3655632), (1, 0.023335017), (2, 0.017892085), (3, 0.5701792), (4, 0.012343701), (5, 0.010686714)]
# [(0, 0.329246), (1, 0.120771766), (2, 0.31610543), (3, 0.113148674), (4, 0.01110933), (5, 0.1096188)]
# [(0, 0.32924277), (1, 0.22075477), (2, 0.016121697), (3, 0.41315302), (4, 0.011109717)]
# [(0, 0.42954472), (1, 0.070528865), (2, 0.38700876), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.76396185), (1, 0.06923682), (2, 0.05388363), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.823097), (1, 0.051927615), (2, 0.040257152), (3, 0.032899816), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.09750265), (1, 0.7359035), (2, 0.053676207), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.658283), (1, 0.041765463), (2, 0.2322009), (3, 0.026295861), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.2774755), (1, 0.023287218), (2, 0.1289963), (3, 0.014613218), (4, 0.43160447), (5, 0.1240233)]
# [(0, 0.43083462), (1, 0.06923682), (2, 0.053676203), (3, 0.04382643), (4, 0.037031095), (5, 0.3653948)]
# [(0, 0.20855832), (1, 0.10979376), (2, 0.0146393515), (3, 0.28477108), (4, 0.37349376)]
# [(0, 0.764129), (1, 0.06923682), (2, 0.053676203), (3, 0.043866772), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.41639537), (1, 0.51220727), (2, 0.023004087), (3, 0.01878276), (4, 0.01587047), (5, 0.013740061)]
# [(0, 0.10095938), (1, 0.069560446), (2, 0.053676203), (3, 0.7067127), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750268), (1, 0.06923684), (2, 0.053676214), (3, 0.37716103), (4, 0.0370311), (5, 0.36539218)]
# [(0, 0.07312698), (1, 0.30192766), (2, 0.040257152), (3, 0.2828697), (4, 0.027773324), (5, 0.2740452)]
# [(0, 0.058501743), (1, 0.24154505), (2, 0.032205798), (3, 0.42630202), (4, 0.022218693), (5, 0.21922667)]
# [(0, 0.09941697), (1, 0.016033297), (2, 0.01238682), (3, 0.7759006), (4, 0.088863775)]
# [(0, 0.058502354), (1, 0.04154224), (2, 0.03220578), (3, 0.2208538), (4, 0.20780714), (5, 0.43908873)]
# [(0, 0.4295093), (1, 0.07056397), (2, 0.053676207), (3, 0.043826435), (4, 0.0370311), (5, 0.36539295)]
# [(0, 0.28653702), (1, 0.19172312), (2, 0.020128584), (3, 0.47567564), (4, 0.013909249), (5, 0.012026371)]
# [(0, 0.412375), (1, 0.02596383), (2, 0.020128587), (3, 0.016450867), (4, 0.13923165), (5, 0.38585004)]
# [(0, 0.07312753), (1, 0.051927727), (2, 0.7902565), (3, 0.032869834), (4, 0.027773328), (5, 0.024045108)]
# [(0, 0.053001408), (1, 0.36795273), (2, 0.026838103), (3, 0.5176621), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.4306886), (1, 0.40256986), (2, 0.053676207), (3, 0.04397409), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.11901632), (1, 0.22069763), (2, 0.13837421), (3, 0.10338607), (4, 0.010099395), (5, 0.4084264)]
# [(0, 0.39820778), (1, 0.02372041), (2, 0.12871693), (3, 0.23682512), (4, 0.20184201), (5, 0.01068773)]
# [(0, 0.5730919), (1, 0.05192762), (2, 0.29025805), (3, 0.032904036), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.715286), (1, 0.034750517), (2, 0.026838101), (3, 0.021913217), (4, 0.18518211), (5, 0.016030071)]
# [(0, 0.8228294), (1, 0.052195158), (2, 0.040257152), (3, 0.032899864), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.7359035), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.43083605), (1, 0.06923682), (2, 0.38700947), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.038124584), (1, 0.02596381), (2, 0.020128578), (3, 0.63735443), (4, 0.14140658), (5, 0.137022)]
# [(0, 0.41326958), (1, 0.2867741), (2, 0.032205723), (3, 0.22629583), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.06210181), (1, 0.25585437), (2, 0.6142932), (3, 0.02629587), (4, 0.022218663), (5, 0.019236086)]
# [(0, 0.49394587), (1, 0.023078974), (2, 0.30931154), (3, 0.014608813), (4, 0.0123441825), (5, 0.14671066)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.3771594), (4, 0.0370311), (5, 0.36539385)]
# [(0, 0.21542105), (1, 0.034817927), (2, 0.026838118), (3, 0.3552523), (4, 0.1849877), (5, 0.18268293)]
# [(0, 0.7641275), (1, 0.06923682), (2, 0.053676203), (3, 0.04382643), (4, 0.037072916), (5, 0.03206014)]
# [(0, 0.042430267), (1, 0.02967293), (2, 0.30872077), (3, 0.18224002), (4, 0.42319584), (5, 0.013740189)]
# [(0, 0.7641289), (1, 0.06923682), (2, 0.053676203), (3, 0.043866847), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.30222362), (1, 0.24153116), (2, 0.032205734), (3, 0.026341785), (4, 0.17850213), (5, 0.21919557)]
# [(0, 0.0585016), (1, 0.61673534), (2, 0.03221653), (3, 0.2510827), (4, 0.022227788), (5, 0.019236084)]
# [(0, 0.073135704), (1, 0.051935658), (2, 0.040257253), (3, 0.782853), (4, 0.027773326), (5, 0.024045106)]
# [(0, 0.027413359), (1, 0.01888277), (2, 0.014638966), (3, 0.92022175), (4, 0.01009944)]
# [(0, 0.2255164), (1, 0.18483026), (2, 0.055287033), (3, 0.1374249), (4, 0.39236137)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.04122673), (1, 0.026423065), (2, 0.020128576), (3, 0.40138906), (4, 0.49880883), (5, 0.012023747)]
# [(0, 0.09750271), (1, 0.069236845), (2, 0.053676218), (3, 0.04382644), (4, 0.037031103), (5, 0.6987267)]
# [(0, 0.02693546), (1, 0.10976493), (2, 0.10555356), (3, 0.64566106), (4, 0.010113519), (5, 0.101971485)]
# [(0, 0.07464557), (1, 0.30192307), (2, 0.04025716), (3, 0.032869827), (4, 0.27625585), (5, 0.27404854)]
# [(0, 0.09750274), (1, 0.06923686), (2, 0.053676225), (3, 0.3771635), (4, 0.3703605), (5, 0.03206014)]
# [(0, 0.2585021), (1, 0.04392805), (2, 0.032232206), (3, 0.6238605), (4, 0.022241011), (5, 0.019236084)]
# [(0, 0.09750264), (1, 0.7358648), (2, 0.053676203), (3, 0.043865144), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.572706), (1, 0.052348632), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.27404514)]
# [(0, 0.058501612), (1, 0.24639702), (2, 0.032205727), (3, 0.026306903), (4, 0.4173501), (5, 0.21923864)]
# [(0, 0.09750264), (1, 0.40257022), (2, 0.053676203), (3, 0.04390328), (4, 0.0370311), (5, 0.3653166)]
# [(0, 0.43083584), (1, 0.40247765), (2, 0.053676203), (3, 0.043919053), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750265), (1, 0.7359035), (2, 0.053676207), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# ...
# [(0, 0.43083596), (1, 0.06923682), (2, 0.053676203), (3, 0.37715974), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.5528462), (1, 0.013873929), (2, 0.010749568), (3, 0.26760817), (4, 0.078678675), (5, 0.07624347)]
# [(0, 0.2925956), (1, 0.029672923), (2, 0.023004087), (3, 0.1965452), (4, 0.15872738), (5, 0.29945484)]
# [(0, 0.19896355), (1, 0.64415395), (2, 0.016102863), (3, 0.013153722), (4, 0.11800782)]
# [(0, 0.69896215), (1, 0.21773648), (2, 0.0268381), (3, 0.021913216), (4, 0.018515548), (5, 0.0160345)]
# [(0, 0.33533543), (1, 0.010494484), (2, 0.10805632), (3, 0.28313383), (4, 0.20769925), (5, 0.055280685)]
# [(0, 0.45850724), (1, 0.24153094), (2, 0.032205757), (3, 0.22630134), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.7641692), (1, 0.06923687), (2, 0.053676225), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.5731272), (1, 0.3019274), (2, 0.040257156), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.39264843), (1, 0.26731226), (2, 0.09675225), (3, 0.22599186)]
# [(0, 0.7636078), (1, 0.069798306), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750266), (1, 0.06923683), (2, 0.7203429), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.6222671), (1, 0.27773768), (2, 0.032205723), (3, 0.026321482), (4, 0.022231894), (5, 0.019236084)]
# [(0, 0.25768846), (1, 0.04241789), (2, 0.032205723), (3, 0.6262332), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.42949575), (1, 0.07058234), (2, 0.05367624), (3, 0.043826446), (4, 0.3703591), (5, 0.032060143)]
# [(0, 0.6143691), (1, 0.30233392), (2, 0.026838103), (3, 0.021913217), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.76416904), (1, 0.06923698), (2, 0.053676292), (3, 0.043826442), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.21540014), (1, 0.03525807), (2, 0.5051753), (3, 0.021913217), (4, 0.20622282), (5, 0.016030496)]
# [(0, 0.5731137), (1, 0.051927615), (2, 0.040257152), (3, 0.03288302), (4, 0.27777344), (5, 0.024045106)]
# [(0, 0.11931815), (1, 0.37981907), (2, 0.053611066), (3, 0.11625637), (5, 0.32616404)]
# [(0, 0.09750265), (1, 0.7358658), (2, 0.053676203), (3, 0.043864176), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312699), (1, 0.8019276), (2, 0.040257156), (3, 0.03286983), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.29617068), (1, 0.22025365), (2, 0.023004087), (3, 0.018791221), (4, 0.01587047), (5, 0.42590988)]
# [(0, 0.073126994), (1, 0.3019248), (2, 0.040257156), (3, 0.03287609), (4, 0.52776986), (5, 0.024045106)]
# [(0, 0.2585106), (1, 0.6414399), (2, 0.032284893), (3, 0.026295865), (4, 0.02223256), (5, 0.019236203)]
# [(0, 0.097503185), (1, 0.06923698), (2, 0.053676262), (3, 0.37716785), (4, 0.37035558), (5, 0.032060143)]
# [(0, 0.1877994), (1, 0.025963817), (2, 0.020128582), (3, 0.740199), (4, 0.013886662), (5, 0.012022553)]
# [(0, 0.1949575), (1, 0.07086815), (2, 0.40517592), (3, 0.127976), (4, 0.06997215), (5, 0.13105024)]
# [(0, 0.75606), (1, 0.17252986), (2, 0.023004085), (3, 0.018795555), (4, 0.01587047), (5, 0.01374006)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.3703643), (5, 0.3653936)]
# [(0, 0.0731278), (1, 0.05192786), (2, 0.040257268), (3, 0.24790132), (4, 0.5627407), (5, 0.024045108)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.43082654), (1, 0.06923693), (2, 0.05367626), (3, 0.377169), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.430836), (1, 0.06923682), (2, 0.38699067), (3, 0.043826435), (4, 0.03704993), (5, 0.032060143)]
# [(0, 0.70043963), (1, 0.12637216), (2, 0.016102862), (3, 0.013152489), (4, 0.13431421)]
# [(0, 0.09750301), (1, 0.40255487), (2, 0.05367628), (3, 0.3771746), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.09750285), (1, 0.40258154), (2, 0.053676244), (3, 0.37714812), (4, 0.0370311), (5, 0.03206014)]
# [(0, 0.5729698), (1, 0.05192773), (2, 0.040257204), (3, 0.032998435), (4, 0.027773323), (5, 0.27407348)]
# [(0, 0.34688845), (1, 0.030536966), (2, 0.023004092), (3, 0.44179565), (4, 0.14403479), (5, 0.013740062)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312698), (1, 0.8019276), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.57255316), (1, 0.052493464), (2, 0.040257208), (3, 0.2828777), (4, 0.027773326), (5, 0.024045106)]
# [(0, 0.058501583), (1, 0.04154209), (2, 0.032205723), (3, 0.82629585), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.35869548), (1, 0.38190117), (3, 0.24338973)]
# [(0, 0.3371554), (1, 0.27670917), (2, 0.026838103), (3, 0.021949641), (4, 0.32131764), (5, 0.016030071)]
# [(0, 0.25173587), (1, 0.5912956), (2, 0.016102873), (3, 0.0131479325), (4, 0.011109331), (5, 0.11660844)]
# [(0, 0.47036725), (1, 0.18049182), (2, 0.023004103), (3, 0.29652628), (4, 0.015870472), (5, 0.013740061)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750276), (1, 0.40255904), (2, 0.05367623), (3, 0.043826435), (4, 0.0370311), (5, 0.3654044)]
# [(0, 0.10897646), (1, 0.017309213), (2, 0.09675097), (3, 0.16188593), (4, 0.6070624)]
# [(0, 0.5335501), (1, 0.03498818), (2, 0.026838114), (3, 0.20341551), (4, 0.18517804), (5, 0.016030071)]
# [(0, 0.037134167), (1, 0.2351305), (2, 0.19624597), (3, 0.3637487), (4, 0.15571812), (5, 0.012022553)]
# [(0, 0.3818357), (1, 0.023194125), (2, 0.017892087), (3, 0.12572284), (4, 0.012343701), (5, 0.43901148)]
# [(0, 0.07312699), (1, 0.05192762), (2, 0.040257156), (3, 0.78286934), (4, 0.027773816), (5, 0.024045108)]
# [(0, 0.32312527), (1, 0.051927626), (2, 0.040257156), (3, 0.2828707), (4, 0.27777413), (5, 0.024045106)]
# [(0, 0.2583908), (1, 0.0415986), (2, 0.032205805), (3, 0.62635005), (4, 0.022218663), (5, 0.019236086)]
# [(0, 0.4702013), (1, 0.0298297), (2, 0.023004089), (3, 0.44735438), (4, 0.015870472), (5, 0.013740062)]
# [(0, 0.043241866), (1, 0.8853434), (2, 0.023004087), (3, 0.018783735), (4, 0.01588687), (5, 0.013740061)]
# [(0, 0.16895868), (1, 0.39387456), (2, 0.11835788), (3, 0.14062454), (4, 0.11728331), (5, 0.060901)]
# [(0, 0.763608), (1, 0.06979815), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.75598717), (1, 0.029761976), (2, 0.02300409), (3, 0.018782757), (4, 0.15872395), (5, 0.01374006)]
# [(0, 0.68650234), (1, 0.018905979), (2, 0.014638981), (3, 0.26110956), (4, 0.0100993905)]
# [(0, 0.823121), (1, 0.051927622), (2, 0.040257156), (3, 0.032869827), (4, 0.027773324), (5, 0.02405103)]
# [(0, 0.43083587), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.36539352)]
# [(0, 0.37218335), (1, 0.10214443), (2, 0.013419073), (3, 0.09493396), (5, 0.40806141)]
# [(0, 0.09750265), (1, 0.07167296), (2, 0.053676203), (3, 0.37472305), (4, 0.0370311), (5, 0.3653941)]
# [(0, 0.0749167), (1, 0.05215947), (2, 0.040257156), (3, 0.032869827), (4, 0.52574927), (5, 0.2740476)]
# [(0, 0.42952928), (1, 0.07054365), (2, 0.053676203), (3, 0.043826435), (4, 0.3703643), (5, 0.032060143)]
# [(0, 0.07312707), (1, 0.30191836), (2, 0.04025717), (3, 0.53287756), (4, 0.027774734), (5, 0.024045106)]
# [(0, 0.76416934), (1, 0.06923682), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.07312697), (1, 0.051927608), (2, 0.04025715), (3, 0.53286964), (4, 0.02777332), (5, 0.2740453)]
# [(0, 0.430836), (1, 0.06923682), (2, 0.053676203), (3, 0.3771597), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.2969456), (1, 0.506903), (2, 0.0201286), (3, 0.016435925), (4, 0.1475644), (5, 0.012022554)]
# [(0, 0.073674075), (1, 0.051927615), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.77349806)]
# [(0, 0.062367223), (1, 0.010092197), (2, 0.15052955), (3, 0.43381068), (4, 0.13477084), (5, 0.20842952)]
# [(0, 0.43083593), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.36539352)]
# [(0, 0.25846094), (1, 0.041542195), (2, 0.23222399), (3, 0.4263181), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.09750264), (1, 0.7359035), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.16535723), (1, 0.026285267), (2, 0.020128582), (3, 0.76231974), (4, 0.013886662), (5, 0.012022553)]
# [(0, 0.04875137), (1, 0.70128435), (2, 0.02683811), (3, 0.021923734), (4, 0.18517238), (5, 0.016030071)]
# [(0, 0.058501583), (1, 0.04158154), (2, 0.032205723), (3, 0.82625455), (4, 0.022220485), (5, 0.019236084)]
# [(0, 0.24023414), (1, 0.026229333), (2, 0.020128578), (3, 0.4375005), (4, 0.013886662), (5, 0.2620208)]
# [(0, 0.09750264), (1, 0.069477946), (2, 0.053676203), (3, 0.710252), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.0761977), (1, 0.051927615), (2, 0.040257152), (3, 0.7797991), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.09750265), (1, 0.7359035), (2, 0.053676207), (3, 0.04382644), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.763608), (1, 0.06979813), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.5731272), (1, 0.05192762), (2, 0.040257156), (3, 0.28286964), (4, 0.027773326), (5, 0.024045108)]
# [(0, 0.43083623), (1, 0.06923685), (2, 0.38700926), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.4308361), (1, 0.06923682), (2, 0.3870094), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.45850015), (1, 0.24154246), (2, 0.032205723), (3, 0.026295861), (4, 0.22221974), (5, 0.019236084)]
# [(0, 0.881969), (1, 0.034722056), (2, 0.026838101), (3, 0.021925231), (4, 0.01851555), (5, 0.016030071)]
# [(0, 0.43083245), (1, 0.06923686), (2, 0.38701302), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.76398134), (1, 0.06923682), (2, 0.05386414), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.6050331), (1, 0.041778937), (2, 0.032205723), (3, 0.2795275), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.430836), (1, 0.40257013), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.097521454), (1, 0.069238506), (2, 0.053676534), (3, 0.7104723), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.16488181), (1, 0.025963921), (2, 0.020313209), (3, 0.30904108), (4, 0.18935809), (5, 0.2904419)]
# [(0, 0.42954347), (1, 0.070529364), (2, 0.053676203), (3, 0.37715974), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.64828736), (1, 0.025963873), (2, 0.28340462), (3, 0.016434914), (4, 0.013886661), (5, 0.012022551)]
# [(0, 0.058773886), (1, 0.041542094), (2, 0.23220465), (3, 0.026295861), (4, 0.6219474), (5, 0.019236084)]
# [(0, 0.09750264), (1, 0.40256998), (2, 0.053676203), (3, 0.043826435), (4, 0.37036464), (5, 0.032060143)]
# [(0, 0.327077), (1, 0.029672947), (2, 0.023430336), (3, 0.16163538), (4, 0.30158177), (5, 0.15660258)]
# [(0, 0.02446895), (1, 0.01730922), (2, 0.21825731), (3, 0.09425912), (4, 0.16981809), (5, 0.47588733)]
# [(0, 0.548566), (1, 0.034801666), (2, 0.026838107), (3, 0.021923214), (4, 0.18517417), (5, 0.18269686)]
# [(0, 0.21640067), (1, 0.034618527), (2, 0.51800233), (3, 0.021913223), (4, 0.19303523), (5, 0.016030071)]
# [(0, 0.07312699), (1, 0.5519285), (2, 0.040257152), (3, 0.032869827), (4, 0.27777243), (5, 0.024045106)]
# [(0, 0.32667774), (1, 0.04154209), (2, 0.032205723), (3, 0.55811965), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.7636077), (1, 0.06979845), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.51650774), (1, 0.35854682), (2, 0.040257152), (3, 0.032869823), (4, 0.02777332), (5, 0.024045102)]
# [(0, 0.3406134), (1, 0.21873581), (3, 0.36015755), (5, 0.064480476)]
# [(0, 0.45850095), (1, 0.24154241), (2, 0.032205723), (3, 0.02629586), (4, 0.22221892), (5, 0.019236082)]
# [(0, 0.06002714), (1, 0.44153768), (2, 0.032205727), (3, 0.026295861), (4, 0.42069754), (5, 0.019236084)]
# [(0, 0.4308352), (1, 0.06923682), (2, 0.0536762), (3, 0.04382643), (4, 0.037031095), (5, 0.36539423)]
# [(0, 0.22106609), (1, 0.0297503), (2, 0.023004089), (3, 0.35646152), (4, 0.015873572), (5, 0.35384443)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.65828484), (1, 0.041758828), (2, 0.032205723), (3, 0.026309878), (4, 0.02221866), (5, 0.21922207)]
# [(0, 0.24699461), (1, 0.40563568), (2, 0.026838101), (3, 0.021913217), (4, 0.2825877), (5, 0.016030656)]
# [(0, 0.123581044), (1, 0.15692489), (2, 0.014638967), (3, 0.2375484), (4, 0.19191265), (5, 0.27539408)]
# [(0, 0.37397057), (1, 0.5260731), (2, 0.032205738), (3, 0.026295865), (4, 0.022218661), (5, 0.019236084)]
# [(0, 0.04876734), (1, 0.47432932), (2, 0.027052818), (3, 0.41529414), (4, 0.018526288), (5, 0.01603007)]
# [(0, 0.07951898), (1, 0.36498067), (2, 0.040257163), (3, 0.46340528), (4, 0.027790053), (5, 0.024047853)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.049567536), (1, 0.034618475), (2, 0.3602301), (3, 0.18848425), (4, 0.018544212), (5, 0.34855548)]
# [(0, 0.09750271), (1, 0.06923685), (2, 0.3870091), (3, 0.37716007), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.7641625), (1, 0.06924292), (2, 0.053676903), (3, 0.043826446), (4, 0.037031103), (5, 0.032060143)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.21943429), (1, 0.02970313), (2, 0.023004087), (3, 0.55539006), (4, 0.01587095), (5, 0.15659747)]
# [(0, 0.7641693), (1, 0.06923682), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.43083596), (1, 0.40257016), (2, 0.053676203), (3, 0.043826435), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.07312698), (1, 0.8019276), (2, 0.040257152), (3, 0.032869827), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.3771595), (4, 0.0370311), (5, 0.36539373)]
# [(0, 0.097502664), (1, 0.06923683), (2, 0.053676203), (3, 0.3771567), (4, 0.037031095), (5, 0.36539647)]
# [(0, 0.36570495), (1, 0.04154209), (2, 0.032205723), (3, 0.51909244), (4, 0.02221866), (5, 0.019236084)]
# [(0, 0.823097), (1, 0.051927615), (2, 0.040257152), (3, 0.03289981), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.097502664), (1, 0.73590344), (2, 0.053676203), (3, 0.04382643), (4, 0.037031095), (5, 0.03206014)]
# [(0, 0.57270604), (1, 0.052348286), (2, 0.040257156), (3, 0.28285787), (4, 0.027785541), (5, 0.024045106)]
# [(0, 0.04007585), (1, 0.15680721), (2, 0.04533485), (4, 0.35063046), (5, 0.40302572)]
# [(0, 0.38679013), (1, 0.12674063), (2, 0.46037754), (3, 0.010147576)]
# [(0, 0.32096124), (1, 0.32487503), (4, 0.231515), (5, 0.108684085)]
# [(0, 0.6289773), (1, 0.034770302), (2, 0.02683817), (3, 0.2748686), (4, 0.018515551), (5, 0.016030071)]
# [(0, 0.21950135), (1, 0.3854364), (2, 0.010777286), (3, 0.18217394), (4, 0.0740726), (5, 0.12803847)]
# [(0, 0.69526356), (1, 0.03507138), (2, 0.026838163), (3, 0.20827137), (4, 0.018525468), (5, 0.016030071)]
# [(0, 0.43081728), (1, 0.06923691), (2, 0.053676248), (3, 0.043826442), (4, 0.037031103), (5, 0.36541203)]
# [(0, 0.09750264), (1, 0.06923682), (2, 0.053676203), (3, 0.7104931), (4, 0.0370311), (5, 0.032060143)]
# [(0, 0.097502634), (1, 0.069236815), (2, 0.38700944), (3, 0.04382643), (4, 0.37036452), (5, 0.03206014)]
# [(0, 0.07313051), (1, 0.051927976), (2, 0.040257238), (3, 0.7828658), (4, 0.027773326), (5, 0.024045106)]
# [(0, 0.4858784), (1, 0.02308429), (2, 0.1332213), (3, 0.14602666), (4, 0.20110267), (5, 0.010686714)]
# [(0, 0.4044768), (1, 0.016374625), (2, 0.012386822), (3, 0.3943391), (4, 0.08770483), (5, 0.08471778)]
# [(0, 0.42905158), (1, 0.021343712), (2, 0.016102862), (3, 0.41277313), (4, 0.011110296), (5, 0.109618425)]
# [(0, 0.20471133), (1, 0.029842127), (2, 0.023004094), (3, 0.3293418), (4, 0.39936057), (5, 0.013740062)]
# [(0, 0.038014386), (1, 0.77332443), (2, 0.020128597), (3, 0.14262335), (4, 0.013886663), (5, 0.012022553)]
# [(0, 0.32215977), (1, 0.05289483), (2, 0.040257152), (3, 0.5328698), (4, 0.027773324), (5, 0.024045106)]
# [(0, 0.57207257), (1, 0.052982025), (2, 0.040257152), (3, 0.28286982), (4, 0.027773324), (5, 0.024045106)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#         Document_No  ...                                               Text
# 0                 0  ...                                [iklan, ganggu, as]
# 1                 1  ...                       [tolong, erti, pesan, pesan]
# 2                 2  ...                       [iklan, trossssssss, ganggu]
# 3                 3  ...  [ruwet, metode, bayar, indomart, mlh, cod, apl...
# 4                 4  ...  [dih, dwon, aplikasi, tipu, order, giveaway, h...
# ...             ...  ...                                                ...
# 761725       761725  ...  [belanja, shoppe, bantu, temu, barang, dng, ce...
# 761726       761726  ...  [sampai, sekarang, pakai, alhamdulilah, gapern...
# 761727       761727  ...  [enk, belanja, shopeee, tigkatkn, gratis, ongk...
# 761728       761728  ...                            [belanja, kirim, cepat]
# 761729       761729  ...                           [layan, belanja, shoope]
#
# [761730 rows x 5 columns]
# Warning: total number of rows (761730) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    307778
# 1.0    130510
# 2.0     59557
# 3.0    141850
# 4.0     90489
# 5.0     31546
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500000)

plt.show()
