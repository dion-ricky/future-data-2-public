# %% [markdown]
# # Latent Dirichlet Allocation
#
# The purpose of applying the LDA method is to obtain the distribution of words that make up a topic and documents with a particular topic. The first stage in LDA modeling is to initialize the parameters. These parameters can be the number of documents, the number of words in the document, the number of topics, the number of iterations, and the LDA coefficient. The next stage is to mark a word with a predetermined topic by applying a semi-random distribution based on the Dirichlet distribution method. Next is the iteration stage. In this stage, there are parameters that can determine the distribution of the number of topics and the distribution of words from topics in a document.

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-bigquery
# !pip install PySastrawi
# !pip install nltk
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.7/dist-packages (1.21.0)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (3.17.3)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.26.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (21.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.15.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.35.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2018.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)

# %%
import pandas as pd
import numpy as np
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from string import punctuation
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
import pyLDAvis.gensim_models
import pickle
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## Load Data

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'future-data-track-1-sapporo.json'

# %%
# Imports the Google Cloud client library
from google.cloud import bigquery

# %%
# Instantiates a client for Bigquery Service
bigquery_client = bigquery.Client(project='future-data-track-1')

# %%
# Query for BigQuery
QUERY = """
SELECT
  *
FROM
  `future-data-track-1.sapporo_mart.topic_modelling`
"""

# %%
# Run the query and get data from BigQuery
query_job = bigquery_client.query(QUERY) # API request

# %%
# Turn the data into pandas DataFrame
df = query_job.to_dataframe()

# %%
# Show the result
df
# Out:
#                                                     review  rating
# 0                                     IKLAN NYA GANGGU AS*       1
# 1        Pihak lazada tolong di mengerti masa saya pesa...       1
# 2                            Iklan trossssssss, ganggu aja       1
# 3        Lazada Ruwet anjir. Mau menggunakan metode pem...       1
# 4        Dih jangan dwon ni aplikasi tempat para penipu...       1
# ...                                                    ...     ...
# 1695878                                    Sangat membantu       5
# 1695879                                    Sangat membantu       5
# 1695880                                    Sangat membantu       5
# 1695881                                    Sangat membantu       5
# 1695882                                    Sangat membantu       5
#
# [1695883 rows x 2 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Initial Stopwords

# %%
# Extending Sastrawi StopWords

class ExtendStopWordRemoverFactory(StopWordRemoverFactory):
  def get_stop_words(self):
    new_sw = [
              "ud","udah","sdh","sudah","kalau","klo","sy","aing","saia","gue"
    ,"awak","aq","gua","gw","ak","aku","saya","banget","blibli","tokopedia"
    ,"shopee","bukalapak","lazada","jdid","zalora","elevenia","sudah","bhinneka"
    ,"gk","yg","ga","gak","nggak","saja","aja","aj","ada","adalah","adanya"
    ,"adapun","agak","agaknya","agar","akan","akankah","akhir","akhiri"
    ,"akhirnya","aku","akulah","amat","amatlah","anda","andalah","antar"
    ,"antara","antaranya","apa","apaan","apabila","apakah","apalagi","apatah"
    ,"artinya","asal","asalkan","atas","atau","ataukah","ataupun","awal"
    ,"awalnya","bagai","bagaikan","bagaimana","bagaimanakah","bagaimanapun"
    ,"bagi","bagian","bahkan","bahwa","bahwasanya","baik","bakal","bakalan"
    ,"balik","banyak","bapak","baru","bawah","beberapa","begini","beginian"
    ,"beginikah","beginilah","begitu","begitukah","begitulah","begitupun"
    ,"bekerja","belakang","belakangan","belum","belumlah","benar","benarkah"
    ,"benarlah","berada","berakhir","berakhirlah","berakhirnya","berapa"
    ,"berapakah","berapalah","berapapun","berarti","berawal","berbagai"
    ,"berdatangan","beri","berikan","berikut","berikutnya","berjumlah"
    ,"berkali-kali","berkata","berkehendak","berkeinginan","berkenaan"
    ,"berlainan","berlalu","berlangsung","berlebihan","bermacam"
    ,"bermacam-macam","bermaksud","bermula","bersama","bersama-sama","bersiap"
    ,"bersiap-siap","bertanya","bertanya-tanya","berturut","berturut-turut"
    ,"bertutur","berujar","berupa","besar","betul","betulkah","biasa"
    ,"biasanya","bila","bilakah","bisa","bisakah","boleh","bolehkah","bolehlah"
    ,"buat","bukan","bukankah","bukanlah","bukannya","bulan","bung","cara"
    ,"caranya","cukup","cukupkah","cukuplah","cuma","dahulu","dalam","dan"
    ,"dapat","dari","daripada","datang","dekat","demi","demikian","demikianlah"
    ,"dengan","depan","di","dia","diakhiri","diakhirinya","dialah","diantara"
    ,"diantaranya","diberi","diberikan","diberikannya","dibuat","dibuatnya"
    ,"didapat","didatangkan","digunakan","diibaratkan","diibaratkannya"
    ,"diingat","diingatkan","diinginkan","dijawab","dijelaskan","dijelaskannya"
    ,"dikarenakan","dikatakan","dikatakannya","dikerjakan","diketahui"
    ,"diketahuinya","dikira","dilakukan","dilalui","dilihat","dimaksud"
    ,"dimaksudkan","dimaksudkannya","dimaksudnya","diminta","dimintai"
    ,"dimisalkan","dimulai","dimulailah","dimulainya","dimungkinkan","dini"
    ,"dipastikan","diperbuat","diperbuatnya","dipergunakan","diperkirakan"
    ,"diperlihatkan","diperlukan","diperlukannya","dipersoalkan","dipertanyakan"
    ,"dipunyai","diri","dirinya","disampaikan","disebut","disebutkan"
    ,"disebutkannya","disini","disinilah","ditambahkan","ditandaskan","ditanya"
    ,"ditanyai","ditanyakan","ditegaskan","ditujukan","ditunjuk","ditunjuki"
    ,"ditunjukkan","ditunjukkannya","ditunjuknya","dituturkan","dituturkannya"
    ,"diucapkan","diucapkannya","diungkapkan","dong","dua","dulu","empat"
    ,"enggak","enggaknya","entah","entahlah","guna","gunakan","hal","hampir"
    ,"hanya","hanyalah","hari","harus","haruslah","harusnya","hendak"
    ,"hendaklah","hendaknya","hingga","ia","ialah","ibarat","ibaratkan"
    ,"ibaratnya","ibu","ikut","ingat","ingat-ingat","ingin","inginkah"
    ,"inginkan","ini","inikah","inilah","itu","itukah","itulah","jadi"
    ,"jadilah","jadinya","jangan","jangankan","janganlah","jauh","jawab"
    ,"jawaban","jawabnya","jelas","jelaskan","jelaslah","jelasnya","jika"
    ,"jikalau","juga","jumlah","jumlahnya","justru","kala","kalau","kalaulah"
    ,"kalaupun","kalian","kami","kamilah","kamu","kamulah","kan","kapan"
    ,"kapankah","kapanpun","karena","karenanya","kasus","kata","katakan"
    ,"katakanlah","katanya","ke","keadaan","kebetulan","kecil","kedua"
    ,"keduanya","keinginan","kelamaan","kelihatan","kelihatannya","kelima"
    ,"keluar","kembali","kemudian","kemungkinan","kemungkinannya","kenapa"
    ,"kepada","kepadanya","kesampaian","keseluruhan","keseluruhannya"
    ,"keterlaluan","ketika","khususnya","kini","kinilah","kira","kira-kira"
    ,"kiranya","kita","kitalah","kok","kurang","lagi","lagian","lah","lain"
    ,"lainnya","lalu","lama","lamanya","lanjut","lanjutnya","lebih","lewat"
    ,"lima","luar","macam","maka","makanya","makin","malah","malahan","mampu"
    ,"mampukah","mana","manakala","manalagi","masa","masalah","masalahnya"
    ,"masih","masihkah","masing","masing-masing","mau","maupun","melainkan"
    ,"melakukan","melalui","melihat","melihatnya","memang","memastikan"
    ,"memberi","memberikan","membuat","memerlukan","memihak","meminta"
    ,"memintakan","memisalkan","memperbuat","mempergunakan","memperkirakan"
    ,"memperlihatkan","mempersiapkan","mempersoalkan","mempertanyakan"
    ,"mempunyai","memulai","memungkinkan","menaiki","menambahkan","menandaskan"
    ,"menanti","menanti-nanti","menantikan","menanya","menanyai","menanyakan"
    ,"mendapat","mendapatkan","mendatang","mendatangi","mendatangkan"
    ,"menegaskan","mengakhiri","mengapa","mengatakan","mengatakannya","mengenai"
    ,"mengerjakan","mengetahui","menggunakan","menghendaki","mengibaratkan"
    ,"mengibaratkannya","mengingat","mengingatkan","menginginkan","mengira"
    ,"mengucapkan","mengucapkannya","mengungkapkan","menjadi","menjawab"
    ,"menjelaskan","menuju","menunjuk","menunjuki","menunjukkan","menunjuknya"
    ,"menurut","menuturkan","menyampaikan","menyangkut","menyatakan"
    ,"menyebutkan","menyeluruh","menyiapkan","merasa","mereka","merekalah"
    ,"merupakan","meski","meskipun","meyakini","meyakinkan","minta","mirip"
    ,"misal","misalkan","misalnya","mula","mulai","mulailah","mulanya","mungkin"
    ,"mungkinkah","nah","naik","namun","nanti","nantinya","nyaris","nyatanya"
    ,"oleh","olehnya","pada","padahal","padanya","pak","paling","panjang"
    ,"pantas","para","pasti","pastilah","penting","pentingnya","per","percuma"
    ,"perlu","perlukah","perlunya","pernah","persoalan","pertama","pertama-tama"
    ,"pertanyaan","pertanyakan","pihak","pihaknya","pukul","pula","pun","punya"
    ,"rasa","rasanya","rata","rupanya","saat","saatnya","saja","sajalah"
    ,"saling","sama","sama-sama","sambil","sampai","sampai-sampai","sampaikan"
    ,"sana","sangat","sangatlah","satu","saya","sayalah","se","sebab","sebabnya"
    ,"sebagai","sebagaimana","sebagainya","sebagian","sebaik","sebaik-baiknya"
    ,"sebaiknya","sebaliknya","sebanyak","sebegini","sebegitu","sebelum"
    ,"sebelumnya","sebenarnya","seberapa","sebesar","sebetulnya","sebisanya"
    ,"sebuah","sebut","sebutlah","sebutnya","secara","secukupnya","sedang"
    ,"sedangkan","sedemikian","sedikit","sedikitnya","seenaknya","segala"
    ,"segalanya","segera","seharusnya","sehingga","seingat","sejak","sejauh"
    ,"sejenak","sejumlah","sekadar","sekadarnya","sekali","sekali-kali"
    ,"sekalian","sekaligus","sekalipun","sekarang","sekarang","sekecil"
    ,"seketika","sekiranya","sekitar","sekitarnya","sekurang-kurangnya"
    ,"sekurangnya","sela","selain","selaku","selalu","selama","selama-lamanya"
    ,"selamanya","selanjutnya","seluruh","seluruhnya","semacam","semakin"
    ,"semampu","semampunya","semasa","semasih","semata","semata-mata","semaunya"
    ,"sementara","semisal","semisalnya","sempat","semua","semuanya","semula"
    ,"sendiri","sendirian","sendirinya","seolah","seolah-olah","seorang"
    ,"sepanjang","sepantasnya","sepantasnyalah","seperlunya","seperti"
    ,"sepertinya","sepihak","sering","seringnya","serta","serupa","sesaat"
    ,"sesama","sesampai","sesegera","sesekali","seseorang","sesuatu"
    ,"sesuatunya","sesudah","sesudahnya","setelah","setempat","setengah"
    ,"seterusnya","setiap","setiba","setibanya","setidak-tidaknya","setidaknya"
    ,"setinggi","seusai","sewaktu","siap","siapa","siapakah","siapapun","sini"
    ,"sinilah","soal","soalnya","suatu","sudah","sudahkah","sudahlah","supaya"
    ,"tadi","tadinya","tahu","tahun","tak","tambah","tambahnya","tampak"
    ,"tampaknya","tandas","tandasnya","tanpa","tanya","tanyakan","tanyanya"
    ,"tapi","tegas","tegasnya","telah","tempat","tengah","tentang","tentu"
    ,"tentulah","tentunya","tepat","terakhir","terasa","terbanyak","terdahulu"
    ,"terdapat","terdiri","terhadap","terhadapnya","teringat","teringat-ingat"
    ,"terjadi","terjadilah","terjadinya","terkira","terlalu","terlebih"
    ,"terlihat","termasuk","ternyata","tersampaikan","tersebut","tersebutlah"
    ,"tertentu","tertuju","terus","terutama","tetap","tetapi","tiap","tiba"
    ,"tiba-tiba","tidak","tidakkah","tidaklah","tiga","tinggi","toh","tunjuk"
    ,"turut","tutur","tuturnya","ucap","ucapnya","ujar","ujarnya","umum"
    ,"umumnya","ungkap","ungkapnya","untuk","usah","usai","waduh","wah","wahai"
    ,"waktu","waktunya","walau","walaupun","wong","yaitu","yakin","yakni","yang"
    ,"anjing","anjiang","anjir","anjay","anying","asu","asoe","babi","bajingan"
    ,"banci","bangsat","bego","bengak","berak","bokong","bodoh","bongak","edan"
    ,"fak","fuck","fakboi","bitch","fap","gigolo","goblok","gila","gilo"
    ,"jablay","jalang","jancuk","jancok","kampret","kafir","kontol","kentot"
    ,"dancok","kunyuk","kufar","kimak","homo","maho","memek","monyet","ngentot"
    ,"pantat","pantak","pantek","pecun","pelakor","ngehe","pelacur","perek"
    ,"peler","pepek","pukimak","setan","syaithon","saiton","sial","sialan"
    ,"sinting","sintiang","silit","sontoloyo","tai","telek","tolol","lonte"
    ,"entut","gimana","widihh","nya","gabisa","nambah","kontoll"
    ,"ih",
    "sih","selesai","banget","si","knapa","bngt","kamu","an","tanggal"
    ,"dizalora","in","an","ini","emang","sngt","many","to","thank","you","ko"
    ,"tumben","lho","segitu","kalau","doang","ayo","doank","rbuan","woi"
    ,"parahhhh","trus","woy","emg","gausah","udh","gadak","huhh","akh","nanti"
    ,"belum","cuiiihhh","bangt","selamat","begitu","bhineka","situ","loh","deh"
    ,"mah","yaa","tapi","the","karena","padabal","ttep","sopi","ealah","mas"
    ,"kampreeeeet","busetttt","tahi","ah","sich","tokped","lzd","gada","gatau"
    ,"udh","ttep","ehhh","bosss","wkekwk","bajing","laknat","asuuu","ku","woiii"
    ,"gueeee","njerr","waduhhhh","ma","dunk","dunk","untuk","dll","brupa"
    ,"sangatx","niih","bos","eh","smua","gni","bye","ajah","gilee","luu","ndro"
    ,"dg","kga","min","sm","haisshhh","piye","iki","skali","hehehe","ms","juga"
    ,"fff","mamam","inibsangat","andri","yopiyanto","broo","donk","tes","si"
    ,"ter","dech","wow","oh","toped","dahhhh","grab","ijo","oren","ovo","gopay"
    ,"kredivo","sok","david","gaes","dr","ovonya","bbrp","gmna","bbrpa","and"
    ,"uah","uhahhhhhh","topeeed","ngak","kamu","anj","nge","lah","linkaja"
    ,"gosend","sicepat","jne","yah","goto","gofood","goride","prakerja"
    ,"haduhhhh","pediya","kakak","hhe","bro","bismillah","fuulll","goof"
    ,"assalamualaikum","atsu","pea","you","agan","semenjak","gojek","lagiii"
    ,"lagi","bts","kkzara","cog","aaaaa","sich","cih","ciyy","padahal","ad"
    ,"adlh","ahaha","aj","ak","akika","akkoh","akuwh","alow","anjrit","ap2"
    ,"apasih","aps","aq","aqueh","q","asem","ato","awak","bakalan","bangedh"
    ,"bcanda","beud","bg","bgmn","bgt","bkl","bknnya","blum","boljug","boyeh"
    ,"bs","bt","btw","bwt","byk","can","thanks","d","dah","dapet","de","dek"
    ,"deyh","dgn","disono","dkk","dlu","dngn","dongs","dpt","dri","drmn","drtd"
    ,"dst","duh","egp","eke","ane","ente","elu","emangnya","emng","endak"
    ,"enggak","gaada","gag","gaje","gpp","gan","gbs","geje","ghiy","gimana"
    ,"githu","gj","gn","gt","gpny","gr","gtau","guoblok","ha","haha","hallow"
    ,"hehe","helo","he","halo","hey","hai","hny","hrus","imho","iye","ja"
    ,"jadiin","jdi","jga","jir","k","kagak","kalo","kamuwh","karna","katrok"
    ,"kayanya","kdu","kepengen","kepingin","kl","klianz","klw","km","knp","kpn"
    ,"kt","kyk","leh","lgi","lgsg","liat","low","lum","maneh","mao","mw","n"
    ,"napa","nda","ne","ngapah","ngga","ngmng","nie","nih","niyh","np","ogah"
    ,"pd","pi","pisan","qmu","ruz","saia","samsek","siech","sj","spt","sgt"
    ,"shg","scr","sbh","sbnrny","sdgkn","td","thankz","tks","ttg","tuch","tuh"
    ,"u","urang","yawdah","yasudah","adlah","ajj","akko","akyu","ama","aqu"
    ,"atuh","ayok","bet","beut","bgd","brur","bapak","ibu","bokap","nyokap"
    ,"cama","ceu","teh","coz","cpa","guys","kaka","kamuh","kamyu","kau","khan"
    ,"kk","klian","koq","ky","krn","kykny","lu","lw","maaciw","makasih","mba"
    ,"mas","nyok","qmo","qt","spy","sy","thanks","thx","tp","tq","trims","mz"
    ,"alfamart","cm"
    ,"buruk","lambat","jelek","bagus","ok","oke","kecewa","mantap","manfaat"
    ,"gblk","ni","keren","bagus","ajg","iya","tidak","muas","puas","goblog"
    ,"tdk","dancuk","huff","lumayan","mayan","y","eek","belum","blm","nyesel"
    ,"bahagia","senang","seneng","mantul","good","top","suka","not","bad"
    ,"kak","okey","gitu","coba","sip","nice","job","thanks","terima kasih"
    ,"moga","lasada","jd","id","parah","for","sumpah","best","bli","payah"
    ,"blibi","blipay","gg","love","amazing","mantab","terimakasih","cakep"
    ,"very","bgs","jos","is","euy","gandos","of","waw","biar","buka","lapak"
    ,"terima","kasih","alhamdulillah","pokok"
    ]
    new_sw.extend(super().get_stop_words())
    return list(set(new_sw))

# %% [markdown]
# ### Initial Stemming
#
# using sastrawi

# %%
# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ### Initial Formalization

# %%
formalization_indo = {
    "@": "di", "abis": "habis", "ad": "ada", "adlh": "adalah", "ahaha": "haha", "aj": "saja", "ajep-ajep": "disko", "ak": "saya", "akika": "aku", "akkoh": "aku", "akuwh": "aku", "alay": "norak", "alow": "halo", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar", "ap2": "apa", "apasih": "apa", "apes": "sial", "aps": "apa", "aq": "saya", "aquwh": "aku", "aseekk": "asyik", "asekk": "asyik", "asem": "asam", "aspal": "palsu", "ato": "atau", "awak": "saya", "ay": "sayang", "ayank": "sayang", "b4": "sebelum", "bakalan": "akan", "bangedh": "banget", "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "beli", "bencong": "banci", "bentar": "sebentar", "ber3": "bertiga", "beresin": "membereskan", "bete": "bosan", "beud": "banget", "bg": "abang", "bgmn": "bagaimana", "bgt": "banget", "bijimane": "bagaimana", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "benar", "bodor": "lucu", "bokap": "ayah", "bokis": "bohong", "boljug": "boleh", "boyeh": "boleh", "br": "baru", "brg": "bareng", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong", "bubbu": "tidur", "bubu": "tidur", "bw": "bawa", "bwt": "buat", "byk": "banyak", "byrin": "bayarkan", "cabal": "sabar", "cadas": "keren", "calo": "makelar", "can": "belum", "capcus": "pergi", "ce": "cewek", "cekal": "cegah", "cemen": "penakut", "cengengesan": "tertawa", "cepet": "cepat", "cew": "cewek", "chuyunk": "sayang", "cimeng": "ganja", "ciyh": "sih", "ckepp": "cakep", "ckp": "cakep", "cmpur": "campur", "cong": "banci", "cowwyy": "maaf", "cpe": "capek", "cppe": "capek", "cucok": "cocok", "cuex": "cuek", "cups": "culun", "curanmor": "pencurian", "cwek": "cewek", "cyin": "cinta", "d": "di", "dah": "deh", "dapet": "dapat", "de": "adik", "dek": "adik", "demen": "suka", "deyh": "deh", "dgn": "dengan", "diancurin": "hancur", "dimaafin": "maaf", "dimintak": "minta", "disono": "sana", "dket": "dekat", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "doku": "uang", "dtg": "datang", "duren": "durian", "ed": "edisi", "eke": "aku", "elu": "kamu", "emangnya": "memangnya", "emng": "memang", "endak": "tidak", "enggak": "tidak", "envy": "iri", "ex": "mantan", "fax": "facsimile", "fyi": "informasi", "gag": "tidak", "gan": "juragan", "gawe": "kerja", "ghiy": "lagi", "gile": "gila", "gimana": "bagaimana", "githu": "gitu", "gmana": "bagaimana", "gn": "begini", "goblok": "bodoh", "gretongan": "gratis", "gua": "saya", "guoblok": "goblok", "gw": "saya", "ha": "tertawa", "haha": "tertawa", "hallow": "halo", "hehe": "he", "helo": "halo", "hey": "hai", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "hum": "rumah", "humz": "rumah", "ilang": "hilang", "ilfil": "benci", "imoetz": "imut", "item": "hitam", "itungan": "hitungan", "iye": "iya", "ja": "saja", "jadiin": "jadi", "jdi": "jadi", "jem": "jam", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kabor": "kabur", "kacrut": "kacau", "kagak": "tidak", "kalo": "kalau", "kampret": "sialan", "kamuwh": "kamu", "karna": "karena", "katrok": "kampungan", "kayanya": "seperti", "kbr": "kabar", "kdu": "harus", "kec": "kecamatan", "kekeuh": "bersikeras", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "terima", "kgiatan": "kegiatan", "kibul": "bohong", "kimpoi": "kawin", "kl": "kalau", "klianz": "kalian", "klw": "kalau", "km": "kamu", "kmps": "kampus", "kmrn": "kemarin", "knal": "kenal", "knp": "kenapa", "korup": "korupsi", "kpn": "kapan", "krenz": "keren", "krm": "kirim", "kt": "kita", "ktmu": "ketemu", "ktr": "kantor", "kw": "imitasi", "kyk": "seperti", "la": "lah", "lam": "salam", "lamp": "lampiran", "lebay": "berlebihan", "leh": "boleh", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lmyn": "lumayan", "lo": "kamu", "loe": "kamu", "lola": "lemot", "louph": "cinta", "low": "kalau", "lp": "lupa", "luchuw": "lucu", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "mabal": "bolos", "macem": "macam", "macih": "masih", "maem": "makan", "maho": "homo", "maksain": "maksa", "malem": "malam", "mam": "makan", "maneh": "kamu", "maniez": "manis", "mao": "mau", "masukin": "masukkan", "melu": "ikut", "mepet": "dekat", "mgu": "minggu", "miras": "minuman keras", "mlah": "malah", "mngkn": "mungkin", "mo": "mau", "mokad": "mati", "moso": "masa", "mpe": "sampai", "msk": "masuk", "mslh": "masalah", "mulu": "melulu", "mumpung": "selagi", "musti": "mesti", "muupz": "maaf", "nanam": "menanam", "nanya": "bertanya", "napa": "kenapa", "napi": "narapidana", "nda": "tidak", "ndiri": "sendiri", "ne": "ini", "nekolin": "neokolonialisme", "ngaku": "mengaku", "ngambil": "mengambil", "ngapah": "kenapa", "ngaret": "terlambat", "ngasih": "beri", "ngebandel": "bandel", "ngegosip": "gosip", "ngeklaim": "klaim", "ngeles": "berkilah", "ngelidur": "menggigau", "ngerampok": "rampok", "ngga": "tidak", "ngibul": "bohong", "ngiler": "mau", "ngiri": "iri", "ngisiin": "mengisikan", "ngmng": "bicara", "ngomong": "bicara", "ngubek2": "cari", "ngurus": "urus", "nie": "ini", "nih": "ini", "niyh": "nih", "nmr": "nomor", "nntn": "nonton", "ntar": "nanti", "ntn": "nonton", "numpuk": "tumpuk", "nutupin": "tutup", "nyari": "cari", "nyekar": "menyekar", "nyicil": "cicil", "nyoblos": "coblos", "nyokap": "ibu", "ol": "online", "pacal": "pacar", "pake": "pakai", "pala": "kepala", "pd": "pada", "perhatiin": "perhatikan", "pesenan": "pesanan", "pgang": "pegang", "pi": "tapi", "pisan": "sangat", "pk": "pakai", "plg": "paling", "pmrnth": "pemerintah", "prg": "pergi", "prnh": "pernah", "psen": "pesan", "pst": "pasti", "pswt": "pesawat", "pw": "posisi nyaman", "qmu": "kamu", "re": "balas", "ref": "referensi", "rehab": "rehabilitasi", "rempong": "sulit", "repp": "balas", "rhs": "rahasia", "rmh": "rumah", "ru": "baru", "ruz": "terus", "saia": "saya", "sampe": "sampai", "sapose": "siapa", "sbh": "sebuah", "sbnrny": "sebenarnya", "scr": "secara", "sdgkn": "sedangkan", "sdkt": "sedikit", "se7": "setuju", "sempet": "sempat", "sgt": "sangat", "shg": "sehingga", "siech": "sih", "siramin": "siram", "sj": "saja", "skalian": "sekalian", "sklh": "sekolah", "skt": "sakit", "slesai": "selesai", "sll": "selalu", "slma": "selama", "slsai": "selesai", "smpt": "sempat", "smw": "semua", "sndiri": "sendiri",  "songong": "sombong", "sory": "maaf", "sotoy": "tahu", "spa": "siapa", "sppa": "siapa", "spt": "seperti", "srtfkt": "sertifikat", "stiap": "setiap", "stlh": "setelah", "suk": "masuk", "sumpek": "sempit", "syg": "sayang", "t4": "tempat", "tajir": "kaya", "tau": "tahu", "taw": "tahu", "td": "tadi", "tdk": "tidak", "telat": "terlambat", "temen": "teman", "tengil": "menyebalkan", "tepar": "terkapar", "tggu": "tunggu", "tgu": "tunggu", "thn": "tahun", "tilang": "bukti pelanggaran", "tlp": "telepon", "tls": "tulis", "tmbah": "tambah", "tmpah": "tumpah", "tmpt": "tempat", "tngu": "tunggu", "tnyta": "ternyata", "tokai": "tai", "tpi": "tapi", "trdhulu": "terdahulu", "trima": "terima", "trm": "terima", "trs": "terus", "trutama": "terutama", "ts": "penulis", "ttg": "tentang", "tuch": "tuh", "tuir": "tua", "tw": "tahu", "u": "kamu", "ud": "sudah", "udah": "sudah", "ujg": "ujung", "ul": "ulangan", "unyu": "lucu", "uplot": "unggah", "urang": "saya", "usah": "perlu", "utk": "untuk", "w/": "dengan", "wat": "buat", "wkt": "waktu", "xixixi": "tertawa", "ya": "iya", "yap": "iya", "yg": "yang", "yo": "iya", "yup": "iya", "7an": "tujuan", "adlah": "adalah", "adoh": "aduh", "aha": "tertawa", "aing": "saya", "aja": "saja", "ajj": "saja", "akko": "aku", "akku": "aku", "akyu": "aku", "ama": "sama", "ambl": "ambil", "anjir": "anjing", "ank": "anak", "ap": "apa", "apaan": "apa", "ape": "apa", "aplot": "unggah", "apva": "apa", "aqu": "aku", "asap": "segera", "aseek": "asyik", "asek": "asyik", "aseknya": "asyiknya", "asoy": "asyik", "astrojim": "astagfirullahaladzim", "ava": "avatar", "aws": "awas", "ayang": "sayang", "ayok": "ayo", "bales": "balas", "bangkotan": "tua", "bcoz": "karena", "beb": "sayang", "bejibun": "banyak", "belom": "belum", "bener": "benar", "ber2": "berdua", "bet": "banget", "beut": "banget", "bgd": "banget", "bgs": "bagus", "bhubu": "tidur", "bkn": "bukan", "bl": "beli", "blg": "bilang", "blm": "belum", "bls": "balas", "bnchi": "benci", "bngung": "bingung", "bnyk": "banyak", "bokep": "porno", "bokin": "pacar", "bole": "boleh", "bolot": "bodoh", "bpk": "bapak", "brngkt": "berangkat", "brp": "berapa", "bsa": "bisa", "bsk": "besok", "bu_bu": "tidur", "bubarin": "bubarkan", "bwhn": "bawahan", "byar": "bayar", "byr": "bayar", "c8": "chat", "cabut": "pergi", "caem": "cakep", "cape": "capek", "caur": "jelek", "cemplungin": "masuk", "ceper": "pendek", "cewe": "cewek", "cibuk": "sibuk", "cin": "cinta", "ciye": "cie", "ckck": "ck", "cmpr": "campur", "cnenk": "senang", "congor": "mulut", "cow": "cowok", "coz": "karena", "cpa": "siapa", "gokil": "gila", "gretong": "gratis", "gt": "begitu", "gue": "saya", "haghaghag": "tertawa", "hakhak": "tertawa", "hellow": "halo", "helow": "halo", "hi": "hai", "hlng": "hilang", "hnya": "hanya", "houm": "rumah", "hrs": "harus", "huft": "mengeluh", "humas": "hubungan masyarakat", "imoet": "imut", "info": "informasi", "itung": "hitung", "isengin": "bercanda", "iyala": "iya lah", "iyo": "iya", "jancuk": "anjing", "jd": "jadi", "jdikan": "jadikan", "jg": "juga", "jgn": "jangan", "jijay": "jijik", "jkt": "jakarta", "jnj": "janji", "jth": "jatuh", "jwb": "jawab", "ka": "kakak", "kacian": "kasihan", "kaga": "tidak", "kaka": "kakak", "kamuh": "kamu", "kamyu": "kamu", "kapt": "kapten", "kau": "kamu", "kbar": "kabar", "kcian": "kasihan", "keburu": "terlanjur", "kek": "seperti", "keknya": "seperti", "keliatan": "kelihatan", "keneh": "masih", "kepikiran": "terpikirkan", "kepo": "penasaran", "kesian": "kasihan", "ketauan": "ketahuan", "keukeuh": "bersikeras", "khan": "kan", "kk": "kakak", "klian": "kalian", "klo": "kalau", "kluarga": "keluarga", "klwrga": "keluarga", "kmari": "kemari", "kmpus": "kampus", "kn": "kan", "knl": "kenal", "knpa": "kenapa", "kog": "kok", "kompi": "komputer", "koq": "kok", "kpd": "kepada", "kptsan": "keputusan", "krik": "garing", "krn": "karena", "ktauan": "ketahuan", "ktny": "katanya", "kudu": "harus", "kuq": "kok", "ky": "seperti", "kykny": "kayanya", "laka": "kecelakaan", "lambreta": "lambat", "lbur": "libur", "lg": "lagi", "lgkp": "lengkap", "lht": "lihat", "linmas": "perlindungan masyarakat", "lmyan": "lumayan", "lngkp": "lengkap", "loch": "loh", "lol": "tertawa", "lom": "belum", "loupz": "cinta", "lowh": "kamu", "lu": "kamu", "luchu": "lucu", "luff": "cinta", "luph": "cinta", "lw": "kamu", "lwt": "lewat", "maen": "main", "mak": "ibu", "malah": "bahkan", "malu2in": "memalukan", "mamz": "makan", "manies": "manis", "mantep": "mantap", "mba": "mbak", "mending": "lebih baik", "mgkn": "mungkin", "mhn": "mohon", "mksd": "maksud", "mls": "malas", "mnt": "minta",  "mokat": "mati", "mosok": "masa", "msh": "masih", "mskpn": "meskipun", "muahal": "mahal", "mumet": "pusing", "muna": "munafik", "muup": "maaf", "muuv": "maaf", "nal": "kenal", "nangis": "menangis", "naon": "apa", "naq": "anak", "nax": "anak", "ndak": "tidak", "ndut": "gendut", "nekolim": "neokolonialisme", "nelfon": "menelepon", "ngabis2in": "menghabiskan", "ngakak": "tertawa", "ngambek": "marah", "ngantri": "antri", "ngaruh": "pengaruh", "ngawur": "sembarangan", "ngeceng": "kumpul", "ngeh": "sadar", "ngekos": "kos", "ngelamar": "lamar", "ngeliat": "lihat", "ngemeng": "bicara", "ngerti": "mengerti", "nggak": "tidak", "ngikut": "ikut", "nginep": "menginap", "ngisi": "mengisi", "ngmg": "bicara", "ngocol": "lucu", "ngomongin": "bicara", "ngumpul": "kumpul", "ni": "ini", "nyasar": "tersesat", "nyariin": "cari", "nyiapin": "siap", "nyiram": "siram", "nyok": "ayo", "o/": "oleh", "ok": "ok", "priksa": "periksa", "pro": "profesional", "psn": "pesan", "psti": "pasti", "puanas": "panas", "qmo": "kamu", "qt": "kita", "rame": "ramai", "raskin": "rakyat miskin", "red": "redaksi", "reg": "register", "rejeki": "rezeki", "sni": "sini", "sorry": "maaf", "sowry": "maaf", "spd": "sepeda", "sprti": "seperti", "spy": "supaya", "stelah": "setelah", "subbag": "subbagian", "sumbangin": "sumbangkan", "sy": "saya", "syp": "siapa", "tar": "nanti", "taun": "tahun", "tawh": "tahu", "tdi": "tadi", "te2p": "tetap", "tekor": "rugi", "telkom": "telekomunikasi", "telp": "telepon", "tengok": "jenguk", "terbitin": "terbit", "tgl": "tanggal", "thd": "terhadap", "tipi": "TV", "tkg": "tukang", "tll": "terlalu", "tlpn": "telepon", "tman": "teman", "tmbh": "tambah", "tmph": "tumpah", "tnda": "tanda", "tnh": "tanah", "tp": "tapi", "trgntg": "tergantung", "cb": "coba", "y": "ya", "munfik": "munafik", "reklamuk": "reklamasi", "sma": "sama", "tren": "trend", "ngehe": "kesal", "mz": "mas", "analisise": "analisis", "sadaar": "sadar", "sept": "september", "nmenarik": "menarik", "zonk": "bodoh", "rights": "benar", "simiskin": "miskin", "ngumpet": "sembunyi", "hardcore": "keras", "akhirx": "akhirnya", "solve": "solusi", "watuk": "batuk", "ngebully": "intimidasi", "masy": "masyarakat", "still": "masih", "tauk": "tahu", "mbual": "bual", "tioghoa": "tionghoa", "ngentotin": "senggama", "kentot": "senggama", "faktakta": "fakta", "sohib": "teman", "rubahnn": "rubah", "trlalu": "terlalu", "nyela": "cela", "heters": "pembenci", "nyembah": "sembah", "most": "paling", "ikon": "lambang", "light": "terang", "pndukung": "pendukung", "setting": "atur", "seting": "akting", "next": "lanjut", "waspadalah": "waspada", "gantengsaya": "ganteng", "parte": "partai", "nyerang": "serang", "nipu": "tipu", "ktipu": "tipu", "jentelmen": "berani", "buangbuang": "buang", "tsangka": "tersangka", "kurng": "kurang", "ista": "nista", "less": "kurang", "koar": "teriak", "paranoid": "takut", "problem": "masalah", "tahi": "kotoran", "tirani": "tiran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "penertiban": "tertib", "uasai": "kuasa", "mnolak": "tolak", "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "ahokncc": "ahok", "istaa": "nista", "benarjujur": "jujur", "mgkin": "mungkin", "apk": "aplikasi", "dg" : "dengan", "blanja": "belanja", "sukaa": "suka", "cpt": "cepat", "bwrtransaksi": "transaksi", "realpict": "asli", "moga": "semoga", "muas": "puas", "ori": "asli", "ongkirnya": "ongkir", "turunin": "turun", "orii": "asli", "original": "asli", "hargax": "harga", "mehong": "mahal", "kainx": "kain", "rb": "ribu", "shopping": "belanja", "made": "buat", "easier": "mudah", "ways": "cara", "pay": "bayar", "applikasi": "aplikasi", "kwalitas": "kualitas", "good": "bagus", "ngechat": "chat", "ngobrol": "bicara", "ngertiin": "mengerti", "protol": "lepas", "balikin": "balik", "trx": "transaksi", "nyebelin": "sebal", "trf": "transfer", "ngebantuin": "bantu", "org": "orang", "peribet": "ribet", "fedback": "feedback", "koment": "komentar", "takuuut": "takut", "ketipuuuuh": "tipu", "register": "daftar", "hp": "handphone", "org": "orang", "instal": "install", "skarng": "sekarang", "true": "benar", "story": "cerita", "payment": "bayar", "confirm": "konfirmasi", "batalin": "batal", "ig": "instagram", "pelyanan": "layanan", "after": "setelah", "nunggu": "tunggu", "blom": "belum", "reffund": "refund", "jeleeeekkk": "jelek", "make": "pakai", "nyoba": "coba", "pantesan": "pantas", "slow": "lambat", "skrg": "sekarang", "dibalikin": "balik", "transver": "transfer", "pantes": "pantas", "staffnya": "staff", "divalidasi": "validasi", "smpe": "sampai", "pelayananya": "layanan", "komennya": "komentar", "komplin": "komplain", "complaint": "komplain", "hpus": "hapus", "muaaahal": "mahal", "masukkk": "masuk", "tlg": "tolong", "wa": "whatsapp", "luama": "lama", "stokmya": "stok", "ready": "siap", "setrlah": "setelah", "sprt": "seperti", "cs": "customer service", "direspon": "respon","prcuma": "percuma", "bkin": "bikin", "app": "aplikasi", "hape": "handphone", "karti": "kartu",  "apps": "aplikasi", "responnya": "respon", "mahalllll": "mahal", "balesan": "balas", "paswordnya": "password", "masul": "masuk", "ksong": "kosong", "nyarinya": "cari", "kluarnya": "keluar", "system": "sistem", "systemnya": "sistem", "chatt": "chat", "kridit": "kredit", "pelayananya": "layanan", "kwalitasnya": "kualitas","mantap": "bagus", "produck": "produk", "baharu": "baru", "slalu": "selalu", "dwnld": "unduh", "download": "unduh", "sndri":  "sendiri", "batalin": "batal", "mbingungin": "bingung", "vocer": "voucher", "boong”": "bohong", "apus": "hapus", "sori": "maaf", "tf": "transfer", "apknya": "aplikasi", "diem": "diam", "dtang": "datang", "bukak": "buka", "boong": "bohong", "setiyap": "setiap", "sukak": "suka", "ngincer": "incar", "store": "toko", "fiturnya": "fitur", "apkx": "aplikasi", "voucherx": "voucher", "hub": "hubungi", "payaaaaaaaahh": "payah", "apl": "aplikasi", "mamam": "makan", "luama": "lama"
}

# %%
formalization_indo
# Out:
# {'7an': 'tujuan',
#  '@': 'di',
#  'abis': 'habis',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'after': 'setelah',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'disko',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
#  'ap2': 'apa',
#  'apaan': 'apa',
#  'apasih': 'apa',
#  'ape': 'apa',
#  'apes': 'sial',
#  'apk': 'aplikasi',
#  'apknya': 'aplikasi',
#  'apkx': 'aplikasi',
#  'apl': 'aplikasi',
#  'aplot': 'unggah',
#  'app': 'aplikasi',
#  'applikasi': 'aplikasi',
#  'apps': 'aplikasi',
#  'aps': 'apa',
#  'apus': 'hapus',
#  'apva': 'apa',
#  'aq': 'saya',
#  'aqu': 'aku',
#  'aquwh': 'aku',
#  'asap': 'segera',
#  'aseek': 'asyik',
#  'aseekk': 'asyik',
#  'asek': 'asyik',
#  'asekk': 'asyik',
#  'aseknya': 'asyiknya',
#  'asem': 'asam',
#  'asoy': 'asyik',
#  'aspal': 'palsu',
#  'astrojim': 'astagfirullahaladzim',
#  'ato': 'atau',
#  'ava': 'avatar',
#  'awak': 'saya',
#  'aws': 'awas',
#  'ay': 'sayang',
#  'ayang': 'sayang',
#  'ayank': 'sayang',
#  'ayok': 'ayo',
#  'b4': 'sebelum',
#  'baharu': 'baru',
#  'bakalan': 'akan',
#  'bales': 'balas',
#  'balesan': 'balas',
#  'balikin': 'balik',
#  'bangedh': 'banget',
#  'bangkotan': 'tua',
#  'basbang': 'basi',
#  'batalin': 'batal',
#  'bcanda': 'bercanda',
#  'bcoz': 'karena',
#  'bdg': 'bandung',
#  'beb': 'sayang',
#  'begajulan': 'nakal',
#  'bejibun': 'banyak',
#  'beliin': 'beli',
#  'belom': 'belum',
#  'benarjujur': 'jujur',
#  'bencong': 'banci',
#  'bener': 'benar',
#  'bentar': 'sebentar',
#  'ber2': 'berdua',
#  'ber3': 'bertiga',
#  'beresin': 'membereskan',
#  'bet': 'banget',
#  'bete': 'bosan',
#  'beud': 'banget',
#  'beut': 'banget',
#  'bg': 'abang',
#  'bgd': 'banget',
#  'bgmn': 'bagaimana',
#  'bgs': 'bagus',
#  'bgt': 'banget',
#  'bhubu': 'tidur',
#  'bijimane': 'bagaimana',
#  'bkin': 'bikin',
#  'bkl': 'akan',
#  'bkn': 'bukan',
#  'bknnya': 'bukannya',
#  'bl': 'beli',
#  'blanja': 'belanja',
#  'blegug': 'bodoh',
#  'blg': 'bilang',
#  'blh': 'boleh',
#  'blm': 'belum',
#  'bln': 'bulan',
#  'blom': 'belum',
#  'bls': 'balas',
#  'blum': 'belum',
#  'bnchi': 'benci',
#  'bnci': 'benci',
#  'bngung': 'bingung',
#  'bnran': 'benar',
#  'bnyk': 'banyak',
#  'bodor': 'lucu',
#  'bokap': 'ayah',
#  'bokep': 'porno',
#  'bokin': 'pacar',
#  'bokis': 'bohong',
#  'bole': 'boleh',
#  'boljug': 'boleh',
#  'bolot': 'bodoh',
#  'boong': 'bohong',
#  'boong”': 'bohong',
#  'boyeh': 'boleh',
#  'bpk': 'bapak',
#  'br': 'baru',
#  'brg': 'bareng',
#  'brngkt': 'berangkat',
#  'brp': 'berapa',
#  'bru': 'baru',
#  'bs': 'bisa',
#  'bsa': 'bisa',
#  'bsen': 'bosan',
#  'bsk': 'besok',
#  'bt': 'buat',
#  'btw': 'ngomong',
#  'bu_bu': 'tidur',
#  'buangbuang': 'buang',
#  'bubarin': 'bubarkan',
#  'bubbu': 'tidur',
#  'bubu': 'tidur',
#  'bukak': 'buka',
#  'bw': 'bawa',
#  'bwhn': 'bawahan',
#  'bwrtransaksi': 'transaksi',
#  'bwt': 'buat',
#  'byar': 'bayar',
#  'byk': 'banyak',
#  'byr': 'bayar',
#  'byrin': 'bayarkan',
#  'c8': 'chat',
#  'cabal': 'sabar',
#  'cabut': 'pergi',
#  'cadas': 'keren',
#  'caem': 'cakep',
#  'calo': 'makelar',
#  'can': 'belum',
#  'capcus': 'pergi',
#  'cape': 'capek',
#  'caur': 'jelek',
#  'cb': 'coba',
#  'ce': 'cewek',
#  'cekal': 'cegah',
#  'cemen': 'penakut',
#  'cemplungin': 'masuk',
#  'cengengesan': 'tertawa',
#  'ceper': 'pendek',
#  'cepet': 'cepat',
#  'cew': 'cewek',
#  'cewe': 'cewek',
#  'chatt': 'chat',
#  'chuyunk': 'sayang',
#  'cibuk': 'sibuk',
#  'cimeng': 'ganja',
#  'cin': 'cinta',
#  'ciye': 'cie',
#  'ciyh': 'sih',
#  'ckck': 'ck',
#  'ckepp': 'cakep',
#  'ckp': 'cakep',
#  'cmpr': 'campur',
#  'cmpur': 'campur',
#  'cnenk': 'senang',
#  'complaint': 'komplain',
#  'confirm': 'konfirmasi',
#  'cong': 'banci',
#  'congor': 'mulut',
#  'cow': 'cowok',
#  'cowwyy': 'maaf',
#  'coz': 'karena',
#  'cpa': 'siapa',
#  'cpe': 'capek',
#  'cppe': 'capek',
#  'cpt': 'cepat',
#  'cs': 'customer service',
#  'cucok': 'cocok',
#  'cuex': 'cuek',
#  'cups': 'culun',
#  'curanmor': 'pencurian',
#  'cwek': 'cewek',
#  'cyin': 'cinta',
#  'd': 'di',
#  'dah': 'deh',
#  'dapet': 'dapat',
#  'de': 'adik',
#  'dek': 'adik',
#  'demen': 'suka',
#  'deyh': 'deh',
#  'dg': 'dengan',
#  'dgn': 'dengan',
#  'diancurin': 'hancur',
#  'dibalikin': 'balik',
#  'diem': 'diam',
#  'dimaafin': 'maaf',
#  'dimintak': 'minta',
#  'direspon': 'respon',
#  'disono': 'sana',
#  'divalidasi': 'validasi',
#  'dket': 'dekat',
#  'dlu': 'dulu',
#  'dngn': 'dengan',
#  'dodol': 'bodoh',
#  'doku': 'uang',
#  'download': 'unduh',
#  'dtang': 'datang',
#  'dtg': 'datang',
#  'duren': 'durian',
#  'dwnld': 'unduh',
#  'easier': 'mudah',
#  'ed': 'edisi',
#  'eke': 'aku',
#  'elu': 'kamu',
#  'emangnya': 'memangnya',
#  'emng': 'memang',
#  'endak': 'tidak',
#  'enggak': 'tidak',
#  'envy': 'iri',
#  'ex': 'mantan',
#  'faktakta': 'fakta',
#  'fax': 'facsimile',
#  'fedback': 'feedback',
#  'fiturnya': 'fitur',
#  'fyi': 'informasi',
#  'gag': 'tidak',
#  'gan': 'juragan',
#  'gantengsaya': 'ganteng',
#  'gawe': 'kerja',
#  'ghiy': 'lagi',
#  'gile': 'gila',
#  'gimana': 'bagaimana',
#  'githu': 'gitu',
#  'gmana': 'bagaimana',
#  'gn': 'begini',
#  'goblok': 'bodoh',
#  'gokil': 'gila',
#  'good': 'bagus',
#  'gretong': 'gratis',
#  'gretongan': 'gratis',
#  'gt': 'begitu',
#  'gua': 'saya',
#  'gue': 'saya',
#  'guoblok': 'goblok',
#  'gw': 'saya',
#  'ha': 'tertawa',
#  'haghaghag': 'tertawa',
#  'haha': 'tertawa',
#  'hakhak': 'tertawa',
#  'hallow': 'halo',
#  'hape': 'handphone',
#  'happy': 'bahagia',
#  'hardcore': 'keras',
#  'hargax': 'harga',
#  'hehe': 'he',
#  'hellow': 'halo',
#  'helo': 'halo',
#  'helow': 'halo',
#  'heters': 'pembenci',
#  'hey': 'hai',
#  'hi': 'hai',
#  'hlm': 'halaman',
#  'hlng': 'hilang',
#  'hny': 'hanya',
#  'hnya': 'hanya',
#  'houm': 'rumah',
#  'hp': 'handphone',
#  'hpus': 'hapus',
#  'hr': 'hari',
#  'hrs': 'harus',
#  'hrus': 'harus',
#  'hub': 'hubungi',
#  'huff': 'mengeluh',
#  'huft': 'mengeluh',
#  'hum': 'rumah',
#  'humas': 'hubungan masyarakat',
#  'humz': 'rumah',
#  'ig': 'instagram',
#  'ikon': 'lambang',
#  'ilang': 'hilang',
#  'ilfil': 'benci',
#  'imoet': 'imut',
#  'imoetz': 'imut',
#  'info': 'informasi',
#  'instal': 'install',
#  'isengin': 'bercanda',
#  'ista': 'nista',
#  'istaa': 'nista',
#  'item': 'hitam',
#  'itung': 'hitung',
#  'itungan': 'hitungan',
#  'iyala': 'iya lah',
#  'iye': 'iya',
#  'iyo': 'iya',
#  'ja': 'saja',
#  'jadiin': 'jadi',
#  'jancuk': 'anjing',
#  'jd': 'jadi',
#  'jdi': 'jadi',
#  'jdikan': 'jadikan',
#  'jeleeeekkk': 'jelek',
#  'jem': 'jam',
#  'jentelmen': 'berani',
#  'jg': 'juga',
#  'jga': 'juga',
#  'jgn': 'jangan',
#  'jgnkan': 'jangankan',
#  'jijay': 'jijik',
#  'jir': 'anjing',
#  'jkt': 'jakarta',
#  'jln': 'jalan',
#  'jnj': 'janji',
#  'jth': 'jatuh',
#  'jutek': 'galak',
#  'jwb': 'jawab',
#  'k': 'ke',
#  'ka': 'kakak',
#  'kab': 'kabupaten',
#  'kabor': 'kabur',
#  'kacian': 'kasihan',
#  'kacrut': 'kacau',
#  'kaga': 'tidak',
#  'kagak': 'tidak',
#  'kainx': 'kain',
#  'kaka': 'kakak',
#  'kalo': 'kalau',
#  'kampret': 'sialan',
#  'kamuh': 'kamu',
#  'kamuwh': 'kamu',
#  'kamyu': 'kamu',
#  'kapt': 'kapten',
#  'karna': 'karena',
#  'karti': 'kartu',
#  'katrok': 'kampungan',
#  'kau': 'kamu',
#  'kayanya': 'seperti',
#  'kbar': 'kabar',
#  'kbr': 'kabar',
#  'kcian': 'kasihan',
#  'kdu': 'harus',
#  'keburu': 'terlanjur',
#  'kec': 'kecamatan',
#  'kek': 'seperti',
#  'kekeuh': 'bersikeras',
#  'keknya': 'seperti',
#  'kel': 'kelurahan',
#  'keliatan': 'kelihatan',
#  'kemaren': 'kemarin',
#  'keneh': 'masih',
#  'kentot': 'senggama',
#  'kepengen': 'mau',
#  'kepikiran': 'terpikirkan',
#  'kepingin': 'mau',
#  'kepo': 'penasaran',
#  'kesian': 'kasihan',
#  'ketauan': 'ketahuan',
#  'ketipuuuuh': 'tipu',
#  'ketrima': 'terima',
#  'keukeuh': 'bersikeras',
#  'kgiatan': 'kegiatan',
#  'khan': 'kan',
#  'kibul': 'bohong',
#  'kimpoi': 'kawin',
#  'kk': 'kakak',
#  'kl': 'kalau',
#  'klian': 'kalian',
#  'klianz': 'kalian',
#  'klo': 'kalau',
#  'kluarga': 'keluarga',
#  'kluarnya': 'keluar',
#  'klw': 'kalau',
#  'klwrga': 'keluarga',
#  'km': 'kamu',
#  'kmari': 'kemari',
#  'kmps': 'kampus',
#  'kmpus': 'kampus',
#  'kmrn': 'kemarin',
#  'kn': 'kan',
#  'knal': 'kenal',
#  'knl': 'kenal',
#  'knp': 'kenapa',
#  'knpa': 'kenapa',
#  'koar': 'teriak',
#  'kog': 'kok',
#  'komennya': 'komentar',
#  'koment': 'komentar',
#  'kompi': 'komputer',
#  'komplin': 'komplain',
#  'koq': 'kok',
#  'korup': 'korupsi',
#  'kpd': 'kepada',
#  'kpn': 'kapan',
#  'kptsan': 'keputusan',
#  'krenz': 'keren',
#  'kridit': 'kredit',
#  'krik': 'garing',
#  'krm': 'kirim',
#  'krn': 'karena',
#  'ksong': 'kosong',
#  'kt': 'kita',
#  'ktauan': 'ketahuan',
#  'ktipu': 'tipu',
#  'ktmu': 'ketemu',
#  'ktny': 'katanya',
#  'ktr': 'kantor',
#  'kudu': 'harus',
#  'kuq': 'kok',
#  'kurng': 'kurang',
#  'kw': 'imitasi',
#  'kwalitas': 'kualitas',
#  'kwalitasnya': 'kualitas',
#  'ky': 'seperti',
#  'kyk': 'seperti',
#  'kykny': 'kayanya',
#  'la': 'lah',
#  'laka': 'kecelakaan',
#  'lam': 'salam',
#  'lambreta': 'lambat',
#  'lamp': 'lampiran',
#  'lbur': 'libur',
#  'lebay': 'berlebihan',
#  'leh': 'boleh',
#  'lelet': 'lambat',
#  'lemot': 'lambat',
#  'less': 'kurang',
#  'lg': 'lagi',
#  'lgi': 'lagi',
#  'lgkp': 'lengkap',
#  'lgsg': 'langsung',
#  'lht': 'lihat',
#  'liat': 'lihat',
#  'light': 'terang',
#  'linmas': 'perlindungan masyarakat',
#  'lmyan': 'lumayan',
#  'lmyn': 'lumayan',
#  'lngkp': 'lengkap',
#  'lo': 'kamu',
#  'loch': 'loh',
#  'loe': 'kamu',
#  'lol': 'tertawa',
#  'lola': 'lemot',
#  'lom': 'belum',
#  'louph': 'cinta',
#  'loupz': 'cinta',
#  'low': 'kalau',
#  'lowh': 'kamu',
#  'lp': 'lupa',
#  'lu': 'kamu',
#  'luama': 'lama',
#  'luchu': 'lucu',
#  'luchuw': 'lucu',
#  'luff': 'cinta',
#  'lum': 'belum',
#  'luph': 'cinta',
#  'luthu': 'lucu',
#  'lw': 'kamu',
#  'lwn': 'lawan',
#  'lwt': 'lewat',
#  'mabal': 'bolos',
#  'macem': 'macam',
#  'macih': 'masih',
#  'made': 'buat',
#  'maem': 'makan',
#  'maen': 'main',
#  'mahalllll': 'mahal',
#  'maho': 'homo',
#  'mak': 'ibu',
#  'make': 'pakai',
#  'maksain': 'maksa',
#  'malah': 'bahkan',
#  'malem': 'malam',
#  'malu2in': 'memalukan',
#  'mam': 'makan',
#  'mamam': 'makan',
#  'mamz': 'makan',
#  'maneh': 'kamu',
#  'manies': 'manis',
#  'maniez': 'manis',
#  'mantap': 'bagus',
#  'mantep': 'mantap',
#  'mao': 'mau',
#  'masukin': 'masukkan',
#  'masukkk': 'masuk',
#  'masul': 'masuk',
#  'masy': 'masyarakat',
#  'mba': 'mbak',
#  'mbingungin': 'bingung',
#  'mbual': 'bual',
#  'mehong': 'mahal',
#  'melu': 'ikut',
#  'mending': 'lebih baik',
#  'mepet': 'dekat',
#  'mgkin': 'mungkin',
#  'mgkn': 'mungkin',
#  'mgu': 'minggu',
#  'mhn': 'mohon',
#  'miras': 'minuman keras',
#  'mksd': 'maksud',
#  'mlah': 'malah',
#  'mls': 'malas',
#  'mngkn': 'mungkin',
#  'mnolak': 'tolak',
#  'mnt': 'minta',
#  'mo': 'mau',
#  'moga': 'semoga',
#  'mokad': 'mati',
#  'mokat': 'mati',
#  'moso': 'masa',
#  'mosok': 'masa',
#  'most': 'paling',
#  'mpe': 'sampai',
#  'msh': 'masih',
#  'msk': 'masuk',
#  'mskpn': 'meskipun',
#  'mslh': 'masalah',
#  'muaaahal': 'mahal',
#  'muahal': 'mahal',
#  'muas': 'puas',
#  'mulu': 'melulu',
#  'mumet': 'pusing',
#  'mumpung': 'selagi',
#  'muna': 'munafik',
#  'munfik': 'munafik',
#  'musti': 'mesti',
#  'muup': 'maaf',
#  'muupz': 'maaf',
#  'muuv': 'maaf',
#  'mz': 'mas',
#  'nal': 'kenal',
#  'nanam': 'menanam',
#  'nangis': 'menangis',
#  'nanya': 'bertanya',
#  'naon': 'apa',
#  'napa': 'kenapa',
#  'napi': 'narapidana',
#  'naq': 'anak',
#  'nax': 'anak',
#  'nda': 'tidak',
#  'ndak': 'tidak',
#  'ndiri': 'sendiri',
#  'ndut': 'gendut',
#  'ne': 'ini',
#  'nekolim': 'neokolonialisme',
#  'nekolin': 'neokolonialisme',
#  'nelfon': 'menelepon',
#  'next': 'lanjut',
#  'ngabis2in': 'menghabiskan',
#  'ngakak': 'tertawa',
#  'ngaku': 'mengaku',
#  'ngambek': 'marah',
#  'ngambil': 'mengambil',
#  'ngantri': 'antri',
#  'ngapah': 'kenapa',
#  'ngaret': 'terlambat',
#  'ngaruh': 'pengaruh',
#  'ngasih': 'beri',
#  'ngawur': 'sembarangan',
#  'ngebandel': 'bandel',
#  'ngebantuin': 'bantu',
#  'ngebully': 'intimidasi',
#  'ngeceng': 'kumpul',
#  'ngechat': 'chat',
#  'ngegosip': 'gosip',
#  'ngeh': 'sadar',
#  'ngehe': 'kesal',
#  'ngeklaim': 'klaim',
#  'ngekos': 'kos',
#  'ngelamar': 'lamar',
#  'ngeles': 'berkilah',
#  'ngeliat': 'lihat',
#  'ngelidur': 'menggigau',
#  'ngemeng': 'bicara',
#  'ngentotin': 'senggama',
#  'ngerampok': 'rampok',
#  'ngerti': 'mengerti',
#  'ngertiin': 'mengerti',
#  'ngga': 'tidak',
#  'nggak': 'tidak',
#  'ngibul': 'bohong',
#  'ngikut': 'ikut',
#  'ngiler': 'mau',
#  'ngincer': 'incar',
#  'nginep': 'menginap',
#  'ngiri': 'iri',
#  'ngisi': 'mengisi',
#  'ngisiin': 'mengisikan',
#  'ngmg': 'bicara',
#  'ngmng': 'bicara',
#  'ngobrol': 'bicara',
#  'ngocol': 'lucu',
#  'ngomong': 'bicara',
#  'ngomongin': 'bicara',
#  'ngubek2': 'cari',
#  'ngumpet': 'sembunyi',
#  'ngumpul': 'kumpul',
#  'ngurus': 'urus',
#  'ni': 'ini',
#  'nie': 'ini',
#  'nih': 'ini',
#  'nipu': 'tipu',
#  'niyh': 'nih',
#  'nmenarik': 'menarik',
#  'nmr': 'nomor',
#  'nntn': 'nonton',
#  'ntar': 'nanti',
#  'ntn': 'nonton',
#  'numpuk': 'tumpuk',
#  'nunggu': 'tunggu',
#  'nutupin': 'tutup',
#  'nyari': 'cari',
#  'nyariin': 'cari',
#  'nyarinya': 'cari',
#  'nyasar': 'tersesat',
#  'nyebelin': 'sebal',
#  'nyekar': 'menyekar',
#  'nyela': 'cela',
#  'nyembah': 'sembah',
#  'nyerang': 'serang',
#  'nyiapin': 'siap',
#  'nyicil': 'cicil',
#  'nyiram': 'siram',
#  'nyoba': 'coba',
#  'nyoblos': 'coblos',
#  'nyok': 'ayo',
#  'nyokap': 'ibu',
#  'o/': 'oleh',
#  'ok': 'ok',
#  'ol': 'online',
#  'ongkirnya': 'ongkir',
#  'org': 'orang',
#  'ori': 'asli',
#  'original': 'asli',
#  'orii': 'asli',
#  'pacal': 'pacar',
#  'pake': 'pakai',
#  'pala': 'kepala',
#  'pantes': 'pantas',
#  'pantesan': 'pantas',
#  'paranoid': 'takut',
#  'parte': 'partai',
#  'paswordnya': 'password',
#  'pay': 'bayar',
#  'payaaaaaaaahh': 'payah',
#  'payment': 'bayar',
#  'pd': 'pada',
#  'pelayananya': 'layanan',
#  'pelyanan': 'layanan',
#  'penertiban': 'tertib',
#  'perhatiin': 'perhatikan',
#  'peribet': 'ribet',
#  'pesenan': 'pesanan',
#  'pgang': 'pegang',
#  'pi': 'tapi',
#  'pisan': 'sangat',
#  'pk': 'pakai',
#  'plg': 'paling',
#  'pmrnth': 'pemerintah',
#  'pndukung': 'pendukung',
#  'prcuma': 'percuma',
#  'prg': 'pergi',
#  'priksa': 'periksa',
#  'prnh': 'pernah',
#  'pro': 'profesional',
#  'problem': 'masalah',
#  'produck': 'produk',
#  'protol': 'lepas',
#  'psen': 'pesan',
#  'psn': 'pesan',
#  'pst': 'pasti',
#  'psti': 'pasti',
#  'pswt': 'pesawat',
#  'puanas': 'panas',
#  'pw': 'posisi nyaman',
#  'qmo': 'kamu',
#  'qmu': 'kamu',
#  'qt': 'kita',
#  'rame': 'ramai',
#  'raskin': 'rakyat miskin',
#  'rb': 'ribu',
#  're': 'balas',
#  'ready': 'siap',
#  'realpict': 'asli',
#  'red': 'redaksi',
#  'ref': 'referensi',
#  'reffund': 'refund',
#  'reg': 'register',
#  'register': 'daftar',
#  'rehab': 'rehabilitasi',
#  'rejeki': 'rezeki',
#  'reklamuk': 'reklamasi',
#  'rempong': 'sulit',
#  'repp': 'balas',
#  'responnya': 'respon',
#  'rhs': 'rahasia',
#  'rights': 'benar',
#  'rmh': 'rumah',
#  'ru': 'baru',
#  'rubahnn': 'rubah',
#  'ruz': 'terus',
#  'sadaar': 'sadar',
#  'saia': 'saya',
#  'sampe': 'sampai',
#  'sapose': 'siapa',
#  'sbh': 'sebuah',
#  'sbnrny': 'sebenarnya',
#  'scr': 'secara',
#  'sdgkn': 'sedangkan',
#  'sdkt': 'sedikit',
#  'se7': 'setuju',
#  'sempet': 'sempat',
#  'sept': 'september',
#  'seting': 'akting',
#  'setiyap': 'setiap',
#  'setrlah': 'setelah',
#  'setting': 'atur',
#  'sgt': 'sangat',
#  'shg': 'sehingga',
#  'shopping': 'belanja',
#  'siech': 'sih',
#  'simiskin': 'miskin',
#  'siramin': 'siram',
#  'sj': 'saja',
#  'skalian': 'sekalian',
#  'skarng': 'sekarang',
#  'sklh': 'sekolah',
#  'skrg': 'sekarang',
#  'skt': 'sakit',
#  'slalu': 'selalu',
#  'slesai': 'selesai',
#  'sll': 'selalu',
#  'slma': 'selama',
#  'slow': 'lambat',
#  'slsai': 'selesai',
#  'sma': 'sama',
#  'smpe': 'sampai',
#  'smpt': 'sempat',
#  'smw': 'semua',
#  'sndiri': 'sendiri',
#  'sndri': 'sendiri',
#  'sni': 'sini',
#  'sohib': 'teman',
#  'solve': 'solusi',
#  'songong': 'sombong',
#  'sori': 'maaf',
#  'sorry': 'maaf',
#  'sory': 'maaf',
#  'sotoy': 'tahu',
#  'sowry': 'maaf',
#  'spa': 'siapa',
#  'spd': 'sepeda',
#  'sppa': 'siapa',
#  'sprt': 'seperti',
#  'sprti': 'seperti',
#  'spt': 'seperti',
#  'spy': 'supaya',
#  'srtfkt': 'sertifikat',
#  'staffnya': 'staff',
#  'stelah': 'setelah',
#  'stiap': 'setiap',
#  'still': 'masih',
#  'stlh': 'setelah',
#  'stokmya': 'stok',
#  'store': 'toko',
#  'story': 'cerita',
#  'subbag': 'subbagian',
#  'suk': 'masuk',
#  'sukaa': 'suka',
#  'sukak': 'suka',
#  'sumbangin': 'sumbangkan',
#  'sumpek': 'sempit',
#  'sy': 'saya',
#  'syg': 'sayang',
#  'syp': 'siapa',
#  'system': 'sistem',
#  'systemnya': 'sistem',
#  't4': 'tempat',
#  'tahi': 'kotoran',
#  'taik': 'tahi',
#  'tajir': 'kaya',
#  'tak': 'tidak',
#  'takuuut': 'takut',
#  'tar': 'nanti',
#  'tau': 'tahu',
#  'tauk': 'tahu',
#  'taun': 'tahun',
#  'taw': 'tahu',
#  'tawh': 'tahu',
#  'td': 'tadi',
#  'tdi': 'tadi',
#  'tdk': 'tidak',
#  'te2p': 'tetap',
#  'tekor': 'rugi',
#  'telat': 'terlambat',
#  'telkom': 'telekomunikasi',
#  'telp': 'telepon',
#  'temen': 'teman',
#  'tengil': 'menyebalkan',
#  'tengok': 'jenguk',
#  'tepar': 'terkapar',
#  'terbitin': 'terbit',
#  'tf': 'transfer',
#  'tggu': 'tunggu',
#  'tgl': 'tanggal',
#  'tgu': 'tunggu',
#  'thd': 'terhadap',
#  'thn': 'tahun',
#  'tilang': 'bukti pelanggaran',
#  'tilep': 'tilap',
#  'tioghoa': 'tionghoa',
#  'tipi': 'TV',
#  'tirani': 'tiran',
#  'tkg': 'tukang',
#  'tlg': 'tolong',
#  'tll': 'terlalu',
#  'tlp': 'telepon',
#  'tlpn': 'telepon',
#  'tls': 'tulis',
#  'tman': 'teman',
#  'tmbah': 'tambah',
#  'tmbh': 'tambah',
#  'tmpah': 'tumpah',
#  'tmph': 'tumpah',
#  'tmpt': 'tempat',
#  'tnda': 'tanda',
#  'tngu': 'tunggu',
#  'tnh': 'tanah',
#  'tnyta': 'ternyata',
#  'tokai': 'tai',
#  'tp': 'tapi',
#  'tpi': 'tapi',
#  'transver': 'transfer',
#  'trdhulu': 'terdahulu',
#  'tren': 'trend',
#  'trending': 'trend',
#  'trf': 'transfer',
#  'trgntg': 'tergantung',
#  'trima': 'terima',
#  'trlalu': 'terlalu',
#  'trm': 'terima',
#  'trs': 'terus',
#  'true': 'benar',
#  'trutama': 'terutama',
#  'trx': 'transaksi',
#  'ts': 'penulis',
#  'tsangka': 'tersangka',
#  'ttg': 'tentang',
#  'tuch': 'tuh',
#  'tuir': 'tua',
#  'turunin': 'turun',
#  'tw': 'tahu',
#  'u': 'kamu',
#  'uasai': 'kuasa',
#  'ud': 'sudah',
#  'udah': 'sudah',
#  'ujg': 'ujung',
#  'ul': 'ulangan',
#  'unyu': 'lucu',
#  'uplot': 'unggah',
#  'urang': 'saya',
#  'usah': 'perlu',
#  'utk': 'untuk',
#  'vocer': 'voucher',
#  'voucherx': 'voucher',
#  'w/': 'dengan',
#  'wa': 'whatsapp',
#  'waspadalah': 'waspada',
#  'wat': 'buat',
#  'watuk': 'batuk',
#  'ways': 'cara',
#  'wkt': 'waktu',
#  'wkwkkw': 'tertawa',
#  'xixixi': 'tertawa',
#  'y': 'ya',
#  'ya': 'iya',
#  'yap': 'iya',
#  'yg': 'yang',
#  'yo': 'iya',
#  'yup': 'iya',
#  'zonk': 'bodoh'}

# %%
random_state = 0

# %% [markdown]
# ### Initial Token

# %%
# list for tokenized documents in loop
texts = []

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Preprocess
#
# This process include casefolding, remove special character, multiple whitespace, stopword, and stemming

# %%
def preprocess(value, sw_remover):
  value = value.lower()
  value = re.sub(r'[^a-zA-Z]', ' ', value)
  value = re.sub(r'\s\s+', ' ', value)
  value = stemmer.stem(value)
  value = sw_remover.remove(value)
  return value

# %%
df.dropna(subset = ["review"], inplace=True)

# %%
sw_remover = ExtendStopWordRemoverFactory().create_stop_word_remover()
# df['review'] = df['review'].fillna("",inplace=True)
processed_values = df['review'].apply(lambda x: preprocess(x, sw_remover))
processed_values = processed_values.replace('', float("NaN"))
df_token = df.copy()
df_token['review'] = processed_values

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token = df_token[[len(i.split())>1 for i in df_token['review'].values]]

# %%
df_token.dropna(subset = ["review"], inplace=True)

# %%
df_token
# Out:
#                                                     review  rating
# 0                                          iklan ganggu as       1
# 1                                  tolong erti pesan pesan       1
# 2                                 iklan trossssssss ganggu       1
# 3        ruwet metode bayar indomart mlh cod aplikasi v...       1
# 4        dih dwon aplikasi tipu order giveaway hp perca...       1
# ...                                                    ...     ...
# 1475049  belanja shoppe bantu temu barang dng cepat har...       5
# 1475050    sampe skrg pake alhamdulilah gapernah ngecewain       5
# 1475052     enk blanja shopeee tigkatkn gratis ongkir psan       5
# 1475053                                  belanja kirim cpt       5
# 1475055                               layan belanja shoope       5
#
# [761730 rows x 2 columns]

# %% [markdown]
# ### Tokenization

# %%
# Tokenize
for i in df_token['review']:
  tokens = tokenizer.tokenize(i)
  texts.append(tokens)

# %% [markdown]
# ### Formalization

# %%
def convert(l, d):
  return [convert(x, d) if isinstance(x, list) else d.get(x, x) for x in l]

# %%
texts = convert(texts, formalization_indo)

# %%
texts
# Out:
# [['iklan', 'ganggu', 'as'],
#  ['tolong', 'erti', 'pesan', 'pesan'],
#  ['iklan', 'trossssssss', 'ganggu'],
#  ['ruwet', 'metode', 'bayar', 'indomart', 'mlh', 'cod', 'aplikasi', 'voucher'],
#  ['dih',
#   'dwon',
#   'aplikasi',
#   'tipu',
#   'order',
#   'giveaway',
#   'handphone',
#   'percaya',
#   'dateng',
#   'kawat',
#   'bayar',
#   'ribu',
#   'masak',
#   'kasi',
#   'kawat',
#   'untung',
#   'gin',
#   'tipu',
#   'bgettt',
#   'yaaa',
#   'gesss',
#   'aman',
#   'percaya',
#   'tukang',
#   'tipu',
#   'kaya',
#   'hapus',
#   'lgsung',
#   'aplikasi'],
#  ['cashbacknya', 'dapetnya', 'kirim', 'dikit', 'serius', 'bikin', 'promo'],
#  ['bnrn',
#   'sya',
#   'menang',
#   'untung',
#   'undi',
#   'handphone',
#   'ip',
#   'kirim',
#   'alamat',
#   'tinggal',
#   'sya',
#   'kp',
#   'rawahingkik',
#   'rt',
#   'rw',
#   'cileungsi',
#   'bogor',
#   'ichat'],
#  ['keluh', 'langgan', 'tanggung'],
#  ['pocer', 'tapi', 'ngk'],
#  ['ui', 'ribet'],
#  ['aplikasi', 'pesan', 'barang', 'bayar', 'barang', 'pesan', 'nyampe'],
#  ['keluan',
#   'setelah',
#   'bc',
#   'komntr',
#   'apa',
#   'banyak',
#   'penipuny',
#   'pelyananya'],
#  ['transaksi', 'tranfer', 'uang'],
#  ['cok', 'asyifa'],
#  ['ampuh', 'sehat', 'aman', 'damai'],
#  ['males', 'belanja', 'shope', 'lebih baik', 'toko', 'belah'],
#  ['maf',
#   'aplikasi',
#   'sayah',
#   'terimna',
#   'hadiah',
#   'puter',
#   'katnya',
#   'hadiah',
#   'uang',
#   'tapi',
#   'bacan',
#   'ambil',
#   'uang',
#   'sama',
#   'hadia',
#   'sayah',
#   'terimna',
#   'aplikasi',
#   'nga',
#   'bisin',
#   'kuota',
#   'bantu',
#   'jawap',
#   'kenah',
#   'ambil'],
#  ['beli', 'barang', 'sesuai', 'boykot'],
#  ['tolong', 'cepat'],
#  ['membaii', 'layanan'],
#  ['ban', 'ban', 'bekas'],
#  ['toko', 'beli', 'gantung', 'tas', 'nggkak', 'kirim', 'kirim'],
#  ['cod', 'transfer', 'proses', 'bikin', 'ribet'],
#  ['rupiah', 'ongkir', 'bayar'],
#  ['gratis',
#   'ongkir',
#   'promo',
#   'cashback',
#   'juga',
#   'hilang',
#   'pindah',
#   'aplikasi',
#   'nihh'],
#  ['kode',
#   'verifikasi',
#   'otp',
#   'sulit',
#   'verifikasi',
#   'whatsapp',
#   'nomer',
#   'via',
#   'telepon',
#   'nyampe',
#   'gin',
#   'bikin',
#   'sulit',
#   'daftar',
#   'shoppe',
#   'bayar',
#   'maaf',
#   'lanjur',
#   'harap',
#   'sistem',
#   'verifikasi',
#   'kode',
#   'otp',
#   'ribet',
#   'cuman',
#   'ganti',
#   'pasword',
#   'simple',
#   'maju',
#   'kayak',
#   'gin'],
#  ['belanja',
#   'barang',
#   'dateng',
#   'lapor',
#   'kirim',
#   'alhasil',
#   'bolak',
#   'ekspedisi',
#   'plus',
#   'debat',
#   'jual',
#   'uang',
#   'hilang',
#   'barang',
#   'nyampe',
#   'jujur',
#   'ekspedisi',
#   'expres'],
#  ['akun',
#   'nonaktif',
#   'order',
#   'bayar',
#   'shopeepay',
#   'nonaktif',
#   'jlskan',
#   'salah'],
#  ['proses',
#   'rim',
#   'padhal',
#   'update',
#   'tepaksa',
#   'batal',
#   'prises',
#   'kirim',
#   'tolong',
#   'dibantuh'],
#  ['paylater', 'beku', 'limit', 'terlambat', 'bayar', 'solusi'],
#  ['aplikasi',
#   'ndk',
#   'masak',
#   'beli',
#   'speaker',
#   'gantung',
#   'kunci',
#   'tolong',
#   'tok',
#   'bossku',
#   'aplikasi',
#   'rusak',
#   'serius'],
#  ['terkadang', 'dilazada', 'barang', 'sesuai'],
#  ['tukang',
#   'tipu',
#   'aplikasi',
#   'kawan',
#   'kawan',
#   'jngan',
#   'unduh',
#   'aplikasi',
#   'modus',
#   'tipu',
#   'iming',
#   'iming',
#   'hadiah',
#   'lebih baik',
#   'unduh',
#   'bonus'],
#  ['dtipu',
#   'muncul',
#   'pembritahuan',
#   'memdapat',
#   'hadiah',
#   'cmn',
#   'suruh',
#   'install',
#   'aplikasi',
#   'tempek'],
#  ['error', 'yaaaaaaa'],
#  ['iklan', 'akeh', 'cok'],
#  ['idexpress', 'hapus', 'paket', 'regelur', 'sampai'],
#  ['unduh', 'bantu'],
#  ['susah', 'memasukkn', 'otp', 'kirim'],
#  ['ngk', 'aplikasi'],
#  ['install', 'anjenk'],
#  ['emosi',
#   'internet',
#   'aplikasi',
#   'lancar',
#   'pas',
#   'shope',
#   'ketik',
#   'cari',
#   'pencet',
#   'enter',
#   'emosi',
#   'jam',
#   'seperti',
#   'besok',
#   'seperti',
#   'loading',
#   'pas',
#   'loading',
#   'produk',
#   'temu',
#   'tahu',
#   'barang',
#   'cari',
#   'iseng',
#   'sia',
#   'sia',
#   'tunggu'],
#  ['saldo', 'blokir', 'tolong', 'customer', 'care', 'aktifin', 'saldo'],
#  ['jangan',
#   'belanja',
#   'tipu',
#   'pesan',
#   'kirim',
#   'pakai',
#   'metode',
#   'bayar',
#   'cod',
#   'kurir',
#   'bilang',
#   'bayar',
#   'jual',
#   'prnah',
#   'beli',
#   'bareng',
#   'sesuai',
#   'pas',
#   'cod',
#   'dpn',
#   'kurir',
#   'kurir',
#   'sendiri',
#   'inisiatif',
#   'bilang',
#   'jual',
#   'basa',
#   'basi',
#   'rugi',
#   'tipu',
#   'berkah',
#   'makan',
#   'tu',
#   'duit',
#   'haram',
#   'ikhlas',
#   'dunia',
#   'akhirat'],
#  ['pesan',
#   'balik',
#   'gudang',
#   'lagi',
#   'kurir',
#   'wilayah',
#   'kirim',
#   'suruh',
#   'tunggu',
#   'lagi',
#   'sesuai',
#   'wilayah',
#   'kirim'],
#  ['iklanya', 'lindung', 'handphone', 'mu', 'viruz', 'pas', 'pencet', 'malak'],
#  ['tipu', 'tolong', 'pantau', 'jual', 'tipu', 'tolak'],
#  ['aplikasi',
#   'taiii',
#   'mesen',
#   'sampai',
#   'pas',
#   'sampai',
#   'barang',
#   'sampai',
#   'cancel',
#   'costumer'],
#  ['loading', 'berat', 'susahhhh'],
#  ['njirrr', 'selancar', 'alih', 'ksini', 'vanke'],
#  ['pesan',
#   'photocard',
#   'taehyung',
#   'eror',
#   'ulang',
#   'pas',
#   'checkout',
#   'notif',
#   'barang',
#   'saldo',
#   'potong',
#   'tolong',
#   'jngn',
#   'sperti'],
#  ['aplikasi', 'iklan', 'ngotak', 'mentang', 'duit', 'bikin', 'iklan'],
#  ['sebal',
#   'kesini',
#   'akun',
#   'apain',
#   'gagal',
#   'checkout',
#   'alas',
#   'curiga',
#   'janggal',
#   'ngeselin',
#   'pakai',
#   'shopeepay',
#   'gilir',
#   'pakai',
#   'bayar',
#   'gratis',
#   'ongkir',
#   'cashback',
#   'dipake',
#   'shopeepay',
#   'tolong',
#   'bikin',
#   'ribet'],
#  ['milih',
#   'jasa',
#   'ekspedisi',
#   'monopoli',
#   'express',
#   'cepat',
#   'sukur',
#   'paket',
#   'kirim',
#   'jakarta',
#   'estimasi',
#   'oktober',
#   'karawang',
#   'alih',
#   'toko'],
#  ['iklan', 'muncul', 'konttttttoooooooollllllllllll'],
#  ['kesel',
#   'update',
#   'diupdate',
#   'februari',
#   'besok',
#   'update',
#   'event',
#   'tanggal',
#   'februari',
#   'berat',
#   'handphone',
#   'handphone',
#   'kentang',
#   'ngebul',
#   'kuat',
#   'pakai',
#   'aplikasi',
#   'proses',
#   'belanja',
#   'gampang'],
#  ['pelit', 'ongkir', 'belanja', 'aplikasi', 'sedih', 'epribadi'],
#  ['iklan', 'muncul', 'ng'],
#  ['beli',
#   'sadar',
#   'barang',
#   'beli',
#   'beda',
#   'berat',
#   'tulis',
#   'berat',
#   'berat',
#   'sesunguhnya',
#   'berat',
#   'kg',
#   'tulis',
#   'kg',
#   'bayar',
#   'kg',
#   'kg',
#   'beli',
#   'ambil',
#   'bonus',
#   'beli',
#   'beli',
#   'cari',
#   'berat',
#   'barang',
#   'wajar',
#   'berat',
#   'sesuai',
#   'beda',
#   'kg',
#   'wajar',
#   'beda',
#   'kg',
#   'ajar'],
#  ['aplokasi', 'ribet', 'mau', 'jual', 'susah'],
#  ['member', 'platinum', 'shopepay', 'later', 'aktif', 'payahhh'],
#  ['spaylater',
#   'mesti',
#   'verifikasi',
#   'wajah',
#   'gagal',
#   'bayar',
#   'cicil',
#   'cicil',
#   'pakek',
#   'spaylater',
#   'malas',
#   'atm',
#   'sistem',
#   'bayar',
#   'sms',
#   'banking',
#   'kendala',
#   'malas',
#   'belanja',
#   'dishopee'],
#  ['seperti', 'ngk'],
#  ['ngapain', 'nongol', 'melulu', 'iklan', 'aplikasi', 'ganggu'],
#  ['unduh', 'update', 'hahaha', 'untung'],
#  ['hapus',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'data',
#   'pribadi',
#   'kait',
#   'akun',
#   'hapus',
#   'bantu'],
#  ['sistem', 'beli', 'pulsa', 'uang', 'cepat', 'bangkrut', 'amin'],
#  ['dindownliad', 'hapus'],
#  ['isi',
#   'saldo',
#   'shoopepay',
#   'pas',
#   'klik',
#   'bank',
#   'virtual',
#   'account',
#   'blank',
#   'layar',
#   'handphone',
#   'putih',
#   'refresh',
#   'tetep',
#   'adehhhh',
#   'transaksi',
#   'njengggg'],
#  ['olshop',
#   'hancur',
#   'jasa',
#   'ekpedisi',
#   'kurir',
#   'amanh',
#   'smoga',
#   'benah',
#   'olshop',
#   'bagaimna',
#   'prioritas',
#   'customer'],
#  ['beli',
#   'handphone',
#   'barang',
#   'sesuai',
#   'retur',
#   'handphone',
#   'jual',
#   'uang',
#   'bantu',
#   'admin'],
#  ['toko', 'bnyak', 'tipu'],
#  ['aplikasi',
#   'tipu',
#   'program',
#   'promo',
#   'cashback',
#   'bodoh',
#   'rugi',
#   'nyesal'],
#  ['amanah',
#   'bayar',
#   'dibatalin',
#   'sistem',
#   'dana',
#   'dikembaliin',
#   'juga',
#   'belanja',
#   'tolong',
#   'cari',
#   'uang',
#   'susah',
#   'fikembalikan',
#   'cepat'],
#  ['sapi',
#   'lajanda',
#   'ribet',
#   'akun',
#   'cuman',
#   'handphone',
#   'ttp',
#   'batal',
#   'sistem',
#   'busul'],
#  ['shoope', 'pesan', 'dibatalin', 'tampa', 'konfirmasi'],
#  ['aplikasi', 'lambat', 'unduh'],
#  ['cari', 'tahu', 'tahu'],
#  ['kurir',
#   'expres',
#   'mahal',
#   'beda',
#   'kurir',
#   'ribu',
#   'pakai',
#   'expres',
#   'ribu',
#   'pakai',
#   'voucher',
#   'no',
#   'ongkir',
#   'tetep',
#   'biaya',
#   'ongkir'],
#  ['tanam',
#   'blank',
#   'eror',
#   'update',
#   'cache',
#   'uninstall',
#   'install',
#   'begtu'],
#  ['proses',
#   'bayar',
#   'btl',
#   'seller',
#   'tolong',
#   'bayar',
#   'cepat',
#   'cod',
#   'tindak',
#   'lh',
#   'mksh'],
#  ['toko',
#   'jual',
#   'barang',
#   'sesuai',
#   'klik',
#   'pesan',
#   'bantu',
#   'solusi',
#   'tertawa'],
#  ['daftar', 'susah'],
#  ['belanja', 'barang', 'batal', 'otomatis', 'terssss', 'kezeellllll'],
#  ['susah',
#   'cari',
#   'barang',
#   'isi',
#   'barang',
#   'pasang',
#   'harga',
#   'perut',
#   'efek',
#   'gampang',
#   'bikin',
#   'bahan',
#   'timbang',
#   'bikin',
#   'betah',
#   'buyer'],
#  ['shopeepay', 'later', 'jngan', 'bayar', 'sllu'],
#  ['ganggu', 'jual', 'murah', 'iklaaaan', 'terusss', 'kamorer'],
#  ['loginnya', 'login', 'pakai', 'no', 'telepon', 'error'],
#  ['bnyak',
#   'seller',
#   'tipu',
#   'hati',
#   'ditelfon',
#   'seller',
#   'remote',
#   'akun',
#   'shopeenya',
#   'tolong',
#   'aplikasiny',
#   'update',
#   'refund',
#   'jangan',
#   'bgitu',
#   'batal',
#   'refund',
#   'uang',
#   'tunggu',
#   'hari'],
#  ['aplikasi', 'ongkir', 'bayar'],
#  ['iklan', 'melulu'],
#  ['update', 'pas', 'update', 'error', 'komplain', 'fast', 'respon', 'solusi'],
#  ['engga',
#   'kapok',
#   'layan',
#   'super',
#   'dengar',
#   'komplain',
#   'langgan',
#   'langgan',
#   'kompalin',
#   'tetbaik',
#   'dengar',
#   'terkadang',
#   'fiturr',
#   'chat',
#   'mati',
#   'layan'],
#  ['maaf',
#   'kenape',
#   'verifikasi',
#   'sms',
#   'susah',
#   'bug',
#   'verifikasi',
#   'sms',
#   'auto',
#   'mengisi',
#   'salah',
#   'kode',
#   'kode',
#   'tulis',
#   'ulang',
#   'hapus',
#   'keyboard',
#   'ngetik',
#   'angka',
#   'bug',
#   'ganggu',
#   'asli',
#   'ampas',
#   'aplikasi',
#   'tolong',
#   'kasi',
#   'hadeh',
#   'ecommerce',
#   'indonesia',
#   'gin',
#   'ampas',
#   'hadeuh'],
#  ['barang',
#   'bilang',
#   'siap',
#   'pas',
#   'transfer',
#   'chat',
#   'balas',
#   'aplikasi',
#   'jual'],
#  ['maaf', 'toko', 'kirim', 'sesuai', 'pesan', 'ulang', 'ulang'],
#  ['iklan', 'melulu', 'aplikasi', 'droppppp'],
#  ['toko', 'tipu'],
#  ['belanja',
#   'dilazada',
#   'garansi',
#   'uang',
#   'hoaks',
#   'barang',
#   'sesuai',
#   'tahu',
#   'return',
#   'dh'],
#  ['eror', 'kode', 'io', 'buin'],
#  ['aplikasi', 'ganggu'],
#  ['livenya',
#   'rekam',
#   'diposting',
#   'minggu',
#   'baju',
#   'postingan',
#   'minggu',
#   'blackpink',
#   'ulang',
#   'please',
#   'fans',
#   'mengatasnamakan',
#   'live',
#   'blackpink'],
#  ['sring',
#   'kcewa',
#   'ditoped',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'tolak',
#   'seller',
#   'sellernya',
#   'bareng',
#   'ssuai',
#   'deskripsi',
#   'komplain',
#   'bareng',
#   'nanggung',
#   'ongkir',
#   'pdhl',
#   'ksalahan',
#   'seller',
#   'bareng',
#   'bukan',
#   'ssuai',
#   'deskripsi',
#   'lagi',
#   'brgnya',
#   'palsu',
#   'kmbalikan',
#   'bareng',
#   'proses',
#   'rumit',
#   'waktu',
#   'garis',
#   'bsarnya',
#   'seller',
#   'mrugikan',
#   'scara',
#   'materi',
#   'energi',
#   'waktu',
#   'heran',
#   'tu',
#   'seller',
#   'sampai',
#   'hari',
#   'masih',
#   'bebas',
#   'jual',
#   'bareng',
#   'palsu',
#   'pdhl',
#   'bukti'],
#  ['aplikasi', 'aneh', 'search', 'produk', 'muncul'],
#  ['aplikasi',
#   'cek',
#   'pesan',
#   'gagal',
#   'antre',
#   'internet',
#   'offline',
#   'lancar',
#   'sesal',
#   'dowload',
#   'aplikasi'],
#  ['tanggung',
#   'koin',
#   'pakai',
#   'koin',
#   'kemarin',
#   'tanam',
#   'koin',
#   'siram',
#   'koin',
#   'koin',
#   'tolong',
#   'gin',
#   'pakai',
#   'jujur',
#   'pakai',
#   'koin',
#   'nama',
#   'glowindo'],
#  ['maaf', 'mesen', 'powerbank', 'pas', 'powerbank', 'rusak'],
#  ['error',
#   'main',
#   'game',
#   'segercep',
#   'kemarin',
#   'promo',
#   'cashbacknya',
#   'tarik',
#   'kemarin',
#   'harga',
#   'barang',
#   'murah',
#   'aplikasi',
#   'belah',
#   'pdhl',
#   'langgan',
#   'pakai',
#   'males',
#   'belanja',
#   'seru',
#   'promo',
#   'up',
#   'shopeepay',
#   'ribu',
#   'juta',
#   'hadiah',
#   'perak',
#   'gilir',
#   'orang',
#   'up',
#   'ribu',
#   'hadiah',
#   'voucher',
#   'emas',
#   'hadeuhh',
#   'fair'],
#  ['marketplace',
#   'kaku',
#   'atur',
#   'ubah',
#   'bikin',
#   'nyaman',
#   'jual',
#   'beli',
#   'kesini',
#   'ribet',
#   'sombong',
#   'maaf',
#   'berat',
#   'uninstall',
#   'makan',
#   'tu',
#   'atur',
#   'kamu'],
#  ['cod', 'cod', 'baku', 'hantam'],
#  ['bertanya', 'dowlod', 'nii'],
#  ['agen', 'call', 'center'],
#  ['tipu', 'aplikasi', 'yes', 'do', 'najis'],
#  ['sabar', 'matket', 'place', 'ribet', 'ribet', 'percaya'],
#  ['sen', 'paket', 'kont'],
#  ['maf',
#   'dowlod',
#   'aplikasi',
#   'garagara',
#   'misi',
#   'penhasil',
#   'saldo',
#   'andai',
#   'aduh',
#   'malas',
#   'dowlod'],
#  ['unduh', 'unduh', 'hidup', 'data', 'seluler', 'unduh', 'hapus'],
#  ['aplikasi',
#   'sengaja',
#   'hapus',
#   'unduh',
#   'lagi',
#   'gagal',
#   'terus',
#   'gmn',
#   'tolong',
#   'solusi',
#   'bayar',
#   'bayar',
#   'later'],
#  ['ongkir',
#   'gede',
#   'beli',
#   'barang',
#   'diskon',
#   'ongkir',
#   'nama',
#   'ongkir',
#   'barang',
#   'lebih baik',
#   'belah'],
#  ['bela',
#   'beli',
#   'wkwk',
#   'sayang',
#   'kaya',
#   'belah',
#   'prioritas',
#   'beli',
#   'tahu',
#   'beli',
#   'raja',
#   'layan',
#   'komplain',
#   'shope',
#   'banyak',
#   'alesan',
#   'gilir',
#   'ajak',
#   'debat',
#   'skak',
#   'ehh',
#   'cht',
#   'wkwkwkkw'],
#  ['jatuh',
#   'tempo',
#   'telpon',
#   'bayar',
#   'jam',
#   'bayar',
#   'bayar',
#   'apaaa',
#   'kesini',
#   'galogis',
#   'gaaakan',
#   'pakai',
#   'gituan',
#   'ribet'],
#  ['aju', 'paylater', 'tolak', 'loyal', 'aplikasi'],
#  ['voucher', 'gratis', 'ongkir', 'dipake', 'kntl'],
#  ['bayar',
#   'tagih',
#   'suruh',
#   'tunggu',
#   'proses',
#   'dana',
#   'salah',
#   'suruh',
#   'tunggu',
#   'dana'],
#  ['saldo',
#   'dana',
#   'beku',
#   'yabg',
#   'rp',
#   'ribu',
#   'tolong',
#   'akun',
#   'lapor',
#   'polisi',
#   'tolong',
#   'kirim',
#   'pesan',
#   'eamil',
#   'stolong',
#   'cepat',
#   'uang',
#   'tarik',
#   'pas',
#   'uang',
#   'beku',
#   'pas',
#   'beku',
#   'uang',
#   'pakai',
#   'butuh',
#   'gajelas'],
#  ['kesal', 'iklan'],
#  ['emangggg', 'tooopppp', 'margotop'],
#  ['order', 'batal', 'sistem'],
#  ['setia',
#   'aplikasi',
#   'aplikasi',
#   'banyak',
#   'mslah',
#   'lot',
#   'error',
#   'alih',
#   'kta',
#   'aplikasi',
#   'baca',
#   'ulas',
#   'tntg',
#   'males',
#   'untuk',
#   'install',
#   'hapus',
#   'sja'],
#  ['aplikasi',
#   'sampah',
#   'nyusahin',
#   'ribet',
#   'bget',
#   'promo',
#   'ikln',
#   'sesuai',
#   'pulsa',
#   'data',
#   'mahal',
#   'asliny'],
#  ['aplikasi', 'lot', 'berat', 'desain', 'ribet', 'beda', 'simpel', 'ringan'],
#  ['aplikasi', 'bgst', 'palir', 'tukang', 'ulah', 'babulu'],
#  ['goyang', 'knph', 'yh', 'klik', 'muncul'],
#  ['bikin', 'akun', 'username', 'salah', 'benar', 'username'],
#  ['kayak', 'siput'],
#  ['ongkir', 'mahal', 'barang', 'mahal', 'belah'],
#  ['saldo', 'juta', 'hangus'],
#  ['hoax', 'habisin', 'paket', 'data'],
#  ['bisa', 'diundh'],
#  ['iklan', 'muncul'],
#  ['kode', 'otp', 'order', 'order', 'verifikasi', 'no', 'telpon'],
#  ['sama', 'iklan'],
#  ['sekar',
#   'seringkali',
#   'belanja',
#   'reward',
#   'gold',
#   'aktif',
#   'shopeepaylater',
#   'mesti',
#   'suruh',
#   'topup',
#   'lagi',
#   'beribet',
#   'konfirmasi'],
#  ['males', 'iklan', 'melulu'],
#  ['maaf',
#   'kirim',
#   'nama',
#   'hj',
#   'leni',
#   'kebeneran',
#   'sen',
#   'aneh',
#   'yahhh',
#   'nmer',
#   'handphone',
#   'nmer',
#   'tapi',
#   'nama',
#   'alamat',
#   'persis',
#   'tapi',
#   'pribadi',
#   'kirim',
#   'misterius',
#   'sya',
#   'bayar',
#   'pdhl',
#   'sen',
#   'diambio',
#   'bayar',
#   'kasi',
#   'kulir',
#   'nyaaaa'],
#  ['sen',
#   'apa',
#   'paket',
#   'dateng',
#   'rumah',
#   'adek',
#   'tindaktegas',
#   'jual',
#   'nakal'],
#  ['masukkan',
#   'kode',
#   'verifikasi',
#   'angka',
#   'smsnya',
#   'masukkan',
#   'dftr',
#   'failed'],
#  ['pilih',
#   'halaman',
#   'search',
#   'produk',
#   'tekan',
#   'back',
#   'kemarin',
#   'tombol',
#   'pojok',
#   'kanan',
#   'versi',
#   'akmask',
#   'mobile',
#   'pakai',
#   'wifi',
#   'sulit',
#   'koneksi',
#   'pakai',
#   'koneksi',
#   'data',
#   'lancar',
#   'tolong',
#   'tim'],
#  ['voucher', 'gratis', 'ongkir', 'tapi', 'pke', 'hedehh'],
#  ['maaf',
#   'jatuh',
#   'aplikasi',
#   'beritahu',
#   'admin',
#   'undi',
#   'hadiah',
#   'malah',
#   'korban',
#   'tipu',
#   'bnyak',
#   'ber',
#   'nama',
#   'jebak'],
#  ['eta', 'da'],
#  ['biaya', 'admin', 'mahal', 'jual', 'raih', 'untung', 'star', 'seller'],
#  ['up', 'dana', 'saldo', 'pindah', 'dompet', 'saldo', 'dompet', 'beku'],
#  ['tolong',
#   'tingkat',
#   'kait',
#   'proses',
#   'aju',
#   'food',
#   'proses',
#   'makan',
#   'optimal',
#   'kait',
#   'makan',
#   'barang'],
#  ['kaya',
#   'harga',
#   'diskon',
#   'pas',
#   'harga',
#   'diskon',
#   'harga',
#   'diskon',
#   'cek',
#   'out',
#   'harga',
#   'diskon',
#   'keranjang',
#   'harga',
#   'diskon',
#   'harga',
#   'beda',
#   'keranjang',
#   'keranjang',
#   'harga',
#   'asli',
#   'coret',
#   'cek',
#   'out',
#   'hargane',
#   'utuh',
#   'diskon',
#   'malesin'],
#  ['mem', 'beli', 'akun', 'bayar', 'beda', 'gambar', 'toko'],
#  ['rate', 'sesuai', 'alam', 'beli', 'sembunyi', 'seller', 'tanggung'],
#  ['unduh', 'pulsa', 'ribu', 'promo', 'dikit', 'pulsa'],
#  ['susa', 'membebahari'],
#  ['fitur', 'pilih', 'jasa', 'kirim'],
#  ['barang', 'akun', 'blok'],
#  ['kendala',
#   'spaylater',
#   'hubung',
#   'agen',
#   'bantu',
#   'lunas',
#   'cicil',
#   'sisa',
#   'sukses'],
#  ['aplikasi', 'belanja', 'akurat', 'percaya'],
#  ['kirim', 'tera', 'maksimal', 'tanggal', 'kirim', 'tanggal'],
#  ['ulas',
#   'bintang',
#   'ikutin',
#   'karnakan',
#   'aplikasi',
#   'bangkrut',
#   'layan',
#   'langgan',
#   'ulas',
#   'ulas',
#   'mudah',
#   'retas',
#   'beli',
#   'topeng',
#   'mahal',
#   'ongkir',
#   'habis',
#   'topeng'],
#  ['daftar', 'belanja', 'bisaaa'],
#  ['konyol',
#   'beli',
#   'jam',
#   'salah',
#   'klik',
#   'barang',
#   'barang',
#   'duit',
#   'hangus',
#   'customer service',
#   'susah',
#   'hubung'],
#  ['ongkos', 'dilembalikan'],
#  ['packing',
#   'nggk',
#   'tambahin',
#   'bubble',
#   'wrap',
#   'beli',
#   'sepatu',
#   'boxnya',
#   'penyok',
#   'lebih baik',
#   'pilih',
#   'bubble',
#   'wrap',
#   'bayar',
#   'ppa',
#   'penyok',
#   'harga'],
#  ['belanja', 'stock', 'kosong'],
#  ['aplikasi', 'rena', 'voucher', 'alas', 'pesan'],
#  ['aplikasi', 'jellllekkkkk', 'akun', 'member', 'daftar', 'spaylater', 'akun'],
#  ['aplikasi', 'lambat'],
#  ['maaf',
#   'unduh',
#   'ulang',
#   'verifikasi',
#   'emain',
#   'no',
#   'tlf',
#   'pakek',
#   'hilang',
#   'aktif',
#   'cek',
#   'aplikasi',
#   'mytelkomsel',
#   'aktif',
#   'no',
#   'tlf',
#   'november',
#   'tolong',
#   'akal'],
#  ['balance', 'belanja', 'susah', 'dirarik'],
#  ['belanja',
#   'simpan',
#   'troli',
#   'bayar',
#   'jarak',
#   'update',
#   'updatenya',
#   'kelar',
#   'aplikasi',
#   'pakai',
#   'belanja',
#   'saldo',
#   'dana',
#   'bayar'],
#  ['nyaman',
#   'pakai',
#   'ehk',
#   'kesal',
#   'pesan',
#   'bareng',
#   'brngnya',
#   'slh',
#   'ktnya',
#   'tanggung',
#   'ehk',
#   'ngilang',
#   'tanggung'],
#  ['aplikasi', 'benar', 'njir'],
#  ['shopi', 'cod'],
#  ['sekian',
#   'pakai',
#   'ken',
#   'pakai',
#   'gegara',
#   'bosen',
#   'aplikasi',
#   'belah',
#   'pas',
#   'login',
#   'nomor',
#   'nonaktif',
#   'tolong',
#   'mudah',
#   'daftar',
#   'pakai',
#   'mail',
#   'konfirmasi',
#   'pilih',
#   'opsi',
#   'pakai',
#   'verifikasi',
#   'mail',
#   'google',
#   'account',
#   'seperti',
#   'gin',
#   'bingung',
#   'alhasil',
#   'bikin',
#   'account',
#   'males'],
#  ['lambat', 'lemod'],
#  ['order',
#   'barang',
#   'bom',
#   'sampai',
#   'samday',
#   'hilang',
#   'males',
#   'belanja',
#   'pagi',
#   'order',
#   'sore',
#   'sampai',
#   'pagi',
#   'order',
#   'bom',
#   'sampai'],
#  ['voucher', 'manipulasi', 'biji'],
#  ['super',
#   'lambat',
#   'jember',
#   'magelang',
#   'toko',
#   'cileduk',
#   'magelang',
#   'kapok',
#   'belanja'],
#  ['sayang',
#   'fitur',
#   'paylater',
#   'beli',
#   'barang',
#   'pulsa',
#   'tagih',
#   'listrik',
#   'pdam',
#   'tv',
#   'kabel'],
#  ['akun',
#   'block',
#   'ban',
#   'kah',
#   'akun',
#   'hilang',
#   'saldo',
#   'shoppe',
#   'hilang',
#   'beli',
#   'barang',
#   'impi',
#   'tua',
#   'smartphone'],
#  ['bintang',
#   'menu',
#   'bayar',
#   'later',
#   'kredit',
#   'aplikasi',
#   'shopeeku',
#   'smtra',
#   'orang',
#   'paylater',
#   'solusi',
#   'ditambahin',
#   'belanja',
#   'bayar',
#   'laternya',
#   'tolong',
#   'jangan',
#   'beda',
#   'langgan',
#   'juga',
#   'sring',
#   'mesan',
#   'smtr',
#   'teman',
#   'mesan',
#   'bayar',
#   'later'],
#  ['anjink', 'aplikasi', 'iklan', 'ganggu', 'tahu'],
#  ['ongkir', 'horor', 'iklan', 'bebas', 'ongkir', 'ongkir', 'keri'],
#  ['flassale', 'beli', 'reload', 'taikkkkkkkkkkkk'],
#  ['toko',
#   'filter',
#   'toko',
#   'toko',
#   'nakal',
#   'beli',
#   'mobil',
#   'remot',
#   'gantung'],
#  ['unduh', 'gagal', 'unduh', 'huh', 'belanja'],
#  ['dana',
#   'smp',
#   'skrng',
#   'transfer',
#   'rekening',
#   'telfon',
#   'customer',
#   'service',
#   'selalu',
#   'suruh',
#   'tunggu',
#   'sdah',
#   'hmpir',
#   'trnsferan',
#   'rekening',
#   'nunngu'],
#  ['belanja',
#   'pesan',
#   'sepatu',
#   'baju',
#   'aju',
#   'dana',
#   'barang',
#   'pesan',
#   'aju',
#   'dana',
#   'tingkat',
#   'kualitas',
#   'layan',
#   'hack'],
#  ['basi',
#   'keluarga',
#   'akun',
#   'promo',
#   'alas',
#   'alamat',
#   'keluarga',
#   'rumah',
#   'alamat',
#   'pakai',
#   'alamat',
#   'tetangga',
#   'pakai',
#   'bacot'],
#  ['kuis', 'aplikasi', 'ram', 'ruang', 'hadiah', 'capek'],
#  ['maaf', 'lebe', 'ongkir'],
#  ['ken',
#   'login',
#   'akun',
#   'susah',
#   'tunggu',
#   'sms',
#   'smsnya',
#   'bangke',
#   'capek',
#   'nungguin'],
#  ['tolong', 'bebas', 'milih', 'ekspedisi', 'jnt'],
#  ['kolom', 'cari', 'ngebug', 'melulu', 'anjg'],
#  ['tolong',
#   'kirim',
#   'layan',
#   'express',
#   'kur',
#   'barang',
#   'asing',
#   'konfirmasi',
#   'barang',
#   'elektronik',
#   'harga'],
#  ['shopeepay',
#   'emas',
#   'kirim',
#   'minimal',
#   'minggu',
#   'aneh',
#   'pakai',
#   'cod',
#   'why',
#   'perbaikin',
#   'tolong',
#   'reseller',
#   'tipu',
#   'tindak',
#   'bnyak',
#   'korban',
#   'beli'],
#  ['versi',
#   'ringan',
#   'update',
#   'versi',
#   'bin',
#   'lot',
#   'pakai',
#   'internet',
#   'cepat',
#   'mbps',
#   'bayangin',
#   'cepat',
#   'aplikasi',
#   'belanja',
#   'konten',
#   'nongol',
#   'alias',
#   'susah',
#   'update',
#   'versi',
#   'sekarang',
#   'auto',
#   'aplikasi',
#   'kaliyan',
#   'yuk',
#   'komentar',
#   'aplikasi'],
#  ['kurir', 'kirim', 'timika', 'papua', 'belanja', 'uninstal'],
#  ['barang', 'sampah'],
#  ['tolong',
#   'verifikasi',
#   'ganti',
#   'akun',
#   'mudah',
#   'akun',
#   'email',
#   'no',
#   'handphone',
#   'ganti',
#   'akun',
#   'double',
#   'akun',
#   'hadehh'],
#  ['seler',
#   'tolong',
#   'atur',
#   'ketat',
#   'order',
#   'barang',
#   'transfer',
#   'barang',
#   'jalan',
#   'cancel',
#   'uang',
#   'jangka',
#   'sampai',
#   'minggu'],
#  ['maap', 'sekarng', 'aplikasi', 'yoko', 'tida', 'mwnanggapi'],
#  ['devolepor',
#   'mesti',
#   'tipu',
#   'cashback',
#   'gratis',
#   'ongkir',
#   'iklan',
#   'tv',
#   'gratis',
#   'ongkir',
#   'minimum',
#   'belanja',
#   'belanja'],
#  ['easi',
#   'soping',
#   'pt',
#   'karisma',
#   'bahana',
#   'gemilang',
#   'tipu',
#   'suruh',
#   'mutar',
#   'lotery',
#   'lucki',
#   'miliader',
#   'rodah',
#   'henti',
#   'angka',
#   'miliard',
#   'hasil',
#   'rezeki',
#   'bukti',
#   'hoaks',
#   'tahu',
#   'almat',
#   'easi',
#   'soping',
#   'pulsa',
#   'informasi',
#   'hitung',
#   'buta',
#   'hukum',
#   'hak',
#   'tuhan',
#   'yesus',
#   'kutuk',
#   'cilakalah',
#   'binasa',
#   'kru',
#   'easy',
#   'soping',
#   'musiba',
#   'tabrak',
#   'maut',
#   'do',
#   'putra',
#   'flores',
#   'korban',
#   'tipu',
#   'amin',
#   'easi',
#   'soping',
#   'utang',
#   'timor'],
#  ['kode', 'otp', 'kirim', 'checkout'],
#  ['waaah',
#   'shoppi',
#   'benar',
#   'kirim',
#   'srkng',
#   'kesel',
#   'tunggu',
#   'jakarta',
#   'palembang',
#   'kemarin',
#   'kadang',
#   'sampai',
#   'sik',
#   'jasa',
#   'kirim',
#   'hadeh',
#   'langgan',
#   'pindah',
#   'aplikasi',
#   'tolong',
#   'seperti',
#   'jasa',
#   'kirim',
#   'yok',
#   'yok',
#   'seperti',
#   'jasa',
#   'kirim'],
#  ['bikin', 'emosi', 'tombal', 'batal', 'transaksi'],
#  ['pelit',
#   'gara',
#   'score',
#   'game',
#   'menu',
#   'bilang',
#   'main',
#   'normal',
#   'normal',
#   'ranking',
#   'voucher'],
#  ['kirim', 'lambattt', 'sen'],
#  ['platform', 'jaz'],
#  ['tunggu', 'jam', 'terintal', 'intal'],
#  ['tipu',
#   'hadiah',
#   'google',
#   'chrom',
#   'ujung',
#   'sruh',
#   'donlot',
#   'aplikasi',
#   'tapi',
#   'hadiah',
#   'bisa',
#   'ambil',
#   'dasar',
#   'tukang',
#   'tipu',
#   'pngen',
#   'bnyak',
#   'pngguna',
#   'tapi',
#   'pakai',
#   'mutu'],
#  ['aplikasi', 'nyaa', 'bagetttt', 'boooooggg'],
#  ['aplikasi', 'lihah', 'kopon', 'lodingnya'],
#  ['sesuai',
#   'iklan',
#   'iklan',
#   'promo',
#   'diskon',
#   'bebas',
#   'ongkir',
#   'promo',
#   'bayar',
#   'cod',
#   'bayar',
#   'bikin'],
#  ['kemarin',
#   'kasi',
#   'bintang',
#   'skarang',
#   'ganti',
#   'respon',
#   'pas',
#   'dana',
#   'barang',
#   'kirim',
#   'kasi',
#   'kabar',
#   'dana',
#   'jual',
#   'barang',
#   'uang',
#   'kontak',
#   'jual',
#   'hati',
#   'kirim'],
#  ['hancur',
#   'tokopoint',
#   'daerah',
#   'pakai',
#   'kupon',
#   'diskon',
#   'batal',
#   'transfer',
#   'alas',
#   'langgar',
#   'klu',
#   'jangan',
#   'kupon',
#   'diskon',
#   'pdahal',
#   'hancur',
#   'updatenya',
#   'maaf',
#   'uninstal',
#   'pindah',
#   'toko',
#   'belah',
#   'lebih baik'],
#  ['uninstal', 'dominan', 'toko', 'orange'],
#  ['unduh', 'kenapa', 'pas', 'taut', 'suruh', 'dwonload'],
#  ['layan',
#   'tunggu',
#   'pesan',
#   'tampa',
#   'update',
#   'kirim',
#   'batal',
#   'kirim',
#   'tampa',
#   'terang'],
#  ['bodo', 'aplikasi', 'gratis', 'ongkir', 'bayar', 'ongkir', 'mahal'],
#  ['tol', 'aplikasi'],
#  ['update',
#   'aplikasi',
#   'selalu',
#   'ngeblank',
#   'ngetik',
#   'cari',
#   'barang',
#   'susah',
#   'brng',
#   'keranjang',
#   'bisa',
#   'hapus',
#   'msih',
#   'banyak',
#   'setelah',
#   'update',
#   'perbaikin',
#   'bug'],
#  ['limit', 'spaylater', 'bayar', 'jatuh', 'tempo'],
#  ['mahal', 'beda', 'selisih', 'bangetttttt'],
#  ['maaf', 'transaksi', 'shopeepay', 'shopeepay', 'later', 'limit'],
#  ['minimal',
#   'belanja',
#   'ribu',
#   'free',
#   'ongkir',
#   'kaget',
#   'belanja',
#   'butuh',
#   'rumah',
#   'ongkir',
#   'langit',
#   'alih',
#   'pindah',
#   'belanja',
#   'toko',
#   'belah',
#   'free',
#   'ongkir'],
#  ['sembako', 'kupon', 'utuh'],
#  ['beli', 'paket', 'sertifikat', 'dashboard'],
#  ['kemarin',
#   'pesan',
#   'pesan',
#   'batal',
#   'dana',
#   'transfer',
#   'untuk',
#   'dana',
#   'tolong',
#   'rekening',
#   'akun',
#   'nama',
#   'masukkan',
#   'rekening',
#   'seller',
#   'aktif'],
#  ['dana',
#   'pesan',
#   'batal',
#   'dana',
#   'rekening',
#   'perhati',
#   'langgan',
#   'sulit',
#   'uang',
#   'hak',
#   'tolong',
#   'dana'],
#  ['deret', 'ssrx', 'det', 'er'],
#  ['mecahin',
#   'telur',
#   'update',
#   'koin',
#   'update',
#   'gratis',
#   'ongkir',
#   'update',
#   'update',
#   'padal',
#   'update',
#   'tetep',
#   'update',
#   'kuota',
#   'habis',
#   'update',
#   'aplikasi',
#   'ginian',
#   'tolong',
#   'perintah',
#   'update',
#   'rang'],
#  ['jgan',
#   'belanja',
#   'barang',
#   'pesan',
#   'barang',
#   'ngk',
#   'sesuai',
#   'sya',
#   'mesan',
#   'baju',
#   'celana',
#   'bokser',
#   'pendek'],
#  ['beri',
#   'kupon',
#   'diskon',
#   'pas',
#   'belanja',
#   'pesan',
#   'batal',
#   'otomatis',
#   'kupon',
#   'pakai',
#   'lagi',
#   'kupon',
#   'diskon',
#   'rugi'],
#  ['tracking',
#   'paket',
#   'jalan',
#   'web',
#   'kurir',
#   'cek',
#   'jalan',
#   'asa',
#   'belanja',
#   'gin'],
#  ['aplikasi',
#   'go',
#   'internasional',
#   'urus',
#   'tagih',
#   'spaylatter',
#   'spinjam',
#   'nada',
#   'bicara',
#   'pesan',
#   'ngalahin',
#   'rentenir',
#   'mkn',
#   'bangku',
#   'sekolah',
#   'bunga',
#   'gede',
#   'dibyr',
#   'cicil',
#   'masih',
#   'orang',
#   'peres',
#   'layak',
#   'hutang',
#   'ratus',
#   'juta',
#   'miris',
#   'gaji',
#   'krywn',
#   'hasil',
#   'paksa',
#   'pinjam',
#   'ksh',
#   'kenal',
#   'lagi',
#   'zaman',
#   'lagi',
#   'covid',
#   'tegang',
#   'aplikasi',
#   'sblh',
#   'move',
#   'on'],
#  ['aplikasi', 'mahal', 'ongkir', 'harga', 'normal'],
#  ['lot', 'loading', 'terusssss'],
#  ['beli',
#   'dishopee',
#   'jual',
#   'tanggung',
#   'barang',
#   'kirim',
#   'salah',
#   'dana',
#   'barang'],
#  ['iklan', 'paksa', 'resah', 'hadeh'],
#  ['bayar', 'pakai', 'dana', 'unistal'],
#  ['iklanya', 'menggangu'],
#  ['mh', 'transaksi', 'ny', 'eror', 'terusssssss'],
#  ['akun',
#   'non',
#   'aktif',
#   'beku',
#   'langgar',
#   'atur',
#   'aplikasi',
#   'banned',
#   'kominfo',
#   'beli',
#   'latih',
#   'aplikasi',
#   'lulus',
#   'sertifikat',
#   'skill',
#   'academy',
#   'lapor',
#   'instansi',
#   'taung',
#   'bekerjasama',
#   'aplikasi',
#   'sertifikat',
#   'latih',
#   'muncul',
#   'dashboard',
#   'akun',
#   'tipu',
#   'publik'],
#  ['penguna', 'ambil', 'rp', 'kocak'],
#  ['jelekkk',
#   'bangett',
#   'voucher',
#   'beli',
#   'kaos',
#   'toko',
#   'dibatalinn',
#   'uang',
#   'balik',
#   'kejebakk',
#   'saldo',
#   'ambil',
#   'gabisaa',
#   'pakai',
#   'dana',
#   'pakeovo',
#   'gabisaa',
#   'gabanyakk',
#   'namnaya',
#   'uang'],
#  ['daftar', 'kode', 'frivikasi', 'muncul', 'muncul'],
#  ['aplikasi',
#   'bohong',
#   'pakai',
#   'sopepay',
#   'susah',
#   'kode',
#   'otp',
#   'kirim',
#   'bonuss',
#   'akun',
#   'saldo',
#   'ribu',
#   'tipu'],
#  ['habisin', 'kuota', 'update', 'profil', 'sampai', 'kiamat'],
#  ['pesan',
#   'cancel',
#   'kirim',
#   'kirim',
#   'gmn',
#   'jual',
#   'verifikasi',
#   'sopenya',
#   'solusi',
#   'gmn'],
#  ['limit', 'shopeepaylater', 'rp', 'cicil', 'lunas'],
#  ['spaylater', 'diaktivasi', 'gagal'],
#  ['kirain',
#   'harga',
#   'murah',
#   'wkwkwkwk',
#   'diskon',
#   'pelit',
#   'maaf',
#   'auto',
#   'uninstal'],
#  ['cashback',
#   'bukareksa',
#   'promo',
#   'reksajul',
#   'reksajul',
#   'reksaaug',
#   'reksaaug',
#   'hitung',
#   'cashback',
#   'komplain',
#   'ulang',
#   'tunggu',
#   'seninggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'suruh',
#   'tunggu',
#   'minggu',
#   'tahan',
#   'dana',
#   'jual'],
#  ['update', 'susah'],
#  ['barang', 'manaaaaa'],
#  ['rugi', 'beli', 'realpeack'],
#  ['aplikasi', 'nyampah'],
#  ['terimah', 'pesan', 'barangx', 'cepat', 'kirim'],
#  ['lindung',
#   'konsumen',
#   'tipu',
#   'seller',
#   'kayak',
#   'barang',
#   'butuh',
#   'minggu'],
#  ['akun',
#   'transaksi',
#   'kemarin',
#   'beli',
#   'promo',
#   'klaim',
#   'langgar',
#   'pdhal',
#   'transaksi',
#   'aju',
#   'kpan',
#   'langgar',
#   'internal',
#   'customer',
#   'bukti'],
#  ['kesini', 'aplikasi', 'kok', 'bayar', 'eror', 'gakda', 'solusi', 'aplikasi'],
#  ['update',
#   'versi',
#   'hubung',
#   'ulang',
#   'kolom',
#   'feed',
#   'tolong',
#   'nyaman',
#   'handphone',
#   'samsung',
#   'profesional'],
#  ['tarik', 'dana'],
#  ['aplikasi', 'layan'],
#  ['bnayak', 'update'],
#  ['sistem', 'error'],
#  ['bertanya',
#   'event',
#   'paket',
#   'data',
#   'pulsa',
#   'perak',
#   'tu',
#   'boongan',
#   'ubah',
#   'bintang',
#   'kecuali',
#   'please'],
#  ['sanggat', 'kecewaa'],
#  ['aju', 'hapus', 'akun', 'ribet'],
#  ['rugi', 'tolong', 'uang'],
#  ['krkurangan',
#   'transaksi',
#   'aplikasi',
#   'tampil',
#   'wahhh',
#   'sistem',
#   'transaksi',
#   'normal'],
#  ['barang', 'rusak', 'jual', 'gemanay'],
#  ['uda', 'bayar', 'bom', 'sampai'],
#  ['transfer', 'airpayinternal', 'beli', 'barang', 'batal', 'dana', 'tidak'],
#  ['jangan',
#   'unduh',
#   'bnyak',
#   'pnipuan',
#   'jual',
#   'buukn',
#   'brang',
#   'asli',
#   'rport',
#   'smaa',
#   'bnyak',
#   'unsur',
#   'penipuann'],
#  ['transaksi', 'batal', 'aplikasi', 'jelasssss'],
#  ['belanja',
#   'gilir',
#   'belanja',
#   'poin',
#   'ktanya',
#   'cod',
#   'isi',
#   'pdhl',
#   'pakai',
#   'ongkir',
#   'bebas',
#   'ongkir',
#   'moduss',
#   'kopeeet'],
#  ['saldo', 'hasil', 'refund', 'belanja'],
#  ['aplikasi', 'bohong', 'diskon', 'pas', 'tunggu', 'tunggu', 'unduh'],
#  ['ribet',
#   'jual',
#   'cair',
#   'dana',
#   'beli',
#   'sesuai',
#   'terang',
#   'terang',
#   'sampai',
#   'oktober',
#   'konfirmasi',
#   'beli',
#   'dana',
#   'otomatis',
#   'jual',
#   'oktober',
#   'dana',
#   'tahan',
#   'terang',
#   'bikin',
#   'jual',
#   'harap'],
#  ['kaya', 'massa', 'pesan', 'barang'],
#  ['komentar',
#   'hapus',
#   'nanti',
#   'ketik',
#   'pergi',
#   'hibur',
#   'nanti',
#   'ketik',
#   'komen',
#   'hapus',
#   'shoope',
#   'asw',
#   'salin',
#   'komen',
#   'hapus',
#   'tinggal',
#   'paste',
#   'dikomen',
#   'sembuyikan',
#   'komen',
#   'hapus',
#   'komen',
#   'ketik',
#   'salin',
#   'komen',
#   'hapus',
#   'shoope',
#   'update',
#   'macet',
#   'pantang',
#   'nyerah',
#   'ubah',
#   'santet',
#   'balesanya',
#   'santet'],
#  ['aplikasi', 'unduh'],
#  ['ongkir', 'mahal', 'tolong', 'murahin', 'kayak', 'pandemi', 'uang'],
#  ['komplain', 'ribet'],
#  ['freeong',
#   'belanja',
#   'ribu',
#   'freeong',
#   'belanja',
#   'freeong',
#   'pindah',
#   'market',
#   'place'],
#  ['belanja',
#   'beli',
#   'jual',
#   'biaya',
#   'adminnya',
#   'toko',
#   'dibanned',
#   'pajak',
#   'negara',
#   'ken',
#   'untung',
#   'buntung'],
#  ['ambisi', 'unt', 'unduh', 'iklan', 'muntah', 'tarik', 'belanja', 'turun'],
#  ['bayar', 'sayang', 'bayar'],
#  ['cuman', 'aplikasi', 'gilir', 'girim'],
#  ['aplikasi', 'rancang', 'tipu'],
#  ['aplikasi', 'maksa', 'ta', 'ekkkkkkkkkkkk', 'anjinkkkkkkkkk'],
#  ['iklan', 'asli', 'jlek', 'tipu', 'belanja', 'batal', 'otomatis'],
#  ['update', 'ui', 'user', 'friendly'],
#  ['sesuai', 'iklan'],
#  ['reses', 'iklan', 'bikin', 'risih', 'unduh'],
#  ['shoope',
#   'iklan',
#   'spam',
#   'melulu',
#   'renti',
#   'seperti',
#   'lagi',
#   'main',
#   'ml',
#   'iklan',
#   'shoope'],
#  ['kesini', 'lambat', 'njir', 'pakai', 'wifi', 'ram'],
#  ['iklan', 'ngabisin', 'kuota'],
#  ['sponsor', 'broser', 'unduh', 'aplikasi', 'melulu', 'susah', 'pusing'],
#  ['tiktok',
#   'iklan',
#   'toko',
#   'terus',
#   'diam',
#   'jan',
#   'ganggu',
#   'seru',
#   'nonton',
#   'tiktokk'],
#  ['update', 'koneksi', 'bikin', 'kesel'],
#  ['aju', 'tolak', 'spaylaternya', 'hadeh', 'bintang', 'atulah'],
#  ['ongkos',
#   'kirim',
#   'ribu',
#   'voucernya',
#   'sus',
#   'sope',
#   'bayar',
#   'cod',
#   'voucer',
#   'gratis',
#   'ongkir'],
#  ['voucher',
#   'gratis',
#   'ongkir',
#   'beli',
#   'kasi',
#   'voucher',
#   'sisa',
#   'rebut',
#   'icon',
#   'free',
#   'ogkir',
#   'hilang'],
#  ['aplikasi',
#   'nyampe',
#   'tangal',
#   'nyampenya',
#   'tangal',
#   'aplikasi',
#   'bohong',
#   'install',
#   'aplikasi',
#   'dasar',
#   'aplikasi',
#   'penbohong'],
#  ['beli',
#   'case',
#   'handphone',
#   'negeri',
#   'cari',
#   'produk',
#   'negeri',
#   'cari',
#   'case',
#   'negeri',
#   'negeri',
#   'gmn',
#   'solusi'],
#  ['bayar', 'suruh', 'tunggu', 'jam', 'jam', 'akun', 'blokirr', 'tanggung'],
#  ['susah', 'unduh'],
#  ['mengambil',
#   'gratis',
#   'ongkir',
#   'nominal',
#   'ongkir',
#   'ny',
#   'gede',
#   'sedih',
#   'kadang',
#   'barang',
#   'pes',
#   'mahal',
#   'ongkir'],
#  ['jual',
#   'ragu',
#   'waswas',
#   'sampai',
#   'opsi',
#   'pilih',
#   'asuransi',
#   'halaman',
#   'cek',
#   'out',
#   'produk',
#   'kalah',
#   'toko',
#   'online',
#   'belah',
#   'opsi',
#   'asuransi',
#   'pas',
#   'kantor',
#   'ribet',
#   'karyawan',
#   'admin',
#   'paham',
#   'menbahkan',
#   'asuransi',
#   'profesional',
#   'kacau'],
#  ['jual', 'buku', 'baja', 'liar', 'belanja', 'nyaman'],
#  ['kesini', 'pas', 'unduh', 'video', 'gugel'],
#  ['beli',
#   'produk',
#   'pas',
#   'gilir',
#   'beli',
#   'kamera',
#   'oppo',
#   'nyala',
#   'tolong',
#   'tindak',
#   'lanjutin',
#   'jual'],
#  ['dagang',
#   'nakal',
#   'daripahda',
#   'bikin',
#   'promo',
#   'tv',
#   'lebih baik',
#   'aplikasi'],
#  ['respon',
#   'tolong',
#   'toko',
#   'toko',
#   'amanah',
#   'jual',
#   'respon',
#   'makan',
#   'pergi',
#   'hilang',
#   'konsumen',
#   'keluh',
#   'diam'],
#  ['iklan',
#   'lebih baik',
#   'pas',
#   'nonton',
#   'youtube',
#   'nonton',
#   'halaman',
#   'utama',
#   'layar',
#   'tolong',
#   'iklan'],
#  ['beli',
#   'tas',
#   'gunung',
#   'minggu',
#   'sepatu',
#   'roda',
#   'tipu',
#   'amanah',
#   'pesan',
#   'tas',
#   'kamu',
#   'sepatu',
#   'roda',
#   'gin',
#   'hapus',
#   'aplikashi',
#   'amanah'],
#  ['plis',
#   'batal',
#   'pesan',
#   'ubah',
#   'pikir',
#   'kirimm',
#   'allah',
#   'tolong',
#   'rugi',
#   'bangett'],
#  ['update', 'melulu'],
#  ['from', 'zero', 'hero'],
#  ['ngk', 'gratis', 'ongir'],
#  ['customer',
#   'service',
#   'layan',
#   'nelpon',
#   'butuh',
#   'customer service',
#   'sopan',
#   'santun',
#   'mati',
#   'panggil',
#   'pulsa'],
#  ['aman',
#   'aman',
#   'gilir',
#   'kirim',
#   'barang',
#   'tim',
#   'ehh',
#   'hasil',
#   'nol',
#   'konfirmasi',
#   'bukti',
#   'adu',
#   'tim',
#   'jangan',
#   'harap'],
#  ['staff', 'tolong', 'profesional', 'beda', 'gratis', 'ongkir', 'sedih'],
#  ['ongkir', 'mahal'],
#  ['belanja',
#   'komplain',
#   'sanggup',
#   'sarat',
#   'berat',
#   'bangat',
#   'suruh',
#   'bikin',
#   'video',
#   'youtuber',
#   'nomor',
#   'seri',
#   'bukti',
#   'foto',
#   'lanjur',
#   'paket',
#   'wuish',
#   'nang',
#   'beli'],
#  ['shope', 'bayar', 'qd', 'blokir', 'salah'],
#  ['muncul', 'iklan', 'internet', 'otomatis', 'kesini', 'orang', 'maksa'],
#  ['maaf', 'sen', 'apa', 'dateng', 'tolong'],
#  ['jangan', 'kirim', 'promo', 'handphone', 'tarik', 'ganggu'],
#  ['erti', 'beli', 'latih', 'kartu', 'gagal', 'tipu', 'kayak', 'gin'],
#  ['jan', 'maksa', 'install'],
#  ['mntep', 'shopefood'],
#  ['cobakalau',
#   'promosi',
#   'tipu',
#   'gratis',
#   'ongkir',
#   'beli',
#   'barang',
#   'ongkir',
#   'gede',
#   'harga',
#   'barang'],
#  ['kesini', 'gara', 'google', 'crome', 'ribu'],
#  ['update', 'klik', 'toko'],
#  ['cerita', 'shopi', 'hoax'],
#  ['curang', 'event', 'event', 'sistem', 'talu', 'lot', 'sistem', 'jadul'],
#  ['kirim', 'pesan', 'kayak', 'buka', 'kirim', 'dikit', 'tinggal', 'buka'],
#  ['ualah', 'tahu', 'cod', 'biaya', 'nang', 'xixixixixididi'],
#  ['apdead', 'paylater'],
#  ['aplikasi',
#   'belanja',
#   'seller',
#   'blokir',
#   'toko',
#   'tanggung',
#   'rugi',
#   'beli'],
#  ['aplikasi', 'cuman', 'iklan', 'ganggu', 'anjeng'],
#  ['trooble', 'tuuuerruusss'],
#  ['berat',
#   'beli',
#   'setia',
#   'beli',
#   'barang',
#   'harga',
#   'juta',
#   'tipu',
#   'beli',
#   'ebook',
#   'tips',
#   'jitu',
#   'isi',
#   'screen',
#   'shot',
#   'kirim',
#   'biji',
#   'admin',
#   'tolak',
#   'adu',
#   'sungguh',
#   'menang',
#   'tipu',
#   'kayak',
#   'gin',
#   'lebih baik',
#   'unistall',
#   'jamin',
#   'aman',
#   'beli',
#   'tipu',
#   'bukalapa'],
#  ['tolong',
#   'aplikasi',
#   'muslim',
#   'profesional',
#   'solat',
#   'iklan',
#   'menganggu',
#   'muslim',
#   'profesional',
#   'tutup',
#   'aplikasi',
#   'kesel',
#   'maaf',
#   'ulas',
#   'salah',
#   'salah',
#   'seller',
#   'tanggung',
#   'tindak'],
#  ['benar',
#   'bikin',
#   'murka',
#   'pesan',
#   'sya',
#   'sesuai',
#   'chat',
#   'seller',
#   'tidak',
#   'etikad',
#   'baca',
#   'tolong',
#   'smpein',
#   'toko',
#   'ling',
#   'hong',
#   'jual',
#   'amanah'],
#  ['harga',
#   'dimainin',
#   'aplikasi',
#   'pilih',
#   'warna',
#   'size',
#   'harga',
#   'ubah',
#   'tertawa',
#   'capek',
#   'capek',
#   'milih',
#   'mlototin',
#   'order',
#   'harga',
#   'sesuai',
#   'tema',
#   'stop',
#   'gunain'],
#  ['aplikasi', 'aneh', 'barang', 'bayar', 'batal', 'aplikasi'],
#  ['susah', 'loadingnya'],
#  ['shope',
#   'plis',
#   'mengundng',
#   'teman',
#   'verif',
#   'ktp',
#   'teman',
#   'bom',
#   'bikin',
#   'ktf',
#   'macam',
#   'plis',
#   'rakyat',
#   'indonesia',
#   'even'],
#  ['daya', 'bayar', 'ngeblank'],
#  ['kada', 'baikk'],
#  ['akun',
#   'hack',
#   'atm',
#   'akun',
#   'pinjam',
#   'uang',
#   'jt',
#   'block',
#   'aplikasi',
#   'aman'],
#  ['masak',
#   'aju',
#   'spaylater',
#   'bayar',
#   'kartu',
#   'kredit',
#   'mengunakan',
#   'aplikasi',
#   'shoppee',
#   'lah',
#   'kartu',
#   'kredit',
#   'ngk',
#   'shopeepay',
#   'aneh',
#   'shoppe',
#   'limit',
#   'ngk'],
#  ['ribet', 'sen', 'gratis', 'ongkir'],
#  ['sesal', 'nang', 'akun', 'blok'],
#  ['sama',
#   'aplikasi',
#   'pilih',
#   'transaksi',
#   'batalakan',
#   'dn',
#   'belah',
#   'transaksi',
#   'sampai',
#   'tunggu',
#   'minggu',
#   'uang'],
#  ['sakit', 'killik', 'kirim', 'barang'],
#  ['hapus',
#   'aju',
#   'phaylater',
#   'tolak',
#   'muncul',
#   'tawar',
#   'phaylater',
#   'aju',
#   'tolak'],
#  ['maaf',
#   'pakai',
#   'aplikasi',
#   'ajh',
#   'gratis',
#   'ongkir',
#   'minggu',
#   'ganti',
#   'handphone',
#   'unduh',
#   'teman',
#   'kenapa',
#   'potong',
#   'ongkir'],
#  ['aplikasi', 'sempurna'],
#  ['sen',
#   'barang',
#   'dilazada',
#   'tahu',
#   'tahu',
#   'kurir',
#   'dateng',
#   'rumah',
#   'tas',
#   'slempang',
#   'bayar',
#   'sen',
#   'sen',
#   'dateng',
#   'gmn',
#   'hapus',
#   'akun'],
#  ['transaksi',
#   'batal',
#   'recommended',
#   'belanja',
#   'lebih baik',
#   'pakai',
#   'mudah',
#   'aman',
#   'ribet',
#   'iming',
#   'gratis',
#   'ongkir',
#   'tahu',
#   'fiktif',
#   'google',
#   'mereview',
#   'aplikasi',
#   'ngrugiin'],
#  ['kirim',
#   'lambattt',
#   'bngettt',
#   'proses',
#   'toko',
#   'belah',
#   'cepat',
#   'tolong',
#   'koreksi'],
#  ['aneh', 'transaksi', 'anggap', 'pesan', 'batal', 'alas', 'nila', 'fitnah'],
#  ['toko', 'ngentodddd'],
#  ['cepat',
#   'install',
#   'oo',
#   'penuh',
#   'lah',
#   'simpan',
#   'takbisa',
#   'ookesel',
#   'capek',
#   'huudan',
#   'baguss',
#   'oooooooooo'],
#  ['bangke', 'beli', 'paket', 'data', 'suruh', 'tunggu', 'tutup'],
#  ['klaim', 'barang', 'rp'],
#  ['susah', 'cek', 'out', 'lancar'],
#  ['aplikasi',
#   'cantemer',
#   'servis',
#   'sms',
#   'alibi',
#   'aju',
#   'pinjam',
#   'dana',
#   'aju',
#   'pinjam',
#   'dana',
#   'aplikasi',
#   'telepon',
#   'sms',
#   'ganggu'],
#  ['belanja', 'mudah'],
#  ['toko',
#   'vavio',
#   'acc',
#   'jual',
#   'chip',
#   'high',
#   'domino',
#   'tolong',
#   'band',
#   'sdah',
#   'bayar',
#   'suruh',
#   'batal',
#   'transaksi',
#   'aplikasi',
#   'skrng',
#   'tunggu',
#   'dana'],
#  ['bingung',
#   'jual',
#   'jujur',
#   'bilang',
#   'langgar',
#   'akun',
#   'batas',
#   'dana',
#   'beli',
#   'saldo',
#   'jual',
#   'beli',
#   'setia',
#   'hapus',
#   'bilang',
#   'curiga',
#   'toko',
#   'curiga',
#   'lancar',
#   'bayar',
#   'barang',
#   'beli',
#   'dishopee',
#   'bijak',
#   'seperti',
#   'sp',
#   'timbang'],
#  ['saring', 'jual', 'tipu', 'tayiiiilahhh'],
#  ['kanapa', 'barang', 'data', 'ng', 'sedangkab', 'mes', 'tipu'],
#  ['install',
#   'aplikasi',
#   'keamananya',
#   'kemarin',
#   'paket',
#   'tersesat',
#   'akun',
#   'mesan',
#   'log',
#   'out',
#   'akun',
#   'unistal',
#   'tahu',
#   'paket',
#   'ajar',
#   'real',
#   'alam',
#   'tolong',
#   'perhati'],
#  ['aplikasi', 'jlas', 'kirim', 'akun', 'cek', 'kosong'],
#  ['aplikasi', 'sungguh', 'sulit', 'paham', 'barang', 'batal', 'otomatis'],
#  ['tolong',
#   'dijelasin',
#   'aplikasi',
#   'klik',
#   'tapi',
#   'kluar',
#   'klik',
#   'kluar',
#   'lagi',
#   'klik',
#   'kluar',
#   'lagi',
#   'orang',
#   'belanja',
#   'tidak'],
#  ['sistem', 'jual', 'ekspedisi', 'ubah', 'rubah', 'ekspedisi'],
#  ['nggk', 'update', 'gim'],
#  ['balik', 'jasa', 'kirim'],
#  ['flash', 'sale', 'ngadat', 'anjeng'],
#  ['bayar', 'latter', 'bayar', 'sekarang', 'gabiisaa', 'butuh', 'baaanget'],
#  ['batas',
#   'kirim',
#   'seller',
#   'sistem',
#   'cod',
#   'kadang',
#   'kurir',
#   'rumah',
#   'rumah',
#   'kasihan',
#   'kurir',
#   'bolak',
#   'ngekost',
#   'titip',
#   'tetangga',
#   'tetangga'],
#  ['minggu', 'juga', 'pesan', 'detail', 'kirim', 'akurat'],
#  ['seller',
#   'nd',
#   'respon',
#   'proses',
#   'jual',
#   'kirim',
#   'kurir',
#   'nd',
#   'kayak',
#   'lari',
#   'dehh'],
#  ['ngeselin',
#   'aplikasi',
#   'beli',
#   'kirim',
#   'cepat',
#   'tapi',
#   'ngeselin',
#   'brli',
#   'barang',
#   'pengirimanya',
#   'minggu',
#   'kirim',
#   'tutup',
#   'batal',
#   'barang',
#   'begi',
#   'pindah',
#   'toko',
#   'online',
#   'belah',
#   'tolong',
#   'ekspedisi',
#   'instan',
#   'aktif',
#   'cepat',
#   'respon',
#   'auto',
#   'uninstal'],
#  ['benci', 'ygjadi', 'bintang', 'iklan', 'cowok', 'cowok', 'cantik'],
#  ['aplikasi',
#   'sesal',
#   'unduh',
#   'gratis',
#   'traktir',
#   'pas',
#   'pesan',
#   'dibatalin',
#   'langgar',
#   'langgar',
#   'pesan',
#   'kaya',
#   'aplikasi'],
#  ['rp',
#   'ambil',
#   'stok',
#   'habis',
#   'ambil',
#   'stok',
#   'habis',
#   'gilir',
#   'jarak',
#   'pilih',
#   'jasa',
#   'kirim',
#   'harga',
#   'beli',
#   'uninstall'],
#  ['voucher',
#   'jt',
#   'tapi',
#   'tu',
#   'saldo',
#   'toko',
#   'bohong',
#   'mnta',
#   'ampun',
#   'unduh'],
#  ['iklan', 'nongol', 'ganggu'],
#  ['ribet',
#   'ganti',
#   'nomer',
#   'telpon',
#   'susah',
#   'benar',
#   'kirim',
#   'sulit',
#   'kamera',
#   'handphone',
#   'telpon',
#   'customer service',
#   'ngebantunya'],
#  ['kesel', 'harga', 'ongkir', 'mahal', 'skrng', 'ongkir'],
#  ['gratis', 'ongkir', 'boongan'],
#  ['unduh', 'handphone', 'handphone'],
#  ['susah',
#   'flash',
#   'sale',
#   'barang',
#   'mewah',
#   'klik',
#   'terang',
#   'stok',
#   'habis',
#   'barang',
#   'murah',
#   'habis',
#   'stok',
#   'flash',
#   'sale',
#   'kaya',
#   'flash',
#   'sale',
#   'atur',
#   'antri',
#   'aplikasi',
#   'barang',
#   'flash',
#   'sale',
#   'atur',
#   'sistem',
#   'stel',
#   'beda',
#   'pkoknya',
#   'habis',
#   'kaya',
#   'atur',
#   'sistem',
#   'buyer',
#   'habis'],
#  ['kirim', 'cepat', 'terpercsya', 'tunggu', 'tidak', 'kirim'],
#  ['aplikasi', 'kirim', 'cepat'],
#  ['shope', 'aneh'],
#  ['bintang', 'pesan'],
#  ['aplikasi', 'tolong', 'bantu', 'masak', 'saldo', 'hilang', 'bintang'],
#  ['aplikasi', 'bujang', 'mahal', 'beda', 'tetangga', 'laz'],
#  ['sya', 'bayar', 'status', 'belanja', 'ubah', 'bayar'],
#  ['cocok', 'kulit', 'pakai', 'aloe', 'vera', 'pesan'],
#  ['sen',
#   'kirim',
#   'pesan',
#   'barang',
#   'cancel',
#   'jual',
#   'tolong',
#   'laa',
#   'bikin'],
#  ['ambil', 'aplikasi', 'pakai', 'jengkel', 'muncul'],
#  ['iklan', 'resah'],
#  ['cashback', 'rp', 'hilang', 'rugi', 'gin'],
#  ['cod', 'gratis', 'ongkir', 'bohong', 'nihhh'],
#  ['danta',
#   'paket',
#   'donwload',
#   'bekal',
#   'mentang',
#   'isi',
#   'paket',
#   'pakai',
#   'paket',
#   'mahal',
#   'sesuai',
#   'gadantaaaawwa'],
#  ['pindah', 'masak', 'kurir', 'anggap', 'budak'],
#  ['klaim',
#   'diskon',
#   'ribu',
#   'jam',
#   'voucher',
#   'hilang',
#   'refresh',
#   'ttp',
#   'ngadain',
#   'diskon',
#   'leg'],
#  ['agent',
#   'chat',
#   'live',
#   'shoppe',
#   'jk',
#   'bantu',
#   'chat',
#   'putus',
#   'paket',
#   'ydk',
#   'kirim',
#   'minta',
#   'dana',
#   'toko',
#   'tolak',
#   'aplikasi',
#   'lepas',
#   'tangan'],
#  ['driver',
#   'shope',
#   'food',
#   'pakai',
#   'fake',
#   'gps',
#   'tuyul',
#   'aplikasi',
#   'larang',
#   'tindak',
#   'jangan',
#   'mlh',
#   'kasihan',
#   'driver',
#   'jujur',
#   'driver',
#   'order',
#   'pakai',
#   'tuyul',
#   'suspend',
#   'pakai',
#   'aplikasi',
#   'aman',
#   'maju',
#   'jaya'],
#  ['beli', 'barang', 'paket', 'kosong', 'dana'],
#  ['iklan', 'otomatis', 'amit', 'lebih baik', 'shopie', 'olx'],
#  ['gratis',
#   'ongkir',
#   'belanja',
#   'ribu',
#   'ribu',
#   'sesuai',
#   'tema',
#   'lebih baik'],
#  ['seller', 'cetak', 'print', 'alamat', 'kirim', 'aplikasi'],
#  ['tipu',
#   'jgan',
#   'kayak',
#   'gin',
#   'percaya',
#   'sama',
#   'permai',
#   'pesan',
#   'batal',
#   'saldo',
#   'direfund',
#   'bisa',
#   'belanja',
#   'uang',
#   'bisa',
#   'tarik',
#   'capek',
#   'capek',
#   'alfamidi',
#   'bayar',
#   'uang',
#   'admin',
#   'batal',
#   'saldo',
#   'refund',
#   'pakai',
#   'tarik',
#   'malu',
#   'maluin'],
#  ['pesan',
#   'barang',
#   'oct',
#   'tngl',
#   'barang',
#   'kirim',
#   'barang',
#   'juga',
#   'belum',
#   'barang',
#   'kirim',
#   'kacau',
#   'toko',
#   'barang',
#   'belum',
#   'kirim',
#   'kurir',
#   'nelpon',
#   'tidak',
#   'barang',
#   'sampai',
#   'no',
#   'handphone',
#   'customer service',
#   'ninja',
#   'exxpres',
#   'beres',
#   'atw',
#   'pm',
#   'kurir'],
#  ['ongkir', 'mahal', 'barang', 'beli', 'ribu', 'ongkir'],
#  ['lot', 'parahh', 'sinyal', 'wifi', 'gambar', 'polos', 'notificationnya'],
#  ['check', 'out', 'hubungi', 'customer service'],
#  ['unduh',
#   'aplikasi',
#   'aplikasi',
#   'pesan',
#   'sampai',
#   'sampai',
#   'tangan',
#   'tungguin',
#   'tetep',
#   'datang',
#   'datang',
#   'belanja',
#   'mengecewaken',
#   'gabakal',
#   'belanja',
#   'rim',
#   'konsisten'],
#  ['log', 'nomor', 'blokir', 'pdhl', 'pakai', 'order', 'jual'],
#  ['aplikasi', 'php'],
#  ['aplikasi',
#   'akun',
#   'sya',
#   'blokir',
#   'sya',
#   'sarankn',
#   'dwonload',
#   'jangan',
#   'dwnload',
#   'nyeseel'],
#  ['bayar', 'link'],
#  ['belanja',
#   'pesan',
#   'bayar',
#   'tanggal',
#   'nov',
#   'tanda',
#   'kirim',
#   'catat',
#   'proses',
#   'kemas',
#   'gilir',
#   'chat',
#   'customer service',
#   'muter',
#   'karuan'],
#  ['iklan', 'melulu', 'kntol', 'aplikasi', 'anjng'],
#  ['seller', 'bodoh'],
#  ['kirim', 'kayak', 'toko'],
#  ['tolong',
#   'skrng',
#   'ongkir',
#   'pisah',
#   'pisah',
#   'ongkir',
#   'distuin',
#   'sdkit',
#   'tolong',
#   'satuin',
#   'ongkir'],
#  ['sayang',
#   'cicil',
#   'kartu',
#   'kredit',
#   'toko',
#   'belah',
#   'kredit',
#   'kartu',
#   'kredit'],
#  ['terkadang',
#   'masuk',
#   'fitur',
#   'siram',
#   'tanam',
#   'lngsng',
#   'freeze',
#   'baru',
#   'restart',
#   'ulang',
#   'handphone',
#   'khawarir',
#   'rebout',
#   'handphone',
#   'tolong',
#   'lagi',
#   'memori',
#   'masih',
#   'seger',
#   'ram',
#   'juga',
#   'masih',
#   'sisa',
#   'gb',
#   'lbh',
#   'gb',
#   'handphone',
#   'juga',
#   'bukan',
#   'kentang',
#   'aplikasi',
#   'berat',
#   'fitur',
#   'selalu',
#   'lin'],
#  ['aplikasi', 'gun', 'tipu'],
#  ['belanja',
#   'pakai',
#   'voucher',
#   'gratis',
#   'ongkir',
#   'extra',
#   'susah',
#   'check',
#   'out',
#   'bolak'],
#  ['syah', 'bayar', 'expres'],
#  ['jelekkk',
#   'main',
#   'game',
#   'minecrft',
#   'nama',
#   'survival',
#   'na',
#   'muncul',
#   'ikkelan',
#   'pencet',
#   'skip',
#   'mati',
#   'iiih',
#   'jelekk'],
#  ['bug', 'bnerin'],
#  ['shope', 'gimmick', 'flashsale', 'iphone', 'kirim', 'batal', 'hahaha'],
#  ['beres',
#   'aplikasi',
#   'unduh',
#   'aplikasi',
#   'ken',
#   'coba',
#   'belanja',
#   'kayak',
#   'ny',
#   'checkout',
#   'payung',
#   'harga',
#   'ongkir',
#   'akal',
#   'tanggerang',
#   'jambi',
#   'ongkir',
#   'rp',
#   'benar',
#   'harga',
#   'payung'],
#  ['team',
#   'becus',
#   'cie',
#   'nanganin',
#   'custamer',
#   'transaksi',
#   'tanggal',
#   'nov',
#   'sampai',
#   'tanggal',
#   'nov',
#   'biarin',
#   'komplian',
#   'pakai',
#   'mesin',
#   'tolong',
#   'bantu',
#   'jual',
#   'pinter',
#   'barang',
#   'kirim',
#   'retur',
#   'kurir',
#   'tolong',
#   'bantu',
#   'dana',
#   'belanja'],
#  ['kenal',
#   'toko',
#   'sukses',
#   'beli',
#   'barang',
#   'sesuai',
#   'foto',
#   'beli',
#   'barang',
#   'rusak',
#   'kan',
#   'anjig'],
#  ['ribet', 'beli', 'shpee'],
#  ['recomended',
#   'aplikasi',
#   'belanja',
#   'pesan',
#   'akun',
#   'mes',
#   'lemari',
#   'harga',
#   'heboh',
#   'keluarga',
#   'batal',
#   'pesan',
#   'handphone',
#   'jam',
#   'pakai',
#   'ajar',
#   'kirim',
#   'kirim',
#   'alamat',
#   'bilang',
#   'pesan',
#   'kirim',
#   'men',
#   'percaya',
#   'cari',
#   'google'],
#  ['maaf',
#   'uninstal',
#   'tipu',
#   'tipu',
#   'komplen',
#   'gubris',
#   'maaf',
# ...
#   'diturunin',
#   'naekin',
#   'tolong',
#   'dinaekkn',
#   'merger',
#   'suramm'],
#  ['aplikasi',
#   'anjig',
#   'pdahal',
#   'install',
#   'promo',
#   'batal',
#   'sen',
#   'voucher',
#   'ongkir',
#   'hilang',
#   'tlol'],
#  ['aplikasi',
#   'produk',
#   'sesuai',
#   'pesan',
#   'sayang',
#   'ongkir',
#   'mahal',
#   'diskon',
#   'voucer',
#   'gratis',
#   'ongkir',
#   'cuman',
#   'mengambil',
#   'ribu'],
#  ['promo',
#   'mancing',
#   'awam',
#   'pengaruh',
#   'promo',
#   'fitur',
#   'aplikasi',
#   'kaku',
#   'saldo',
#   'dipake',
#   'bayar',
#   'ambil',
#   'lebih baik'],
#  ['gratis',
#   'ongkir',
#   'dwnlod',
#   'pesan',
#   'barang',
#   'langgan',
#   'knk',
#   'cas',
#   'ribu',
#   'ongkir',
#   'kelimapuluh',
#   'kabupaten',
#   'batubara',
#   'harga',
#   'mahal',
#   'bnding',
#   'murah',
#   'ongkir',
#   'cmn',
#   'ribu',
#   'gratis',
#   'ongkir',
#   'pulau',
#   'jawa',
#   'kesumut',
#   'ribu',
#   'gilaaak',
#   'klen',
#   'seperti',
#   'gmn',
#   'banyak',
#   'plnggnnya',
#   'blnj',
#   'berat',
#   'diongkir',
#   'hrg',
#   'mahal',
#   'banding',
#   'aplikasi',
#   'ttngga'],
#  ['keluarin', 'iklan', 'boss', 'kesel', 'iklan', 'nyaman'],
#  ['up', 'kemarin', 'indomart', 'sukses', 'saldo'],
#  ['aplikasi',
#   'commerce',
#   'bikin',
#   'bingung',
#   'masukkan',
#   'nomor',
#   'rekening',
#   'susah'],
#  ['sinyal', 'butuh'],
#  ['maaf',
#   'bri',
#   'bintang',
#   'ea',
#   'nnti',
#   'klau',
#   'brng',
#   'smpai',
#   'baru',
#   'ksih',
#   'bintang',
#   'lagi'],
#  ['lambat', 'downloadnya'],
#  ['organisasi', 'birokrasi'],
#  ['gin',
#   'dowanload',
#   'lagu',
#   'chrome',
#   'ngapain',
#   'unduh',
#   'bilang',
#   'macam',
#   'macam',
#   'poromo',
#   'case',
#   'back',
#   'bikin',
#   'repot',
#   'perasaandah'],
#  ['iklan', 'ganggu', 'tolong', 'jangan', 'iklan', 'sembarang'],
#  ['beli',
#   'bayar',
#   'batal',
#   'promo',
#   'promo',
#   'sisa',
#   'promo',
#   'batal',
#   'transaksi',
#   'kupon',
#   'kupon',
#   'gratis',
#   'ongkir',
#   'ribu',
#   'kupon',
#   'cashback',
#   'ribu',
#   'hilang',
#   'pagi',
#   'sisa',
#   'aju',
#   'care',
#   'balas',
#   'sesuai',
#   'prosedur',
#   'langgar',
#   'tolong'],
#  ['barang', 'siap', 'order', 'kirim', 'kirim', 'batal', 'konfirmasi'],
#  ['takut', 'jahat', 'ngrim', 'alamat'],
#  ['tmpat', 'tinggal', 'camat', 'grong', 'kabupaten', 'pidie', 'kota', 'sigli'],
#  ['tutup', 'akun', 'tanda', 'sistem', 'shoppe', 'kualitas'],
#  ['gratis',
#   'ongkir',
#   'pakai',
#   'sekal',
#   'cari',
#   'toko',
#   'label',
#   'gratis',
#   'ongkir',
#   'toko',
#   'barang',
#   'cari',
#   'pakai',
#   'toko',
#   'kacau',
#   'tolong'],
#  ['lot', 'bnget', 'bayar', 'susah', 'kesini', 'mkin', 'mles', 'lot'],
#  ['lma',
#   'lot',
#   'sebentar',
#   'logout',
#   'sendiri',
#   'pdhal',
#   'ram',
#   'msih',
#   'nyukup',
#   'ntah',
#   'berat',
#   'game',
#   'ny',
#   'tolong'],
#  ['unduh', 'komplen'],
#  ['aplikasi', 'eror', 'terus', 'pdhl', 'update', 'pke', 'pers', 'tetep'],
#  ['budug', 'rehan'],
#  ['gratis', 'ongkir'],
#  ['mola',
#   'minggu',
#   'malam',
#   'kirim',
#   'hadiah',
#   'menang',
#   'nga',
#   'nyampe',
#   'coi',
#   'hadiah',
#   'palsu'],
#  ['barang', 'sesuai'],
#  ['klu',
#   'setock',
#   'barang',
#   'jangan',
#   'pajang',
#   'pajang',
#   'gambar',
#   'pesan',
#   'baju',
#   'batas',
#   'proses',
#   'proses',
#   'potong',
#   'biayamah',
#   'cepat',
#   'kirim',
#   'susah',
#   'puayah'],
#  ['notifikasi', 'kirim', 'cepat', 'fakta', 'kaya', 'bulus', 'lot', 'estimasi'],
#  ['jual',
#   'amanah',
#   'aplikasi',
#   'proses',
#   'barang',
#   'salah',
#   'kirim',
#   'sulit',
#   'seler',
#   'amanah',
#   'tindak',
#   'sebenernya',
#   'rugi',
#   'aplikasi',
#   'customer',
#   'alih',
#   'aplikasi',
#   'lbh',
#   'amanah',
#   'lbh',
#   'mudah',
#   'proses',
#   'pengembalaian',
#   'barang'],
#  ['game', 'jual', 'ayig'],
#  ['toko', 'handal'],
#  ['tolong',
#   'bantu',
#   'foto',
#   'jual',
#   'ratus',
#   'muncul',
#   'tarik',
#   'pelang',
#   'barang',
#   'gudang',
#   'muncul',
#   'pantas',
#   'jual',
#   'terus'],
#  ['aplikasi',
#   'sihh',
#   'kmarin',
#   'apdet',
#   'isi',
#   'saldo',
#   'ribu',
#   'suruh',
#   'ngapdet',
#   'apdet',
#   'kok',
#   'uang',
#   'koin',
#   'koinya',
#   'hilang',
#   'rugi',
#   'dongg',
#   'erti'],
#  ['update',
#   'asa',
#   'gratis',
#   'ongkir',
#   'update',
#   'layar',
#   'putih',
#   'gambar',
#   'gapernah',
#   'gratis',
#   'ongkir',
#   'cod',
#   'why'],
#  ['tipu',
#   'promo',
#   'flash',
#   'sale',
#   'ken',
#   'hapus',
#   'aplikasi',
#   'standby',
#   'sblm',
#   'pkl',
#   'pesan',
#   'stock',
#   'habis',
#   'terang',
#   'jual',
#   'stock',
#   'kosong',
#   'jam',
#   'saran',
#   'klu',
#   'masih',
#   'banyak',
#   'tipu',
#   'promo',
#   'sesuai'],
#  ['update',
#   'bayar',
#   'chat',
#   'customer service',
#   'hang',
#   'restart',
#   'aplikasi'],
#  ['berat',
#   'aplikasi',
#   'respon',
#   'pencet',
#   'berat',
#   'beda',
#   'ringan',
#   'smooth'],
#  ['ongkir',
#   'mahal',
#   'brooo',
#   'hadeuh',
#   'hadeuh',
#   'ganti',
#   'opsi',
#   'kurir',
#   'harga',
#   'up',
#   'up',
#   'mahal',
#   'customer service',
#   'bot',
#   'mlu',
#   'jwbannya',
#   'ktnya',
#   'unicorn',
#   'customer service',
#   'bot'],
#  ['virus', 'iklan', 'handphone', 'eror'],
#  ['aplikasi',
#   'bela',
#   'seller',
#   'beli',
#   'please',
#   'be',
#   'careful',
#   'skripsi',
#   'sesat',
#   'seller',
#   'utama',
#   'dropship',
#   'seller',
#   'modal'],
#  ['chekout',
#   'pin',
#   'salah',
#   'pdhl',
#   'benar',
#   'sampai',
#   'blokir',
#   'tolong',
#   'gimanain'],
#  ['haraga', 'barang', 'beli'],
#  ['toko', 'tanggung', 'kirim', 'barang', 'sesuai', 'pesan', 'barang'],
#  ['kemarin',
#   'aktif',
#   'kredit',
#   'isi',
#   'data',
#   'data',
#   'hapus',
#   'nama',
#   'tika',
#   'aprilia',
#   'triyanto',
#   'kredit',
#   'handphone',
#   'counter',
#   'bantu',
#   'hapus',
#   'data'],
#  ['tipu', 'barang', 'sesuai', 'tokony', 'bawa', 'rezeky', 'usaha', 'tipu'],
#  ['beli', 'pulsa', 'refund', 'melulu', 'anjimmm', 'kaya'],
#  ['unduh', 'tunggu', 'hati', 'riang', 'gembira', 'tbtb', 'gagal'],
#  ['aplikasi', 'jelekk', 'login', 'pke', 'verifikasi', 'wajah', 'upgrade'],
#  ['aplikasi',
#   'hancur',
#   'ran',
#   'ribet',
#   'lebih baik',
#   'aplikasi',
#   'belah',
#   'dasar'],
#  ['verrsi',
#   'android',
#   'hambat',
#   'tunanetra',
#   'menu',
#   'food',
#   'akses',
#   'searching',
#   'lokasi',
#   'resto',
#   'menu',
#   'keranjang',
#   'tulis',
#   'salah',
#   'tindak'],
#  ['lindung',
#   'garansi',
#   'bintang',
#   'bicara',
#   'tim',
#   'jual',
#   'jual',
#   'amanah',
#   'jual',
#   'jujur',
#   'tim',
#   'bantuin',
#   'keluh',
#   'mbelinya'],
#  ['jasa', 'kirim', 'sedia'],
#  ['scar', 'tri'],
#  ['engga',
#   'up',
#   'logika',
#   'up',
#   'akun',
#   'ngendap',
#   'bank',
#   'konvensional',
#   'tranfer',
#   'ganggu',
#   'jam',
#   'kelas',
#   'bank',
#   'aplikasi',
#   'urus',
#   'up',
#   'engga',
#   'tunggu'],
#  ['bintang', 'pakek', 'amplikasi', 'iklan', 'muncul', 'handphone'],
#  ['baru',
#   'pakai',
#   'order',
#   'ngecewain',
#   'batal',
#   'jasa',
#   'kirim',
#   'baru',
#   'tahu',
#   'js',
#   'pgriman',
#   'batal',
#   'kirim',
#   'jam',
#   'bareng',
#   'kirim',
#   'alamat',
#   'jm',
#   'sore',
#   'untuk',
#   'siapkn',
#   'uang',
#   'sstm',
#   'bayar',
#   'ttpi',
#   'jm',
#   'mlm',
#   'pmbritahuan',
#   'bareng',
#   'gagal',
#   'kirim',
#   'curiga',
#   'psnan',
#   'mysteri',
#   'box',
#   'nominal',
#   'paham',
#   'kan',
#   'kcurigaan',
#   'aneh',
#   'jsa',
#   'pgirimannya',
#   'sam',
#   'lx',
#   'tlglah',
#   'lbh',
#   'selektif',
#   'dlm',
#   'pilih',
#   'jasa',
#   'kirim',
#   'amatir',
#   'model',
#   'gtu'],
#  ['cod', 'toko', 'tipu', 'hadeeeee'],
#  ['unduh', 'lagu'],
#  ['aplikasi',
#   'browsing',
#   'tonton',
#   'drakor',
#   'ehh',
#   'suruh',
#   'unduh',
#   'aplikasi',
#   'aplikasi'],
#  ['iklan', 'anjim'],
#  ['aplikasi', 'tipu'],
#  ['semerawut',
#   'sen',
#   'bareng',
#   'tunggu',
#   'dibatalin',
#   'lagi',
#   'sellernya',
#   'kapok',
#   'blja',
#   'dsni',
#   'beli',
#   'sepele',
#   'uninstall',
#   'az',
#   'puzink'],
#  ['beli',
#   'platihan',
#   'status',
#   'transaksi',
#   'batal',
#   'status',
#   'platihan',
#   'aktif',
#   'voucher',
#   'pltihan',
#   'beli',
#   'hambat',
#   'beli',
#   'platihan',
#   'aktif',
#   'email',
#   'pusat',
#   'bantu',
#   'refand',
#   'ribet',
#   'hambat',
#   'karir'],
#  ['aplikasi',
#   'cekout',
#   'rupiah',
#   'pas',
#   'cek',
#   'out',
#   'batal',
#   'coba',
#   'ganti',
#   'nomer',
#   'batal',
#   'donlut',
#   'aplikasi',
#   'males',
#   'php',
#   'kaya',
#   'toko',
#   'pilih',
#   'barang',
#   'rupiah',
#   'batal'],
#  ['anteraja', 'dipake', 'laaah', 'bikin', 'layan'],
#  ['promo',
#   'pakai',
#   'coin',
#   'dahh',
#   'benar',
#   'promo',
#   'potong',
#   'ongkir',
#   'pakai',
#   'pakai',
#   'point',
#   'evektif'],
#  ['susah',
#   'unduh',
#   'aplikasi',
#   'belanja',
#   'online',
#   'tarik',
#   'murah',
#   'ongkir'],
#  ['pakai', 'trsnsaksi'],
#  ['kirim', 'kuno', 'instan'],
#  ['update', 'mennggapi'],
#  ['bintang',
#   'rena',
#   'install',
#   'ulang',
#   'sampai',
#   'akun',
#   'hapus',
#   'pindah',
#   'pakai',
#   'aplikasi',
#   'ribet'],
#  ['akun',
#   'shoppe',
#   'login',
#   'costumer',
#   'service',
#   'tolong',
#   'bantu',
#   'bayar',
#   'shoppepaylatter'],
#  ['aowkwowkwok', 'aplikasi', 'mandang', 'handphone'],
#  ['aneh', 'pesan', 'barang', 'nama', 'kirim'],
#  ['ganggu', 'link', 'unduh'],
#  ['tipu',
#   'toko',
#   'nakal',
#   'kirim',
#   'barang',
#   'cod',
#   'pesan',
#   'barang',
#   'filter',
#   'tipu'],
#  ['aplikasi', 'prank', 'konten'],
#  ['barang',
#   'dikirm',
#   'nggk',
#   'sesuai',
#   'mau',
#   'barang',
#   'proses',
#   'ribet',
#   'banding',
#   'toko',
#   'online',
#   'belah',
#   'nggk',
#   'kaya',
#   'gin'],
#  ['iklan', 'mental', 'play', 'toko'],
#  ['sampai',
#   'sertifikat',
#   'bom',
#   'muncul',
#   'dasbor',
#   'prakerjaaaaaaaa',
#   'tolong',
#   'cepat'],
#  ['sore',
#   'aplikasi',
#   'burik',
#   'loading',
#   'gagal',
#   'muat',
#   'pdahal',
#   'jaringal'],
#  ['bikin', 'promo', 'diskon', 'gilir', 'dipake', 'anggap', 'menyalaho'],
#  ['aplikasi', 'sen', 'paket', 'hancur', 'kirim', 'hancurrrrrrr'],
#  ['pilih', 'jasa', 'kirim', 'sinyal'],
#  ['aneh', 'dh', 'diupdate', 'ttp', 'ilangin', 'ganggu'],
#  ['bisa', 'downlod'],
#  ['woyy',
#   'bangke',
#   'cari',
#   'lot',
#   'bangkee',
#   'update',
#   'aplikasi',
#   'sinyal',
#   'tahi',
#   'laah'],
#  ['ngadain',
#   'cashback',
#   'cashback',
#   'jarang',
#   'aplikasi',
#   'tembah',
#   'lot',
#   'mitra',
#   'curang',
#   'males',
#   'beli',
#   'belanja',
#   'pakai',
#   'pindah',
#   'toko'],
#  ['tolong', 'tolong', 'up', 'snack', 'vidio', 'uang'],
#  ['kecewaaa',
#   'bangett',
#   'sntadar',
#   'ekpress',
#   'kirim',
#   'bangett',
#   'banding',
#   'kirim',
#   'reguler',
#   'lai',
#   'lebih baik',
#   'ituu',
#   'hedhhh'],
#  ['live', 'chat', 'susah'],
#  ['tolong', 'bantu', 'saldo', 'hubung', 'dana'],
#  ['ribet',
#   'dipake',
#   'lockout',
#   'verivikasi',
#   'belibet',
#   'muter',
#   'auto',
#   'un',
#   'install',
#   'ao',
#   'gin'],
#  ['aplikasi',
#   'pngiriman',
#   'bnyak',
#   'pnjual',
#   'jelassss',
#   'paket',
#   'dateng',
#   'lgsung',
#   'uinstal',
#   'bkal',
#   'dowlnd',
#   'lh'],
#  ['aplikasi',
#   'tipu',
#   'sen',
#   'box',
#   'dateng',
#   'cincin',
#   'harga',
#   'ribu',
#   'pantau',
#   'toko',
#   'toko',
#   'amanah',
#   'korban',
#   'aplikasi'],
#  ['baca',
#   'editor',
#   'notice',
#   'bintang',
#   'cuman',
#   'saran',
#   'letak',
#   'gambar',
#   'produk',
#   'sejajar',
#   'judul',
#   'produk',
#   'tulis',
#   'kecilin',
#   'mudah',
#   'gambar',
#   'contolah',
#   'akun',
#   'shope',
#   'belah',
#   'gambar',
#   'iklan',
#   'nyaingin',
#   'toko',
#   'belah',
#   'fitur',
#   'tampil',
#   'tarik',
#   'toko',
#   'belah',
#   'notice',
#   'baca'],
#  ['kurir',
#   'alamat',
#   'tera',
#   'cantum',
#   'nama',
#   'orang',
#   'belanja',
#   'setelah',
#   'komplain',
#   'tuntas',
#   'tutup',
#   'beli',
#   'rugi',
#   'barang',
#   'hilang'],
#  ['sayang',
#   'pesan',
#   'rupiah',
#   'beli',
#   'eror',
#   'bilang',
#   'pesan',
#   'sdngkan',
#   'dengn',
#   'bareng',
#   'kecewaa'],
#  ['gratis', 'ongkir', 'kya'],
#  ['tulis', 'kolom', 'cari', 'eror'],
#  ['tolong',
#   'benah',
#   'kurir',
#   'shoope',
#   'express',
#   'pesan',
#   'hold',
#   'jarak',
#   'kirim',
#   'lokasi',
#   'kirim'],
#  ['chat', 'eror', 'connect', 'jaring'],
#  ['mengisi', 'shopay', 'saldo', 'atm', 'duit'],
#  ['verivikasi', 'bikin', 'ribet'],
#  ['dear',
#   'mimin',
#   'kendala',
#   'checkout',
#   'checkout',
#   'pesan',
#   'checkout',
#   'gagal',
#   'risih',
#   'pesan',
#   'pesan',
#   'otomatis',
#   'checkout',
#   'pesan',
#   'harga',
#   'barang',
#   'beli',
#   'sesuai',
#   'voucher',
#   'voucher',
#   'tolong',
#   'mimin',
#   'mudah',
#   'checkout',
#   'tolong',
#   'checkout',
#   'gagal'],
#  ['belanja', 'kli', 'isi', 'pakrtnya', 'bodoh'],
#  ['iklan', 'spam', 'google', 'nonton', 'film', 'skip', 'heran'],
#  ['belanja',
#   'bayar',
#   'alfa',
#   'indomaret',
#   'barang',
#   'cod',
#   'malas',
#   'pakai',
#   'aplikasi',
#   'tolong',
#   'informasi'],
#  ['bintang', 'pilih', 'kurir', 'besok', 'tunggu', 'kurir', 'lamban'],
#  ['mantaaaa', 'belanja', 'tipu', 'belanja', 'pesan', 'sesuai'],
#  ['sampah', 'selalu', 'ganggu'],
#  ['aplikasi', 'serius'],
#  ['mahal', 'ongkir', 'beli', 'kirim', 'hadehhh', 'gaze'],
#  ['commerce',
#   'gajelas',
#   'pakai',
#   'voucher',
#   'promo',
#   'dipake',
#   'pas',
#   'dipake',
#   'transaksi',
#   'batal',
#   'otomatis',
#   'transaksi',
#   'akun',
#   'tahu',
#   'akun',
#   'bertanya',
#   'costumer',
#   'service',
#   'solusi'],
#  ['aplikasi',
#   'aman',
#   'hubung',
#   'akun',
#   'informasi',
#   'kartu',
#   'kredit',
#   'link',
#   'fintech',
#   'otp',
#   'login',
#   'perangkat',
#   'pin',
#   'transaksi',
#   'fintech',
#   'retas',
#   'alami',
#   'sendir',
#   'akun',
#   'retas',
#   'topup',
#   'money',
#   'koneksi',
#   'akun',
#   'bertanggungjawab',
#   'rubah',
#   'pin',
#   'password',
#   'rutin',
#   'hubung',
#   'bayar'],
#  ['donlod', 'chekout', 'aneh'],
#  ['pliss',
#   'data',
#   'cur',
#   'ganti',
#   'rugi',
#   'jt',
#   'lapor',
#   'shoppe',
#   'polisi',
#   'titik'],
#  ['benar',
#   'order',
#   'proses',
#   'kirim',
#   'toleransi',
#   'jual',
#   'kirim',
#   'recommended',
#   'order',
#   'kuciwa'],
#  ['bayar', 'cok'],
#  ['aduhh',
#   'maaf',
#   'isi',
#   'alamat',
#   'kecamatan',
#   'kota',
#   'salah',
#   'pdhal',
#   'ulang',
#   'ulang'],
#  ['menu',
#   'utama',
#   'mesti',
#   'pencet',
#   'salah',
#   'gimna',
#   'sen',
#   'haduh',
#   'makane',
#   'sebel',
#   'pakai',
#   'shoopee',
#   'gin',
#   'tolong',
#   'bantu',
#   'dibenerin',
#   'gimna'],
#  ['barang', 'bnyak', 'sesuai', 'kirim'],
#  ['gimn', 'belanja', 'sistem', 'cod'],
#  ['toko', 'tipu', 'tolong', 'banned', 'toko', 'tipu', 'periksa', 'lagiiiii'],
#  ['daftar', 'akun', 'sulit', 'mnding', 'toko', 'belah'],
#  ['tolong', 'aplikasi', 'beli', 'kouta', 'aplikasi', 'tapi', 'ny', 'aplikasi'],
#  ['pakai', 'pakai', 'voucher'],
#  ['bayar', 'link', 'enggk'],
#  ['daftar', 'ngabis', 'kuota'],
#  ['aplikasi', 'lot'],
#  ['pesan', 'sini', 'pesn', 'sini', 'barang', 'proses', 'bayar', 'hadeeeeee'],
#  ['suruh',
#   'kritik',
#   'keritik',
#   'ber',
#   'diam',
#   'ubah',
#   'kirim',
#   'lempar',
#   'xpres',
#   'lot',
#   'sap',
#   'expres',
#   'bangke',
#   'benar',
#   'kirim',
#   'area',
#   'jawa',
#   'makan',
#   'full'],
#  ['gambar', 'ampas'],
#  ['maaf',
#   'masak',
#   'muncul',
#   'detik',
#   'muncul',
#   'detik',
#   'muncul',
#   'tolong',
#   'menit',
#   'seperti',
#   'menit',
#   'tibul',
#   'timbul',
#   'jengkel',
#   'cek',
#   'maaf',
#   'hoak'],
#  ['tolong',
#   'iklan',
#   'menggangu',
#   'nyaman',
#   'jelajah',
#   'internet',
#   'hapus',
#   'aplikasi',
#   'ganggu'],
#  ['unduh', 'aplikasi', 'tipu'],
#  ['beri',
#   'rating',
#   'tanggung',
#   'dsb',
#   'kerjain',
#   'nyuruh',
#   'hubung',
#   'hubung',
#   'puter',
#   'puter',
#   'lagi',
#   'orang',
#   'beri',
#   'kritik',
#   'ketidakpuasan',
#   'cepat',
#   'tanganin',
#   'nyuruh',
#   'hubung',
#   'gambar',
#   'tampil',
#   'pending',
#   'bingung',
#   'internet',
#   'pasang',
#   'gb',
#   'handphone',
#   'redmi',
#   'note',
#   'apalalagi',
#   'salah'],
#  ['install', 'aplikasi', 'hadiah', 'jangan', 'bohong', 'aje'],
#  ['tawarin',
#   'rupiah',
#   'pas',
#   'cek',
#   'tetep',
#   'beli',
#   'mahal',
#   'aplikasi',
#   'shopy'],
#  ['terlambat',
#   'bayar',
#   'shopeepaylater',
#   'tlponin',
#   'puluh',
#   'kayak',
#   'hutang',
#   'puluh',
#   'juta',
#   'ngk',
#   'bayar',
#   'bom',
#   'gaji',
#   'gaji',
#   'undur',
#   'nelponin',
#   'ngk',
#   'paut',
#   'tunggak',
#   'bayar',
#   'kasi',
#   'teman',
#   'diganguin',
#   'melulu',
#   'kayak',
#   'teror',
#   'ganggu',
#   'tolong',
#   'baca',
#   'tolong',
#   'erti'],
#  ['tari',
#   'saldo',
#   'even',
#   'bayar',
#   'kumpulun',
#   'kawan',
#   'susah',
#   'tolong',
#   'ikan'],
#  ['cod', 'cash', 'or', 'duel'],
#  ['akun',
#   'alami',
#   'janggal',
#   'live',
#   'chat',
#   'sulit',
#   'tombol',
#   'live',
#   'chat',
#   'unduh'],
#  ['setia', 'sllu', 'sperti', 'vocher', 'valid', 'vocher', 'msih'],
#  ['maaf', 'bri', 'dl', 'baru'],
#  ['iklan',
#   'amplikasi',
#   'ganggu',
#   'donlod',
#   'musik',
#   'tadi',
#   'muncul',
#   'handphone',
#   'teruss',
#   'bikin',
#   'emosi'],
#  ['aplikasi',
#   'nggk',
#   'install',
#   'unduh',
#   'berualang',
#   'ulang',
#   'kuota',
#   'hangus',
#   'bgtu',
#   'gara',
#   'unduh',
#   'tapi',
#   'terinstal'],
#  ...]

# %% [markdown]
# ## Modelling

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
for k in range (6, 7):
  # generate LDA model
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes=20, iterations=100, alpha=[0.01]*k, eta=[0.01]*len(dictionary.keys()))
  # print(ldamodel.show_topics())
  # compute coherence score
  coherence_model_lda = CoherenceModel(model=ldamodel, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence_lda = coherence_model_lda.get_coherence()
  print(k, ldamodel.log_perplexity(corpus),coherence_lda)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
  # Init output
  sent_topics_df = pd.DataFrame()

  # Get main topic in each document
  for i, row_list in enumerate(ldamodel[corpus]):
    row = row_list[0] if ldamodel.per_word_topics else row_list
    print(row)
    row = sorted(row, key=lambda x: (x[1]), reverse=True)
    # Get the Dominant topic, Perc Contribution and Keywords for each document
    for j, (topic_num, prop_topic) in enumerate(row):
      if j == 0:
        wp = ldamodel.show_topic(topic_num)
        topic_keywords = ", ".join([word for word, prop in wp])
        sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
      else:
        break
  sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

  # Add original text to the end of the output
  contents = pd.Series(texts)
  sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
  return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=texts)
# Out:
# Streaming output truncated to the last 5000 lines.
# [(4, 0.95283026)]
# [(2, 0.4902912), (4, 0.49029127)]
# [(3, 0.20948079), (5, 0.7826141)]
# [(0, 0.32081762), (1, 0.6693302)]
# [(2, 0.13907559), (3, 0.7737307), (5, 0.083882466)]
# [(0, 0.08374793), (1, 0.26898932), (2, 0.30807093), (3, 0.09117266), (4, 0.24718997)]
# [(1, 0.49029127), (4, 0.4902912)]
# [(3, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.97572815)]
# [(2, 0.98768467)]
# [(0, 0.16712008), (1, 0.6463766), (5, 0.18225397)]
# [(4, 0.95283026)]
# [(1, 0.49029127), (4, 0.4902912)]
# [(5, 0.95283026)]
# [(2, 0.97572815)]
# [(1, 0.97572815)]
# [(2, 0.4902912), (4, 0.49029127)]
# [(1, 0.97572815)]
# [(1, 0.95283026)]
# [(1, 0.37146255), (3, 0.6154656)]
# [(2, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(2, 0.43378597), (4, 0.3817655), (5, 0.18173598)]
# [(0, 0.39723322), (2, 0.19960475), (5, 0.39723322)]
# [(0, 0.47041526), (1, 0.24876848), (2, 0.2734271)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.27470532), (2, 0.24876848), (5, 0.46913707)]
# [(2, 0.97572815)]
# [(2, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(1, 0.97572815)]
# [(0, 0.11147902), (1, 0.11541659), (2, 0.120142825), (5, 0.65075403)]
# [(2, 0.97572815)]
# [(0, 0.24876848), (1, 0.45777905), (3, 0.2860633)]
# [(3, 0.49029127), (5, 0.49029127)]
# [(0, 0.39723322), (1, 0.37010518), (2, 0.22673275)]
# [(1, 0.49507388), (5, 0.49507388)]
# [(2, 0.24876848), (4, 0.49507388), (5, 0.24876848)]
# [(2, 0.40652314), (4, 0.5855717)]
# [(0, 0.54473895), (2, 0.4421891)]
# [(0, 0.24876845), (2, 0.74137926)]
# [(0, 0.97572815)]
# [(0, 0.49507388), (2, 0.24876845), (4, 0.24876845)]
# [(2, 0.95283026)]
# [(0, 0.10443634), (1, 0.13306268), (3, 0.08608985), (4, 0.67567205)]
# [(3, 0.98366016)]
# [(0, 0.6358153), (2, 0.35433242)]
# [(2, 0.8413404), (4, 0.15299386)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(0, 0.97572815)]
# [(2, 0.6557726), (3, 0.112174444), (5, 0.22907075)]
# [(0, 0.38786346), (2, 0.4740506), (3, 0.13436389)]
# [(1, 0.49029127), (5, 0.4902912)]
# [(4, 0.99174917)]
# [(0, 0.16666667), (2, 0.25568044), (4, 0.5727024)]
# [(1, 0.23321274), (4, 0.7601866)]
# [(4, 0.98366016)]
# [(0, 0.450432), (1, 0.2802402), (4, 0.2619386)]
# [(0, 0.13033193), (2, 0.7759483), (4, 0.09172778)]
# [(0, 0.95283026)]
# [(0, 0.97572815)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(4, 0.97572815)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.49029127), (5, 0.4902912)]
# [(3, 0.95283026)]
# [(0, 0.14305949), (2, 0.54923534), (4, 0.3034559)]
# [(1, 0.4156744), (2, 0.5712537)]
# [(4, 0.97572815)]
# [(5, 0.97572815)]
# [(2, 0.17022704), (4, 0.6581558), (5, 0.16666666)]
# [(0, 0.36309427), (1, 0.40512583), (2, 0.22805786)]
# [(0, 0.11147902), (1, 0.56254315), (2, 0.17039214), (5, 0.15337816)]
# [(1, 0.95283026)]
# [(3, 0.95283026)]
# [(3, 0.14305948), (4, 0.5679887), (5, 0.2847025)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.97572815)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(4, 0.98366016)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(2, 0.99011856)]
# [(1, 0.29533702), (4, 0.39723322), (5, 0.30150092)]
# [(0, 0.98366016)]
# [(3, 0.49507388), (4, 0.24876848), (5, 0.24876848)]
# [(2, 0.98366016)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(0, 0.19960475), (1, 0.57170355), (2, 0.2227629)]
# [(2, 0.45056456), (4, 0.54283476)]
# [(0, 0.12531017), (2, 0.5330963), (4, 0.33787137)]
# [(4, 0.97572815)]
# [(0, 0.97572815)]
# [(0, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.98366016)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(2, 0.97572815)]
# [(2, 0.7413793), (3, 0.24876848)]
# [(0, 0.33453628), (2, 0.26103196), (3, 0.32706884), (4, 0.075940445)]
# [(1, 0.14587583), (2, 0.37875503), (4, 0.46944025)]
# [(1, 0.41358843), (2, 0.57655936)]
# [(0, 0.22370255), (1, 0.29920477), (2, 0.10142687), (3, 0.17347135), (5, 0.20120046)]
# [(0, 0.20945057), (3, 0.78613436)]
# [(1, 0.24876848), (2, 0.74137926)]
# [(2, 0.95283026)]
# [(5, 0.95283026)]
# [(3, 0.98366016)]
# [(1, 0.28361818), (4, 0.71071607)]
# [(1, 0.33006537), (5, 0.65686274)]
# [(3, 0.3043203), (4, 0.68582743)]
# [(0, 0.19960475), (3, 0.2420474), (4, 0.552419)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.71745986), (3, 0.27268788)]
# [(1, 0.7222159), (2, 0.26793197)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.97572815)]
# [(2, 0.98768467)]
# [(0, 0.19960472), (3, 0.7924901)]
# [(1, 0.34045392), (3, 0.20465198), (4, 0.4499436)]
# [(0, 0.95283026)]
# [(2, 0.97572815)]
# [(4, 0.95283026)]
# [(2, 0.98768467)]
# [(0, 0.33168313), (3, 0.66171616)]
# [(1, 0.6077829), (4, 0.3791452)]
# [(2, 0.33404183), (4, 0.46042454), (5, 0.19960472)]
# [(0, 0.95283026)]
# [(0, 0.97572815)]
# [(2, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(2, 0.99011856)]
# [(2, 0.7924901), (5, 0.19960472)]
# [(0, 0.19960476), (1, 0.57814634), (3, 0.21632002)]
# [(4, 0.97572815)]
# [(0, 0.2218543), (1, 0.35593316), (5, 0.41890123)]
# [(1, 0.41564232), (2, 0.5712857)]
# [(1, 0.95283026)]
# [(0, 0.24876848), (2, 0.46211627), (4, 0.28172612)]
# [(2, 0.97572815)]
# [(1, 0.61856145), (4, 0.3683667)]
# [(1, 0.45794868), (3, 0.52897936)]
# [(1, 0.55438), (4, 0.4377148)]
# [(0, 0.33006534), (4, 0.6568628)]
# [(2, 0.47167787), (3, 0.2721645), (5, 0.24876848)]
# [(2, 0.33006537), (4, 0.65686274)]
# [(2, 0.14459646), (4, 0.85098857)]
# [(0, 0.35049698), (1, 0.46181473), (3, 0.1817594)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(5, 0.95283026)]
# [(5, 0.95283026)]
# [(1, 0.2085605), (2, 0.78782284)]
# [(2, 0.97572815)]
# [(1, 0.72427374), (2, 0.26587406)]
# [(0, 0.10742165), (2, 0.689795), (4, 0.10039761), (5, 0.10039761)]
# [(1, 0.21771507), (2, 0.60255367), (5, 0.17548198)]
# [(1, 0.95283026)]
# [(0, 0.32770118), (2, 0.37447396), (3, 0.15193248), (5, 0.14305949)]
# [(4, 0.95283026)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(2, 0.97572815)]
# [(5, 0.95283026)]
# [(0, 0.24876848), (2, 0.49507388), (5, 0.24876848)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(2, 0.98366016)]
# [(2, 0.98366016)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(4, 0.95283026)]
# [(2, 0.98768467)]
# [(2, 0.97572815)]
# [(2, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.49507388)]
# [(0, 0.33006537), (5, 0.65686274)]
# [(2, 0.24876845), (3, 0.74137926)]
# [(2, 0.24910957), (4, 0.5619465), (5, 0.18522182)]
# [(0, 0.14803648), (3, 0.34763995), (4, 0.4189173), (5, 0.08374793)]
# [(0, 0.16666666), (2, 0.59603286), (3, 0.23234998)]
# [(2, 0.98366016)]
# [(0, 0.4902912), (2, 0.49029127)]
# [(1, 0.97572815)]
# [(0, 0.47780836), (1, 0.12531018), (2, 0.39315942)]
# [(4, 0.95283026)]
# [(5, 0.95283026)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(5, 0.95283026)]
# [(3, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.38937026), (2, 0.2476301), (4, 0.13893785), (5, 0.22185431)]
# [(2, 0.33006537), (4, 0.65686274)]
# [(2, 0.98768467)]
# [(0, 0.108327), (1, 0.09037068), (4, 0.6569211), (5, 0.14295875)]
# [(0, 0.49507388), (5, 0.49507383)]
# [(1, 0.39723322), (2, 0.39723322), (5, 0.19960476)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.1973128), (1, 0.17591901), (2, 0.07538785), (3, 0.22178416), (4, 0.062889166), (5, 0.26670706)]
# [(4, 0.99011856)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.33006534), (4, 0.6568628)]
# [(0, 0.95283026)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.22141303), (1, 0.4051303), (5, 0.36920735)]
# [(0, 0.95283026)]
# [(0, 0.33461958), (2, 0.38739523), (3, 0.16072056), (4, 0.115733206)]
# [(1, 0.49669966), (3, 0.33168316), (5, 0.16666667)]
# [(0, 0.97572815)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(3, 0.95283026)]
# [(2, 0.6950175), (4, 0.29931676)]
# [(1, 0.97572815)]
# [(1, 0.2272685), (2, 0.35457653), (4, 0.4144329)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(0, 0.4975186), (1, 0.36563712), (2, 0.13312219)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.97572815)]
# [(2, 0.5580897), (4, 0.43400517)]
# [(5, 0.95283026)]
# [(0, 0.24937966), (1, 0.43331167), (3, 0.12531018), (5, 0.18951716)]
# [(1, 0.98366016)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.55439264), (4, 0.4377022)]
# [(1, 0.98366016)]
# [(3, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.19466592), (2, 0.14051794), (3, 0.2888856), (5, 0.37344915)]
# [(1, 0.95283026)]
# [(0, 0.111295685), (1, 0.27655512), (2, 0.3763525), (3, 0.05756016), (4, 0.17768286)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.65686274), (5, 0.33006534)]
# [(2, 0.49029127), (4, 0.49029127)]
# [(2, 0.74137926), (5, 0.24876845)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(1, 0.4902912), (4, 0.49029127)]
# [(0, 0.14305949), (1, 0.35240752), (2, 0.34733897), (3, 0.15436114)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.17574044), (2, 0.8185938)]
# [(4, 0.95283026)]
# [(0, 0.22528706), (1, 0.19960472), (3, 0.32034138), (5, 0.25081426)]
# [(1, 0.19026121), (2, 0.20938054), (4, 0.2889693), (5, 0.30808863)]
# [(0, 0.14305949), (2, 0.28470254), (4, 0.4263456), (5, 0.14305949)]
# [(1, 0.5601866), (3, 0.42996117)]
# [(2, 0.39938858), (4, 0.59619635)]
# [(2, 0.97572815)]
# [(1, 0.7124798), (2, 0.27766797)]
# [(4, 0.98768467)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(2, 0.98366016)]
# [(0, 0.21718879), (1, 0.45841867), (4, 0.2455258), (5, 0.07733537)]
# [(3, 0.98366016)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.97572815)]
# [(0, 0.34024236), (3, 0.48814043), (5, 0.16666666)]
# [(1, 0.98366016)]
# [(3, 0.95283026)]
# [(0, 0.2855936), (3, 0.2475491), (4, 0.4609284)]
# [(0, 0.39723322), (2, 0.37854782), (3, 0.21829014)]
# [(2, 0.98366016)]
# [(2, 0.95283026)]
# [(0, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.4263456), (2, 0.5679887)]
# [(0, 0.39723322), (2, 0.5948617)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(2, 0.95283026)]
# [(0, 0.33006537), (4, 0.65686274)]
# [(3, 0.98366016)]
# [(1, 0.4902912), (2, 0.49029133)]
# [(1, 0.97572815)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(2, 0.95283026)]
# [(2, 0.41362488), (4, 0.5807094)]
# [(2, 0.5286553), (4, 0.46474403)]
# [(4, 0.98366016)]
# [(3, 0.49029127), (5, 0.4902912)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.65686274), (4, 0.33006537)]
# [(1, 0.36759013), (2, 0.39723322), (4, 0.22924781)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(0, 0.24876848), (2, 0.7413793)]
# [(5, 0.97572815)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(1, 0.95283026)]
# [(0, 0.5780697), (3, 0.21004319), (4, 0.20595829)]
# [(4, 0.97572815)]
# [(1, 0.37692523), (5, 0.6100029)]
# [(0, 0.08374792), (2, 0.36218178), (4, 0.35166886), (5, 0.20074308)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.36876732), (4, 0.6233275)]
# [(2, 0.39723322), (4, 0.5948617)]
# [(0, 0.95283026)]
# [(1, 0.97572815)]
# [(3, 0.4902912), (5, 0.49029127)]
# [(3, 0.6312946), (4, 0.2824699), (5, 0.08374792)]
# [(1, 0.97572815)]
# [(0, 0.12531017), (1, 0.47280675), (2, 0.13848865), (4, 0.260913)]
# [(1, 0.33168313), (2, 0.66171616)]
# [(0, 0.099777274), (1, 0.531135), (4, 0.10279368), (5, 0.2644857)]
# [(1, 0.20131525), (2, 0.6137633), (4, 0.18161017)]
# [(0, 0.23534189), (3, 0.7567529)]
# [(0, 0.23995236), (2, 0.5523417), (5, 0.20345663)]
# [(3, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.98366016)]
# [(0, 0.39723322), (3, 0.19960475), (5, 0.39723322)]
# [(3, 0.97572815)]
# [(4, 0.95283026)]
# [(1, 0.3300654), (4, 0.31539166), (5, 0.34473905)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.4167901), (5, 0.570138)]
# [(2, 0.59969914), (4, 0.39239576)]
# [(1, 0.7573208), (4, 0.23477402)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(0, 0.3083648), (1, 0.24937966), (3, 0.2239813), (5, 0.21579285)]
# [(1, 0.95283026)]
# [(3, 0.95283026)]
# [(5, 0.95283026)]
# [(0, 0.24876848), (3, 0.49507388), (5, 0.24876848)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.3226665), (2, 0.2760893), (3, 0.39894706)]
# [(0, 0.2704146), (2, 0.28245613), (3, 0.32717797), (4, 0.11930739)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.95283026)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(0, 0.1430595), (2, 0.5540077), (3, 0.29868352)]
# [(3, 0.95283026)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(1, 0.95283026)]
# [(1, 0.40086958), (2, 0.33560428), (3, 0.25927687)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.95283026)]
# [(0, 0.12531017), (2, 0.28138587), (3, 0.12531018), (4, 0.46551242)]
# [(2, 0.22988224), (4, 0.765155)]
# [(1, 0.95283026)]
# [(1, 0.95283026)]
# [(3, 0.65686274), (4, 0.33006537)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(3, 0.98366016)]
# [(1, 0.6169573), (2, 0.3699708)]
# [(2, 0.99011856)]
# [(2, 0.97572815)]
# [(2, 0.98366016)]
# [(1, 0.95283026)]
# [(0, 0.06544343), (2, 0.79854846), (4, 0.13451265)]
# [(1, 0.98768467)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(2, 0.5948617), (5, 0.39723322)]
# [(0, 0.19960472), (2, 0.7924901)]
# [(1, 0.37452796), (2, 0.6198063)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(0, 0.33006537), (1, 0.6568627)]
# [(1, 0.97572815)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(4, 0.33006537), (5, 0.65686274)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(3, 0.42849886), (4, 0.55842924)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.49507388)]
# [(5, 0.95283026)]
# [(0, 0.43146268), (4, 0.54911983)]
# [(1, 0.33006537), (2, 0.6568627)]
# [(1, 0.5948617), (3, 0.39723322)]
# [(2, 0.76547664), (3, 0.22661823)]
# [(1, 0.31330064), (2, 0.43054172), (4, 0.24876848)]
# [(3, 0.97572815)]
# [(0, 0.11147902), (2, 0.23467909), (3, 0.24319391), (4, 0.40844044)]
# [(1, 0.589801), (4, 0.39712706)]
# [(2, 0.98366016)]
# [(1, 0.61183673), (2, 0.37509137)]
# [(2, 0.97572815)]
# [(0, 0.33006537), (1, 0.33006534), (5, 0.33006534)]
# [(1, 0.58978903), (4, 0.39713904)]
# [(0, 0.16666667), (2, 0.66171616), (3, 0.16666667)]
# [(1, 0.24876848), (4, 0.7413793)]
# [(1, 0.63647115), (2, 0.3504569)]
# [(2, 0.49669966), (4, 0.49669966)]
# [(0, 0.31881896), (1, 0.3423332), (4, 0.33512568)]
# [(1, 0.95283026)]
# [(0, 0.42242658), (1, 0.053243116), (2, 0.15954143), (3, 0.14344704), (4, 0.07245488), (5, 0.14888695)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.19960475), (1, 0.5948617), (3, 0.19960475)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.19000465), (2, 0.5494516), (4, 0.25559327)]
# [(1, 0.95283026)]
# [(1, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(5, 0.95283026)]
# [(0, 0.37621543), (1, 0.15108584), (2, 0.4684494)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.49669966), (2, 0.33168316), (3, 0.16666667)]
# [(0, 0.24937963), (2, 0.12531017), (3, 0.12531017), (4, 0.24937963), (5, 0.24937963)]
# [(0, 0.12531017), (1, 0.17874734), (2, 0.5625749), (4, 0.13088611)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(5, 0.97572815)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(4, 0.95283026)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(1, 0.14942522), (3, 0.703266), (4, 0.14305948)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(0, 0.33106008), (2, 0.2327101), (4, 0.14248814), (5, 0.2912602)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.21139663), (4, 0.78069824)]
# [(1, 0.97572815)]
# [(1, 0.95283026)]
# [(2, 0.65686274), (4, 0.33006537)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.10187875), (1, 0.09132006), (2, 0.80408865)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(2, 0.6375794), (3, 0.35581994)]
# [(1, 0.44621164), (3, 0.54718775)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.7228298), (4, 0.26731798)]
# [(1, 0.95283026)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(2, 0.24876845), (4, 0.49507388), (5, 0.24876845)]
# [(1, 0.32453847), (3, 0.30700824), (4, 0.364204)]
# [(1, 0.3764799), (5, 0.61044824)]
# [(2, 0.97572815)]
# [(0, 0.24876848), (1, 0.45803156), (4, 0.28581077)]
# [(1, 0.98366016)]
# [(1, 0.49029127), (4, 0.4902912)]
# [(4, 0.95283026)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(2, 0.99291784)]
# [(1, 0.40851614), (4, 0.58163166)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.19214186), (1, 0.28673524), (2, 0.35115588), (4, 0.16666666)]
# [(2, 0.97572815)]
# [(0, 0.24876848), (2, 0.49507388), (3, 0.24876848)]
# [(0, 0.49029127), (3, 0.4902912)]
# [(0, 0.99011856)]
# [(2, 0.97572815)]
# [(0, 0.3300653), (1, 0.33006537), (3, 0.33006537)]
# [(4, 0.98366016)]
# [(2, 0.95283026)]
# [(2, 0.9950298)]
# [(1, 0.20450684), (2, 0.19313875), (3, 0.24799389), (4, 0.24566859), (5, 0.108167246)]
# [(1, 0.97572815)]
# [(2, 0.72266465), (3, 0.27166963)]
# [(3, 0.97572815)]
# [(0, 0.40447548), (1, 0.11402039), (2, 0.362886), (4, 0.116410606)]
# [(2, 0.49029127), (5, 0.4902912)]
# [(2, 0.95283026)]
# [(0, 0.43730238), (2, 0.28516), (3, 0.27014843)]
# [(4, 0.97572815)]
# [(1, 0.98366016)]
# [(0, 0.98768467)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(4, 0.97572815)]
# [(2, 0.97572815)]
# [(4, 0.97572815)]
# [(0, 0.47944927), (2, 0.23159888), (5, 0.28470254)]
# [(0, 0.97572815)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(0, 0.075124584), (1, 0.14457378), (3, 0.07183499), (4, 0.7070441)]
# [(2, 0.66171616), (3, 0.33168313)]
# [(0, 0.40096208), (4, 0.47904885), (5, 0.1175015)]
# [(0, 0.24876848), (2, 0.74137926)]
# [(5, 0.95283026)]
# [(1, 0.30072632), (2, 0.5541812), (5, 0.14295876)]
# [(2, 0.99011856)]
# [(2, 0.49029127), (3, 0.4902912)]
# [(0, 0.98366016)]
# [(4, 0.4902912), (5, 0.49029127)]
# [(2, 0.24876848), (4, 0.7413793)]
# [(5, 0.95283026)]
# [(0, 0.33006537), (1, 0.33006537), (3, 0.33006537)]
# [(4, 0.98366016)]
# [(2, 0.65686274), (5, 0.33006537)]
# [(1, 0.7828612), (2, 0.20923367)]
# [(2, 0.97572815)]
# [(2, 0.97572815)]
# [(4, 0.98366016)]
# [(5, 0.95283026)]
# [(1, 0.578655), (4, 0.40827304)]
# [(1, 0.24876848), (4, 0.7413793)]
# [(0, 0.25848654), (1, 0.19960475), (4, 0.53597987)]
# [(2, 0.97572815)]
# [(4, 0.49029133), (5, 0.4902912)]
# [(3, 0.97572815)]
# [(0, 0.65686274), (1, 0.33006537)]
# [(3, 0.24876848), (4, 0.7413793)]
# [(5, 0.95283026)]
# [(5, 0.95283026)]
# [(2, 0.98366016)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.49507383), (1, 0.24876848), (5, 0.24876848)]
# [(1, 0.97572815)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(0, 0.6568627), (2, 0.33006537)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.27202967), (2, 0.24876848), (3, 0.47181273)]
# [(2, 0.98366016)]
# [(2, 0.39723322), (4, 0.5948617)]
# [(1, 0.26572758), (3, 0.7244202)]
# [(2, 0.82673264), (5, 0.16666666)]
# [(0, 0.33168316), (3, 0.49669966), (5, 0.16666667)]
# [(2, 0.97572815)]
# [(0, 0.24876845), (3, 0.24876845), (4, 0.24876848), (5, 0.24876848)]
# [(4, 0.97572815)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(0, 0.09326882), (2, 0.10363972), (3, 0.800379)]
# [(1, 0.46616694), (3, 0.24876848), (4, 0.2776754)]
# [(1, 0.95283026)]
# [(0, 0.11147902), (2, 0.5277521), (3, 0.3574576)]
# [(1, 0.30127516), (3, 0.6908197)]
# [(4, 0.95283026)]
# [(0, 0.49507388), (1, 0.24876845), (5, 0.24876845)]
# [(2, 0.3888537), (3, 0.24876848), (4, 0.35498872)]
# [(4, 0.98366016)]
# [(0, 0.19960472), (1, 0.7924901)]
# [(1, 0.37344912), (2, 0.6215881)]
# [(0, 0.37930438), (2, 0.21753356), (5, 0.39723322)]
# [(1, 0.95283026)]
# [(1, 0.98366016)]
# [(1, 0.25751463), (3, 0.48632777), (5, 0.24876848)]
# [(1, 0.5762815), (2, 0.16666667), (5, 0.25210136)]
# [(3, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.29193106), (1, 0.19960475), (2, 0.29035208), (3, 0.21415952)]
# [(4, 0.97572815)]
# [(0, 0.15402706), (2, 0.3436844), (3, 0.11843894), (4, 0.38164204)]
# [(1, 0.98366016)]
# [(3, 0.97572815)]
# [(1, 0.95283026)]
# [(0, 0.214592), (1, 0.14410432), (3, 0.15332791), (4, 0.48598772)]
# [(2, 0.713161), (3, 0.27698678)]
# [(4, 0.97572815)]
# [(0, 0.2933312), (1, 0.3771798), (3, 0.12017087), (4, 0.20750985)]
# [(3, 0.7413793), (5, 0.24876848)]
# [(0, 0.97572815)]
# [(1, 0.5569792), (2, 0.43511567)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(2, 0.65686274), (5, 0.33006537)]
# [(1, 0.97572815)]
# [(0, 0.1553265), (2, 0.6759074), (4, 0.16451684)]
# [(1, 0.95283026)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(0, 0.97572815)]
# [(0, 0.12531017), (1, 0.12531017), (2, 0.74565756)]
# [(2, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.16666666), (2, 0.82673264)]
# [(2, 0.97572815)]
# [(0, 0.3360625), (1, 0.44530895), (2, 0.08374792), (3, 0.13322227)]
# [(1, 0.65686274), (2, 0.33006537)]
# [(1, 0.3378093), (2, 0.5148819), (5, 0.14305948)]
# [(0, 0.12531017), (2, 0.71218115), (4, 0.15878662)]
# [(2, 0.52815324), (4, 0.4619946)]
# [(0, 0.0983331), (1, 0.2200571), (2, 0.28186452), (3, 0.14775996), (5, 0.2510811)]
# [(1, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.6114855), (2, 0.3754426)]
# [(0, 0.19960472), (2, 0.7924901)]
# [(0, 0.39657003), (2, 0.13563603), (3, 0.16293705), (4, 0.30398956)]
# [(2, 0.98366016)]
# [(1, 0.97572815)]
# [(1, 0.33168316), (2, 0.3141847), (3, 0.18416518), (5, 0.16666667)]
# [(2, 0.95283026)]
# [(1, 0.36981943), (3, 0.6171087)]
# [(3, 0.4902912), (4, 0.49029127)]
# [(1, 0.97572815)]
# [(0, 0.97572815)]
# [(2, 0.97572815)]
# [(5, 0.95283026)]
# [(2, 0.97572815)]
# [(5, 0.95283026)]
# [(0, 0.32850164), (1, 0.33222955), (3, 0.22558223), (4, 0.11147902)]
# [(0, 0.33006537), (4, 0.65686274)]
# [(2, 0.49029127), (4, 0.49029127)]
# [(4, 0.98768467)]
# [(5, 0.95283026)]
# [(2, 0.97572815)]
# [(0, 0.97572815)]
# [(4, 0.99011856)]
# [(0, 0.1377752), (1, 0.3031669), (3, 0.18080553), (4, 0.3760449)]
# [(3, 0.49029127), (5, 0.49029127)]
# [(0, 0.70404327), (4, 0.14864798), (5, 0.14305949)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(4, 0.95283026)]
# [(4, 0.99011856)]
# [(3, 0.98366016)]
# [(5, 0.95283026)]
# [(2, 0.33006537), (5, 0.65686274)]
# [(0, 0.95283026)]
# [(0, 0.50489867), (5, 0.48202944)]
# [(2, 0.98366016)]
# [(1, 0.95283026)]
# [(0, 0.17491573), (1, 0.35350564), (3, 0.46662816)]
# [(3, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.24876848), (4, 0.49507388), (5, 0.24876848)]
# [(1, 0.97572815)]
# [(3, 0.35325837), (4, 0.6368894)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(2, 0.98768467)]
# [(2, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(4, 0.64313954), (5, 0.34700826)]
# [(0, 0.11147904), (1, 0.15117826), (2, 0.15839244), (4, 0.5767427)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(4, 0.97572815)]
# [(0, 0.12636143), (1, 0.124885924), (4, 0.6214212), (5, 0.12512396)]
# [(3, 0.65686274), (5, 0.33006537)]
# [(3, 0.14305948), (4, 0.8512748)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(2, 0.49029127), (4, 0.49029127)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.98366016)]
# [(1, 0.2840611), (2, 0.24876848), (5, 0.4597813)]
# [(3, 0.65686274), (4, 0.33006537)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(2, 0.95283026)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.1885864), (1, 0.46546814), (4, 0.34099495)]
# [(2, 0.41293284), (4, 0.579162)]
# [(3, 0.65686274), (4, 0.33006537)]
# [(1, 0.14828435), (2, 0.5299137), (3, 0.22223659), (4, 0.09775703)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.49507388), (2, 0.49507388)]
# [(1, 0.19013557), (4, 0.80419874)]
# [(2, 0.28293923), (4, 0.7072085)]
# [(0, 0.3300653), (4, 0.65686274)]
# [(0, 0.54233277), (3, 0.43824974)]
# [(1, 0.33006534), (2, 0.33006534), (3, 0.3300654)]
# [(1, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.49507394), (1, 0.24876848), (2, 0.24876845)]
# [(0, 0.5598591), (3, 0.25753915), (5, 0.17765126)]
# [(3, 0.97572815)]
# [(3, 0.33006537), (5, 0.65686274)]
# [(4, 0.97572815)]
# [(0, 0.7296806), (5, 0.26046717)]
# [(4, 0.97572815)]
# [(3, 0.95283026)]
# [(4, 0.97572815)]
# [(1, 0.33006537), (4, 0.65686274)]
# [(1, 0.95283026)]
# [(2, 0.95283026)]
# [(1, 0.6985494), (2, 0.29159838)]
# [(1, 0.40818816), (4, 0.58195955)]
# [(0, 0.16666667), (2, 0.2556993), (4, 0.5726836)]
# [(1, 0.38311794), (3, 0.36911353), (4, 0.24183965)]
# [(0, 0.49507388), (4, 0.49507388)]
# [(4, 0.95283026)]
# [(4, 0.95283026)]
# [(1, 0.6078275), (4, 0.37910062)]
# [(1, 0.98768467)]
# [(1, 0.95283026)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(1, 0.24160121), (2, 0.5232405), (3, 0.22922938)]
# [(2, 0.7227973), (4, 0.26735052)]
# [(1, 0.98768467)]
# [(1, 0.3765927), (5, 0.61033535)]
# [(4, 0.97572815)]
# [(2, 0.98366016)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.6455698), (2, 0.34782955)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.17185482), (4, 0.8224794)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.95283026)]
# [(2, 0.5948617), (4, 0.39723322)]
# [(1, 0.98366016)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(1, 0.4325322), (2, 0.27653092), (3, 0.28354776)]
# [(1, 0.49286172), (2, 0.19960472), (4, 0.3016047)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.26740867), (1, 0.39949515), (2, 0.21155162), (3, 0.046862103), (4, 0.07422915)]
# [(0, 0.19960475), (1, 0.39723322), (3, 0.39723322)]
# [(3, 0.49029127), (4, 0.4902912)]
# [(2, 0.95283026)]
# [(0, 0.39884177), (3, 0.5880863)]
# [(1, 0.98366016)]
# [(0, 0.45866692), (3, 0.16891238), (4, 0.3699331)]
# [(0, 0.97572815)]
# [(5, 0.97572815)]
# [(1, 0.46630833), (2, 0.2842565), (4, 0.24204609)]
# [(1, 0.97572815)]
# [(1, 0.7413793), (3, 0.24876848)]
# [(0, 0.25691032), (1, 0.07291461), (2, 0.6692092)]
# [(1, 0.98366016)]
# [(1, 0.33168322), (3, 0.66171616)]
# [(0, 0.455704), (1, 0.53769535)]
# [(5, 0.95283026)]
# [(1, 0.95283026)]
# [(2, 0.7691711), (3, 0.22422822)]
# [(1, 0.14305948), (4, 0.6647997), (5, 0.1878915)]
# [(1, 0.24876848), (3, 0.24876851), (5, 0.49507388)]
# [(0, 0.49507388), (2, 0.49507388)]
# [(5, 0.95283026)]
# [(2, 0.5948616), (4, 0.19960476), (5, 0.19960475)]
# [(0, 0.11528236), (3, 0.22055446), (4, 0.45913854), (5, 0.20360218)]
# [(2, 0.98366016)]
# [(2, 0.33006537), (4, 0.65686274)]
# [(0, 0.16666667), (1, 0.35244405), (2, 0.14590581), (5, 0.33168316)]
# [(0, 0.0736852), (1, 0.24564101), (2, 0.10434894), (3, 0.45498788), (5, 0.120625705)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(1, 0.98768467)]
# [(4, 0.9937965)]
# [(0, 0.95283026)]
# [(0, 0.33006537), (3, 0.65686274)]
# [(2, 0.97572815)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(2, 0.65686274), (3, 0.33006537)]
# [(0, 0.95283026)]
# [(2, 0.49507388), (3, 0.49507388)]
# [(0, 0.12248866), (1, 0.23364402), (3, 0.20484471), (5, 0.43777728)]
# [(2, 0.33006537), (4, 0.65686274)]
# [(0, 0.65686274), (4, 0.33006537)]
# [(1, 0.49507388), (4, 0.24876848), (5, 0.24876851)]
# [(0, 0.24089451), (2, 0.17602473), (3, 0.2708506), (4, 0.21492703), (5, 0.09684979)]
# [(0, 0.11265013), (4, 0.88403314)]
# [(0, 0.18234919), (1, 0.16005026), (2, 0.23960984), (3, 0.16274168), (4, 0.25453782)]
# [(1, 0.98366016)]
# [(2, 0.13315094), (4, 0.8122846), (5, 0.052990556)]
# [(0, 0.95283026)]
# [(0, 0.24876848), (1, 0.7413793)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(1, 0.97572815)]
# [(5, 0.95283026)]
# [(2, 0.49507383), (4, 0.49507388)]
# [(0, 0.97572815)]
# [(1, 0.98366016)]
# [(0, 0.26730388), (2, 0.37123612), (3, 0.3591629)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.38452917), (1, 0.18242374), (2, 0.2433788), (3, 0.10871308), (4, 0.08018947)]
# [(4, 0.97572815)]
# [(2, 0.98366016)]
# [(4, 0.97572815)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(1, 0.33006534), (4, 0.6568628)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.98366016)]
# [(0, 0.33006537), (1, 0.33006537), (3, 0.33006537)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(1, 0.97572815)]
# [(0, 0.69372797), (4, 0.20289226), (5, 0.10039761)]
# [(0, 0.99011856)]
# [(0, 0.19960472), (1, 0.7924901)]
# [(1, 0.3126194), (2, 0.2631), (4, 0.4230337)]
# [(5, 0.97572815)]
# [(0, 0.24876845), (1, 0.49507388), (2, 0.24876845)]
# [(1, 0.4824742), (4, 0.5044539)]
# [(5, 0.95283026)]
# [(4, 0.33006537), (5, 0.65686274)]
# [(3, 0.97572815)]
# [(0, 0.49507388), (1, 0.24876848), (2, 0.24876848)]
# [(1, 0.37454608), (2, 0.6197882)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.98366016)]
# [(5, 0.97572815)]
# [(1, 0.97572815)]
# [(2, 0.98366016)]
# [(2, 0.65686274), (4, 0.33006537)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.25250512), (2, 0.28470254), (4, 0.28470254), (5, 0.17525691)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(1, 0.98366016)]
# [(2, 0.65686274), (3, 0.33006537)]
# [(0, 0.24876848), (3, 0.74137926)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(1, 0.97572815)]
# [(4, 0.95283026)]
# [(3, 0.74137926), (5, 0.24876848)]
# [(5, 0.97572815)]
# [(5, 0.95283026)]
# [(0, 0.11147902), (1, 0.2164708), (2, 0.11686252), (4, 0.5529801)]
# [(0, 0.65686274), (4, 0.33006537)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.65686274), (5, 0.33006537)]
# [(2, 0.97572815)]
# [(4, 0.65686274), (5, 0.33006537)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.97572815)]
# [(0, 0.20170641), (1, 0.24760431), (2, 0.28625125), (4, 0.11635784), (5, 0.14725102)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(0, 0.19960476), (1, 0.19960475), (2, 0.37845516), (3, 0.21838275)]
# [(1, 0.39723322), (2, 0.5948617)]
# [(1, 0.26700518), (3, 0.29340193), (4, 0.16578788), (5, 0.27097216)]
# [(1, 0.97572815)]
# [(0, 0.37344912), (3, 0.24937963), (4, 0.37344912)]
# [(4, 0.97572815)]
# [(2, 0.97572815)]
# [(2, 0.49029127), (4, 0.4902912)]
# [(1, 0.33006537), (5, 0.65686274)]
# [(1, 0.97572815)]
# [(2, 0.73513865), (4, 0.2598985)]
# [(4, 0.98366016)]
# [(0, 0.38158333), (1, 0.051278442), (3, 0.51042473), (4, 0.055716492)]
# [(2, 0.65686274), (5, 0.33006537)]
# [(2, 0.97572815)]
# [(3, 0.7924901), (5, 0.19960472)]
# [(2, 0.97572815)]
# [(2, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.95283026)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(0, 0.33168316), (1, 0.30881783), (2, 0.189532), (3, 0.16666667)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.3300653), (2, 0.65686274)]
# [(0, 0.39723322), (2, 0.5948617)]
# [(1, 0.3002471), (5, 0.69408715)]
# [(2, 0.24876848), (3, 0.34205168), (4, 0.40179068)]
# [(2, 0.62567586), (3, 0.36125225)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.97572815)]
# [(0, 0.25323564), (4, 0.5913909), (5, 0.15206222)]
# [(0, 0.3300653), (4, 0.65686274)]
# [(4, 0.98366016)]
# [(0, 0.33006534), (4, 0.6568628)]
# [(2, 0.98366016)]
# [(2, 0.7737307), (3, 0.2218543)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(0, 0.15274237), (2, 0.69994885), (5, 0.14305949)]
# [(0, 0.3300653), (5, 0.65686274)]
# [(2, 0.95283026)]
# [(2, 0.95283026)]
# [(1, 0.98366016)]
# [(1, 0.24281448), (2, 0.50628793), (4, 0.24496871)]
# [(3, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.33006537), (4, 0.65686274)]
# [(1, 0.97572815)]
# [(1, 0.64084744), (2, 0.34608066)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.49507388)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.48475093), (4, 0.5073439)]
# [(1, 0.95283026)]
# [(1, 0.97572815)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(1, 0.98366016)]
# [(1, 0.61161226), (2, 0.37531587)]
# [(0, 0.65686274), (3, 0.33006537)]
# [(1, 0.95283026)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(3, 0.97572815)]
# [(2, 0.95283026)]
# [(0, 0.65686274), (5, 0.33006537)]
# [(1, 0.97572815)]
# [(1, 0.99174917)]
# [(1, 0.22021814), (2, 0.46850032), (3, 0.30633104)]
# [(0, 0.23528261), (2, 0.13940723), (4, 0.62158805)]
# [(0, 0.69537234), (2, 0.0903471), (5, 0.21179299)]
# [(5, 0.95283026)]
# [(0, 0.30739954), (1, 0.68469536)]
# [(0, 0.4008006), (2, 0.12531018), (4, 0.24937966), (5, 0.22202823)]
# [(4, 0.99011856)]
# [(1, 0.95283026)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(0, 0.98366016)]
# [(2, 0.49903134), (4, 0.49530295)]
# [(0, 0.33006537), (4, 0.65686274)]
# [(0, 0.12531017), (3, 0.13370316), (4, 0.7372646)]
# [(2, 0.7924901), (5, 0.19960472)]
# [(1, 0.65686274), (3, 0.33006537)]
# [(1, 0.6334019), (2, 0.18500543), (4, 0.17664224)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(1, 0.5948617), (5, 0.39723322)]
# [(1, 0.62212616), (4, 0.36480188)]
# [(2, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.97572815)]
# [(1, 0.6568628), (5, 0.33006534)]
# [(0, 0.40173063), (1, 0.079160914), (3, 0.34810895), (4, 0.1694681)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(4, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.6420117), (3, 0.17656527), (4, 0.17647253)]
# [(1, 0.49029127), (2, 0.4902912)]
# [(1, 0.6376695), (4, 0.35572985)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(1, 0.97572815)]
# [(2, 0.73341376), (3, 0.2586811)]
# [(0, 0.49507388), (2, 0.24876848), (3, 0.24876848)]
# [(1, 0.95283026)]
# [(5, 0.97572815)]
# [(2, 0.98768467)]
# [(5, 0.97572815)]
# [(0, 0.16666666), (2, 0.24444951), (3, 0.2547213), (4, 0.08374792), (5, 0.24958539)]
# [(1, 0.97572815)]
# [(1, 0.98768467)]
# [(1, 0.23316753), (4, 0.7602318)]
# [(0, 0.97572815)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.33006534), (1, 0.6568628)]
# [(0, 0.47553152), (1, 0.14729725), (2, 0.37344912)]
# [(0, 0.49669966), (3, 0.31738788), (4, 0.1809619)]
# [(4, 0.7413793), (5, 0.24876848)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(1, 0.97572815)]
# [(3, 0.99011856)]
# [(4, 0.65686274), (5, 0.33006537)]
# [(1, 0.4581494), (4, 0.28569296), (5, 0.24876848)]
# [(0, 0.16496938), (1, 0.48113877), (4, 0.34964257)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(4, 0.98366016)]
# [(5, 0.95283026)]
# [(1, 0.3074314), (2, 0.3195338), (3, 0.21068984), (4, 0.16053668)]
# [(5, 0.95283026)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.6409141), (2, 0.346014)]
# [(2, 0.66908044), (3, 0.3243189)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(2, 0.4277144), (3, 0.31612796), (5, 0.24876848)]
# [(0, 0.16666666), (1, 0.66171616), (5, 0.16666666)]
# [(2, 0.99291784)]
# [(0, 0.98366016)]
# [(2, 0.49029127), (5, 0.4902912)]
# [(2, 0.74137926), (3, 0.24876848)]
# [(1, 0.98366016)]
# [(1, 0.98768467)]
# [(2, 0.97572815)]
# [(1, 0.98366016)]
# [(2, 0.4614192), (3, 0.53198016)]
# [(5, 0.95283026)]
# [(2, 0.97572815)]
# [(0, 0.56791097), (3, 0.42223683)]
# [(0, 0.97572815)]
# [(1, 0.24876845), (2, 0.49507388), (3, 0.24876845)]
# [(2, 0.727941), (3, 0.2622068)]
# [(1, 0.97572815)]
# [(1, 0.98366016)]
# [(0, 0.43759495), (1, 0.24937963), (2, 0.12531017), (3, 0.1852338)]
# [(1, 0.98366016)]
# [(1, 0.42195842), (2, 0.56818944)]
# [(2, 0.97572815)]
# [(5, 0.95283026)]
# [(2, 0.6187868), (4, 0.18025851), (5, 0.1960042)]
# [(0, 0.33006537), (3, 0.65686274)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(2, 0.98768467)]
# [(1, 0.95283026)]
# [(0, 0.14305949), (1, 0.5282963), (2, 0.3243949)]
# [(2, 0.49507388), (4, 0.49507388)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.95283026)]
# [(2, 0.99174917)]
# [(4, 0.98366016)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.6568628), (5, 0.33006534)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(1, 0.95283026)]
# [(1, 0.97572815)]
# [(4, 0.97572815)]
# [(0, 0.6568628), (1, 0.33006534)]
# [(4, 0.97572815)]
# [(4, 0.95283026)]
# [(1, 0.1629062), (2, 0.2363033), (3, 0.5948617)]
# [(0, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(4, 0.97572815)]
# [(0, 0.33006537), (1, 0.33006537), (2, 0.33006537)]
# [(0, 0.4902912), (2, 0.49029127)]
# [(2, 0.98366016)]
# [(4, 0.97572815)]
# [(0, 0.24876845), (2, 0.74137926)]
# [(1, 0.4902912), (3, 0.49029127)]
# [(0, 0.97572815)]
# [(4, 0.65686274), (5, 0.33006537)]
# [(1, 0.49029127), (5, 0.4902912)]
# [(1, 0.2787619), (2, 0.5922059), (3, 0.12531017)]
# [(0, 0.26285413), (1, 0.51001626), (3, 0.16263656), (5, 0.06344366)]
# [(4, 0.97572815)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(1, 0.95283026)]
# [(1, 0.98366016)]
# [(1, 0.98768467)]
# [(0, 0.0769465), (1, 0.20049141), (2, 0.19483235), (3, 0.4053387), (4, 0.12172701)]
# [(0, 0.33006537), (5, 0.65686274)]
# [(5, 0.97572815)]
# [(3, 0.97572815)]
# [(1, 0.5545315), (4, 0.43756336)]
# [(2, 0.98366016)]
# [(0, 0.162639), (2, 0.38596717), (3, 0.3055015), (5, 0.14305949)]
# [(0, 0.49029127), (5, 0.4902912)]
# [(0, 0.37149024), (5, 0.61543787)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(0, 0.5299822), (1, 0.45694584)]
# [(2, 0.14221808), (3, 0.19809875), (4, 0.12531017), (5, 0.53189164)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.95283026)]
# [(0, 0.12075332), (1, 0.17179054), (3, 0.14572994), (4, 0.36384135), (5, 0.1975912)]
# [(4, 0.97572815)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.25745732), (1, 0.19076872), (3, 0.4177684), (4, 0.1317981)]
# [(1, 0.97572815)]
# [(0, 0.09132007), (1, 0.15395439), (2, 0.11498251), (3, 0.2227126), (4, 0.41612625)]
# [(1, 0.98366016)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(0, 0.24876848), (1, 0.49507388), (3, 0.24876848)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(2, 0.7942723), (4, 0.20131265)]
# [(2, 0.86596954), (4, 0.12906773)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.49669966), (1, 0.49669963)]
# [(0, 0.98366016)]
# [(1, 0.20583485), (4, 0.29292443), (5, 0.4975186)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.70963174), (5, 0.28470254)]
# [(1, 0.4086444), (4, 0.5815034)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(1, 0.7413793), (3, 0.24876848)]
# [(3, 0.95283026)]
# [(0, 0.33006537), (2, 0.33006537), (4, 0.33006537)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(1, 0.24876848), (2, 0.74137926)]
# [(2, 0.40155065), (3, 0.5885971)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(2, 0.30625188), (4, 0.685843)]
# [(2, 0.98366016)]
# [(0, 0.97572815)]
# [(0, 0.65686274), (2, 0.33006537)]
# [(0, 0.28470254), (1, 0.22327013), (2, 0.487778)]
# [(1, 0.95283026)]
# [(1, 0.95283026)]
# [(1, 0.32783222), (3, 0.19960475), (4, 0.4666342)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.95283026)]
# [(1, 0.3041572), (2, 0.6879376)]
# [(4, 0.97572815)]
# [(1, 0.52234566), (2, 0.4645824)]
# [(1, 0.97572815)]
# [(0, 0.14651556), (3, 0.84781873)]
# [(1, 0.3300653), (5, 0.65686274)]
# [(0, 0.33006537), (3, 0.33006537), (4, 0.33006537)]
# [(0, 0.97572815)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(2, 0.95283026)]
# [(0, 0.25392833), (1, 0.19188604), (2, 0.5492351)]
# [(0, 0.37344918), (1, 0.18784934), (4, 0.43497944)]
# [(0, 0.95283026)]
# [(0, 0.14100564), (1, 0.15738219), (2, 0.31089112), (3, 0.10039762), (4, 0.28932944)]
# [(1, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.58029115), (1, 0.2141753), (5, 0.19960475)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(0, 0.362517), (2, 0.19447862), (3, 0.44029194)]
# [(1, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.33006537), (5, 0.65686274)]
# [(1, 0.98366016)]
# [(1, 0.97572815)]
# [(4, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(0, 0.19960472), (1, 0.7924901)]
# [(2, 0.98366016)]
# [(1, 0.39723322), (3, 0.5948616)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.2638213), (2, 0.29806134), (3, 0.18816687), (4, 0.13640435), (5, 0.113176554)]
# [(0, 0.14305949), (2, 0.37037656), (4, 0.48231465)]
# [(2, 0.598069), (4, 0.38885912)]
# [(0, 0.7413793), (1, 0.24876848)]
# [(1, 0.98366016)]
# [(1, 0.33006537), (3, 0.25791144), (4, 0.40221927)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.16684675), (3, 0.28733304), (4, 0.41603464), (5, 0.12836307)]
# [(1, 0.33250412), (2, 0.66417915)]
# [(0, 0.30575278), (1, 0.35761356), (3, 0.33168316)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.14305949), (2, 0.23931715), (4, 0.33008796), (5, 0.28470254)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(0, 0.24876848), (3, 0.49507388), (4, 0.24876848)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.33168316), (5, 0.16666667)]
# [(0, 0.2653736), (1, 0.27772835), (2, 0.4519476)]
# [(2, 0.98768467)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.98366016)]
# [(2, 0.98768467)]
# [(0, 0.37344915), (1, 0.36292887), (3, 0.13583046), (5, 0.12531018)]
# [(3, 0.97572815)]
# [(0, 0.11792617), (1, 0.26026988), (3, 0.29237124), (5, 0.3274446)]
# [(1, 0.97572815)]
# [(0, 0.43928605), (2, 0.24876848), (5, 0.30455628)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(1, 0.3078482), (2, 0.14305949), (3, 0.3945127), (5, 0.15174673)]
# [(1, 0.7036627), (2, 0.28648514)]
# [(0, 0.95283026)]
# [(4, 0.98366016)]
# [(4, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.32232228), (4, 0.24876848), (5, 0.42152005)]
# [(1, 0.53106546), (2, 0.24667156), (3, 0.21633409)]
# [(0, 0.4119263), (4, 0.15451103), (5, 0.42984062)]
# [(2, 0.98768467)]
# [(1, 0.16666666), (2, 0.82673264)]
# [(2, 0.4902912), (3, 0.49029127)]
# [(0, 0.12531017), (1, 0.28240892), (2, 0.46448934), (3, 0.12531017)]
# [(2, 0.62581134), (3, 0.36111677)]
# [(2, 0.98366016)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(2, 0.98768467)]
# [(1, 0.98768467)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.15475194), (2, 0.25270197), (3, 0.30501068), (5, 0.28470254)]
# [(3, 0.65686274), (5, 0.33006537)]
# [(2, 0.99174917)]
# [(1, 0.97572815)]
# [(1, 0.08374792), (2, 0.7819946), (3, 0.13176994)]
# [(1, 0.28470254), (3, 0.70963174)]
# [(0, 0.3104009), (2, 0.19902518), (4, 0.34903017), (5, 0.14021574)]
# [(0, 0.97572815)]
# [(1, 0.97572815)]
# [(1, 0.65686274), (2, 0.33006537)]
# [(0, 0.19960475), (1, 0.5781639), (3, 0.21630242)]
# [(0, 0.49507388), (3, 0.24876851), (5, 0.24876848)]
# [(2, 0.98366016)]
# [(2, 0.97572815)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(4, 0.97572815)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.16666667), (1, 0.57652336), (5, 0.2518595)]
# [(0, 0.1680662), (2, 0.24350822), (3, 0.09710326), (4, 0.42588255), (5, 0.0651178)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.19960475), (2, 0.39723322), (4, 0.39723322)]
# [(0, 0.11150245), (1, 0.44321904), (2, 0.30881825), (4, 0.13447213)]
# [(3, 0.97572815)]
# [(1, 0.58161247), (2, 0.40531564)]
# [(5, 0.95283026)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(1, 0.97572815)]
# [(2, 0.98366016)]
# [(5, 0.95283026)]
# [(5, 0.95283026)]
# [(1, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.98366016)]
# [(3, 0.97572815)]
# [(0, 0.350691), (1, 0.29257616), (2, 0.0510434), (3, 0.082826324), (5, 0.22238825)]
# [(0, 0.97572815)]
# [(1, 0.98366016)]
# [(3, 0.95283026)]
# [(1, 0.3551631), (2, 0.38867927), (5, 0.24876848)]
# [(0, 0.6097685), (3, 0.22107728), (5, 0.16666666)]
# [(2, 0.95283026)]
# [(4, 0.97572815)]
# [(0, 0.95283026)]
# [(2, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.62461036), (2, 0.3655374)]
# [(1, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.97572815)]
# [(0, 0.99174917)]
# [(0, 0.24876851), (3, 0.24876848), (4, 0.49507388)]
# [(1, 0.42634562), (2, 0.40139464), (4, 0.16801047)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(0, 0.45392957), (1, 0.24450885), (5, 0.29825035)]
# [(0, 0.24876848), (1, 0.45818752), (4, 0.2856548)]
# [(0, 0.64571184), (1, 0.093182676), (3, 0.25861788)]
# [(1, 0.8661745), (2, 0.12886271)]
# [(0, 0.39723322), (5, 0.5948617)]
# [(1, 0.27190924), (2, 0.50063974), (4, 0.22152217)]
# [(2, 0.8200342), (4, 0.17336513)]
# [(1, 0.97572815)]
# [(0, 0.12773985), (2, 0.12531017), (5, 0.7432279)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(1, 0.95283026)]
# [(0, 0.1897577), (2, 0.8036416)]
# [(2, 0.62853134), (5, 0.36356348)]
# [(2, 0.14305949), (3, 0.564184), (4, 0.2885072)]
# [(0, 0.5072209), (1, 0.47970715)]
# [(1, 0.6029166), (4, 0.3904827)]
# [(0, 0.084003404), (1, 0.31327564), (2, 0.096394725), (4, 0.078098275), (5, 0.42760527)]
# [(1, 0.98366016)]
# [(4, 0.6568628), (5, 0.33006534)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(2, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(4, 0.99174917)]
# [(1, 0.95283026)]
# [(2, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.49741343), (1, 0.4946814)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(2, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.95283026)]
# [(0, 0.14490794), (2, 0.7016936), (3, 0.15110134)]
# [(2, 0.6361062), (4, 0.3540416)]
# [(2, 0.75523543), (3, 0.08182337), (4, 0.07733537), (5, 0.08407444)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.21171126), (1, 0.46581414), (2, 0.31949246)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(2, 0.7286744), (3, 0.26342043)]
# [(2, 0.82673264), (5, 0.16666666)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(3, 0.98366016)]
# [(1, 0.65686274), (4, 0.33006537)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.95283026)]
# [(1, 0.57725567), (2, 0.40967244)]
# [(0, 0.33006537), (5, 0.65686274)]
# [(2, 0.67983913), (4, 0.31356025)]
# [(1, 0.53581613), (2, 0.1511685), (3, 0.30876607)]
# [(2, 0.98366016)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(1, 0.98768467)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.506625), (1, 0.48352277)]
# [(2, 0.5948616), (3, 0.19960475), (4, 0.19960475)]
# [(4, 0.98366016)]
# [(2, 0.79249007), (5, 0.19960475)]
# [(0, 0.24876848), (1, 0.7413793)]
# [(4, 0.97572815)]
# [(2, 0.98366016)]
# [(2, 0.97572815)]
# [(0, 0.24876845), (2, 0.49507388), (5, 0.24876845)]
# [(1, 0.95283026)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(1, 0.1547397), (2, 0.83959454)]
# [(1, 0.98366016)]
# [(1, 0.97572815)]
# [(0, 0.3319822), (1, 0.27927256), (2, 0.09635868), (4, 0.29114127)]
# [(0, 0.39723322), (1, 0.19960476), (4, 0.19960475), (5, 0.19960475)]
# [(1, 0.98366016)]
# [(1, 0.95283026)]
# [(1, 0.98768467)]
# [(3, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.24876848), (2, 0.24876848), (3, 0.49507388)]
# [(2, 0.24876848), (3, 0.49507388), (4, 0.24876848)]
# [(4, 0.98366016)]
# [(5, 0.97572815)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.19960475), (2, 0.5714326), (3, 0.22303382)]
# [(1, 0.33006537), (4, 0.6568627)]
# [(5, 0.97572815)]
# [(1, 0.98366016)]
# [(1, 0.97572815)]
# [(5, 0.95283026)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(5, 0.95283026)]
# [(4, 0.98366016)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.42868507), (4, 0.5663521)]
# [(4, 0.98366016)]
# [(1, 0.33006534), (5, 0.6568628)]
# [(5, 0.95283026)]
# [(1, 0.95283026)]
# [(2, 0.98366016)]
# [(2, 0.98366016)]
# [(2, 0.7827533), (3, 0.20934153)]
# [(1, 0.97572815)]
# [(1, 0.31519863), (3, 0.6768962)]
# [(0, 0.49507388), (1, 0.24876845), (2, 0.24876845)]
# [(0, 0.97572815)]
# [(4, 0.6568628), (5, 0.33006534)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(1, 0.5948617), (2, 0.19960475), (5, 0.19960475)]
# [(2, 0.6867638), (4, 0.30663553)]
# ...
# [(0, 0.63845783), (4, 0.3484702)]
# [(0, 0.23332576), (4, 0.5950571), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(1, 0.98366016)]
# [(2, 0.7924901), (5, 0.19960472)]
# [(2, 0.49029127), (4, 0.49029127)]
# [(2, 0.97572815)]
# [(2, 0.97572815)]
# [(1, 0.8334555), (5, 0.1615817)]
# [(5, 0.98366016)]
# [(1, 0.19960475), (2, 0.5948617), (3, 0.19960472)]
# [(2, 0.4843777), (3, 0.077335365), (4, 0.4359898)]
# [(2, 0.49029127), (3, 0.49029127)]
# [(4, 0.65686274), (5, 0.33006537)]
# [(2, 0.72285247), (4, 0.2672953)]
# [(1, 0.95283026)]
# [(1, 0.7413793), (5, 0.24876848)]
# [(0, 0.95283026)]
# [(1, 0.49507383), (2, 0.24876848), (3, 0.24876848)]
# [(2, 0.7413793), (5, 0.24876848)]
# [(1, 0.98768467)]
# [(1, 0.98366016)]
# [(0, 0.95283026)]
# [(4, 0.74137926), (5, 0.24876845)]
# [(1, 0.5178035), (3, 0.47822034)]
# [(2, 0.74137926), (5, 0.24876845)]
# [(0, 0.33168313), (2, 0.66171616)]
# [(2, 0.98768467)]
# [(1, 0.97572815)]
# [(2, 0.5679887), (3, 0.28470254), (4, 0.14305948)]
# [(1, 0.5348793), (2, 0.45721552)]
# [(1, 0.122803316), (2, 0.46685904), (4, 0.40702638)]
# [(2, 0.95283026)]
# [(1, 0.98366016)]
# [(1, 0.15813342), (2, 0.5088138), (4, 0.3288035)]
# [(3, 0.25526926), (4, 0.7316589)]
# [(1, 0.95283026)]
# [(2, 0.97572815)]
# [(1, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(2, 0.98366016)]
# [(0, 0.33006537), (2, 0.6568627)]
# [(2, 0.99174917)]
# [(3, 0.33006537), (4, 0.65686274)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.29892477), (4, 0.6931701)]
# [(0, 0.97572815)]
# [(2, 0.98768467)]
# [(1, 0.5784735), (5, 0.41167432)]
# [(2, 0.8029279), (4, 0.19047143)]
# [(4, 0.95283026)]
# [(0, 0.16666664), (1, 0.16666664), (2, 0.66171616)]
# [(5, 0.95283026)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.14305948), (1, 0.25464255), (2, 0.5980486)]
# [(4, 0.97572815)]
# [(0, 0.23142888), (1, 0.14031398), (2, 0.10112238), (3, 0.2237244), (4, 0.30295703)]
# [(0, 0.42634562), (2, 0.56798863)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.39723322), (2, 0.5948617)]
# [(1, 0.49507388), (3, 0.49507383)]
# [(0, 0.20778647), (2, 0.5148478), (3, 0.2736436)]
# [(1, 0.49507388), (3, 0.24876845), (5, 0.24876845)]
# [(1, 0.97572815)]
# [(2, 0.102598906), (3, 0.28761688), (4, 0.23789309), (5, 0.3707837)]
# [(5, 0.97572815)]
# [(4, 0.97572815)]
# [(0, 0.19960475), (2, 0.39869937), (3, 0.39576703)]
# [(2, 0.98366016)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(4, 0.97572815)]
# [(2, 0.33006537), (4, 0.65686274)]
# [(0, 0.95283026)]
# [(1, 0.6077919), (4, 0.3791362)]
# [(4, 0.95283026)]
# [(1, 0.69573677), (2, 0.29441103)]
# [(0, 0.12193005), (1, 0.2356796), (3, 0.30823877), (4, 0.33297923)]
# [(0, 0.19960476), (2, 0.39723322), (4, 0.39723322)]
# [(4, 0.97572815)]
# [(2, 0.98768467)]
# [(0, 0.95283026)]
# [(0, 0.3300653), (1, 0.65686274)]
# [(1, 0.8105862), (4, 0.1828131)]
# [(4, 0.79249007), (5, 0.19960475)]
# [(3, 0.5783005), (4, 0.4167367)]
# [(2, 0.95283026)]
# [(1, 0.98366016)]
# [(5, 0.95283026)]
# [(5, 0.95283026)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.16404384), (2, 0.30111715), (3, 0.21969904), (5, 0.31265864)]
# [(0, 0.39723322), (2, 0.5948616)]
# [(1, 0.2787245), (2, 0.7168605)]
# [(5, 0.95283026)]
# [(1, 0.98768467)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(0, 0.95283026)]
# [(3, 0.49029127), (4, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.31888992), (1, 0.08374792), (2, 0.49834162), (3, 0.097362146)]
# [(0, 0.4735599), (1, 0.37913135), (5, 0.14305949)]
# [(0, 0.12531018), (1, 0.25983515), (2, 0.47116545), (4, 0.14120783)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(2, 0.20387223), (4, 0.7882226)]
# [(3, 0.19960472), (4, 0.7924901)]
# [(1, 0.19960475), (2, 0.7924901)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.6529665), (4, 0.16963615), (5, 0.17244686)]
# [(2, 0.95283026)]
# [(1, 0.60796106), (4, 0.37896702)]
# [(0, 0.49507388), (4, 0.24876848), (5, 0.24876848)]
# [(1, 0.97572815)]
# [(1, 0.4902912), (2, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.18173598), (1, 0.18173598), (2, 0.18173598), (3, 0.3123168), (5, 0.14157104)]
# [(0, 0.1915241), (1, 0.1443078), (2, 0.40632915), (3, 0.131288), (5, 0.12531017)]
# [(2, 0.99011856)]
# [(0, 0.95283026)]
# [(2, 0.49495217), (4, 0.40166813), (5, 0.10039761)]
# [(2, 0.98366016)]
# [(1, 0.33006534), (3, 0.6568628)]
# [(2, 0.97572815)]
# [(1, 0.95283026)]
# [(1, 0.4573983), (2, 0.34090355), (3, 0.19674768)]
# [(1, 0.5569579), (2, 0.43513694)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(2, 0.98366016)]
# [(1, 0.51915675), (2, 0.2807102), (4, 0.1958838)]
# [(1, 0.2847025), (2, 0.5679887), (5, 0.14305948)]
# [(5, 0.95283026)]
# [(1, 0.24876845), (2, 0.49507388), (4, 0.24876845)]
# [(4, 0.97572815)]
# [(0, 0.08564982), (1, 0.24958539), (3, 0.6622772)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.98366016)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.95283026)]
# [(0, 0.13264595), (2, 0.7525638), (5, 0.11147902)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.95283026)]
# [(4, 0.98366016)]
# [(0, 0.97572815)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(0, 0.39723322), (1, 0.2276954), (5, 0.36914256)]
# [(0, 0.24876848), (2, 0.49507388), (4, 0.24876848)]
# [(2, 0.34635568), (4, 0.6457392)]
# [(1, 0.95283026)]
# [(2, 0.97572815)]
# [(0, 0.37376037), (1, 0.24876848), (2, 0.370082)]
# [(1, 0.97572815)]
# [(1, 0.97572815)]
# [(3, 0.33006537), (4, 0.33006537), (5, 0.33006537)]
# [(1, 0.37691152), (5, 0.6100166)]
# [(2, 0.95283026)]
# [(2, 0.16293803), (3, 0.6118964), (5, 0.2218543)]
# [(3, 0.95283026)]
# [(2, 0.65686274), (3, 0.33006537)]
# [(2, 0.49029127), (5, 0.49029127)]
# [(2, 0.97572815)]
# [(1, 0.95283026)]
# [(3, 0.95283026)]
# [(2, 0.99011856)]
# [(1, 0.3300653), (4, 0.65686274)]
# [(0, 0.47643882), (4, 0.24937966), (5, 0.27045944)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(2, 0.98366016)]
# [(1, 0.65686274), (2, 0.33006537)]
# [(0, 0.2968652), (2, 0.5615638), (4, 0.13784885)]
# [(0, 0.076407894), (3, 0.314135), (4, 0.20725475), (5, 0.40095702)]
# [(1, 0.39723322), (2, 0.5948617)]
# [(2, 0.97572815)]
# [(1, 0.49029127), (2, 0.49029127)]
# [(0, 0.19960472), (1, 0.19960472), (5, 0.5948616)]
# [(1, 0.33006537), (3, 0.65686274)]
# [(0, 0.95283026)]
# [(1, 0.63168746), (4, 0.36171186)]
# [(1, 0.95283026)]
# [(0, 0.17640017), (2, 0.5369558), (5, 0.28465202)]
# [(0, 0.24876848), (4, 0.7413793)]
# [(0, 0.28470254), (3, 0.70963174)]
# [(1, 0.2196338), (3, 0.2804664), (4, 0.155056), (5, 0.34236237)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(1, 0.18624136), (2, 0.5491824), (4, 0.2596257)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.21408235), (1, 0.11470202), (2, 0.32292038), (3, 0.23025127), (4, 0.11737999)]
# [(0, 0.97572815)]
# [(3, 0.95283026)]
# [(1, 0.97572815)]
# [(3, 0.49029127), (5, 0.49029127)]
# [(2, 0.97572815)]
# [(0, 0.23589133), (2, 0.75620353)]
# [(1, 0.720761), (4, 0.2693868)]
# [(0, 0.07303593), (1, 0.3990704), (3, 0.43433857), (5, 0.09222707)]
# [(2, 0.98768467)]
# [(0, 0.71881604), (1, 0.12102198), (4, 0.15717988)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.98768467)]
# [(3, 0.97572815)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.49507388)]
# [(1, 0.6074072), (3, 0.3795209)]
# [(1, 0.49029127), (3, 0.49029127)]
# [(2, 0.98768467)]
# [(0, 0.11081688), (1, 0.18894663), (2, 0.33932877), (3, 0.35891962)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.24876848), (3, 0.7413793)]
# [(1, 0.37668425), (5, 0.6102438)]
# [(0, 0.33006534), (1, 0.6568628)]
# [(0, 0.6568628), (3, 0.33006534)]
# [(2, 0.95283026)]
# [(1, 0.60713774), (3, 0.3797904)]
# [(5, 0.95283026)]
# [(3, 0.97572815)]
# [(0, 0.12912898), (3, 0.4833035), (4, 0.12489654), (5, 0.26149863)]
# [(5, 0.97572815)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(2, 0.65686274), (5, 0.33006537)]
# [(1, 0.46093488), (2, 0.28290743), (3, 0.24876848)]
# [(5, 0.95283026)]
# [(1, 0.97572815)]
# [(1, 0.18998545), (4, 0.80434877)]
# [(2, 0.7924901), (4, 0.19960475)]
# [(1, 0.14305948), (2, 0.8512748)]
# [(1, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(4, 0.95283026)]
# [(2, 0.74152935), (5, 0.25056553)]
# [(2, 0.97572815)]
# [(0, 0.39723316), (2, 0.5948616)]
# [(2, 0.9937965)]
# [(3, 0.41652814), (5, 0.57361966)]
# [(2, 0.97572815)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.95283026)]
# [(2, 0.99174917)]
# [(2, 0.99011856)]
# [(2, 0.98366016)]
# [(1, 0.97572815)]
# [(1, 0.95283026)]
# [(2, 0.95283026)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.29889107), (1, 0.33006537), (2, 0.3612396)]
# [(1, 0.97572815)]
# [(0, 0.49029127), (4, 0.49029127)]
# [(0, 0.29920477), (1, 0.38407612), (3, 0.10039761), (4, 0.21433339)]
# [(0, 0.2309044), (2, 0.21875763), (3, 0.11766904), (4, 0.3791537), (5, 0.052990552)]
# [(0, 0.95283026)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(0, 0.6568627), (5, 0.33006537)]
# [(1, 0.6119058), (2, 0.3750223)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(2, 0.98366016)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(2, 0.29594997), (3, 0.14305949), (4, 0.4150982), (5, 0.14305949)]
# [(4, 0.98366016)]
# [(0, 0.97572815)]
# [(1, 0.74137926), (2, 0.24876848)]
# [(1, 0.95283026)]
# [(1, 0.97572815)]
# [(0, 0.40595692), (2, 0.58419085)]
# [(1, 0.33006537), (2, 0.33006537), (3, 0.33006537)]
# [(2, 0.72285384), (4, 0.26729393)]
# [(0, 0.49029127), (1, 0.4902912)]
# [(3, 0.95283026)]
# [(1, 0.95283026)]
# [(0, 0.30674887), (1, 0.049920075), (2, 0.28603607), (3, 0.26490653), (4, 0.04288657), (5, 0.049501844)]
# [(0, 0.33006537), (1, 0.65686274)]
# [(2, 0.1558438), (3, 0.72803944), (4, 0.113629214)]
# [(2, 0.97572815)]
# [(0, 0.24792752), (1, 0.32968137), (2, 0.30827096), (3, 0.112132095)]
# [(2, 0.5116155), (3, 0.31676736), (4, 0.16666667)]
# [(1, 0.20197569), (3, 0.11309353), (4, 0.68161947)]
# [(1, 0.7809231), (4, 0.21117176)]
# [(0, 0.49254608), (1, 0.08977469), (2, 0.35730413), (5, 0.059202816)]
# [(5, 0.97572815)]
# [(4, 0.95283026)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(2, 0.23889247), (4, 0.49801198), (5, 0.26011348)]
# [(1, 0.97572815)]
# [(5, 0.97572815)]
# [(1, 0.3608486), (3, 0.6260795)]
# [(1, 0.24876851), (2, 0.7413793)]
# [(1, 0.4902912), (2, 0.49029127)]
# [(0, 0.24876848), (5, 0.7413793)]
# [(5, 0.95283026)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(0, 0.6818685), (3, 0.3082793)]
# [(1, 0.6568628), (3, 0.3300653)]
# [(0, 0.3102579), (2, 0.24632637), (4, 0.4416572)]
# [(4, 0.95283026)]
# [(4, 0.98366016)]
# [(0, 0.21806188), (1, 0.5764045), (4, 0.19960475)]
# [(2, 0.3999241), (3, 0.587004)]
# [(0, 0.49029127), (5, 0.49029127)]
# [(4, 0.95283026)]
# [(1, 0.19319133), (2, 0.800208)]
# [(0, 0.16260144), (1, 0.14890623), (2, 0.19467175), (5, 0.4921622)]
# [(2, 0.99174917)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.95283026)]
# [(0, 0.49029127), (2, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(5, 0.97572815)]
# [(0, 0.533539), (1, 0.21467473), (3, 0.12253934), (4, 0.12703936)]
# [(2, 0.95283026)]
# [(4, 0.95283026)]
# [(1, 0.4902912), (5, 0.49029127)]
# [(0, 0.33168313), (1, 0.35681242), (2, 0.3065539)]
# [(5, 0.97572815)]
# [(4, 0.98366016)]
# [(3, 0.95283026)]
# [(2, 0.98768467)]
# [(0, 0.04723032), (1, 0.07780872), (2, 0.21600945), (4, 0.38925555), (5, 0.26924264)]
# [(0, 0.19960475), (1, 0.3278127), (4, 0.46665367)]
# [(0, 0.47346485), (4, 0.18990149), (5, 0.33168316)]
# [(2, 0.24876848), (5, 0.7413793)]
# [(5, 0.95283026)]
# [(1, 0.4902912), (5, 0.49029127)]
# [(1, 0.09132007), (2, 0.18992372), (3, 0.6247137), (4, 0.09223417)]
# [(1, 0.99011856)]
# [(2, 0.5996897), (4, 0.39240512)]
# [(1, 0.38431215), (2, 0.15697457), (3, 0.31282094), (5, 0.14305949)]
# [(2, 0.98366016)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(2, 0.98366016)]
# [(0, 0.16666667), (1, 0.33168316), (2, 0.49669966)]
# [(4, 0.99011856)]
# [(0, 0.2140825), (2, 0.18234414), (3, 0.07183499), (4, 0.3880684), (5, 0.14295875)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(1, 0.78091663), (4, 0.21117827)]
# [(0, 0.236132), (2, 0.47491616), (3, 0.28470254)]
# [(0, 0.33006537), (3, 0.33006537), (5, 0.33006537)]
# [(2, 0.97572815)]
# [(2, 0.5948616), (3, 0.39723316)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(0, 0.3616521), (3, 0.625276)]
# [(1, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.95283026)]
# [(0, 0.33006537), (2, 0.65686274)]
# [(2, 0.49029127), (5, 0.4902912)]
# [(4, 0.66171616), (5, 0.33168316)]
# [(1, 0.60726565), (3, 0.37966245)]
# [(0, 0.37484092), (2, 0.32692593), (3, 0.13282125), (4, 0.16436256)]
# [(2, 0.97572815)]
# [(2, 0.97572815)]
# [(4, 0.97572815)]
# [(0, 0.20764583), (2, 0.78668845)]
# [(0, 0.63825864), (4, 0.34866944)]
# [(2, 0.98768467)]
# [(1, 0.39723322), (2, 0.5948617)]
# [(2, 0.97572815)]
# [(1, 0.95283026)]
# [(2, 0.98366016)]
# [(4, 0.97572815)]
# [(1, 0.97572815)]
# [(0, 0.33006537), (2, 0.6568627)]
# [(5, 0.95283026)]
# [(5, 0.95283026)]
# [(0, 0.24876845), (1, 0.24876845), (3, 0.49507388)]
# [(1, 0.77909386), (3, 0.213001)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(5, 0.97572815)]
# [(2, 0.97572815)]
# [(1, 0.7259615), (2, 0.26418632)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(3, 0.39723322), (4, 0.19960472), (5, 0.39723316)]
# [(1, 0.97572815)]
# [(0, 0.65686274), (5, 0.33006537)]
# [(3, 0.7413793), (4, 0.24876848)]
# [(0, 0.49029127), (3, 0.49029127)]
# [(0, 0.24876848), (3, 0.49507388), (5, 0.24876848)]
# [(0, 0.100397594), (1, 0.10361758), (3, 0.79300267)]
# [(4, 0.98366016)]
# [(1, 0.95283026)]
# [(4, 0.6568628), (5, 0.3300653)]
# [(2, 0.5547358), (4, 0.43541193)]
# [(1, 0.97572815)]
# [(1, 0.49029127), (5, 0.49029127)]
# [(1, 0.17345057), (2, 0.32421887), (4, 0.50033855)]
# [(0, 0.33006537), (1, 0.33006537), (2, 0.33006537)]
# [(0, 0.5417454), (3, 0.4451827)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(1, 0.67968345), (2, 0.31046426)]
# [(2, 0.97572815)]
# [(0, 0.2540534), (1, 0.73609436)]
# [(0, 0.21655682), (3, 0.3391051), (4, 0.4384092)]
# [(0, 0.14440644), (1, 0.19701423), (2, 0.14090057), (4, 0.32764813), (5, 0.1889269)]
# [(1, 0.6078921), (4, 0.379036)]
# [(2, 0.3947709), (4, 0.5953769)]
# [(2, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.39723322), (3, 0.5948617)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(0, 0.16666667), (1, 0.16666667), (2, 0.16666667), (3, 0.16666667), (4, 0.16666667), (5, 0.16666667)]
# [(1, 0.97572815)]
# [(0, 0.17430153), (2, 0.6540813), (5, 0.16666667)]
# [(0, 0.49029127), (1, 0.49029127)]
# [(4, 0.49029127), (5, 0.49029127)]
# [(4, 0.98366016)]
# [(2, 0.97572815)]
# [(1, 0.49029127), (4, 0.49029127)]
# [(1, 0.49507388), (2, 0.49507388)]
# [(1, 0.98366016)]
# [(4, 0.95283026)]
# [(4, 0.98366016)]
# [(0, 0.1029118), (1, 0.037324462), (2, 0.040075473), (3, 0.65049845), (4, 0.16882025)]
# [(0, 0.95283026)]
# [(0, 0.1796065), (1, 0.23695467), (2, 0.15791687), (3, 0.10160793), (4, 0.2129618), (5, 0.11095218)]
# [(1, 0.57896453), (5, 0.4111833)]
# [(0, 0.26661617), (1, 0.13513553), (2, 0.10628272), (4, 0.3531409), (5, 0.13792051)]
# [(0, 0.24876848), (1, 0.24876848), (2, 0.24876848), (3, 0.24876848)]
# [(1, 0.95283026)]
# [(2, 0.97572815)]
# [(3, 0.97572815)]
# [(2, 0.97572815)]
# [(0, 0.24876848), (1, 0.40218952), (2, 0.34165287)]
# [(2, 0.15689415), (3, 0.24422158), (4, 0.5961718)]
# [(0, 0.11147904), (1, 0.3596019), (2, 0.20415601), (4, 0.32255554)]
# [(0, 0.48086268), (4, 0.31360373), (5, 0.19960475)]
# [(4, 0.74137926), (5, 0.24876845)]
# [(1, 0.33006537), (2, 0.65686274)]
# [(1, 0.33006537), (2, 0.33006537), (3, 0.33006537)]

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#         Document_No  ...                                               Text
# 0                 0  ...                                [iklan, ganggu, as]
# 1                 1  ...                       [tolong, erti, pesan, pesan]
# 2                 2  ...                       [iklan, trossssssss, ganggu]
# 3                 3  ...  [ruwet, metode, bayar, indomart, mlh, cod, apl...
# 4                 4  ...  [dih, dwon, aplikasi, tipu, order, giveaway, h...
# ...             ...  ...                                                ...
# 761725       761725  ...  [belanja, shoppe, bantu, temu, barang, dng, ce...
# 761726       761726  ...  [sampai, sekarang, pakai, alhamdulilah, gapern...
# 761727       761727  ...  [enk, belanja, shopeee, tigkatkn, gratis, ongk...
# 761728       761728  ...                            [belanja, kirim, cepat]
# 761729       761729  ...                           [layan, belanja, shoope]
#
# [761730 rows x 5 columns]

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
  corpus_sel = corpus[start:end]
  dominant_topics = []
  topic_percentages = []
  for i, corp in enumerate(corpus_sel):
    topic_percs = model[corp]
    dominant_topic = sorted(topic_percs, key = lambda x:x[1], reverse=True)[0][0]
    dominant_topics.append((i, dominant_topic))
    topic_percentages.append(topic_percs)
  return(dominant_topics, topic_percentages)

# %%
dominant_topics, topic_percentages = topics_per_document(model=ldamodel, corpus=corpus, start=0, end=4)

# %%
# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])

dominant_topic_in_each_doc = df_dominant_topic.groupby('Dominant_Topic').size()
print(dominant_topic_in_each_doc)
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()
# Out:
# Dominant_Topic
# 0.0    136939
# 1.0    162218
# 2.0    173044
# 3.0    104618
# 4.0    114673
# 5.0     70238
# dtype: int64

# %%
# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# %%
# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in ldamodel.show_topics(formatted=False)for j, (topic, wt) in enumerate(topics) if j < 3]
df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(',\n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# ## Visualize

# %%
fig, ax1 = plt.subplots()

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', 
        data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x,pos: 'Topic  ' + str(x)+'\n'+ df_top3words.loc[df_top3words.topic_id==x,'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Topic Review', fontdict=dict(size=10))
ax1.set_ylabel('Count Review')
ax1.set_ylim(0,500000)

plt.show()
